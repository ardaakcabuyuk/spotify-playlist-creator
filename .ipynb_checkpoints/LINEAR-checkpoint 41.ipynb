# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'STARGAZING':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['Barbara Mason']", 'Got To Get You Off My Mind'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=5001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['La Sonora Santanera']", 'Palabras de Mujer'],
#         ["['The Dixie Cups']", 'Gee the Moon Is Shining Bright'],
#         ["['The Carter Family', 'Johnny Cash']",
#          "I'm Working on a Building"],
#         ...,
#         ["['Edu Da Gaita']", 'Espelha'],
#         ["['The Imperials']", 'Oh Buddha'],
#         ["['The Mamas & The Papas']", 'Twist And Shout']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.0006

# %%
relevance
# Out:
# 96.99999999997146

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.column_stack((predictions, song_info[:,0], song_info[:,1]))

# %%
sort_indices = np.argsort(predictions)[::-1]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[sort_indices]

# %%
list(predicted)
# Out:
# [array(['99.23621091246605', "['Sound Dreamer']",
#         'Brown Noise - 90 Minutes'], dtype='<U661'),
#  array(['98.98584720492363', "['Lightning, Thunder and Rain Storm']",
#         'Midnight Thunderstorm Part 2'], dtype='<U661'),
#  array(['98.91230902075768', "['Sleep']", 'Dopesmoker'], dtype='<U661'),
#  array(['98.85393536090851',
#         "['Richard Wagner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Bruno Walter Rehearses the Siegfried-Idyll'], dtype='<U661'),
#  array(['98.83571854233742', "['Umm Kulthum']", 'Salo Qalbe'],
#        dtype='<U661'),
#  array(['98.81887727975845', "['Umm Kulthum']", 'Ghana El Rabea'],
#        dtype='<U661'),
#  array(['98.80955657362938', "['Umm Kulthum']", 'Amal Hayate'],
#        dtype='<U661'),
#  array(['98.80921041965485', "['Umm Kulthum']", 'Gholobt Asaleh Fe Rohy'],
#        dtype='<U661'),
#  array(['98.80857589840889', "['Ocean Sounds']", 'Ocean Waves Sounds'],
#        dtype='<U661'),
#  array(['98.79731765389442', "['Umm Kulthum']", 'Raq El Habeb'],
#        dtype='<U661'),
#  array(['98.7869420349598', "['Umm Kulthum']", 'Ana Fe Entzark'],
#        dtype='<U661'),
#  array(['98.78677126765251', "['Ocean Waves For Sleep']",
#         'Ocean Waves for Sleep'], dtype='<U661'),
#  array(['98.77709433436394', "['Umm Kulthum']", 'Naheg El Berda'],
#        dtype='<U661'),
#  array(['98.76817375421524', "['Umm Kulthum']", 'Seret El Hob'],
#        dtype='<U661'),
#  array(['98.76806792616844', "['Fela Kuti']",
#         "Teacher Don't Teach Me Nonsense"], dtype='<U661'),
#  array(['98.76400822401047', "['Umm Kulthum']", 'Yalle Kan Yshgek Anene'],
#        dtype='<U661'),
#  array(['98.75439608097076', "['Pharoah Sanders']",
#         'The Creator Has A Master Plan'], dtype='<U661'),
#  array(['98.73663991689682', "['Umm Kulthum']", 'Robaaeyat El Khayam'],
#        dtype='<U661'),
#  array(['98.73547688126564', "['Umm Kulthum']", 'Sahran Lewahde'],
#        dtype='<U661'),
#  array(['98.70929154753685', "['Franklin Delano Roosevelt']",
#         'Address to Congress on Yalta - 03 01 1945'], dtype='<U661'),
#  array(['98.6907761991024', "['Blaise Cendrars']", 'Les Pâques a New York'],
#        dtype='<U661'),
#  array(['98.685840010643', "['Pankaj Mullick']", 'Mahaprasthaner Pathe'],
#        dtype='<U661'),
#  array(['98.67870119214058', "['Sonny Rollins Quintet']",
#         'Medley: I Remember You / My Melancholy Baby / Old Folks / They Can’t Take That Away From Me / Just Friends / My Little Suede Shoes / Star Eyes - Rudy Van Gelder Remaster'],
#        dtype='<U661'),
#  array(['98.6772665977478', "['Emerson, Lake & Palmer']",
#         'Karn Evil 9 - i. 1st Impression, ii. 2nd Impression, iii. 3rd Impression; Live 1974; 2016 - Remaster'],
#        dtype='<U661'),
#  array(['98.6766332089901', "['Miles Davis']", "Sid's Ahead"],
#        dtype='<U661'),
#  array(['98.67647105455399', "['Clifford Brown All Stars']", 'Coronado'],
#        dtype='<U661'),
#  array(['98.67586541175842', "['Jerry Garcia Band', 'Jerry Garcia']",
#         "Don't Let Go - Bonus Track"], dtype='<U661'),
#  array(['98.67399567365646', "['Juanes']", 'Nada Valgo Sin Tu Amor'],
#        dtype='<U661'),
#  array(['98.67345279455185', "['Cali Y El Dandee', 'Rauw Alejandro']",
#         'Tequila Sunrise'], dtype='<U661'),
#  array(['98.67229473590851',
#         "['Giuseppe Verdi', 'Robert Bowman', 'Michael Langdon', 'Fernando Corena', 'Regina Resnik', 'The New Symphony Orchestra Of London', 'Sir Edward Downes']",
#         'Falstaff / Act 2: Siam pentiti e contriti...Reverenza'],
#        dtype='<U661'),
#  array(['98.67079105973244', "['Clifford Brown All Stars']", 'Coronado'],
#        dtype='<U661'),
#  array(['98.670359313488', "['Jethro Tull']",
#         'Thick as a Brick (Pt. I) - 1997 Remaster'], dtype='<U661'),
#  array(['98.66996654868126', "['Genesis']",
#         "Supper's Ready - Live in Paris"], dtype='<U661'),
#  array(['98.66933542490005', "['Umm Kulthum']", 'Faker Lma Kont Ganby'],
#        dtype='<U661'),
#  array(['98.66861563920975', "['Alekos Dimou']", 'Osoi eis Xriston'],
#        dtype='<U661'),
#  array(['98.66839775443077', "['Cali Y El Dandee', 'Sebastian Yatra']",
#         'Locura'], dtype='<U661'),
#  array(['98.66643235087395', "['Juanes']", 'Volverte A Ver'], dtype='<U661'),
#  array(['98.66485387086868', "['Cali Y El Dandee', 'Piso 21']",
#         'Voy Por Ti'], dtype='<U661'),
#  array(['98.66445010900497', "['Juanes']", 'Volverte A Ver'], dtype='<U661'),
#  array(['98.66262328624725', "['Luis Fonsi', 'Demi Lovato']",
#         'Échame La Culpa'], dtype='<U661'),
#  array(['98.66221594810486', "['LANY']", 'Super Far'], dtype='<U661'),
#  array(['98.66157639026642',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Das Lied von der Erde: VI. Der Abschied'], dtype='<U661'),
#  array(['98.66037273406982', "['Jethro Tull']",
#         'Thick as a Brick (Pt. II) - 1997 Remaster'], dtype='<U661'),
#  array(['98.65959596633911', "['Yes']",
#         'The Revealing Science of God (Dance of the Dawn)'], dtype='<U661'),
#  array(['98.65826001763344', "['Rush']", 'Cygnus X-1 Book II: Hemispheres'],
#        dtype='<U661'),
#  array(['98.65732452273369', "['Charles Mingus']",
#         'Medley: Mode D-Trio and Group Dancers/Mode E- Single solos and Group Dance/ModeF-Group and Solo Dance'],
#        dtype='<U661'),
#  array(['98.65719121694565',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Das Lied von der Erde: VI. Der Abschied'], dtype='<U661'),
#  array(['98.65676689147949', "['Grateful Dead']",
#         'Turn on Your Lovelight - Live at Fillmore East, New York City, April 1971'],
#        dtype='<U661'),
#  array(['98.65597131848335', "['Marshmello', 'Bastille']", 'Happier'],
#        dtype='<U661'),
#  array(['98.65529742836952', "['Jack Johnson']", 'Better Together'],
#        dtype='<U661'),
#  array(['98.65496072173119', "['Juanes']", 'A Dios Le Pido'], dtype='<U661'),
#  array(['98.65444177389145', "['Miles Davis']", 'Star People'],
#        dtype='<U661'),
#  array(['98.65331518650055', "['Jack Johnson']", 'Better Together'],
#        dtype='<U661'),
#  array(['98.65331518650055', "['Jack Johnson']", 'Better Together'],
#        dtype='<U661'),
#  array(['98.65316507220268', "['Brian Eno']",
#         'Thursday Afternoon - 2005 Digital Remaster'], dtype='<U661'),
#  array(['98.65311849117279', "['Rush']", 'The Fountain Of Lamneth'],
#        dtype='<U661'),
#  array(['98.65137764811516', "['Glenn Gould', 'SYMPHONIA QUARTET']",
#         'String Quartet, Op. 1'], dtype='<U661'),
#  array(['98.65049082040787', "['Chuck Riley']", 'Aladdin - Storyteller'],
#        dtype='<U661'),
#  array(['98.65027114748955', "['Lorde']", 'Royals'], dtype='<U661'),
#  array(['98.64999562501907', "['Yes']",
#         'The Revealing Science of God (Dance of the Dawn) - 2003 Remaster'],
#        dtype='<U661'),
#  array(['98.64864614605904', "['Bryan Adams']",
#         '(Everything I Do) I Do It For You - 2017 Ultimate Edit'],
#        dtype='<U661'),
#  array(['98.64813870191574', "['Charles Mingus']",
#         'C Jam Blues - Live Version'], dtype='<U661'),
#  array(['98.64658638834953', "['Fela Kuti', 'Roy Ayers']",
#         '2000 Blacks Got To Be Free (feat. Roy Ayers)'], dtype='<U661'),
#  array(['98.64559581875801', "['George Clinton']",
#         "Man's Best Friend / Loopzilla"], dtype='<U661'),
#  array(['98.64417001605034', "['Don Omar']", 'Pobre Diabla'], dtype='<U661'),
#  array(['98.64385083317757', "['Tropicalísimo Apache']", 'Apache Mix'],
#        dtype='<U661'),
#  array(['98.64149680733681', "['Fela Kuti']", "Je'nwi Temi (Don't Gag Me)"],
#        dtype='<U661'),
#  array(['98.64146682620049', "['Keith Emerson']",
#         'Tarkus (i. Eruption / ii. Stones of Years / iii. Iconoclast / iv. Mass / v. Manticore / vi. Battlefield / vii. Aquatarkus) [2012 Remastered Version]'],
#        dtype='<U661'),
#  array(['98.6410961151123', "['Bastille']", 'Pompeii'], dtype='<U661'),
#  array(['98.6406762599945', "['Becky Hill']", 'Losing - Joe Goddard Remix'],
#        dtype='<U661'),
#  array(['98.63986703753471',
#         "['Gustav Mahler', 'Kathleen Ferrier', 'Wiener Philharmoniker', 'Bruno Walter']",
#         'Das Lied von der Erde: 6. Der Abschied'], dtype='<U661'),
#  array(['98.63926967978477', "['Rush']", 'Cygnus X-1 Book II: Hemispheres'],
#        dtype='<U661'),
#  array(['98.63902774453163', "['Arijit Singh']", 'Tomar Dyakha Naai'],
#        dtype='<U661'),
#  array(['98.63850596547127', "['Rush']",
#         '2112: Overture / The Temples Of Syrinx / Discovery / Presentation / Oracle / Soliloquy / Grand Finale - Medley'],
#        dtype='<U661'),
#  array(['98.63816040754318',
#         "['Sergei Prokofiev', 'New York Philharmonic', 'Leonard Bernstein']",
#         'Peter and the Wolf, Op. 67'], dtype='<U661'),
#  array(['98.63810712099075', "['The Offspring']", 'Smash'], dtype='<U661'),
#  array(['98.6375261247158', "['Flo Rida']", 'Right Round (US Version)'],
#        dtype='<U661'),
#  array(['98.63646811246872', "['CAN']", 'You Doo Right'], dtype='<U661'),
#  array(['98.63510861992836', "['Rick James']",
#         'You And I - Extended M+M Mix'], dtype='<U661'),
#  array(['98.63433226943016', "['Van Morrison']", 'Summertime In England'],
#        dtype='<U661'),
#  array(['98.6340771317482', "['Johnny Hodges', 'Gerry Mulligan']",
#         'Back Beat'], dtype='<U661'),
#  array(['98.63373357057571', "['Bob Dylan']",
#         'Desolation Row - Alternate Take'], dtype='<U661'),
#  array(['98.63365584611893', "['Alejandro Fernández', 'Morat']",
#         'Sé Que Te Duele'], dtype='<U661'),
#  array(['98.6335800588131', '[\'Cherrelle\', "Alexander O\'Neal"]',
#         'Saturday Love'], dtype='<U661'),
#  array(['98.63320246338844', "['Sebastian Yatra']",
#         'Devuélveme El Corazón'], dtype='<U661'),
#  array(['98.63315269351006', "['Morat']", 'Cómo Te Atreves'], dtype='<U661'),
#  array(['98.63282132148743', "['Ice Cube', 'George Clinton']",
#         'Bop Gun (One Nation)'], dtype='<U661'),
#  array(['98.63244190812111', "['Avicii']", 'Wake Me Up - Radio Edit'],
#        dtype='<U661'),
#  array(['98.63244190812111', "['Avicii']", 'Wake Me Up - Radio Edit'],
#        dtype='<U661'),
#  array(['98.63210099935532', "['Juanes', 'Nelly Furtado']", 'Fotografía'],
#        dtype='<U661'),
#  array(['98.63209575414658', "['Maryline Garcia & Christophe da Silva']",
#         'Eu Ouvi um Passarinho'], dtype='<U661'),
#  array(['98.63191777467728', "['Black Eyed Peas']", 'I Gotta Feeling'],
#        dtype='<U661'),
#  array(['98.6317510008812', "['Morat']",
#         'En Un Sólo Dia - Versión Acústica'], dtype='<U661'),
#  array(['98.63078793883324', "['Gerry Mulligan Band']", "Mulligan's Too"],
#        dtype='<U661'),
#  array(['98.6304524242878', "['Genesis']",
#         'Driving the Last Spike - 2007 Remaster'], dtype='<U661'),
#  array(['98.63028725981712',
#         '[\'Sergei Prokofiev\', \'Gérard Philipe\', "Orchestre Symphonique De l\'U.R.S.S", \'Guennadi Rojdestvenski\']',
#         'Pierre et le Loup'], dtype='<U661'),
#  array(['98.6299355328083', "['Black Eyed Peas']", 'I Gotta Feeling'],
#        dtype='<U661'),
#  array(['98.62975281476974', "['Mad Dog', 'Meltdown']", 'Oh Yeah Oh Yeah'],
#        dtype='<U661'),
#  array(['98.62921550869942', "['Big Bub']", 'Zoom'], dtype='<U661'),
#  array(['98.6290063560009', "['Prince']", 'Automatic - 2019 Remaster'],
#        dtype='<U661'),
#  array(['98.62841147184372', "['Daryl Hall & John Oates']",
#         'Your Imagination - Disco Remix'], dtype='<U661'),
#  array(['98.6283347606659', "['Queen']",
#         'I Want To Break Free - Extended Mix'], dtype='<U661'),
#  array(['98.62801942229271',
#         "['John Coltrane', 'Red Garland', 'Paul Chambers', 'Art Taylor']",
#         'Little Melonae - RVG Remaster'], dtype='<U661'),
#  array(['98.62761425971985', "['Arijit Singh']", 'Ore Mon Udashi'],
#        dtype='<U661'),
#  array(['98.6274428665638', "['Usher']", 'I Will'], dtype='<U661'),
#  array(['98.62719720602036', "['Umm Kulthum']", 'Yatol Azaby'],
#        dtype='<U661'),
#  array(['98.62614810466766', "['Stevie Wonder']",
#         'Superstition - Single Version'], dtype='<U661'),
#  array(['98.62550064921379', "['Paul Bridgwater']", 'Cry Cry'],
#        dtype='<U661'),
#  array(['98.62512063980103', "['Sebastian Yatra', 'Wisin', 'Nacho']",
#         'Alguien Robo'], dtype='<U661'),
#  array(['98.62476778030396', "['Morat', 'Juanes']", 'Besos En Guerra'],
#        dtype='<U661'),
#  array(['98.62460222840309', "['Gusttavo Lima']", 'Perrengue - Ao Vivo'],
#        dtype='<U661'),
#  array(['98.62426885962486', "['Talking Heads']",
#         'Television Man - Extended Mix'], dtype='<U661'),
#  array(['98.6240838766098', "['Ellie Goulding']",
#         'How Long Will I Love You'], dtype='<U661'),
#  array(['98.62389981746674', "['Luis Fonsi']", 'Corazón En La Maleta'],
#        dtype='<U661'),
#  array(['98.62389981746674', "['Luis Fonsi']", 'Corazón En La Maleta'],
#        dtype='<U661'),
#  array(['98.62347820401192', "['Why Not']", 'Angel'], dtype='<U661'),
#  array(['98.62333768606186', "['Generación 12']",
#         'Dios Incomparable (Invitado: Marco Barrientos)'], dtype='<U661'),
#  array(['98.6232779622078', "['Angel Garcia y Tino Lopez']",
#         'Con La Prensa Me Agarraron'], dtype='<U661'),
#  array(['98.62309744954109', "['Peter Tosh']",
#         'Stand Firm - 2002 Remaster'], dtype='<U661'),
#  array(['98.6230075955391', "['Miles Davis']", 'Maiysha'], dtype='<U661'),
#  array(['98.62214580178261', "['Prince']", 'D.M.S.R. - 2019 Remaster'],
#        dtype='<U661'),
#  array(['98.6221336722374', "['John Coltrane']", 'Tunji'], dtype='<U661'),
#  array(['98.62210163474083', "['Ellie Goulding']",
#         'How Long Will I Love You'], dtype='<U661'),
#  array(['98.62163135409355', "['Roger']",
#         'I Heard It Through the Grapevine'], dtype='<U661'),
#  array(['98.6215207874775', "['Queen']", 'Dancer - Remastered 2011'],
#        dtype='<U661'),
#  array(['98.6213176548481', "['Paul Bridgwater', 'Geoff Horgan']",
#         "I Don't Mind"], dtype='<U661'),
#  array(['98.6211109161377', '[\'Johnny "Guitar" Watson\']',
#         'I Wanna Thank You'], dtype='<U661'),
#  array(['98.62096837162971', "['James Brown']", 'Cold Sweat'],
#        dtype='<U661'),
#  array(['98.6202801167965', "['Sonny Rollins']",
#         'If Ever I Would Leave You'], dtype='<U661'),
#  array(['98.62007594108582', "['Fela Kuti']", 'Confusion (Parts 1 & 2)'],
#        dtype='<U661'),
#  array(['98.62003293633461', "['Wade Bowen']", 'Mood Ring'], dtype='<U661'),
#  array(['98.61940956115723', "['Miles Davis']",
#         'Straight, No Chaser - alternate take'], dtype='<U661'),
#  array(['98.61933064460754', "['Frankie Smith']",
#         'Double Dutch Bus - Original 12'], dtype='<U661'),
#  array(['98.61862659454346',
#         "['Dimitri Vegas & Like Mike', 'Like Mike', 'Vangosh', 'Pedro Henriques']",
#         'Deeper Love - Pedro Henriques Remix'], dtype='<U661'),
#  array(['98.6185382604599', "['Michael Salgado']",
#         'The Ultimate Power Mix'], dtype='<U661'),
#  array(['98.6181371808052', "['Ellie Goulding']",
#         'How Long Will I Love You'], dtype='<U661'),
#  array(['98.61798509955406', "['Spoon']", 'I Turn My Camera On'],
#        dtype='<U661'),
#  array(['98.61798438429832', "['EOR']", 'Offese'], dtype='<U661'),
#  array(['98.61787980794907', "['Yes']",
#         'And You and I - Alternate Version'], dtype='<U661'),
#  array(['98.61785846948624', "['OneRepublic']", 'Counting Stars'],
#        dtype='<U661'),
#  array(['98.61783787608147', "['Miles Davis']", "Sid's Ahead"],
#        dtype='<U661'),
#  array(['98.61764147877693', "['John Coltrane']",
#         'A Love Supreme Pt. III - Pursuance - Live In Juan-les-Pins, France/1965'],
#        dtype='<U661'),
#  array(['98.61755812168121', "['Steve Stills', 'Al Kooper']",
#         'Season of the Witch'], dtype='<U661'),
#  array(['98.61747348308563', "['Erykah Badu']", 'Bump It'], dtype='<U661'),
#  array(['98.61730924248695', "['Bastille']", 'Pompeii'], dtype='<U661'),
#  array(['98.61724215745926', "['Peter Frampton', 'Chris Kimsey']",
#         'Do You Feel Like We Do - Live'], dtype='<U661'),
#  array(['98.61723193526268', "['Gusttavo Lima']",
#         'Contador de Reencontros - Ao Vivo'], dtype='<U661'),
#  array(['98.61711552739143', "['John Coltrane']",
#         'India - Live At The Village Vanguard, New York/1961'],
#        dtype='<U661'),
#  array(['98.61711180210114',
#         '[\'Igor Stravinsky\', "L\'Orchestre de la Suisse Romande", \'Ernest Ansermet\']',
#         'Le Sacre du Printemps - Version for Orchestra (published 1921): Part 2: The Sacrifice'],
#        dtype='<U661'),
#  array(['98.61656519770622', "['Fleetwood Mac']",
#         'Sara (3/10/79) - 3/10/79; 2015 Remaster'], dtype='<U661'),
#  array(['98.61610513925552', "['Rickie Lee Jones']",
#         'Weasel and the White Boys Cool'], dtype='<U661'),
#  array(['98.6160175204277', "['Loleatta Holloway']",
#         'Hit and Run - 12" Mix'], dtype='<U661'),
#  array(['98.61596018075943', "['Gusttavo Lima']",
#         'Até a Garrafa Chora - Ao Vivo'], dtype='<U661'),
#  array(['98.61584860086441', "['Lauv']", 'Feelings'], dtype='<U661'),
#  array(['98.61564871668816',
#         "['Kintero Shinigami', 'One Shot Jones', '2nd Generation Outlawz', 'Fallout Beatz']",
#         'Just Know'], dtype='<U661'),
#  array(['98.61547848582268', "['Tony! Toni! Toné!']", 'I Care'],
#        dtype='<U661'),
#  array(['98.61524969339371', "['Gusttavo Lima']",
#         'Contador de Reencontros - Ao Vivo'], dtype='<U661'),
#  array(['98.61521917581558', "['Eminem']", 'Without Me'], dtype='<U661'),
#  array(['98.61501425504684', "['Tenor Saw']", 'Roll Call'], dtype='<U661'),
#  array(['98.61484110355377', "['Keith Washington', 'Chanté Moore']",
#         'I Love You'], dtype='<U661'),
#  array(['98.6146414577961', "['William Onyeabor']", 'Atomic Bomb'],
#        dtype='<U661'),
#  array(['98.61450666189194', "['Annette Peacock']", 'Survival'],
#        dtype='<U661'),
#  array(['98.61431229114532', "['Sublime']", 'Slow Ride'], dtype='<U661'),
#  array(['98.61361110210419', "['Kenny Burrell', 'John Coltrane']",
#         'Big Paul'], dtype='<U661'),
#  array(['98.61341491341591', "['Tony! Toni! Toné!']", 'Anniversary'],
#        dtype='<U661'),
#  array(['98.61336362361908', "['Johnny Hodges & His Orchestra']",
#         'Reeling And Rocking'], dtype='<U661'),
#  array(['98.61311227083206',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 4 - Dialogues'], dtype='<U661'),
#  array(['98.6130653321743', "['Peter Tosh']", 'Downpressor Man'],
#        dtype='<U661'),
#  array(['98.61303213238716', "['Lakeside']", 'I Want to Hold Your Hand'],
#        dtype='<U661'),
#  array(['98.61302843689919', "['Orchestra Studio 7']",
#         'Reginella - Instrument and base Version'], dtype='<U661'),
#  array(['98.61288431286812', "['Brian McKnight']", 'Hold Me'],
#        dtype='<U661'),
#  array(['98.61285519599915', "['Lauv', 'LANY']", 'Mean It'], dtype='<U661'),
#  array(['98.6124378144741', "['Metallica']", 'Loverman'], dtype='<U661'),
#  array(['98.61191177368164', "['OneRepublic']", 'Counting Stars'],
#        dtype='<U661'),
#  array(['98.6119039952755', "['Orchestra Studio 7']",
#         'Agata - Instrument and base Version'], dtype='<U661'),
#  array(['98.6115787923336', "['The Fixx']",
#         'Deeper And Deeper - Long Version'], dtype='<U661'),
#  array(['98.61149564385414',
#         "['Kodak Black', 'Mike Smiff', 'WizDaWizard']",
#         'VULTURES CRY 2 (feat. WizDaWizard and Mike Smiff)'], dtype='<U661'),
#  array(['98.61128124594688', "['Tim Maia']", 'Rational Culture'],
#        dtype='<U661'),
#  array(['98.61124357581139', "['Public Announcement']",
#         "Body Bumpin' (Yippie-Yi-Yo)"], dtype='<U661'),
#  array(['98.61122208833694', "['Black Harmony']",
#         "Don't Let It Go to Your Head"], dtype='<U661'),
#  array(['98.61102265119553',
#         "['Claude Debussy', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'La Damoiselle élue, L. 62'], dtype='<U661'),
#  array(['98.61097404360771', "['John Coltrane']", 'Ole'], dtype='<U661'),
#  array(['98.61087429523468', "['Ago']", 'For You - Original Album'],
#        dtype='<U661'),
#  array(['98.61080995202065',
#         "['Al Kooper', 'Mike Bloomfield', 'Stephen Stills']",
#         'Season of the Witch - 2002 Remix w/o Horns'], dtype='<U661'),
#  array(['98.61076360940933', "['The Human League']",
#         'Human - Extended Version'], dtype='<U661'),
#  array(['98.61070862412453', "['Miles Davis']", 'Country Son'],
#        dtype='<U661'),
#  array(['98.61066994071007', "['Franklin Delano Roosevelt']",
#         'On Sacrifice and Losses - 04 28 1948'], dtype='<U661'),
#  array(['98.61024168133736', "['Midnight Star']", 'Electricity'],
#        dtype='<U661'),
#  array(['98.61005303263664', "['Abdel Halim Hafez']",
#         'فاتت جنبنا تسجيل حفلة'], dtype='<U661'),
#  array(['98.61002358794212', "['Alabama']", 'Take Me Down'], dtype='<U661'),
#  array(['98.6100178360939', "['Midnight Star']", 'Electricity'],
#        dtype='<U661'),
#  array(['98.60982266068459', "['Strafe']", 'Set It Off (Vocal)'],
#        dtype='<U661'),
#  array(['98.60964232683182', "['Levert']", "Smilin'"], dtype='<U661'),
#  array(['98.60955545306206', "['Jerry Garcia Band', 'Jerry Garcia']",
#         'Rain'], dtype='<U661'),
#  array(['98.60953652858734', "['Bobby Brown', 'Louil Silas Jr.']",
#         "Don't Be Cruel - Remix"], dtype='<U661'),
#  array(['98.60950139164925', "['Miles Davis']",
#         'All of You - alternate take'], dtype='<U661'),
#  array(['98.60950082540512', '[\'Evelyn "Champagne" King\']', 'Stop That'],
#        dtype='<U661'),
#  array(['98.60922348499298', "['My Morning Jacket']", 'Phone Went West'],
#        dtype='<U661'),
#  array(['98.60910740494728', "['Bob Seger']", 'Little Victories'],
#        dtype='<U661'),
#  array(['98.60902941226959', "['Tom Petty and the Heartbreakers']", 'Echo'],
#        dtype='<U661'),
#  array(['98.6090090572834', "['Charlie Wilson']", "Let's Chill"],
#        dtype='<U661'),
#  array(['98.60899537801743', "['Jeff Floyd']",
#         'I Found Love (On A Lonely Highway)'], dtype='<U661'),
#  array(['98.60891655087471', "['Sweetback']", 'You Will Rise'],
#        dtype='<U661'),
#  array(['98.6087979376316', "['Surface']",
#         'Closer Than Friends - Single Version'], dtype='<U661'),
#  array(['98.60867241024971', "['La Tropa Vallenata']",
#         'Popurri Festival Vallenato'], dtype='<U661'),
#  array(['98.60845026373863',
#         "['One Nation Experience', 'Phil Bates', 'Lea Hart', 'Sugar T.', 'Jackie Deane', 'Irie White', 'The Nice Guys', 'Rick Chase', 'Dennis Jarrett', 'Alvin Davis']",
#         'Everyone Got To Be Free - Remastered Mix'], dtype='<U661'),
#  array(['98.60839149355888', "['Roger']", 'Do It Roger'], dtype='<U661'),
#  array(['98.60835680365562', "['Dead Can Dance']", 'Xavier (Remastered)'],
#        dtype='<U661'),
#  array(['98.60834902524948', "['Travis Greene']", 'Made A Way'],
#        dtype='<U661'),
#  array(['98.60829210281372',
#         "['Luis Fonsi', 'Daddy Yankee', 'Justin Bieber']",
#         'Despacito - Remix'], dtype='<U661'),
#  array(['98.6081628203392', "['Brian McKnight', 'Mase']",
#         "You Should Be Mine (Don't Waste Your Time)"], dtype='<U661'),
#  array(['98.60813003778458', "['Fela Kuti']",
#         'Mistake (Live At The Berlin Jazz Festival - 1978)'], dtype='<U661'),
#  array(['98.60811173915863',
#         "['Johannes Brahms', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'I. Allegro non troppo'], dtype='<U661'),
#  array(['98.60805463790894', "['Alekos Dimou']", 'Aksion esti'],
#        dtype='<U661'),
#  array(['98.60802468657494', "['B2K']", 'Gots Ta Be'], dtype='<U661'),
#  array(['98.60789403319359', "['NOFX']", 'The Decline'], dtype='<U661'),
#  array(['98.6078932583332', "['Tonéx', 'Peculiar People']", 'Make Me Over'],
#        dtype='<U661'),
#  array(['98.60782194137573', "['Three 6 Mafia']", 'Late Night Tip'],
#        dtype='<U661'),
#  array(['98.60781061649323', "['Lakeside']", 'Raid'], dtype='<U661'),
#  array(['98.60775807499886', "['Montell Jordan']", 'Falling'],
#        dtype='<U661'),
#  array(['98.60758963227272', "['Grand Funk Railroad']",
#         "I'm Your Captain/Closer To Home"], dtype='<U661'),
#  array(['98.60752895474434', "['New Ridaz']", 'Special Girl'],
#        dtype='<U661'),
#  array(['98.60748758912086', "['The Marshall Tucker Band']",
#         "I Should Have Never Started Lovin' You"], dtype='<U661'),
#  array(['98.60744735598564', "['Shanice']", 'When I Close My Eyes'],
#        dtype='<U661'),
#  array(['98.60720068216324', "['Rush']",
#         '2112: Overture / The Temples Of Syrinx / Discovery / Presentation / Oracle / Soliloquy / Grand Finale - Medley'],
#        dtype='<U661'),
#  array(['98.60713255405426', "['Rick James']", 'Come Into My Life'],
#        dtype='<U661'),
#  array(['98.60699129104614', "['Alejandro Fernández']",
#         'Me Olvidé De Vivir'], dtype='<U661'),
#  array(['98.60693094134331', "['Mike Posner']", 'Drug Dealer Girl'],
#        dtype='<U661'),
#  array(['98.60685792565346', "['Dru Hill']", 'You Are Everything'],
#        dtype='<U661'),
#  array(['98.60671165585518', "['Gerry Mulligan']", "Mulligan's Too"],
#        dtype='<U661'),
#  array(['98.6067086160183', "['Foreigner']", 'Head Games'], dtype='<U661'),
#  array(['98.60667517781258', "['Raquel Meller']",
#         'Si Yo Tuviera un Millón'], dtype='<U661'),
#  array(['98.60667222738266', "['Mary J. Blige']", 'Missing You'],
#        dtype='<U661'),
#  array(['98.60658407211304', "['Warren Haynes']",
#         'Do You Feel Like We Do - Live'], dtype='<U661'),
#  array(['98.60632562637329', "['Public Announcement']",
#         'John Doe featuring MZ Lelee'], dtype='<U661'),
#  array(['98.60622256994247', "['Yes']", 'And You and I'], dtype='<U661'),
#  array(['98.60615861415863', "['Blue Scholars']", 'No Rest For The Weary'],
#        dtype='<U661'),
#  array(['98.6060531437397', "['OneRepublic']", 'Apologize'], dtype='<U661'),
#  array(['98.60602849721909',
#         "['Dizzy Gillespie', 'Sonny Rollins', 'Sonny Stitt']", "Anythin'"],
#        dtype='<U661'),
#  array(['98.60593411326408', "['Donna Summer']", 'Love To Love You Baby'],
#        dtype='<U661'),
#  array(['98.60590848326683', "['Big Time Rush']", 'No Idea'], dtype='<U661'),
#  array(['98.60587644577026', "['Horace Brown']", 'One For The Money'],
#        dtype='<U661'),
#  array(['98.60572904348373', "['President Franklin Delano Roosevelt']",
#         'State of the Union Address (January 7, 1943)'], dtype='<U661'),
#  array(['98.605672031641', "['Bell Biv DeVoe']", 'Word To The Mutha!'],
#        dtype='<U661'),
#  array(['98.60558152198792', "['Kim Gun Mo']", 'Excuses'], dtype='<U661'),
#  array(['98.60538271069527', "['2 Crows']", 'La vie (still) en rose'],
#        dtype='<U661'),
#  array(['98.6053327023983', "['Pet Shop Boys']",
#         'Go West - 2018 Remaster; Hidden Track'], dtype='<U661'),
#  array(['98.60527113080025', "['Midnight Star']", 'Feels so Good'],
#        dtype='<U661'),
#  array(['98.60523867607117', "['Usher']", 'Bedtime'], dtype='<U661'),
#  array(['98.60519155859947', "['The Kinks']",
#         'Sunny Afternoon - Alternate Stereo Mix'], dtype='<U661'),
#  array(['98.60501030087471', "['Jimmy Buffett']",
#         'Sending The Old Man Home'], dtype='<U661'),
#  array(['98.60483965277672', "['Frances Faye']", 'She Looks - Bonus Track'],
#        dtype='<U661'),
#  array(['98.60478365421295', "['Xscape']", "Am I Dreamin'"], dtype='<U661'),
#  array(['98.60465550422668', "['Orchestra Studio 7']",
#         "Palomma 'e notte - Musical base Version"], dtype='<U661'),
#  array(['98.60464143753052',
#         "['Ludwig van Beethoven', 'Jascha Heifetz', 'Charles Münch', 'Boston Symphony Orchestra']",
#         'Violin Concerto in D Major, Op. 61: I. Allegro, ma non troppo'],
#        dtype='<U661'),
#  array(['98.60437256097794', "['Willie Nelson']",
#         "Red Headed Stranger Medley - Live at Harrah's Casino, Lake Tahoe, NV - April 1978"],
#        dtype='<U661'),
#  array(['98.6043426990509', "['Nahko And Medicine For The People']",
#         'Black As Night'], dtype='<U661'),
#  array(['98.6043319106102', "['Perfect Confusion']",
#         'Make Peace and be Free'], dtype='<U661'),
#  array(['98.60418197512627', "['Van Morrison', 'Brooks Arthur']",
#         'Santa Fe / Beautiful Obsession - Remastered'], dtype='<U661'),
#  array(['98.60417351126671', "['Gabrielle']", 'Sunshine'], dtype='<U661'),
#  array(['98.60406097769737', "['Talking Heads', 'Jerry Harrison']",
#         'City of Dreams - 2005 Remaster'], dtype='<U661'),
#  array(['98.60401257872581', "['Fela Kuti']", 'Yellow Fever'],
#        dtype='<U661'),
#  array(['98.60394340753555', "['Sublime']", 'Get Ready'], dtype='<U661'),
#  array(['98.6037093102932', "['Daryl Hall & John Oates']",
#         "You've Lost That Lovin' Feeling"], dtype='<U661'),
#  array(['98.60370829701424', "['Modest Mouse']", 'Heart Cooks Brain'],
#        dtype='<U661'),
#  array(['98.60369727015495', "['B2K']", 'Why I Love You'], dtype='<U661'),
#  array(['98.60352712869644', "['The Wallflowers']", 'One Headlight'],
#        dtype='<U661'),
#  array(['98.60350868105888',
#         "['Luis Fonsi', 'Aleks Syntek', 'Noel Schajris', 'David Bisbal']",
#         'Aqui Estoy Yo'], dtype='<U661'),
#  array(['98.60350567102432', "['Nomy']", 'Tempo - LOL Edit'], dtype='<U661'),
#  array(['98.60337972640991', "['Monique Nikkole']", 'This Christmas'],
#        dtype='<U661'),
#  array(['98.60325711965561', "['Lakeside']", 'Given in to Love'],
#        dtype='<U661'),
#  array(['98.60309010744095', "['John Mellencamp']", 'Tonight'],
#        dtype='<U661'),
#  array(['98.60304141044617',
#         "['Erik Satie', 'Darius Milhaud', 'Suzanne Danco', 'Orchestra Sinfonica Della Rai Di Roma']",
#         'Socrate: III. La mort de Socrate'], dtype='<U661'),
#  array(['98.60290002822876', "['9 Days Wonder']", '10,000 Summers'],
#        dtype='<U661'),
#  array(['98.60284826159477', "['Donald Byrd']",
#         'High Energy - Original 12" Version'], dtype='<U661'),
#  array(['98.60283920168877', "['Ruff Endz']", 'Someone To Love You'],
#        dtype='<U661'),
#  array(['98.60278236865997', "['Miles Davis']", 'Little Melonae'],
#        dtype='<U661'),
#  array(['98.60272091627121', "['Yellowman']", 'Yellowman Getting Married'],
#        dtype='<U661'),
#  array(['98.6026294529438', "['Kierra Sheard', 'BRL']",
#         'Indescribable - Live'], dtype='<U661'),
#  array(['98.60261023044586', "['Cameo']", 'Why Have I Lost You'],
#        dtype='<U661'),
#  array(['98.60252317786217', "['Lauv']", 'Chasing Fire'], dtype='<U661'),
#  array(['98.6024529337883', "['Stars On 45']",
#         'Stars On 45 - Original 12-Inch Version'], dtype='<U661'),
#  array(['98.60243684053421', "['The Notorious B.I.G.']",
#         'Big Poppa - Instrumental; 2014 Remaster'], dtype='<U661'),
#  array(['98.60237345099449', "['Run–D.M.C.']", "Jam-Master Jammin'"],
#        dtype='<U661'),
#  array(['98.60235130786896', "['Dave Matthews Band']",
#         'Seek Up - Live at Red Rocks Amphitheatre, Morrison, CO - August 1995'],
#        dtype='<U661'),
#  array(['98.60213330388069', "['Yarbrough & Peoples']", 'Guilty'],
#        dtype='<U661'),
#  array(['98.60207024216652', "['Black Sabbath']",
#         'A Bit of Finger / Sleeping Village / Warning - 2013 Remaster'],
#        dtype='<U661'),
#  array(['98.60193225741386', "['Aroma']", 'Querido Ladrón'], dtype='<U661'),
#  array(['98.60183253884315', "['Pelle Törner tolkar Evert Taube']",
#         'Invitation till Guatemala'], dtype='<U661'),
#  array(['98.60181745886803', "['Faith Evans', 'Carl Thomas']",
#         "Can't Believe (feat. Carl Thomas)"], dtype='<U661'),
#  array(['98.6016566157341', "['Arijit Singh', 'Shadab Faridi']", 'Dilli'],
#        dtype='<U661'),
#  array(['98.6016446352005', "['John Cafferty & the Beaver Brown Band']",
#         'NYC Song'], dtype='<U661'),
#  array(['98.60160902142525', "['Billy Idol']",
#         'Hot In The City - Exterminator Mix / 24-Bit Digitally Remastered 2001'],
#        dtype='<U661'),
#  array(['98.60158285498619', "['No Doubt']", 'Rock Steady'], dtype='<U661'),
#  array(['98.60157054662704', "['Martha Munizzi']",
#         'Because of Who You Are'], dtype='<U661'),
#  array(['98.60145077109337', "['Umm Kulthum']", 'Ezkrony'], dtype='<U661'),
#  array(['98.60135301947594', "['Stetsasonic']", 'Go Stetsa I'],
#        dtype='<U661'),
#  array(['98.60132673382759',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C minor "Resurrection": V. Im Tempo des Scherzos. Wild herausfahrend'],
#        dtype='<U661'),
#  array(['98.60129606723785', "['Stan Getz', 'Chet Baker']",
#         'Half-Breed Apache'], dtype='<U661'),
#  array(['98.60124439001083', "['Peter Tosh']", 'Stepping Razor'],
#        dtype='<U661'),
#  array(['98.60121339559555', "['After 7']", "'Til You Do Me Right"],
#        dtype='<U661'),
#  array(['98.6011797785759', "['Travis Tritt']",
#         'Between an Old Memory and Me'], dtype='<U661'),
#  array(['98.60107070207596', "['Three 6 Mafia']", 'Late Nite Tip'],
#        dtype='<U661'),
#  array(['98.6010437309742', "['Talking Heads']",
#         'Take Me to the River - 2004 Remaster'], dtype='<U661'),
#  array(['98.60102912783623', "['Paul Bridgwater']",
#         "Can't Stop Thinking About You"], dtype='<U661'),
#  array(['98.6010103225708', "['The 1975']", 'You'], dtype='<U661'),
#  array(['98.60100856423378', "['Miles Davis Quintet']",
#         'It Could Happen To You'], dtype='<U661'),
#  array(['98.60099029541016', "['Arijit Singh']",
#         'Phir Kabhi (From "M.S.Dhoni - The Untold Story")'], dtype='<U661'),
#  array(['98.60098135471344', "['Taylor Swift']", 'Dear John'],
#        dtype='<U661'),
#  array(['98.60096246004105', "['Peter Gabriel']",
#         'Sledgehammer - 2012 Remaster'], dtype='<U661'),
#  array(['98.60093685984612', "['Nomy']", 'Your Last Breath - LOL Edit'],
#        dtype='<U661'),
#  array(['98.60083955526352', "['Sun Ra']", 'Kingdom of Thunder'],
#        dtype='<U661'),
#  array(['98.60075849294662', "['Johnnie Taylor']", 'Walk Away With Me'],
#        dtype='<U661'),
#  array(['98.60075807571411', "['Blue October']", 'Chameleon Boy'],
#        dtype='<U661'),
#  array(['98.60064354538918',
#         "['Eurythmics', 'Annie Lennox', 'Dave Stewart']",
#         'Regrets - Remastered Version'], dtype='<U661'),
#  array(['98.60056301951408', "['Mary J. Blige', 'Elton John']",
#         'Deep Inside'], dtype='<U661'),
#  array(['98.60052806138992', "['Blondie']",
#         'Rapture - Special Disco Mix/2001 Remaster'], dtype='<U661'),
#  array(['98.60049784183502', "['Billy Joel']", 'Laura'], dtype='<U661'),
#  array(['98.6004127562046', "['Luis Fonsi']", 'Girasoles'], dtype='<U661'),
#  array(['98.60036239027977', "['Tesla']", 'Games People Play'],
#        dtype='<U661'),
#  array(['98.60028970241547', "['Queen']",
#         'I Want To Break Free - Remastered 2011'], dtype='<U661'),
#  array(['98.60028514266014', "['Blues Traveler']", 'Crystal Flame'],
#        dtype='<U661'),
#  array(['98.6002266407013', "['Midnight Star']", 'Operator - 12" Mix'],
#        dtype='<U661'),
#  array(['98.6002125442028', "['J Boog']", 'Leaving With Me'], dtype='<U661'),
#  array(['98.60016837716103', "['Jesse Johnson']", 'I Want My Girl'],
#        dtype='<U661'),
#  array(['98.60012400150299', "['Grandmaster Flash & The Furious Five']",
#         'White Lines (Long Version) [Re-Recorded]'], dtype='<U661'),
#  array(['98.60008054971695', "['Candlebox']", 'Change'], dtype='<U661'),
#  array(['98.6000742316246', "['Mecano']", 'Un Año Mas'], dtype='<U661'),
#  array(['98.6000303030014', "['Roy Harper']", 'Me and My Woman'],
#        dtype='<U661'),
#  array(['98.60002493858337', "['John Mellencamp']", 'Golden Gates'],
#        dtype='<U661'),
#  array(['98.59988930821419', "['Sudhir Phadke']",
#         'Swaye Shri Ramprabhu Aikati'], dtype='<U661'),
#  array(['98.59982323646545', "['Daryl Hall & John Oates']",
#         'Out of Touch - Club Version'], dtype='<U661'),
#  array(['98.59971284866333', "['Foreigner']", "Can't Wait"], dtype='<U661'),
#  array(['98.59965643286705', "['Usher']", 'Papers'], dtype='<U661'),
#  array(['98.59965282678604', "['Max Roach', 'Abbey Lincoln']", 'Mendacity'],
#        dtype='<U661'),
#  array(['98.59964844584465', "['John Coltrane', 'Paul Quinichette']",
#         'Sunday - Instrumental'], dtype='<U661'),
#  array(['98.59961491823196', "['Fleetwood Mac']", 'Tell Me You Need Me'],
#        dtype='<U661'),
#  array(['98.59959799051285', "['Fiji']", 'Sweet Darlin'], dtype='<U661'),
#  array(['98.59954279661179',
#         "['Eric Kupper', 'Motomo 315', 'Connie Harvey']",
#         'Make Sweet Music Dub (feat. Connie Harvey) - Motomo 315 Vocal Dub'],
#        dtype='<U661'),
#  array(['98.59954249858856', "['Train']", 'I Am'], dtype='<U661'),
#  array(['98.59949523210526', "['The Who']", "I've Known No War"],
#        dtype='<U661'),
#  array(['98.59949207305908', "['Ray Wylie Hubbard']", 'Choctaw Bingo'],
#        dtype='<U661'),
#  array(['98.5994263291359', "['Marvin Gaye']", 'Got To Give It Up'],
#        dtype='<U661'),
#  array(['98.59942200779915', "['Montell Jordan', 'Slick Rick']", 'I Like'],
#        dtype='<U661'),
#  array(['98.59939214587212', "['Lucia Belen']",
#         'Besame Mucho (Long Version)'], dtype='<U661'),
#  array(['98.59931087493896', "['The Isley Brothers']", 'Secret Lover'],
#        dtype='<U661'),
#  array(['98.59927439689636',
#         "['Richard Wagner', 'Bavarian Radio Symphony Orchestra', 'Lorin Maazel', 'Waltraud Meier']",
#         'Starke Scheite schichtet mir dort (Brünnhilde, Schlußszene 3. Aufzug)'],
#        dtype='<U661'),
#  array(['98.59926342964172',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['98.59921890497208', "['George Duke']", 'I Want You for Myself'],
#        dtype='<U661'),
#  array(['98.59917512536049', "['Marvin Sease']", 'Do You Qualify'],
#        dtype='<U661'),
#  array(['98.59915563464165', "['Biswarup Ghoshdastidar']",
#         'Piyal Shakhar Phaanke'], dtype='<U661'),
#  array(['98.59910371899605', "['Peter Gabriel']", 'Shaking The Tree'],
#        dtype='<U661'),
#  array(['98.59908264875412', "['Elliott Smith']", 'Pretty (Ugly Before)'],
#        dtype='<U661'),
#  array(['98.59903624653816', "['Commissioned']", 'Love Is The Way'],
#        dtype='<U661'),
#  array(['98.59903407096863', "['Miles Davis Sextet']", "Walkin'"],
#        dtype='<U661'),
#  array(['98.5990241765976', "['Paul Bridgwater']", 'River of Souls'],
#        dtype='<U661'),
#  array(['98.59900259971619', "['Gojira']", 'VACUITY'], dtype='<U661'),
#  array(['98.5988971889019', "['The Sweetback Sisters']",
#         "That's All It Took"], dtype='<U661'),
#  array(['98.59877094626427', "['Eric Benét', 'Kevin Davis']", 'Femininity'],
#        dtype='<U661'),
#  array(['98.59874761104584', "['Björk', 'Dobie']",
#         'I Miss You (Dobie Rub Part One) - Sunshine Mix'], dtype='<U661'),
#  array(['98.5986895263195', "['The Sweetback Sisters']",
#         'King of Killing Time'], dtype='<U661'),
#  array(['98.59860336780548', "['France Joli']", 'Come to Me'],
#        dtype='<U661'),
#  array(['98.59858989715576', "['Stick Figure']", 'Out the Door'],
#        dtype='<U661'),
#  array(['98.59857416152954', "['Takis Karnavas']",
#         'Ola ta poulakia / Na eixa th xari sou aite / Marainomai o kaimenos / Tora o Mais kai h Anoiksh / Apopse pou koimomouna'],
#        dtype='<U661'),
#  array(['98.59841358661652', "['Mecano']",
#         'El Blues del Esclavo (Version Tango)'], dtype='<U661'),
#  array(['98.5983744263649', "['CHIC']", "I Feel Your Love Comin' On"],
#        dtype='<U661'),
#  array(['98.59836110472679', "['Metallica']",
#         'Seek & Destroy (Live in Mexico City)'], dtype='<U661'),
#  array(['98.59834605455399', "['Spoon']", 'I Turn My Camera On'],
#        dtype='<U661'),
#  array(['98.59829404950142', "['Jackson Browne']",
#         'Your Bright Baby Blues'], dtype='<U661'),
#  array(['98.59829261898994', "['Al Kooper']", 'Season of the Witch'],
#        dtype='<U661'),
#  array(['98.59828490018845', "['Johnnie Taylor']",
#         'Still Called the Blues'], dtype='<U661'),
#  array(['98.5982366502285', "['Ramon Ayala Y Sus Bravos Del Norte']",
#         'Tristes Recuerdos'], dtype='<U661'),
#  array(['98.59816145896912', "['Les Paul']", 'Caravan'], dtype='<U661'),
#  array(['98.59815862774849', "['Usher']", 'Simple Things'], dtype='<U661'),
#  array(['98.59807413816452', "['Luther Vandross']",
#         'Other Side of the World'], dtype='<U661'),
#  array(['98.59805580973625', "['Miami Mass Choir']", 'It Is For Me'],
#        dtype='<U661'),
#  array(['98.59800952672958', "['Bruce Prince-Joseph']",
#         'Vivaldi-Bach: Concerto II, in Am; Allegro, Adagio, Allegro'],
#        dtype='<U661'),
#  array(['98.5979673564434', "['R. Kelly']",
#         'Baby, Baby, Baby, Baby, Baby...'], dtype='<U661'),
#  array(['98.59791991114616', "['Depeche Mode']",
#         'Everything Counts - In Larger Amounts'], dtype='<U661'),
#  array(['98.59791487455368', "['The Marshall Tucker Band']",
#         'Love Is a Mystery'], dtype='<U661'),
#  array(['98.59789144992828', "['TobyMac']", 'Catchafire (Whoopsi-Daisy)'],
#        dtype='<U661'),
#  array(['98.59784412384033', "['Mötley Crüe']", 'Time For Change - Demo'],
#        dtype='<U661'),
#  array(['98.59778609871864', "['Prince']", 'Gold'], dtype='<U661'),
#  array(['98.59775364398956',
#         "['Lalo Ebratt', 'Yera', 'Skinny Happy', 'Trapical']",
#         'Te Encantaría'], dtype='<U661'),
#  array(['98.5977438390255', "['Supertramp']", 'Brother Where You Bound'],
#        dtype='<U661'),
#  array(['98.59768316149712', "['Janet Jackson']", 'Someday Is Tonight'],
#        dtype='<U661'),
#  array(['98.59767520427704', "['Aniceto Molina']",
#         'La Cumbia Sampuesana Y La Cumbia Cienaguera'], dtype='<U661'),
#  array(['98.59761855006218', "['Christopher Plummer']",
#         'The Many Adventures of Winnie the Pooh'], dtype='<U661'),
#  array(['98.59761759638786', "['Creed']", 'Never Die'], dtype='<U661'),
#  array(['98.59760197997093', "['The Hollies']",
#         'Lullaby to Tim - Mono; 1999 Remaster'], dtype='<U661'),
#  array(['98.59755736589432', "['John Legend']", 'Everybody Knows'],
#        dtype='<U661'),
#  array(['98.59740644693375', "['Bob Seger']", 'The Ring'], dtype='<U661'),
#  array(['98.59739184379578', "['Travis Tritt']", 'If I Were a Drinker'],
#        dtype='<U661'),
#  array(['98.59738692641258', "['Don Henley']", 'Gimme What You Got'],
#        dtype='<U661'),
#  array(['98.59737420082092', "['Something Corporate']", 'Konstantine'],
#        dtype='<U661'),
#  array(['98.59735348820686',
#         "['Lil Jon & The East Side Boyz', 'Ying Yang Twins']", 'Get Low'],
#        dtype='<U661'),
#  array(['98.5973430275917', "['Waylon Jennings']", 'The Hunger'],
#        dtype='<U661'),
#  array(['98.59728854894638', "['Russ Taff']", 'Silent Love'], dtype='<U661'),
#  array(['98.59728637337685', "['Johnnie Taylor']", 'Drown In My Own Tears'],
#        dtype='<U661'),
#  array(['98.59726423025131', "['Joe Diffie']", 'A Night To Remember'],
#        dtype='<U661'),
#  array(['98.5970584154129', "['Kenny G']",
#         'What Does It Take (To Win Your Love)'], dtype='<U661'),
#  array(['98.59699320793152', "['Britt Nicole']", 'The Lost Get Found'],
#        dtype='<U661'),
#  array(['98.59698861837387', "['Brandy']", 'Learn the Hard Way'],
#        dtype='<U661'),
#  array(['98.59684747457504', "['R.E.M.']",
#         'Camera - Original Album Version'], dtype='<U661'),
#  array(['98.59682396054268', "['Alabama', '*NSYNC']",
#         'God Must Have Spent a Little More Time on You (feat. *NSYNC)'],
#        dtype='<U661'),
#  array(['98.59678649902344', "['Jonny Lang']", "Breakin' Me"],
#        dtype='<U661'),
#  array(['98.59676107764244', "['Jennifer Lopez']", "I'm Real"],
#        dtype='<U661'),
#  array(['98.59672200679779', "['Blonde Redhead']", 'In Particular'],
#        dtype='<U661'),
#  array(['98.59672045707703', '[\'James Brown\', "The J.B.\'s"]',
#         'Soul Power - Re-Edit / Mono'], dtype='<U661'),
#  array(['98.59662047028542', "['Yung Joc', 'Nitti']",
#         "It's Goin' Down (feat. Nitti)"], dtype='<U661'),
#  array(['98.5966128706932', "['Stick Figure']", 'Songs of Yesterday'],
#        dtype='<U661'),
#  array(['98.59653663635254', "['Tom Tom Club']",
#         'Genius of Love - Long Version'], dtype='<U661'),
#  array(['98.59651705622673', "['The Marshall Tucker Band']",
#         'Southern Woman'], dtype='<U661'),
#  array(['98.596516340971', "['REO Speedwagon']",
#         'I Wish You Were There - Live Studio Demo - June/October 1980'],
#        dtype='<U661'),
#  array(['98.59642907977104', "['The Vaughan Brothers']", 'Tick Tock'],
#        dtype='<U661'),
#  array(['98.59642854332924', "['Cannonball Adderley']",
#         'Fiddler On The Roof - Remastered'], dtype='<U661'),
#  array(['98.5963454246521', "['Grateful Dead']",
#         "Help on the Way / Slipknot! / Franklin's Tower - Live October 1989 - April 1990"],
#        dtype='<U661'),
#  array(['98.5961944758892', "['Alabama']", 'She and I'], dtype='<U661'),
#  array(['98.59615889191628', "['Nomy']", 'Stupid - LOL Edit'],
#        dtype='<U661'),
#  array(['98.59613740444183', "['Calvin Richardson']", 'Falling Out'],
#        dtype='<U661'),
#  array(['98.59613135457039', "['Parliament']",
#         'The Freeze (Sizzaleenmean)'], dtype='<U661'),
#  array(['98.59610888361931', "['Lauv']", 'Tell My Mama'], dtype='<U661'),
#  array(['98.59598955512047', "['James Brown']",
#         'Hot Pants (She Got To Use What She Got To Get What She Wants)'],
#        dtype='<U661'),
#  array(['98.59597793221474', "['The Rolling Stones']",
#         'Indian Girl - Remastered'], dtype='<U661'),
#  array(['98.59593519568443', "['Car Seat Headrest']", 'Maud Gone'],
#        dtype='<U661'),
#  array(['98.59590610861778', "['Billy Ocean']",
#         'Caribbean Queen (No More Love On the Run)'], dtype='<U661'),
#  array(['98.59584900736809', "['Alekos Dimou']", 'To tafo sou Sotir'],
#        dtype='<U661'),
#  array(['98.595848351717', "['Los Relampagos Del Norte']",
#         'Un Día Con Otro'], dtype='<U661'),
#  array(['98.59580671787262', "['John Mayer']", 'City Love'], dtype='<U661'),
#  array(['98.59577336907387', "['Michael Salgado']",
#         'Otra Vez A La Cantina'], dtype='<U661'),
#  array(['98.59575819969177', "['MC Blvd']", 'I Remember You, Homie'],
#        dtype='<U661'),
#  array(['98.59572410583496', "['Honeytraps']", 'Winter Wonderland'],
#        dtype='<U661'),
#  array(['98.59569489955902', "['Queen']", 'Dancer'], dtype='<U661'),
#  array(['98.59568905830383', "['Blue October']", 'A Quiet Mind'],
#        dtype='<U661'),
#  array(['98.59563606977463', "['Jeff Stetson']",
#         'You Make Your Own Heaven and Hell'], dtype='<U661'),
#  array(['98.59560444951057', "['Colin Gordon-Farleigh']",
#         'Blue Eyes Crying In The Rain'], dtype='<U661'),
#  array(['98.59558475017548', "['Funky 4 + 1']", "That's the Joint"],
#        dtype='<U661'),
#  array(['98.59555023908615', "['Chris LeDoux']", 'Tougher Than The Rest'],
#        dtype='<U661'),
#  array(['98.59543663263321', "['Kansas']", 'Song for America'],
#        dtype='<U661'),
#  array(['98.59542647004128', "['Pierce The Veil']", 'Wonderless'],
#        dtype='<U661'),
#  array(['98.59541022777557', "['Miles Davis']",
#         'Milestones - alternate take'], dtype='<U661'),
#  array(['98.59539780020714', "['Horace Brown']", 'Things We Do For Love'],
#        dtype='<U661'),
#  array(['98.59537279605865', "['Blu Cantrell', 'Sean Paul']",
#         'Breathe - Rap Version'], dtype='<U661'),
#  array(['98.59536969661713', "['Monica', '112']",
#         'Right Here Waiting (feat. 112)'], dtype='<U661'),
#  array(['98.59536337852478', "['MercyMe']", 'Spoken For'], dtype='<U661'),
#  array(['98.59526073932648', "['Usher']", 'Think Of You'], dtype='<U661'),
#  array(['98.59525209665298', "['Brownside']", 'Last Day'], dtype='<U661'),
#  array(['98.59521827101707', "['Blackstreet']", 'Never Gonna Let You Go'],
#        dtype='<U661'),
#  array(['98.59514454007149', "['Bruno Mars', 'Passion Pit']",
#         'Grenade - Passion Pit Remix'], dtype='<U661'),
#  array(['98.59510788321495', "['Blue Magic']", "Since You've Been Gone"],
#        dtype='<U661'),
#  array(['98.59508743882179', "['Tony! Toni! Toné!', 'DJ Quik']",
#         "Let's Get Down"], dtype='<U661'),
#  array(['98.59508034586906', "['Fleetwood Mac']", 'If You Be My Baby'],
#        dtype='<U661'),
#  array(['98.59504535794258', "['Jill Scott']", 'One Is the Magic #'],
#        dtype='<U661'),
#  array(['98.5950445830822',
#         '[\'Montell Jordan\', \'Silk "The Shocker" Friend\', \'Master P\']',
#         "Let's Ride"], dtype='<U661'),
#  array(['98.59504234790802', "['Tennessee Ernie Ford']", 'John Henry'],
# ...
#        dtype='<U661'),
#  array(['98.58545958995819', "['Selena']", 'Dreaming Of You'],
#        dtype='<U661'),
#  array(['98.58543848991394', "['Anton LaVey']", 'The Satanic Mass'],
#        dtype='<U661'),
#  array(['98.58543694019318', "['Steely Dan']", 'Hey Nineteen'],
#        dtype='<U661'),
#  array(['98.58543500304222', "['J. Cole']", 'Work Out'], dtype='<U661'),
#  array(['98.58542719483376', "['Maroon 5']", 'Goodnight Goodnight'],
#        dtype='<U661'),
#  array(['98.58541914820671', "['Billy Joel', 'Cyndi Lauper']",
#         'Code of Silence (feat. Cyndi Lauper)'], dtype='<U661'),
#  array(['98.58538940548897', "['Blue Zoo']", "I'm Your Man - Edit?"],
#        dtype='<U661'),
#  array(['98.5853061079979', "['Peter Gabriel']",
#         'Red Rain - 2012 Remaster'], dtype='<U661'),
#  array(['98.58529540896416', "['Gerry Mulligan']", "Bernie's Tune"],
#        dtype='<U661'),
#  array(['98.58529308438301', "['Love and Rockets']",
#         'Haunted When The Minutes Drag'], dtype='<U661'),
#  array(['98.585270434618', "['Ladron']", 'Vengo A Pedir Tu Mano'],
#        dtype='<U661'),
#  array(['98.58523944020271', "['James Brown & The Famous Flames']",
#         'Mashed Potatoes U.S.A.'], dtype='<U661'),
#  array(['98.58518934249878', "['Prince']", 'D.M.S.R.'], dtype='<U661'),
#  array(['98.58518821001053', "['Paul McCartney']",
#         'Wanderlust - Remixed 2015'], dtype='<U661'),
#  array(['98.5851739346981', "['Kirk Franklin', 'The Family']",
#         'Conquerors'], dtype='<U661'),
#  array(['98.58514842391014', "['Thelonious Monk']", "Brake's Sake"],
#        dtype='<U661'),
#  array(['98.58512815833092', "['Super Banda G']", 'Amores Que Sueñan'],
#        dtype='<U661'),
#  array(['98.58511397242546', "['Roger Creager']", 'Love'], dtype='<U661'),
#  array(['98.58510726690292', "['Big John Patton']", 'Along Came John'],
#        dtype='<U661'),
#  array(['98.58505636453629', "['Genesis']", 'One for the Vine'],
#        dtype='<U661'),
#  array(['98.58504945039749', "['Angelina']", 'Release Me'], dtype='<U661'),
#  array(['98.58504313230515', "['Mariah Carey']", 'Angels Cry'],
#        dtype='<U661'),
#  array(['98.58503684401512', "['Metallica']", 'Mercyful Fate'],
#        dtype='<U661'),
#  array(['98.58503019809723', "['Bauhaus']", 'Rosegarden Funeral of Sores'],
#        dtype='<U661'),
#  array(['98.58501541614532', "['Prism']", 'Armageddon'], dtype='<U661'),
#  array(['98.58499899506569', "['Bob Marley & The Wailers']",
#         'Buffalo Soldier - 12" Mix'], dtype='<U661'),
#  array(['98.58498722314835', "['Charo', 'The Salsoul Orchestra']",
#         'Dance A Little Bit Closer'], dtype='<U661'),
#  array(['98.5849791765213', "['Marques Houston']", 'Sex Wit You'],
#        dtype='<U661'),
#  array(['98.58495989441872', "['Los Gatos Negros De Tiberio']",
#         'Grabada en Mi Piel'], dtype='<U661'),
#  array(['98.58495232462883', "['Maryline Garcia & Christophe da Silva']",
#         'Cheira a Lisboa'], dtype='<U661'),
#  array(['98.58493208885193', "['Kid Rock']", 'Roll On'], dtype='<U661'),
#  array(['98.5849201977253', "['The Hollies']",
#         "Blowin' in the Wind - 1999 Remaster"], dtype='<U661'),
#  array(['98.58490091562271', "['Ronnie Milsap']", 'Inside'], dtype='<U661'),
#  array(['98.58489760756493', "['Jaheim', 'Terry Dexter']",
#         'Remarkable (feat. Terry Dexter)'], dtype='<U661'),
#  array(['98.58487486839294', "['John Coltrane']",
#         'Good Bait - Rudy Van Gelder Remaster'], dtype='<U661'),
#  array(['98.58487007021904', "['The Association']", "I'll Be Your Man"],
#        dtype='<U661'),
#  array(['98.5848577618599', "['Clint Black']", 'Half Way Up'],
#        dtype='<U661'),
#  array(['98.58483317494392', "['Kid Frost']", 'Thin Line'], dtype='<U661'),
#  array(['98.58480668067932', "['Blake Shelton']", 'Ready to Roll'],
#        dtype='<U661'),
#  array(['98.58479106426239', "['Reba McEntire']", 'How Was I To Know'],
#        dtype='<U661'),
#  array(['98.58478635549545', "['The Time']", 'Cool'], dtype='<U661'),
#  array(['98.58471414446831', "['Sister Hazel']", 'Your Winter'],
#        dtype='<U661'),
#  array(['98.58470204472542', '["\'Til Tuesday"]', 'Voices Carry'],
#        dtype='<U661'),
#  array(['98.58466938138008', "['Héctor Lavoe']", 'Mentira'], dtype='<U661'),
#  array(['98.58465540409088', "['Gladys Knight & The Pips']",
#         'Save the Overtime (For Me)'], dtype='<U661'),
#  array(['98.58465334773064', "['Steely Dan']", 'Babylon Sisters'],
#        dtype='<U661'),
#  array(['98.58464029431343', "['Maroon 5']", 'Must Get Out'], dtype='<U661'),
#  array(['98.58463588356972', "['Tony! Toni! Toné!']",
#         'For The Love Of You'], dtype='<U661'),
#  array(['98.58453077077866', "['The Rolling Stones']", 'You Win Again'],
#        dtype='<U661'),
#  array(['98.58452773094177',
#         "['John Coltrane', 'Red Garland', 'Paul Chambers', 'Art Taylor']",
#         'If There Is Someone Lovelier Than You - RVG Remaster'],
#        dtype='<U661'),
#  array(['98.58451288938522', "['Neil Young']",
#         'Hold Back the Tears - 2016 Remaster'], dtype='<U661'),
#  array(['98.58450490236282', "['Rush']", 'Xanadu - Live In Canada / 1980'],
#        dtype='<U661'),
#  array(['98.58450132608414', "['Roxette']",
#         'It Must Have Been Love (Christmas for the Broken Hearted)'],
#        dtype='<U661'),
#  array(['98.58448052406311', "['Fobia']", 'Hoy Tengo Miedo'], dtype='<U661'),
#  array(['98.58447295427322', "['Gungor']", 'Beautiful Things'],
#        dtype='<U661'),
#  array(['98.58445233106613', "['Jerry Garcia']", 'Fennario - Bonus Track'],
#        dtype='<U661'),
#  array(['98.58441358804703', "['Chris Tomlin']", 'God Of This City'],
#        dtype='<U661'),
#  array(['98.58441269397736', "['Mad Season']", 'Wake Up'], dtype='<U661'),
#  array(['98.58438357710838', "['Exile']", "She's a Miracle"], dtype='<U661'),
#  array(['98.58437186479568', "['Los Temerarios']", 'Eras Todo para Mí'],
#        dtype='<U661'),
#  array(['98.5843611061573', "['Brownstone']", "Sometimes Dancin'"],
#        dtype='<U661'),
#  array(['98.58430394530296', "['Dierks Bentley']", 'Come A Little Closer'],
#        dtype='<U661'),
#  array(['98.58429735898972', "['Willie K']", 'Good Morning'], dtype='<U661'),
#  array(['98.58428862690926', "['Jeff Bates']", 'Long, Slow Kisses'],
#        dtype='<U661'),
#  array(['98.5842724442482', "['Baby Bash', 'Sean Kingston']",
#         'What Is It (feat. Sean Kingston)'], dtype='<U661'),
#  array(['98.5842450261116', "['The Penetraitors']", 'Money & Power'],
#        dtype='<U661'),
#  array(['98.58419370651245', "['Jackie DeShannon']",
#         'Laurel Canyon - 2005 Digital Remaster'], dtype='<U661'),
#  array(['98.58418709039688', "['Bobby Mackey']", 'Johanna'], dtype='<U661'),
#  array(['98.58417332172394', "['Leonardo Paniagua']", 'Cuando Tu No Estas'],
#        dtype='<U661'),
#  array(['98.5841598212719', "['Chicago']",
#         'Once in a Lifetime - 2006 Remaster'], dtype='<U661'),
#  array(['98.58415871858597', "['The Whispers']", 'Say Yes'], dtype='<U661'),
#  array(['98.58415654301643', "['2Pac', 'Talent']",
#         'Changes - Greatest Hits Version'], dtype='<U661'),
#  array(['98.5841538310051', "['CAN']", 'Mother Sky (from Deep End)'],
#        dtype='<U661'),
#  array(['98.58414995670319', "['Art Blakey & The Jazz Messengers']",
#         'Stella by Starlight'], dtype='<U661'),
#  array(['98.584137737751', "['Alabama']", 'She and I'], dtype='<U661'),
#  array(['98.58411902189255', "['Bob Marley & The Wailers']", 'Exodus'],
#        dtype='<U661'),
#  array(['98.58411633968353', "['Alabama']", 'Pass It On Down'],
#        dtype='<U661'),
#  array(['98.58406409621239', "['Les Paul', 'Mary Ford']",
#         "Walkin' And Whistlin' Blues"], dtype='<U661'),
#  array(['98.58404731750488', "['Miles Davis Sextet']", "Walkin'"],
#        dtype='<U661'),
#  array(['98.58404624462128', '["Sergio Vega Y Sus Shaka\'s Del Norte"]',
#         'El Dollar Doblado'], dtype='<U661'),
#  array(['98.58403772115707',
#         "['Calixto Ochoa y Su Conjunto', 'Los Corraleros De Majagual']",
#         'La Medallita'], dtype='<U661'),
#  array(['98.58403488993645', "['Sublime']", 'Pawn Shop'], dtype='<U661'),
#  array(['98.58402487635612', "['Reik']", 'Levemente'], dtype='<U661'),
#  array(['98.58401775360107', "['Eagles']", 'The Long Run - 2013 Remaster'],
#        dtype='<U661'),
#  array(['98.58399480581284', "['Bon Jovi']", 'Silent Night'], dtype='<U661'),
#  array(['98.58399400115013', "['Kenny G']", 'Theme from "Dying Young"'],
#        dtype='<U661'),
#  array(['98.58399379253387', '["Sinéad O\'Connor"]',
#         'You Cause as Much Sorrow'], dtype='<U661'),
#  array(['98.58399245142937', "['Surface']", 'Closer Than Friends'],
#        dtype='<U661'),
#  array(['98.58399191498756', "['Viento Y Sol']",
#         'Cuando Un Hombre Ama A Una Mujer'], dtype='<U661'),
#  array(['98.58397847414017', "['John Coltrane', 'Paul Quinichette']",
#         'Exactly Like You - Instrumental'], dtype='<U661'),
#  array(['98.58396601676941', "['Cheryl Lynn']",
#         'Encore - Extended Version'], dtype='<U661'),
#  array(['98.58396518230438', "['Maroon 5']", 'Must Get Out'], dtype='<U661'),
#  array(['98.58395570516586', "['Maze', 'Frankie Beverly']",
#         "Happy Feelin's - Remastered"], dtype='<U661'),
#  array(['98.58394056558609', "['Jay Chou']", '簡單愛'], dtype='<U661'),
#  array(['98.58392632007599', "['Paul Hertzog']", 'Feeling So Good Today'],
#        dtype='<U661'),
#  array(['98.58390003442764', "['Wilco']", "She's a Jar"], dtype='<U661'),
#  array(['98.5838722884655', "['Common Rider']", 'Carry On'], dtype='<U661'),
#  array(['98.58381339907646', "['Sister Sledge']",
#         'We Are Family - 2006 Remaster'], dtype='<U661'),
#  array(['98.5837636590004', "['PMW Studio Musicians']", 'O Ferreiro'],
#        dtype='<U661'),
#  array(['98.58372795581818', "['Justin Bieber', 'Usher']", 'First Dance'],
#        dtype='<U661'),
#  array(['98.58372291922569', "['Sid King & The Five Strings']",
#         'Purr, Kitty Purr'], dtype='<U661'),
#  array(['98.58371484279633', "['Justice']", 'Phantom'], dtype='<U661'),
#  array(['98.58371329307556', "['EOR']", 'Vele'], dtype='<U661'),
#  array(['98.58367604017258', "['The Rolling Stones']", 'Going Home'],
#        dtype='<U661'),
#  array(['98.58366802334785', "['Yelle']", 'Ce jeu'], dtype='<U661'),
#  array(['98.58364188671112', "['Alabama']", "You've Got the Touch"],
#        dtype='<U661'),
#  array(['98.58362802863121', "['Jonny Lang']", "Still Rainin'"],
#        dtype='<U661'),
#  array(['98.58361175656319', "['Alekos Dimou']",
#         'Pasa pnoi ainesato to Kurio'], dtype='<U661'),
#  array(['98.58360213041306', "['Commonwealth Jones']", 'Do Do Do'],
#        dtype='<U661'),
#  array(['98.58360150456429', "['Paul McCartney']",
#         'What’s That You’re Doing? - Remixed 2015'], dtype='<U661'),
#  array(['98.5835972726345', "['Little Richard']", "It Ain't What You Do"],
#        dtype='<U661'),
#  array(['98.58358654379845', "['Los Baron De Apodaca']",
#         "Pa'Que Sientas Lo Que Siento"], dtype='<U661'),
#  array(['98.58358332514763', "['Cory Morrow']", 'Drink One More Round'],
#        dtype='<U661'),
#  array(['98.58355012536049', "['Bobby Brown']", "I'll Be Good To You"],
#        dtype='<U661'),
#  array(['98.58354237675667', "['Stonewall Jackson']", "Why I'm Walkin'"],
#        dtype='<U661'),
#  array(['98.58353301882744', "['The Time']", 'Ice Cream Castles'],
#        dtype='<U661'),
#  array(['98.5835203230381', "['Queen']", 'Bohemian Rhapsody - Remastered'],
#        dtype='<U661'),
#  array(['98.58351865410805', "['Tevin Campbell']", "I'm Ready"],
#        dtype='<U661'),
#  array(['98.58349624276161', "['Blue Öyster Cult']", 'Shooting Shark'],
#        dtype='<U661'),
#  array(['98.58349040150642', "['Miles Davis']", 'Madness'], dtype='<U661'),
#  array(['98.58348485827446', "['Queen']",
#         'She Makes Me (Stormtrooper In Stilettos) - Remastered 2011'],
#        dtype='<U661'),
#  array(['98.5834698677063', "['Oasis']",
#         'All Around The World - Remastered'], dtype='<U661'),
#  array(['98.58346265554428', '[\'Cherrelle\', "Alexander O\'Neal"]',
#         'Saturday Love - 12" Extended Version'], dtype='<U661'),
#  array(['98.58344405889511', "['Casting Crowns']",
#         'Glorious Day (Living He Loved Me)'], dtype='<U661'),
#  array(['98.58343681693077', "['Asleep At The Wheel']",
#         'Miles and Miles of Texas'], dtype='<U661'),
#  array(['98.58342385292053', "['Grupo Ladron']", 'Tu Desprecio'],
#        dtype='<U661'),
#  array(['98.58336928486824', "['Queen']", 'Back Chat - Single Remix'],
#        dtype='<U661'),
#  array(['98.58336704969406', "['Rossy War y Su Banda Kaliente']",
#         'Nunca Pense Llorar'], dtype='<U661'),
#  array(['98.58335393667221', "['Robert David Hall']",
#         "Things They Don't Teach You In School"], dtype='<U661'),
#  array(['98.58333814144135', "['Grupo Ladron']", 'Y es que la quiero'],
#        dtype='<U661'),
#  array(['98.58331322669983', "['Yellowman']", 'Jamaica A Little Miami'],
#        dtype='<U661'),
#  array(['98.58327934145927', "['Usher']", 'Twork It Out'], dtype='<U661'),
#  array(['98.58326870203018', "['The Samples']", 'Little Silver Ring'],
#        dtype='<U661'),
#  array(['98.58324280381203', "['Olivia Newton-John']", 'Magic'],
#        dtype='<U661'),
#  array(['98.5832367837429', "['Tom Petty and the Heartbreakers']",
#         'You Tell Me'], dtype='<U661'),
#  array(['98.58322504162788', "['K7']",
#         'Move It Like This - Alternative Mix'], dtype='<U661'),
#  array(['98.58321261405945',
#         "['Pyotr Ilyich Tchaikovsky', 'Jascha Heifetz', 'Fritz Reiner', 'Chicago Symphony Orchestra']",
#         'Violin Concerto in D Major, Op. 35: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['98.5831849873066', "['Whitney Houston']",
#         'Why Does It Hurt So Bad - from Waiting to Exhale - Original Soundtrack'],
#        dtype='<U661'),
#  array(['98.58318275213242', "['Wailing Souls']", 'Bandits Taking Over'],
#        dtype='<U661'),
#  array(['98.58313885331154', "['Vicious Pink']",
#         '8:15 to Nowhere / Great Balls of Fire'], dtype='<U661'),
#  array(['98.58310905098915', "['Rebelution']", 'Suffering'], dtype='<U661'),
#  array(['98.5830762386322', "['En Vogue']", 'Hold On'], dtype='<U661'),
#  array(['98.58307608962059', "['Kesha']", 'Crazy Beautiful Life'],
#        dtype='<U661'),
#  array(['98.5830714404583', "['Third Eye Blind']",
#         'Deep Inside of You - 2008 Remaster'], dtype='<U661'),
#  array(['98.58305305242538', "['Jimmy Buffett']", 'I Love The Now'],
#        dtype='<U661'),
#  array(['98.58304989337921', "['Bob Dylan']",
#         'Desolation Row - Take 1, Alternate Take'], dtype='<U661'),
#  array(['98.58303105831146', "['Talking Heads']",
#         'Ruby Dear - 2005 Remaster'], dtype='<U661'),
#  array(['98.58302646875381', "['A Perfect Circle']", 'Imagine'],
#        dtype='<U661'),
#  array(['98.58299699425697', "['Maze', 'Frankie Beverly']",
#         'Song For My Mother - Remastered'], dtype='<U661'),
#  array(['98.5829938352108', "['The Velvet Underground']",
#         'I Found a Reason - 2015 Remaster'], dtype='<U661'),
#  array(['98.5829767882824', "['Alabama']", 'Take Me Down'], dtype='<U661'),
#  array(['98.58293843269348', "['Lucia Belen']", 'Besame Mucho'],
#        dtype='<U661'),
#  array(['98.58290988206863', "['My Chemical Romance']",
#         'The Light Behind Your Eyes'], dtype='<U661'),
#  array(['98.58290374279022', "['Grateful Dead']",
#         'If I Had the World to Give'], dtype='<U661'),
#  array(['98.58290326595306', "['Green Day']", 'Rest'], dtype='<U661'),
#  array(['98.58289015293121', "['Bob Marley & The Wailers']",
#         "Love Won't Be Mine"], dtype='<U661'),
#  array(['98.58278220891953', "['The Postal Service']", 'Brand New Colony'],
#        dtype='<U661'),
#  array(['98.58278152346611', "['Al Stewart']", 'Song on the Radio'],
#        dtype='<U661'),
#  array(['98.58277669548988', "['Imagine Dragons']", 'Selene'],
#        dtype='<U661'),
#  array(['98.58277621865273', "['Aerosmith']", 'Blind Man'], dtype='<U661'),
#  array(['98.582754611969', "['Jerry Lewis']", 'Back In Your Own Back Yard'],
#        dtype='<U661'),
#  array(['98.58273112773895', "['Peter Frampton']",
#         "Baby (Somethin's Happening)"], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[sort_indices][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-83362090fb4c> in <module>
#       1 playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
#       2 scope = "playlist-modify-public"
# ----> 3 username = input('Enter username:')
#       4 token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri)
#       5 sp = spotipy.Spotify(auth=token)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:
