# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Toby Keith']", 'Made in America'],
#         ["['K/DA', 'Madison Beer', '(G)I-DLE', 'Jaira Burns', 'League of Legends']",
#          'POP/STARS'],
#         ["['Taylor Swift']", 'Getaway Car'],
#         ...,
#         ["['Mariah Carey']", 'When I Saw You'],
#         ["['Vampire Weekend']", 'Everlasting Arms'],
#         ["['Clay Walker']", 'If I Could Make a Living']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.001

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.c_[predictions, song_info]

# %%
predicted
# Out:
# array([['95.02418461027236', "['The Canton Spirituals']",
#         'Mississippi Poor Boy'],
#        ['94.8660920192211', "['Marvin Gaye']", 'After The Dance'],
#        ['94.85442495592086', "['Nas']", 'Get Down'],
#        ...,
#        ['95.06557628457729', "['Cultura Profética']", 'De Antes'],
#        ['94.92189920023301', "['Dua Lipa']", 'Blow Your Mind (Mwah)'],
#        ['94.87602294197016',
#         "['James Brown & The Famous Flames', 'Cy Langston']",
#         'Night Train']], dtype='<U661')

# %%
predicted = predicted[np.argsort(predictions)][::-1]

# %%
list(predicted)
# Out:
# [array(['95.02418461027236', "['The Canton Spirituals']",
#         'Mississippi Poor Boy'], dtype='<U661'),
#  array(['94.8660920192211', "['Marvin Gaye']", 'After The Dance'],
#        dtype='<U661'),
#  array(['94.85442495592086', "['Nas']", 'Get Down'], dtype='<U661'),
#  array(['95.00789244334372', "['Los Tigres Del Norte']",
#         'Ni Parientes Somos'], dtype='<U661'),
#  array(['94.39749995468684',
#         "['Igor Stravinsky', 'New York Philharmonic']",
#         'Petrushka Ballet Suite: Dance of the Coachmen and the Grooms'],
#        dtype='<U661'),
#  array(['94.98120350721568', "['Banda Carnaval']", 'Encontrarte'],
#        dtype='<U661'),
#  array(['94.58176468992585', "['Young M.A']", 'OOOUUU'], dtype='<U661'),
#  array(['94.4563743863132', "['Billie Holiday', 'Teddy Wilson']",
#         'Yours and Mine (with Teddy Wilson & His Orchestra)'],
#        dtype='<U661'),
#  array(['94.41846561933741', "['Petros Epitropakis']",
#         'Ta xronia ki an diavainoun'], dtype='<U661'),
#  array(['94.42535736213412', '["Flo Sandon\'s"]', 'Jezebel'], dtype='<U661'),
#  array(['94.93288386848681', "['Yelawolf']", 'Catfish Billy'],
#        dtype='<U661'),
#  array(['94.49233317817603', "['Elvis Presley']", 'Indescribably Blue'],
#        dtype='<U661'),
#  array(['94.61470790133993', "['Lata Mangeshkar', 'Mukesh']",
#         'Dam Bhar Jo Udhar Munh Phere'], dtype='<U661'),
#  array(['94.95285758199489', "['Francesca Battistelli']", "It's Your Life"],
#        dtype='<U661'),
#  array(['95.17936032341743', "['Slave']", 'Steal Your Heart'],
#        dtype='<U661'),
#  array(['94.79540745489396', "['Linda Ronstadt']",
#         "The Only Mama That'll Walk The Line"], dtype='<U661'),
#  array(['94.78000185769956', "['Jimi Hendrix']", "Ain't No Telling"],
#        dtype='<U661'),
#  array(['94.87633395672992', "['Santana']", 'Jingo - Single Version'],
#        dtype='<U661'),
#  array(['94.67833693296781', "['Henry Mancini']", 'Baby Elephant Walk'],
#        dtype='<U661'),
#  array(['94.7033967573022', "['Jack Jones']", 'Dear Heart'], dtype='<U661'),
#  array(['94.41097502542414',
#         "['Giuseppe Verdi', 'Vittorio Gui', 'Coro di Roma della RAI', 'Gaetano Riccitelli', 'Giulietta Simionato', 'Giulio Neri', 'Orchestra Sinfonica di Roma della RAI']",
#         'Verdi : Aida : Act 3 "Vieni d\'Iside al Tempio" [Ramfis, Amneris, Chorus]'],
#        dtype='<U661'),
#  array(['94.87304812827233', "['Joseph Arthur']", 'Honey And The Moon'],
#        dtype='<U661'),
#  array(['94.64426853403484', "['Johann Sebastian Bach', 'Glenn Gould']",
#         'The Art of the Fugue, BWV 1080: Contrapunctus I - Excerpts'],
#        dtype='<U661'),
#  array(['94.64648329408446', "['Nina Simone']", "Don't Take All Night"],
#        dtype='<U661'),
#  array(['95.08124884783183', "['P.E.P.E.']", 'Shadilay (Radio Edit)'],
#        dtype='<U661'),
#  array(['95.01148295699393', "['Various Artists']",
#         'The Burning Bush - The Prince Of Egypt/Soundtrack Version'],
#        dtype='<U661'),
#  array(['94.94449721880916', "['Mystikal']", "Still Smokin'"],
#        dtype='<U661'),
#  array(['95.1578223635182', "['The Cure']",
#         'Pictures of You - 2010 Remaster'], dtype='<U661'),
#  array(['95.01295334682173', "['The Neighbourhood']", 'Afraid'],
#        dtype='<U661'),
#  array(['94.87560732107832', "['João Gilberto']", 'Caminhos Cruzados'],
#        dtype='<U661'),
#  array(['94.96676049867462', "['Los Originales De San Juan']",
#         'Las Santísima Muerte'], dtype='<U661'),
#  array(['94.93987630908173', "['Julee Cruise']", 'The Nightingale'],
#        dtype='<U661'),
#  array(['94.76916944720271', "['Three 6 Mafia', 'Bow Wow', 'Project Pat']",
#         'Side 2 Side - feat. Bow Wow & Project Pat - Explicit'],
#        dtype='<U661'),
#  array(['94.33271077924658', "['Los Provincianos', 'Dúo Larrea-Terán']",
#         'El Solterito (Gracias a Dios Soy Soltero…)'], dtype='<U661'),
#  array(['94.7361118629769', "['Five Finger Death Punch']", 'Hard To See'],
#        dtype='<U661'),
#  array(['94.69707446558543', "['John Martyn']", "Couldn't Love You More"],
#        dtype='<U661'),
#  array(['94.95503791745311', "['Vinnie Vincent Invasion']",
#         'Boyz Are Gonna Rock - Remastered'], dtype='<U661'),
#  array(['94.9981617208188', "['Steve Earle']", 'Guitar Town'],
#        dtype='<U661'),
#  array(['94.60196029093724', "['Fairuz']", 'Anti Ya May Zahra'],
#        dtype='<U661'),
#  array(['94.77867626190671', "['Buena Vista Social Club']",
#         'Amor de Loca Juventud'], dtype='<U661'),
#  array(['94.75881072161968', "['Arijit Singh']",
#         'Khairiyat (From "Chhichhore")'], dtype='<U661'),
#  array(['94.8509624151052', "['Townes Van Zandt']",
#         'Fare Thee Well, Miss Carousel'], dtype='<U661'),
#  array(['94.55707249500729',
#         "['Giacomo Puccini', 'Maria Callas', 'Philharmonia Orchestra', 'Tullio Serafin']",
#         'Puccini: Madama Butterfly, Act 2: "Con onor muore" (Madama Butterfly)'],
#        dtype='<U661'),
#  array(['95.01861299810331', "['Krokus']", 'Night Wolf - Remastered'],
#        dtype='<U661'),
#  array(['94.97407954961453', "['Randy Travis']", 'Is It Still Over?'],
#        dtype='<U661'),
#  array(['94.69199307752908', "['The Beatles']",
#         'Eleanor Rigby - Remastered 2015'], dtype='<U661'),
#  array(['94.8632395953371', "['The Beach Boys']",
#         'You Still Believe In Me - Remastered'], dtype='<U661'),
#  array(['94.59802489870698', "['Zofia Dromlewiczowa']",
#         'Chapter 1.17 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['95.18373733938463', "['Ram Jam']", 'Black Betty'], dtype='<U661'),
#  array(['94.37839481428557', "['Rita Abatzi']", 'Μάνα διώξε τους γιατρούς'],
#        dtype='<U661'),
#  array(['94.74586174563056', "['Bob Dylan']", 'One More Night'],
#        dtype='<U661'),
#  array(['94.47128603429744', "['Bobby Day']", 'Darling if I Had You'],
#        dtype='<U661'),
#  array(['95.10834370170163',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'New York Philharmonic']",
#         "How a Great Symphony Was Written (Leonard Bernstein Discusses the First Movement of Beethoven's Eroica with Musical Illustrations)"],
#        dtype='<U661'),
#  array(['94.39660905944234', "['Francisco Canaro', 'Charlo']",
#         'Dos Ojos Negros - Remasterizado'], dtype='<U661'),
#  array(['95.04719136114225', "['Euge Groove']", "Livin' Large"],
#        dtype='<U661'),
#  array(['94.71239600849661', "['Comethazine']", 'Walk'], dtype='<U661'),
#  array(['94.99519979177826', "['Nazareth']", 'Bad Bad Boy'], dtype='<U661'),
#  array(['94.91530323119864', "['George Jones']", "White Lightnin'"],
#        dtype='<U661'),
#  array(['95.04033591939964', "['Los Angeles Negros']",
#         'Déjenme Si Estoy Llorando'], dtype='<U661'),
#  array(['94.2735420658444', "['Jimmie Rodgers']",
#         "Ben Dewberry's Final Run"], dtype='<U661'),
#  array(['95.09469657765179', "['Trevor Jones']", 'The Kiss'], dtype='<U661'),
#  array(['94.95887604378228', "['Post Malone']", 'I Fall Apart'],
#        dtype='<U661'),
#  array(['94.68703216980019', "['Nat King Cole']",
#         'A Nightingale Sang In Berkeley Square'], dtype='<U661'),
#  array(['94.82842820284668', '["Sergio Mendes & Brasil \'66"]',
#         'Pretty World'], dtype='<U661'),
#  array(['94.52056101688434', "['Hank Thompson']", "Bummin' Around"],
#        dtype='<U661'),
#  array(['94.60643470111278', "['Oscar Peterson Trio']",
#         'This Could Be The Start Of Something Big'], dtype='<U661'),
#  array(['94.98928932082178', "['Don Omar']", 'Ojitos Chiquitos'],
#        dtype='<U661'),
#  array(['94.92436657442846', "['Anri']", 'Lady Sunshine'], dtype='<U661'),
#  array(['94.78093343559665', '[\'James Brown\', "The J.B.\'s"]',
#         'Super Bad'], dtype='<U661'),
#  array(['94.73833812050242',
#         "['Giuseppe Verdi', 'Inge Borkh', 'Wiener Philharmoniker', 'Rudolf Moralt']",
#         'Un ballo in maschera / Act 2: "Ecco l\'orrido campo...Ma dall\'arido stelo divulsa"'],
#        dtype='<U661'),
#  array(['94.66199853289395', "['Kanye West', 'PARTYNEXTDOOR']",
#         "Wouldn't Leave"], dtype='<U661'),
#  array(['94.86944081464476', "['Happy Mondays']",
#         "God's Cop - 2007 Remastered Version"], dtype='<U661'),
#  array(['94.39440211462824', "['Richard Wagner', 'Arturo Toscanini']",
#         'Götterdämmerung, WWV 86D: Act III: Fliegt heim, ihr Raben!'],
#        dtype='<U661'),
#  array(['94.64652576604017', "['張琪', '謝雷']", '騎上駿馬追不到'], dtype='<U661'),
#  array(['94.75997423826198', "['Göran Söllscher']",
#         '4 Estaciones Portenas (pour guitare): N°.1 Primavera Porteña'],
#        dtype='<U661'),
#  array(['94.6359246186746', "['于璇']", '憶良人'], dtype='<U661'),
#  array(['94.98249963157053', "['NF']", 'Statement'], dtype='<U661'),
#  array(['94.93045098635497', "['Kansas']",
#         "It Takes a Woman's Love (To Make a Man)"], dtype='<U661'),
#  array(['94.76105041789299', "['Erik Satie', 'Philippe Entremont']",
#         'Gymnopédie No. 3'], dtype='<U661'),
#  array(['94.55736260637416', "['Rusty & Doug Kershaw']", 'Kaw Liga'],
#        dtype='<U661'),
#  array(['94.87333847275353', "['Jenni Rivera', 'Lupillo Rivera']",
#         'Que Me Entierren Con la Banda'], dtype='<U661'),
#  array(['94.9327495492932', "['YoungBoy Never Broke Again']",
#         'Self Control'], dtype='<U661'),
#  array(['94.65197423094965', "['Frédéric Chopin', 'Vladimir Horowitz']",
#         'Barcarolle, Op. 60'], dtype='<U661'),
#  array(['94.54054005778268', "['Talat Mahmood']",
#         'Aaye Bhi Akela Jaye Bhi Akela (From "Dost")'], dtype='<U661'),
#  array(['95.58976093733851',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 2 - Dialogues'], dtype='<U661'),
#  array(['95.03663341419976', "['Chris Isaak']", "Cryin'"], dtype='<U661'),
#  array(['95.0949256664608', "['Saxon']", 'Ride Like the Wind'],
#        dtype='<U661'),
#  array(['95.00849379204442', "['Demon Hunter']", 'I Am a Stone'],
#        dtype='<U661'),
#  array(['94.63234660704113', "['Dave Bartholomew']", 'My Ding-A-Ling'],
#        dtype='<U661'),
#  array(['94.86356164654305', "['謝雷']", '流浪漢'], dtype='<U661'),
#  array(['94.72031527651842', "['The Dave Brubeck Quartet']", 'Countdown'],
#        dtype='<U661'),
#  array(['94.61258870620398', "['Эрих Мария Ремарк']",
#         'Часть 21.3 & Часть 22.1 - Триумфальная арка'], dtype='<U661'),
#  array(['95.07951613889223', "['Los Invasores De Nuevo León']", 'Clave 7'],
#        dtype='<U661'),
#  array(['95.09030446512014', "['Sigur Rós']", 'Olsen olsen'], dtype='<U661'),
#  array(['94.89295802338623', "['Martina McBride']", 'Concrete Angel'],
#        dtype='<U661'),
#  array(['94.79691763522546', "['The Turtles']",
#         'Guide For The Married Man'], dtype='<U661'),
#  array(['94.77723896202897',
#         "['Dizzy Gillespie', 'Charlie Parker', 'Thelonious Monk', 'Curly Russell', 'Buddy Rich']",
#         'Leap Frog - Take 11 / Take 6 / Master Take'], dtype='<U661'),
#  array(['94.75839039106978', "['Harry Belafonte']", 'Hava Nageela - Live'],
#        dtype='<U661'),
#  array(['95.08328049682558', "['Los Acosta']", 'Y Cómo Te Va'],
#        dtype='<U661'),
#  array(['94.60824007594837', "['Hemant Kumar']", 'Tomay Gaan Shonabo'],
#        dtype='<U661'),
#  array(['94.91952597752176',
#         "['Abraham Vazquez', 'T3R Elemento', 'Los de la O']",
#         'El De Las Dos Pistolas'], dtype='<U661'),
#  array(['94.51499872883477', "['Bessie Smith']",
#         'Need a Little Sugar in My Bowl'], dtype='<U661'),
#  array(['94.87739176179142', "['Eagles']",
#         'Pretty Maids All In A Row - Live On MTV, 1994'], dtype='<U661'),
#  array(['95.04173649508998', "['Ann Lee']", '2 Times - Original'],
#        dtype='<U661'),
#  array(['95.02390270631432', "['Valencia']", 'The Space Between'],
#        dtype='<U661'),
#  array(['94.97825385088294', "['Creed']", 'On My Sleeve'], dtype='<U661'),
#  array(['95.10627324880356', "['Audioslave']", 'Gasoline'], dtype='<U661'),
#  array(['94.82369161336136', "['Killumantii']", 'Rules'], dtype='<U661'),
#  array(['94.37607338592021',
#         "['Johann Sebastian Bach', 'Amsterdam Toonkunst Choir', 'Concertgebouworkest', 'Willem Mengelberg']",
#         'St. Matthew Passion, BWV 244 - Part One: No.4d Chorus I: "Wozu dienet dieser Unrat"'],
#        dtype='<U661'),
#  array(['94.89584620609169',
#         "['Alicia Keys', 'Tony! Toni! Toné!', 'Jermaine Paul']",
#         'Diary (feat. Tony! Toni! Tone! & Jermaine Paul)'], dtype='<U661'),
#  array(['95.19266667952817', "['Don Felder']",
#         'Heavy Metal - Take a Ride; Soundtrack Version'], dtype='<U661'),
#  array(['94.82408482076114', "['The Rolling Stones']",
#         '2120 South Michigan Avenue - Mono Version'], dtype='<U661'),
#  array(['94.5506153931086', "['Tara']", 'Ankhon Mein Ankhen'],
#        dtype='<U661'),
#  array(['94.7047250369007', "['The Smashing Pumpkins']",
#         'Mellon Collie And The Infinite Sadness - Remastered 2012'],
#        dtype='<U661'),
#  array(['94.80142522553051', "['The Rolling Stones']",
#         'Where The Boys Go - Remastered'], dtype='<U661'),
#  array(['94.99428180567696', "['Styx']", 'Rock & Roll Feeling'],
#        dtype='<U661'),
#  array(['94.58891280847837', "['Wolfgang Amadeus Mozart', 'George Szell']",
#         'Violin Sonata in G Major, K.301/293a: II. Allegro'], dtype='<U661'),
#  array(['94.82949141234694', "['Fleetwood Mac']", 'Woman of 1000 Years'],
#        dtype='<U661'),
#  array(['95.08062607140431', "['Tommy Roe']", 'Dizzy'], dtype='<U661'),
#  array(['94.56932698390057', "['The Dubliners', 'Luke Kelly']",
#         'Love Is Pleasing - Live'], dtype='<U661'),
#  array(['94.7749126558993', "['Frank Sinatra']", 'Ring-A-Ding Ding'],
#        dtype='<U661'),
#  array(['94.99011352221271', "['Lorenzo Antonio']", 'Doce Rosas'],
#        dtype='<U661'),
#  array(['94.46720102819849',
#         "['Sergei Prokofiev', 'William Kapell', 'Antal Doráti']",
#         'Concerto No. 3 in C, Op.26: Theme and Variations: Variation IV: Andante meditativo'],
#        dtype='<U661'),
#  array(['94.87355712249776', "['Boosie Badazz', 'Yung Joc']",
#         'Zoom (feat. Yung Joc)'], dtype='<U661'),
#  array(['94.94870343017122', "['Oingo Boingo']", 'Violent Love - 10" EP'],
#        dtype='<U661'),
#  array(['95.1523170038111', "['Red Hot Chili Peppers']",
#         'Naked in the Rain'], dtype='<U661'),
#  array(['94.52331418130487', "['Ella Fitzgerald']", 'That Certain Feeling'],
#        dtype='<U661'),
#  array(['95.12422354512849', "['Flans']", 'Veinte Millas'], dtype='<U661'),
#  array(['94.96644640128233', "['Peter Tosh']",
#         'Wanted Dread and Alive - 2002 Remaster'], dtype='<U661'),
#  array(['94.9540365216839', "['James Taylor']",
#         'How Sweet It Is (To Be Loved By You) - 2019 Remaster'],
#        dtype='<U661'),
#  array(['94.78735701484639', "['Ahmad Jamal Trio']",
#         "What's New - Live At The Pershing, Chicago, 1958"], dtype='<U661'),
#  array(['94.70978716830426', "['Thelonious Monk Quartet']",
#         "'Round Midnight - Live At The Five Spot / July 9, 1958"],
#        dtype='<U661'),
#  array(['94.68779602999328', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 187'], dtype='<U661'),
#  array(['94.82582592519972', "['Kygo', 'Oh Wonder']", 'How Would I Know'],
#        dtype='<U661'),
#  array(['95.00842501128811', "['Shaggy', 'Rayvon']", 'Angel'],
#        dtype='<U661'),
#  array(['95.02449114749189', "['Funkadelic']",
#         "Let's Take It to the Stage"], dtype='<U661'),
#  array(['95.23313523483493', "['Metallica']", 'The Unforgiven III'],
#        dtype='<U661'),
#  array(['94.78682681016095', "['Johann Sebastian Bach', 'Jascha Heifetz']",
#         'Sonata No. 3, BWV 1005, in C: Fugue: Alla breve'], dtype='<U661'),
#  array(['95.10842222554453', "['Aaliyah', 'R. Kelly']",
#         'At Your Best (You Are Love) - Gangstar Child Remix'],
#        dtype='<U661'),
#  array(['95.17442079364443', "['Alicia Keys']", 'No One'], dtype='<U661'),
#  array(['94.95749331274733', "['Bob Dylan']", 'Gotta Serve Somebody'],
#        dtype='<U661'),
#  array(['94.8996296982674', "['The Jacka', 'Andre Nickatina']",
#         'Glamorous Lifestyle (feat. Andre Nickatina)'], dtype='<U661'),
#  array(['94.52497587092444', "['James Brown & The Famous Flames']",
#         'If You Want Me'], dtype='<U661'),
#  array(['94.82017773905599', "['Neil Diamond']", 'Be'], dtype='<U661'),
#  array(['94.96336967636331', "['Men At Work']", 'Overkill'], dtype='<U661'),
#  array(['95.25522869101842', "['Jethro Tull']",
#         'Thick as a Brick - Live at Madison Square Garden'], dtype='<U661'),
#  array(['94.62407536782821', "['Mukesh']",
#         'Chandan Sa Badan Chanchal Chitwan - Male Vocals'], dtype='<U661'),
#  array(['94.58315921419145',
#         "['Fromental Halévy', 'Richard Tucker', 'Wilfrid Pelletier']",
#         'La Juive: "Rachel, quand du seigneur"'], dtype='<U661'),
#  array(['94.97127270545027', "['The Rolling Stones']",
#         'Get Off Of My Cloud - Mono Version'], dtype='<U661'),
#  array(['95.13225381618264', "['Ratatat']", 'Gettysburg'], dtype='<U661'),
#  array(['95.1860337239927', "['Stars Of The Lid']", 'The Atomium Part 2'],
#        dtype='<U661'),
#  array(['94.83292883402075', "['Tom Waits']", 'Chocolate Jesus'],
#        dtype='<U661'),
#  array(['95.04369827078612', "['Shawn Mendes']", "Fallin' All In You"],
#        dtype='<U661'),
#  array(['95.19123958402429', "['Erykah Badu']", 'Tyrone - Live'],
#        dtype='<U661'),
#  array(['94.44476178898596',
#         "['Johann Sebastian Bach', 'Herman Schey', 'Concertgebouworkest', 'Willem Mengelberg']",
#         'St. Matthew Passion, BWV 244 - Part Two: No.64 Recitative (Bass): "Am Abend, da es kühle war"'],
#        dtype='<U661'),
#  array(['94.60410692515804', "['Junior H']", 'No Eh Cambiado'],
#        dtype='<U661'),
#  array(['94.49090328163933', "['Carla Boni']", 'Jezebel'], dtype='<U661'),
#  array(['95.03051711706172', "['Midnight Oil']",
#         'Forgotten Years - 2011 Remaster'], dtype='<U661'),
#  array(['94.29205746427486', "['Francisco Canaro']",
#         'Malvaloca - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['95.06097370185255', "['Slowdive']", 'When the Sun Hits'],
#        dtype='<U661'),
#  array(['94.70665130947788', "['Herb Alpert & The Tijuana Brass']",
#         'Acapulco 1922'], dtype='<U661'),
#  array(['95.21785423369745', "['Jorge Meza Y Su Tropi Colombia']",
#         'Quiero Volar'], dtype='<U661'),
#  array(['95.07599124727878', "['Guster']", 'Do You Love Me'], dtype='<U661'),
#  array(['94.64392079898315', "['The Supremes']",
#         'This Old Heart Of Mine (Is Weak For You) - Mono'], dtype='<U661'),
#  array(['94.97964410700929', "['Queensrÿche']",
#         'Eyes Of A Stranger - Remastered 2003'], dtype='<U661'),
#  array(['94.34594777591593', "['Dimitris Arapakis']",
#         'Evga Gkolfo Sto Vouno'], dtype='<U661'),
#  array(['94.971832619799', "['The Sylvers']", 'Boogie Fever'],
#        dtype='<U661'),
#  array(['95.24114623951749', "['T-Pain', 'Yung Joc']",
#         "Buy U a Drank (Shawty Snappin') (feat. Yung Joc)"], dtype='<U661'),
#  array(['94.73757499844282', "['Nomy']", 'Your Last Breath - LOL Edit'],
#        dtype='<U661'),
#  array(['94.53066459240988',
#         "['Claude Debussy', 'Roger Desormière/Choeurs Yvonne Gouverné/Orchestre Symphonique de Paris', 'Roger Desormiere', 'Orchestre Symphonique De Paris']",
#         'Pelléas et Mélisande (2006 Digital Remaster), Act III, Scene Three: Ah! Je respire enfin! (Pelléas/Golaud)'],
#        dtype='<U661'),
#  array(['94.5799442893908', "['Curtis Lee']",
#         'With All My Heart (I Love You)'], dtype='<U661'),
#  array(['94.55277569673237', "['The Notorious Rio']", 'Twa - Twa'],
#        dtype='<U661'),
#  array(['94.70496599208956', "['Iron & Wine']", 'The Sea and the Rhythm'],
#        dtype='<U661'),
#  array(['94.47298167008847', "['Kostas Roukounas']",
#         'H mana sou tha ta plhrosei'], dtype='<U661'),
#  array(['94.82709222137375', "['Rodríguez']", 'A Most Disgusting Song'],
#        dtype='<U661'),
#  array(['95.06036751988302', "['Lady Gaga']", 'Marry The Night'],
#        dtype='<U661'),
#  array(['94.61217055731922', "['Marty Robbins']", 'I Hang My Head And Cry'],
#        dtype='<U661'),
#  array(['95.13952400629739', "['The Stranglers']", 'Golden Brown'],
#        dtype='<U661'),
#  array(['94.95470829829591', "['EARTHGANG', 'Young Thug']",
#         'Proud Of U (feat. Young Thug)'], dtype='<U661'),
#  array(['94.9343933652445',
#         "['Minnie Riperton', 'Peabo Bryson', 'Roberta Flack']",
#         'Here We Go'], dtype='<U661'),
#  array(['94.40190336471143', "['Lloyd Price']", 'Lawdy Miss Clawdy'],
#        dtype='<U661'),
#  array(['94.79397815767007', "['Pop Smoke', 'A Boogie Wit da Hoodie']",
#         'Foreigner (feat. A Boogie Wit da Hoodie)'], dtype='<U661'),
#  array(['94.73683550208148', "['Camilo Sesto']", 'Sueño de Pilatos'],
#        dtype='<U661'),
#  array(['94.66007821957785', "['Marty Robbins']", 'The Fastest Gun Around'],
#        dtype='<U661'),
#  array(['94.67141209471265', "['Doja Cat', 'Smino']", "Won't Bite"],
#        dtype='<U661'),
#  array(['94.95975272294442', "['Nine Inch Nails']", 'Pilgrimage'],
#        dtype='<U661'),
#  array(['94.57801496349437', "['C418']", 'Chris'], dtype='<U661'),
#  array(['94.6056804999916', "['Lefty Frizzell']",
#         "My Baby's Just Like Money"], dtype='<U661'),
#  array(['95.04652495109964', "['Bigger Thomas']", 'Chaos'], dtype='<U661'),
#  array(['94.92155945033834', "['Grupo Cañaveral De Humberto Pabón']",
#         'Estoy Enamorado De Ti'], dtype='<U661'),
#  array(['94.46404814100616', "['Orchestra Studio 7']",
#         "Uocchie c' arraggiunate - Instrument and base Version"],
#        dtype='<U661'),
#  array(['94.40642880657322',
#         "['Giuseppe Verdi', 'Ede Marietti Gandolfo', 'Gabriele Santini', 'Mario Zorgniotti', 'Orchestra Sinfonica della RAI']",
#         'Verdi: La traviata, Act 2: "Avram lieta di maschere la notte" (Flora, Marquis, Doctor)'],
#        dtype='<U661'),
#  array(['94.81823038665935', "['Air']", 'New Star in the Sky'],
#        dtype='<U661'),
#  array(['94.5370421055774', "['The Amboina Serenaders']",
#         'Binta Ingin Man Poelang'], dtype='<U661'),
#  array(['94.98293102515632', "['The Manhattans']",
#         'We Never Danced To A Love Song'], dtype='<U661'),
#  array(['95.03824826533942', "['Todd Rundgren']",
#         'Izzat Love? - 2015 Remaster'], dtype='<U661'),
#  array(['94.49089186650643', "['The Channels', 'Earl Lewis']",
#         'Stay as You Are'], dtype='<U661'),
#  array(['94.90744063933178', "['Nolan Porter']", "Keep On Keepin' On"],
#        dtype='<U661'),
#  array(['94.71389575493332', "['$uicideBoy$', 'Germ']", 'Obey The Walrus'],
#        dtype='<U661'),
#  array(['94.61380460076394', "['Dinah Washington', 'Brook Benton']",
#         "Baby (You've Got What It Takes)"], dtype='<U661'),
#  array(['94.58060989306558',
#         "['Evadne Baker', 'Annalee', 'Portia Nelson', 'Marni Nixon']",
#         'Goodbye Maria / How Can Love Survive Waltz'], dtype='<U661'),
#  array(['95.10605451330348', "['Janet Jackson', 'Vanessa-Mae']",
#         'Velvet Rope'], dtype='<U661'),
#  array(['94.87876253808706', "['Fleetwood Mac']",
#         'Spare Me a Little of Your Love'], dtype='<U661'),
#  array(['94.52931052338363', "['Ray Price']", 'Heartaches By The Number'],
#        dtype='<U661'),
#  array(['95.02278890126895', "['Asia']", 'Never In A Million Years'],
#        dtype='<U661'),
#  array(['94.70218236589139', "['Zofia Dromlewiczowa']",
#         'Chapter 3.10 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['95.1541421215084', "['Reckless Kelly']", 'Seven Nights In Eire'],
#        dtype='<U661'),
#  array(['94.50803168942652',
#         "['Richard Wagner', 'Joseph Keilberth', 'Bayreuth Festival Orchestra']",
#         'Der Ring Des Nibelungen : Reisen Wurm Winde Sich Ringelnd!'],
#        dtype='<U661'),
#  array(['94.4249108690337', "['Sergei Rachmaninoff', 'Moura Lympany']",
#         '13 Preludes, Op. 32: No. 13 in D-Flat Major: Grave - Allegro - Grave'],
#        dtype='<U661'),
#  array(['94.80867330278808', "['James Horner']",
#         '"Take Her to Sea, Mr. Murdoch"'], dtype='<U661'),
#  array(['94.9442507728487', "['Rey Ruiz']", 'Si Te Preguntan'],
#        dtype='<U661'),
#  array(['94.55026658617159', "['Erroll Garner']", 'Love Walked In'],
#        dtype='<U661'),
#  array(['94.82349759607916', "['Kehlani']", 'Bad News'], dtype='<U661'),
#  array(['94.76855135602838', "['The Dave Clark Five']",
#         'Your Turn to Cry - 2019 - Remaster'], dtype='<U661'),
#  array(['94.87726781394682', "['The Pharcyde']", 'Moment In Time'],
#        dtype='<U661'),
#  array(['94.59338019753487', "['Andrew Rowan Summers']",
#         'My Mother Chose My Husband'], dtype='<U661'),
#  array(['95.20751603153379', "['Rebelution']", 'Green to Black'],
#        dtype='<U661'),
#  array(['94.9276237084361', '["Girls\' Generation"]', 'Gee'], dtype='<U661'),
#  array(['95.02772157453369', "['Lifehouse']", 'Falling In'], dtype='<U661'),
#  array(['95.06723050133627', "['Fugees']", 'The Mask'], dtype='<U661'),
#  array(['95.14835525809728', "['Dr. John']", 'I Walk on Guilded Splinters'],
#        dtype='<U661'),
#  array(['94.93731303403635', "['Salt-N-Pepa']", 'None Of Your Business'],
#        dtype='<U661'),
#  array(['95.03952043208832', "['Nerf Herder']", 'Van Halen'], dtype='<U661'),
#  array(['94.51126631717989', "['Buddy DeFranco']",
#         'It Could Happen To You'], dtype='<U661'),
#  array(['94.66388914725405', "['Dean Martin']", 'Zing-A Zing-A Zing Boom'],
#        dtype='<U661'),
#  array(['95.08818530844353', "['Jodeci']", 'My Heart Belongs To U'],
#        dtype='<U661'),
#  array(['94.727518711338', "['Mukesh', 'Vyjayanthimala']",
#         'Bol Radha Bol, Pt. 1'], dtype='<U661'),
#  array(['94.79746578005243', "['Ramon Ayala Y Sus Bravos Del Norte']",
#         'Corrido De El Quemador'], dtype='<U661'),
#  array(['94.96808248389789', "['New Order']", 'Round & Round'],
#        dtype='<U661'),
#  array(['94.52263596917518', "['Oscar Peterson']", 'Angel Eyes'],
#        dtype='<U661'),
#  array(['94.50246705530972', "['Uma Devi']", 'Aaj Machi Hai Dhoom'],
#        dtype='<U661'),
#  array(['94.83244152185124', "['El Potro De Sinaloa']", 'Chuy Y Mauricio'],
#        dtype='<U661'),
#  array(['95.10440078435103', "['The Kinks']",
#         'Lola - Live at Providence Civic Center, Providence, RI - September 1979'],
#        dtype='<U661'),
#  array(['95.12138010898934', "['Miles Davis']",
#         "Walkin' - Live at Philharmonic Hall, New York, NY - February 1964"],
#        dtype='<U661'),
#  array(['95.02217812335051', "['Nine Inch Nails']", 'Closer'],
#        dtype='<U661'),
#  array(['94.43027002613617',
#         "['Yessister, Jazzsister', 'Marine Band Of The Royal Netherlands Navy', 'Major Peter Kleine Schaars']",
#         'Hark! The Herald Angels Sing'], dtype='<U661'),
#  array(['94.76748489073368', "['Ariana Grande']", 'Only 1'], dtype='<U661'),
#  array(['94.90914086809785', "['Los Bukis']", 'Ella No Sabia'],
#        dtype='<U661'),
#  array(['95.05864093107355', "['London Grammar', 'ARTY']",
#         'Hey Now - Arty Remix'], dtype='<U661'),
#  array(['95.02072546805186', "['Donovan']", 'I Love My Shirt'],
#        dtype='<U661'),
#  array(['94.94544659154961', "['Billy Stewart']", 'Summertime'],
#        dtype='<U661'),
#  array(['94.84993827607316', "['Johann Sebastian Bach', 'Julia Cload']",
#         'Goldberg-Variationen, BWV 988: I. Aria'], dtype='<U661'),
#  array(['94.49172333774165', "['Bharat Vyas', 'Shanta Thakar']",
#         'Chhip Chhip Kar Mat Dekho Ji'], dtype='<U661'),
#  array(['95.09233531245901',
#         "['James Horner', 'London Symphony Orchestra']",
#         "'Sons Of Scotland' - From “Braveheart” Soundtrack"], dtype='<U661'),
#  array(['94.90134054191957', "['B.o.B']", "Don't Let Me Fall"],
#        dtype='<U661'),
#  array(['94.81639908410047', "['Carmen McRae']", 'Them There Eyes'],
#        dtype='<U661'),
#  array(['94.80015501622626', "['The Notorious B.I.G.']",
#         'Ready to Die - 2006 Remaster'], dtype='<U661'),
#  array(['95.23101217491676', "['Frank Zappa', 'The Mothers Of Invention']",
#         'Inca Roads'], dtype='<U661'),
#  array(['94.8771660426919', "['Death']", 'Infernal Death'], dtype='<U661'),
#  array(['94.87037270990292', "['Los Herederos De Nuevo León']",
#         'Palabra de borracho'], dtype='<U661'),
#  array(['94.84402219403604', "['Daft Punk', 'Panda Bear']",
#         "Doin' it Right (feat. Panda Bear)"], dtype='<U661'),
#  array(['95.03682695735161', "['Big Pun', 'Joe']",
#         'Still Not a Player (feat. Joe)'], dtype='<U661'),
#  array(['94.97354612421202', "['Rodney Atkins']", "Farmer's Daughter"],
#        dtype='<U661'),
#  array(['94.97392661847307', "['David Gilmour']", 'On an Island'],
#        dtype='<U661'),
#  array(['94.96065817413134', "['Carrie Underwood']",
#         'Something in the Water'], dtype='<U661'),
#  array(['95.03553861822061',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: II. Im Tempo eines gemächlichen Ländlers - Etwas täppisch und sehr derb'],
#        dtype='<U661'),
#  array(['94.83076830421487', "['Francesco De Gregori']", 'Rimmel'],
#        dtype='<U661'),
#  array(['94.84435444580838',
#         "['50 Cent', 'Justin Timberlake', 'Timbaland']", 'Ayo Technology'],
#        dtype='<U661'),
#  array(['94.73246615458856', "['Jimmy Buffett']", 'California Promises'],
#        dtype='<U661'),
#  array(['94.92131198102786', "['Mary J. Blige', 'U2']", 'One'],
#        dtype='<U661'),
#  array(['94.84049427102207', "['Indigo Girls']", 'Get Out the Map'],
#        dtype='<U661'),
#  array(['94.52317290451117', "['MGM Studio Orchestra', 'André Previn']",
#         "Gigi's Big Moment"], dtype='<U661'),
#  array(['94.75513707777417', "['Eddie Palmieri']", "Si Echo Pa'lante"],
#        dtype='<U661'),
#  array(['94.44222815082011', "['Bernard Herrmann']",
#         'The Wild Ride / Car Crash'], dtype='<U661'),
#  array(['94.86246965035666', "['The Animals']", 'Boom Boom'], dtype='<U661'),
#  array(['95.06287667789094', "['Black Sabbath']",
#         'Wishing Well - 2008 Remaster'], dtype='<U661'),
#  array(['94.68738136996042', "['Alan Silvestri']",
#         "I'm Forrest... Forrest Gump"], dtype='<U661'),
#  array(['94.59493503101345', "['Sushil Chatterjee']",
#         'Gaan Amar Jaay Bhese Jaay'], dtype='<U661'),
#  array(['94.6278004527526', "['Charlie Parker Septet']", 'Cardboard'],
#        dtype='<U661'),
#  array(['94.48740760891113', "['Francisco Canaro', 'Carlos Roldán']",
#         'Naipe - Remasterizado'], dtype='<U661'),
#  array(['94.7883932205127', "['Los Invasores De Nuevo León']",
#         'Mi Flor De Naranjo'], dtype='<U661'),
#  array(['94.99871173609577', '[\'"Weird Al" Yankovic\']',
#         'Smells Like Nirvana'], dtype='<U661'),
#  array(['94.66170670517019', "['George Jones']", 'The Grand Tour'],
#        dtype='<U661'),
#  array(['94.83892500474687', "['Stan Getz']", 'Split Kick'], dtype='<U661'),
#  array(['94.76357871257987', "['Cyndi Lauper']", "I'm Gonna Be Strong"],
#        dtype='<U661'),
#  array(['94.60032473582798', "['Massiel']", 'Rosas en el Mar'],
#        dtype='<U661'),
#  array(['94.48931227295968',
#         "['Victor Silvester and his Ballroom Orchestra']",
#         'That Lovely Weekend'], dtype='<U661'),
#  array(['94.73816336571572', "['Austin Wintory']", 'Nascence'],
#        dtype='<U661'),
#  array(['95.1931121933506', "['Rita Ora', 'Chris Brown']",
#         'Body on Me (feat. Chris Brown)'], dtype='<U661'),
#  array(['95.0114318503669', "['Elvis Presley']",
#         'A Little Less Conversation'], dtype='<U661'),
#  array(['94.34295482484576',
#         "['Jelly Roll Morton & His Red Hot Peppers', 'Jelly Roll Morton']",
#         'Smoke House Blues'], dtype='<U661'),
#  array(['94.91014725146967', "['Jerry Reed']", 'East Bound and Down'],
#        dtype='<U661'),
#  array(['95.05991435731396', "['Montgomery Gentry']",
#         'Something to Be Proud Of'], dtype='<U661'),
#  array(['95.0158247134474', "['Norman Greenbaum']", 'Spirit in the Sky'],
#        dtype='<U661'),
#  array(['94.8271335402011', "['Dalida']", 'Love In Portofino'],
#        dtype='<U661'),
#  array(['95.09921260729351', "['City Boy']", '5-7-0-5'], dtype='<U661'),
#  array(['94.8420775275803', "['Koko Taylor']", 'Wang Dang Doodle'],
#        dtype='<U661'),
#  array(['94.85081734056021',
#         "['La Arrolladora Banda El Limón De Rene Camacho']", 'Mi Gusto Es'],
#        dtype='<U661'),
#  array(['94.69724804300202', "['The Marcels']", 'Blue Moon - 45 Version'],
#        dtype='<U661'),
#  array(['95.07245572634086', "['Trick Daddy', 'Lil Jon', 'Twista']",
#         "Let's Go (feat. Big D & Twista)"], dtype='<U661'),
#  array(['95.05688927508605', "['LOCASH']", 'I Love This Life'],
#        dtype='<U661'),
#  array(['94.50343490628751', "['Carlo Buti']", 'Stornellacci – 2'],
#        dtype='<U661'),
#  array(['94.83684470026533', "['Chama Wijnen']", 'Reaching'], dtype='<U661'),
#  array(['95.00396077716279', "['Chicago']",
#         'Please Hold On - 2006 Remaster'], dtype='<U661'),
#  array(['94.75428613582187', "['The J. Geils Band']", 'Wait'],
#        dtype='<U661'),
#  array(['94.79468699798628', "['Sean Hayes']", 'Rattlesnake Charm'],
#        dtype='<U661'),
#  array(['94.2663643516401',
#         "['Francois Campion', 'Julio Martinez Oyanguren']",
#         'Gavotte en rondeau'], dtype='<U661'),
#  array(['94.58345367506612', "['Bill Evans Trio']",
#         'Polka Dots And Moonbeams - Take 3'], dtype='<U661'),
#  array(['94.93751687991073', "['Miles Davis', 'Lighthouse All Stars']",
#         'Drum Conversation'], dtype='<U661'),
#  array(['94.82257650368562', "['Huey Lewis & The News']", 'World To Me'],
#        dtype='<U661'),
#  array(['94.63495792252313', "['Bad Religion']", 'Turn On the Light'],
#        dtype='<U661'),
#  array(['95.21198723193926', "['The Rascals']", 'Like a Rolling Stone'],
#        dtype='<U661'),
#  array(['95.00285066265756',
#         "['Big Head Todd and The Monsters', 'Tom Lord-Alge']",
#         'Resignation Superman'], dtype='<U661'),
#  array(['94.53166965297164', "['George Winston']", 'Rest Your Head'],
#        dtype='<U661'),
#  array(['94.44408063584022',
#         "['Dionisio Aguado', 'Julio Martinez Oyanguren']",
#         'Allegro in G major'], dtype='<U661'),
#  array(['95.0388581951245', "['Brooks & Dunn']", 'Lost and Found'],
#        dtype='<U661'),
#  array(['95.02164862819238', "['Billy Squier']",
#         'Whadda You Want From Me - Remastered'], dtype='<U661'),
#  array(['94.64968271861422',
#         "['Pyotr Ilyich Tchaikovsky', 'Fritz Reiner']",
#         'Symphony No. 6 in B Minor, Op. 74 "Pathétique": III. Allegro molto vivace'],
#        dtype='<U661'),
#  array(['94.69175213147652', "['A Heart Beats']", 'A Thousand Miles Away'],
#        dtype='<U661'),
#  array(['95.04811590366472', "['Discovery']", 'Osaka Loop Line'],
#        dtype='<U661'),
#  array(['94.51817155780667',
#         "['Ashok Kumar', 'Rahmat Bano', 'Arun Kumar']",
#         'Aaj Mausam Salona Salona Re'], dtype='<U661'),
#  array(['94.85390208640376', "['Elvis Costello']", 'Pay It Back - \\'],
#        dtype='<U661'),
#  array(['94.82253788158066', "['J.I the Prince of N.Y']", 'Blame on Me'],
#        dtype='<U661'),
#  array(['95.0532831119593', "['Ava Max']", 'Not Your Barbie Girl'],
#        dtype='<U661'),
#  array(['94.9845401322305', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 42'], dtype='<U661'),
#  array(['94.70603988067802', "['Jorge Ben Jor']", 'Uala Ualalá'],
#        dtype='<U661'),
#  array(['94.72977967495426', "['Martin Denny']", 'Clair De Lune'],
#        dtype='<U661'),
#  array(['95.08496685742683', "['Beastie Boys']",
#         'Pass The Mic (Pt. 2, Skills To Pay The Bills)'], dtype='<U661'),
#  array(['94.52879701529194', "['Mildred Bailey & Her Orchestra']",
#         'Lover, Come Back to Me'], dtype='<U661'),
#  array(['95.01272994001292', "['Kanales']", 'Benito'], dtype='<U661'),
#  array(['94.87584991240902', "['Hillsong UNITED']",
#         'Even When It Hurts (Praise Song) - Live'], dtype='<U661'),
#  array(['94.53987254570288', "['Ella Fitzgerald']",
#         'White Christmas - Alternate Take'], dtype='<U661'),
#  array(['94.68088660351414', "['Andrew Dice Clay']", 'Mother Goose'],
#        dtype='<U661'),
#  array(['94.68371063647788', "['Merle Haggard', 'The Strangers']",
#         'The Silver Ghost'], dtype='<U661'),
#  array(['94.56761494764628', "['Paul Simon']", 'He Was My Brother'],
#        dtype='<U661'),
#  array(['94.66278508415485', "['Nine Inch Nails']", 'March Of The Pigs'],
#        dtype='<U661'),
#  array(['95.1289608931601', "['Bad Bunny']", '25/8'], dtype='<U661'),
#  array(['94.47603009807227', "['Master Krishnarao']",
#         'Hriday Mein Murti Jiski Hai'], dtype='<U661'),
#  array(['95.06189573748034', "['Jimmy Eat World']", 'Kill'], dtype='<U661'),
#  array(['94.94605473288568', "['Lalah Hathaway']", 'That Was Then'],
#        dtype='<U661'),
#  array(['94.96980250322034', "['Bad Religion']", 'Operation Rescue'],
#        dtype='<U661'),
#  array(['95.0486008791605', "['Cream']", 'N.S.U.'], dtype='<U661'),
#  array(['94.99837217610829', "['Skillet']", "Don't Wake Me"], dtype='<U661'),
#  array(['94.79327187940338', "['The Beach Boys', 'Mark Linett', 'Sweet']",
#         'Christmas Day - 1991 Remix'], dtype='<U661'),
#  array(['94.97511126968347', "['Hootie & The Blowfish']", 'I Go Blind'],
#        dtype='<U661'),
#  array(['94.93177704209468', "['Sam & Dave']", 'You Got It Made'],
#        dtype='<U661'),
#  array(['94.4492690916672', "['Münir Nurettin Selçuk']", 'Aylar Geçiyor'],
#        dtype='<U661'),
#  array(['94.8995718552128', "['Ouse', 'Powfu']", 'Lovemark'], dtype='<U661'),
#  array(['94.48213613125759', "['Эрнест Хемингуэй']",
#         'Часть 11.3 & Часть 12.1 - Прощай оружие'], dtype='<U661'),
#  array(['94.62858320978626',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 50'],
#        dtype='<U661'),
#  array(['95.10008814973969', "['No Doubt']", 'Hella Good'], dtype='<U661'),
#  array(['94.58286191800255', "['Elvis Presley']", "You Don't Know Me"],
#        dtype='<U661'),
#  array(['94.4905318130264',
#         "['Sister Rosetta Tharpe', 'Marie Knight', 'Sam Price Trio']",
#         'Up Above My Head I Hear Music In The Air'], dtype='<U661'),
#  array(['94.25412517132526', "['Benny Goodman']", "Let's Dance"],
#        dtype='<U661'),
#  array(['94.59498121633011', "['Count Basie']", 'Basie Goes Wess'],
#        dtype='<U661'),
#  array(['94.87802122156127', "['Sam Smith']", 'Pray'], dtype='<U661'),
#  array(['94.45762241855566', "['Frédéric Chopin', 'Arthur Rubinstein']",
#         'Mazurkas, Op. 6: No. 2 in C-Sharp Minor'], dtype='<U661'),
#  array(['94.55622817588375', "['Billie Holiday', 'Eddie Heywood']",
#         "Let's Do It (with Eddie Heywood & His Orchestra) - Take 2"],
#        dtype='<U661'),
#  array(['95.00764244637656', "['Lonestar']", 'Mr. Mom'], dtype='<U661'),
#  array(['94.69824053993463', "['J. Cole']", 'For Whom The Bell Tolls'],
#        dtype='<U661'),
#  array(['94.85140433687802', "['Jaymes Young']", 'Moondust - EP Version'],
#        dtype='<U661'),
#  array(['95.13433544887162', "['Dead Can Dance']",
#         'Black Sun (Remastered)'], dtype='<U661'),
#  array(['94.74023345815972', "['Marlene Dietrich']", 'Lili Marleen.'],
#        dtype='<U661'),
#  array(['94.4424962772139', "['Panos Gavalas']", 'O,ti fas kai o,ti pieis'],
#        dtype='<U661'),
#  array(['95.20981183991276', "['Bob James']", 'Sign Of The Times'],
#        dtype='<U661'),
#  array(['94.67379303687427', "['Johnny Cash']", 'Folsom Prison Blues'],
#        dtype='<U661'),
#  array(['94.55886064507919', "['Johann Sebastian Bach', 'Isaac Stern']",
#         'Violin Sonata in E Minor, BWV 1023: II. Adagio ma non tanto'],
#        dtype='<U661'),
#  array(['94.91835654285993', "['Big Gemini']", 'Hypnotized'], dtype='<U661'),
#  array(['95.0970807884001', "['Depeche Mode']",
#         'People Are People - 2006 Remaster'], dtype='<U661'),
#  array(['94.78028985234005', "['John Coltrane']", 'Chronic Blues'],
#        dtype='<U661'),
#  array(['95.28407577385157', "['Marc Broussard']", 'Love And Happiness'],
#        dtype='<U661'),
#  array(['95.1464855861205', "['Tevin Campbell']", "I'm Ready"],
#        dtype='<U661'),
#  array(['95.18230023020912', "['Miike Snow']", 'Animal'], dtype='<U661'),
#  array(['94.96215894510945', "['The Isley Brothers']",
#         'For the Love of You, Pts. 1 & 2'], dtype='<U661'),
#  array(['94.81726609475108', "['Nas', 'Quan']",
#         'Just a Moment (feat. Quan)'], dtype='<U661'),
#  array(['94.63210223043842',
#         "['Wolfgang Amadeus Mozart', 'William Kapell']", 'Adagio II'],
#        dtype='<U661'),
#  array(['95.03355371567292', "['Dokken']",
#         'Paris Is Burning - Live in Berlin, 1982'], dtype='<U661'),
#  array(['94.77612628732201', "['Angela Carrasco']", 'Quererte a Ti'],
#        dtype='<U661'),
#  array(['94.86371870034444', "['El Komander']", 'El Taquicardio'],
#        dtype='<U661'),
#  array(['95.04177663418662', "['The Byrds']",
#         'Stranger in a Strange Land - Instrumental'], dtype='<U661'),
#  array(['94.88469371189842',
#         "['Wolfgang Amadeus Mozart', 'Howard Shelley', 'London Mozart Players']",
#         'Piano Concerto No. 21 in C Major, K. 467 "Elvira Madigan": II. Andante'],
#        dtype='<U661'),
#  array(['94.7769693031505',
#         "['Johann Sebastian Bach', 'Jascha Heifetz', 'Erick Friedman', 'Thornton Lofthouse', 'The New Symphony Orchestra Of London', 'Sir Malcolm Sargent']",
#         'Concerto in D Minor for Two Violins, BWV 1043: Allegro'],
#        dtype='<U661'),
#  array(['94.70811976834321', "['Boards of Canada']",
#         'Over The Horizon Radar'], dtype='<U661'),
#  array(['94.9245550622615', "['Lee Morgan']", 'A Night In Tunisia'],
#        dtype='<U661'),
#  array(['95.0486946608338', "['Kings of Leon']", 'California Waiting'],
#        dtype='<U661'),
#  array(['94.98254632480312',
#         "['Maia Mitchell', 'Grace Phipps', 'Ross Lynch', 'Spencer Lee', 'Teen Beach Movie Cast']",
#         'Like Me'], dtype='<U661'),
#  array(['95.17305433287494', "['Lady Gaga', 'BLACKPINK']",
#         'Sour Candy (with BLACKPINK)'], dtype='<U661'),
#  array(['95.12518564337195', "['Jon Bon Jovi']", 'Santa Fe'], dtype='<U661'),
#  array(['95.07321263562086', "['The Sound']", 'Where the Love Is'],
#        dtype='<U661'),
#  array(['94.61884212756482', "['Michael Maguire']",
#         'Do You Hear The People Sing?'], dtype='<U661'),
#  array(['95.01791801755822', "['The Who']", 'Bargain - Live'],
#        dtype='<U661'),
#  array(['94.98250466786433', "['TobyMac']", 'Ignition'], dtype='<U661'),
#  array(['94.69929542508794', "['Ludwig van Beethoven', 'Wilhelm Kempff']",
#         'Sonate pour piano No. 31 in A-Flat Major, Op. 110: III. Adagio, ma non troppo – Fuga (Allegro, ma non troppo)'],
#        dtype='<U661'),
#  array(['94.452466469468', "['Lata Mangeshkar']",
#         'Man Mile Jithe Doghanche'], dtype='<U661'),
#  array(['95.01246113478135', "['John Holt']", 'Fat She Fat'], dtype='<U661'),
#  array(['94.85121808471797', "['Chris de Burgh']",
#         'Carry Me (Like A Fire In Your Heart)'], dtype='<U661'),
#  array(['94.6392352137223', "['Coleman Hawkins', 'Ben Webster']",
#         'Shine On Harvest Moon'], dtype='<U661'),
#  array(['94.74978204374554', "['The Kinks']",
#         'You Really Got Me - Mono Mix'], dtype='<U661'),
#  array(['94.42516808254526', "['Francisco Canaro', 'Charlo']",
#         'Liborio No Te Cases - Remasterizado'], dtype='<U661'),
#  array(['95.13532515412919',
#         "['Dimitri Vegas & Like Mike', 'Martin Garrix']",
#         'Tremor - Sensation 2014 Anthem'], dtype='<U661'),
#  array(['94.79458269800598', "['Yo La Tengo']", "I'll Be Around"],
#        dtype='<U661'),
#  array(['94.71168749091096', "['Françoise Hardy']",
#         "L'anamour - Remasterisé en 2016"], dtype='<U661'),
#  array(['94.57178465701958', "['Los Panchos', 'Javier Solís']",
#         'Llorarás (with Javier Solís)'], dtype='<U661'),
#  array(['94.98316172573071', "['Phantogram']", "When I'm Small"],
#        dtype='<U661'),
#  array(['94.42293463926666', "['S. D. Batish']", 'Meri Arzoo Dekh Kya'],
#        dtype='<U661'),
#  array(['95.129892829928', "['Queen']", 'Let Me Entertain You'],
#        dtype='<U661'),
#  array(['94.67713910098216', "['Jr. Walker & The All Stars']",
#         "Cleo's Mood"], dtype='<U661'),
#  array(['95.04830523434279', "['Julieta Venegas']", 'Limón y Sal'],
#        dtype='<U661'),
#  array(['94.38215013873655', "['George Olsen']",
#         "You'll Never Get to Heaven with Those Eyes"], dtype='<U661'),
#  array(['94.90219903868379', "['Andrew W.K.']", "It's Time To Party"],
#        dtype='<U661'),
#  array(['95.1743486345023', "['Wilson Pickett']", 'Mustang Sally'],
#        dtype='<U661'),
#  array(['94.5935559228526', "['THE GUY']", 'Return/Gone'], dtype='<U661'),
#  array(['95.05295839459205', "['Britny Fox']", 'Long Way To Love'],
#        dtype='<U661'),
#  array(['94.8453652667532', "['The Kinks']",
#         'House In the Country - Mono Mix'], dtype='<U661'),
#  array(['94.64120705156243', "['Local Oafs']",
#         'Jag Har Ett Sinne För Tobak Och Alkohol'], dtype='<U661'),
#  array(['95.10480030235627', "['Merl Saunders', 'Jerry Garcia']",
#         'Positively 4th Street'], dtype='<U661'),
#  array(['94.9382643633076', "['Squeeze']", 'Annie Get Your Gun'],
#        dtype='<U661'),
#  array(['94.76237698961666', "['Rocío Dúrcal']", 'No Lastimes Más'],
#        dtype='<U661'),
#  array(['94.87385817564011', "['Nancy Sinatra']", 'So Long, Babe'],
#        dtype='<U661'),
#  array(['94.56665295579582', "['Giuseppe Verdi', 'Arturo Toscanini']",
#         'Overture'], dtype='<U661'),
#  array(['94.54449914342932',
#         "['Ella Fitzgerald', 'Paul Weston And His Orchestra']",
#         "You're Laughing At Me"], dtype='<U661'),
#  array(['94.44815007533131', "['Alexander Scriabin', 'Vladimir Horowitz']",
#         'Prelude in B-Flat Minor, Op. 11, No. 16: Misterioso - Remastered'],
#        dtype='<U661'),
#  array(['94.59717497586384', '["Lightnin\' Hopkins"]',
#         'Have You Ever Loved a Woman'], dtype='<U661'),
#  array(['94.79750959881164', "['Frank Sinatra']",
#         'It Happened In Monterey - Remastered 1998'], dtype='<U661'),
#  array(['94.82947538818499', "['The Game', 'Lil Wayne']", 'My Life'],
#        dtype='<U661'),
#  array(['94.76601589560697', "['Marisela']", 'Ahora No'], dtype='<U661'),
#  array(['94.89126523357021', "['Gerardo Ortiz']", 'Para Qué Lastimarme'],
#        dtype='<U661'),
#  array(['94.99910059396838', "['Queen']", 'Somebody To Love - 2011 Mix'],
#        dtype='<U661'),
#  array(['94.86885211255938', "['JAY-Z', 'Alicia Keys']",
#         'Empire State Of Mind'], dtype='<U661'),
#  array(['94.84115845073241',
#         "['The New Life Community Choir', 'John P. Kee']",
#         'Jesus Is Real (feat. John P. Kee) - Live'], dtype='<U661'),
#  array(['95.12355717521618', "['Blake Shelton']", 'Ready to Roll'],
#        dtype='<U661'),
#  array(['94.67212457853073', "['Explosions In The Sky']",
#         'Remember Me As A Time Of Day - Remastered'], dtype='<U661'),
#  array(['94.62789454384', "['Johnny Cash']", 'Mean Eyed Cat'],
#        dtype='<U661'),
#  array(['94.6042149963122', "['Bob Dylan']",
#         'Farewell - Witmark Demo - 1963'], dtype='<U661'),
#  array(['94.93351326841373', "['Eric Weissberg']", 'Old Joe Clark'],
#        dtype='<U661'),
#  array(['95.3012521363801', "['Opeth']", 'Bleak'], dtype='<U661'),
#  array(['94.8578700922884', "['Jimi Hendrix']", 'Highway Chile'],
#        dtype='<U661'),
#  array(['94.61465627677435', "['Andy Williams']", 'The First Noël'],
#        dtype='<U661'),
#  array(['95.045090410669', "['U2']", 'Trip Through Your Wires'],
#        dtype='<U661'),
#  array(['94.82981476725692', "['Primus']", 'Los Bastardos'], dtype='<U661'),
#  array(['94.83801845452194', "['Future']", 'Kno The Meaning'],
#        dtype='<U661'),
#  array(['94.72798031283426', "['Marvin Gaye']", 'Taking My Time'],
#        dtype='<U661'),
#  array(['95.05711181156308', "['Slowdive']", 'Machine Gun'], dtype='<U661'),
#  array(['94.68368662152129', "['John Lee Hooker']", "Please Don't Go"],
#        dtype='<U661'),
#  array(['94.83551214741567', "['Attila']", 'About That Life'],
#        dtype='<U661'),
#  array(['94.70718095777832', "['霜華雪華']", '嘆相思'], dtype='<U661'),
#  array(['95.00217684828984', "['The Kooks']", 'She Moves In Her Own Way'],
#        dtype='<U661'),
#  array(['94.76426033704891', "['Alan Jackson']", 'Remember When'],
#        dtype='<U661'),
#  array(['95.04609876185259', "['New Order']", 'Elegia - 2015 Remaster'],
#        dtype='<U661'),
#  array(['94.71442726777644',
#         "['Wolfgang Amadeus Mozart', 'András Schiff']",
#         'Piano Sonata No.18 in D, K.576: 1. Allegro'], dtype='<U661'),
# ...
#        dtype='<U661'),
#  array(['94.80219805925861', "['R.E.M.']",
#         'Feeling Gravitys Pull - Remastered'], dtype='<U661'),
#  array(['94.7488867753825', "['Albert King']", 'The Very Thought Of You'],
#        dtype='<U661'),
#  array(['94.92885059720753', "['Nitty Gritty Dirt Band']",
#         'An American Dream'], dtype='<U661'),
#  array(['94.963066667687', "['Barre Phillips']", 'S.C. & W.'],
#        dtype='<U661'),
#  array(['94.61169006762336', "['Los Teen Tops']", 'Lucila - Lucille'],
#        dtype='<U661'),
#  array(['94.86628697605941', "['Hollywood Undead']", 'Pour Me'],
#        dtype='<U661'),
#  array(['94.98421353634772', "['Stevie Wonder']", 'My Girl'], dtype='<U661'),
#  array(['94.87616754227392', "['James Brown']",
#         'Funky Drummer - Bonus Beat Reprise'], dtype='<U661'),
#  array(['94.6728457961882',
#         "['Giacomo Puccini', 'Antonino Votto', 'Orchestra Del Teatro Alla Scala Di Milan', 'Orchestra Del Teatro Alla Scala, Milano']",
#         'Chi guardi? (Rodolfo/Colline/Mimì/Schaunard/Marcello/Coro/Parpignol/Ragazzi) - 1997 Remastered Version'],
#        dtype='<U661'),
#  array(['94.92708522183936', "['The Beatles']",
#         "A Hard Day's Night - Remastered 2009"], dtype='<U661'),
#  array(['94.85765356499626', "['Ben Webster', 'Joe Zawinul']", 'Soulmates'],
#        dtype='<U661'),
#  array(['95.05518262935131', "['Three Dog Night']",
#         "Sure As I'm Sittin' Here"], dtype='<U661'),
#  array(['95.00675912514151', "['Cardenales De Nuevo León']",
#         'Belleza De Cantina'], dtype='<U661'),
#  array(['94.5885690467227', "['Misfits', 'Glenn Danzig']",
#         'Who Killed Marilyn?'], dtype='<U661'),
#  array(['95.19961086917868',
#         "['Lola Beltrán', 'Amalia Mendoza', 'Lucha Villa', 'Juan Gabriel', 'Vicente Fernández', 'Las Hermanas Padilla', 'Las Jilguerillas', 'El Piporro', 'La Prieta Linda']",
#         'Obertura Mexicana'], dtype='<U661'),
#  array(['95.0557967304106', "['U2']",
#         'Where The Streets Have No Name - Remastered'], dtype='<U661'),
#  array(['94.40340933504423', "['Robin Majumdar']",
#         'Chale Rater O Rajanigandha'], dtype='<U661'),
#  array(['94.78317748664877',
#         '[\'Johnny Pacheco\', \'Celia Cruz\', \'Pete "El Conde" Rodriguez\']',
#         'La Dicha Mía'], dtype='<U661'),
#  array(['95.08438257008038', "['Sade']", 'Keep Looking'], dtype='<U661'),
#  array(['94.44365916224191', "['John Fahey']", 'Bicycle Built For Two'],
#        dtype='<U661'),
#  array(['94.59971688937557', "['Sisters & Brothers']",
#         'Sisters And Brothers'], dtype='<U661'),
#  array(['94.67674137242304', "['The 1937 Flood']", 'My Dear Companion'],
#        dtype='<U661'),
#  array(['94.65110368458065',
#         "['Irving Berlin', 'Ethel Merman', 'Mitzi Gaynor']",
#         "A Sailor's Not A Sailor ('Til A Sailor's Been Tatooed)"],
#        dtype='<U661'),
#  array(['95.07072587697006', "['Tedeschi Trucks Band']", 'Bound for Glory'],
#        dtype='<U661'),
#  array(['94.82046806521257', "['Sonny Rollins']",
#         'There Is No Greater Love'], dtype='<U661'),
#  array(['94.86903259534053', "['George Benson']",
#         'The Greatest Love of All'], dtype='<U661'),
#  array(['94.86458669353425',
#         "['Eazy-E', 'Gangsta Dresta', 'B.G. Knocc Out']",
#         'Sippin on a 40 (feat. Gangsta Dresta & B.G. Knocc Out)'],
#        dtype='<U661'),
#  array(['95.14469398238892', "['Britney Spears', 'Iggy Azalea']",
#         'Pretty Girls'], dtype='<U661'),
#  array(['95.05930478483086', "['Marilyn Manson']", 'Personal Jesus'],
#        dtype='<U661'),
#  array(['95.11432461668575', '[\'Evelyn "Champagne" King\']',
#         'Get Up Off Your Love'], dtype='<U661'),
#  array(['94.82655516216184', "['Bahamas']", 'Whole Wide World'],
#        dtype='<U661'),
#  array(['94.98185351161776', "['DR. KUCHO!', 'Gregor Salto', 'Ane Brun']",
#         "Can't Stop Playing (Makes Me High) [feat. Ane Brun] - Oliver Heldens & Gregor Salto Vocal Mix Edit"],
#        dtype='<U661'),
#  array(['94.49607752162031', "['Felix Mendelssohn', 'Maryla Jonas']",
#         'Song without Words in G Minor, Op. 102 No. 4'], dtype='<U661'),
#  array(['94.70599613178676', "['Эрих Мария Ремарк']",
#         'Часть 156.5 & Часть 157.1 - Триумфальная арка'], dtype='<U661'),
#  array(['94.29512099931235', "['Erik Satie', 'Philippe Entremont']",
#         'Les trois valses distingúees du precieux dégoûté: III. Ses jambes'],
#        dtype='<U661'),
#  array(['94.99687193924684', '[\'"Weird Al" Yankovic\']',
#         'Living With a Hernia'], dtype='<U661'),
#  array(['94.72211436099897', "['Rainbow Kitten Surprise']",
#         'Black and White'], dtype='<U661'),
#  array(['94.74610798252773', "['James Baskett']",
#         'Zip- A- Dee-Doo-Dah - From "Song Of The South"'], dtype='<U661'),
#  array(['94.9277724509068', "['Bob Seger']",
#         "Travelin' Man - Live In Detroit/1975"], dtype='<U661'),
#  array(['94.68120994004465', "['Johannes Brahms', 'Glenn Gould']",
#         '6 Klavierstücke, Op. 118: No. 2, Intermezzo in A Major (Alternate Version)'],
#        dtype='<U661'),
#  array(['95.16707208660034', "['Moby']", 'Extreme Ways'], dtype='<U661'),
#  array(['94.89463899626219', '[\'"Weird Al" Yankovic\']',
#         'Girls Just Want to Have Lunch'], dtype='<U661'),
#  array(['94.78222177382175', "['Group of Australian aborigines']",
#         'Djedbang-ari'], dtype='<U661'),
#  array(['94.69310357666652', "['Ray Price']", "I Won't Mention It Again"],
#        dtype='<U661'),
#  array(['94.64450532593618', "['Anson Seabra']", 'Broken'], dtype='<U661'),
#  array(['94.98848828327294', "['Ed Sheeran']", 'Thinking out Loud'],
#        dtype='<U661'),
#  array(['94.36758948461623',
#         "['Louis Armstrong & His Savoy Ballroom Five']", 'Tight Like This'],
#        dtype='<U661'),
#  array(['94.87774690828151', "['Amy Winehouse']", 'Wake Up Alone'],
#        dtype='<U661'),
#  array(['95.03781864624106', "['Whitney Houston']", 'Miracle'],
#        dtype='<U661'),
#  array(['94.95377160131355', "['The Cure']",
#         'The Caterpillar - 2006 Remaster'], dtype='<U661'),
#  array(['94.87228914643964', "['Joji']", 'Sanctuary'], dtype='<U661'),
#  array(['94.57754648041903', "['The Clancy Brothers', 'Tommy Makem']",
#         'All for Me Grog'], dtype='<U661'),
#  array(['94.66521061745082', "['Grupo Laberinto']", "Pa' Otro Rumbo"],
#        dtype='<U661'),
#  array(['94.96615578469117', "['R.E.M.']",
#         'Begin The Begin - 2011 Remaster'], dtype='<U661'),
#  array(['94.78945871667094', "['Frank Sinatra']",
#         'On a Clear Day (You Can See Forever)'], dtype='<U661'),
#  array(['94.96056927939459', "['Them', 'Van Morrison']",
#         'Could You Would You (feat. Van Morrison)'], dtype='<U661'),
#  array(['94.61464204175526',
#         "['Gregorian Chant', 'Benedictine Monks of the Abbey of St. Maurice & St. Maur, Clevaux']",
#         'Adoro te devote - Hymnus in Honorem SS. Sacramenti'],
#        dtype='<U661'),
#  array(['94.92812929029529', "['why mona']", 'Happy Together'],
#        dtype='<U661'),
#  array(['94.74084413551948', "['Mudvayne']", 'Silenced'], dtype='<U661'),
#  array(['94.52040395831995', "['John Denver']", "Cowboy's Delight"],
#        dtype='<U661'),
#  array(['94.47187333782489', "['George Bruns']", 'Monkey Chase'],
#        dtype='<U661'),
#  array(['94.5597216610759', "['Ray Charles']",
#         'Hard Times (No One Knows Better Than I)'], dtype='<U661'),
#  array(['94.9924342512701', "['Guaynaa']", 'Rebota'], dtype='<U661'),
#  array(['94.78825166788891', "['Banda El Recodo']", 'Pena Tras Pena'],
#        dtype='<U661'),
#  array(['94.35350913994323', "['Maurice Jaubert']",
#         'Marche villageoise (From Un carnet de bal) (1937)'], dtype='<U661'),
#  array(['94.50721261473244', "['Shamshad Begum']",
#         'More Angana Balam Ka Murga Bole'], dtype='<U661'),
#  array(['94.68174530255969', "['Sonny Boy Williamson II']",
#         'Bring It On Home'], dtype='<U661'),
#  array(['94.48310501087231', "['Bhanumathi Ramakrishna']",
#         'Manchidinamu Nede'], dtype='<U661'),
#  array(['94.8758353749033', "['Ludacris', 'Lil Wayne']",
#         'Last Of A Dying Breed'], dtype='<U661'),
#  array(['94.53911343523609', "['Peggy Lee', 'Robert Norberg']",
#         "You're Getting To Be A Habit With Me - Remastered"], dtype='<U661'),
#  array(['95.00653326453094', "['Alice In Chains']", 'Got Me Wrong'],
#        dtype='<U661'),
#  array(['94.84506456854287', "['Heart']", 'How Deep It Goes'],
#        dtype='<U661'),
#  array(['94.76926923743635', "['Marvin Gaye']",
#         'Trouble Man - Extended Version'], dtype='<U661'),
#  array(['94.73067882402684', "['blink-182']", 'Dammit - Live/1999'],
#        dtype='<U661'),
#  array(['94.91310187475193',
#         "['Commander Cody and His Lost Planet Airmen']", 'Hot Rod Lincoln'],
#        dtype='<U661'),
#  array(['94.93881150497873', "['Elliott Smith']", 'Christian Brothers'],
#        dtype='<U661'),
#  array(['94.33496217964986', "['Francisco Canaro']",
#         'El Ultimo Gaucho - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.49286417589752', "['Robert Johnson']", '32-20 Blues'],
#        dtype='<U661'),
#  array(['94.57832053910387', "['Gino Bechi']", 'Fenesta Che Lucive'],
#        dtype='<U661'),
#  array(['94.58241025551042', "['Frank Sinatra']", "I'm Glad There Is You"],
#        dtype='<U661'),
#  array(['94.67066771575874', "['Raekwon', 'Ghostface Killah', 'Nas']",
#         'Verbal Intercourse (feat. Ghostface Killah & Nas)'], dtype='<U661'),
#  array(['94.43919442710727', "['Sarah Vaughan']", 'Misty'], dtype='<U661'),
#  array(['94.78622220020515',
#         "['George Gershwin', 'Oscar Levant', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Rhapsody in Blue'], dtype='<U661'),
#  array(['94.56366160318554', "['Ignacio Corsini']",
#         'La Casita Blanca - Remasterizado'], dtype='<U661'),
#  array(['94.75876364017815', "['Kaveret']", 'גולית'], dtype='<U661'),
#  array(['95.059896453908', "['Queen']", 'Liar - Remastered 2011'],
#        dtype='<U661'),
#  array(['94.42116419325141', "['Mixalis Thomakos']", 'Mi Me Rotas'],
#        dtype='<U661'),
#  array(['94.58909518894339', "['Roza Eskenazi']", 'Ntougkiax Manes'],
#        dtype='<U661'),
#  array(['94.57775577277258', "['Erroll Garner']",
#         'Where or When - Original Edited Concert - Live at Sunset School, Carmel-by-the-Sea, CA, September 1955'],
#        dtype='<U661'),
#  array(['95.00018782046095', "['Jimmy Buffett']", 'Fins - Live/1990'],
#        dtype='<U661'),
#  array(['94.67352270644543', "['Janis Ian']", 'In the Winter - Remastered'],
#        dtype='<U661'),
#  array(['94.64277868182191', "['Krishna Chatterjee', 'Tarun Banerjee']",
#         'Badhan Cherar Sadan Hobe'], dtype='<U661'),
#  array(['94.62842499691718', "['Julie London']", 'Spring Is Here'],
#        dtype='<U661'),
#  array(['95.05255306489047', "['Real Estate']", "It's Real"], dtype='<U661'),
#  array(['94.98963536957514', "['Mary Mary']", 'Sunday Morning'],
#        dtype='<U661'),
#  array(['95.20164876184566', "['David Bowie']",
#         'Moonage Daydream - 2012 Remaster'], dtype='<U661'),
#  array(['94.99567598652358', "['Scarface']", 'Mary Jane'], dtype='<U661'),
#  array(['95.01411089495392', "['Placebo']", 'Nancy Boy'], dtype='<U661'),
#  array(['95.10275654375343', "['Van Morrison']",
#         'Take It Where You Find It - Remastered'], dtype='<U661'),
#  array(['95.23310142190142', "['Los Huracanes del Norte']",
#         'Mi Complemento'], dtype='<U661'),
#  array(['94.93681489436116', "['Dan Zanes', 'Friends', 'Sharon Jones']",
#         'In The Basement'], dtype='<U661'),
#  array(['94.62921355860912', "['Bonobo']", 'Terrapin'], dtype='<U661'),
#  array(['94.69170304680496', "['Red Hot Chili Peppers']",
#         'Nobody Weird Like Me - Remastered'], dtype='<U661'),
#  array(['94.48750472357887',
#         "['Django Reinhardt', 'Quintette du Hot Club de France']",
#         'Swing 42'], dtype='<U661'),
#  array(['95.12020958109574',
#         "['Santana', 'Dave Matthews', 'Carter Beauford']",
#         'Love of My Life (feat. Dave Matthews & Carter Beauford)'],
#        dtype='<U661'),
#  array(['95.11428916381165', "['Thompson Twins']", 'Lay Your Hands On Me'],
#        dtype='<U661'),
#  array(['95.09755159588475', "['Seether']", 'Broken'], dtype='<U661'),
#  array(['94.95963589732015', "['999']", "Feelin' Alright with the Crew"],
#        dtype='<U661'),
#  array(['94.34705583050047', "['Francisco Canaro', 'Charlo']",
#         'El pua - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.80748454397396', "['Bad Company']",
#         'Ready for Love - 2009 Remaster'], dtype='<U661'),
#  array(['95.07377296707344', "['Kanye West']", 'Bad News'], dtype='<U661'),
#  array(['94.91273682188069', "['Randy Travis']", 'Better Class of Losers'],
#        dtype='<U661'),
#  array(['94.79817407776126', "['Bobby Bare']", 'The Winner'], dtype='<U661'),
#  array(['95.05737857610436', "['Wilco']", 'War on War'], dtype='<U661'),
#  array(['94.47825026768004', "['Frédéric Chopin', 'Maryla Jonas']",
#         'Mazurkas, Op. 67: No. 2 in G Minor (Cantabile)'], dtype='<U661'),
#  array(['94.7544390957626', "['Gorilla Zoe']", 'Hood Nigga'], dtype='<U661'),
#  array(['95.08884862802327', "['Filter']", 'Hey Man Nice Shot'],
#        dtype='<U661'),
#  array(['94.55353637745556', "['Dinah Washington', 'Brook Benton']",
#         'I Believe'], dtype='<U661'),
#  array(['94.51661579407023', "['Johnny Cash']",
#         'I Heard That Lonesome Whistle'], dtype='<U661'),
#  array(['94.43992727334334', "['Billie Holiday', 'Teddy Wilson']",
#         'Yours and Mine (with Teddy Wilson & His Orchestra)'],
#        dtype='<U661'),
#  array(['95.0497572732671', "['Sara']", 'BURNING UP FOR YOU'],
#        dtype='<U661'),
#  array(['95.21820766424904', "['The Charlie Daniels Band']",
#         'Billy The Kid'], dtype='<U661'),
#  array(['95.08012055901744', "['The Michael Zager Band']",
#         "Let's All Chant"], dtype='<U661'),
#  array(['95.12607458893127', "['SWV']", 'Use Your Heart'], dtype='<U661'),
#  array(['94.97050240588048', "['Madonna']", 'American Pie'], dtype='<U661'),
#  array(['95.11418055021038', "['Quincy Jones']", 'Razzamatazz'],
#        dtype='<U661'),
#  array(['94.82091319583009', "['Negami', 'Ricky Martinez']",
#         'Dicen por Ahi'], dtype='<U661'),
#  array(['94.36694332109674', "['Francisco Canaro']",
#         'Angela Mia - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.6516759833168', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 48'], dtype='<U661'),
#  array(['94.8856884182975', "['Carole King', 'James Taylor']",
#         'Will You Still Love Me Tomorrow (with James Taylor) - Live'],
#        dtype='<U661'),
#  array(['94.82729494577026', "['Joan Sebastian']", 'El Precio'],
#        dtype='<U661'),
#  array(['95.11153578212179', "['Crosby, Stills, Nash & Young']",
#         'American Dream'], dtype='<U661'),
#  array(['95.06930197253908', "['Jade']", "Don't Walk Away"], dtype='<U661'),
#  array(['94.81040635330218', "['Ennio Morricone']", 'The Trio'],
#        dtype='<U661'),
#  array(['94.86758836584723', "['Beastie Boys']", '3-Minute Rule'],
#        dtype='<U661'),
#  array(['95.03218544662293', "['Lemon Jelly']", "Ramblin' Man"],
#        dtype='<U661'),
#  array(['94.63496801442365',
#         "['Ludwig van Beethoven', 'NBC Symphony Orchestra', 'Arturo Toscanini']",
#         'Symphony No. 1 in C Major, Op. 21: I. Adagio molto - Allegro con brio'],
#        dtype='<U661'),
#  array(['94.54790389845783',
#         "['Georgia Mitaki', 'Giorgos Anestopoulos', 'Klarino']",
#         'To foystanaki'], dtype='<U661'),
#  array(['94.61626496921738', "['Wolfgang Amadeus Mozart', 'Glenn Gould']",
#         'Piano Sonata No. 12 in F Major, K. 332: II. Adagio'],
#        dtype='<U661'),
#  array(['94.66846866314783',
#         "['Carl Maria von Weber', 'Hilde Gueden', 'Orchester der Deutschen Oper Berlin', 'Gerhard Steeger']",
#         "Der Freischütz, Op. 77, J. 277: Einst träumte meiner sel'gen Base"],
#        dtype='<U661'),
#  array(['95.06978226270232', "['Glenn Frey']", 'Part Of Me, Part Of You'],
#        dtype='<U661'),
#  array(['94.78324565292738', "['Regina Mira']", 'October'], dtype='<U661'),
#  array(['95.09469664750833', "['Train']", 'I Am'], dtype='<U661'),
#  array(['94.87009607422623', "['Pedro Fernández']", 'Mi Forma De Sentir'],
#        dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
