# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'STARGAZING':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['Travis Scott']", 'BUTTERFLY EFFECT'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=5001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Khalid', 'Normani']", 'Love Lies (with Normani)'],
#         ["['Britney Spears']", 'Womanizer'],
#         ["['Zac Efron', 'Zendaya']", 'Rewrite The Stars'],
#         ...,
#         ["['Jorja Smith']", 'Blue Lights'],
#         ["['Pearl Jam']", 'Yellow Ledbetter'],
#         ["['Ray LaMontagne']", 'Let It Be Me']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.0006

# %%
relevance
# Out:
# 96.99999999997146

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.column_stack((predictions, song_info[:,0], song_info[:,1]))

# %%
sort_indices = np.argsort(predictions)[::-1]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[sort_indices]

# %%
list(predicted)
# Out:
# [array(['101.55194716379863', "['Sound Dreamer']",
#         'Brown Noise - 90 Minutes'], dtype='<U661'),
#  array(['101.13042939713209', "['Sounds for Life']",
#         'Brown Noise for Sleep'], dtype='<U661'),
#  array(['100.88227843176021', "['Sleep']", 'Dopesmoker'], dtype='<U661'),
#  array(['100.72877809466478', "['Ocean Waves For Sleep']",
#         'Ocean Waves for Sleep'], dtype='<U661'),
#  array(['100.71935851805448', "['Ocean Sounds']", 'Ocean Waves Sounds'],
#        dtype='<U661'),
#  array(['100.63373645125243', "['Brian Eno']",
#         'Thursday Afternoon - 2005 Digital Remaster'], dtype='<U661'),
#  array(['100.5815676179279', "['Lightning, Thunder and Rain Storm']",
#         'Midnight Thunderstorm Part 2'], dtype='<U661'),
#  array(['100.4357549423283', "['Umm Kulthum']", 'Naheg El Berda'],
#        dtype='<U661'),
#  array(['100.35055219463278', "['Environments']",
#         'The Psychologically Ultimate Seashore (16 rpm)'], dtype='<U661'),
#  array(['100.10015675428401', "['Portugallien']", 'Anslag'], dtype='<U661'),
#  array(['100.09770379002843', "['Terry Riley']", 'In C - 2009 Remastered'],
#        dtype='<U661'),
#  array(['100.09176514609058', "['Umm Kulthum']", 'Enta Oumry'],
#        dtype='<U661'),
#  array(['100.02739719479354', "['Umm Kulthum']", 'Yalle Kan Yshgek Anene'],
#        dtype='<U661'),
#  array(['100.01626323140006', "['Jeremy Soule']", 'Skyrim Atmospheres'],
#        dtype='<U661'),
#  array(['99.89561993493935', "['Environments']", 'Ultimate Thunderstorm'],
#        dtype='<U661'),
#  array(['99.83705953321719', "['Fishmans']", 'LONG SEASON'], dtype='<U661'),
#  array(['99.75435181359154', "['Umm Kulthum']", 'Halet Layale El Qamar'],
#        dtype='<U661'),
#  array(['99.74852003429247', "['Miles Davis']", 'He Loved Him Madly'],
#        dtype='<U661'),
#  array(['99.73756455942281', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone: Rainy Days'], dtype='<U661'),
#  array(['99.73474934215636', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['99.70711485550366', "['Abdel Halim Hafez']", 'Qareat El Fengan'],
#        dtype='<U661'),
#  array(['99.68740573525459',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in D Minor, Part I: I. Kräftig, Entschieden - Remastered'],
#        dtype='<U661'),
#  array(['99.6347844521506', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone: Raise Positive Vibrations - Healing Frequency (Positive Energy Boost)'],
#        dtype='<U661'),
#  array(['99.62036673924088', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone With 528Hz Solfeggio Frequency'], dtype='<U661'),
#  array(['99.61127572209897', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['99.60104804545796', "['Umm Kulthum']", 'El Ahat'], dtype='<U661'),
#  array(['99.59067079266273',
#         "['Richard Wagner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Bruno Walter Rehearses the Siegfried-Idyll'], dtype='<U661'),
#  array(['99.58824159510874', "['Umm Kulthum']", 'Ghana El Rabea'],
#        dtype='<U661'),
#  array(['99.58818053664314', "['Umm Kulthum']", 'Amal Hayate'],
#        dtype='<U661'),
#  array(['99.5826728599085', "['Dr. Jeffrey Thompson']", 'Delta Sleep One'],
#        dtype='<U661'),
#  array(['99.58043615244718', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['99.57544142552403', "['Brian Eno']",
#         'Discreet Music - Remastered 2004'], dtype='<U661'),
#  array(['99.5467440598318',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['99.52186212803414', "['Dmitri Shostakovich', 'Arturo Toscanini']",
#         'Symphony No. 7 in C Major, Op. 60 "Leningrad": I. Allegretto'],
#        dtype='<U661'),
#  array(['99.50477380942027', "['Glenn Gould', 'SYMPHONIA QUARTET']",
#         'String Quartet, Op. 1'], dtype='<U661'),
#  array(['99.50128386264835',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['99.49951825264614', "['Steve Roach']", 'Structures from Silence'],
#        dtype='<U661'),
#  array(['99.49366397234942',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C minor "Resurrection": V. Im Tempo des Scherzos. Wild herausfahrend'],
#        dtype='<U661'),
#  array(['99.48373783582404', "['Franz Liszt', 'Vladimir Horowitz']",
#         'Piano Sonata in B Minor, S. 178'], dtype='<U661'),
#  array(['99.47473198692467', "['Environments']",
#         'The Psychologically Ultimate Seashore'], dtype='<U661'),
#  array(['99.47105562781113', "['Chuck Riley']", 'Aladdin - Storyteller'],
#        dtype='<U661'),
#  array(['99.47057090005285', "['Pink Floyd']", 'Atom Heart Mother'],
#        dtype='<U661'),
#  array(['99.46772012899416',
#         "['Henryk Górecki', 'Dawn Upshaw', 'London Sinfonietta', 'David Zinman']",
#         'Symphony No. 3, Op. 36: I. Lento - Sostenuto Tranquillo Ma Cantabile'],
#        dtype='<U661'),
#  array(['99.45740996905205', "['Umm Kulthum']", 'Gholobt Asaleh Fe Rohy'],
#        dtype='<U661'),
#  array(['99.44926116938582', "['Shankar']",
#         'Ananda Nadamadum Tillai Sankara'], dtype='<U661'),
#  array(['99.43578157418864', "['Don Slepian']", 'Awakening'], dtype='<U661'),
#  array(['99.43195160816389', "['Umm Kulthum']", 'Ahl El Hawa'],
#        dtype='<U661'),
#  array(['99.42553447540676', "['Emerson, Lake & Palmer']",
#         'Karn Evil 9 - i. 1st Impression, ii. 2nd Impression, iii. 3rd Impression; Live 1974; 2016 - Remaster'],
#        dtype='<U661'),
#  array(['99.4179744960529', "['Nature Sounds']",
#         'Rain With Light Thunderstorm'], dtype='<U661'),
#  array(['99.4179744960529', "['Nature Sounds']",
#         'Rain With Distant Thunderstorm'], dtype='<U661'),
#  array(['99.4081637722192', "['Charles Mingus', 'Eric Dolphy']",
#         'Fables Of Faubus'], dtype='<U661'),
#  array(['99.4041807582579',
#         "['Pyotr Ilyich Tchaikovsky', 'Evgeny Kissin', 'Berliner Philharmoniker', 'Herbert von Karajan']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23, TH. 55: 1. Allegro non troppo e molto maestoso - Allegro con spirito - Live at Philharmonie, Berlin'],
#        dtype='<U661'),
#  array(['99.39870082671625', "['Godspeed You! Black Emperor']", 'Storm'],
#        dtype='<U661'),
#  array(['99.39577061693686', "['Umm Kulthum']", 'Seret El Hob'],
#        dtype='<U661'),
#  array(['99.38995001410584', "['Kraftwerk']", 'Autobahn - 2009 Remaster'],
#        dtype='<U661'),
#  array(['99.38749825723369',
#         "['Binaural Beats Brain Waves Isochronic Tones Brain Wave Entrainment']",
#         'Delta Waves for Deep Healing Sleep'], dtype='<U661'),
#  array(['99.38436975333087', "['President Franklin Delano Roosevelt']",
#         'State of the Union Address (January 7, 1943)'], dtype='<U661'),
#  array(['99.38124499252956', "['Umm Kulthum']", 'Salo Qalbe'],
#        dtype='<U661'),
#  array(['99.37915468999113', "['Umm Kulthum']", 'Raq El Habeb'],
#        dtype='<U661'),
#  array(['99.37500309548228',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": I. Allegro maestoso - Remastered'],
#        dtype='<U661'),
#  array(['99.37385398260125', "['Umm Kulthum']", 'Sahran Lewahde'],
#        dtype='<U661'),
#  array(['99.37221624661231',
#         "['Igor Stravinsky', 'Philadelphia Orchestra', 'Leopold Stokowski']",
#         'Petrushka'], dtype='<U661'),
#  array(['99.3696081870898', "['Keith Jarrett']",
#         'Köln, January 24, 1975, Pt. I - Live'], dtype='<U661'),
#  array(['99.36942216762728', "['Danny Kaye']", "Uncle Dan's Cabin"],
#        dtype='<U661'),
#  array(['99.36624508295466', "['Mike Oldfield']", 'Tubular Bells - Pt. I'],
#        dtype='<U661'),
#  array(['99.35635539998556', "['Joanna Brouk']", 'The Space Between'],
#        dtype='<U661'),
#  array(['99.3539294268689', "['Mike Oldfield']", 'Tubular Bells - Pt. II'],
#        dtype='<U661'),
#  array(['99.35046153763807', "['Pink Floyd']", 'Echoes'], dtype='<U661'),
#  array(['99.3483653041291', "['Miles Davis']", 'Go Ahead John'],
#        dtype='<U661'),
#  array(['99.34573979564266', "['Godspeed You! Black Emperor']", 'Sleep'],
#        dtype='<U661'),
#  array(['99.3426900909713', "['Umm Kulthum']", 'Woleda El Hoda'],
#        dtype='<U661'),
#  array(['99.34110410188171',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: I. Andante comodo'], dtype='<U661'),
#  array(['99.34063433959753', "['Sounds Of Nature : Thunderstorm, Rain']",
#         'Music For Sleep Thunderstorm, Rain'], dtype='<U661'),
#  array(['99.33586757488658', "['Grateful Dead']",
#         'Dark Star - Live at the Fillmore West San Francisco, 1969; 2001 Remaster'],
#        dtype='<U661'),
#  array(['99.33581863309148', "['Jim Hall']", 'Concierto De Aranjuez'],
#        dtype='<U661'),
#  array(['99.33334460862648',
#         "['Richard Wagner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Tannhäuser, WWV 70: Overture'], dtype='<U661'),
#  array(['99.3242757142393', "['Nature Sounds']",
#         'Relaxing Rain and Thunderstorm'], dtype='<U661'),
#  array(['99.32059241302377',
#         "['Pyotr Ilyich Tchaikovsky', 'Van Cliburn', 'Kirill Kondrashin']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: Allegro non troppo e molto maestoso'],
#        dtype='<U661'),
#  array(['99.31958697218593',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in D Minor, Part II: VI. Langsam, Ruhevoll. Empfunden'],
#        dtype='<U661'),
#  array(['99.31781068217163',
#         "['Ludwig van Beethoven', 'Glenn Gould', 'Leopold Stokowski', 'American Symphony Orchestra']",
#         'Piano Concerto No. 5 in E-Flat Major, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.31731653188103', "['Miles Davis']", 'In a Silent Way - LP Mix'],
#        dtype='<U661'),
#  array(['99.31192707695402',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Minor, WAB 109 (Original 1894 Version): I. Feierlich, misterioso - Edition: Leopold Nowak'],
#        dtype='<U661'),
#  array(['99.30417892470302', "['Jim Hall']", 'Concierto De Aranjuez'],
#        dtype='<U661'),
#  array(['99.303547283288',
#         "['Ludwig van Beethoven', 'Karl Freund', 'Berliner Philharmoniker', 'Walther Davisson']",
#         'Violin Concerto in D Major, Op. 61: 1. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['99.30350054851144', "['Umm Kulthum']", 'Ezkrony'], dtype='<U661'),
#  array(['99.30055028842567',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'I. Andante comodo'], dtype='<U661'),
#  array(['99.29409407409773',
#         "['Anton Bruckner', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Bruckner: Symphony No. 5 in B-Flat Major: IV. Finale - Adagio - Allegro moderato'],
#        dtype='<U661'),
#  array(['99.29016726125337', "['Caravan']",
#         'Nine Feet Underground - Medley'], dtype='<U661'),
#  array(['99.28983406890316', "['Terry Riley']",
#         'Poppy Nogood and the Phantom Band - Instrumental'], dtype='<U661'),
#  array(['99.28803040166719', "['Franklin Delano Roosevelt']",
#         'Address to Congress on Yalta - 03 01 1945'], dtype='<U661'),
#  array(['99.28752057432186', "['Miles Davis']", 'Bitches Brew'],
#        dtype='<U661'),
#  array(['99.28747020796062',
#         "['Richard Strauss', 'London Philharmonic Orchestra']",
#         'Tod und Verklärung Op. 24'], dtype='<U661'),
#  array(['99.280482431195', "['Pharoah Sanders']",
#         'The Creator Has A Master Plan'], dtype='<U661'),
#  array(['99.27995436322323',
#         "['Ludwig van Beethoven', 'Stefan Vladar', 'Capella Istropolitana', 'Barry Wordsworth']",
#         'Piano Concerto No. 4 in G Major, Op. 58: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.27857719044636',
#         "['Ludwig van Beethoven', 'Edwin Fischer', 'Wilhelm Furtwängler', 'Philharmonia Orchestra']",
#         'Beethoven: Piano Concerto No. 5 in E-Flat Major, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.27834949169687', "['Fela Kuti']", 'Beasts of No Nation'],
#        dtype='<U661'),
#  array(['99.27549109842063', "['Miles Davis']", 'Bitches Brew'],
#        dtype='<U661'),
#  array(['99.27537004102169',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Minor, WAB 109 (Original 1894 Version): III. Adagio. Langsam, feierlich - Edition: Leopold Nowak'],
#        dtype='<U661'),
#  array(['99.27496574446798',
#         "['Samuel Coleridge-Taylor', 'Royal Liverpool Philharmonic Orchestra', 'Grant Llewellyn']",
#         'Symphonic Variations on an African Air, Op.63'], dtype='<U661'),
#  array(['99.26719033467357', "['Herbie Hancock']", 'Chameleon'],
#        dtype='<U661'),
#  array(['99.26643148688684', "['Meco']", 'Medley: Star Wars - 12" Version'],
#        dtype='<U661'),
#  array(['99.25810933253315', "['The White Noise']",
#         'White Noise Fan for Babies'], dtype='<U661'),
#  array(['99.25705449920534', "['Grateful Dead']",
#         'The Other One - Live at Fillmore East, New York, NY, April 28, 1971'],
#        dtype='<U661'),
#  array(['99.2551862862048', "['Ludwig van Beethoven', 'Pablo Casals']",
#         'Cello Sonata No. 2 in G Minor, Op. 5 No. 2: I. Adagio sostenuto ed espressivo - II. Allegro molto più tosto presto'],
#        dtype='<U661'),
#  array(['99.25445693046338', "['Led Zeppelin']",
#         'Dazed and Confused - Live at MSG 1973; 2018 Remaster'],
#        dtype='<U661'),
#  array(['99.25155091876745', "['CAN']", 'Bel Air'], dtype='<U661'),
#  array(['99.25108099590227',
#         "['Ludwig van Beethoven', 'Paul Badura-Skoda', 'Vienna State Opera Orchestra', 'Hermann Scherchen']",
#         'Klavierkonzert Nr. 5 Es-Dur, Op. 73: I. Allegro'], dtype='<U661'),
#  array(['99.25103799572933', "['Ludwig van Beethoven', 'Rudolf Serkin']",
#         'Sonata No. 2 in G Minor, Op. 5, No. 2: I. Adagio sostenuto e espressivo / Allegro molto più tosto presto - Remastered'],
#        dtype='<U661'),
#  array(['99.24813849159699', "['Soft Machine']", 'Slightly All The Time'],
#        dtype='<U661'),
#  array(['99.24501633926295',
#         "['Sergei Rachmaninoff', 'Earl Wild', 'Royal Philharmonic Orchestra', 'Jascha Horenstein']",
#         'Rhapsody on a Theme of Paganini, Op. 43'], dtype='<U661'),
#  array(['99.24368561539488',
#         "['Ludwig van Beethoven', 'Rudolf Serkin', 'Philadelphia Orchestra', 'Eugene Ormandy']",
#         'Piano Concerto No. 5 in E-Flat Major, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.23951513207355', "['London Symphony Orchestra']",
#         'Boléro (Ravel)'], dtype='<U661'),
#  array(['99.23588318531081', "['Laraaji']", 'Meditation No. 1'],
#        dtype='<U661'),
#  array(['99.23505228569316', "['Tangerine Dream']",
#         'Phaedra - Remastered 2018'], dtype='<U661'),
#  array(['99.2345044164186', "['Umm Kulthum']", 'Robaaeyat El Khayam'],
#        dtype='<U661'),
#  array(['99.23344817392986',
#         "['Ludwig van Beethoven', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Concerto No. 5 for Piano and Orchestra in E-Flat Major, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.23338086569592',
#         "['Frederick Delius', 'Sir Thomas Beecham', 'Philadelphia Orchestra']",
#         'Paris - A Nocturne: Adagio - Allegretto grazioso - Molto lento - Lunga'],
#        dtype='<U661'),
#  array(['99.23300789558392', "['Fela Kuti']",
#         "Teacher Don't Teach Me Nonsense"], dtype='<U661'),
#  array(['99.23267282878449',
#         "['George Gershwin', 'James Thomson', 'Orchestre Symphonique de Montréal', 'Charles Dutoit']",
#         'An American in Paris'], dtype='<U661'),
#  array(['99.2321577115326',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'New York Philharmonic', 'Rudolf Serkin']",
#         'Piano Concerto No. 5 in E-Flat Major, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.22848137999523', "['Richard Strauss', 'Bruno Walter']",
#         'Tod und Verklärung, Op. 24'], dtype='<U661'),
#  array(['99.22809033784391', "['Umm Kulthum']", 'Ana Fe Entzark'],
#        dtype='<U661'),
#  array(['99.22532682840593', "['Chuck Mangione']", "Consuelo's Love Theme"],
#        dtype='<U661'),
#  array(['99.22478033485426',
#         "['Ludwig van Beethoven', 'New York Philharmonic', 'Bruno Walter']",
#         'Concerto for Piano and Orchestra No. 5 in E-Flat Major, Op. 73 "Emperor": I. Allegro - Instrumental'],
#        dtype='<U661'),
#  array(['99.22155753341674',
#         "['Ludwig van Beethoven', 'Artur Schnabel', 'Frederick Stock', 'Chicago Symphony Orchestra']",
#         'Piano Concerto No. 5 in E Flat Major, Op. 73, "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.21618442983521',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C minor "Resurrection": I. Allegro maestoso'],
#        dtype='<U661'),
#  array(['99.21421319806295',
#         "['Ludwig van Beethoven', 'Rudolf Serkin', 'Bruno Walter']",
#         'Concerto No. 5 in E-Flat Major for Piano and Orchestra, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.21401072398852', "['Ludwig van Beethoven', 'Pablo Casals']",
#         'Cello Sonata No. 1 in F Major, Op. 5 No. 1: I. Adagio sostenuto - II. Allegro - Adagio - Presto'],
#        dtype='<U661'),
#  array(['99.21338724065225',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'Glenn Gould', 'New York Philharmonic']",
#         'Piano Concerto No. 4 in G Major, Op. 58: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.21315439884214', "['Ludwig van Beethoven', 'Pablo Casals']",
#         'Cello Sonata No. 1 in F Major, Op. 5 No. 1: I. Adagio sostenuto - II. Allegro - Adagio - Presto'],
#        dtype='<U661'),
#  array(['99.20861587850908',
#         "['Benjamin Britten', 'Royal Philharmonic Orchestra', 'Robin Stapleton']",
#         "Young Person's Guide To The Orchestra"], dtype='<U661'),
#  array(['99.20766102317064', "['Sonny Rollins Quintet']",
#         'Medley: I Remember You / My Melancholy Baby / Old Folks / They Can’t Take That Away From Me / Just Friends / My Little Suede Shoes / Star Eyes - Rudy Van Gelder Remaster'],
#        dtype='<U661'),
#  array(['99.20721842109657',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'I. Allegro maestoso'], dtype='<U661'),
#  array(['99.20527551617792', "['Fela Kuti']", 'Confusion (Parts 1 & 2)'],
#        dtype='<U661'),
#  array(['99.20348113879838',
#         "['George Gershwin', 'Leonard Bernstein', 'New York Philharmonic']",
#         'An American in Paris'], dtype='<U661'),
#  array(['99.20308060414679',
#         "['Дмитрий Шостакович', 'Mieczysław Weinberg', 'Моисей Вайнберг']",
#         'Симфония No. 10 ми минор, соч. 93: I. Moderato'], dtype='<U661'),
#  array(['99.20077599700502', "['CAN']", 'Halleluhwah - 2011 Remastered'],
#        dtype='<U661'),
#  array(['99.2004634736284', "['Fela Kuti']", 'Fear Not For Man'],
#        dtype='<U661'),
#  array(['99.19956090150734',
#         "['Pyotr Ilyich Tchaikovsky', 'Royal Philharmonic Orchestra', 'Philip Ellis']",
#         '1812 Overture'], dtype='<U661'),
#  array(['99.19826800401451',
#         "['Johannes Brahms', 'Gary Graffman', 'Charles Münch']",
#         'Piano Concerto No. 1 in D Minor, Op. 15: I. Maestoso'],
#        dtype='<U661'),
#  array(['99.1978782444833',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 4 in E-Flat Major, WAB 104 "Romantic": IV. Finale. Bewegt, doch nicht zu schnell'],
#        dtype='<U661'),
#  array(['99.19599193721889', "['Umm Kulthum']", 'Hadeth El Rouh'],
#        dtype='<U661'),
#  array(['99.1939253958339', "['CAN']", 'Halleluhwah - 2011 Remastered'],
#        dtype='<U661'),
#  array(['99.19194929311662', "['The Allman Brothers Band']",
#         'Whipping Post - Live At The Fillmore East, March 1971'],
#        dtype='<U661'),
#  array(['99.19117953298152', "['King Crimson']",
#         'Lizard (Prince Rupert Awakes/Bolero/The Battle of Glass Tears/Big Top)'],
#        dtype='<U661'),
#  array(['99.19094491320746',
#         "['Anton Bruckner', 'Berliner Philharmoniker', 'Carl Schuricht']",
#         'Symphony No.7 In E Major, WAB 107 - Ed. Haas: 2. Adagio. Sehr feierlich und sehr langsam'],
#        dtype='<U661'),
#  array(['99.1906949575473', "['Elî Merdan']", 'Le Bazarî Eşq'],
#        dtype='<U661'),
#  array(['99.19034971278462',
#         "['Pyotr Ilyich Tchaikovsky', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 4 in F Minor, Op. 36, TH 27: I. Andante sostenuto - Moderato con anima'],
#        dtype='<U661'),
#  array(['99.18806571119431', "['Christopher Plummer']",
#         'The Many Adventures of Winnie the Pooh'], dtype='<U661'),
#  array(['99.18549003055587', "['Hans Zimmer', 'James Newton Howard']",
#         'A Dark Knight'], dtype='<U661'),
#  array(['99.18011398876727',
#         "['Pyotr Ilyich Tchaikovsky', 'Vladimir Horowitz', 'Arturo Toscanini', 'NBC Symphony Orchestra']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: I. Allegro non troppo e molto maestoso'],
#        dtype='<U661'),
#  array(['99.17921950391583',
#         "['Gustav Mahler', 'London Symphony Orchestra', 'Sir Georg Solti']",
#         'Symphony No.1 in D: 4. Stürmisch bewegt'], dtype='<U661'),
#  array(['99.17822185026559', "['Lotus ']", 'Umbilical Moonrise'],
#        dtype='<U661'),
#  array(['99.17303946573331', "['Red Garland Quintet']", 'Soul Junction'],
#        dtype='<U661'),
#  array(['99.17200427641845', "['TOOL']", 'Invincible'], dtype='<U661'),
#  array(['99.17130071554197',
#         "['Ludwig van Beethoven', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Beethoven: Piano Concerto No. 5 in E-Flat Major, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['99.17123642742817',
#         "['Anton Bruckner', 'Concertgebouworkest', 'Eugen Jochum']",
#         'Symphony No. 5 in B-Flat Major, WAB 105: 1. Introduction. Adagio - Allegro - Live In Ottobeuren / 1964'],
#        dtype='<U661'),
#  array(['99.16759021485016', "['Guti & Dubshape']",
#         'Every Cow Has A Bird - original mix'], dtype='<U661'),
#  array(['99.16613747941466',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'Glenn Gould', 'Columbia Symphony Orchestra']",
#         'Piano Concerto No. 3 in C Minor, Op. 37: I. Allegro con brio'],
#        dtype='<U661'),
#  array(['99.16612837531346',
#         "['Ludwig van Beethoven', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto No. 4 in G Major, Op. 58: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.16547636966668',
#         "['Ludwig van Beethoven', 'Glenn Gould', 'Leonard Bernstein', 'Columbia Symphony Orchestra']",
#         'Piano Concerto No. 3 in C Minor, Op. 37: I. Allegro con brio'],
#        dtype='<U661'),
#  array(['99.16436411766828', "['Miles Davis']", 'Great Expectations'],
#        dtype='<U661'),
#  array(['99.16410887053638',
#         "['Johannes Brahms', 'Rudolf Serkin', 'Fritz Reiner', 'Pittsburgh Symphony Orchestra']",
#         'Concerto No. 1 in D Minor for Piano and Orchestra, Op. 15: I. Maestoso'],
#        dtype='<U661'),
#  array(['99.16316507663468', "['Miles Davis']",
#         'Mademoiselle Mabry - New Mix'], dtype='<U661'),
#  array(['99.16182267858773',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 1 in D Major "Titan": IV. Stürmisch bewegt - Energisch'],
#        dtype='<U661'),
#  array(['99.16050654535624',
#         "['Ludwig van Beethoven', 'Van Cliburn', 'Fritz Reiner']",
#         'Piano Concerto No. 4 in G Major, Op. 58: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.15997538070425', "['Soft Machine']", 'Moon In June'],
#        dtype='<U661'),
#  array(['99.15879463216015',
#         "['Pyotr Ilyich Tchaikovsky', 'André Previn', 'London Symphony Orchestra']",
#         'Swan Lake, Op.20, Act II: 13. Dances of the Swans'], dtype='<U661'),
#  array(['99.15701576582909', "['Godspeed You! Black Emperor']",
#         'The Dead Flag Blues'], dtype='<U661'),
#  array(['99.15644173724601', "['Arnold Bax', 'Hallé']",
#         'Symphony No. 3 in C Major: I. Lento Moderato - Allegro Moderato'],
#        dtype='<U661'),
#  array(['99.15557900793428',
#         "['Edward Elgar', 'Daniel Barenboim', 'London Philharmonic Orchestra']",
#         'In the South Overture, Op. 50 "Alassio"'], dtype='<U661'),
#  array(['99.15552288665702',
#         "['Ludwig van Beethoven', 'Joseph Szigeti', 'Bruno Walter', 'New York Philharmonic']",
#         'Violin Concerto in D Major, Op. 61: I. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['99.15514530999877',
#         "['Edvard Grieg', 'Javier Perianes', 'BBC Symphony Orchestra', 'Sakari Oramo']",
#         'Piano Concerto in A Minor, Op.16: I. Allegro molto moderato'],
#        dtype='<U661'),
#  array(['99.15508993400432',
#         "['Jean Sibelius', 'Herbert von Karajan', 'Philharmonia Orchestra']",
#         'Sibelius: Tapiola, Op. 112'], dtype='<U661'),
#  array(['99.15274618949987',
#         "['Ralph Vaughan Williams', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Fantasia on a Theme by Thomas Tallis'], dtype='<U661'),
#  array(['99.15111624370698',
#         "['Pyotr Ilyich Tchaikovsky', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Romeo and Juliet Fantasy Overture, TH 42'], dtype='<U661'),
#  array(['99.15057825754049', "['Harold Budd']",
#         "Bismillahi 'Rrahmani 'Rrahim"], dtype='<U661'),
#  array(['99.15054368798984',
#         "['Frédéric Chopin', 'György Cziffra', 'Orchestre National de la RTF', 'Manuel Rosenthal']",
#         'Concerto pour piano No. 1 in E Minor, Op. 11: I. Allegro maestoso'],
#        dtype='<U661'),
#  array(['99.15047634031565',
#         "['Leonard Bernstein', 'New York Philharmonic']",
#         'Symphonic Dances from "West Side Story"'], dtype='<U661'),
#  array(['99.15014354477728',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 7 in E Major, WAB 107 (1885 Version, ed. R. Haas): I. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.14960363569465', "['Tangerine Dream']",
#         'Rubycon - Pt. 1 / Remastered 2018'], dtype='<U661'),
#  array(['99.14752044070198',
#         "['Johannes Brahms', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Concerto No. 2 for Piano and Orchestra in B-Flat Major, Op. 83: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.14648153568109',
#         "['Pyotr Ilyich Tchaikovsky', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Hamlet Fantasy Overture, Op. 67, TH 53'], dtype='<U661'),
#  array(['99.14632950378409',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in E-Flat Major, Op. 55 "Eroica": I. Allegro con brio'],
#        dtype='<U661'),
#  array(['99.14557737300368', "['Ravi Shankar']",
#         'Dhun (Dadra And Fast Teental) - Live'], dtype='<U661'),
#  array(['99.14532831252772',
#         "['César Franck', 'Deutsches Symphonie-Orchester Berlin', 'Lorin Maazel']",
#         'Symphony In D Minor: 1. Lento - Allegro ma non troppo - Allegro'],
#        dtype='<U661'),
#  array(['99.14496441834208',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 1 in D Major "Titan": IV. Stürmisch bewegt - Energisch'],
#        dtype='<U661'),
#  array(['99.14393215688642', "['TOOL']", 'Pneuma'], dtype='<U661'),
#  array(['99.14348336101975',
#         "['Pyotr Ilyich Tchaikovsky', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: I. Allegro non troppo e molto maestoso'],
#        dtype='<U661'),
#  array(['99.14292751730812', "['New Orchestral Society of Boston']",
#         'Brahms, Johannes: First Symphony, Part 4'], dtype='<U661'),
#  array(['99.14200996786067',
#         "['Ludwig van Beethoven', 'Joseph Szigeti', 'Bruno Walter', 'New York Philharmonic']",
#         'Violin Concerto in D Major, Op. 61: I. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['99.1418440342948',
#         "['Ludwig van Beethoven', 'London Symphony Orchestra', 'Josef Krips', 'Jennifer Vyvyan', 'Shirley Verrett', 'Rudolf Petrak', 'Donaldson Bell']",
#         'Symphony No. 9 in D Minor, Op. 125 "Choral": IV. Presto - Allegro assai - Choral Finale'],
#        dtype='<U661'),
#  array(['99.14115364271429',
#         "['Ludwig van Beethoven', 'Joseph Szigeti', 'Bruno Walter', 'New York Philharmonic']",
#         'Violin Concerto in D Major, Op. 61: I. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['99.14021639533917',
#         "['Johannes Brahms', 'Jascha Heifetz', 'New York Philharmonic', 'Arturo Toscanini']",
#         'Violin Concerto in D Major, Op. 77: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.13722740468921', "['Donald Byrd']", 'The Emperor'],
#        dtype='<U661'),
#  array(['99.13592775488698',
#         "['Ludwig van Beethoven', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Beethoven: Violin Concerto in D Major, Op. 61: I. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['99.1338301723796', "['Rare Earth']", 'Get Ready'], dtype='<U661'),
#  array(['99.13235615820088',
#         "['Ludwig van Beethoven', 'London Symphony Orchestra', 'Josef Krips']",
#         'Symphony No. 9 in D Minor, Op. 125 "Choral": I. Allegro ma non troppo, un poco maestoso'],
#        dtype='<U661'),
#  array(['99.13175140652298',
#         "['Maurice Ravel', 'Orchestre Symphonique de Montréal', 'Charles Dutoit']",
#         'Boléro, M. 81'], dtype='<U661'),
#  array(['99.13116931267274', "['Johannes Brahms', 'Arturo Toscanini']",
#         'Symphony No. 1 in C Minor, Op. 68: IV. Adagio - Più andante - Allegro non troppo, ma con brio'],
#        dtype='<U661'),
#  array(['99.12927106111944', "['J.S. Epperson']", '528 Hz D.N.A. Repair'],
#        dtype='<U661'),
#  array(['99.12774470052251', "['This Will Destroy You']",
#         'The Mighty Rio Grande'], dtype='<U661'),
#  array(['99.12754687562892', "['Jimmy Giuffre']",
#         'Western Suite (Pony Express, Apaches, Saturday Night Dance, Big Pow Wow)'],
#        dtype='<U661'),
#  array(['99.12752096501238',
#         "['Anton Bruckner', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Bruckner: Symphony No. 4 in E-Flat Major, "Romantic": IV. Finale - Bewegt, doch nicht zu schnell'],
#        dtype='<U661'),
#  array(['99.12687438855959',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 1 in D Major "Titan": IV. Stürmisch bewegt'],
#        dtype='<U661'),
#  array(['99.12685526398951',
#         "['Franz Schubert', 'Berliner Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 9 in C Major, D. 944 - "The Great": 2. Andante con moto'],
#        dtype='<U661'),
#  array(['99.12585021481532', "['Brian Eno']", '1/1 - Remastered 2004'],
#        dtype='<U661'),
#  array(['99.12439136998671', "['Pigeons Playing Ping Pong']", 'Horizon'],
#        dtype='<U661'),
#  array(['99.12265196158471', "['deadmau5']", 'Strobe'], dtype='<U661'),
#  array(['99.12193370621853', "['Miles Davis']",
#         'Mademoiselle Mabry (Miss Mabry)'], dtype='<U661'),
#  array(['99.12010775901528',
#         "['Franz Schubert', 'Wiener Philharmoniker', 'Josef Krips']",
#         'Symphony No.8 in B minor, D.759 - "Unfinished": 1. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.11929285484992',
#         "['Ludwig van Beethoven', 'Wilhelm Backhaus', 'Wiener Philharmoniker', 'Clemens Krauss']",
#         'Piano Concerto No. 4 in G Major, Op. 58: 1. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.11916768193363',
#         "['Ludwig van Beethoven', 'Wilhelm Furtwängler', 'Wiener Philharmoniker']",
#         'Beethoven: Symphony No. 3 in E-Flat Major, Op. 55 "Eroica": I. Allegro con brio'],
#        dtype='<U661'),
#  array(['99.1181469680647', "['Keith Jarrett']",
#         'Köln, January 24, 1975, Pt. II B - Live'], dtype='<U661'),
#  array(['99.1163074547926', "['deadmau5']", 'Not Exactly'], dtype='<U661'),
#  array(['99.1160987446214', "['Grant Green', 'Ray Blair']",
#         "Sookie Sookie - Live At The Cliche' Lounge, Newark, New Jersey, 1970 / Remastered 2000"],
#        dtype='<U661'),
#  array(['99.11588473283263',
#         "['Bedřich Smetana', 'Polish National Radio Symphony Orchestra', 'Antoni Wit']",
#         'Má vlast (My Country): No. 2, Vltava [Moldau]'], dtype='<U661'),
#  array(['99.11568358506402',
#         "['Ludwig van Beethoven', 'Berliner Philharmoniker', 'Herbert von Karajan']",
#         'Symphony No.9 In D Minor, Op.125 - "Choral": 1. Allegro ma non troppo, un poco maestoso'],
#        dtype='<U661'),
#  array(['99.11523798158721',
#         "['Anton Bruckner', 'Berliner Philharmoniker', 'Carl Schuricht']",
#         'Symphony No.7 In E Major, WAB 107 - Ed. Haas: 1. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.11500461882703', "['John Coltrane']",
#         'Lush Life - Rudy Van Gelder Remaster'], dtype='<U661'),
#  array(['99.11418931213912',
#         "['Hariprasad Chaurasia', 'Shivkumar Sharma', 'Kashinath Mishra']",
#         'Raga Jhinjhoti in Rupak Tal (7 beats) and Tintal (16 beats)'],
#        dtype='<U661'),
#  array(['99.1140209606099',
#         "['George Gershwin', 'Gary Graffman', 'Zubin Mehta', 'New York Philharmonic']",
#         'Rhapsody in Blue'], dtype='<U661'),
#  array(['99.11400872255786',
#         "['John Williams', 'London Symphony Orchestra']",
#         'A New Hope and End Credits'], dtype='<U661'),
#  array(['99.11386548141438', "['César Franck', 'Arturo Toscanini']",
#         'Symphony in D Minor, FWV 48: I. Lento - Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.11352606900353',
#         "['Ludwig van Beethoven', 'Artur Schnabel', 'Frederick Stock', 'Chicago Symphony Orchestra']",
#         'Piano Concerto No. 4 in G Major, Op. 58: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['99.11266918484307', "['Papadosio']", 'Find Your Cloud'],
#        dtype='<U661'),
#  array(['99.11226671649598', "['New Order']",
#         'Blue Monday - 2016 Remaster'], dtype='<U661'),
#  array(['99.11107055313857',
#         "['Gustav Mahler', 'Kathleen Ferrier', 'Wiener Philharmoniker', 'Bruno Walter']",
#         'Das Lied von der Erde: 6. Der Abschied'], dtype='<U661'),
#  array(['99.10920344532039',
#         "['Richard Strauss', 'Wiener Philharmoniker', 'Wilhelm Furtwängler']",
#         'Don Juan, Op. 20, TrV 156 (Live)'], dtype='<U661'),
#  array(['99.10886741709174',
#         "['Ludwig van Beethoven', 'Tilla Briem', 'Elisabeth Höngen', 'Peter Anders', 'Rudolf Watzke', 'Choeur Bruno Kittel', 'Berliner Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": III. Adagio molto e cantabile - Andante moderato'],
#        dtype='<U661'),
#  array(['99.10885348350574',
#         "['Richard Strauss', 'Claudio Arrau', 'Désiré Defauw', 'Chicago Symphony Orchestra']",
#         'Burleske for Piano and Orchestra in D Minor, TrV 145 - Live'],
#        dtype='<U661'),
#  array(['99.10872730175771', "['Benny Goodman']",
#         'Honeysuckle Rose - Live'], dtype='<U661'),
#  array(['99.10723618336871',
#         "['George Gershwin', 'Columbia Symphony Orchestra', 'Leonard Bernstein', 'New York Philharmonic']",
#         'An American in Paris'], dtype='<U661'),
#  array(['99.10674050356661',
#         "['Johannes Brahms', 'Eugene Ormandy', 'Philadelphia Orchestra', 'Michael O. Drexler']",
#         'Concerto No. 2 for Piano and Orchestra, Op. 83 in B-flat Major (Remastered): I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.10400324151604',
#         "['Leopold Stokowski', 'Philadelphia Orchestra']",
#         'Rite of Spring'], dtype='<U661'),
#  array(['99.10387233569097',
#         "['Ludwig van Beethoven', 'Elisabeth Schwarzkopf', 'Elisabeth Höngen', 'Hans Hopf', 'Otto Edelmann', 'Bayreuth Festival Orchestra', 'Wilhelm Furtwängler']",
#         'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": III. Adagio molto e cantabile - Andante moderato'],
#        dtype='<U661'),
#  array(['99.1035591460441',
#         "['Jean Françaix', 'André Previn', 'London Symphony Orchestra']",
#         "L'Horloge de flore"], dtype='<U661'),
#  array(['99.10311123215432',
#         "['Johannes Brahms', 'Herbert von Karajan', 'Philharmonia Orchestra']",
#         'Brahms: Symphony No. 1 in C Minor, Op. 68: IV. Adagio - Allegro non troppo, ma con brio'],
#        dtype='<U661'),
#  array(['99.10288263760113', "['Fela Kuti']", 'Upside Down'], dtype='<U661'),
#  array(['99.10253201714325', "['The Allman Brothers Band']",
#         "You Don't Love Me - Live At Fillmore East, March 12, 1971"],
#        dtype='<U661'),
#  array(['99.10058106017428',
#         "['Pyotr Ilyich Tchaikovsky', 'Leningrad Philharmonic Orchestra', 'Evgeny Mravinsky']",
#         'Symphony No. 6 in B Minor, Op. 74, TH 30 - "Pathétique": 1. Adagio - Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.09963814430941',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 4 in G Major: I. Bedächtig, nicht eilen'],
#        dtype='<U661'),
#  array(['99.09899535968728',
#         "['Maurice Ravel', 'Robert Casadesus', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto for the Left Hand in D Major, M. 82'],
#        dtype='<U661'),
#  array(['99.09737901647497',
#         "['Antonín Dvořák', 'Jacqueline du Pré', 'Daniel Barenboim', 'Chicago Symphony Orchestra']",
#         'Dvorák: Cello Concerto in B Minor, Op. 104, B. 191: I. Allegro'],
#        dtype='<U661'),
#  array(['99.0961430998564', "['Harvey Karp, MD, FAAP']", 'Rain (Sleep)'],
#        dtype='<U661'),
#  array(['99.09527703608278',
#         "['Junior Vasquez', 'Lectroluv (Fred Jorio)']",
#         'Dream Drums - All Over Sound Factory Mix'], dtype='<U661'),
#  array(['99.09476355902315',
#         "['Pyotr Ilyich Tchaikovsky', 'Leningrad Philharmonic Orchestra', 'Evgeny Mravinsky']",
#         'Symphony No.4 In F Minor, Op.36, TH.27: 1. Andante sostenuto - Moderato con anima - Moderato assai, quasi Andante - Allegro vivo'],
#        dtype='<U661'),
#  array(['99.09443282262012', "['Philip Glass']", 'Mad Rush'], dtype='<U661'),
#  array(['99.09404085196971', "['Johann Sebastian Bach', 'Itzhak Perlman']",
#         'Bach, J.S.: Violin Partita No. 2 in D Minor, BWV 1004: V. Chaconne'],
#        dtype='<U661'),
#  array(['99.09354908111503',
#         "['Wolfgang Amadeus Mozart', 'Murray Perahia']",
#         'Piano Sonata No. 11 in A Major, K. 331: I. Theme & Variations. Andante grazioso'],
#        dtype='<U661'),
#  array(['99.09294532407242', "['Wipers']", 'Youth of America'],
#        dtype='<U661'),
#  array(['99.09156803572367',
#         "['Pyotr Ilyich Tchaikovsky', 'Daniel Barenboim', 'Chicago Symphony Orchestra']",
#         'Tchaikovsky : 1812 Overture Op.49'], dtype='<U661'),
#  array(['99.09149863109437', "['John Powell']",
#         'Sonata Teutonica, Op. 24: II. Andante sostenuto - Scherzo - Andante quasi Trio - Tempo di Scherzo - Tempo del Thema'],
#        dtype='<U661'),
#  array(['99.0912402716288', "['New Order']",
#         'Blue Monday - 2011 Total Version'], dtype='<U661'),
#  array(['99.09022864090777', "['George Gershwin']", 'Rhapsody in Blue'],
#        dtype='<U661'),
#  array(['99.08973923016522', "['George Gershwin', 'Arturo Toscanini']",
#         'An American in Paris'], dtype='<U661'),
#  array(['99.08972760738675', "['Darude']", 'Sandstorm - Original Mix'],
#        dtype='<U661'),
#  array(['99.08901715063935',
#         "['Franz Schubert', 'George Szell', 'Cleveland Orchestra']",
#         'Symphony No. 9 in C Major, D. 944 "Great": I. Andante - Allegro ma non troppo - Più moto'],
#        dtype='<U661'),
#  array(['99.08876701287531', "['Blind Faith']", 'Do What You Like'],
#        dtype='<U661'),
#  array(['99.08850257356559', "['Deep Purple']", 'Son Of Alerik'],
#        dtype='<U661'),
#  array(['99.08755454915449',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 7 in E Major, WAB 107 (1885 Version, ed. R. Haas): II. Adagio. Sehr feierlich und sehr langsam'],
#        dtype='<U661'),
#  array(['99.08708522549689',
#         "['Wolfgang Amadeus Mozart', 'Columbia Symphony Orchestra', 'Rudolf Serkin', 'George Szell', 'Alexander Schneider']",
#         'Piano Concerto No. 25 in C Major, K. 503: I. Allegro maestoso'],
#        dtype='<U661'),
#  array(['99.08616470441886',
#         "['Johannes Brahms', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 2 in D Major, Op. 73: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.0859442684497', "['Jon Hopkins']", 'Immunity'], dtype='<U661'),
#  array(['99.08553377150426',
#         "['Wolfgang Amadeus Mozart', 'Arthur Rubinstein', 'Alfred Wallenstein', 'RCA Victor Symphony Orchestra']",
#         'Piano Concerto No. 21 in C Major, K. 467: I. Allegro maestoso'],
#        dtype='<U661'),
#  array(['99.08525031015735', "['Terry Riley']",
#         'A Rainbow in the Curved Air - Instrumental'], dtype='<U661'),
#  array(['99.08413560670074', "['D.O.A.', 'Jello Biafra']",
#         'Full Metal Jackoff'], dtype='<U661'),
#  array(['99.08366032032984', "['David Raskin']",
#         "Part III: Amber's Theme / Ride / Death / Sickness / Attack / Ordeal"],
#        dtype='<U661'),
#  array(['99.08353439513256',
#         "['Richard Strauss', 'Claudio Arrau', 'Désiré Defauw', 'Chicago Symphony Orchestra']",
#         'Burleske for Piano and Orchestra in D Minor, TrV 145 - Live'],
#        dtype='<U661'),
#  array(['99.08345501181594',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: II. Im Tempo eines gemächlichen Ländlers - Etwas täppisch und sehr derb'],
#        dtype='<U661'),
#  array(['99.08128264065819', "['Dan Hartman']", 'Vertigo/Relight My Fire'],
#        dtype='<U661'),
#  array(['99.0802527144575', "['Miles Davis']", "Pharaoh's Dance"],
#        dtype='<U661'),
#  array(['99.08012658825253',
#         "['Pyotr Ilyich Tchaikovsky', 'Oscar Levant', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23 (Remastered): I. Allegro non troppo e molto maestoso - Allegro con spirito'],
#        dtype='<U661'),
#  array(['99.07984736733864', "['TOOL']", 'Lateralus'], dtype='<U661'),
#  array(['99.07963463406924', "['Ruben Gonzalez']", 'Almendra'],
#        dtype='<U661'),
#  array(['99.07914573160255',
#         "['Johannes Brahms', 'Arthur Rubinstein', 'Charles Münch']",
#         'Concerto No. 2 in B-Flat Major, Op. 83: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.07910037149233',
#         "['Ludwig van Beethoven', 'Nikolaus Harnoncourt', 'Chamber Orchestra of Europe']",
#         'Beethoven: Symphony No. 9 in D Minor, Op. 125 "Choral": II. Molto vivace - Presto'],
#        dtype='<U661'),
#  array(['99.07891162916559', "['Grant Green']",
#         "Blues In Maude's Flat - Remastered"], dtype='<U661'),
#  array(['99.07760837206321',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 4 in E-Flat Major, WAB 104 "Romantic": I. Bewegt, nicht zu schnell'],
#        dtype='<U661'),
#  array(['99.07691425536633',
#         "['Ralph Vaughan Williams', 'London Philharmonic Orchestra', 'Bryden Thomson']",
#         'Fantasia on a Theme by Thomas Tallis'], dtype='<U661'),
#  array(['99.07606786826749',
#         "['Johannes Brahms', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto No. 2 in B-Flat Major, Op. 83: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.07569199633885', "['Dream Theater']",
#         'A Change of Seasons - The Crimson Sunrise / Innocence / Carpe Diem / The Darkest of Winters / Another World / The Inevitable Summer / The Crimson Sunset'],
#        dtype='<U661'),
#  array(['99.07561163370316', "['Herbie Hancock']", 'Butterfly'],
#        dtype='<U661'),
#  array(['99.07483257212299', "['Metallica']", 'Suicide & Redemption'],
#        dtype='<U661'),
#  array(['99.07430921579254', "['Miles Davis']", "Pharaoh's Dance"],
#        dtype='<U661'),
#  array(['99.07375034749597', "['Zoel', 'Junior Vasquez']",
#         'Quiet - Junior Vasquez Vocal Remix'], dtype='<U661'),
#  array(['99.07322343966487',
#         "['George Gershwin', 'Benjamin Grosvenor', 'Royal Liverpool Philharmonic Orchestra', 'James Judd']",
#         'Rhapsody In Blue'], dtype='<U661'),
#  array(['99.07217434719814',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: II. Im Tempo eines gemächlichen Ländlers - Etwas täppisch und sehr derb'],
#        dtype='<U661'),
#  array(['99.07196995280553',
#         "['Wolfgang Amadeus Mozart', 'Pablo Casals', 'Perpignan Festival Orchestra']",
#         'Piano Concerto No. 22 in E-Flat Major, K. 482: I. Allegro'],
#        dtype='<U661'),
#  array(['99.07174662991893', "['deadmau5']", 'Alone With You'],
#        dtype='<U661'),
#  array(['99.07168216830672',
#         "['Pyotr Ilyich Tchaikovsky', 'Leningrad Philharmonic Orchestra', 'Evgeny Mravinsky']",
#         'Symphony No.5 In E Minor, Op.64, TH.29: 1. Andante - Allegro con anima'],
#        dtype='<U661'),
#  array(['99.0710846724899', "['Yes']", 'The Gates of Delirium'],
#        dtype='<U661'),
#  array(['99.07076617769185', "['Blue Boy']", 'Remember Me - Original Mix'],
#        dtype='<U661'),
#  array(['99.06927310435802', "['The Temptations']", 'Masterpiece'],
#        dtype='<U661'),
#  array(['99.0690734905215',
#         "['Sergei Rachmaninoff', 'Valentina Lisitsa', 'London Symphony Orchestra', 'Michael Francis']",
#         'Piano Concerto No. 2 in C Minor, Op. 18: 2. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['99.06674771083388',
#         "['Richard Wagner', 'Wiener Philharmoniker', 'Sir Georg Solti']",
#         'Tannhäuser: Overture'], dtype='<U661'),
#  array(['99.06644737379835',
#         "['Edward Elgar', 'Daniel Barenboim', 'London Philharmonic Orchestra']",
#         'Cockaigne Overture, Op. 40 "In London Town"'], dtype='<U661'),
#  array(['99.06608660565838',
#         "['Johannes Brahms', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Double Concerto for Violin & Cello in A Minor, Op. 102: I. Allegro'],
#        dtype='<U661'),
#  array(['99.0653769220218', "['Ludwig van Beethoven', 'Artur Schnabel']",
#         'Sonata No. 32 in C Minor, Op. 111: II. Arietta - Adagio molto semplice cantabile'],
#        dtype='<U661'),
#  array(['99.06511479879872',
#         "['Pyotr Ilyich Tchaikovsky', 'Berliner Philharmoniker']",
#         'Symphony No.6 in B Minor Op. 74: I. Adagio – Allegro non troppo'],
#        dtype='<U661'),
#  array(['99.06507891562022', "['Porcupine Tree']",
#         'Arriving Somewhere But Not Here'], dtype='<U661'),
#  array(['99.06486989789178',
#         "['Wolfgang Amadeus Mozart', 'Rudolf Serkin', 'Alexander Schneider', 'Columbia Symphony Orchestra']",
#         'Piano Concerto No. 21 in C Major, K. 467 "Elvira Madigan": I. Allegro maestoso'],
#        dtype='<U661'),
#  array(['99.06479655153012', "['Fela Kuti']",
#         'Coffin For Head of State (Part 1 & 2)'], dtype='<U661'),
#  array(['99.0647594861763', "['TOOL']", 'Right In Two'], dtype='<U661'),
#  array(['99.06461334461807', "['Nightmares On Wax']", 'Stars'],
#        dtype='<U661'),
#  array(['99.06430542831153', "['The Allman Brothers Band']",
#         'Whipping Post - Live At The Fillmore East, March 1971'],
#        dtype='<U661'),
#  array(['99.06354076506045',
#         "['Ludwig van Beethoven', 'Wiener Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 9 in D Minor, Op. 125 "Choral": I. Allegro ma non troppo, un poco maestoso (Live)'],
#        dtype='<U661'),
#  array(['99.06299568014644',
#         "['Anton Bruckner', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Bruckner: Symphony No. 5 in B-Flat Major: I. Introduction - Adagio - Allegro'],
#        dtype='<U661'),
#  array(['99.06257155626716',
#         "['Johannes Brahms', 'Isaac Stern', 'Sir Thomas Beecham', 'Royal Philharmonic Orchestra']",
# ...
#        dtype='<U661'),
#  array(['98.95869588544299', "['Matthew Halsall']", 'Together'],
#        dtype='<U661'),
#  array(['98.95862624848829', "['Art Farmer']", 'Chanson'], dtype='<U661'),
#  array(['98.9584924302722', "['Nine Inch Nails']",
#         'The Mark Has Been Made'], dtype='<U661'),
#  array(['98.95840043093985', "['Toby Fox']", 'MEGALOVANIA'], dtype='<U661'),
#  array(['98.9583832324915',
#         "['Johannes Brahms', 'Sir John Barbirolli', 'New York Philharmonic']",
#         'Symphony No. 2 in D Major, Op. 73: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['98.95831067663997', "['Chick Corea']", 'Sometime Ago / La Fiesta'],
#        dtype='<U661'),
#  array(['98.958033627294', "['El Ten Eleven']", 'Fanshawe'], dtype='<U661'),
#  array(['98.95801817777594', "['Tropicalísimo Apache']", 'Apache Mix'],
#        dtype='<U661'),
#  array(['98.95793432960423', "['Kino']", 'Лето'], dtype='<U661'),
#  array(['98.95786168367299',
#         "['Ludwig van Beethoven', 'Glenn Gould', 'Leonard Bernstein', 'Columbia Symphony Orchestra']",
#         'Piano Concerto No. 2 in B-Flat Major, Op. 19: I. Allegro con brio'],
#        dtype='<U661'),
#  array(['98.95786036380845', "['Jimmy Smith']",
#         'Midnight Special - Rudy Van Gelder Digital Remaster/2007'],
#        dtype='<U661'),
#  array(['98.95775190545409',
#         "['Ludwig van Beethoven', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto No. 3 in C Minor, Op. 37: I. Allegro con brio'],
#        dtype='<U661'),
#  array(['98.95770811477593', "['The Allman Brothers Band']",
#         'Whipping Post - Live At The Final Fillmore East Concert, 1971'],
#        dtype='<U661'),
#  array(['98.95760366017322', "['Soolamangalam Sisters']",
#         'Skandha Sashti Kavacham'], dtype='<U661'),
#  array(['98.95755566869244',
#         "['John Abercrombie', 'Jan Hammer', 'Jack DeJohnette']",
#         'Timeless'], dtype='<U661'),
#  array(['98.95736291934193', "['Brian Culbertson']", 'On My Mind'],
#        dtype='<U661'),
#  array(['98.95726265464276', "['Harmless']", 'Swing Lynn'], dtype='<U661'),
#  array(['98.95723430123614', "['Herbie Hancock']", 'Chameleon'],
#        dtype='<U661'),
#  array(['98.95716408890681', "['Dean Evenson', 'Jonathan Kramer']",
#         'Heart Chakra - Breath of Love'], dtype='<U661'),
#  array(['98.9571352673267', "['Spiritualized']", 'Shine a Light'],
#        dtype='<U661'),
#  array(['98.95713170927532', "['Miles Davis']",
#         'Miles Runs the Voodoo Down'], dtype='<U661'),
#  array(['98.95691329582499', "['Incubus']", 'Aqueous Transmission'],
#        dtype='<U661'),
#  array(['98.95672154322634', "['LAKEY INSPIRED']", 'Better Days'],
#        dtype='<U661'),
#  array(['98.95658621965211', "['Miles Davis']", 'Spanish Key'],
#        dtype='<U661'),
#  array(['98.95650359759793', "['Tribal Tech']", 'Face First'],
#        dtype='<U661'),
#  array(['98.95646784446018', "['Parijat']", 'Healing the Heart'],
#        dtype='<U661'),
#  array(['98.95644712213785', "['Kid Loco']", "Relaxin' with cherry"],
#        dtype='<U661'),
#  array(['98.95641102799266',
#         "['Johannes Brahms', 'Jascha Heifetz', 'Fritz Reiner', 'Chicago Symphony Orchestra']",
#         'Violin Concerto in D Major, Op. 77: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['98.95627382079886', "['Electro-Light']", 'Symbolism'],
#        dtype='<U661'),
#  array(['98.95614373811367', "['Ashra']", 'Ocean Of Tenderness'],
#        dtype='<U661'),
#  array(['98.95607615109617',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in E-Flat Major, Op. 55 "Eroica": IV. Finale. Allegro molto'],
#        dtype='<U661'),
#  array(['98.95576723340214', "['Boney James']", "Nothin' But Love"],
#        dtype='<U661'),
#  array(['98.95570666072426', "['Seefeel']",
#         'Time To Find Me (AFX Fast Mix)'], dtype='<U661'),
#  array(['98.95562716623976', "['Miles Davis']",
#         'Miles Runs the Voodoo Down'], dtype='<U661'),
#  array(['98.95560307772254', "['Little People']", 'Moon'], dtype='<U661'),
#  array(['98.95557808996818',
#         "['Wolfgang Amadeus Mozart', 'Rudolf Serkin', 'Alexander Schneider']",
#         'Allegretto grazioso'], dtype='<U661'),
#  array(['98.9555583430098', "['Iggy Pop']", 'Dum Dum Boys'], dtype='<U661'),
#  array(['98.95553348173026', "['Donna Summer']",
#         'MacArthur Park Suite: MacArthur Park/One Of A Kind/Heavens Knows/MacArthur Park Reprise'],
#        dtype='<U661'),
#  array(['98.95534589680013',
#         "['Sergei Rachmaninoff', 'Earl Wild', 'Royal Philharmonic Orchestra', 'Jascha Horenstein']",
#         'Piano Concerto No. 1 in F-Sharp Minor, Op. 1: I. Vivace'],
#        dtype='<U661'),
#  array(['98.95527441640859', "['Dwight Sills']", 'Sliver Moon'],
#        dtype='<U661'),
#  array(['98.95512245805881',
#         "['Johannes Brahms', 'Gary Graffman', 'Charles Münch']",
#         'Piano Concerto No. 1 in D Minor, Op. 15: II. Adagio'],
#        dtype='<U661'),
#  array(['98.95505807170127', "['ODESZA']", 'My Friends Never Die'],
#        dtype='<U661'),
#  array(['98.9549482216773', "['John Cage', 'Herbert Henck']",
#         'In A Landscape'], dtype='<U661'),
#  array(['98.95492756564032',
#         "['Ralph Vaughan Williams', 'Iona Brown', 'Academy of St. Martin in the Fields', 'Sir Neville Marriner']",
#         'The Lark Ascending'], dtype='<U661'),
#  array(['98.9548353097101', "['Route 94', 'Jess Glynne']",
#         'My Love (feat. Jess Glynne)'], dtype='<U661'),
#  array(['98.9545690990017', "['Joe McBride']", 'Walking In Rhythm'],
#        dtype='<U661'),
#  array(['98.95454036280171', "['Avicii']", 'Levels'], dtype='<U661'),
#  array(['98.95447582490578',
#         "['Edvard Grieg', 'Arthur Rubinstein', 'Alfred Wallenstein', 'RCA Victor Symphony Orchestra']",
#         'Piano Concerto in A Minor, Op. 16: I. Allegro molto moderato - Remastered'],
#        dtype='<U661'),
#  array(['98.95441358639229',
#         "['Frederick Delius', 'Royal Philharmonic Orchestra', 'Sir Thomas Beecham']",
#         'Over the hills and far away (Fantasy Overture)'], dtype='<U661'),
#  array(['98.95439471789103', "['Pretty Lights']", 'Finally Moving'],
#        dtype='<U661'),
#  array(['98.9543470993966', "['Have A Nice Life']",
#         'Holy Fucking Shit: 40,000'], dtype='<U661'),
#  array(['98.95434508439814', "['Tears For Fears']",
#         'Pale Shelter - Long Version'], dtype='<U661'),
#  array(['98.9543276950071',
#         "['Felix Mendelssohn', 'Concertgebouworkest', 'Eduard van Beinum']",
#         'Overture "A Midsummer Night\'s Dream", Op.21'], dtype='<U661'),
#  array(['98.9543150890433', "['Type O Negative']", 'Paranoid'],
#        dtype='<U661'),
#  array(['98.95416280861453', "['deadmau5']", "Moar Ghosts 'n' Stuff"],
#        dtype='<U661'),
#  array(['98.9540299641568', "['Héctor Lavoe']", 'Periódico De Ayer'],
#        dtype='<U661'),
#  array(['98.9540173255552', "['Santigold']", 'Disparate Youth'],
#        dtype='<U661'),
#  array(['98.95394546873929', "['DJ Magic Mike']", 'Feel The Bass Again'],
#        dtype='<U661'),
#  array(['98.9537727562768', "['The Who']", 'Underture'], dtype='<U661'),
#  array(['98.95373277947687', "['Frédéric Chopin', 'Janusz Olejniczak']",
#         'Ballade No. 1 in G Minor, Op. 23'], dtype='<U661'),
#  array(['98.95368286377591', "['The Allman Brothers Band']",
#         'In Memory Of Elizabeth Reed - Live At The Final Fillmore East Concert, 1971'],
#        dtype='<U661'),
#  array(['98.95363218890434', "['William Onyeabor']", 'Fantastic Man'],
#        dtype='<U661'),
#  array(['98.95338838161786', "['Darude']", 'Sandstorm - Radio Edit'],
#        dtype='<U661'),
#  array(['98.95334091486897', "['Gayngs']", 'The Gaudy Side of Town'],
#        dtype='<U661'),
#  array(['98.95325064159884', "['Herbie Hancock']", "Steppin' In It"],
#        dtype='<U661'),
#  array(['98.95324297521505', "['Jimmy Smith']", 'Ode To Billie Joe'],
#        dtype='<U661'),
#  array(['98.95312751084312', "['Bob Marley & The Wailers']",
#         'Punky Reggae Party - Dub / Jamaican 12" Version'], dtype='<U661'),
#  array(['98.95311476282932',
#         "['Anthony Wonsey Trio', 'Richie Goods', 'Tony Reedus']",
#         'The Peacocks'], dtype='<U661'),
#  array(['98.95306358304907', "['Bossfight']", 'Milky Ways'], dtype='<U661'),
#  array(['98.95302486211457', "['Stanley Clarke']", 'School Days'],
#        dtype='<U661'),
#  array(['98.95300783590905', "['Johann Sebastian Bach', 'Jascha Heifetz']",
#         'Partita No. 2 in D Minor, BWV 1004: V. Chaconne'], dtype='<U661'),
#  array(['98.95290847907205', "['King Crimson']", 'The Devils Triangle'],
#        dtype='<U661'),
#  array(['98.95261745058515', "['Art Farmer']", 'Siddhartha'], dtype='<U661'),
#  array(['98.95249365123617', "['Noisestorm']", 'Crab Rave'], dtype='<U661'),
#  array(['98.95243598947786', "['Death Cab for Cutie']",
#         'Different Names for the Same Thing'], dtype='<U661'),
#  array(['98.95230585282117', "['Stereolab']", 'Metronomic Underground'],
#        dtype='<U661'),
#  array(['98.95230417318865', "['Lime']", 'Your Love - Album Mix'],
#        dtype='<U661'),
#  array(['98.95214132376157', "['Yo La Tengo']", 'You Can Have It All'],
#        dtype='<U661'),
#  array(['98.9520120513717', "['Nightmares On Wax']", 'Morse'],
#        dtype='<U661'),
#  array(['98.95196934759267', "['Jawga Boyz']", 'Redneck Dirt Road Riders'],
#        dtype='<U661'),
#  array(['98.95166800214756', "['Moby']", 'Rushing'], dtype='<U661'),
#  array(['98.95127748856085', "['Franz Schubert', 'Arturo Toscanini']",
#         'Symphony No. 9 in C Major, D. 944 "The Great": I. Andante - Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['98.95117283567895', "['Paul Hardcastle']", 'Rain Forest'],
#        dtype='<U661'),
#  array(['98.95113158422592', "['Tosca']", 'Suzuki'], dtype='<U661'),
#  array(['98.95111830858235', "['Talk Talk', 'Tim Friese-Greene']",
#         "It's My Life - Extended Mix; 2003 Remaster"], dtype='<U661'),
#  array(['98.95111075265163', "['Sade']", 'Siempre Hay Esperanza'],
#        dtype='<U661'),
#  array(['98.9511071987787', "['Charles Mingus']", 'What Love'],
#        dtype='<U661'),
#  array(['98.95091340066931',
#         "['Wolfgang Amadeus Mozart', 'Capella Istropolitana', 'Barry Wordsworth']",
#         'Symphony No. 41 in C Major, K. 551 "Jupiter": I. Allegro vivace'],
#        dtype='<U661'),
#  array(['98.95082999618559', "['Montez de Durango']", 'La Pava'],
#        dtype='<U661'),
#  array(['98.95081019021823',
#         "['Wolfgang Amadeus Mozart', 'Daniel Barenboim', 'English Chamber Orchestra']",
#         'Sinfonia Concertante for Violin, Viola and Orchestra in E-Flat Major, K. 364: I. Allegro maestoso'],
#        dtype='<U661'),
#  array(['98.95075686416078', "['Donald Byrd', 'Pepper Adams']",
#         'Stardust - 2013 - Remaster'], dtype='<U661'),
#  array(['98.95067503243992', "['Kool & The Gang']", 'Wild And Peaceful'],
#        dtype='<U661'),
#  array(['98.95057651025232',
#         "['Edward Elgar', 'Daniel Barenboim', 'London Philharmonic Orchestra']",
#         'Symphony No. 2 in E-Flat Major, Op. 63: II. Larghetto'],
#        dtype='<U661'),
#  array(['98.95037868333416',
#         "['Anton Bruckner', 'Wiener Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 4 in E-Flat Major, WAB 104 "Romantic" (1888 Version): IV. Finale: Bewegt, doch nicht zu schnell'],
#        dtype='<U661'),
#  array(['98.95023539949904',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: III. Rondo-Burleske. Allegro assai'],
#        dtype='<U661'),
#  array(['98.95008874684724', "['Joe Sample']", 'Seven Years of Good Luck'],
#        dtype='<U661'),
#  array(['98.95004063192994', "['Kraftwerk']",
#         'Computer Love - 2009 Remaster'], dtype='<U661'),
#  array(['98.94999972705163', "['Herbie Mann']", 'Memphis Underground'],
#        dtype='<U661'),
#  array(['98.94994869380271', "['Piano Pianissimo']",
#         'When You Love Someone'], dtype='<U661'),
#  array(['98.94991485369431', "['Proleter']", 'April Showers'],
#        dtype='<U661'),
#  array(['98.94989544106615',
#         "['Tomaso Albinoni', 'Berliner Philharmoniker', 'Herbert von Karajan', 'David Bell', 'Leon Spierer']",
#         'Adagio For Strings And Organ In G Minor'], dtype='<U661'),
#  array(['98.94985362792757', "['Orchestral Manoeuvres In The Dark']",
#         'Extended Souvenir - 2003 Digital Remaster'], dtype='<U661'),
#  array(['98.94978796392368', "['Ludwig van Beethoven', 'Pablo Casals']",
#         '12 Variations on "Ein Mädchen oder Weibchen", Op. 66'],
#        dtype='<U661'),
#  array(['98.94976118940049', "['Isaac Hayes']", 'Hung Up On My Baby'],
#        dtype='<U661'),
#  array(['98.9494683645533', "['The Egyptian Lover']",
#         'I Cry (Night after Night)'], dtype='<U661'),
#  array(['98.9493667859993', "['Jack Wilkins']", 'Windows'], dtype='<U661'),
#  array(['98.9492844188636', "['Gigi Masin']", "Swallow's Tempest"],
#        dtype='<U661'),
#  array(['98.94927743692152', "['Charlie Chaplin']", 'The Boxing Match'],
#        dtype='<U661'),
#  array(['98.9491561260296', "['Radiohead']", 'Daydreaming'], dtype='<U661'),
#  array(['98.94905913538065', "['Babe Ruth']", 'King Kong - 2007 Remaster'],
#        dtype='<U661'),
#  array(['98.94903184561491', "['Nobuo Uematsu']", 'Force Your Way'],
#        dtype='<U661'),
#  array(['98.94900604488278', "['Petit Biscuit']", 'You'], dtype='<U661'),
#  array(['98.94896038623797', "['Lemon Jelly']", "'75 aka Stay With You"],
#        dtype='<U661'),
#  array(['98.94893315251237', "['John Coltrane']",
#         'Lush Life - Rudy Van Gelder Remaster'], dtype='<U661'),
#  array(['98.94855142166969',
#         "['Ludwig van Beethoven', 'Sir Georg Solti', 'London Symphony Orchestra']",
#         'IV. "Ode to Joy" (excerpt) from Symphony No. 9 in D minor, Op. 125 - Voice'],
#        dtype='<U661'),
#  array(['98.94851745260829', "['Gustavo Cerati']", 'Amor Amarillo'],
#        dtype='<U661'),
#  array(['98.94850777365082', "['RŮDE']", 'Eternal Youth'], dtype='<U661'),
#  array(['98.94846770172515', "['This Will Destroy You']",
#         'They Move on Tracks of Never-Ending Light'], dtype='<U661'),
#  array(['98.94833939579969', "['The Whitest Boy Alive']", 'Burning'],
#        dtype='<U661'),
#  array(['98.94832282654298', "['The Dice Man']", 'Polygon Window'],
#        dtype='<U661'),
#  array(['98.94828216841266', "['Kyle Landry']",
#         "Howl's Moving Castle Theme"], dtype='<U661'),
#  array(['98.94815815144426',
#         "['Ludwig van Beethoven', 'Staatskapelle Berlin', 'Hans Pfitzner']",
#         'Symphony No. 6 in F Major, Op. 68 "Pastoral": 2. Szene am Bach - Andante molto mosso'],
#        dtype='<U661'),
#  array(['98.94815507343338', "['Boards of Canada']", 'Aquarius'],
#        dtype='<U661'),
#  array(['98.94814638578251', "['David Lanz']",
#         "Variations On A Theme From Pachelbel's Canon In D Major"],
#        dtype='<U661'),
#  array(['98.94809268242996', "['Maurice Ravel', 'Robert Casadesus']",
#         'Valses nobles et sentimentales, M. 61'], dtype='<U661'),
#  array(['98.94803027491918', "['Ott']", 'The Queen of All Everything'],
#        dtype='<U661'),
#  array(['98.94795608971414', "['David Benoit']", 'Freedom At Midnight'],
#        dtype='<U661'),
#  array(['98.947912185294', "['Marcel Dupré', 'Pierre Cochereau']",
#         'Passion-Symphony, Op. 23: III. Crucifixion'], dtype='<U661'),
#  array(['98.94788194780696', "['Grateful Dead']",
#         "Franklin's Tower - Live at Pembroke Pines, FL, May 22, 1977"],
#        dtype='<U661'),
#  array(['98.94778307888923',
#         "['Pyotr Ilyich Tchaikovsky', 'André Previn', 'London Symphony Orchestra']",
#         'Swan Lake, Op.20, Act I: 4. Pas de trois'], dtype='<U661'),
#  array(['98.9476816617628', "['Donna Summer']",
#         'I Feel Love - 12" Version'], dtype='<U661'),
#  array(['98.94764281810596', "['Beat Happening']", 'Godsend'],
#        dtype='<U661'),
#  array(['98.94752556551727', "['Tim Bowman']", 'Soul Dream'], dtype='<U661'),
#  array(['98.94746353017426', "['Parov Stelar']", 'All Night'],
#        dtype='<U661'),
#  array(['98.9474248031679',
#         "['Dr. Lonnie Smith', 'George Benson', 'Ron Carter', 'Joe Lovano']",
#         "It's Changed"], dtype='<U661'),
#  array(['98.94740483546371', "['Khruangbin']", "So We Won't Forget"],
#        dtype='<U661'),
#  ...]

# %%
playlist_added = ids[sort_indices][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
