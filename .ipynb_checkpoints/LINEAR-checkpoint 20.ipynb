# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Toby Keith']", 'Made in America'],
#         ["['K/DA', 'Madison Beer', '(G)I-DLE', 'Jaira Burns', 'League of Legends']",
#          'POP/STARS'],
#         ["['Taylor Swift']", 'Getaway Car'],
#         ...,
#         ["['Mariah Carey']", 'When I Saw You'],
#         ["['Vampire Weekend']", 'Everlasting Arms'],
#         ["['Clay Walker']", 'If I Could Make a Living']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.001

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.concatenate((predictions, song_info))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-0413ea156181> in <module>
#       4         #predictions.append((reg.predict([track]), ids[i], song_info[i]))
#       5 predictions = reg.predict(data)
# ----> 6 predicted = np.concatenate((predictions, song_info))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[predicted[:,0].argsort()][::-1]

# %%
list(predicted)
# Out:
# [array(['98.8711467147646', "['Sound Dreamer']",
#         'Brown Noise - 90 Minutes'], dtype='<U661'),
#  array(['98.12097371378078', "['Lightning, Thunder and Rain Storm']",
#         'Midnight Thunderstorm Part 2'], dtype='<U661'),
#  array(['97.50304302389938', "['Sounds for Life']",
#         'Brown Noise for Sleep'], dtype='<U661'),
#  array(['97.47615182510336', "['Sleep']", 'Dopesmoker'], dtype='<U661'),
#  array(['97.26676785437694', "['Ocean Waves For Sleep']",
#         'Ocean Waves for Sleep'], dtype='<U661'),
#  array(['97.2432257917862', "['Ocean Sounds']", 'Ocean Waves Sounds'],
#        dtype='<U661'),
#  array(['97.09545106870708', "['Brian Eno']",
#         'Thursday Afternoon - 2005 Digital Remaster'], dtype='<U661'),
#  array(['97.01862978460558', "['Chuck Riley']", 'Aladdin - Storyteller'],
#        dtype='<U661'),
#  array(['96.99477828628403', "['Environments']",
#         'The Psychologically Ultimate Seashore (16 rpm)'], dtype='<U661'),
#  array(['96.90422152383948', "['Umm Kulthum']", 'Enta Oumry'],
#        dtype='<U661'),
#  array(['96.5826333189708', "['Umm Kulthum']", 'Naheg El Berda'],
#        dtype='<U661'),
#  array(['96.54765735054501', "['Jeremy Soule']", 'Skyrim Atmospheres'],
#        dtype='<U661'),
#  array(['96.53945424415068', "['Portugallien']", 'Anslag'], dtype='<U661'),
#  array(['96.4950780711056', "['Environments']", 'Ultimate Thunderstorm'],
#        dtype='<U661'),
#  array(['96.4902211542417', "['Christopher Plummer']",
#         'The Many Adventures of Winnie the Pooh'], dtype='<U661'),
#  array(['96.4057579451271', "['Prince']",
#         'Eye No, Alphabet St., Glam Slam, Anna Stesia, Dance On, Lovesexy, When 2R in Love, I Wish U Heaven, Positivity'],
#        dtype='<U661'),
#  array(['96.40256728160864', "['Franklin Delano Roosevelt']",
#         'Address to Congress on Yalta - 03 01 1945'], dtype='<U661'),
#  array(['96.40067666139193', "['Deftones']", 'MX'], dtype='<U661'),
#  array(['96.40056972255957', "['Nature Sounds']",
#         'Relaxing Rain and Thunderstorm'], dtype='<U661'),
#  array(['96.39569994819858', "['Umm Kulthum']", 'Yalle Kan Yshgek Anene'],
#        dtype='<U661'),
#  array(['96.36641251910764', "['Nature Sounds']",
#         'Rain With Light Thunderstorm'], dtype='<U661'),
#  array(['96.36641251910764', "['Nature Sounds']",
#         'Rain With Distant Thunderstorm'], dtype='<U661'),
#  array(['96.36375691953167', "['Abdel Halim Hafez']", 'Qareat El Fengan'],
#        dtype='<U661'),
#  array(['96.34721550327313', "['President Franklin Delano Roosevelt']",
#         'State of the Union Address (January 7, 1943)'], dtype='<U661'),
#  array(['96.2573105217999', "['Emerson, Lake & Palmer']",
#         'Karn Evil 9 - i. 1st Impression, ii. 2nd Impression, iii. 3rd Impression; Live 1974; 2016 - Remaster'],
#        dtype='<U661'),
#  array(['96.25465983718664',
#         "['Richard Wagner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Bruno Walter Rehearses the Siegfried-Idyll'], dtype='<U661'),
#  array(['96.23570440339101', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['96.23190271416357', "['Sounds Of Nature : Thunderstorm, Rain']",
#         'Music For Sleep Thunderstorm, Rain'], dtype='<U661'),
#  array(['96.22126000296848', "['Umm Kulthum']", 'Ghana El Rabea'],
#        dtype='<U661'),
#  array(['96.20737459263829', "['Umm Kulthum']", 'Seret El Hob'],
#        dtype='<U661'),
#  array(['96.1997658413563', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['96.17226374659816', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['96.14365130822759', "['Umm Kulthum']", 'Halet Layale El Qamar'],
#        dtype='<U661'),
#  array(['96.11393653717633', "['Dr. Jeffrey Thompson']", 'Delta Sleep One'],
#        dtype='<U661'),
#  array(['96.11138952897774', "['The White Noise']",
#         'White Noise Fan for Babies'], dtype='<U661'),
#  array(['96.11116011374786', "['Umm Kulthum']", 'Gholobt Asaleh Fe Rohy'],
#        dtype='<U661'),
#  array(['96.1018247549395', "['Pharoah Sanders']",
#         'The Creator Has A Master Plan'], dtype='<U661'),
#  array(['96.06691726996958', "['Umm Kulthum']", 'Ahl El Hawa'],
#        dtype='<U661'),
#  array(['96.05231110344445', "['Umm Kulthum']", 'Amal Hayate'],
#        dtype='<U661'),
#  array(['96.03526465376312', "['Fishmans']", 'LONG SEASON'], dtype='<U661'),
#  array(['96.03064129543907', "['Umm Kulthum']", 'Woleda El Hoda'],
#        dtype='<U661'),
#  array(['96.02342564953904', "['Umm Kulthum']", 'Salo Qalbe'],
#        dtype='<U661'),
#  array(['96.01394273752823', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #12 - On the Recession (April 14, 1938)'],
#        dtype='<U661'),
#  array(['96.0077004052397', "['Miles Davis']", 'Go Ahead John'],
#        dtype='<U661'),
#  array(['96.00056080461825', "['Led Zeppelin']",
#         'Dazed and Confused - Live at MSG 1973; 2018 Remaster'],
#        dtype='<U661'),
#  array(['95.9912985686202', "['Gaston Bachelard']",
#         'Les dormeurs éveillés. La rêverie lucide'], dtype='<U661'),
#  array(['95.98118439517899', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone: Raise Positive Vibrations - Healing Frequency (Positive Energy Boost)'],
#        dtype='<U661'),
#  array(['95.97126524972435', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone With 528Hz Solfeggio Frequency'], dtype='<U661'),
#  array(['95.96916988121998', "['Umm Kulthum']", 'Raq El Habeb'],
#        dtype='<U661'),
#  array(['95.96816932139741', "['Glenn Gould', 'SYMPHONIA QUARTET']",
#         'String Quartet, Op. 1'], dtype='<U661'),
#  array(['95.94063573329142', "['Umm Kulthum']", 'Robaaeyat El Khayam'],
#        dtype='<U661'),
#  array(['95.91097037990386', "['Fela Kuti']", 'Beasts of No Nation'],
#        dtype='<U661'),
#  array(['95.90194473859181',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C minor "Resurrection": V. Im Tempo des Scherzos. Wild herausfahrend'],
#        dtype='<U661'),
#  array(['95.90135152876222',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['95.90038195138717', "['Brian Eno']",
#         'Discreet Music - Remastered 2004'], dtype='<U661'),
#  array(['95.89419018548219', "['Umm Kulthum']", 'Hadeth El Rouh'],
#        dtype='<U661'),
#  array(['95.8885338095886', "['Terry Riley']", 'In C - 2009 Remastered'],
#        dtype='<U661'),
#  array(['95.88809872772202',
#         "['Henryk Górecki', 'Dawn Upshaw', 'London Sinfonietta', 'David Zinman']",
#         'Symphony No. 3, Op. 36: I. Lento - Sostenuto Tranquillo Ma Cantabile'],
#        dtype='<U661'),
#  array(['95.88641099184126', "['King Crimson']",
#         'Lizard (Prince Rupert Awakes/Bolero/The Battle of Glass Tears/Big Top)'],
#        dtype='<U661'),
#  array(['95.882945191795', "['Juan Gabriel']",
#         'Hasta Que Te Conocí (Popurrí) [En Vivo] - En el Palacio de Bellas Artes'],
#        dtype='<U661'),
#  array(['95.88072899018479', "['Caravan']",
#         'Nine Feet Underground - Medley'], dtype='<U661'),
#  array(['95.87481429223794', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #20 - On the Progress of the War (February 23, 1942)'],
#        dtype='<U661'),
#  array(['95.8677199958513', "['Umm Kulthum']", 'Ana Fe Entzark'],
#        dtype='<U661'),
#  array(['95.86336893810454', "['Umm Kulthum']", 'Sahran Lewahde'],
#        dtype='<U661'),
#  array(['95.86218581050503', "['Franklin Delano Roosevelt']",
#         'On the Progress of the War - 02 23 1942'], dtype='<U661'),
#  array(['95.85845450983167', "['Environments']",
#         'The Psychologically Ultimate Seashore'], dtype='<U661'),
#  array(['95.85831100654983', "['Dream Theater']",
#         'A Change of Seasons - The Crimson Sunrise / Innocence / Carpe Diem / The Darkest of Winters / Another World / The Inevitable Summer / The Crimson Sunset'],
#        dtype='<U661'),
#  array(['95.8516867321144', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone: Rainy Days'], dtype='<U661'),
#  array(['95.84939463973824',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['95.84244175793583', "['Jethro Tull']",
#         'Thick as a Brick (Pt. I) - 1997 Remaster'], dtype='<U661'),
#  array(['95.83495054797348', "['Fela Kuti']",
#         "Teacher Don't Teach Me Nonsense"], dtype='<U661'),
#  array(['95.8316432834078', "['Umm Kulthum']", 'El Ahat'], dtype='<U661'),
#  array(['95.83080598609973', "['Charles Mingus']",
#         'C Jam Blues - Live Version'], dtype='<U661'),
#  array(['95.80361040845078', "['Shankar']",
#         'Ananda Nadamadum Tillai Sankara'], dtype='<U661'),
#  array(['95.79173793787042', "['Steve Roach']", 'Structures from Silence'],
#        dtype='<U661'),
#  array(['95.7889230073674', "['Built To Spill']",
#         'Cortez the Killer - Live'], dtype='<U661'),
#  array(['95.78076540426797', "['Yes']",
#         'The Gates of Delirium - 2003 Remaster'], dtype='<U661'),
#  array(['95.77918404610554', "['Mike Oldfield']", 'Tubular Bells - Pt. I'],
#        dtype='<U661'),
#  array(['95.77317913785336', "['Charles Mingus', 'Eric Dolphy']",
#         'Fables Of Faubus'], dtype='<U661'),
#  array(['95.77002057077753', "['Miles Davis']",
#         'What I Say - Live at the Cellar Door, Washington, DC - December 1970'],
#        dtype='<U661'),
#  array(['95.76943900849722', "['Kraftwerk']", 'Autobahn - 2009 Remaster'],
#        dtype='<U661'),
#  array(['95.7543910576295', "['Pink Floyd']", 'Echoes'], dtype='<U661'),
#  array(['95.75389015612504', "['Miles Davis']", 'Great Expectations'],
#        dtype='<U661'),
#  array(['95.7538349416691', "['Danny Kaye']", "Uncle Dan's Cabin"],
#        dtype='<U661'),
#  array(['95.75091090169967',
#         "['Playero', 'Daddy Yankee', 'Maicol & Manuel', 'Master Joe', 'Fellas Rican', '2* Sweet']",
#         'Ragga Moofin Mix'], dtype='<U661'),
#  array(['95.75051213295009', "['Franklin Delano Roosevelt']",
#         "Response to Hitler's invasions - 05 26 1940"], dtype='<U661'),
#  array(['95.74902861447413', "['Genesis']",
#         "Supper's Ready - Live in Paris"], dtype='<U661'),
#  array(['95.74855338576285', "['Keith Emerson']",
#         'Tarkus (i. Eruption / ii. Stones of Years / iii. Iconoclast / iv. Mass / v. Manticore / vi. Battlefield / vii. Aquatarkus) [2012 Remastered Version]'],
#        dtype='<U661'),
#  array(['95.73677579341474', "['Rare Earth']", 'Get Ready'], dtype='<U661'),
#  array(['95.73155162060294',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in D Minor, Part I: I. Kräftig, Entschieden - Remastered'],
#        dtype='<U661'),
#  array(['95.7277898644356', "['Godspeed You! Black Emperor']", 'Sleep'],
#        dtype='<U661'),
#  array(['95.72539551553237',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Das Lied von der Erde: VI. Der Abschied'], dtype='<U661'),
#  array(['95.72423533103324',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Das Lied von der Erde: VI. Der Abschied'], dtype='<U661'),
#  array(['95.72413220296667', "['Miles Davis']", 'Bitches Brew'],
#        dtype='<U661'),
#  array(['95.72360374380204', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #23 - On the Home Front (October 12, 1942)'],
#        dtype='<U661'),
#  array(['95.7211441673506', "['Genesis']",
#         "Supper's Ready - New Stereo Mix"], dtype='<U661'),
#  array(['95.72059027691068', "['Donna Summer']",
#         'Try Me, I Know We Can Make It'], dtype='<U661'),
#  array(['95.71187099925068', "['Miles Davis']", 'He Loved Him Madly'],
#        dtype='<U661'),
#  array(['95.71172372777161', "['Franklin Delano Roosevelt']",
#         'On Sacrifice and Losses - 04 28 1948'], dtype='<U661'),
#  array(['95.70818414184231', "['Jethro Tull']",
#         'Thick as a Brick (Pt. II) - 1997 Remaster'], dtype='<U661'),
#  array(['95.70283670781038',
#         "['Binaural Beats Brain Waves Isochronic Tones Brain Wave Entrainment']",
#         'Delta Waves for Deep Healing Sleep'], dtype='<U661'),
#  array(['95.70157328589609', "['Harvey Karp, MD, FAAP']", 'Rain (Sleep)'],
#        dtype='<U661'),
#  array(['95.69797197033478', "['Mike Oldfield']", 'Tubular Bells - Pt. II'],
#        dtype='<U661'),
#  array(['95.69618453873281', "['Danny Kaye']",
#         'The Great Donivitch Kayeoff'], dtype='<U661'),
#  array(['95.68961297475636', "['Miles Davis']", 'Bitches Brew'],
#        dtype='<U661'),
#  array(['95.67984333086648', "['Merian C. Cooper']", 'King Kong'],
#        dtype='<U661'),
#  array(['95.67249240504636', "['Korn']", 'Daddy'], dtype='<U661'),
#  array(['95.66966919926053', "['Umm Kulthum']", 'Ezkrony'], dtype='<U661'),
#  array(['95.66958238034152', "['Atlas Fret']", '(silent track)'],
#        dtype='<U661'),
#  array(['95.66404022579805', "['Donna Summer']",
#         'MacArthur Park Suite: MacArthur Park/One Of A Kind/Heavens Knows/MacArthur Park Reprise'],
#        dtype='<U661'),
#  array(['95.6600949118486', "['Yes']",
#         'The Revealing Science of God (Dance of the Dawn) - 2003 Remaster'],
#        dtype='<U661'),
#  array(['95.65970179283266', "['Fela Kuti']",
#         'Coffin For Head of State (Part 1 & 2)'], dtype='<U661'),
#  array(['95.65773323408204', "['Grateful Dead']",
#         'Turn on Your Lovelight - Live at Fillmore East, New York City, April 1971'],
#        dtype='<U661'),
#  array(['95.65366369145798', "['Pink Floyd']", 'Dogs'], dtype='<U661'),
#  array(['95.6525146064043', "['Tmsoft’s White Noise Sleep Sounds']",
#         'Box Fan Sound'], dtype='<U661'),
#  array(['95.65042718284234',
#         "['Igor Stravinsky', 'Philadelphia Orchestra', 'Leopold Stokowski']",
#         'Petrushka'], dtype='<U661'),
#  array(['95.64809905280676', "['Danny Kaye']",
#         'Opening Night of Playhouse'], dtype='<U661'),
#  array(['95.64634393584012', "['Tropicalísimo Apache']", 'Apache Mix'],
#        dtype='<U661'),
#  array(['95.6453558450935', "['Future Rapper']",
#         'StaggerLee Has His Day at the Beach'], dtype='<U661'),
#  array(['95.64274242644383', "['White Noise Sound Garden']",
#         'Real Fan Noise (White Noise)'], dtype='<U661'),
#  array(['95.63705396837828', "['The Allman Brothers Band']",
#         'Whipping Post - Live At The Final Fillmore East Concert, 1971'],
#        dtype='<U661'),
#  array(['95.63142418725484', "['Godspeed You! Black Emperor']", 'Storm'],
#        dtype='<U661'),
#  array(['95.62682296988217', "['NOFX']", 'The Decline'], dtype='<U661'),
#  array(['95.6264367725341', "['Moses Hadas']",
#         'Introduction / Books I-III / Book IV'], dtype='<U661'),
#  array(['95.62595147874096',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'I. Andante comodo'], dtype='<U661'),
#  array(['95.62509626147515', "['Miles Davis']", 'Star People'],
#        dtype='<U661'),
#  array(['95.6238674252402', "['The Doors']",
#         "When the Music's Over - Live"], dtype='<U661'),
#  array(['95.62262152244706', "['Donna Summer']",
#         'MacArthur Park Suite: MacArthur Park/One Of A Kind/Heavens Knows/MacArthur Park Reprise'],
#        dtype='<U661'),
#  array(['95.62027636248047', "['T. Rex']",
#         'The T. Rex Electric Warrior Interview'], dtype='<U661'),
#  array(['95.61832316706668', "['Rush']",
#         '2112: Overture / The Temples Of Syrinx / Discovery / Presentation / Oracle / Soliloquy / Grand Finale - Medley'],
#        dtype='<U661'),
#  array(['95.6179321371456', "['The 1975']", 'You'], dtype='<U661'),
#  array(['95.61558305136124', "['Alcoholics Anonymous']",
#         'He Had To Be Shown'], dtype='<U661'),
#  array(['95.61544818247316', "['Tmsoft’s White Noise Sleep Sounds']",
#         'Oscillating Fan Sound'], dtype='<U661'),
#  array(['95.61423029572997',
#         "['Sergei Prokofiev', 'New York Philharmonic', 'Leonard Bernstein']",
#         'Peter and the Wolf, Op. 67'], dtype='<U661'),
#  array(['95.61283107612815', "['The Allman Brothers Band']",
#         'Whipping Post - Live At The Fillmore East, March 1971'],
#        dtype='<U661'),
#  array(['95.61269569945965', "['Cream']", 'Spoonful - Live'], dtype='<U661'),
#  array(['95.61108980945401', "['Abdel Halim Hafez']",
#         'حاول تفتكرنى تسجيل حفلة'], dtype='<U661'),
#  array(['95.61057887966017', "['Yes']", 'The Gates of Delirium'],
#        dtype='<U661'),
#  array(['95.60609645449108', "['Iron Butterfly']",
#         'In-A-Gadda-Da-Vida - 2006 Remaster Full-Length'], dtype='<U661'),
#  array(['95.60497928637535', "['Angela Davis']",
#         'Panel Discussion with Burnham, Mitchell and Noble'], dtype='<U661'),
#  array(['95.60313344507436', "['Franklin Delano Roosevelt']",
#         'On the Fall of Mussolini - 07 28 1943'], dtype='<U661'),
#  array(['95.60040691387985',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: I. Andante comodo'], dtype='<U661'),
#  array(['95.59760847848551', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #28 - On the State of the Union (January 11, 1944)'],
#        dtype='<U661'),
#  array(['95.59488564492166', "['Nature Sounds']",
#         'Meditative Gentle Rain and Distant Thunder'], dtype='<U661'),
#  array(['95.5940061199713', "['Ravi Shankar']", 'Raga Bhimpalasi - Live'],
#        dtype='<U661'),
#  array(['95.5934008942047', "['Ravi Shankar']",
#         'Madhuvanti - Live; Digitally Remastered'], dtype='<U661'),
#  array(['95.5921489316442', "['Danny Kaye']", 'Benny Rubin'], dtype='<U661'),
#  array(['95.59207798772417', "['The Allman Brothers Band']",
#         'In Memory Of Elizabeth Reed - Live At The Fillmore East/1971/First Show'],
#        dtype='<U661'),
#  array(['95.58976093733851',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 2 - Dialogues'], dtype='<U661'),
#  array(['95.58896048576936', "['Fan Sounds']",
#         'Box Fan Long Loop For Sleep'], dtype='<U661'),
#  array(['95.58882975136936', "['Robert Earl Keen']", 'Silent Track'],
#        dtype='<U661'),
#  array(['95.58623146199565', "['Alcoholics Anonymous']",
#         'Our Southern Friend'], dtype='<U661'),
#  array(['95.58483999448599', "['Peter Frampton']",
#         'Do You Feel Like We Do'], dtype='<U661'),
#  array(['95.58335622295806', "['Connie Francis']", 'My Yiddishe Momme'],
#        dtype='<U661'),
#  array(['95.5828173609698', "['Rush']",
#         '2112: Overture / The Temples Of Syrinx / Discovery / Presentation / Oracle / Soliloquy / Grand Finale - Medley'],
#        dtype='<U661'),
#  array(['95.58210630536007', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #27 - On the Tehran and Cairo Conferences (December 24, 1943)'],
#        dtype='<U661'),
#  array(['95.58135423194186', "['Frankie Goes To Hollywood']",
#         'Welcome To The Pleasuredome'], dtype='<U661'),
#  array(['95.58033444193158', "['Cream']", 'Toad - Live'], dtype='<U661'),
#  array(['95.57868083241208', "['Tmsoft’s White Noise Sleep Sounds']",
#         'Air Conditioner'], dtype='<U661'),
#  array(['95.5784077325002', "['Archie Shepp']",
#         'Things Have Got To Change (Part 1 & 2)'], dtype='<U661'),
#  array(['95.57560370463436', "['Eric Clapton']",
#         'I Shot The Sheriff - Live At Hammersmith Odeon'], dtype='<U661'),
#  array(['95.57532807073679', "['Rush']", 'Cygnus X-1 Book II: Hemispheres'],
#        dtype='<U661'),
#  array(['95.57330466982971', "['Grateful Dead']",
#         'Dark Star - Live at the Fillmore West San Francisco, 1969; 2001 Remaster'],
#        dtype='<U661'),
#  array(['95.57295849112886', "['TOOL']", 'Invincible'], dtype='<U661'),
#  array(['95.57151303015705',
#         '[\'Sergei Prokofiev\', \'Gérard Philipe\', "Orchestre Symphonique De l\'U.R.S.S", \'Guennadi Rojdestvenski\']',
#         'Pierre et le Loup'], dtype='<U661'),
#  array(['95.56919757924', "['Danny Kaye']", 'Danny Returns from New York'],
#        dtype='<U661'),
#  array(['95.56564658994402', "['Yes']",
#         'Close to the Edge (i. The Solid Time of Change, ii. Total Mass Retain, iii. I Get up I Get Down, iv. Seasons of Man) - 2003 Remaster'],
#        dtype='<U661'),
#  array(['95.56362908797733', "['Calmsound']", 'Thunder and Rain'],
#        dtype='<U661'),
#  array(['95.56316265268946',
#         "['Gustav Mahler', 'Kathleen Ferrier', 'Wiener Philharmoniker', 'Bruno Walter']",
#         'Das Lied von der Erde: 6. Der Abschied'], dtype='<U661'),
#  array(['95.56100705938432', "['Brown Noise']", 'Brown Noise'],
#        dtype='<U661'),
#  array(['95.56018000268452', "['CAN']", 'You Doo Right'], dtype='<U661'),
#  array(['95.55159649651351', "['Vangelis']", 'Chariots Of Fire'],
#        dtype='<U661'),
#  array(['95.55127612224658', "['Franklin Delano Roosevelt']",
#         'Speech at Madison Square Garden - 10 31 1936'], dtype='<U661'),
#  array(['95.54896435390528', "['Tony Hancock']", 'The Jewel Robbery'],
#        dtype='<U661'),
#  array(['95.54739509837565', "['The Offspring']", 'Smash'], dtype='<U661'),
#  array(['95.54703823530164', "['Dexter Gordon']",
#         'Tanya - Remastered 2015'], dtype='<U661'),
#  array(['95.54309177194047', "['Fela Kuti', 'Ginger Baker']",
#         'Ginger Baker and Tony Allen (feat. Ginger Baker) - Drum Solo Live at the Berlin Jazz Festival 1978'],
#        dtype='<U661'),
#  array(['95.54296681351322', "['Blind Faith']", 'Do What You Like'],
#        dtype='<U661'),
#  array(['95.5422167199363', "['Yes']",
#         'Close to the Edge (I. The Solid Time of Change, II. Total Mass Retain, III. I Get up I Get Down, IV. Seasons of Man)'],
#        dtype='<U661'),
#  array(['95.54076727370713', "['Fans & White Noise']", 'White Noise: Fan'],
#        dtype='<U661'),
#  array(['95.5405223075138', "['Crosby, Stills, Nash & Young']",
#         'Southern Man - Live'], dtype='<U661'),
#  array(['95.53961029924552',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 3 - Dialogues'], dtype='<U661'),
#  array(['95.53741033721495', "['Metallica']",
#         'Seek & Destroy (Live in Mexico City)'], dtype='<U661'),
#  array(['95.53738466773065', "['TOOL']", 'Disgustipated'], dtype='<U661'),
#  array(['95.53479398965857', "['Grateful Dead']",
#         "Help on the Way / Slipknot! / Franklin's Tower - Live October 1989 - April 1990"],
#        dtype='<U661'),
#  array(['95.53450413734195', "['Fela Kuti']",
#         'Shuffering And Shmiling (Part 1 & 2)'], dtype='<U661'),
#  array(['95.5328608698422', "['Connie Francis']", 'Hava Nagilah'],
#        dtype='<U661'),
#  array(['95.53031592989802',
#         "['Jesus Culture', 'Chris Quilala', 'Kim Walker-Smith']",
#         "You Won't Relent - Live"], dtype='<U661'),
#  array(['95.52984717158458', "['The Temptations']", 'Masterpiece'],
#        dtype='<U661'),
#  array(['95.52983705731165', "['Rush']", 'Cygnus X-1 Book II: Hemispheres'],
#        dtype='<U661'),
#  array(['95.52981959988142', "['Yes']",
#         'The Revealing Science of God (Dance of the Dawn)'], dtype='<U661'),
#  array(['95.52947694100276', "['Donna Summer']",
#         'MacArthur Park Suite: MacArthur Park/One Of A Kind/Heavens Knows/MacArthur Park Reprise - DJ Promo 12" Version'],
#        dtype='<U661'),
#  array(['95.5277731350756',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 1 - Dialogues'], dtype='<U661'),
#  array(['95.52711351038587', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #13 - On Purging the Democratic Party (June 24, 1938)'],
#        dtype='<U661'),
#  array(['95.5265401695989', "['Miles Davis']", 'Spanish Key'],
#        dtype='<U661'),
#  array(['95.52578435043168',
#         "['Pyotr Ilyich Tchaikovsky', 'Evgeny Kissin', 'Berliner Philharmoniker', 'Herbert von Karajan']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23, TH. 55: 1. Allegro non troppo e molto maestoso - Allegro con spirito - Live at Philharmonie, Berlin'],
#        dtype='<U661'),
#  array(['95.5255680985557', "['The Allman Brothers Band']",
#         'Whipping Post - Live At The Fillmore East, March 1971'],
#        dtype='<U661'),
#  array(['95.52369391425974', "['Nature Sounds']",
#         'Calm Rolling Thunder and Soothing Rain'], dtype='<U661'),
#  array(['95.52239717850347', "['Annette Peacock']", 'Survival'],
#        dtype='<U661'),
#  array(['95.52217084935111', "['John Coltrane']",
#         'India - Live At The Village Vanguard, New York/1961'],
#        dtype='<U661'),
#  array(['95.52068199002473', "['Hans Zimmer', 'James Newton Howard']",
#         'A Dark Knight'], dtype='<U661'),
#  array(['95.52012967962426', "['John Coltrane']",
#         'Ascension - Edition I / Pt. 1'], dtype='<U661'),
#  array(['95.51908381739524',
#         "['Ralph Vaughan Williams', 'Tasmin Little', 'BBC Philharmonic', 'Andrew Davis']",
#         'The Lark Ascending'], dtype='<U661'),
#  array(['95.51906899614997',
#         "['Ralph Vaughan Williams', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Fantasia on a Theme by Thomas Tallis'], dtype='<U661'),
#  array(['95.51543315983616', "['Grupo Inspiracion']", 'Aleluya'],
#        dtype='<U661'),
#  array(['95.51469200134453', "['Tmsoft’s White Noise Sleep Sounds']",
#         'Air Conditioner Ac Fan Sound'], dtype='<U661'),
#  array(['95.51418714526223', "['Charles Mingus']",
#         'Medley: Mode D-Trio and Group Dancers/Mode E- Single solos and Group Dance/ModeF-Group and Solo Dance'],
#        dtype='<U661'),
#  array(['95.51356949025326', "['Fela Kuti']", 'Original Sufferhead'],
#        dtype='<U661'),
#  array(['95.51354292706844', "['Pink Floyd']", 'Atom Heart Mother'],
#        dtype='<U661'),
#  array(['95.51290009642806', "['Grateful Dead']",
#         'Terrapin Station Medley - 2014 Remaster'], dtype='<U661'),
#  array(['95.51210765657896', "['Fela Kuti']", 'Confusion (Parts 1 & 2)'],
#        dtype='<U661'),
#  array(['95.51209699086223', "['Robert Palmer']",
#         "Through It All There's You"], dtype='<U661'),
#  array(['95.50958218120842', "['Miles Davis']", 'Spanish Key'],
#        dtype='<U661'),
#  array(['95.5081421442508', "['Fela Kuti']", 'Opposite People'],
#        dtype='<U661'),
#  array(['95.50594626360603', "['Various Artists', 'Igor Stravinsky']",
#         'A propos of Le Sacre - Commentary by Igor Stravinsky About the History of a Musical Landmark'],
#        dtype='<U661'),
#  array(['95.50475517821287', "['Pat Metheny', 'Lyle Mays']",
#         'As Falls Wichita, So Falls Wichita Falls'], dtype='<U661'),
#  array(['95.50400225303933', "['Dire Straits']", 'Telegraph Road'],
#        dtype='<U661'),
#  array(['95.50341447748137', "['Danny Kaye']", 'His Own Guest Star'],
#        dtype='<U661'),
#  array(['95.49861640257623', '[\'B.B. King\', \'Bobby "Blue" Bland\']',
#         "Medley: The Thrill Is Gone / I Ain't Gonna Be The First To Cry - Live At Coconut Grove, Los Angeles/1976"],
#        dtype='<U661'),
#  array(['95.49569174838416', "['Jimi Hendrix']",
#         'Red House - Live San Diego Sports Arena, May 25, 1969'],
#        dtype='<U661'),
#  array(['95.49445961647898', "['Frank Zappa']", 'Big Swifty'],
#        dtype='<U661'),
#  array(['95.49427128978824', "['Donna Summer']", 'Love To Love You Baby'],
#        dtype='<U661'),
#  array(['95.49317112391087', "['Nature Sounds']",
#         'Soothing Approaching Storm with Warning Thunder Rolls'],
#        dtype='<U661'),
#  array(['95.49284036434643', "['Rush']", 'The Fountain Of Lamneth'],
#        dtype='<U661'),
#  array(['95.49016166344593', "['Van Morrison']", 'Summertime In England'],
#        dtype='<U661'),
#  array(['95.48945714268974', "['Abdel Halim Hafez']",
#         'فاتت جنبنا تسجيل حفلة'], dtype='<U661'),
#  array(['95.48871138091805', "['Keith Jarrett']",
#         'Köln, January 24, 1975, Pt. I - Live'], dtype='<U661'),
#  array(['95.48835454074316', "['Peter Frampton']",
#         'Do You Feel Like We Do - Live'], dtype='<U661'),
#  array(['95.48699715810478', "['Elton John']",
#         'Burn Down The Mission (Incl. My Baby Left Me / Get Back)'],
#        dtype='<U661'),
#  array(['95.48671423867683',
#         "['Leopold Stokowski', 'Philadelphia Orchestra']",
#         'Rite of Spring'], dtype='<U661'),
#  array(['95.4848412232994', "['Pink Floyd']", 'Comfortably Numb - Live'],
#        dtype='<U661'),
#  array(['95.48426435384319', "['Helloween']", 'Keeper of the Seven Keys'],
#        dtype='<U661'),
#  array(['95.48408711956564', "['Franz Liszt', 'Vladimir Horowitz']",
#         'Piano Sonata in B Minor, S. 178'], dtype='<U661'),
#  array(['95.48399053113557', "['Sly & The Family Stone']", 'Sex Machine'],
#        dtype='<U661'),
#  array(['95.48360485171358', "['Chick Corea']", 'Sometime Ago / La Fiesta'],
#        dtype='<U661'),
#  array(['95.48336055063011',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in D Minor, Part II: VI. Langsam, Ruhevoll. Empfunden'],
#        dtype='<U661'),
#  array(['95.48121895716864',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 4 - Dialogues'], dtype='<U661'),
#  array(['95.48028900929778', "['Enigma']",
#         'Back To The Rivers Of Belief: Way To Eternity / Hallelujah / The Rivers Of Belief'],
#        dtype='<U661'),
#  array(['95.48016285458202', "['Widespread Panic']", 'Diner'],
#        dtype='<U661'),
#  array(['95.47961419028405', "['Chuck Mangione', 'Esther Satterfield']",
#         'Land Of Make Believe'], dtype='<U661'),
#  array(['95.47861100445151', "['Miles Davis']",
#         'So What - Live at Kurhaus, Den Haag, Holland - April 1960'],
#        dtype='<U661'),
#  array(['95.47848263298833', "['Lynyrd Skynyrd']",
#         'Free Bird - Live At Fox Theater, Atlanta/1976'], dtype='<U661'),
#  array(['95.4784556495267', "['William DeVaughn']",
#         "Be Thankful for What You've Got - David Todd Remix"],
#        dtype='<U661'),
#  array(['95.47786569213415', "['The Allman Brothers Band']",
#         "You Don't Love Me - Live At The Final Fillmore East Concert, 1971"],
#        dtype='<U661'),
#  array(['95.4763442758083', "['Sheila E.']", 'A Love Bizarre'],
#        dtype='<U661'),
#  array(['95.47632758332878', "['CAN']", 'Halleluhwah - 2011 Remastered'],
#        dtype='<U661'),
#  array(['95.47482437532706', "['Dwight D. Eisenhower']",
#         'On the atomic capabilities - 12 08 1953'], dtype='<U661'),
#  array(['95.47442737351138', "['Pink Floyd']", 'Comfortably Numb - Live'],
#        dtype='<U661'),
#  array(['95.47431235370365', "['Franklin Delano Roosevelt']",
#         'Purge of the Democratic Party - 06 24 1938'], dtype='<U661'),
#  array(['95.47419591821779', "['Herbie Hancock']", 'Chameleon'],
#        dtype='<U661'),
#  array(['95.47377559160985', "['TOOL']", 'Pneuma'], dtype='<U661'),
#  array(['95.47326980681306', "['Fela Kuti', 'Roy Ayers']",
#         '2000 Blacks Got To Be Free (feat. Roy Ayers)'], dtype='<U661'),
#  array(['95.47304944216363', "['Traffic']",
#         'The Low Spark Of High-Heeled Boys'], dtype='<U661'),
#  array(['95.47138611496155', "['CAN']", 'Bel Air'], dtype='<U661'),
#  array(['95.47123281506026', "['Miles Davis']", 'Stuff'], dtype='<U661'),
#  array(['95.47096696456668', "['TOOL']", 'Third Eye'], dtype='<U661'),
#  array(['95.46922558127586', "['Grateful Dead']",
#         'Eyes of the World - Live October 1989 - April 1990'],
#        dtype='<U661'),
#  array(['95.46877821596136', "['Joe Walsh']",
#         'Rocky Mountain Way - Live At Santa Monica Civic Auditorium/1976'],
#        dtype='<U661'),
#  array(['95.46838500184658', "['Frank Zappa']", 'The Gumbo Variations'],
#        dtype='<U661'),
#  array(['95.46805369399674', "['Jon & Vangelis']",
#         'The Friends Of Mr. Cairo'], dtype='<U661'),
#  array(['95.46768028577928', "['Franklin Delano Roosevelt']",
#         'On meetings in Cairo and Teheran with Churchill, Stalin, and Chiang Kai-shek - 12 24 1943'],
#        dtype='<U661'),
#  array(['95.46514612110897', "['John Coltrane']",
#         'Ascension - Edition I / Pt. 2'], dtype='<U661'),
#  array(['95.46441082258342', "['Yes']", 'Awaken - 2003 Remaster'],
#        dtype='<U661'),
#  array(['95.46330915274676', "['Phish']", 'David Bowie'], dtype='<U661'),
#  array(['95.46229559392256', "['Anna Russell']",
#         'Survey of Singing from Madrigals to Modern Opera'], dtype='<U661'),
#  array(['95.46079961523766', "['Crosby, Stills, Nash & Young']",
#         'Carry On - Live'], dtype='<U661'),
#  array(['95.46009096917399', "['Peter Frampton', 'Chris Kimsey']",
#         'Do You Feel Like We Do - Live'], dtype='<U661'),
#  array(['95.45920608326279', "['CAN']", 'Halleluhwah - 2011 Remastered'],
#        dtype='<U661'),
#  array(['95.45892334760497', "['Franklin Delano Roosevelt']",
#         'German submarine fired an American destroyer - 09 11 1941'],
#        dtype='<U661'),
#  array(['95.45824219968866', "['John Coltrane']",
#         'Impressions - Live At The Village Vanguard, New York/1961'],
#        dtype='<U661'),
#  array(['95.4573470662959', "['Dmitri Shostakovich', 'Arturo Toscanini']",
#         'Symphony No. 7 in C Major, Op. 60 "Leningrad": I. Allegretto'],
#        dtype='<U661'),
#  array(['95.45723521088527', "['Albert King', 'Stevie Ray Vaughan']",
#         'Blues At Sunrise'], dtype='<U661'),
#  array(['95.45555517962372', "['Dream Theater']", 'Learning to Live'],
#        dtype='<U661'),
#  array(['95.45480482997752', "['Erykah Badu']",
#         'Next Lifetime - Live Version'], dtype='<U661'),
#  array(['95.45421946290902', "['Pink Floyd']", 'Comfortably Numb - Live'],
#        dtype='<U661'),
#  array(['95.45344495533826', "['D.O.A.', 'Jello Biafra']",
#         'Full Metal Jackoff'], dtype='<U661'),
#  array(['95.45267878430982',
#         "['Dmitri Shostakovich', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 5 in D Minor, Op. 47: III. Largo'], dtype='<U661'),
#  array(['95.45133036493712', "['Craig Pruess & Ananda']", 'Devi Prayer'],
#        dtype='<U661'),
#  array(['95.45096464007854', "['Fela Kuti']", 'Roforofo Fight'],
#        dtype='<U661'),
#  array(['95.45080475789678', "['Hawkwind']",
#         "You Shouldn't Do That - 1996 Remaster"], dtype='<U661'),
#  array(['95.45077663286749', "['Don Slepian']", 'Awakening'], dtype='<U661'),
#  array(['95.45006763224919', "['Isaac Hayes']",
#         'By The Time I Get To Phoenix - Album - Remaster'], dtype='<U661'),
#  array(['95.44970031440302', "['Fela Kuti']", 'No Agreement'],
#        dtype='<U661'),
#  array(['95.44945880507947', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #22 - On Inflation and Food Prices (September 7, 1942)'],
#        dtype='<U661'),
#  array(['95.44872812661245', "['The Time']", 'Get It Up'], dtype='<U661'),
#  array(['95.44867727827344',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 1 in D Major "Titan": IV. Stürmisch bewegt - Energisch'],
#        dtype='<U661'),
#  array(['95.44858404610726', "['Marijata']", 'I Walk Alone'], dtype='<U661'),
#  array(['95.44857197845965',
#         "['Giuseppe Verdi', 'Robert Bowman', 'Michael Langdon', 'Fernando Corena', 'Regina Resnik', 'The New Symphony Orchestra Of London', 'Sir Edward Downes']",
#         'Falstaff / Act 2: Siam pentiti e contriti...Reverenza'],
#        dtype='<U661'),
#  array(['95.44774045979221', "['Fela Kuti']", 'Gentleman'], dtype='<U661'),
#  array(['95.44739825766098',
#         "['Noel Coward', 'Andre Kostelanetz & His Orchestra', 'Frank Miller', 'Julius Baker', 'Leonid Hambro', 'Jascha Zayde']",
#         'The Carnival of the Animals'], dtype='<U661'),
#  array(['95.44682829573513', "['Dave Matthews Band']",
#         'Seek Up - Live at Red Rocks Amphitheatre, Morrison, CO - August 1995'],
#        dtype='<U661'),
#  array(['95.44666029315157', "['Santa Esmeralda']",
#         "Don't Let Me Be Misunderstood"], dtype='<U661'),
#  array(['95.44615594683816', "['The Allman Brothers Band']",
#         "You Don't Love Me - Live At The Fillmore East/1971/First Show"],
#        dtype='<U661'),
#  array(['95.44584065033362', "['Nature Sounds']",
#         'Healthful Rolling Thunder with Distant Rumbles'], dtype='<U661'),
#  array(['95.44572796623194', "['Rush']", '2112 - Live'], dtype='<U661'),
#  array(['95.44559624041273', "['Grateful Dead']",
#         'The Other One - Live at Fillmore East, New York, NY, April 28, 1971'],
#        dtype='<U661'),
#  array(['95.44526391853562', "['Dwight D. Eisenhower']",
#         'Call for peace and on the rising of the MIC military-industrial complex - 01-17-1961'],
#        dtype='<U661'),
#  array(['95.4430409177327', "['Miles Davis']", "Pharaoh's Dance"],
#        dtype='<U661'),
#  array(['95.44228241311882', "['The Outlaws']",
#         'Green Grass & High Tides - Remastered'], dtype='<U661'),
#  array(['95.4417128394817', "['James Brown']", "Papa Don't Take No Mess"],
#        dtype='<U661'),
#  array(['95.43949629992478', "['Alcoholics Anonymous']", "Joe's Woes"],
#        dtype='<U661'),
#  array(['95.43872518890275', "['Jerry Garcia Band', 'Jerry Garcia']",
#         "Don't Let Go - Bonus Track"], dtype='<U661'),
#  array(['95.43763627511856', "['Led Zeppelin']",
#         'You Shook Me - Live in Paris, 1969'], dtype='<U661'),
#  array(['95.43683527572205', "['Camel']",
#         'Lady Fantasy: Encounter / Smiles for You / Lady Fantasy'],
#        dtype='<U661'),
#  array(['95.4367575730871', "['Led Zeppelin']",
#         'Whole Lotta Love - Live at MSG 1973; 2018 Remaster'],
#        dtype='<U661'),
#  array(['95.43511890827176', "['TOOL']", 'Reflection'], dtype='<U661'),
#  array(['95.43358762649113', "['Krishna Das']", 'Baba Hanuman'],
#        dtype='<U661'),
#  array(['95.43281968796092', "['Soolamangalam Sisters']",
#         'Skandha Sashti Kavacham'], dtype='<U661'),
#  array(['95.43273918491437', "['Anita Ward']", 'Ring My Bell'],
#        dtype='<U661'),
#  array(['95.43235604116738', "['John Coltrane']", 'Ole'], dtype='<U661'),
#  array(['95.43223304840238',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: IV. Adagio - Sehr langsam und noch zurückhaltend'],
#        dtype='<U661'),
#  array(['95.4311141977877', "['John Cage', 'Herbert Henck']",
#         'In A Landscape'], dtype='<U661'),
#  array(['95.4309623447966', "['Dwight D. Eisenhower']",
#         'Cross of Iron Speech (after the death of Stalin) - 04 16 1953'],
#        dtype='<U661'),
#  array(['95.43036031062087', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 17'],
#        dtype='<U661'),
#  array(['95.43032569355763', "['The Wailers']",
#         'Lively Up Yourself - Live At Leeds Polytechnic, 1973'],
#        dtype='<U661'),
#  array(['95.42893179962431', "['The Who']",
#         'My Generation - Live / Medley'], dtype='<U661'),
#  array(['95.42673602757989', "['Godspeed You! Black Emperor']",
#         'East Hastings'], dtype='<U661'),
#  array(['95.42596017694645', "['George Michael']",
#         'I Want Your Sex - Pts. 1 & 2 Remastered'], dtype='<U661'),
#  array(['95.42576749673002', "['Led Zeppelin']",
#         'Dazed and Confused - Live in Paris, 1969'], dtype='<U661'),
#  array(['95.42516102592899', "['Black Sabbath']",
#         'A Bit of Finger / Sleeping Village / Warning - 2013 Remaster'],
#        dtype='<U661'),
#  array(['95.42396758173427', "['Tim Maia']", 'Rational Culture'],
#        dtype='<U661'),
#  array(['95.42206992991105', "['Sheila E.']", 'The Glamorous Life'],
#        dtype='<U661'),
#  array(['95.42142175516952', "['Black Sabbath']",
#         'Wasp / Behind the Wall of Sleep / Bassically / N.I.B. - 2014 Remaster'],
#        dtype='<U661'),
#  array(['95.41936247838872', "['Sonny Rollins Quintet']",
#         'Medley: I Remember You / My Melancholy Baby / Old Folks / They Can’t Take That Away From Me / Just Friends / My Little Suede Shoes / Star Eyes - Rudy Van Gelder Remaster'],
#        dtype='<U661'),
#  array(['95.41886615837436', "['The Time']", 'Cool'], dtype='<U661'),
#  array(['95.4186730390215', "['The Allman Brothers Band']",
#         'In Memory Of Elizabeth Reed - Live At The Final Fillmore East Concert, 1971'],
#        dtype='<U661'),
#  array(['95.41853397976655', "['Fan Sounds']", 'Box Fan Rest Sound'],
#        dtype='<U661'),
#  array(['95.41820473188132', "['James Baldwin']", 'The Struggle - Part I'],
#        dtype='<U661'),
#  array(['95.41754142063903', "['Fela Kuti']", 'Open & Close'],
#        dtype='<U661'),
#  array(['95.41683219022757', "['TOOL']", 'Fear Inoculum'], dtype='<U661'),
#  array(['95.41616387244034', "['Pink Floyd']",
#         'Pigs (Three Different Ones)'], dtype='<U661'),
#  array(['95.41550475200012',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 1 in D Major "Titan": IV. Stürmisch bewegt - Energisch'],
#        dtype='<U661'),
#  array(['95.41508394846907', "['Miles Davis']", "Pharaoh's Dance"],
#        dtype='<U661'),
#  array(['95.41503309448836', "['Van Morrison']", 'T. B. Sheets'],
#        dtype='<U661'),
#  array(['95.41264506804896', "['John Mayer']",
#         'Covered in Rain - Live at the Oak Mountain Amphitheater, Birmingham, AL - September 2002'],
#        dtype='<U661'),
#  array(['95.41176939831026',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": I. Allegro maestoso - Remastered'],
#        dtype='<U661'),
#  array(['95.41141000905746', "['Pink Floyd']",
#         'Shine On You Crazy Diamond (Pts. 1-5, 7) - Live'], dtype='<U661'),
#  array(['95.41126761616206', "['Al Kooper']", 'Season of the Witch'],
#        dtype='<U661'),
#  array(['95.41118409486343', "['President Franklin Delano Roosevelt']",
#         'The "Stab in the Back" Speech (June 10, 1940)'], dtype='<U661'),
#  array(['95.41117945457744', "['Derek & The Dominos']",
#         'Got To Get Better In A Little While - Live'], dtype='<U661'),
#  array(['95.41003926529564', "['Nature Sounds']",
#         'Healing Thunderstorm with Light Rain'], dtype='<U661'),
#  array(['95.40947512324', "['The Gap Band']", 'Yearning For Your Love'],
#        dtype='<U661'),
#  array(['95.40907217677261', "['Daft Punk']", 'Too Long'], dtype='<U661'),
#  array(['95.4085021278975', "['Public Image Ltd.']", 'Albatross'],
#        dtype='<U661'),
#  array(['95.40849050408083', "['Freeez']", 'I.O.U. (12" Version)'],
#        dtype='<U661'),
#  array(['95.40807780248785', "['Four Tet']", 'Locked'], dtype='<U661'),
#  array(['95.40806365761553', "['William DeVaughn']",
#         "Be Thankful for What You've Got - David Todd Remix"],
#        dtype='<U661'),
#  array(['95.40719881085967',
#         "['Duke Ellington', 'Clark Terry', 'Willie Cook', 'Cat Anderson', 'Ray Nance', 'Quentin Jackson', 'Britt Woodman', 'George Jean', 'Jimmy Hamilton', 'Rick Henderson', 'Russell Procope', 'Paul Gonsalves', 'Harry Carney', 'Wendell Marshall', 'Dave Black']",
#         'Skin Deep'], dtype='<U661'),
#  array(['95.40616799749723',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: IV. Adagio - Sehr langsam und noch zurückhaltend'],
#        dtype='<U661'),
#  array(['95.40572157324918', "['George Benson']", 'On Broadway - Live'],
#        dtype='<U661'),
#  array(['95.4044952868146', "['Pink Floyd']",
#         'Shine On You Crazy Diamond - Live'], dtype='<U661'),
#  array(['95.40356914852994', "['Taana Gardner']", 'Heartbeat'],
#        dtype='<U661'),
#  array(['95.40275298603913', "['Didrik Thulin']", 'Dancer (Kygo Remix)'],
#        dtype='<U661'),
#  array(['95.40269890222386', "['The Offspring']", 'Smash'], dtype='<U661'),
#  array(['95.40250294516181', "['Bruce Springsteen']",
#         'The River - Live at LA Coliseum, Los Angeles, CA - September 1985'],
#        dtype='<U661'),
#  array(['95.40245828058825', "['Frank Zappa']", 'The Grand Wazoo'],
#        dtype='<U661'),
#  array(['95.40243310293896', "['Enigma']",
#         'Principles Of Lust: Sadeness / Find Love / Sadeness (Reprise)'],
#        dtype='<U661'),
#  array(['95.40145193467578', "['Fela Kuti']",
#         'Trouble Sleep Yanga Wake Am'], dtype='<U661'),
#  array(['95.40103270143973', "['Pigeons Playing Ping Pong']", 'Horizon'],
#        dtype='<U661'),
#  array(['95.40072960619919', "['TOTO']", 'Rosanna'], dtype='<U661'),
#  array(['95.40038355133932', "['Miles Davis']", 'Country Son'],
#        dtype='<U661'),
#  array(['95.40027792684745', "['George Michael']",
#         'I Want Your Sex - Pts. 1 & 2 Remastered'], dtype='<U661'),
#  array(['95.39999264943752', "['Television']", 'Marquee Moon'],
#        dtype='<U661'),
#  array(['95.39944738109985', "['Peter Green']", 'A Fool No More'],
#        dtype='<U661'),
#  array(['95.39940651777337', "['Phish']", 'The Divided Sky'], dtype='<U661'),
#  array(['95.39885309686518', "['The Temptations']",
#         'Smiling Faces Sometimes'], dtype='<U661'),
#  array(['95.39844886519282', "['Grateful Dead']",
#         'Sugaree - Live at Pembroke Pines, FL, May 22, 1977'],
#        dtype='<U661'),
#  array(['95.39798795515397', "['The Mission']", 'Tower Of Strength'],
#        dtype='<U661'),
#  array(['95.39754212854864', "['Fela Kuti']", 'Upside Down'], dtype='<U661'),
#  array(['95.3973094908781', "['Naturaleza FX']", 'Colors of the Rain'],
#        dtype='<U661'),
#  array(['95.39679830367265', "['Supertramp']", 'Brother Where You Bound'],
#        dtype='<U661'),
#  array(['95.39669377090908', "['Fela Kuti']", 'Water No Get Enemy - Edit'],
#        dtype='<U661'),
#  array(['95.39662637543096', "['Sounds of Nature Noise']", 'Soft Thunder'],
#        dtype='<U661'),
#  array(['95.39634642414792', "['Nature Sounds']",
#         'Thoughtful Approaching Thunderstorm'], dtype='<U661'),
#  array(['95.39620998145769', "['Black Sabbath']",
#         'A Bit of Finger / Sleeping Village / Warning - 2013 Remaster'],
#        dtype='<U661'),
#  array(['95.39608184748475', "['Red Rocks Worship']",
#         'Breakthrough - Live'], dtype='<U661'),
#  array(['95.3960144284188', "['MGMT']", 'Siberian Breaks'], dtype='<U661'),
#  array(['95.39588445231918', "['Mohammed Abdel Wahab']", 'من غير ليه'],
#        dtype='<U661'),
#  array(['95.39559566732326', "['Barry White']",
#         "I'm Gonna Love You Just A Little More Baby"], dtype='<U661'),
#  array(['95.3949381421299', "['Bob Marley & The Wailers']",
#         'Exodus - Live At Ahoy Hallen/1978'], dtype='<U661'),
#  array(['95.3944483312715',
#         "['Samuel Coleridge-Taylor', 'Royal Liverpool Philharmonic Orchestra', 'Grant Llewellyn']",
#         'Symphonic Variations on an African Air, Op.63'], dtype='<U661'),
#  array(['95.39443905333036', "['Wolfgang Weyrauch']",
#         'Kapitel 1 - Das Wirtshaus im Taunus und andere Erzählungen'],
#        dtype='<U661'),
#  array(['95.39374510124638', "['Fela Kuti']", 'Fear Not For Man'],
#        dtype='<U661'),
#  array(['95.39347181472074', "['Betty Wright']",
#         "Medley: Clean up Woman / Pillow Talk / You Got the Love / Mr. Melody / Midnight at the Oasis / Me and Mrs. Jones / You Are My Sunshine / Let's Get Married Today - Live"],
#        dtype='<U661'),
#  array(['95.39325354746977',
#         "['Deep Sleep', 'Sleep Baby Sleep', 'Lullabies for Deep Meditation', 'Relax Meditate Sleep', 'Relaxation', 'Soothing White Noise for Infant Sleeping and Massage, Crying & Colic Relief']",
#         'Pure Brown Noise - Loopable with no fade'], dtype='<U661'),
#  array(['95.39282959500461', "['Yura Yura Teikoku']", 'YURA YURA UGOKU'],
#        dtype='<U661'),
#  array(['95.39227741163866', "['Helloween']", 'Halloween'], dtype='<U661'),
#  array(['95.39131528308322', "['Chuck Mangione', 'Don Potter']",
#         'Children Of Sanchez'], dtype='<U661'),
#  array(['95.39081101881601', "['Stevie Ray Vaughan']",
#         "Little Wing / Third Stone From The Sun - Live at Ripley's Music Hall, Philadelphia, PA, Oct. 20, 1983"],
#        dtype='<U661'),
#  array(['95.39003572492969', "['Grateful Dead']",
#         "Franklin's Tower - Live at Pembroke Pines, FL, May 22, 1977"],
#        dtype='<U661'),
# ...
#  array(['95.30212636974525', "['Madonna']",
#         'Like a Virgin - Extended Dance Remix'], dtype='<U661'),
#  array(['95.3021073155417', "['First Choice']", 'Doctor Love'],
#        dtype='<U661'),
#  array(['95.30198481957558', "['Opeth']", 'Face Of Melinda (Remastered)'],
#        dtype='<U661'),
#  array(['95.30195118305028', "['Damian Marley', 'Treach', 'Yami Bolo']",
#         'Stand A Chance'], dtype='<U661'),
#  array(['95.30193332431055', "['Paul Hardcastle']", 'Rain Forest'],
#        dtype='<U661'),
#  array(['95.30184944640168', "['Lynyrd Skynyrd']", 'That Smell'],
#        dtype='<U661'),
#  array(['95.30173905093686', "['Too $hort']", 'Dope Fiend Beat'],
#        dtype='<U661'),
#  array(['95.30173160394983', "['Jim Hall']", 'Concierto De Aranjuez'],
#        dtype='<U661'),
#  array(['95.30171776251018', "['Led Zeppelin']",
#         'Achilles Last Stand - 2007 Remaster'], dtype='<U661'),
#  array(['95.3015823564169',
#         "['Pyotr Ilyich Tchaikovsky', 'Royal Philharmonic Orchestra', 'Philip Ellis']",
#         '1812 Overture'], dtype='<U661'),
#  array(['95.30158232943964', "['Strafe']", 'Set It Off (Vocal)'],
#        dtype='<U661'),
#  array(['95.30157894297494', "['J Balvin', 'Bad Bunny']", 'QUE PRETENDES'],
#        dtype='<U661'),
#  array(['95.3015604476783', "['Sample Rain Library']",
#         'Brain Relaxation Sky'], dtype='<U661'),
#  array(['95.30150228088965', "['Yes']", 'Siberian Khatru - 2003 Remaster'],
#        dtype='<U661'),
#  array(['95.30143008041807', "['Black Sabbath']", 'N.I.B.'], dtype='<U661'),
#  array(['95.30138139516086', "['Genesis']",
#         'Firth of Fifth - Live in Paris'], dtype='<U661'),
#  array(['95.30128525220374', "['Nazareth']", "Whisky Drinkin' Woman"],
#        dtype='<U661'),
#  array(['95.3012521363801', "['Opeth']", 'Bleak'], dtype='<U661'),
#  array(['95.30118703784132', "['Charles Mingus']", 'Love Chant'],
#        dtype='<U661'),
#  array(['95.30096849329675', "['Iration']", 'Dream'], dtype='<U661'),
#  array(['95.30093276762003', "['Suicidal Tendencies']",
#         'How Will I Laugh Tomorrow'], dtype='<U661'),
#  array(['95.30073534175293', "['Jethro Tull']", 'Aqualung'], dtype='<U661'),
#  array(['95.30068471862354', "['Sample Rain Library']", 'Dark Rain Sound'],
#        dtype='<U661'),
#  array(['95.30060160416286', "['Rain Sounds']", 'White Noise'],
#        dtype='<U661'),
#  array(['95.30055987675775', "['Electric Wizard']", 'Funeralopolis'],
#        dtype='<U661'),
#  array(['95.30045110417478', "['Brian Eno']", '1/1 - Remastered 2004'],
#        dtype='<U661'),
#  array(['95.30036024508348', "['France Joli']",
#         'Gonna Get Over You - 12" Mix'], dtype='<U661'),
#  array(['95.30035807761737', "['DMX']", "Slippin'"], dtype='<U661'),
#  array(['95.30033802303376', "['Albert King']", 'Night Stomp - Live'],
#        dtype='<U661'),
#  array(['95.30032811693634',
#         "['Johannes Brahms', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'I. Allegro non troppo'], dtype='<U661'),
#  array(['95.30009156787169', "['Nightmares On Wax']", 'Stars'],
#        dtype='<U661'),
#  array(['95.30001667132198', "['Granular']", 'Pink Noise - BP 240 hz'],
#        dtype='<U661'),
#  array(['95.29947247168593', "['Bob Marley & The Wailers']",
#         'Keep On Moving - Dub'], dtype='<U661'),
#  array(['95.29946545239777', "['Kevin Morby']", 'Harlem River'],
#        dtype='<U661'),
#  array(['95.29945152483782', "['Danza Invisible']", 'Sin aliento, 1984'],
#        dtype='<U661'),
#  array(['95.29943903378918', "['Marvin Gaye']", 'Is That Enough'],
#        dtype='<U661'),
#  array(['95.29941086327693',
#         "['Ralph Vaughan Williams', 'Iona Brown', 'Academy of St. Martin in the Fields', 'Sir Neville Marriner']",
#         'The Lark Ascending'], dtype='<U661'),
#  array(['95.29933543471037', "['Sade']", 'Soldier of Love'], dtype='<U661'),
#  array(['95.29922134688056', "['André Breton', 'André Parinaud']",
#         "De la fin de Dada au premier manifeste surréaliste: activités expérimentales. Robert Desnos / L'aventure surréaliste"],
#        dtype='<U661'),
#  array(['95.29916021121913', "['Cynthia']", 'Change On Me'], dtype='<U661'),
#  array(['95.29894566372435', "['Pink Floyd']", 'Money - Live'],
#        dtype='<U661'),
#  array(['95.29864515142211', "['Pat Benatar']", 'Love Is A Battlefield'],
#        dtype='<U661'),
#  array(['95.29849044343203', "['Foals']", 'Spanish Sahara'], dtype='<U661'),
#  array(['95.2984523221089', "['Stevie Wonder']",
#         "Master Blaster (Jammin')"], dtype='<U661'),
#  array(['95.29838166819161', "['Change']", 'Searching'], dtype='<U661'),
#  array(['95.29836093596282', "['The String Cheese Incident']",
#         'This Must Be the Place (Naive Melody)'], dtype='<U661'),
#  array(['95.29823401548614',
#         "['Ludwig van Beethoven', 'Karl Böhm', 'Elisabeth Höngen', 'Josef Herrmann', 'Margarete Teschemacher', 'Staatsopernchor Dresden', 'Torsten Ralf', 'Staatskapelle Dresden']",
#         'Beethoven: Symphony No. 9 in D Minor, Op. 125 "Choral": IV. Presto - "O Freunde, nicht diese Töne!" (Ode to Joy)'],
#        dtype='<U661'),
#  array(['95.29811484934264', "['The Rain Library']", 'Monsun Rain Fall'],
#        dtype='<U661'),
#  array(['95.29809516130096', "['David Bowie']",
#         "Let's Dance - 2018 Remaster"], dtype='<U661'),
#  array(['95.29805558451896', "['Eric Clapton', 'John Jansen']",
#         'I Shot The Sheriff - Live Version'], dtype='<U661'),
#  array(['95.29802032483846',
#         "['Dele Sosimi, Sam Duckworth, The Goldsmith Vocal Ensemble & ESKA']",
#         'Water No Get Enemy'], dtype='<U661'),
#  array(['95.29796444235004', '["Gov\'t Mule"]', 'Soulshine'], dtype='<U661'),
#  array(['95.2979480257897', "['Zapp']", 'Heartbreaker (Pt. I, Pt. II)'],
#        dtype='<U661'),
#  array(['95.29789646014916', "['Tiroro']", 'Best Drummer in Haiti'],
#        dtype='<U661'),
#  array(['95.29752692529338', "['Fela Kuti & The Africa 70']",
#         'Egbe Mi O (Carry Me) - feat. Ginger Baker'], dtype='<U661'),
#  array(['95.29736749005527', "['King Crimson']",
#         'Epitaph - Including "March for No Reason" and "Tomorrow and Tomorrow"'],
#        dtype='<U661'),
#  array(['95.2973573490466', "['David Bowie']",
#         'Sweet Thing/Candidate/Sweet Thing - Live; 2005 Mix; 2016 Remaster'],
#        dtype='<U661'),
#  array(['95.29730104577784', "['Bob Marley & The Wailers']",
#         'Punky Reggae Party - Dub / Jamaican 12" Version'], dtype='<U661'),
#  array(['95.297191015226', "['Steve Winwood']", 'Freedom Overspill'],
#        dtype='<U661'),
#  array(['95.29712081668941', "['Wishbone Ash']", 'Phoenix'], dtype='<U661'),
#  array(['95.29704718102013', "['Franklin Delano Roosevelt']",
#         'On the war with Japan - 12 09 1941'], dtype='<U661'),
#  array(['95.2969644419811', "['Erykah Badu']", 'Green Eyes'], dtype='<U661'),
#  array(['95.2969292237374', "['Bob Marley & The Wailers']",
#         'Punky Reggae Party'], dtype='<U661'),
#  array(['95.29679169183976', "['The Time']", '777-9311'], dtype='<U661'),
#  array(['95.2967762240138', "['Drop Nineteens']", 'Kick The Tragedy'],
#        dtype='<U661'),
#  array(['95.296660206901', "['Marillion']",
#         'Forgotten Sons - 1997 Remaster'], dtype='<U661'),
#  array(['95.2965913481103', "['Tesla']", 'Song And Emotion'], dtype='<U661'),
#  array(['95.29649535392782', "['Led Zeppelin']",
#         'In My Time of Dying - 1990 Remaster'], dtype='<U661'),
#  array(['95.29649463631947', "['Stevie Ray Vaughan']",
#         'Life Without You - Live at Montreux Casino, Montreux, Switzerland - July 1985'],
#        dtype='<U661'),
#  array(['95.29645120920358', "['King Crimson']", 'The Devils Triangle'],
#        dtype='<U661'),
#  array(['95.29645062334956', "['Childish Gambino', 'Ariana Grande']",
#         'Time (feat. Ariana Grande)'], dtype='<U661'),
#  array(['95.29636318992897', "['Mississippi Mass Choir']",
#         'Near The Cross-Trad. Arrangement'], dtype='<U661'),
#  array(['95.29606697549214', "['This Will Destroy You']",
#         'The Mighty Rio Grande'], dtype='<U661'),
#  array(['95.29588994408493', "['Sting']", 'Shadows In The Rain'],
#        dtype='<U661'),
#  array(['95.29581881951734', "['Renaissance']", 'Can You Understand'],
#        dtype='<U661'),
#  array(['95.29558622962236', "['UB40']", 'Red Red Wine'], dtype='<U661'),
#  array(['95.29551104767344', "['Phish']", 'Stash'], dtype='<U661'),
#  array(['95.29528055349526', "['Bruce Springsteen']",
#         'New York City Serenade'], dtype='<U661'),
#  array(['95.29519785105092', "['Gwen McCrae']", 'Keep the Fire Burning'],
#        dtype='<U661'),
#  array(['95.295060623988', "['Airiel']", 'In Your Room'], dtype='<U661'),
#  array(['95.29492615288959', "['King Crimson']", 'In The Wake Of Poseidon'],
#        dtype='<U661'),
#  array(['95.29481424570103', "['Explosions In The Sky']",
#         'First Breath After Coma'], dtype='<U661'),
#  array(['95.29463224933306', "['Fern Kinney']", 'Groove Me'], dtype='<U661'),
#  array(['95.29457016665773', "['The Stooges']",
#         'We Will Fall - 2019 Remaster'], dtype='<U661'),
#  array(['95.29453659023382', "['Iron Maiden']",
#         'Rime of the Ancient Mariner - 2015 Remaster'], dtype='<U661'),
#  array(['95.29452313712635', "['Lime']", 'Come and Get Your Love'],
#        dtype='<U661'),
#  array(['95.29446440252748', "['Bryan Adams']", 'Cuts Like A Knife'],
#        dtype='<U661'),
#  array(['95.29441820980186', "['Cameo']", 'Back And Forth'], dtype='<U661'),
#  array(['95.29421040418474', "['Grover Washington, Jr.']", "Loran's Dance"],
#        dtype='<U661'),
#  array(['95.29418227088634', "['François Mauriac', 'Jean Amrouche']",
#         'Thérèse Desqueyroux'], dtype='<U661'),
#  array(['95.29414579583018',
#         "['Benjamin Britten', 'Royal Philharmonic Orchestra', 'Robin Stapleton']",
#         "Young Person's Guide To The Orchestra"], dtype='<U661'),
#  array(['95.29413907632465', "['Gary Numan']", 'Conversation'],
#        dtype='<U661'),
#  array(['95.2940223160294', "['SNAP!']", 'Ooops Up'], dtype='<U661'),
#  array(['95.29396554133454', "['Rebelution']", 'Heart Like a Lion'],
#        dtype='<U661'),
#  array(['95.29393478070602',
#         "['Ludwig van Beethoven', 'Joseph Szigeti', 'Bruno Walter', 'New York Philharmonic']",
#         'Violin Concerto in D Major, Op. 61: I. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['95.29392130708986', "['Mighty Clouds Of Joy']", 'Pray for Me'],
#        dtype='<U661'),
#  array(['95.29392092242026', "['Heart']", 'Straight On'], dtype='<U661'),
#  array(['95.29389979344721', "['Charles Mingus']",
#         'Better Git It in Your Soul'], dtype='<U661'),
#  array(['95.29383706812015', "['The Beatles']",
#         'Hey Jude - Remastered 2015'], dtype='<U661'),
#  array(['95.29381199970426', "['King Crimson']", 'Pictures Of A City'],
#        dtype='<U661'),
#  array(['95.29373105155527',
#         "['Moonshine Bandits', 'Durwood Black', 'Redneck Souljers', 'Bubba Sparxxx', 'Demun Jones', 'The Lacs', 'D. Thrash', 'Moccasin Creek', 'Lenny Cooper']",
#         'Outback (Extended Remix)'], dtype='<U661'),
#  array(['95.29372208503388', "['Buzzcocks']",
#         "Why Can't I Touch It? - 2001 Remastered Version"], dtype='<U661'),
#  array(['95.29369639764923', "['Miles Davis']", 'So What - Live'],
#        dtype='<U661'),
#  array(['95.29357749777758', "['Groove Theory']", 'Tell Me'], dtype='<U661'),
#  array(['95.29351367583929', "['LCD Soundsystem']", 'Losing My Edge'],
#        dtype='<U661'),
#  array(['95.29346293807549', "['Scorpions']", 'Still Loving You'],
#        dtype='<U661'),
#  array(['95.2934420172159', "['Elevation Worship', 'Brandon Lake']",
#         'Graves Into Gardens (Live)'], dtype='<U661'),
#  array(['95.29342085691422', "['Little River Band']",
#         "It's A Long Way There - Album Version / 2002 Digital Remaster"],
#        dtype='<U661'),
#  array(['95.29341879124365', "['KSI', 'Swarmz', 'Tion Wayne']",
#         'Houdini (feat. Swarmz & Tion Wayne)'], dtype='<U661'),
#  array(['95.2933343894528', "['Metallica']",
#         '...And Justice for All (Remastered)'], dtype='<U661'),
#  array(['95.29322930459925', "['Pink Floyd']",
#         'Careful with That Axe, Eugene - Live'], dtype='<U661'),
#  array(['95.29319021396134', "['Metallica']",
#         'The Frayed Ends of Sanity (Remastered)'], dtype='<U661'),
#  array(['95.29314112433342', "['The Beatles']",
#         "I Want You (She's So Heavy) - Remastered 2009"], dtype='<U661'),
#  array(['95.29312652340052', "['Kansas']", 'Song For America'],
#        dtype='<U661'),
#  array(['95.29304426170094', "['TOOL']", 'The Patient'], dtype='<U661'),
#  array(['95.2929405450396', "['The Allman Brothers Band']",
#         'Back Where It All Begins'], dtype='<U661'),
#  array(['95.29286834588765', "['Pankaj Mullick']", 'Mahaprasthaner Pathe'],
#        dtype='<U661'),
#  array(['95.29282007075787', "['Cross Canadian Ragweed']",
#         'Boys From Oklahoma'], dtype='<U661'),
#  array(['95.29273491658518', "['Harry Chapin']",
#         '30,000 Pounds of Bananas - Live 1975 Version'], dtype='<U661'),
#  array(['95.29258404856', "['Foghat']", 'Slow Ride'], dtype='<U661'),
#  array(['95.29239931133225', "['Albert King']",
#         "I'll Play The Blues For You - Album Version - (Parts 1 & 2)"],
#        dtype='<U661'),
#  array(['95.29225962949668', "['Wishbone Ash']", 'Persephone'],
#        dtype='<U661'),
#  array(['95.29223281942309', "['Parliament']", 'Mr. Wiggles'],
#        dtype='<U661'),
#  array(['95.29218425152393', "['Weather Report']",
#         'Nubian Sundance - Live'], dtype='<U661'),
#  array(['95.29209894923129', "['Spirit']", 'Like A Rolling Stone'],
#        dtype='<U661'),
#  array(['95.29206075317501', "['Loggins & Messina']",
#         'Angry Eyes - Single Version'], dtype='<U661'),
#  array(['95.29203675849809', "['UB40']", 'Rat In Mi Kitchen'],
#        dtype='<U661'),
#  array(['95.29192016113996', "['Talk Talk']", 'Give It Up - 1997 Remaster'],
#        dtype='<U661'),
#  array(['95.2918613500538', "['Prince']",
#         'All the Critics Love U in New York'], dtype='<U661'),
#  array(['95.29183751411475', "['Kaleidoscope', 'Frank Tirado']",
#         'Once Upon a Time There Was a World'], dtype='<U661'),
#  array(['95.29181584247645', "['Prince']", 'Private Joy'], dtype='<U661'),
#  array(['95.29176499407347', '["Her\'s"]', 'Cool with You'], dtype='<U661'),
#  array(['95.29158832758854', "['Loleatta Holloway']",
#         'Love Sensation - 12" Mix; 2012 - Remaster'], dtype='<U661'),
#  array(['95.29140988793979', "['Lonnie Mack']",
#         'Camp Washington Chile/If You Have To Know'], dtype='<U661'),
#  array(['95.29140567230762', "['Danilo Montero']", 'Salmo 84'],
#        dtype='<U661'),
#  array(['95.29136470325548', "['Yasuaki Shimizu']", 'Umi No Ue Kara'],
#        dtype='<U661'),
#  array(['95.29127617489259', "['CHIC']", 'Everybody Dance - 2018 Remaster'],
#        dtype='<U661'),
#  array(['95.29125240084171', "['Mother Nature Sound FX']",
#         'Pouring Rain & Thunder'], dtype='<U661'),
#  array(['95.29111559280025', "['Led Zeppelin']",
#         'Carouselambra - 2012 Remaster'], dtype='<U661'),
#  array(['95.29110566593405', "['James Gang']", 'Stop'], dtype='<U661'),
#  array(['95.2909558645731', "['Bob Marley & The Wailers']",
#         'Is This Love - Live At The Pavillon De Paris, 1977'],
#        dtype='<U661'),
#  array(['95.2909484954394', "['The Temptations']",
#         "Papa Was A Rollin' Stone"], dtype='<U661'),
#  array(['95.29092161231009', "['Forest FX']", 'Camping Rain'],
#        dtype='<U661'),
#  array(['95.29081240756295', "['Foo Fighters']",
#         'The Sky Is A Neighborhood'], dtype='<U661'),
#  array(['95.29065143476755', "['Nick Cave & The Bad Seeds']",
#         'Loverman - 2011 Remastered Version'], dtype='<U661'),
#  array(['95.29060618953744', "['Pink Floyd']", 'Money'], dtype='<U661'),
#  array(['95.29057717442669', "['Miles Davis']",
#         'Miles Runs the Voodoo Down'], dtype='<U661'),
#  array(['95.29050858460815', "['Lime']", 'Angel Eyes'], dtype='<U661'),
#  array(['95.2904743062804', "['Genesis']",
#         'Tonight, Tonight, Tonight - 2007 Remaster'], dtype='<U661'),
#  array(['95.29046221642417',
#         "['Eric Clapton', 'Jon Astley', 'Andy Macpherson']",
#         'Badge - Live At Hammersmith'], dtype='<U661'),
#  array(['95.29028799612267', "['Pat Benatar']", 'Love Is A Battlefield'],
#        dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
