# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import oauth2
import pandas as pd

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'
username = 'Arda Akça Büyük'

# %%
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/41GuZcammIkupMPKH2OJ6I'},
#     'href': 'https://api.spotify.com/v1/albums/41GuZcammIkupMPKH2OJ6I',
#     'id': '41GuZcammIkupMPKH2OJ6I',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273072e9faef2ef7b6db63834a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02072e9faef2ef7b6db63834a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851072e9faef2ef7b6db63834a3',
#       'width': 64}],
#     'name': 'ASTROWORLD',
#     'release_date': '2018-08-03',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:41GuZcammIkupMPKH2OJ6I'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 198408,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM11806670'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/27a1mYSG5tYg7dmEjWBcmL'},
#    'href': 'https://api.spotify.com/v1/tracks/27a1mYSG5tYg7dmEjWBcmL',
#    'id': '27a1mYSG5tYg7dmEjWBcmL',
#    'is_local': False,
#    'name': "CAN'T SAY",
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5cf7091a2bbb9811838dcba614b8dd4b57a17447?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:27a1mYSG5tYg7dmEjWBcmL'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/41GuZcammIkupMPKH2OJ6I'},
#     'href': 'https://api.spotify.com/v1/albums/41GuZcammIkupMPKH2OJ6I',
#     'id': '41GuZcammIkupMPKH2OJ6I',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273072e9faef2ef7b6db63834a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02072e9faef2ef7b6db63834a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851072e9faef2ef7b6db63834a3',
#       'width': 64}],
#     'name': 'ASTROWORLD',
#     'release_date': '2018-08-03',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:41GuZcammIkupMPKH2OJ6I'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 270714,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM11806658'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7wBJfHzpfI3032CSD7CE2m'},
#    'href': 'https://api.spotify.com/v1/tracks/7wBJfHzpfI3032CSD7CE2m',
#    'id': '7wBJfHzpfI3032CSD7CE2m',
#    'is_local': False,
#    'name': 'STARGAZING',
#    'popularity': 80,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d2d23f9ea674dffde91d99783732b092655ccaf6?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7wBJfHzpfI3032CSD7CE2m'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#       'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#       'id': '0eDvMgVFoNV3TpwtrVCoTj',
#       'name': 'Pop Smoke',
#       'type': 'artist',
#       'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2MDU46hcBn3u94s46BOSdv'},
#     'href': 'https://api.spotify.com/v1/albums/2MDU46hcBn3u94s46BOSdv',
#     'id': '2MDU46hcBn3u94s46BOSdv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27346e1307c35579c3483ea7b03',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0246e1307c35579c3483ea7b03',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485146e1307c35579c3483ea7b03',
#       'width': 64}],
#     'name': 'Shoot For The Stars Aim For The Moon (Deluxe)',
#     'release_date': '2020-07-20',
#     'release_date_precision': 'day',
#     'total_tracks': 34,
#     'type': 'album',
#     'uri': 'spotify:album:2MDU46hcBn3u94s46BOSdv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#      'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#      'id': '0eDvMgVFoNV3TpwtrVCoTj',
#      'name': 'Pop Smoke',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jGMq4yGs7aQzuGsMgVgZR'},
#      'href': 'https://api.spotify.com/v1/artists/6jGMq4yGs7aQzuGsMgVgZR',
#      'id': '6jGMq4yGs7aQzuGsMgVgZR',
#      'name': 'Lil Tjay',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jGMq4yGs7aQzuGsMgVgZR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 213333,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72013632'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3mZNztgWFsvm9wfcqSOdKg'},
#    'href': 'https://api.spotify.com/v1/tracks/3mZNztgWFsvm9wfcqSOdKg',
#    'id': '3mZNztgWFsvm9wfcqSOdKg',
#    'is_local': False,
#    'name': 'Mood Swings (feat. Lil Tjay)',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f5c575df3e9d033c4cff22ccf754401cf54fda75?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:3mZNztgWFsvm9wfcqSOdKg'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/41GuZcammIkupMPKH2OJ6I'},
#     'href': 'https://api.spotify.com/v1/albums/41GuZcammIkupMPKH2OJ6I',
#     'id': '41GuZcammIkupMPKH2OJ6I',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273072e9faef2ef7b6db63834a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02072e9faef2ef7b6db63834a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851072e9faef2ef7b6db63834a3',
#       'width': 64}],
#     'name': 'ASTROWORLD',
#     'release_date': '2018-08-03',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:41GuZcammIkupMPKH2OJ6I'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 190557,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM11704799'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2cYqizR4lgvp4Qu6IQ3qGN'},
#    'href': 'https://api.spotify.com/v1/tracks/2cYqizR4lgvp4Qu6IQ3qGN',
#    'id': '2cYqizR4lgvp4Qu6IQ3qGN',
#    'is_local': False,
#    'name': 'BUTTERFLY EFFECT',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ca4f131887eae894020e48ea809af1186c95f542?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:2cYqizR4lgvp4Qu6IQ3qGN'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#       'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#       'id': '1RyvyyTE3xzB2ZywiAwp0i',
#       'name': 'Future',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#       'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#       'id': '50co4Is1HCEo8bhOyUWKpn',
#       'name': 'Young Thug',
#       'type': 'artist',
#       'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6k3hqPsGKPCSyBmmvCXd7B'},
#     'href': 'https://api.spotify.com/v1/albums/6k3hqPsGKPCSyBmmvCXd7B',
#     'id': '6k3hqPsGKPCSyBmmvCXd7B',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27387d2b3794f4e86af5e774b1b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0287d2b3794f4e86af5e774b1b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485187d2b3794f4e86af5e774b1b',
#       'width': 64}],
#     'name': 'FRANCHISE (feat. Future, Young Thug & M.I.A.) [REMIX]',
#     'release_date': '2020-10-07',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:6k3hqPsGKPCSyBmmvCXd7B'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#      'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#      'id': '1RyvyyTE3xzB2ZywiAwp0i',
#      'name': 'Future',
#      'type': 'artist',
#      'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#      'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#      'id': '50co4Is1HCEo8bhOyUWKpn',
#      'name': 'Young Thug',
#      'type': 'artist',
#      'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0QJIPDAEDILuo8AIq3pMuU'},
#      'href': 'https://api.spotify.com/v1/artists/0QJIPDAEDILuo8AIq3pMuU',
#      'id': '0QJIPDAEDILuo8AIq3pMuU',
#      'name': 'M.I.A.',
#      'type': 'artist',
#      'uri': 'spotify:artist:0QJIPDAEDILuo8AIq3pMuU'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 207394,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM12006051'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6qUabsNxudatEFedWGHoDh'},
#    'href': 'https://api.spotify.com/v1/tracks/6qUabsNxudatEFedWGHoDh',
#    'id': '6qUabsNxudatEFedWGHoDh',
#    'is_local': False,
#    'name': 'FRANCHISE (feat. Future, Young Thug & M.I.A.) - REMIX',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/76a6b3d6ed77e39a0b45285d643ffc3160bc1180?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6qUabsNxudatEFedWGHoDh'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2y1VzMKAa5nmfXKtJL9jnj'},
#       'href': 'https://api.spotify.com/v1/artists/2y1VzMKAa5nmfXKtJL9jnj',
#       'id': '2y1VzMKAa5nmfXKtJL9jnj',
#       'name': 'Murda',
#       'type': 'artist',
#       'uri': 'spotify:artist:2y1VzMKAa5nmfXKtJL9jnj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LnJKrtFnTEGdbWQ2riWCL'},
#       'href': 'https://api.spotify.com/v1/artists/6LnJKrtFnTEGdbWQ2riWCL',
#       'id': '6LnJKrtFnTEGdbWQ2riWCL',
#       'name': 'Ezhel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LnJKrtFnTEGdbWQ2riWCL'}],
#     'available_markets': ['TR'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1mDlX2DdJbX7FzqWTpCvIl'},
#     'href': 'https://api.spotify.com/v1/albums/1mDlX2DdJbX7FzqWTpCvIl',
#     'id': '1mDlX2DdJbX7FzqWTpCvIl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27360a0a42aa8cf946c88f54dec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0260a0a42aa8cf946c88f54dec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485160a0a42aa8cf946c88f54dec',
#       'width': 64}],
#     'name': 'Made In Turkey',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:1mDlX2DdJbX7FzqWTpCvIl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2y1VzMKAa5nmfXKtJL9jnj'},
#      'href': 'https://api.spotify.com/v1/artists/2y1VzMKAa5nmfXKtJL9jnj',
#      'id': '2y1VzMKAa5nmfXKtJL9jnj',
#      'name': 'Murda',
#      'type': 'artist',
#      'uri': 'spotify:artist:2y1VzMKAa5nmfXKtJL9jnj'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LnJKrtFnTEGdbWQ2riWCL'},
#      'href': 'https://api.spotify.com/v1/artists/6LnJKrtFnTEGdbWQ2riWCL',
#      'id': '6LnJKrtFnTEGdbWQ2riWCL',
#      'name': 'Ezhel',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LnJKrtFnTEGdbWQ2riWCL'}],
#    'available_markets': ['TR'],
#    'disc_number': 1,
#    'duration_ms': 211009,
#    'explicit': True,
#    'external_ids': {'isrc': 'NLG662000544'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3K502RIh0pAHAQUvVQ2pf9'},
#    'href': 'https://api.spotify.com/v1/tracks/3K502RIh0pAHAQUvVQ2pf9',
#    'id': '3K502RIh0pAHAQUvVQ2pf9',
#    'is_local': False,
#    'name': 'Anadolu Flex',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/dde769e62600f12ec08dfa54012f3f3e2a69783c?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3K502RIh0pAHAQUvVQ2pf9'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#       'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#       'id': '4MCBfE4596Uoi2O4DtmEMz',
#       'name': 'Juice WRLD',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6n9DKpOxwifT5hOXtgLZSL'},
#     'href': 'https://api.spotify.com/v1/albums/6n9DKpOxwifT5hOXtgLZSL',
#     'id': '6n9DKpOxwifT5hOXtgLZSL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733e0698e4ae5ffb82a005aeeb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023e0698e4ae5ffb82a005aeeb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513e0698e4ae5ffb82a005aeeb',
#       'width': 64}],
#     'name': 'Legends Never Die',
#     'release_date': '2020-07-10',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:6n9DKpOxwifT5hOXtgLZSL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#      'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#      'id': '4MCBfE4596Uoi2O4DtmEMz',
#      'name': 'Juice WRLD',
#      'type': 'artist',
#      'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 196180,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12002597'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6wQlQrTY5mVS8EGaFZVwVF'},
#    'href': 'https://api.spotify.com/v1/tracks/6wQlQrTY5mVS8EGaFZVwVF',
#    'id': '6wQlQrTY5mVS8EGaFZVwVF',
#    'is_local': False,
#    'name': 'Smile (with The Weeknd)',
#    'popularity': 85,
#    'preview_url': 'https://p.scdn.co/mp3-preview/80d78610eb5ce12c3f51c4a09e078800611ed28e?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:6wQlQrTY5mVS8EGaFZVwVF'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/41GuZcammIkupMPKH2OJ6I'},
#     'href': 'https://api.spotify.com/v1/albums/41GuZcammIkupMPKH2OJ6I',
#     'id': '41GuZcammIkupMPKH2OJ6I',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273072e9faef2ef7b6db63834a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02072e9faef2ef7b6db63834a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851072e9faef2ef7b6db63834a3',
#       'width': 64}],
#     'name': 'ASTROWORLD',
#     'release_date': '2018-08-03',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:41GuZcammIkupMPKH2OJ6I'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 312820,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM11806660'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2xLMifQCjDGFmkHkpNLD9h'},
#    'href': 'https://api.spotify.com/v1/tracks/2xLMifQCjDGFmkHkpNLD9h',
#    'id': '2xLMifQCjDGFmkHkpNLD9h',
#    'is_local': False,
#    'name': 'SICKO MODE',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1c3c01c64477b356e28a652b6447f4ef96689a71?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2xLMifQCjDGFmkHkpNLD9h'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7A8S43ryYdbWpJKeHRZRcq'},
#       'href': 'https://api.spotify.com/v1/artists/7A8S43ryYdbWpJKeHRZRcq',
#       'id': '7A8S43ryYdbWpJKeHRZRcq',
#       'name': 'JACKBOYS',
#       'type': 'artist',
#       'uri': 'spotify:artist:7A8S43ryYdbWpJKeHRZRcq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Sf8GsXG32t0jNrX11xqWx'},
#     'href': 'https://api.spotify.com/v1/albums/1Sf8GsXG32t0jNrX11xqWx',
#     'id': '1Sf8GsXG32t0jNrX11xqWx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dfc2f59568272de50a257f2f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dfc2f59568272de50a257f2f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dfc2f59568272de50a257f2f',
#       'width': 64}],
#     'name': 'JACKBOYS',
#     'release_date': '2019-12-27',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:1Sf8GsXG32t0jNrX11xqWx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7A8S43ryYdbWpJKeHRZRcq'},
#      'href': 'https://api.spotify.com/v1/artists/7A8S43ryYdbWpJKeHRZRcq',
#      'id': '7A8S43ryYdbWpJKeHRZRcq',
#      'name': 'JACKBOYS',
#      'type': 'artist',
#      'uri': 'spotify:artist:7A8S43ryYdbWpJKeHRZRcq'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#      'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#      'id': '0eDvMgVFoNV3TpwtrVCoTj',
#      'name': 'Pop Smoke',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 181144,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM11915307'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/40mjsnRjCpycdUw3xhS20g'},
#    'href': 'https://api.spotify.com/v1/tracks/40mjsnRjCpycdUw3xhS20g',
#    'id': '40mjsnRjCpycdUw3xhS20g',
#    'is_local': False,
#    'name': 'GATTI',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/36019bb0dcbf67bb92506ac9ec877e104cffc67d?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:40mjsnRjCpycdUw3xhS20g'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pVRwX5ZQR7hfJ18w8ZYkl'},
#       'href': 'https://api.spotify.com/v1/artists/5pVRwX5ZQR7hfJ18w8ZYkl',
#       'id': '5pVRwX5ZQR7hfJ18w8ZYkl',
#       'name': 'Ufo361',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pVRwX5ZQR7hfJ18w8ZYkl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4xPKZiJA8wUMx4n58xhZ5C'},
#     'href': 'https://api.spotify.com/v1/albums/4xPKZiJA8wUMx4n58xhZ5C',
#     'id': '4xPKZiJA8wUMx4n58xhZ5C',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c0e7f8d5b89ea5613dbb267f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c0e7f8d5b89ea5613dbb267f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c0e7f8d5b89ea5613dbb267f',
#       'width': 64}],
#     'name': 'WAVE',
#     'release_date': '2019-08-09',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:4xPKZiJA8wUMx4n58xhZ5C'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pVRwX5ZQR7hfJ18w8ZYkl'},
#      'href': 'https://api.spotify.com/v1/artists/5pVRwX5ZQR7hfJ18w8ZYkl',
#      'id': '5pVRwX5ZQR7hfJ18w8ZYkl',
#      'name': 'Ufo361',
#      'type': 'artist',
#      'uri': 'spotify:artist:5pVRwX5ZQR7hfJ18w8ZYkl'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5p7mWeX4RlvqBCxylfiXdE'},
#      'href': 'https://api.spotify.com/v1/artists/5p7mWeX4RlvqBCxylfiXdE',
#      'id': '5p7mWeX4RlvqBCxylfiXdE',
#      'name': 'KC Rebell',
#      'type': 'artist',
#      'uri': 'spotify:artist:5p7mWeX4RlvqBCxylfiXdE'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 182330,
#    'explicit': True,
#    'external_ids': {'isrc': 'DEQ021905560'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/25J2bLknZoRzHjAO2NlfJH'},
#    'href': 'https://api.spotify.com/v1/tracks/25J2bLknZoRzHjAO2NlfJH',
#    'id': '25J2bLknZoRzHjAO2NlfJH',
#    'is_local': False,
#    'name': 'Swiss Made',
#    'popularity': 46,
#    'preview_url': 'https://p.scdn.co/mp3-preview/26da351217daa88a6ba0881f2240895bd375e903?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:25J2bLknZoRzHjAO2NlfJH'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#       'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#       'id': '0eDvMgVFoNV3TpwtrVCoTj',
#       'name': 'Pop Smoke',
#       'type': 'artist',
#       'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6d1vGZsr6Uy3h9IigBpPAf'},
#     'href': 'https://api.spotify.com/v1/albums/6d1vGZsr6Uy3h9IigBpPAf',
#     'id': '6d1vGZsr6Uy3h9IigBpPAf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738fe5d04b06aff90f9fe796f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028fe5d04b06aff90f9fe796f5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518fe5d04b06aff90f9fe796f5',
#       'width': 64}],
#     'name': 'Meet The Woo',
#     'release_date': '2019-07-26',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6d1vGZsr6Uy3h9IigBpPAf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#      'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#      'id': '0eDvMgVFoNV3TpwtrVCoTj',
#      'name': 'Pop Smoke',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 216386,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71914275'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/79s5XnCN4TJKTVMSmOx8Ep'},
#    'href': 'https://api.spotify.com/v1/tracks/79s5XnCN4TJKTVMSmOx8Ep',
#    'id': '79s5XnCN4TJKTVMSmOx8Ep',
#    'is_local': False,
#    'name': 'Dior',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/068c8d7838a9819067c5439475060c4883e17ea5?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:79s5XnCN4TJKTVMSmOx8Ep'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Sjj30aHCmKcM9SdVX7PBK'},
#       'href': 'https://api.spotify.com/v1/artists/5Sjj30aHCmKcM9SdVX7PBK',
#       'id': '5Sjj30aHCmKcM9SdVX7PBK',
#       'name': 'Gringo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Sjj30aHCmKcM9SdVX7PBK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LnJKrtFnTEGdbWQ2riWCL'},
#       'href': 'https://api.spotify.com/v1/artists/6LnJKrtFnTEGdbWQ2riWCL',
#       'id': '6LnJKrtFnTEGdbWQ2riWCL',
#       'name': 'Ezhel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LnJKrtFnTEGdbWQ2riWCL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5mPOOZTRDsRf0iIXixzfgn'},
#       'href': 'https://api.spotify.com/v1/artists/5mPOOZTRDsRf0iIXixzfgn',
#       'id': '5mPOOZTRDsRf0iIXixzfgn',
#       'name': 'Yung Kafa & Kücük Efendi',
#       'type': 'artist',
#       'uri': 'spotify:artist:5mPOOZTRDsRf0iIXixzfgn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0kKpPlButvxWTyrhwz8aEf'},
#     'href': 'https://api.spotify.com/v1/albums/0kKpPlButvxWTyrhwz8aEf',
#     'id': '0kKpPlButvxWTyrhwz8aEf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dc145f143f2cfc3e970df428',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dc145f143f2cfc3e970df428',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dc145f143f2cfc3e970df428',
#       'width': 64}],
#     'name': 'Summer of My Life',
#     'release_date': '2019-07-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0kKpPlButvxWTyrhwz8aEf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Sjj30aHCmKcM9SdVX7PBK'},
#      'href': 'https://api.spotify.com/v1/artists/5Sjj30aHCmKcM9SdVX7PBK',
#      'id': '5Sjj30aHCmKcM9SdVX7PBK',
#      'name': 'Gringo',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Sjj30aHCmKcM9SdVX7PBK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LnJKrtFnTEGdbWQ2riWCL'},
#      'href': 'https://api.spotify.com/v1/artists/6LnJKrtFnTEGdbWQ2riWCL',
#      'id': '6LnJKrtFnTEGdbWQ2riWCL',
#      'name': 'Ezhel',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LnJKrtFnTEGdbWQ2riWCL'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5mPOOZTRDsRf0iIXixzfgn'},
#      'href': 'https://api.spotify.com/v1/artists/5mPOOZTRDsRf0iIXixzfgn',
#      'id': '5mPOOZTRDsRf0iIXixzfgn',
#      'name': 'Yung Kafa & Kücük Efendi',
#      'type': 'artist',
#      'uri': 'spotify:artist:5mPOOZTRDsRf0iIXixzfgn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
# ...
#       'id': '6LnJKrtFnTEGdbWQ2riWCL',
#       'name': 'Ezhel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LnJKrtFnTEGdbWQ2riWCL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5mo701EsMb8GFdF4YL3NG8'},
#     'href': 'https://api.spotify.com/v1/albums/5mo701EsMb8GFdF4YL3NG8',
#     'id': '5mo701EsMb8GFdF4YL3NG8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ecd10eea07796a0edf4fb609',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ecd10eea07796a0edf4fb609',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ecd10eea07796a0edf4fb609',
#       'width': 64}],
#     'name': 'Müptezhel',
#     'release_date': '2017-05-25',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5mo701EsMb8GFdF4YL3NG8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LnJKrtFnTEGdbWQ2riWCL'},
#      'href': 'https://api.spotify.com/v1/artists/6LnJKrtFnTEGdbWQ2riWCL',
#      'id': '6LnJKrtFnTEGdbWQ2riWCL',
#      'name': 'Ezhel',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LnJKrtFnTEGdbWQ2riWCL'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 216010,
#    'explicit': True,
#    'external_ids': {'isrc': 'TCADC1710545'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5CSd3cUlH0b55LSHsqz34g'},
#    'href': 'https://api.spotify.com/v1/tracks/5CSd3cUlH0b55LSHsqz34g',
#    'id': '5CSd3cUlH0b55LSHsqz34g',
#    'is_local': False,
#    'name': 'Hayır',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/280ad50bb90b8daf692096e39d21b68cf261ccb6?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:5CSd3cUlH0b55LSHsqz34g'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NJWI8byqTSqDaJRnqJY2z'},
#       'href': 'https://api.spotify.com/v1/artists/2NJWI8byqTSqDaJRnqJY2z',
#       'id': '2NJWI8byqTSqDaJRnqJY2z',
#       'name': 'KALIM',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NJWI8byqTSqDaJRnqJY2z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/00NqHEsuPC0TG1KItHTuUY'},
#     'href': 'https://api.spotify.com/v1/albums/00NqHEsuPC0TG1KItHTuUY',
#     'id': '00NqHEsuPC0TG1KItHTuUY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738487c2613931c5d3a247387b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028487c2613931c5d3a247387b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518487c2613931c5d3a247387b',
#       'width': 64}],
#     'name': 'NULL AUF HUNDERT',
#     'release_date': '2019-07-04',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:00NqHEsuPC0TG1KItHTuUY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NJWI8byqTSqDaJRnqJY2z'},
#      'href': 'https://api.spotify.com/v1/artists/2NJWI8byqTSqDaJRnqJY2z',
#      'id': '2NJWI8byqTSqDaJRnqJY2z',
#      'name': 'KALIM',
#      'type': 'artist',
#      'uri': 'spotify:artist:2NJWI8byqTSqDaJRnqJY2z'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pVRwX5ZQR7hfJ18w8ZYkl'},
#      'href': 'https://api.spotify.com/v1/artists/5pVRwX5ZQR7hfJ18w8ZYkl',
#      'id': '5pVRwX5ZQR7hfJ18w8ZYkl',
#      'name': 'Ufo361',
#      'type': 'artist',
#      'uri': 'spotify:artist:5pVRwX5ZQR7hfJ18w8ZYkl'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 166285,
#    'explicit': True,
#    'external_ids': {'isrc': 'DEUM71900601'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3RHhQbHs9xrB55eWabBpr1'},
#    'href': 'https://api.spotify.com/v1/tracks/3RHhQbHs9xrB55eWabBpr1',
#    'id': '3RHhQbHs9xrB55eWabBpr1',
#    'is_local': False,
#    'name': 'nie wieder broke',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1fed9d0c0ee8bfc7012db7663a62c8bafdd1b592?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:3RHhQbHs9xrB55eWabBpr1'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3S4AQxtnqGJOtw1k6ZT111'},
#     'href': 'https://api.spotify.com/v1/albums/3S4AQxtnqGJOtw1k6ZT111',
#     'id': '3S4AQxtnqGJOtw1k6ZT111',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e986304881623287fde9a048',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e986304881623287fde9a048',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e986304881623287fde9a048',
#       'width': 64}],
#     'name': 'The Plan (From the Motion Picture "TENET")',
#     'release_date': '2020-08-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3S4AQxtnqGJOtw1k6ZT111'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 185850,
#    'explicit': True,
#    'external_ids': {'isrc': 'USNLR2000855'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/551xyaSJsg8hILXFq9JdST'},
#    'href': 'https://api.spotify.com/v1/tracks/551xyaSJsg8hILXFq9JdST',
#    'id': '551xyaSJsg8hILXFq9JdST',
#    'is_local': False,
#    'name': 'The Plan - From the Motion Picture "TENET"',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4826c6abd8aa2e6bd0d3b4dec3b932bda4bfd538?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:551xyaSJsg8hILXFq9JdST'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#       'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#       'id': '50co4Is1HCEo8bhOyUWKpn',
#       'name': 'Young Thug',
#       'type': 'artist',
#       'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/24jAbLMFzCTlIv3kQ94HwK'},
#     'href': 'https://api.spotify.com/v1/albums/24jAbLMFzCTlIv3kQ94HwK',
#     'id': '24jAbLMFzCTlIv3kQ94HwK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273540db9d6bae7e57baecf8b49',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02540db9d6bae7e57baecf8b49',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851540db9d6bae7e57baecf8b49',
#       'width': 64}],
#     'name': 'So Much Fun (Deluxe)',
#     'release_date': '2019-12-20',
#     'release_date_precision': 'day',
#     'total_tracks': 24,
#     'type': 'album',
#     'uri': 'spotify:album:24jAbLMFzCTlIv3kQ94HwK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#      'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#      'id': '50co4Is1HCEo8bhOyUWKpn',
#      'name': 'Young Thug',
#      'type': 'artist',
#      'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2hlmm7s2ICUX0LVIhVFlZQ'},
#      'href': 'https://api.spotify.com/v1/artists/2hlmm7s2ICUX0LVIhVFlZQ',
#      'id': '2hlmm7s2ICUX0LVIhVFlZQ',
#      'name': 'Gunna',
#      'type': 'artist',
#      'uri': 'spotify:artist:2hlmm7s2ICUX0LVIhVFlZQ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 279906,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21906512'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ea9w8c4ROqiZpJVhfBA3m'},
#    'href': 'https://api.spotify.com/v1/tracks/4ea9w8c4ROqiZpJVhfBA3m',
#    'id': '4ea9w8c4ROqiZpJVhfBA3m',
#    'is_local': False,
#    'name': 'Hot (Remix) [feat. Gunna and Travis Scott]',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/50722f0d4b1c7599518137b486bb42306e20bef8?cid=8c4cb3ef1c0c412181ea69d07b3df0ca',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4ea9w8c4ROqiZpJVhfBA3m'}],
#  'total': 50,
#  'limit': 50,
#  'offset': 0,
#  'previous': None,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=50&offset=0',
#  'next': None}

# %%
track_name = []
track_id = []
artists = []
album = []
duration = []
popularity = []

for i, items in enumerate(results['items']):
    track_name.append(items['name'])
    track_id.append(items['id'])
    artists.append([artist['name'] for artist in items['artists']])
    duration.append(items['duration_ms'])
    album.append(items['album']['name'])
    popularity.append(items['popularity'])

df_favourite = pd.DataFrame({'track_name': track_name,
                            'album': album,
                            'track_id': track_id,
                            'artists': artists,
                            'duration': duration,
                            'popularity': popularity})

df_favourite
# Out:
#                                            track_name  \
# 0                                           CAN'T SAY
# 1                                          STARGAZING
# 2                        Mood Swings (feat. Lil Tjay)
# 3                                    BUTTERFLY EFFECT
# 4   FRANCHISE (feat. Future, Young Thug & M.I.A.) ...
# 5                                        Anadolu Flex
# 6                             Smile (with The Weeknd)
# 7                                          SICKO MODE
# 8                                               GATTI
# 9                                          Swiss Made
# 10                                               Dior
# 11                                  Summer of My Life
# 12                                      Stay High 2.0
# 13                                               SKRR
# 14                                                Opr
# 15              FRANCHISE (feat. Young Thug & M.I.A.)
# 16        Forever (feat. The Hacker & Electric Youth)
# 17                                     Made In Turkey
# 18                               Welcome To The Party
# 19                                            My Life
# 20                                    Blinding Lights
# 21                                            DOPEBOY
# 22                                           Paradies
# 23                Lost in the Fire (feat. The Weeknd)
# 24                                              NC-17
# 25                                             Pahalı
# 26                       War (feat. Lil Tjay) - Bonus
# 27                            90210 (feat. Kacy Hill)
# 28                                           Lemonade
# 29                                     Richard Millie
# 30                    Solitaires (feat. Travis Scott)
# 31                         Turks (feat. Travis Scott)
# 32                                                Koy
# 33                                         goosebumps
# 34                                      Beverly Hills
# 35                         Start Wit Me (feat. Gunna)
# 36                                        Irina Shayk
# 37                                          Obsession
# 38                                        Clandestina
# 39                                       Nur zur Info
# 40                       Still Cold / Pathway Private
# 41                       Oh My Dis Side (feat. Quavo)
# 42                                           Reminder
# 43                                  Sollte nicht sein
# 44                                 HOUSTONFORNICATION
# 45                                          Rich Rich
# 46                                              Hayır
# 47                                   nie wieder broke
# 48         The Plan - From the Motion Picture "TENET"
# 49         Hot (Remix) [feat. Gunna and Travis Scott]
#
#                                                 album                track_id  \
# 0                                          ASTROWORLD  27a1mYSG5tYg7dmEjWBcmL
# 1                                          ASTROWORLD  7wBJfHzpfI3032CSD7CE2m
# 2       Shoot For The Stars Aim For The Moon (Deluxe)  3mZNztgWFsvm9wfcqSOdKg
# 3                                          ASTROWORLD  2cYqizR4lgvp4Qu6IQ3qGN
# 4   FRANCHISE (feat. Future, Young Thug & M.I.A.) ...  6qUabsNxudatEFedWGHoDh
# 5                                      Made In Turkey  3K502RIh0pAHAQUvVQ2pf9
# 6                                   Legends Never Die  6wQlQrTY5mVS8EGaFZVwVF
# 7                                          ASTROWORLD  2xLMifQCjDGFmkHkpNLD9h
# 8                                            JACKBOYS  40mjsnRjCpycdUw3xhS20g
# 9                                                WAVE  25J2bLknZoRzHjAO2NlfJH
# 10                                       Meet The Woo  79s5XnCN4TJKTVMSmOx8Ep
# 11                                  Summer of My Life  7tu0cMhTlTNsjtsJffxgfR
# 12                                                808  6wLwtK3mkAq0zWPpV6QVbF
# 13                                               SKRR  0U9dP3BUlAgq9KkJXOijBH
# 14                                    Conspiracy Pt.2  4aT9Pm5jhQBepwqyyuNbTT
# 15              FRANCHISE (feat. Young Thug & M.I.A.)  4jVBIpuOiMj1crqd8LoCrJ
# 16                                           Hyperion  61aw1V0KLPD4XIjqNsGqo9
# 17                                     Made In Turkey  2hiQGhRewnlcd10bhvszXt
# 18                                       Meet The Woo  0fIffclhgJC5h8AdMMVvkp
# 19                                      RINGOS DESERT  4y78bEIRTzNe2RbGAnX8zU
# 20                                        After Hours  0VjIjW4GlUZAMYd2vXMi3b
# 21                                            DOPEBOY  0KONCbkFfQlOj7SFo4pnFb
# 22                                                VVS  2kx7rcukcL50UysnBiWJxf
# 23                                           Hyperion  2vXKRlJBXyOcvZYTdNeckS
# 24                                         ASTROWORLD  6BJbOXDlgVAXSaq6wYFYT2
# 25                                               DOĞA  3Y4QV5j8Ls5bjUfvihi2yn
# 26                            Meet The Woo 2 (Deluxe)  1wXN2YC8tTGK5J1wOn55TO
# 27                           Rodeo (Expanded Edition)  51EC3I1nQXpec4gDk0mQyP
# 28          Lemonade (feat. Gunna, Don Toliver & NAV)  02kDW379Yfd5PzW5A6vuGt
# 29                                               WAVE  7Dkiyv0M2lxPUc4KojybgP
# 30                                      High Off Life  4kfeRwpq5KUaqTkgi4TbDF
# 31                                              Turks  0lSZh5W0wDeurkGzLYY6hf
# 32                                      Trap Kont 2.5  56UvyKdzqc8RhQzlvp6CH8
# 33                    Birds In The Trap Sing McKnight  6gBFPUFcJLzWGx4lenP6h2
# 34                                                808  42vM3qSh6CIaZLSlzFTZ7f
# 35              Please Excuse Me For Being Antisocial  7A20WnLkjtZU2d7hIB6Ziu
# 36                                               WAVE  6KxCRJ9DzNBVGM3ol0JQ7r
# 37                                              Aleph  7nyprGzLfhdp0zJfa0peji
# 38                                        Clandestina  1GeQpeyZXYJseEjgSZDQc7
# 39                                       Nur zur Info  6Y7ZEVr7lgO8FKGk2vZ2hi
# 40                                 Red Teenage Melody  6oBL8TdQHEO7jeEdqECg37
# 41                           Rodeo (Expanded Edition)  2rMFawCg4BW65jzbwztXAV
# 42                                            Starboy  37F0uwRSrdzkBiuj0D5UHI
# 43                                       Nur Für Dich  5JmXR3MFBuL6CZPKeSFAB1
# 44                                         ASTROWORLD  58TaFP5j5i9swOf584yon2
# 45                                          Rich Rich  3VFT90E0yYjdHSFoGv02us
# 46                                          Müptezhel  5CSd3cUlH0b55LSHsqz34g
# 47                                   NULL AUF HUNDERT  3RHhQbHs9xrB55eWabBpr1
# 48         The Plan (From the Motion Picture "TENET")  551xyaSJsg8hILXFq9JdST
# 49                               So Much Fun (Deluxe)  4ea9w8c4ROqiZpJVhfBA3m
#
#                                         artists  duration  popularity
# 0                                [Travis Scott]    198408          79
# 1                                [Travis Scott]    270714          80
# 2                         [Pop Smoke, Lil Tjay]    213333          68
# 3                                [Travis Scott]    190557          82
# 4    [Travis Scott, Future, Young Thug, M.I.A.]    207394          75
# 5                                [Murda, Ezhel]    211009          70
# 6                      [Juice WRLD, The Weeknd]    196180          85
# 7                                [Travis Scott]    312820          87
# 8           [JACKBOYS, Pop Smoke, Travis Scott]    181144          79
# 9                           [Ufo361, KC Rebell]    182330          46
# 10                                  [Pop Smoke]    216386          86
# 11    [Gringo, Ezhel, Yung Kafa & Kücük Efendi]    232000          51
# 12                                     [Ufo361]    247196          58
# 13                              [KALIM, Ufo361]    119039          66
# 14                              [Gesaffelstein]    233965          57
# 15           [Travis Scott, Young Thug, M.I.A.]    202794          87
# 16  [Gesaffelstein, The Hacker, Electric Youth]    271733          42
# 17                               [Murda, Ezhel]    165908          58
# 18                                  [Pop Smoke]    214960          75
# 19                           [ZHU, Tame Impala]    294351          56
# 20                                 [The Weeknd]    200040          96
# 21                                      [KALIM]    166536          55
# 22                         [Ufo361, RAF Camora]    231071          54
# 23                  [Gesaffelstein, The Weeknd]    202093          69
# 24                               [Travis Scott]    156885          68
# 25                                      [Murda]    132149          62
# 26                        [Pop Smoke, Lil Tjay]    221813          58
# 27                    [Travis Scott, Kacy Hill]    339066          75
# 28    [Internet Money, Gunna, Don Toliver, NAV]    195428          94
# 29                                     [Ufo361]    158517          53
# 30                       [Future, Travis Scott]    205666          75
# 31                   [NAV, Gunna, Travis Scott]    161377          75
# 32                                   [Khontkar]    132992          56
# 33                               [Travis Scott]    243836          88
# 34                                     [Ufo361]    200926          56
# 35                         [Roddy Ricch, Gunna]    158691          72
# 36                                     [Ufo361]    147451          50
# 37                              [Gesaffelstein]    249373          47
# 38                               [FILV, Edmofo]    148822          50
# 39                                     [Ufo361]    142231          59
# 40                               [Night Lovell]    271403          69
# 41                        [Travis Scott, Quavo]    351253          66
# 42                                 [The Weeknd]    218880          72
# 43                           [Ufo361, Sonus030]    179967          64
# 44                               [Travis Scott]    217828          72
# 45                                     [Ufo361]    204319          58
# 46                                      [Ezhel]    216010          54
# 47                              [KALIM, Ufo361]    166285          42
# 48                               [Travis Scott]    185850          78
# 49            [Young Thug, Travis Scott, Gunna]    279906          71
