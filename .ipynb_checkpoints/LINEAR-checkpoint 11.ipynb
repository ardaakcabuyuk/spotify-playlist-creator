# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Toby Keith']", 'Made in America'],
#         ["['K/DA', 'Madison Beer', '(G)I-DLE', 'Jaira Burns', 'League of Legends']",
#          'POP/STARS'],
#         ["['Taylor Swift']", 'Getaway Car'],
#         ...,
#         ["['Mariah Carey']", 'When I Saw You'],
#         ["['Vampire Weekend']", 'Everlasting Arms'],
#         ["['Clay Walker']", 'If I Could Make a Living']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.001

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.c_[predictions, song_info]

# %%
predicted = predicted[predicted[:,0].argsort()][::-1]

# %%
list(predicted)
# Out:
# [array(['94.80498551802192', "['Grupo Libra']", 'Te Maldije'],
#        dtype='<U661'),
#  array(['95.028724751248', "['Aerosmith']", 'Uncle Salty'], dtype='<U661'),
#  array(['94.70224314034218', "['Luther Vandross']", 'Make Me a Believer'],
#        dtype='<U661'),
#  array(['94.54405890142085', "['Johnny Hartman']",
#         'All of Me - 2014 Remastered Version'], dtype='<U661'),
#  array(['94.94238724803833', "['SHAED', 'ZAYN']", 'Trampoline (with ZAYN)'],
#        dtype='<U661'),
#  array(['94.93571112245607', "['Marisela']", 'Muriendo de Amor'],
#        dtype='<U661'),
#  array(['94.75558503981152', "['Big Sean']", 'Guap'], dtype='<U661'),
#  array(['94.92864483291193', "['Tom Petty and the Heartbreakers']",
#         'Casa Dega - Demo'], dtype='<U661'),
#  array(['94.69423275643987', "['Bad Brains']", 'Attitude'], dtype='<U661'),
#  array(['95.0101959165955', "['Jackson Browne']", 'Stay - 2018 Remaster'],
#        dtype='<U661'),
#  array(['94.87310612709912', "['Fabolous', 'The-Dream']",
#         'Throw It In The Bag'], dtype='<U661'),
#  array(['94.96448620587009', "['George Strait']", 'Honky Tonk Crazy'],
#        dtype='<U661'),
#  array(['94.38512771754199', "['Toño Escobar Y Sus Locos']",
#         'Blanca Estela'], dtype='<U661'),
#  array(['94.62774947527043', "['Dean Martin']", 'Love Is All That Matters'],
#        dtype='<U661'),
#  array(['94.78623639551783', "['Bob Dylan']",
#         "Talkin' World War III Blues - Live at Philharmonic Hall, New York, NY - October 1964"],
#        dtype='<U661'),
#  array(['95.07365906882595', "['A Flock Of Seagulls']",
#         'Wishing (If I Had a Photograph of You)'], dtype='<U661'),
#  array(['94.91142281245126', "['Los Tigres Del Norte']", 'La Mafia Muere'],
#        dtype='<U661'),
#  array(['94.500536630067', "['Lord Creator']", 'Big Bamboo - Remastered'],
#        dtype='<U661'),
#  array(['94.9239341078137', "['Mitch Ryder and The Detroit Wheels']",
#         'Baby Jane (Mo-Mo Jane)'], dtype='<U661'),
#  array(['94.4587968886754',
#         "['Igor Stravinsky', 'Columbia Symphony Orchestra']",
#         "L'Oiseau de feu: Lever du jour - Ivan Tsarévitch pénètre dans le palais de Kachtchei - 1910 version"],
#        dtype='<U661'),
#  array(['94.51401945321923',
#         "['Pyotr Ilyich Tchaikovsky', 'André Previn', 'London Symphony Orchestra']",
#         'Swan Lake, Op.20, Act III: 15. Scene (Allegro giusto)'],
#        dtype='<U661'),
#  array(['94.489837808324', "['Эрнест Хемингуэй']",
#         'Часть 8.5 & Часть 9.1 - Фиеста'], dtype='<U661'),
#  array(['94.70603988067802', "['Jorge Ben Jor']", 'Uala Ualalá'],
#        dtype='<U661'),
#  array(['94.5457888011708', "['Satinath Mukherjee']",
#         'Raater Akash Taray Royechhe'], dtype='<U661'),
#  array(['94.59777948183299', "['Dilip Kumar']",
#         'Bhint Phadine Pipalo Ne Ugyo'], dtype='<U661'),
#  array(['95.16361500478973', "['Michael Henderson']", 'Wide Receiver'],
#        dtype='<U661'),
#  array(['94.83598379872028', "['Chet Baker']", "I'm Old Fashioned"],
#        dtype='<U661'),
#  array(['94.92870058555474', "['Red Hot Chili Peppers']",
#         'I Could Die for You'], dtype='<U661'),
#  array(['94.76040675294448',
#         "['Wolfgang Amadeus Mozart', 'Sir Thomas Beecham', 'Royal Philharmonic Orchestra']",
#         'Symphony No. 38 in D Major, K. 505, “Prague”: 2. Andante'],
#        dtype='<U661'),
#  array(['94.52777876008119', "['Ray Charles']", 'Early in the Morning'],
#        dtype='<U661'),
#  array(['94.50407251860022', "['Eugénie Buffet', 'René De Buxeuil']",
#         'Ma Chanson'], dtype='<U661'),
#  array(['94.64645403363328', "['G. I. Gurdjieff']",
#         '65b) No. 65, First Series'], dtype='<U661'),
#  array(['94.9266526770623', "['Whitechapel']", 'This Is Exile'],
#        dtype='<U661'),
#  array(['94.87916655798236', "['Harry Belafonte']", 'Jump in the Line'],
#        dtype='<U661'),
#  array(['95.1879130965762', "['Khalid', 'Disclosure', 'DaVido', 'Tems']",
#         'Know Your Worth'], dtype='<U661'),
#  array(['94.9853671378553', "['3OH!3']", 'STARSTRUKK'], dtype='<U661'),
#  array(['94.73140898512396', "['The Platters']", 'Going Back To Detroit'],
#        dtype='<U661'),
#  array(['94.7076467853549', "['Blondie']", 'In The Flesh - Remastered'],
#        dtype='<U661'),
#  array(['94.86304564559367', "['Fame on Fire']", 'Lucid Dreams'],
#        dtype='<U661'),
#  array(['94.46818332245543', "['The Tiger']", 'The Rats'], dtype='<U661'),
#  array(['96.14365130822759', "['Umm Kulthum']", 'Halet Layale El Qamar'],
#        dtype='<U661'),
#  array(['94.94424738667588', "['Heart']", 'Stranded'], dtype='<U661'),
#  array(['94.79680361101967', "['Dolly Parton']", 'The Bridge'],
#        dtype='<U661'),
#  array(['94.50436559684793', "['Natalino Otto']", 'Tipitipitipso'],
#        dtype='<U661'),
#  array(['95.06128469928234', "['John Coltrane Quartet']", 'Crescent'],
#        dtype='<U661'),
#  array(['94.4487770068921', "['Feroz Nizami']", 'Hum Aage Badhte Jayenge'],
#        dtype='<U661'),
#  array(['94.91753581500316', '["Mother\'s Finest"]', 'Piece of the Rock'],
#        dtype='<U661'),
#  array(['95.07491795399494', "['Muse']", 'Supermassive Black Hole'],
#        dtype='<U661'),
#  array(['94.88182043376018', "['Beanie Sigel']", 'Nothing Like It'],
#        dtype='<U661'),
#  array(['94.51222605758538', "['Johnny Cash']", 'Lead Me Father'],
#        dtype='<U661'),
#  array(['94.89562355897077', "['N.W.A.']", "I'd Rather Fuck You"],
#        dtype='<U661'),
#  array(['94.92254552293363', "['Dr. Dre', 'Snoop Dogg']",
#         'The Next Episode - Album Version (Edited)'], dtype='<U661'),
#  array(['95.30990402329327',
#         "['Charles Mingus', 'Bobby Warner', 'İlhan Mimaroğlu']",
#         'Devil Blues'], dtype='<U661'),
#  array(['94.38211884838567',
#         "['Hoagy Carmichael & His Orchestra', 'Bix Beiderbecke', 'Bud Freeman']",
#         "Bessie Couldn't Help It"], dtype='<U661'),
#  array(['95.04117365867978', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 27'], dtype='<U661'),
#  array(['95.1234352715232', "['Arcadia']", 'Election Day'], dtype='<U661'),
#  array(['94.90277012409672', "['I Prevail']", 'Bow Down'], dtype='<U661'),
#  array(['94.84603380174393', "['Francis Cabrel']",
#         "L'encre de tes yeux - Remastered"], dtype='<U661'),
#  array(['94.76199188627828', "['Sabu']", 'Aggo Elegua'], dtype='<U661'),
#  array(['94.84386339140248', "['Tiffany', 'George Tobin', 'Bill Smith']",
#         "Could've Been"], dtype='<U661'),
#  array(['95.10026070966546', "['Blondie', 'Mike Chapman']", 'Sunday Girl'],
#        dtype='<U661'),
#  array(['95.03957302297081', "['Rene y Rene']", 'Lo Mucho Que Te Quiero'],
#        dtype='<U661'),
#  array(['95.11616428022919', "['Steps']", 'Tragedy'], dtype='<U661'),
#  array(['95.14765253261658', "['Tame Impala']", 'Is It True'],
#        dtype='<U661'),
#  array(['94.95586812444895', "['Art Blakey Quintet']",
#         'Split Kick - Live At Birdland, New York/1954'], dtype='<U661'),
#  array(['94.81615627817706', "['The Shirelles']", 'Foolish Little Girl'],
#        dtype='<U661'),
#  array(['94.84469236442415', "['Electric Light Orchestra']",
#         'Down Home Town'], dtype='<U661'),
#  array(['94.60589857057862', "['Aretha Franklin']",
#         "Until You Come Back to Me (That's What I'm Gonna Do)"],
#        dtype='<U661'),
#  array(['94.54167180067755', "['Jack Payne']", "You're Always in My Arms"],
#        dtype='<U661'),
#  array(['94.67910552712398',
#         "['Felix Mendelssohn', 'Bruno Walter', 'New York Philharmonic']",
#         'Violin Concerto in E Minor, Op. 64, MWV O 14: II. Andante'],
#        dtype='<U661'),
#  array(['94.97023821846987', "['Manzanita']", 'Un Ramito de Violetas'],
#        dtype='<U661'),
#  array(['94.86792020973553', "['David Gates']", 'Goodbye Girl'],
#        dtype='<U661'),
#  array(['94.50777625996494', "['Shamshad Begum']",
#         'Kaise Ankhon Se Chhupa Ke Aa Gaye'], dtype='<U661'),
#  array(['94.80505142273155', "['Jack Kerouac']", 'American Haikus'],
#        dtype='<U661'),
#  array(['94.87476296957854', "['Bone Thugs-N-Harmony']", 'Tha Crossroads'],
#        dtype='<U661'),
#  array(['94.56640833876011',
#         "['Richard Wagner', 'Annelies Kupper', 'Josef Metternich', 'RIAS-Symphonie-Orchester', 'Ferenc Fricsay']",
#         'Der fliegende Holländer / Act 2: "Wie aus der Ferne längst vergang\'ner Zeiten"'],
#        dtype='<U661'),
#  array(['94.6051110594932', "['Doris Day', 'Percy Faith & His Orchestra']",
#         'Shaking the Blues Away (with Percy Faith & His Orchestra)'],
#        dtype='<U661'),
#  array(['94.49831514186339', "['Mubarak Begum', 'Sulochana Kadam']",
#         'Sham Hui Aur Deep Jale'], dtype='<U661'),
#  array(['94.67758685026902', "['Tom Rush']", "Child's Song"], dtype='<U661'),
#  array(['94.85874856437177', "['Jaymes Young']", 'Happiest Year'],
#        dtype='<U661'),
#  array(['94.42153701919494', "['Ying Yin Wu']", '當初見到你'], dtype='<U661'),
#  array(['94.75014806513205',
#         "['Johann Sebastian Bach', 'Catherine Mackintosh/Paul Goodwin/Timothy Brown/Susan Dent/Orchestra of the Age of Enlightenment', 'Orchestra of the Age of Enlightenment']",
#         'Brandenburg Concerto No. 1 in F BWV1046: III. Allegro'],
#        dtype='<U661'),
#  array(['94.58547841830932', "['Danny Kaye']", 'Thumbelina'], dtype='<U661'),
#  array(['95.05829245642632', "['Michael Franks']",
#         'The Lady Wants to Know'], dtype='<U661'),
#  array(['94.88169543038109', "['Supertramp']",
#         'The Logical Song - Live At Pavillon de Paris/1979'], dtype='<U661'),
#  array(['95.20052429180151', "['Violent Femmes']",
#         'Gimme The Car - 1983 Rough Trade UK Single'], dtype='<U661'),
#  array(['94.65500677861213', "['Garrett Hedlund']", 'Timing Is Everything'],
#        dtype='<U661'),
#  array(['95.14463736947351', "['SNAP!']",
#         "Rhythm Is A Dancer - 12'' Version"], dtype='<U661'),
#  array(['95.05307562189513', "['Donell Jones']", 'I Wanna Luv U'],
#        dtype='<U661'),
#  array(['94.51354183679872', "['Pablo de Sarasate', 'Ossy Renardy']",
#         'Adiós montañas mias (Danse espagnole) [Celebre Zortzico], Op. 37'],
#        dtype='<U661'),
#  array(['95.03694537115307', "['John Mayall']", 'California'],
#        dtype='<U661'),
#  array(['94.89828524777553', "['The Black Keys']", 'Heavy Soul'],
#        dtype='<U661'),
#  array(['95.02729159967043', "['Keith Washington']",
#         'Are You Still in Love with Me'], dtype='<U661'),
#  array(['94.98752429160555', '["Manfred Mann\'s Earth Band"]', 'For You'],
#        dtype='<U661'),
#  array(['94.53644007360559',
#         "['Richard Wagner', 'Josef Greindl', 'Philharmonia Orchestra', 'Wilhelm Furtwängler']",
#         'Wagner: Tristan und Isolde, WWV 90, Act 1 Scene 1: "Brangäne, du? Sag - wo sind wir?" (Isolde, Brangäne)'],
#        dtype='<U661'),
#  array(['95.09826449163347', "['Bruce Springsteen']",
#         'Tougher Than the Rest'], dtype='<U661'),
#  array(['95.01733926532206', "['Direct Drive']", "Don't Depend On Me"],
#        dtype='<U661'),
#  array(['94.66660608905839', "['Franz Joseph Haydn', 'Pro Arte Quartet']",
#         'Haydn: String Quartet No. 62 in C Major, Op. 76 No. 3, Hob. III, 77, "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['95.0471406914018', "['Styx']", 'Jennifer'], dtype='<U661'),
#  array(['94.66917686983781', "['Ornette Swoleman']", 'Angst'],
#        dtype='<U661'),
#  array(['95.08913810927737', "['Cheap Trick']", "Don't Be Cruel"],
#        dtype='<U661'),
#  array(['94.77892949269066', "['Jim Reeves']", 'This Is It'], dtype='<U661'),
#  array(['94.64263267557938', "['Cass Elliot']",
#         'Move In A Little Closer, Baby'], dtype='<U661'),
#  array(['94.7805740351442', "['Serge Gainsbourg']",
#         'Vilaines filles, mauvais garçons'], dtype='<U661'),
#  array(['94.8301534720914', "['Jazmine Sullivan']",
#         'In Love With Another Man'], dtype='<U661'),
#  array(['94.80247038624884', "['DeWayne Woods']", 'Let Go'], dtype='<U661'),
#  array(['94.8852085468647', "['50 Cent']",
#         'Wanksta - From "8 Mile" Soundtrack'], dtype='<U661'),
#  array(['95.04924116862885', "['Jack Teagarden & His Band']",
#         "Struttin' With Some Barbecue"], dtype='<U661'),
#  array(['94.72359675316586', "['Daft Punk']", 'Aerodynamic'], dtype='<U661'),
#  array(['94.50269357507776', "['Ennio Morricone']",
#         'El Bueno, El Feo Y El Malo - II Buono, II Brutto, Il Cattivo - Tema principal'],
#        dtype='<U661'),
#  array(['94.57995937174256', "['Lata Mangeshkar']", 'Bachpan Ki Muhabbat'],
#        dtype='<U661'),
#  array(['94.88359401085287', "['Fidel Rueda']", 'Todo Porque Te Amo'],
#        dtype='<U661'),
#  array(['95.12514992228344', "['Pharrell Williams']",
#         'Happy - From "Despicable Me 2"'], dtype='<U661'),
#  array(['94.953141192999', "['Mandy Moore', 'Jonathan Foreman']",
#         "Someday We'll Know"], dtype='<U661'),
#  array(['94.55537703657795', "['Nancy Wilson']", 'The More I See You'],
#        dtype='<U661'),
#  array(['95.04776319531788', "['Queen']", 'Great King Rat'], dtype='<U661'),
#  array(['94.86686108580035', "['Marc Anthony']", 'Se Me Sigue Olvidando'],
#        dtype='<U661'),
#  array(['95.06933106319755', "['Souls Of Mischief']", 'Make Your Mind Up'],
#        dtype='<U661'),
#  array(['95.02011293995997', "['Dexter Gordon']",
#         'A Night In Tunisia - Remastered'], dtype='<U661'),
#  array(['95.01188461288329', "['The Replacements']", "I'll Buy"],
#        dtype='<U661'),
#  array(['94.56778499039629', "['Nina Simone']", 'Backlash Blues'],
#        dtype='<U661'),
#  array(['94.49042255410117', "['Snehprabha']", 'Kahan Chali Gori'],
#        dtype='<U661'),
#  array(['94.87971489204189',
#         "['Isaiah Rashad', 'Zacari', 'Kendrick Lamar']",
#         "Wat's Wrong (feat. Zacari & Kendrick Lamar)"], dtype='<U661'),
#  array(['94.98250682348817', "['Roger Miller']", 'Me And Bobby McGee'],
#        dtype='<U661'),
#  array(['94.43478634716536',
#         "['Markos Vamvakaris', 'Apostolos Xatzixristos']",
#         'Siganopapaditsa'], dtype='<U661'),
#  array(['94.68236921388414',
#         "['Johannes Brahms', 'London Philharmonic Orchestra']",
#         'Symphony No. 3 in F Op. 90: III Poco allegretto'], dtype='<U661'),
#  array(['94.98789580627121', "['The Manhattan Transfer']",
#         'Spice of Life - Remastered'], dtype='<U661'),
#  array(['95.090999869967', "['Olivia Newton-John']", 'Magic'],
#        dtype='<U661'),
#  array(['95.16398105155054', "['Teenage Fanclub']", 'The Concept'],
#        dtype='<U661'),
#  array(['94.76443229713503', "['Michael Nyman']", 'The Promise'],
#        dtype='<U661'),
#  array(['94.86206685029305', "['Eddie Kendricks']", "He's A Friend"],
#        dtype='<U661'),
#  array(['94.87257153019857',
#         "['Handsome Boy Modeling School', 'Jack Johnson']", 'Breakdown'],
#        dtype='<U661'),
#  array(['94.64897466454', "['Jazz Majestic Orchestra']",
#         'Ménage Qui Belle (Beautiful Sweetheart)'], dtype='<U661'),
#  array(['94.9354929804865', "['Mötley Crüe']",
#         'Keep Your Eye On The Money - Demo'], dtype='<U661'),
#  array(['95.02934470645314', "['Alphaville', 'Bernhard Lloyd']",
#         'Sounds Like a Melody'], dtype='<U661'),
#  array(['94.94433831015003', "['David Allan Coe']", 'Roll On 18 Wheeler'],
#        dtype='<U661'),
#  array(['94.67272608958704', "['Porter Wagoner']",
#         "Don't Let Me Cross Over"], dtype='<U661'),
#  array(['94.64579547498282', "['The Stylistics']",
#         "Let's Put It All Together"], dtype='<U661'),
#  array(['94.46613130952355', "['Teddy Petersens Koncertorkester og kor']",
#         'Forår i Heidelberg/En herlig studentertid'], dtype='<U661'),
#  array(['94.7524730051194', "['康丁']", '失戀的草地郎'], dtype='<U661'),
#  array(['94.7502884409111', "['Billy Joel']", 'And So It Goes'],
#        dtype='<U661'),
#  array(['95.1769016793881', "['Leonard Cohen']", 'Waiting for the Miracle'],
#        dtype='<U661'),
#  array(['94.81442159216904', "['Ella Fitzgerald']",
#         'You Do Something To Me'], dtype='<U661'),
#  array(['94.99999469621194', "['Lil Wayne', 'T-Pain']", 'Got Money'],
#        dtype='<U661'),
#  array(['94.48367472679855',
#         "['Giacomo Puccini', 'Giuseppe Antonicelli', 'Metropolitan Opera Orchestra']",
#         'La Bohème: Act I - Mi chiamano Mimì'], dtype='<U661'),
#  array(['94.82760878948757', "['Korn']", 'Ball Tongue'], dtype='<U661'),
#  array(['95.09215424359448', "['John Newman']", 'Love Me Again'],
#        dtype='<U661'),
#  array(['94.54492410676077', "['Robert Johnson']", 'Terraplane Blues'],
#        dtype='<U661'),
#  array(['95.03479304025961', "['Led Zeppelin']",
#         'Stairway to Heaven - 1990 Remaster'], dtype='<U661'),
#  array(['94.7101214032215', "['David Gilmour']", 'Out of the Blue'],
#        dtype='<U661'),
#  array(['94.73870239316867', "['Nina Simone']",
#         'Please Read Me - Remastered'], dtype='<U661'),
#  array(['94.95654710627026', "['Grateful Dead']",
#         "Dupree's Diamond Blues - 2013 Remaster"], dtype='<U661'),
#  array(['94.76073649936092', "['Cliff Richard', 'The Shadows']",
#         'Lessons in Love - 2005 Remaster'], dtype='<U661'),
#  array(['94.98266192089464', "['Manuel Turizo']", 'Una Lady Como Tú'],
#        dtype='<U661'),
#  array(['95.06599674780014', "['Aerosmith']", 'Crazy'], dtype='<U661'),
#  array(['94.58943572216388', "['Sonny Boy Williamson I']",
#         'Decoration Blues'], dtype='<U661'),
#  array(['94.70792291336828',
#         "['Stephen Sondheim', 'Len Cariou', 'Victor Garber', 'Merle Louise', 'Paul Gemignani']",
#         'No Place Like London'], dtype='<U661'),
#  array(['95.00444085249933', "['Stan Bush']", 'Dare'], dtype='<U661'),
#  array(['94.58652743438176', "['alt-J']", 'Interlude 1'], dtype='<U661'),
#  array(['94.855195148424', "['Eric Clapton', 'Steve Winwood']",
#         "Can't Find My Way Home - Live from Madison Square Garden"],
#        dtype='<U661'),
#  array(['94.58476781421952', "['Little Willie John']", 'No Regrets'],
#        dtype='<U661'),
#  array(['95.03375073418789', "['Jackson Browne']", 'Lawyers in Love'],
#        dtype='<U661'),
#  array(['94.62137100664948', "['Frank Sinatra']",
#         "I Hadn't Anyone Till You"], dtype='<U661'),
#  array(['95.04616194204247', "['Raveena']", 'If Only'], dtype='<U661'),
#  array(['95.11252029312477', "['Stone Temple Pilots']", 'Adhesive'],
#        dtype='<U661'),
#  array(['94.49232783934093', "['Rita Abatzi']", 'Ο Βαγγέλης της μαμής'],
#        dtype='<U661'),
#  array(['95.0989922698241', "['Lionel Richie']", 'Penny Lover'],
#        dtype='<U661'),
#  array(['94.42652713250067', "['Jackie Gleason & His Orchestra']",
#         'Winter Wonderland'], dtype='<U661'),
#  array(['94.8869962470707', "['Jeru The Damaja']", "Ya Playin' Yaself"],
#        dtype='<U661'),
#  array(['94.59978789508823', "['Эрих Мария Ремарк']",
#         'Часть 32.3 - Триумфальная арка'], dtype='<U661'),
#  array(['95.04152285588633', "['Los Rehenes']",
#         'Cosas Buenas Que Parecen Malas'], dtype='<U661'),
#  array(['95.0875838058144', "['Spoon']", 'I Turn My Camera On'],
#        dtype='<U661'),
#  array(['94.5712391904637', '[\'Huey "Piano" Smith\']',
#         'Rockin Pneumonia and the Boogie Woogie Flu'], dtype='<U661'),
#  array(['94.74156507229085', "['Elaine Paige']", 'Memory'], dtype='<U661'),
#  array(['94.53878141594501',
#         "['Richard Strauss', 'London Philharmonic Orchestra']",
#         'Le Bourgeois Gentilhomme – Suite Op.60: IV Entrance and Dance of the Tailors'],
#        dtype='<U661'),
#  array(['94.90248658139744', "['Bruce Hornsby', 'The Range']",
#         'The Valley Road'], dtype='<U661'),
#  array(['94.5608968317375', "['Lester Young']", 'June Bug'], dtype='<U661'),
#  array(['94.44230415107027', "['白光']", '如果沒有你'], dtype='<U661'),
#  array(['94.8649617625704', "['Funkadelic']", 'Better By the Pound'],
#        dtype='<U661'),
#  array(['94.74788161087307', "['Firefall']", 'Cinderella'], dtype='<U661'),
#  array(['94.83774809674591', "['Nelly']", 'Thicky Thick Girl'],
#        dtype='<U661'),
#  array(['95.00761680204283', "['Elvis Costello & The Attractions']",
#         'Two Little Hitlers'], dtype='<U661'),
#  array(['94.55220270643518',
#         "['Sergei Rachmaninoff', 'Arthur Rubinstein', 'Fritz Reiner']",
#         'Rhapsody on a Theme of Paganini, Op. 43: Variation IV'],
#        dtype='<U661'),
#  array(['94.42126145951039', "['Henry Mancini']", 'Nothing To Lose'],
#        dtype='<U661'),
#  array(['95.18347133939879', "['Portugal. The Man']", 'Feel It Still'],
#        dtype='<U661'),
#  array(['94.70646632984571', "['Nelson Riddle']", 'Kansas City'],
#        dtype='<U661'),
#  array(['94.66231620691912', "['Pelle Törner tolkar Evert Taube']",
#         'Fragancia'], dtype='<U661'),
#  array(['95.14004438154637', "['Hot Chelle Rae']", 'Honestly'],
#        dtype='<U661'),
#  array(['94.90987738885705', "['Young Dolph', 'Key Glock']", 'Major'],
#        dtype='<U661'),
#  array(['94.60824283457612', "['Ramon Ayala Y Sus Bravos Del Norte']",
#         'Amor Del Bueno'], dtype='<U661'),
#  array(['94.67064986843545', "['The Carter Family', 'Johnny Cash']",
#         'Broken-Hearted Lover'], dtype='<U661'),
#  array(['94.90683206023303', "['Roy Hargrove']", 'September In the Rain'],
#        dtype='<U661'),
#  array(['94.89811817670429', "['James Brown']", "I Got The Feelin'"],
#        dtype='<U661'),
#  array(['95.05853239459827', "['Paramore']", 'Miracle'], dtype='<U661'),
#  array(['94.32033937135569', "['Mixalis Thomakos']", 'San Pio Krasi'],
#        dtype='<U661'),
#  array(['95.02119047623904', "['The Rolling Stones']",
#         'Honky Tonk Women - Live'], dtype='<U661'),
#  array(['95.10660843642734', "['MC5']", 'Miss X'], dtype='<U661'),
#  array(['95.05665581547258', "['Blondie']", 'The Tide Is High'],
#        dtype='<U661'),
#  array(['95.05964538968286', "['Chris Knight']", 'oil patch town'],
#        dtype='<U661'),
#  array(['94.92535138271421', "['R.E.M.']", 'Me In Honey'], dtype='<U661'),
#  array(['94.3635293246834', "['Eric Burdon & the Animals']",
#         'A Girl Named Sandoz'], dtype='<U661'),
#  array(['94.53335911111569', "['Javier Solís']", 'Porqué Negar'],
#        dtype='<U661'),
#  array(['94.48310974090343', "['Carmen Miranda']", 'Dona Geisha'],
#        dtype='<U661'),
#  array(['94.77534466051152', "['O.T. Genasis']", 'Bae'], dtype='<U661'),
#  array(['94.65391400259479', "['Frank Sinatra']",
#         'In The Wee Small Hours Of The Morning - Remastered 1998'],
#        dtype='<U661'),
#  array(['94.7946810564865', "['Steely Dan']", 'Almost Gothic'],
#        dtype='<U661'),
#  array(['94.4847547754624', "['6LACK']", 'Worst Luck'], dtype='<U661'),
#  array(['94.5935095393674', "['Dinah Washington']", 'Come On Home'],
#        dtype='<U661'),
#  array(['95.00046395220997', "['Tye Tribbett']", 'Victory - Live'],
#        dtype='<U661'),
#  array(['95.04668271846435', "['Parkway Drive']", 'Wild Eyes'],
#        dtype='<U661'),
#  array(['94.62001178145235', "['Sam Cooke']", "Goin' Home"], dtype='<U661'),
#  array(['95.01473797514956', "['Bob Seger']", 'The Fire Inside'],
#        dtype='<U661'),
#  array(['94.777231943368', "['Dan Fogelberg']", 'Times Like These'],
#        dtype='<U661'),
#  array(['94.67593856441871', "['Randy Newman']",
#         'Infinity and Beyond - From "Toy Story"/Score'], dtype='<U661'),
#  array(['94.65324760645711', "['Brownsville Station']",
#         "Smokin' in the Boy's Room"], dtype='<U661'),
#  array(['94.444482639993', "['Pietro Mascagni', 'Renato Cellini']",
#         'Cavalleria Rusticana: Il cavallo scalpita'], dtype='<U661'),
#  array(['95.05368949525807', "['Three Days Grace']", 'The High Road'],
#        dtype='<U661'),
#  array(['94.94386789028827', "['Tyler Childers']", 'Middle Ground (Live)'],
#        dtype='<U661'),
#  array(['94.66968541391111',
#         "['Wolfgang Amadeus Mozart', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Mozart: Eine kleine Nachtmusik, K. 525: III. Menuetto (Allegretto) - Trio'],
#        dtype='<U661'),
#  array(['94.64902233177929', "['Frank Sinatra']",
#         "She's Funny That Way - Remastered"], dtype='<U661'),
#  array(['95.0852365209382', "['I Prevail']", 'Heart Vs. Mind'],
#        dtype='<U661'),
#  array(['94.39559136657701', "['Francisco Canaro']",
#         'No Me Llores - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.59327295951798', "['Frank Sinatra']", 'Laura - Remastered'],
#        dtype='<U661'),
#  array(['95.0236019833593',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 4'],
#        dtype='<U661'),
#  array(['95.01447219175296', "['Of Mice & Men']", 'My Understandings'],
#        dtype='<U661'),
#  array(['94.5458336422002', "['Los Panchos']", 'Ojos Tristes'],
#        dtype='<U661'),
#  array(['94.9397454877472', "['Kino']", 'Закрой за мной дверь, я ухожу'],
#        dtype='<U661'),
#  array(['94.98442363188495', '["The B-52\'s"]',
#         'Girl from Ipanema Goes to Greenland'], dtype='<U661'),
#  array(['94.93856919718742', "['The Buckinghams']", 'Susan'], dtype='<U661'),
#  array(['94.37055379541239', "['Stellakis Perpiniadis']",
#         'Agiothodoritissa'], dtype='<U661'),
#  array(['94.51759235958579', "['Gaetano Donizetti', 'Fausto Cleva']",
#         'Lucia di Lamermoor: Act II: Scene 2: Appressati, Lucia... Il pallor, funesto, orrendo'],
#        dtype='<U661'),
#  array(['94.63701194135373', "['Fess Parker']", 'Daniel Boone'],
#        dtype='<U661'),
#  array(['95.11976140093583', "['New Kids On The Block']", "Hangin' Tough"],
#        dtype='<U661'),
#  array(['94.80978788532587', "['Los Reyes Del Camino']",
#         'Para Olvidarme De Ti'], dtype='<U661'),
#  array(['94.49003767344063', "['Lata Mangeshkar']",
#         'Aaj Shivaji Raja Zala'], dtype='<U661'),
#  array(['94.49909306838875', "['Ignacio Corsini']",
#         'Hermano Gaucho - Remasterizado'], dtype='<U661'),
#  array(['94.9595998672204', "['Ramones']", 'Commando - 2017 Remaster'],
#        dtype='<U661'),
#  array(['94.35780091942303',
#         "['Giuseppe Verdi', 'Gabriele Santini', 'Maria Callas', 'Orchestra Sinfonica Di Torino Della Rai']",
#         'Verdi : La Traviata : Act 2 "De\' miei bollenti spiriti" [Alfredo]'],
#        dtype='<U661'),
#  array(['94.88840497848877', "['Celtic Frost']", 'Visions of Mortality'],
#        dtype='<U661'),
#  array(['94.82135581728365', "['Aretha Franklin']", 'Precious Memories'],
#        dtype='<U661'),
#  array(['94.5434013503367', "['Local Oafs']", "You'll Never Catch Me"],
#        dtype='<U661'),
#  array(['94.47933662008998', "['Zeenat Begum']", 'Yeh Kaisa Zamana'],
#        dtype='<U661'),
#  array(['94.94567881629789', "['Jethro Tull']",
#         'Living in the Past - 2001 Remaster'], dtype='<U661'),
#  array(['94.62445417696202', "['The Three Sounds']", 'Love Somebody'],
#        dtype='<U661'),
#  array(['94.96296962978249',
#         "['Frederick Delius', 'Royal Philharmonic Orchestra', 'Sir Thomas Beecham']",
#         'Over the hills and far away (Fantasy Overture)'], dtype='<U661'),
#  array(['94.73055673611852', "['Muddy Waters']", "Walkin' Thru The Park"],
#        dtype='<U661'),
#  array(['94.65731142036893',
#         "['Judy Garland', 'Leo Diamond Harmonica Quartet']",
#         "Bidin' My Time"], dtype='<U661'),
#  array(['94.70541929488088',
#         '[\'Andrew Lloyd Webber\', \'"Cats" 1983 Broadway Cast\', \'Harry Groener\', \'Terrence Mann\', \'Ken Page\']',
#         'Old Deuteronomy'], dtype='<U661'),
#  array(['95.03268433663219',
#         "['Los Angeles Azules', 'Belinda', 'Lalo Ebratt', 'Horacio Palencia']",
#         'Amor A Primera Vista'], dtype='<U661'),
#  array(['94.85387974942846', "['Daryl Hall & John Oates']",
#         'Gino (The Manager)'], dtype='<U661'),
#  array(['94.6564829943126', "['Stan Getz']", 'Round Midnight'],
#        dtype='<U661'),
#  array(['94.88321357581852', "['King Gizzard & The Lizard Wizard']",
#         'Sense'], dtype='<U661'),
#  array(['94.39471852737266', "['Francisco Canaro']",
#         'Me Duele el Alma - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.8724341478058', "['Gruppo Palude']", 'Mayday'], dtype='<U661'),
#  array(['94.736381472343', "['Harold Budd', 'Brian Eno']",
#         'Foreshadowed - 2005 Digital Remaster'], dtype='<U661'),
#  array(['94.44269629199127', "['Charles Mingus']", 'Meditations For Moses'],
#        dtype='<U661'),
#  array(['95.09776067480396', "['Shinedown']", 'Lost in the Crowd'],
#        dtype='<U661'),
#  array(['94.49936648361533', "['Mohammed Rafi']", 'Yeh Mera Prem Patra'],
#        dtype='<U661'),
#  array(['94.75408091139819', "['alt-J']", 'Something Good'], dtype='<U661'),
#  array(['95.26003451217223', "['Bob James', 'David Sanborn']", 'Maputo'],
#        dtype='<U661'),
#  array(['94.96219268984319', "['Edgar Joel', 'Anthony Colon']",
#         'Hechizo De Luna'], dtype='<U661'),
#  array(['94.85881136050665', "['The Art Of Noise']",
#         '(Three Fingers Of) Love'], dtype='<U661'),
#  array(['94.96040364321999',
#         "['Ludwig van Beethoven', 'Vladimir Ashkenazy']",
#         'Piano Sonata No.14 In C Sharp Minor, Op.27 No.2 -"Moonlight": 1. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['94.79781112584256', "['Black Star', 'Vinia Mojica']",
#         'K.O.S. (Determination)'], dtype='<U661'),
#  array(['95.05354039965754',
#         "['070 Shake', 'Ralphy River', 'Hack & Tree']", 'Honey'],
#        dtype='<U661'),
#  array(['94.95578096484063', "['Bazzi']", 'Myself'], dtype='<U661'),
#  array(['94.75075773477458', "['Van Morrison']", 'Stranded'], dtype='<U661'),
#  array(['94.98527799973017', "['Metallica']",
#         'When Hell Freezes Over (The Call of Ktulu) (Garage Demo)'],
#        dtype='<U661'),
#  array(['94.99584294404688', "['Creed']", "What's This Life For"],
#        dtype='<U661'),
#  array(['94.49694862434247', "['Carmen Miranda', 'Nuno Roland']",
#         'Nas Cadeiras Da Baiana'], dtype='<U661'),
#  array(['94.72443285928247', '["Ship\'s Chorus"]',
#         'Fathoms Below - From "The Little Mermaid" / Soundtrack Version'],
#        dtype='<U661'),
#  array(['94.85423747669608', "['YG', 'Mustard']", 'Left, Right'],
#        dtype='<U661'),
#  array(['95.01911550487321', "['Queen']", 'More Of That Jazz'],
#        dtype='<U661'),
#  array(['94.9528668548019', "['The Cramps']", 'Caveman'], dtype='<U661'),
#  array(['94.53947041456', "['Cuco Sánchez']", 'La Chancla'], dtype='<U661'),
#  array(['94.85408724785418', "['Basil Poledouris']",
#         'Hymn To Red October (Main Title)'], dtype='<U661'),
#  array(['95.0402914714674', "['A Day To Remember']",
#         'Violence (Enough Is Enough)'], dtype='<U661'),
#  array(['94.70099892363359',
#         "['Maurice Ravel', 'Charles Gerhardt', 'National Philharmonic Orchestra']",
#         'Pavane pour une infante défunte, M. 19'], dtype='<U661'),
#  array(['94.5917130086564', "['Oscar Peterson']",
#         "Oh Bess, Where's My Bess?"], dtype='<U661'),
#  array(['95.05795952245684', "['Nirvana']", 'In Bloom - Nevermind Version'],
#        dtype='<U661'),
#  array(['94.54600111293963', "['H Khan Mastana']",
#         'Asha Ki Jyoti Lagaye Ja'], dtype='<U661'),
#  array(['95.02843025436506', "['potsu']", '[oops]'], dtype='<U661'),
#  array(['95.00469889005123', "['Jerry Butler']",
#         "(I'm Just Thinking About) Cooling Out"], dtype='<U661'),
#  array(['94.53380659431241', "['Thelonious Monk']",
#         'Black And Tan Fantasy'], dtype='<U661'),
#  array(['95.37442357132124', "['The Mars Volta']", 'Cicatriz Esp'],
#        dtype='<U661'),
#  array(['94.8801954211378', "['Steely Dan']", 'Third World Man'],
#        dtype='<U661'),
#  array(['95.03189548739307', "['Talking Heads']", "Memories Can't Wait"],
#        dtype='<U661'),
#  array(['95.03190688749594', "['Stone Temple Pilots']",
#         'Seven Caged Tigers'], dtype='<U661'),
#  array(['95.23535348107845', "['Deep Purple']", 'No No No'], dtype='<U661'),
#  array(['95.07294823842591', "['Andrew Gold']",
#         'Thank You for Being a Friend'], dtype='<U661'),
#  array(['94.4466711871573', "['Frédéric Chopin', 'Vladimir Horowitz']",
#         'Étude in A-Flat Major, Op. 25, No. 1 "Aeolian Harp"'],
#        dtype='<U661'),
#  array(['94.80774734155212', "['Rod Wave']", 'And I Still'], dtype='<U661'),
#  array(['94.72489736380955', "['The Zombies']", 'This Will Be Our Year'],
#        dtype='<U661'),
#  array(['94.99131129416395', "['Robin Trower']", 'Man of the World'],
#        dtype='<U661'),
#  array(['94.37638720891908', "['Brownie McGhee']", 'Mean Ole Frisco'],
#        dtype='<U661'),
#  array(['94.60209790994263', "['Blossom Dearie']",
#         'Life Upon The Wicked Stage'], dtype='<U661'),
#  array(['94.46514610939951', "['Claude Debussy', 'Robert Casadesus']",
#         "Children's Corner, L. 113: V. The Little Shepherd. Très modéré"],
#        dtype='<U661'),
#  array(['94.91616940892513',
#         "['Duke Ellington', 'Clark Terry', 'Willie Cook', 'Cat Anderson', 'Ray Nance', 'Quentin Jackson', 'Britt Woodman', 'George Jean', 'Jimmy Hamilton', 'Rick Henderson', 'Russell Procope', 'Paul Gonsalves', 'Harry Carney', 'Wendell Marshall', 'Dave Black']",
#         'Isle of Capri Mambo'], dtype='<U661'),
#  array(['94.55640238893993', "['John Denver']", 'Gospel Changes'],
#        dtype='<U661'),
#  array(['94.7338326978739', "['Irving Burgie', 'Chad Mitchell Trio']",
#         'I Do Adore Her - Live'], dtype='<U661'),
#  array(['95.07487941274837', "['UB40']", 'Baby'], dtype='<U661'),
#  array(['95.05807618682955', "['Rihanna']", 'Shut Up And Drive'],
#        dtype='<U661'),
#  array(['94.80582619522816', "['The Cleaners From Venus']",
#         'The Jangling Man'], dtype='<U661'),
#  array(['95.13037665477457', "['The Cab']", 'Temporary Bliss'],
#        dtype='<U661'),
#  array(['94.50733074732877', "['Stella Xaskil']", 'Xaititze'],
#        dtype='<U661'),
#  array(['94.59164072716919', "['Gene Autry']",
#         "Everyone's a Child at Christmas - Single Version"], dtype='<U661'),
#  array(['95.19992837905775', "['The Call']",
#         'I Still Believe (Great Design)'], dtype='<U661'),
#  array(['95.05165672581676',
#         "['Big Head Todd and The Monsters', 'Tom Lord-Alge']",
#         "Please Don't Tell Her"], dtype='<U661'),
#  array(['94.99449361315175', "['DEVO']", 'Speed Racer'], dtype='<U661'),
#  array(['94.79656280053123', "['Kacey Musgraves']", 'Keep It To Yourself'],
#        dtype='<U661'),
#  array(['95.21680873295225', "['Slipknot']", 'The Devil in I'],
#        dtype='<U661'),
#  array(['94.97204740185919', "['Daddy Yankee']", 'King Daddy'],
#        dtype='<U661'),
#  array(['94.76531742092307', "['Elvis Presley']", 'Money Honey'],
#        dtype='<U661'),
#  array(['94.74510326793528', "['Joni Mitchell']",
#         'In France They Kiss on Main Street'], dtype='<U661'),
#  array(['94.7084861205266', "['Jorge Valente']", 'El Triste'],
#        dtype='<U661'),
#  array(['94.57063625791699', '["Herman\'s Hermits"]', 'Listen People'],
#        dtype='<U661'),
#  array(['94.87881199344353', "['Nicki Minaj', '2 Chainz']",
#         'Beez In The Trap'], dtype='<U661'),
#  array(['95.04259414513865', "['Rob Zombie']",
#         'Never Gonna Stop (The Red, Red Kroovy)'], dtype='<U661'),
#  array(['94.69746480334214', "['Nat King Cole']", "You're My Everything"],
#        dtype='<U661'),
#  array(['94.8810744345117', "['Kenny Rogers', 'Anne Murray']",
#         'If I Ever Fall in Love Again - Duet with Anne Murray'],
#        dtype='<U661'),
#  array(['95.12460001829388',
#         "['Alan Walker', 'Sabrina Carpenter', 'Farruko']", 'On My Way'],
#        dtype='<U661'),
#  array(['94.87774975143579', "['Clyde Boudreaux']", 'Nepenthe'],
#        dtype='<U661'),
#  array(['95.07809666489668', "['The Kinks']",
#         "Catch Me Now I'm Falling - Live at Providence Civic Center, Providence, RI - September 1979"],
#        dtype='<U661'),
#  array(['95.0822741106141', "['B.B. King']", 'Hummingbird'], dtype='<U661'),
#  array(['94.57863370001013', "['Frank Sinatra']", 'Bewitched'],
#        dtype='<U661'),
#  array(['94.51117761465284', "['Ignacio Corsini']",
#         'Serenata Maleva - Remasterizado'], dtype='<U661'),
#  array(['95.06200310038737', "['Eagles']",
#         'Take It Easy - Live; 1999 Remaster'], dtype='<U661'),
#  array(['95.03022705686142', "['Jamey Johnson']", 'That Lonesome Song'],
#        dtype='<U661'),
#  array(['94.55649549903133', "['Ritza Ampatzi']", 'Efige h agapi moy'],
#        dtype='<U661'),
#  array(['94.59861833274057', "['Lata Mangeshkar', 'C. Ramchandra']",
#         'Yaar Vai Vai'], dtype='<U661'),
#  array(['95.20406973130066', "['The Jim Carroll Band']", 'People Who Died'],
#        dtype='<U661'),
#  array(['94.3911087213452', "['Wallace Stevens']", 'Imago'], dtype='<U661'),
#  array(['94.9018934956973', "['Wilfred Luckie']", 'My Thing'],
#        dtype='<U661'),
#  array(['94.71532506120367', "['Shanta Hublikar']",
#         'Kis Liye Kal Ki Baat (From "Aadmi")'], dtype='<U661'),
#  array(['95.01410093449871', "['Asia']", 'Cutting It Fine'], dtype='<U661'),
#  array(['94.67203400837191', "['Frank Sinatra']",
#         'Too Marvelous For Words - Remastered 1998'], dtype='<U661'),
#  array(['94.93752950283782', "['John Lennon']",
#         'Crippled Inside - Remastered 2010'], dtype='<U661'),
#  array(['94.88887169876283', "['YG']", "I'm Good"], dtype='<U661'),
#  array(['94.60979281724083', "['Эрнест Хемингуэй']",
#         'Часть 51.3 & Часть 52.1 - Прощай оружие'], dtype='<U661'),
#  array(['94.61043404830123', "['Mac Miller']", 'Of The Soul'],
#        dtype='<U661'),
#  array(['95.02434016171338', "['Lizzo']", 'Fitness'], dtype='<U661'),
#  array(['94.58977518538032', "['Harry Nilsson']", 'The Birds - Narration'],
#        dtype='<U661'),
#  array(['94.93050124759301', "['Sepultura']", 'Slave New World'],
#        dtype='<U661'),
#  array(['94.94112103648871', "['Tom Petty and the Heartbreakers']",
#         'Here Comes My Girl'], dtype='<U661'),
#  array(['94.94680536592232', "['Canserbero']", 'Llovía'], dtype='<U661'),
#  array(['94.79820544837251', "['Xtreme']", 'Te Extraño - Bachata Version'],
#        dtype='<U661'),
#  array(['94.81294578921788', "['Johnny Depp', 'Jamie Campbell Bower']",
#         'No Place Like London'], dtype='<U661'),
#  array(['95.07409850723772', "['Bruce Springsteen']", 'Bobby Jean'],
#        dtype='<U661'),
#  array(['94.42371034539707',
#         "['Carroll Gibbons', 'The Savoy Hotel Orpheans']",
#         "Journey's End (Carroll Gibbons; The Savoy Hotel Orpheans)"],
#        dtype='<U661'),
#  array(['94.807712505554', "['Calvin Harris', 'Future', 'Khalid']",
#         'Rollin (feat. Future & Khalid)'], dtype='<U661'),
#  array(['94.77427616459583',
#         "['Gabriel Fauré', 'Sir David Willcocks', 'New Philharmonia Orchestra']",
#         'Pavane, Op.50 (orch. version, 1887) - 2007 Remastered Version'],
#        dtype='<U661'),
#  array(['94.79261250636584',
#         "['Georges Bizet', 'Katia Labèque', 'Marielle Labèque']",
#         "Jeux d'enfants, Op.22 WD 56: 3. La poupée"], dtype='<U661'),
#  array(['94.87883862412579', "['Haystak']", 'All By Myself'], dtype='<U661'),
#  array(['94.81390863636827',
#         "['The Notorious B.I.G.', 'Bob Marley & The Wailers']",
#         'Hold Ya Head (feat. Bob Marley)'], dtype='<U661'),
#  array(['94.46496024918652', "['Russ Morgan and His Orchestra']",
#         'I Want You for Christmas'], dtype='<U661'),
#  array(['94.96575277412042', "['Menudo']", 'Claridad'], dtype='<U661'),
#  array(['94.82787397666293', "['Johann Sebastian Bach', 'E. Power Biggs']",
#         'Fantasia & Fugue in G Minor, BWV 542: Fugue'], dtype='<U661'),
#  array(['94.83190129503873', "['The LOX', 'Kelly Price']",
#         'So Right (feat. Kelly Price)'], dtype='<U661'),
#  array(['94.5519868203538', "['Zohrabai Ambalawali']",
#         'Rumjhum Barse Badarwa'], dtype='<U661'),
#  array(['94.50780502344455', "['Ignacio Corsini']",
#         'Nido de Amor - Remasterizado'], dtype='<U661'),
#  array(['94.96606364236399', "['Paul Wall', 'Jermaine Dupri']",
#         "I'm Throwed (feat. Jermaine Dupri)"], dtype='<U661'),
#  array(['94.80079321992027', "['Merle Haggard']", 'Footlights'],
#        dtype='<U661'),
#  array(['95.1459466570604', "['Rixton']", 'Speakerphone'], dtype='<U661'),
#  array(['95.00288551508869', "['Prince Royce']", 'Soy el Mismo'],
#        dtype='<U661'),
#  array(['94.51629292363523', "['Fats Waller']", 'Mamacita'], dtype='<U661'),
#  array(['94.61334399527183', "['Joe Hisaishi']", 'A Walk in the Skies'],
#        dtype='<U661'),
#  array(['95.04169439755877', "['Linkin Park']", 'Lying from You'],
#        dtype='<U661'),
#  array(['94.53268050960683', "['Master Krishnarao']",
#         'Aai Re Ghata Sawan Ki Ghir Kar'], dtype='<U661'),
#  array(['94.67975085961184', "['Mukesh']", 'Jis Desh Men Ganga Behti Hai'],
#        dtype='<U661'),
#  array(['94.35012141433617', "['Dock Reed']",
#         'Low Down the Chariot and Let Me Ride'], dtype='<U661'),
#  array(['95.06966314212352', "['AC/DC']", 'Thunderstruck - Live - 1991'],
#        dtype='<U661'),
#  array(['94.37112358417947', "['Francisco Canaro', 'Charlo']",
#         'Nicolasa - Remasterizado'], dtype='<U661'),
#  array(['95.09895461868793', "['George Thorogood & The Destroyers']",
#         'Long Gone'], dtype='<U661'),
#  array(['94.65709486335317', "['Solomon Burke']",
#         'Goodbye Baby (Baby Goodbye)'], dtype='<U661'),
#  array(['94.68033462480058',
#         "['Johannes Brahms', 'Wilhelm Stross', 'Elly Ney', 'Ludwig Hoelscher']",
#         'Piano Trio No.1 in B Major, Op.8: III. Adagio'], dtype='<U661'),
#  array(['94.74319362795384', "['Chance the Rapper']", 'Same Drugs'],
#        dtype='<U661'),
#  array(['94.59037600912704',
#         "['Shamshad Begum', 'Mohammed Rafi', 'C. Ramchandra']",
#         'Tabiyat Saaf Ho Gai Saaf'], dtype='<U661'),
#  array(['94.86254723521513', "['Wire']",
#         'I Am the Fly - 2006 Remastered Version'], dtype='<U661'),
#  array(['94.89075399566735', "['Trippie Redd']", 'Toxic Waste'],
#        dtype='<U661'),
#  array(['94.45323666418726',
#         "['Giovanni Paisiello', 'Irma Kolassi', 'Jacqueline Bonneau']",
#         'Gli Zingari In Fiera: "Chi vuol la zingarella" - 1955 Version'],
#        dtype='<U661'),
#  array(['94.63035944617926', "['Merle Haggard & The Strangers']",
#         'Old Man From The Mountain'], dtype='<U661'),
#  array(['95.1158629918287', "['One Direction']", 'Heart Attack'],
#        dtype='<U661'),
#  array(['94.970297098251',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 22'],
#        dtype='<U661'),
#  array(['94.97301092596065', "['Looking Glass']",
#         "Brandy (You're a Fine Girl)"], dtype='<U661'),
#  array(['95.05264100558759', "['Los Fugitivos']", 'Como Dejar De Amarte'],
#        dtype='<U661'),
#  array(['94.8700357577683', "['Cypress Hill']",
#         "I Ain't Goin' Out Like That"], dtype='<U661'),
#  array(['94.58687053192115', "['Dinah Washington']",
#         "I'll Never Kiss You Goodbye"], dtype='<U661'),
#  array(['95.03154051341927',
#         "['Ghostface Killah', 'Masta Killa', 'Reakwon', 'Cappadonna', 'U-God']",
#         'Winter Warz'], dtype='<U661'),
#  array(['94.79401761871459', "['Dean Martin', 'Robert Norberg']",
#         'All I Do Is Dream Of You - Remastered'], dtype='<U661'),
#  array(['94.92325350750465', "['The Outlaws']", "Keep Prayin'"],
#        dtype='<U661'),
#  array(['94.52172868680086', "['Mitsos Arapakis']", 'Manes Rast'],
#        dtype='<U661'),
#  array(['94.76489845341924',
#         "['Anatoly Lyadov', 'George Szell', 'Cleveland Orchestra']",
#         'The Enchanted Lake, Op. 62'], dtype='<U661'),
#  array(['94.80904026218941', "['Alabama']", 'Lady Down On Love'],
#        dtype='<U661'),
#  array(['94.68823541558935', '[\'Buddy Rich\', \'Harry "Sweets" Edison\']',
#         'Yellow Rose Of Brooklyn - Single Version'], dtype='<U661'),
#  array(['95.0272066089499', "['Cheap Trick']",
#         'ELO Kiddies - Single Version'], dtype='<U661'),
#  array(['94.50559516409304',
#         "['George Frideric Handel', 'The Liverpool Philharmonic Orchestra', 'Sir Malcolm Sargent']",
#         'Messiah, HWV 56, Pt. 2: Lift up your heads, O ye gates - Chorus'],
#        dtype='<U661'),
#  array(['94.43526930369825', "['The Big Bopper']", 'Preacher And The Bear'],
#        dtype='<U661'),
#  array(['94.73771194855213', "['Smokey Robinson']",
#         'Happy (Love Theme From "Lady Sings The Blues")'], dtype='<U661'),
#  array(['94.80500769880113', "['Frédéric Chopin', 'Hélène Grimaud']",
#         'Berceuse In D Flat, Op.57'], dtype='<U661'),
#  array(['94.87763413529376', "['Kate Bush']", 'Moving'], dtype='<U661'),
#  array(['94.74609108237456', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 93'], dtype='<U661'),
#  array(['94.68099628896984', "['Carl Perkins']",
#         'Where the Rio De Rosa Flows'], dtype='<U661'),
#  array(['95.02619701868714', "['Dixie Chicks']", 'Stand by Your Man'],
#        dtype='<U661'),
#  array(['94.74637649805892', "['Beastie Boys']",
#         'B-Boy Bouillabaisse: Get On The Mic'], dtype='<U661'),
#  array(['95.01727442348493', "['Imagine Dragons']", 'Demons'],
#        dtype='<U661'),
#  array(['95.13695025526116', "['The Expendables']", 'Down Down Down'],
#        dtype='<U661'),
#  array(['94.76316125547294', "['Luis Aguilar', 'Antonio Aguilar']",
#         'El Mala Estrella'], dtype='<U661'),
#  array(['94.95779565316198', "['Cavetown']", 'Home'], dtype='<U661'),
#  array(['94.70288466524312', "['Willie Dixon']", "I Ain't Superstitious"],
#        dtype='<U661'),
#  array(['94.98160781019723', "['Thrice']", 'Stare At The Sun'],
#        dtype='<U661'),
#  array(['95.08256650541148', "['Public Enemy']", 'Shut Em Down'],
#        dtype='<U661'),
#  array(['94.88641725061224', "['Beyoncé']", 'Rocket'], dtype='<U661'),
#  array(['94.68407741905769', "['The Mar-Keys']", 'About Noon'],
#        dtype='<U661'),
#  array(['94.71719510339699', "['Frank Sinatra']", 'Stardust'],
#        dtype='<U661'),
#  array(['94.46016796625891', "['Frank Sinatra']",
#         'Someone To Watch Over Me'], dtype='<U661'),
#  array(['94.87547538658383', "['Linkin Park']", "Nobody's Listening"],
#        dtype='<U661'),
#  array(['94.6601075769286', "['Jerry Garcia Band', 'Jerry Garcia']",
#         "I'll Be With Thee - Bonus Track"], dtype='<U661'),
#  array(['95.02223030513095', "['Brandy', 'Kanye West']",
#         'Talk About Our Love (feat. Kanye West)'], dtype='<U661'),
#  array(['94.98302323767132', "['Joy Division']",
#         'The Only Mistake - The Factory, Manchester Live 11 April 1980'],
#        dtype='<U661'),
#  array(['94.47247400730494',
#         "['Wolfgang Amadeus Mozart', 'George Szell', 'Cleveland Orchestra']",
#         'Symphony No. 33 in B-Flat Major, K. 319: III. Menuetto - Trio'],
#        dtype='<U661'),
#  array(['94.89140655273638', "['Indigo Girls']", 'Secure Yourself'],
#        dtype='<U661'),
#  array(['94.75907039550934', "['Brook Benton']",
#         "It's Just A Matter Of Time"], dtype='<U661'),
#  array(['95.2313544255808', "['The Canton Spirituals']",
#         "He's There All the Time"], dtype='<U661'),
#  array(['95.03738156662385', "['Muse']", 'Exo-Politics'], dtype='<U661'),
#  array(['94.62188310583407', "['Stockard Channing']",
#         'There Are Worse Things I Could Do - From “Grease”'], dtype='<U661'),
#  array(['95.0073719262654',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 41'],
#        dtype='<U661'),
#  array(['94.99412887833226', "['Tim McGraw']",
#         'Where The Green Grass Grows'], dtype='<U661'),
#  array(['94.59278653864327', "['The Ventures']", 'Trambone'], dtype='<U661'),
#  array(['95.2021802450252', "['Calvin Harris']", 'Summer'], dtype='<U661'),
#  array(['94.51000855210356', "['Jerry Lee Lewis']", 'Fools Like Me'],
#        dtype='<U661'),
#  array(['94.99175759019971', "['Vampire Sound Inc.']", "We don't care"],
#        dtype='<U661'),
#  array(['94.5929955071246', "['Billie Holiday', 'Eddie Heywood']",
#         'Georgia On My Mind (with Eddie Heywood & His Orchestra) - Take 1'],
#        dtype='<U661'),
#  array(['95.13849448627533', "['Peter Gabriel']", 'I Have The Touch'],
#        dtype='<U661'),
#  array(['94.84302618237571', "['Girma Hadgu']",
#         "Ené Alantchi Alnorem (I Can't Live Without You)"], dtype='<U661'),
#  array(['95.12743452943093', "['Martin Garrix', 'Bebe Rexha']",
#         'In the Name of Love'], dtype='<U661'),
#  array(['94.87194760122709', "['Del Shannon']", 'The Search'],
#        dtype='<U661'),
#  array(['94.90067355035539', "['Cross Canadian Ragweed']",
#         'Boys From Oklahoma'], dtype='<U661'),
#  array(['94.75928518275937',
#         "['Mercedes Sosa', 'Ariel Ramírez', 'Hector Zeoli']",
#         'Alfonsina Y El Mar'], dtype='<U661'),
#  array(['94.69120415390866', "['Shuggie Otis']", 'One Room Country Shack'],
#        dtype='<U661'),
#  array(['94.94806609663141', "['Luis Miguel']", 'Sunny'], dtype='<U661'),
# ...
#  array(['94.58200155610808', "['Stevie Wonder']", 'Castles In The Sand'],
#        dtype='<U661'),
#  array(['94.74538152097462', "['Banda Cuisillos']", 'Cartas Marcadas'],
#        dtype='<U661'),
#  array(['94.94570223664597', "['Chicago']",
#         'If She Would Have Been Faithful... - 2009 Remaster'],
#        dtype='<U661'),
#  array(['94.94373130436782', "['Enrique Iglesias']", 'Hero'], dtype='<U661'),
#  array(['94.98196862622804', "['Cheo Feliciano']", 'Anacaona'],
#        dtype='<U661'),
#  array(['94.55699997461869', "['The Beach Boys']",
#         "I'm So Young - Remastered"], dtype='<U661'),
#  array(['94.89887880825789', "['Eminem', 'Jessie Reyez']",
#         'Good Guy (feat. Jessie Reyez)'], dtype='<U661'),
#  array(['94.35923015189307', "['The Duke Of Iron']", 'Parakeets'],
#        dtype='<U661'),
#  array(['94.7673691045557', "['Carole King']", 'Oh No Not My Baby'],
#        dtype='<U661'),
#  array(['94.46288493586351', "['Billie Holiday', 'Teddy Wilson']",
#         'They Say (with Teddy Wilson & His Orchestra) - Take 2'],
#        dtype='<U661'),
#  array(['95.13754462779993', "['Tropical Del Bravo']", 'La Gorra'],
#        dtype='<U661'),
#  array(['95.18276751336188', "['The Jeff Healey Band']",
#         'While My Guitar Gently Weeps'], dtype='<U661'),
#  array(['94.82337198615919', "['Lil Dicky', 'Brendon Urie']",
#         'Molly (feat. Brendon Urie of Panic at the Disco)'], dtype='<U661'),
#  array(['94.95769976794149', "['Los Bukis']", 'Si Ya No Te Vuelvo A Ver'],
#        dtype='<U661'),
#  array(['94.94690126761601', "['The Specials']",
#         'Concrete Jungle - 2015 Remaster'], dtype='<U661'),
#  array(['95.04399517047297', "['Christión']", 'Full Of Smoke'],
#        dtype='<U661'),
#  array(['94.57115503220864', "['Johnny Tillotson']",
#         "It Keeps Right On A-Hurtin' - 1962 #3Pop; #4Country Billboard Chart Hit"],
#        dtype='<U661'),
#  array(['95.06553651035657', "['Max Webster']", 'Battle Scar'],
#        dtype='<U661'),
#  array(['94.75147627151632', "['Frédéric Chopin', 'Roger W. Lowther']",
#         'Ballade No. 4 in F Minor, Opus 52'], dtype='<U661'),
#  array(['94.57496874673392', "['Johnny Cash']", "My Grandfather's Clock"],
#        dtype='<U661'),
#  array(['94.79266015583677', "['ABBA']", 'Tiger'], dtype='<U661'),
#  array(['94.76354608818305', "['Birdy']", 'Tee Shirt - Soundtrack Version'],
#        dtype='<U661'),
#  array(['94.43369902708152', "['Louis Armstrong & His Hot Seven']",
#         'Melancholy'], dtype='<U661'),
#  array(['94.96184072560035', "['Backstreet Boys']", 'I Need You Tonight'],
#        dtype='<U661'),
#  array(['94.72061292272704', "['Black Sabbath']", 'Fluff - 2013 Remaster'],
#        dtype='<U661'),
#  array(['95.03915746806481', "['INXS']", 'Biting Bullets'], dtype='<U661'),
#  array(['95.14435630769353', "['Semisonic']", 'F.N.T.'], dtype='<U661'),
#  array(['94.85688320971451', "['Dead Prez']",
#         'Hell Yeah (Pimp the System) - Real Version'], dtype='<U661'),
#  array(['94.47835775500897', "['Hector Berlioz', 'Arturo Toscanini']",
#         'Roméo et Juliette, Op. 17, H. 79: Bruits lointaines de concert et de bal'],
#        dtype='<U661'),
#  array(['94.72300416531728', "['Frank Sinatra']",
#         'Street Of Dreams - Live At The Sands Hotel And Casino/1966'],
#        dtype='<U661'),
#  array(['94.83664469161813', "['Chick Corea']", "Armando's Rhumba"],
#        dtype='<U661'),
#  array(['94.45704592066939', "['Unspecified']", 'La Rose; La Marguerite 3'],
#        dtype='<U661'),
#  array(['94.60121696369916', "['Στ.Τσίτσης', 'Στ.Στάθης', 'Μ.Χαρίσης']",
#         'Ξενιτεμένο μου πουλί'], dtype='<U661'),
#  array(['94.6103841041176', "['Julie London']",
#         'Moments Like This - Remastered'], dtype='<U661'),
#  array(['94.8436700375078', "['Philip Wesley']", 'Dark Night of the Soul'],
#        dtype='<U661'),
#  array(['94.42663309973356', "['Phiroz J Bhagalia']",
#         'Jar Jahangir No Jhagado, Pt. 1'], dtype='<U661'),
#  array(['94.53603588753131', "['Rosemary Clooney']", 'From This Moment On'],
#        dtype='<U661'),
#  array(['94.41913892643632', "['Jack Payne']", 'Looking At You'],
#        dtype='<U661'),
#  array(['94.73380176820717', "['Frank Zappa', 'The Mothers Of Invention']",
#         'Call Any Vegetable'], dtype='<U661'),
#  array(['94.74721567797054', "['Molotov']", 'Puto'], dtype='<U661'),
#  array(['94.91529985487087', "['Cake']", 'Stickshifts and Safetybelts'],
#        dtype='<U661'),
#  array(['94.66401515594339', "['Los Horóscopos De Durango']",
#         'Él No Eres Tú'], dtype='<U661'),
#  array(['94.52874432134811', "['Otis Redding']",
#         "Nobody Knows You (When You're Down and Out) - Mono"],
#        dtype='<U661'),
#  array(['94.435030067892', "['Francisco Canaro']",
#         'Bebamos Juntos - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['95.04460361937743', "['Daddy Yankee', 'Zion & Lennox']",
#         'Tu Príncipe'], dtype='<U661'),
#  array(['94.84368286643593', "['The Who']", 'Behind Blue Eyes - Live'],
#        dtype='<U661'),
#  array(['94.76395174966278', "['Carmen Miranda']", 'Fala, Meu Pandeiro'],
#        dtype='<U661'),
#  array(['94.63785115883115', "['Wings']",
#         "Picasso's Last Words - Live / Remastered"], dtype='<U661'),
#  array(['95.04548978757293', "['Zac Brown Band']", 'Beautiful Drug'],
#        dtype='<U661'),
#  array(['94.60225818395926', "['Lata Mangeshkar']",
#         'Mehfil Mein Jal Uthi Shama'], dtype='<U661'),
#  array(['94.9557012519749', "['Exodus']", 'Low Rider - War Cover'],
#        dtype='<U661'),
#  array(['94.85865541911409', "['Les Baxter', '101 Strings Orchestra']",
#         'Boca Chica'], dtype='<U661'),
#  array(['94.88251782831526', "['Nine Inch Nails']", 'Sunspots'],
#        dtype='<U661'),
#  array(['94.66983100747429', "['Roddy Ricch']", 'Boom Boom Room'],
#        dtype='<U661'),
#  array(['94.3290372376157', "['Francisco Canaro']",
#         'Fiesta Campera - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.67641556738769', "['Эрнест Хемингуэй']",
#         'Часть 88.2 - Прощай оружие'], dtype='<U661'),
#  array(['95.17974203281044', "['Skyy']", 'Call Me'], dtype='<U661'),
#  array(['95.05788799041726', "['Melodyia Music']", 'Gotta Go My Own Way'],
#        dtype='<U661'),
#  array(['94.966748938444', "['blackbear']", 'Verbatim'], dtype='<U661'),
#  array(['94.4698144468816', "['Svend Asmussens Kvintet']", 'I Heard'],
#        dtype='<U661'),
#  array(['94.77545909796419', "['Beanie Sigel']", 'Die'], dtype='<U661'),
#  array(['94.87089608082744', "['Boney M.']", 'Malaika'], dtype='<U661'),
#  array(['95.0852374401287', "['Van Morrison']", 'I Shall Sing - Takes 2-3'],
#        dtype='<U661'),
#  array(['95.19355754140932', "['Tasmin Archer']", 'Sleeping Satellite'],
#        dtype='<U661'),
#  array(['94.42086298773623', "['Richard Rodgers']",
#         "There Is Nothin' Like a Dame"], dtype='<U661'),
#  array(['95.4848412232994', "['Pink Floyd']", 'Comfortably Numb - Live'],
#        dtype='<U661'),
#  array(['95.10027124161319', "['Bob Marley & The Wailers']",
#         'Easy Skanking - Live At Ahoy Hallen/1978'], dtype='<U661'),
#  array(['94.6848928795098', "['Claude Debussy', 'Arturo Toscanini']",
#         'Images, L. 122, 2. Ibéria: I. Par les rues et par les chemins'],
#        dtype='<U661'),
#  array(['94.9743159482132', "['Janet Jackson']", 'Because Of Love'],
#        dtype='<U661'),
#  array(['95.07829362224395',
#         "['Ivan Gough', 'Feenixpawl', 'Georgi Kay', 'Axwell']",
#         'In My Mind (feat. Georgi Kay) - Axwell Radio Edit'], dtype='<U661'),
#  array(['94.60924891842964',
#         "['Pyotr Ilyich Tchaikovsky', 'André Previn', 'London Symphony Orchestra']",
#         'Swan Lake, Op.20, Act III: 22. Neapolitan Dance (Allegro moderato - Andantino quasi moderato)'],
#        dtype='<U661'),
#  array(['94.97425649643802', "['Shirley Kwan']", '難得有情人'], dtype='<U661'),
#  array(['94.9891250056086', "['Chicago']", 'Old Days - 2002 Remaster'],
#        dtype='<U661'),
#  array(['94.88503567527955',
#         "['Wolfgang Amadeus Mozart', 'Sir Neville Marriner', 'Academy of St. Martin in the Fields']",
#         'Mozart: Serenade No. 13 in G Major, K. 525 "Eine kleine Nachtmusik": II. Romanze (Andante)'],
#        dtype='<U661'),
#  array(['94.90296753185264', "['Joseph Black']", '(i hope you) miss me'],
#        dtype='<U661'),
#  array(['94.49039633212097', "['Julie London']",
#         'In The Wee Small Hours Of The Morning'], dtype='<U661'),
#  array(['94.4204270951819', "['The Pied Pipers']",
#         "Aren't You Glad You're You"], dtype='<U661'),
#  array(['95.1585651115328', "['Stick Figure']", 'Coming Home'],
#        dtype='<U661'),
#  array(['95.05109238993843', "['Rebelution']", 'More Love'], dtype='<U661'),
#  array(['94.62867637248739', "['George Jones']", 'A Girl I Used To Know'],
#        dtype='<U661'),
#  array(['95.05734089976865', "['Janet Jackson']", 'I Get Lonely'],
#        dtype='<U661'),
#  array(['94.98398390274953', "['Dio']",
#         "Rock 'n' Roll Children - 2016 Remaster"], dtype='<U661'),
#  array(['94.6883479749506', "['Stan Kenton']",
#         "Don't Take Your Love From Me"], dtype='<U661'),
#  array(['94.86291859396437',
#         "['Andrew Lloyd Webber', 'Phantom Of The Opera Original London Cast', 'Michael Crawford', 'Sarah Brightman', 'Steve Barton']",
#         'Wandering Child / Bravo, Monsieur'], dtype='<U661'),
#  array(['94.52061876210128', "['Johann Sebastian Bach', 'Glenn Gould']",
#         'The Well-Tempered Clavier, Book 2, BWV 870-893: Prelude No. 22 in B-Flat Minor, BWV 891'],
#        dtype='<U661'),
#  array(['94.92934915157392', "['Alex Isley']", 'About Him'], dtype='<U661'),
#  array(['95.04173553775685', "['Art Blakey & The Jazz Messengers']",
#         'Children Of The Night - 2005 Remaster'], dtype='<U661'),
#  array(['95.15733982374871', "['Arc Angels']", 'Sent By Angels'],
#        dtype='<U661'),
#  array(['94.77231430268337', "['Steven Universe', 'Deedee Magno Hall']",
#         "It's Over Isn't It (feat. Deedee Magno Hall)"], dtype='<U661'),
#  array(['94.87925869122651', "['Sex Bob-Omb']", 'Garbage Truck'],
#        dtype='<U661'),
#  array(['94.8067389446538', "['ilyTOMMY']", 'Princess Bubblegum'],
#        dtype='<U661'),
#  array(['94.73260466554315', "['Jimmy Buffett']",
#         'Something So Feminine About A Mandolin'], dtype='<U661'),
#  array(['94.56669024862411', "['Frank Sinatra']", 'My Heart Stood Still'],
#        dtype='<U661'),
#  array(['94.82015545645127', "['The Plimsouls']",
#         'Oldest Story In The World'], dtype='<U661'),
#  array(['94.40204613415106', "['Samaresh Roy']", 'Ogo Amar Chiro Achena'],
#        dtype='<U661'),
#  array(['94.81267124718578', "['Crazy Cavan', 'The Rhythm Rockers']",
#         'My Little Sister Gotta Motorbike'], dtype='<U661'),
#  array(['94.55103860503013', "['The Beach Boys']",
#         'Noble Surfer - Remastered 2001'], dtype='<U661'),
#  array(['94.50523524315614', "['Billie Holiday', 'Count Basie']",
#         "I Can't Get Started - Take 2"], dtype='<U661'),
#  array(['94.8075836390601', "['José José']", 'El Amor Acaba'],
#        dtype='<U661'),
#  array(['95.00234963342845', "['Ill Niño']", 'How Can I Live'],
#        dtype='<U661'),
#  array(['95.0870306665336', "['The Police']", 'One World (Not Three)'],
#        dtype='<U661'),
#  array(['94.50177269186607',
#         "['Musikkorps der 1. Gebirgsdivision Garmisch-Partenkirchen & der Chor des Gebirgsfernmeldebataillons 8, Mittenwald; Leitung Herbert Zimmermann']",
#         'Die Jägerbraut'], dtype='<U661'),
#  array(['94.92246304517317', "['Boogie Down Productions']",
#         'Criminal Minded'], dtype='<U661'),
#  array(['94.77629616687517', "['The Dillards']", 'Somebody Touched Me'],
#        dtype='<U661'),
#  array(['94.44634640881918',
#         "['Richard Strauss', 'Bavarian State Orchestra']",
#         'Don Quixote Op.35: III Variation II: The Battle with the Sheep'],
#        dtype='<U661'),
#  array(['94.64116706534537',
#         "['George Frideric Handel', 'Simon Standage', 'Elizabeth Wilcock', 'The English Concert', 'Trevor Pinnock']",
#         'Water Music Suite No.1 In F, HWV 348: 1. Ouverture (Grave - Allegro)'],
#        dtype='<U661'),
#  array(['94.49874458082903', "['Wade Hemsworth']",
#         'Ye Girls of Old Ontario'], dtype='<U661'),
#  array(['95.04102297054152', "['Dom Dolla', 'Go Freek']", 'Define'],
#        dtype='<U661'),
#  array(['95.12938090816021', "['Mecano']", 'La Fuerza del Destino'],
#        dtype='<U661'),
#  array(['94.60887500797006', "['Maurice Ravel', 'Robert Casadesus']",
#         'Gaspard de la Nuit, M. 55: II. Le Gibet'], dtype='<U661'),
#  array(['94.68610550910186', "['Irma Thomas']", "I've Been There"],
#        dtype='<U661'),
#  array(['94.49715040557683', "['The Almanac Singers']",
#         'Get Thee Behind Me, Satan'], dtype='<U661'),
#  array(['94.95116174662189', "['Whitney Houston']", 'All at Once'],
#        dtype='<U661'),
#  array(['95.06570053070759', "['Gregory Isaacs']", 'Not The Way'],
#        dtype='<U661'),
#  array(['94.80919369094286', "['Calvin Harris', 'Big Sean']",
#         'Open Wide (feat. Big Sean)'], dtype='<U661'),
#  array(['95.01598972221943', "['Thin Lizzy']", 'Romeo And The Lonely Girl'],
#        dtype='<U661'),
#  array(['94.92347997118277', "['Townes Van Zandt']", 'Where I Lead Me'],
#        dtype='<U661'),
#  array(['94.5662129529816', "['Cuco Sánchez']",
#         'Que Si Te Quiero?, Júralo'], dtype='<U661'),
#  array(['95.19568769051337', "['Whodini']", "I'm a Ho"], dtype='<U661'),
#  array(['94.46413435458531', "['Noro Morales']", 'Palmeras'], dtype='<U661'),
#  array(['94.82914956912306', "['Ty Herndon']", 'What Mattered Most'],
#        dtype='<U661'),
#  array(['94.57311165357375', "['Ernestine Anderson']",
#         "They Didn't Believe Me"], dtype='<U661'),
#  array(['94.74558462181298', "['Louis The Child', 'K.Flay']",
#         "It's Strange"], dtype='<U661'),
#  array(['94.8792758494666', "['The Raincoats']",
#         'Fairytale in the Supermarket'], dtype='<U661'),
#  array(['94.7351882125793', "['Ghantasala']", 'Hrudayamaa'], dtype='<U661'),
#  array(['94.65711771295288', "['Johann Sebastian Bach', 'Claudio Arrau']",
#         'Goldberg Variations, BWV 988: Variation XIII'], dtype='<U661'),
#  array(['95.13960010614123', "['The 1975']",
#         'If You’re Too Shy (Let Me Know)'], dtype='<U661'),
#  array(['94.70347663939971', "['Grant Green']", "We've Only Just Begun"],
#        dtype='<U661'),
#  array(['94.4773012418174', "['Peggy Lee']", 'Full Moon'], dtype='<U661'),
#  array(['95.1043689724438', "['J Balvin', 'Willy William']", 'Mi Gente'],
#        dtype='<U661'),
#  array(['94.69006977701794', "['Artie Morris']", 'Come on over to Jesus'],
#        dtype='<U661'),
#  array(['94.76000993427193', "['Bon Iver']", '29 #Strafford APTS'],
#        dtype='<U661'),
#  array(['94.80842918881733', "['Pink Floyd']", 'Flaming'], dtype='<U661'),
#  array(['94.96751483632369', "['Ike & Tina Turner']",
#         'Son Of A Preacher Man - Live From Madison Square Garden, New York/1969'],
#        dtype='<U661'),
#  array(['94.49411159760649', "['Frédéric Chopin', 'William Kapell']",
#         'Mazurka in A-flat, Op. 17, No.3'], dtype='<U661'),
#  array(['95.06049147072751', "['Ronnie Milsap']", 'Back On My Mind Again'],
#        dtype='<U661'),
#  array(['94.77650371984315', "['Slum Village']", 'The Look of Love, Pt. 1'],
#        dtype='<U661'),
#  array(['95.00007662098739', "['Elvis Costello & The Attractions']",
#         'Opportunity'], dtype='<U661'),
#  array(['94.94959024537816', "['Ken Ashcorp']", 'Touch Fluffy Tail'],
#        dtype='<U661'),
#  array(['94.51288684241035', "['Peter, Paul and Mary']", 'Mockingbird'],
#        dtype='<U661'),
#  array(['94.98129964242365', "['Miles Davis And Milt Jackson Sextet']",
#         'Minor March'], dtype='<U661'),
#  array(['94.86979788338706', "['Prabhakar Karekar']",
#         'Vimal Adhar Nikati Mohha Papi'], dtype='<U661'),
#  array(['94.79047211372882', "['Bazzi']", 'I Got You'], dtype='<U661'),
#  array(['94.96408385438554', "['Journey']", 'Rubicon'], dtype='<U661'),
#  array(['95.18147943697768', "['Bruno Mars', 'Passion Pit']",
#         'Grenade - Passion Pit Remix'], dtype='<U661'),
#  array(['95.14124856196794', "['ZZ Top']", 'Planet of Women'],
#        dtype='<U661'),
#  array(['94.41382192211574', "['Billie Holiday']",
#         'Practice Makes Perfect - Take 4'], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
