# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=5001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Imagine Dragons']", 'Thunder'],
#         ["['Rachel Platten']", 'Fight Song'],
#         ["['Sia']", 'Together'],
#         ...,
#         ["['Taylor Swift']", 'Long Live'],
#         ["['Sam Smith']", 'Money On My Mind'],
#         ["['Foo Fighters']", 'Generator']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.015

# %%
relevance
# Out:
# 24.999999999997158

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.column_stack((predictions, song_info[:,0], song_info[:,1]))

# %%
sort_indices = np.argsort(predictions)[::-1]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[sort_indices]

# %%
list(predicted)
# Out:
# [array(['81.91456458402585', "['Misfits', 'Glenn Danzig']",
#         'Spinal Remains'], dtype='<U661'),
#  array(['81.7325377829686', "['Bad Brains']",
#         'F.V.K. (Fearless Vampire Killers)'], dtype='<U661'),
#  array(['81.58052566499987', "['Bad Brains']", 'Attitude'], dtype='<U661'),
#  array(['81.48854497723488', "['Misfits']", 'Wolfs Blood'], dtype='<U661'),
#  array(['81.48092661027138', "['Bad Brains']", "Don't Need It"],
#        dtype='<U661'),
#  array(['81.29606132611488', "['Descendents']", 'Pervert'], dtype='<U661'),
#  array(['81.16387908696754', "['Misfits']", 'Bullet'], dtype='<U661'),
#  array(['81.15881279055405', "['FIDLAR']", 'Cheap Beer'], dtype='<U661'),
#  array(['81.15111974425358', "['Conflict']", 'C.R.A.S.S.'], dtype='<U661'),
#  array(['81.11404549401826', "['Choke']", 'Slum Radio'], dtype='<U661'),
#  array(['81.0467444326703', "['blink-182']", 'Blow Job - Live/1999'],
#        dtype='<U661'),
#  array(['81.04260163955396', "['Misfits']", 'Wolfs Blood'], dtype='<U661'),
#  array(['81.02464749586561', "['Korn']", 'Dead'], dtype='<U661'),
#  array(['80.95606409184467', "['Misfits']", 'Demonomania'], dtype='<U661'),
#  array(['80.90304753107493', "['blink-182']", 'Go'], dtype='<U661'),
#  array(['80.87799323558447', "['mysticphonk', 'Lil Peep']", 'Haunt U'],
#        dtype='<U661'),
#  array(['80.86913975262428', "['Bad Brains']", 'Pay to Cum'], dtype='<U661'),
#  array(['80.85060216628676', "['blink-182']", 'Dammit'], dtype='<U661'),
#  array(['80.84831143260205', "['iann dior']", 'pouring'], dtype='<U661'),
#  array(['80.84164840189722', "['Subhumans']", 'Minority'], dtype='<U661'),
#  array(['80.82548704938361', "['The Dead Milkmen']", 'Big Lizard'],
#        dtype='<U661'),
#  array(['80.81046886672921', "['lil aaron']", 'DRUGS'], dtype='<U661'),
#  array(['80.78973703081466', "['Kanye West']", "I'll Fly Away"],
#        dtype='<U661'),
#  array(['80.7602304695164', "['Bad Brains']", "Sailin' On"], dtype='<U661'),
#  array(['80.74807511405898', "['Korn']", 'Wish You Could Be Me'],
#        dtype='<U661'),
#  array(['80.73989001606279', "['blink-182']", 'Sometimes'], dtype='<U661'),
#  array(['80.69672575450548', "['Metallica']", 'Hardwired'], dtype='<U661'),
#  array(['80.66849071955006', "['Misfits']",
#         'Mommy Can I Go out and Kill Tonight - Live'], dtype='<U661'),
#  array(['80.65528596961482', "['Frank Ocean']", 'Pretty Sweet'],
#        dtype='<U661'),
#  array(['80.64537360729356', "['Bad Brains']", 'The Regulator'],
#        dtype='<U661'),
#  array(['80.63448671415173', "['blink-182']", 'Man Overboard'],
#        dtype='<U661'),
#  array(['80.61015147715788', "['blink-182']",
#         'Happy Holidays, You Bastard'], dtype='<U661'),
#  array(['80.58673167264467', "['The Replacements']",
#         'I.O.U. - 2008 Remaster'], dtype='<U661'),
#  array(['80.58634786250653', "['Mac Miller']", 'Best Day Ever'],
#        dtype='<U661'),
#  array(['80.51601064225639', "['Green Day']", 'Jaded'], dtype='<U661'),
#  array(['80.50834120614115', "['Eminem', 'Jeff Bass', 'Mark Bass']",
#         'Lounge - Skit'], dtype='<U661'),
#  array(['80.50807424570397', "['Rihanna']", 'James Joint'], dtype='<U661'),
#  array(['80.50289691964481', "['Misfits']", 'Braineaters'], dtype='<U661'),
#  array(['80.49887242269027', "['Ariana Grande']",
#         'raindrops (an angel cried)'], dtype='<U661'),
#  array(['80.48315287285459', "['Tesla']", 'Signs'], dtype='<U661'),
#  array(['80.47057610307073', "['Misfits', 'Glenn Danzig']", 'Angelfuck'],
#        dtype='<U661'),
#  array(['80.44355710269892', "['Lil Peep']", 'Honestly'], dtype='<U661'),
#  array(['80.43733672628942', "['Eminem', 'Jeff Bass', 'Mark Bass']",
#         'Lounge - Skit'], dtype='<U661'),
#  array(['80.43107718782545', "['blink-182']", 'Man Overboard'],
#        dtype='<U661'),
#  array(['80.42731440978608', "['Rihanna']", 'Higher'], dtype='<U661'),
#  array(['80.42315303384208', "['Bad Brains']", 'I'], dtype='<U661'),
#  array(['80.41255692661544', "['Subhumans']", 'Killing'], dtype='<U661'),
#  array(['80.3988336064502', "['Misfits']", 'Angelfuck'], dtype='<U661'),
#  array(['80.39558089187553', "['Misfits']", 'Attitude'], dtype='<U661'),
#  array(['80.37999971435733', "['Deftones']", 'Street Carp'], dtype='<U661'),
#  array(['80.37428207303196', "['Bad Brains']", 'Supertouch/Shitfit'],
#        dtype='<U661'),
#  array(['80.36542451883695', "['Gang Green']", 'Alcohol'], dtype='<U661'),
#  array(['80.36409822590613', "['Gang Green']", 'Skate To Hell'],
#        dtype='<U661'),
#  array(['80.35797338850664', "['Eminem']", 'Curtains Up'], dtype='<U661'),
#  array(['80.33099519197431', "['Bad Religion']", 'Turn On the Light'],
#        dtype='<U661'),
#  array(['80.33048847518768', "['JFA']", 'Out of School'], dtype='<U661'),
#  array(['80.32935384840229', "['Upchurch']", 'Son of the South'],
#        dtype='<U661'),
#  array(['80.31140641784697', "['Misfits']", 'I Turned into a Martian'],
#        dtype='<U661'),
#  array(['80.30731855747108', "['PARTYNEXTDOOR']", 'Break from Toronto'],
#        dtype='<U661'),
#  array(['80.30114653594663', "['Suicidal Tendencies']",
#         'Feel Like Shit...Deja-Vu'], dtype='<U661'),
#  array(['80.30099222806396', "['Circle Jerks']", 'Parade Of The Horribles'],
#        dtype='<U661'),
#  array(['80.29530522278105', "['XXXTENTACION']",
#         "I Don't Wanna Do This Anymore"], dtype='<U661'),
#  array(['80.28932441915784', "['Discharge']", "I Won't Subscribe"],
#        dtype='<U661'),
#  array(['80.25942662104514', "['I Prevail']", 'Gasoline'], dtype='<U661'),
#  array(['80.25939164569559', "['Misfits']", 'Attitude'], dtype='<U661'),
#  array(['80.23854754145721', "['Roar']", 'Christmas Kids'], dtype='<U661'),
#  array(['80.23300691741277', "['Youth Of Today']", 'Make a Change'],
#        dtype='<U661'),
#  array(['80.22777145891982', "['Bad Religion']", 'Do What You Want'],
#        dtype='<U661'),
#  array(['80.22255790886116', "['blink-182']", 'Obvious'], dtype='<U661'),
#  array(['80.22044551457948', "['Tesla']",
#         'Signs - Live At The Trocadero / 1990'], dtype='<U661'),
#  array(['80.20459138453043', "['Lil Skies']", 'No Rest'], dtype='<U661'),
#  array(['80.18709068333484', "['YG']", 'BPT'], dtype='<U661'),
#  array(['80.1740554555904', "['A$AP Rocky']",
#         'Lord Pretty Flacko Jodye 2 (LPFJ2)'], dtype='<U661'),
#  array(['80.17332095309408', "['Marilyn Manson']", 'Little Horn'],
#        dtype='<U661'),
#  array(['80.16355552138351', "['Bad Religion']", 'What Can You Do?'],
#        dtype='<U661'),
#  array(['80.15154204912005', "['Jim Morrison']", 'The Movie'],
#        dtype='<U661'),
#  array(['80.13565785909319', "['System Of A Down']", 'Boom!'],
#        dtype='<U661'),
#  array(['80.13386408914371', "['The Offspring']", 'One Fine Day'],
#        dtype='<U661'),
#  array(['80.13343929489245', "['Tyler, The Creator']", 'Sometimes...'],
#        dtype='<U661'),
#  array(['80.12714635389719', "['Sick Puppies']", 'Gunfight'], dtype='<U661'),
#  array(['80.12597666735742', "['Stiff Little Fingers']", 'Suspect Device'],
#        dtype='<U661'),
#  array(['80.11140646218556', "['Lil Peep']", 'Cry Alone'], dtype='<U661'),
#  array(['80.11064023250515', "['CHVRCHES']", 'The Mother We Share'],
#        dtype='<U661'),
#  array(['80.10949287176321', "['Ween']", 'You Fucked Up'], dtype='<U661'),
#  array(['80.10042868504087', "['XXXTENTACION']", 'King'], dtype='<U661'),
#  array(['80.09590232739633', "['Roar']", "I Can't Handle Change"],
#        dtype='<U661'),
#  array(['80.09017019905706', "['Big Black']", 'Big Money'], dtype='<U661'),
#  array(['80.08713667069881', "['XXXTENTACION']", 'Dead Inside (Interlude)'],
#        dtype='<U661'),
#  array(['80.08568167394958', "['Mac Miller']", 'Youforia'], dtype='<U661'),
#  array(['80.0750969365797', "['Iron Chic']", 'Cutesy Monster Man'],
#        dtype='<U661'),
#  array(['80.07149436994898', "['T.S.O.L.']", 'Superficial Love'],
#        dtype='<U661'),
#  array(['80.06089472404602', "['Hatebreed']",
#         'Looking Down the Barrel of Today'], dtype='<U661'),
#  array(['80.05989265342154', "['Lil Peep']", 'driveway'], dtype='<U661'),
#  array(['80.05219814222544', "['Lil Peep']", 'yesterday'], dtype='<U661'),
#  array(['80.04752286548394', "['Green Day']", 'The Grouch'], dtype='<U661'),
#  array(['80.04702487760244', "['Seether']", 'FMLYHM'], dtype='<U661'),
#  array(['80.0379694523859', "['Chief Keef']", "That's It"], dtype='<U661'),
#  array(['80.03703901897737', "['Social Distortion']",
#         "Don't Take Me For Granted"], dtype='<U661'),
#  array(['80.03408897737799', "['Bad Religion']", 'You'], dtype='<U661'),
#  array(['80.01992337837447', "['Cage The Elephant']",
#         "Back Stabbin' Betty"], dtype='<U661'),
#  array(['80.01579487454156', "['The 1975']", 'Give Yourself A Try'],
#        dtype='<U661'),
#  array(['80.00901926259615', "['blink-182']", "Here's Your Letter"],
#        dtype='<U661'),
#  array(['80.00868684090551', "['Dr. Know']", 'Mr. Freeze'], dtype='<U661'),
#  array(['80.00806942835752', "['Rage Against The Machine']", 'Tire Me'],
#        dtype='<U661'),
#  array(['79.9989089439884', "['Misfits']", 'Bullet'], dtype='<U661'),
#  array(['79.99853685887896', "['Butthole Surfers']", "Goofy's Concern"],
#        dtype='<U661'),
#  array(['79.98735798215361', "['Arctic Monkeys']",
#         'This House Is a Circus'], dtype='<U661'),
#  array(['79.98354866240362', "['Fear']", "I Don't Care About You"],
#        dtype='<U661'),
#  array(['79.97248983198791', "['Fear']", 'Gimme Some Action'],
#        dtype='<U661'),
#  array(['79.9715581006704', "['Green Day']", 'Stuck with Me'],
#        dtype='<U661'),
#  array(['79.96638627103563', "['Green Day']", 'All the Time'],
#        dtype='<U661'),
#  array(['79.96630220701802', "['Rodney Carrington']", "Don't Look Now"],
#        dtype='<U661'),
#  array(['79.96495154513661', "['The Pogues']", 'Bottle of Smoke'],
#        dtype='<U661'),
#  array(['79.96222654091076', "['Yunggoth✰']", 'Idk How to Kill Myself'],
#        dtype='<U661'),
#  array(['79.95952057968832', "['Rex Orange County']", '10/10'],
#        dtype='<U661'),
#  array(['79.95302574847423', "['Misfits']", 'Astro Zombies'], dtype='<U661'),
#  array(['79.94884558670515', "['Houndmouth']", 'My Cousin Greg'],
#        dtype='<U661'),
#  array(['79.94632300921148', "['Lil Peep']", 'drugz'], dtype='<U661'),
#  array(['79.94597489801866', "['The Dead Milkmen']", 'Serrated Edge'],
#        dtype='<U661'),
#  array(['79.94454677436433', "['The Vaccines']", 'Post Break-Up Sex'],
#        dtype='<U661'),
#  array(['79.94272881270354', "['Rihanna']", 'Birthday Cake'], dtype='<U661'),
#  array(['79.94202843327729', "['Staind']", 'All I Want'], dtype='<U661'),
#  array(['79.94037780702742', "['Slipknot']", 'Spit It Out'], dtype='<U661'),
#  array(['79.93019685524473', "['Green Day']", 'American Idiot'],
#        dtype='<U661'),
#  array(['79.92616210514386', "['The 1975']", 'Me & You Together Song'],
#        dtype='<U661'),
#  array(['79.92487384723823', "['blink-182']", 'Dick Lips - Live/1999'],
#        dtype='<U661'),
#  array(['79.92410875278603', "['Green Day']", 'American Idiot'],
#        dtype='<U661'),
#  array(['79.92404458214024', "['Tenacious D']", 'Friendship'],
#        dtype='<U661'),
#  array(['79.92148442794894', "['I Prevail']", 'Bow Down'], dtype='<U661'),
#  array(['79.91417024575298', "['Mac Miller']", 'Loud'], dtype='<U661'),
#  array(['79.9134981933646', "['Witchfinder General']", 'Free Country'],
#        dtype='<U661'),
#  array(['79.91226363246993', "['Rihanna']", 'Birthday Cake'], dtype='<U661'),
#  array(['79.91116418593121', "['Wasted Youth']", 'Fuck Authority'],
#        dtype='<U661'),
#  array(['79.89806180610938', "['YUNGBLUD']", 'Weird!'], dtype='<U661'),
#  array(['79.89717553701607', "['Koe Wetzel']", 'Kuntry & Wistern'],
#        dtype='<U661'),
#  array(['79.89248317875102', "['Lil Nas X', 'Nas']", 'Rodeo - feat. Nas'],
#        dtype='<U661'),
#  array(['79.8914287622655', "['Green Day']", 'Worry Rock'], dtype='<U661'),
#  array(['79.89063135930891', "['ROLE MODEL']", 'minimal'], dtype='<U661'),
#  array(['79.88672850211819', "['Mac Miller']", 'Loud'], dtype='<U661'),
#  array(['79.88196962384598', "['Sum 41']",
#         'Over My Head (Better Off Dead)'], dtype='<U661'),
#  array(['79.87904350099545', "['Alkaline Trio']", "We've Had Enough"],
#        dtype='<U661'),
#  array(['79.87709437479994', "['Oliver Tree']", 'Miracle Man'],
#        dtype='<U661'),
#  array(['79.87392832623222', "['+44']", 'Baby Come On'], dtype='<U661'),
#  array(['79.87346328311294', "['Lil Peep', 'Lil Tracy']", 'cobain'],
#        dtype='<U661'),
#  array(['79.86940986128336', "['Halestorm']", "Here's to Us"],
#        dtype='<U661'),
#  array(['79.8675380875484', "['jxdn']", 'Angels & Demons'], dtype='<U661'),
#  array(['79.86481847894082', "['Upchurch']", 'Pond Creek Road'],
#        dtype='<U661'),
#  array(['79.86361673822859', "['T.S.O.L.']",
#         'Abolish Government/Silent Majority'], dtype='<U661'),
#  array(['79.86131734854304', "['Ariana Grande']", 'pete davidson'],
#        dtype='<U661'),
#  array(['79.85845285291295', "['Lil Peep']",
#         'skyscrapers (love now, cry later)'], dtype='<U661'),
#  array(['79.85747130323965', "['Eels']", 'Novocaine For The Soul'],
#        dtype='<U661'),
#  array(['79.85539502624229', "['Skid Row']", 'Get the Fuck Out'],
#        dtype='<U661'),
#  array(['79.85486258756926', "['Wheeler Walker Jr.']", 'Redneck Shit'],
#        dtype='<U661'),
#  array(['79.84665584290796', "['Oliver Tree']", 'Hurt'], dtype='<U661'),
#  array(['79.84477383223958', "['Ski Mask The Slump God']", 'So High'],
#        dtype='<U661'),
#  array(['79.8440467339028', "['Fame on Fire']", 'XO TOUR Llif3'],
#        dtype='<U661'),
#  array(['79.8428524594134', "['The Adverts']", 'One Chord Wonders'],
#        dtype='<U661'),
#  array(['79.84254692993146', "['Misfits']", 'Hatebreeders'], dtype='<U661'),
#  array(['79.84148644749725', "['Aries']", 'CAROUSEL'], dtype='<U661'),
#  array(['79.84104042826111', "['blink-182']", 'Dysentery Gary'],
#        dtype='<U661'),
#  array(['79.83941654152011', "['The Dead Milkmen']", 'V.f.w.'],
#        dtype='<U661'),
#  array(['79.83748495534067', "['Bass Mekanik']", '65 Hz Test Tone'],
#        dtype='<U661'),
#  array(['79.83334512132213', "['Bring Me The Horizon']", 'Happy Song'],
#        dtype='<U661'),
#  array(['79.83249869803274', "['Highly Suspect']", 'Bath Salts'],
#        dtype='<U661'),
#  array(['79.83131071022903', "['Joji']", "I Don't Wanna Waste My Time"],
#        dtype='<U661'),
#  array(['79.82672019714775', "['Bring Me The Horizon']", 'Happy Song'],
#        dtype='<U661'),
#  array(['79.82441337495949', "['Bad Religion']",
#         'The Positive Aspect of Negative Thinking'], dtype='<U661'),
#  array(['79.8227069376322', "['Bratmobile']", 'Gimme Brains'],
#        dtype='<U661'),
#  array(['79.82231341811398', "['Elle King']", 'My Neck, My Back - Live'],
#        dtype='<U661'),
#  array(['79.81929083889422', "['Less Than Jake']", 'Automatic'],
#        dtype='<U661'),
#  array(['79.81902768407527', "['blink-182']", 'Feeling This'],
#        dtype='<U661'),
#  array(['79.81526728310051', "['T.S.O.L.']", 'Code Blue'], dtype='<U661'),
#  array(['79.81381878917684', "['Cheat Codes', 'Fetty Wap', 'CVBZ']",
#         'Feels Great (feat. Fetty Wap & CVBZ)'], dtype='<U661'),
#  array(['79.81292726006865', "['BROCKHAMPTON']", 'WASTE'], dtype='<U661'),
#  array(['79.80238670874313', "['The Jam']", 'The Modern World'],
#        dtype='<U661'),
#  array(['79.79805558944346', "['Machine Gun Kelly']", 'why are you here'],
#        dtype='<U661'),
#  array(['79.79561075093739', "['Authority Zero']", 'Mexican Radio'],
#        dtype='<U661'),
#  array(['79.78535508217666', "['Mindless Self Indulgence']", "Boomin'"],
#        dtype='<U661'),
#  array(['79.78237022868248', "['Subhumans']", 'Ashtray Dirt'],
#        dtype='<U661'),
#  array(['79.77639936483287', "['Nine Inch Nails']", 'Big Man With A Gun'],
#        dtype='<U661'),
#  array(['79.77597682061187', "['Marilyn Manson']", 'Dogma'], dtype='<U661'),
#  array(['79.77528027109935', "['Josh A', 'Iamjakehill']",
#         'Endless Nightmare'], dtype='<U661'),
#  array(['79.76945161440433', "['Gorilla Biscuits']", 'Degradation'],
#        dtype='<U661'),
#  array(['79.7676319614859', "['Daron Malakian and Scars On Broadway']",
#         'They Say'], dtype='<U661'),
#  array(['79.766257219812', "['Municipal Waste']", 'The Art of Partying'],
#        dtype='<U661'),
#  array(['79.76625213380933', "['The Suicide Machines']",
#         "Sometimes I Don't Mind"], dtype='<U661'),
#  array(['79.76227680990078', "['T.S.O.L.']", "I'm Tired of Life"],
#        dtype='<U661'),
#  array(['79.76070084164779', "['Slipknot']", 'Spit It Out'], dtype='<U661'),
#  array(['79.75775208752933', '["Jack\'s Mannequin"]',
#         'Holiday from Real - 2015 Remastered'], dtype='<U661'),
#  array(['79.75740059245307',
#         "['Tech N9ne Collabos', 'Serj Tankian', 'John 5', 'Krizz Kaliko']",
#         'Straight Out the Gate: (The Scott Stevens Remix) - Bonus Track'],
#        dtype='<U661'),
#  array(['79.75603037093715', "['Five Finger Death Punch']",
#         'Boots and Blood'], dtype='<U661'),
#  array(['79.75425271169433', "['Eels']", 'Novocaine For The Soul'],
#        dtype='<U661'),
#  array(['79.75202676140793', "['Lil Mosey']", 'Bust Down Cartier'],
#        dtype='<U661'),
#  array(['79.7505185766918', "['iann dior']", 'Flowers'], dtype='<U661'),
#  array(['79.74921253118791', "['System Of A Down']", 'Cigaro'],
#        dtype='<U661'),
#  array(['79.74730325946864', "['Juice WRLD', 'Brent Faiyaz']",
#         'Demonz (feat. Brent Faiyaz) - Interlude'], dtype='<U661'),
#  array(['79.746893229038', "['McCafferty']", 'Dead-Bird'], dtype='<U661'),
#  array(['79.74596678386045', "['Special Duties']", 'Violent Society'],
#        dtype='<U661'),
#  array(['79.74470177108894', '["Panucci\'s Pizza"]',
#         'Naruto Themed Sexting'], dtype='<U661'),
#  array(['79.74443058217635', "['YNW Melly']", 'City Girls'], dtype='<U661'),
#  array(['79.7416352080463', "['Dwarves']", 'Everybodies Girl'],
#        dtype='<U661'),
#  array(['79.73993356941301', "['The Amity Affliction']", 'Drag the Lake'],
#        dtype='<U661'),
#  array(['79.73520844705173', "['Koe Wetzel']", 'Forever'], dtype='<U661'),
#  array(['79.73273461353507', "['Tyler, The Creator']",
#         'ARE WE STILL FRIENDS?'], dtype='<U661'),
#  array(['79.72600030724608', "['$uicideBoy$']", 'Champion Of Death'],
#        dtype='<U661'),
#  array(['79.72568339669273', "['Madvillain']", 'Supervillain Theme'],
#        dtype='<U661'),
#  array(['79.7246929522814', "['Girls']", 'Lust For Life'], dtype='<U661'),
#  array(['79.7241017311173', "['Bird & Macdonald']", 'Rodeo Song'],
#        dtype='<U661'),
#  array(['79.72249111651018', "['T.S.O.L.']", 'The Triangle'], dtype='<U661'),
#  array(['79.71402482369987', "['Five Finger Death Punch']", 'Dying Breed'],
#        dtype='<U661'),
#  array(['79.71285293606026', "['The 1975']", 'Love It If We Made It'],
#        dtype='<U661'),
#  array(['79.70991583001963', "['Machine Gun Kelly', 'Planet Vi']",
#         "Runnin'"], dtype='<U661'),
#  array(['79.70192513271692', "['My Chemical Romance']",
#         'You Know What They Do to Guys Like Us in Prison'], dtype='<U661'),
#  array(['79.69953588241344', "['Korn']", "It's Gonna Go Away"],
#        dtype='<U661'),
#  array(['79.6972574124339', "['Adelitas Way']", 'Invincible'],
#        dtype='<U661'),
#  array(['79.69137968598884', "['blink-182']", 'Pathetic'], dtype='<U661'),
#  array(['79.68985973834072', "['ScHoolboy Q', 'Kid Cudi']",
#         'Dangerous (feat. Kid Cudi)'], dtype='<U661'),
#  array(['79.68917887276156', "['Three Days Grace']", 'Wake Up'],
#        dtype='<U661'),
#  array(['79.68692890879602', "['Ben Folds Five']", 'Army'], dtype='<U661'),
#  array(['79.68497118829879', "['Rozei']", 'Ooo La La'], dtype='<U661'),
#  array(['79.68088671309812', "['Avicii', 'Sandro Cavazza']", 'Without You'],
#        dtype='<U661'),
#  array(['79.67830881666401', "['The Offspring']", 'Mota'], dtype='<U661'),
#  array(['79.67736363261432', "['Five Finger Death Punch']",
#         'This Is My War'], dtype='<U661'),
#  array(['79.67644802388925', "['$uicideBoy$']", 'Exodus'], dtype='<U661'),
#  array(['79.6703881809643', "['blink-182']", 'Pathetic'], dtype='<U661'),
#  array(['79.66992616945623', "['Modern Baseball']", 'Rock Bottom'],
#        dtype='<U661'),
#  array(['79.66883324539273', "['The Offspring']",
#         'Slim Pickens Does The Right Thing And Rides The Bomb To Hell'],
#        dtype='<U661'),
#  array(['79.66728461397727', "['The Adicts']",
#         'My Baby Got Run Over By A Steamroller'], dtype='<U661'),
#  array(['79.66259727050479', "['The Dead Milkmen']", 'Nutrition'],
#        dtype='<U661'),
#  array(['79.66153635245585', "['Hollywood Undead']", 'Pigskin'],
#        dtype='<U661'),
#  array(['79.6605553693157', "['Juice WRLD']", 'Rider'], dtype='<U661'),
#  array(['79.65638293462015', "['Aries']", 'RACECAR'], dtype='<U661'),
#  array(['79.65536499233585',
#         "['Machine Gun Kelly', 'YUNGBLUD', 'Travis Barker']",
#         "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"], dtype='<U661'),
#  array(['79.65517066880633', "['Big Black']", 'L Dopa'], dtype='<U661'),
#  array(['79.65367407994556', "['Jon Bellion']",
#         'Conversations with my Wife'], dtype='<U661'),
#  array(['79.65065934008818', "['Austin Awake']", 'ALL IN'], dtype='<U661'),
#  array(['79.65013640322047', "['Attila']", 'Middle Fingers Up'],
#        dtype='<U661'),
#  array(['79.64538627158092', "['Guided By Voices']",
#         'As We Go Up, We Go Down'], dtype='<U661'),
#  array(['79.64470914433848', "['Josh A', 'Iamjakehill']",
#         'Suicidal Thoughts'], dtype='<U661'),
#  array(['79.64232320178368', "['System Of A Down']", "She's Like Heroin"],
#        dtype='<U661'),
#  array(['79.64135582613532', "['Sublime']", 'Mary'], dtype='<U661'),
#  array(['79.64041977235571', "['Wire']",
#         'Mr Suit - 2006 Remastered Version'], dtype='<U661'),
#  array(['79.63726239223958', "['Motörhead']", '(We Are) The Roadcrew'],
#        dtype='<U661'),
#  array(['79.63604202905626', "['Bone Thugs-N-Harmony']", 'Mr. Quija'],
#        dtype='<U661'),
#  array(['79.63438872720832', "['Green Day']", 'Jinx'], dtype='<U661'),
#  array(['79.63305763177236', "['The Suicide Machines']", 'New Girl'],
#        dtype='<U661'),
#  array(['79.63163835761792', "['My Chemical Romance']",
#         "I'm Not Okay (I Promise)"], dtype='<U661'),
#  array(['79.63107126929863', "['blink-182']", 'The Rock Show'],
#        dtype='<U661'),
#  array(['79.63062317672858', "['Travis Scott']", 'NC-17'], dtype='<U661'),
#  array(['79.62983576251384', "['Three Days Grace']", 'Gone Forever'],
#        dtype='<U661'),
#  array(['79.62911617832445', "['W.A.S.P.']", "I Don't Need No Doctor"],
#        dtype='<U661'),
#  array(['79.6279160006912', "['Big Black']", 'Passing Complexion'],
#        dtype='<U661'),
#  array(['79.62786938549759', "['Foo Fighters']", 'Something from Nothing'],
#        dtype='<U661'),
#  array(['79.62775157808656', "['Box Car Racer']", 'Sorrow'], dtype='<U661'),
#  array(['79.62769177568939', "['Danzig']", 'Long Way Back From Hell'],
#        dtype='<U661'),
#  array(['79.62458823532539', "['iann dior', 'Trippie Redd']", 'gone girl'],
#        dtype='<U661'),
#  array(['79.62458009420281', "['The Used']", "All That I've Got"],
#        dtype='<U661'),
#  array(['79.62450624421035', "['Lil Nas X', 'Cardi B']", 'Rodeo'],
#        dtype='<U661'),
#  array(['79.62260012381687', "['Three Days Grace']", 'Wake Up'],
#        dtype='<U661'),
#  array(['79.62178314459825', "['$uicideBoy$']", 'Do You Believe In God?'],
#        dtype='<U661'),
#  array(['79.62046090119472', "['My Chemical Romance']",
#         "I'm Not Okay (I Promise)"], dtype='<U661'),
#  array(['79.61509647235789', "['Car Seat Headrest']", 'Fill in the Blank'],
#        dtype='<U661'),
#  array(['79.61464331824268', "['Marietta']", 'Cinco De Mayo Shit Show'],
#        dtype='<U661'),
#  array(['79.61463448724922', "['iann dior', 'Trippie Redd']", 'gone girl'],
#        dtype='<U661'),
#  array(['79.61250814815396', "['The Suicide Machines']", 'No Face'],
#        dtype='<U661'),
#  array(['79.61238359605908', "['iann dior', 'Travis Barker']", 'Darkside'],
#        dtype='<U661'),
#  array(['79.60999583702309', "['Skye', 'XXXTENTACION']",
#         'VOICES (feat. XXXTENTACION)'], dtype='<U661'),
#  array(['79.60554555614274', "['Gorilla Biscuits']", 'Start Today'],
#        dtype='<U661'),
#  array(['79.60312255439533', "['6LACK']", 'Switch'], dtype='<U661'),
#  array(['79.60112753891356', "['Barrett Wilbert Weed']", 'Fight for Me'],
#        dtype='<U661'),
#  array(['79.59874049645109', "['Machine Gun Kelly', 'Cassie']",
#         'Warning Shot'], dtype='<U661'),
#  array(['79.59255811259688', "['Trippie Redd']", 'The Grinch'],
#        dtype='<U661'),
#  array(['79.5924265417996', "['blink-182']", 'Pathetic - Live/1999'],
#        dtype='<U661'),
#  array(['79.59122674139404', "['girl in red']", 'bad idea!'], dtype='<U661'),
#  array(['79.58844118215598', "['Nine Inch Nails']", 'March Of The Pigs'],
#        dtype='<U661'),
#  array(['79.58373780203564', "['Discharge']", 'Free Speech for the Dumb'],
#        dtype='<U661'),
#  array(['79.58348078449441', "['The Union Underground']",
#         'Turn Me On "Mr. Deadman"'], dtype='<U661'),
#  array(['79.57620774454378', "['P!nk']", "Leave Me Alone (I'm Lonely)"],
#        dtype='<U661'),
#  array(['79.57322790908427', "['The Libertines']", "Can't Stand Me Now"],
#        dtype='<U661'),
#  array(['79.57251304284443', "['Lil Peep']", 'Better Off (Dying)'],
#        dtype='<U661'),
#  array(['79.56943571548084', "['Avicii', 'Sandro Cavazza']",
#         'Without You (feat. Sandro Cavazza)'], dtype='<U661'),
#  array(['79.56821207870745', "['The Maine']", 'Everything I Ask For'],
#        dtype='<U661'),
#  array(['79.56557517453285', "['Me First and the Gimme Gimmes']",
#         'Leaving on a Jet Plane'], dtype='<U661'),
#  array(['79.56036406203808', "['Magic Man']", 'Paris'], dtype='<U661'),
#  array(['79.55965373130189',
#         "['Rae Sremmurd', 'Swae Lee', 'Slim Jxmmi', 'Travis Scott']",
#         'CLOSE (feat. Travis Scott) - From SR3MM'], dtype='<U661'),
#  array(['79.55630998096213', "['Pantera']", 'Primal Concrete Sledge'],
#        dtype='<U661'),
#  array(['79.55630585846767', "['Theory of a Deadman']", 'Hate My Life'],
#        dtype='<U661'),
#  array(['79.5546280870369', "['Tom Odell']", 'Grow Old with Me'],
#        dtype='<U661'),
#  array(['79.54933223655459', "['Our Last Night']", 'HUMBLE.'],
#        dtype='<U661'),
#  array(['79.54606535986467', "['American Hi-Fi']", 'Flavor Of The Weak'],
#        dtype='<U661'),
#  array(['79.54434735976568', "['Lizzo']", 'Cuz I Love You'], dtype='<U661'),
#  array(['79.54423441153392', "['Gesaffelstein', 'The Weeknd']",
#         'Lost in the Fire (feat. The Weeknd)'], dtype='<U661'),
#  array(['79.54132787715405', "['The Weeknd']",
#         'Nothing Compares - Bonus Track'], dtype='<U661'),
#  array(['79.5380130679582', "['Tame Impala']", 'Love/Paranoia'],
#        dtype='<U661'),
#  array(['79.5376386234117', "['Mac Miller']", 'Frick Park Market'],
#        dtype='<U661'),
#  array(['79.52690004768938', "['Arctic Monkeys']",
#         'The Hellcat Spangled Shalalala'], dtype='<U661'),
#  array(['79.5239266722892', "['A Day To Remember']", 'Out of Time'],
#        dtype='<U661'),
#  array(['79.52309006166925', "['Lil Yachty', 'The Good Perry']",
#         'Wanna Be Us'], dtype='<U661'),
#  array(['79.52057776764221', "['American Hi-Fi']", 'The Art Of Losing'],
#        dtype='<U661'),
#  array(['79.51802286223672', "['Bone Thugs-N-Harmony']", 'Me Killa'],
#        dtype='<U661'),
#  array(['79.51792607600703', "['Sum 41']", 'My Direction'], dtype='<U661'),
#  array(['79.51781363933812', "['Rodney Carrington']",
#         'Titties & Beer - Live'], dtype='<U661'),
#  array(['79.51395710012739', "['Kanye West', 'Common']", 'My Way Home'],
#        dtype='<U661'),
#  array(['79.51391429020137', "['Avenged Sevenfold']", 'Doing Time'],
#        dtype='<U661'),
#  array(['79.5106200087751', "['Green Day']", 'Going to Pasalacqua'],
#        dtype='<U661'),
#  array(['79.5098566253051', "['Five Finger Death Punch']",
#         "Can't Heal You"], dtype='<U661'),
#  array(['79.50721034510826', "['BlackMayo']", "Jus' Know"], dtype='<U661'),
#  array(['79.50524773190725', "['Lana Del Rey', 'A$AP Rocky']",
#         'Groupie Love (feat. A$AP Rocky)'], dtype='<U661'),
#  array(['79.50496282062274', "['T.S.O.L.']", '80 Times'], dtype='<U661'),
#  array(['79.50204342620533', "['Green Day']",
#         'Horseshoes and Handgrenades'], dtype='<U661'),
#  array(['79.49634951980508', "['Gorilla Biscuits']", 'Forgotten'],
#        dtype='<U661'),
#  array(['79.49323321848574', "['Unwritten Law']", 'Save Me'], dtype='<U661'),
#  array(['79.49305214802854', "['Box Car Racer']", 'Tiny Voices'],
#        dtype='<U661'),
#  array(['79.49192314999596', "['System Of A Down']", 'Stealing Society'],
#        dtype='<U661'),
#  array(['79.49155069743529', "['Tory Lanez', 'Rich The Kid']",
#         'TAlk tO Me (with Rich The Kid)'], dtype='<U661'),
#  array(['79.49137583048552', "['$uicideBoy$']", 'Memoirs Of A Gorilla'],
#        dtype='<U661'),
#  array(['79.47954888986189', "['Slipknot']", 'Only One'], dtype='<U661'),
#  array(['79.47854100619327', "['Goldfinger']", 'Spokesman'], dtype='<U661'),
#  array(['79.47432746525162', "['R3HAB', 'GATTÜSO']", 'Creep'],
#        dtype='<U661'),
#  array(['79.47198599976973', "['fIREHOSE']", 'Brave Captain'],
#        dtype='<U661'),
#  array(['79.47022673592998', "['Motionless In White', 'Michael Vampire']",
#         'America'], dtype='<U661'),
#  array(['79.46750575374887', "['Aries']", 'SANTA MONICA'], dtype='<U661'),
#  array(['79.46409113650961', "['Rod Wave']", 'Roaming'], dtype='<U661'),
#  array(['79.46378005336783', "['Attila']", 'About That Life'],
#        dtype='<U661'),
#  array(['79.46372791665213', "['You Me At Six', 'Oli Sykes']",
#         'Bite My Tongue'], dtype='<U661'),
#  array(['79.46317922316223', "['Marc E. Bassy', 'blackbear']",
#         'Just My Luck'], dtype='<U661'),
#  array(['79.46211104758673', "['Kehlani']", 'You Should Be Here'],
#        dtype='<U661'),
#  array(['79.45629673701855', "['Bazzi']", 'Mine'], dtype='<U661'),
#  array(['79.45547572693953', "['Eminem', 'Don Toliver']",
#         'No Regrets (feat. Don Toliver)'], dtype='<U661'),
#  array(['79.45271613511852', "['NLE Choppa']", 'CAPO'], dtype='<U661'),
#  array(['79.45228124090379', "['Nine Inch Nails']", 'March Of The Pigs'],
#        dtype='<U661'),
#  array(['79.44967764570427', "['W.A.S.P.']", 'Ballcrusher'], dtype='<U661'),
#  array(['79.44322100388716', "['The Weeknd']",
#         'Repeat After Me (Interlude)'], dtype='<U661'),
#  array(['79.44244721975464', "['Jhené Aiko']", 'Speak'], dtype='<U661'),
#  array(['79.44059860216615', "['Lil Peep', 'Lil Tracy']", 'white tee'],
#        dtype='<U661'),
#  array(['79.43904309176426', "['JAY-Z', 'Kanye West', 'Mr Hudson']",
#         'Why I Love You'], dtype='<U661'),
#  array(['79.43857841555518', "['Hollywood Undead']", 'Paradise Lost'],
#        dtype='<U661'),
#  array(['79.43844965437535', "['Lil Mosey']", 'Burberry Headband'],
#        dtype='<U661'),
#  array(['79.43675680748606', "['Gryffin', 'Quinn XCII', 'Daniel Wilson']",
#         'Winnebago (feat. Quinn XCII & Daniel Wilson)'], dtype='<U661'),
#  array(['79.43652663547552', "['Lil Peep', 'Cold Hart']", 'big city blues'],
#        dtype='<U661'),
#  array(['79.43523543513896', "['Martha Wainwright']",
#         'Bloody Mother Fucking Asshole'], dtype='<U661'),
#  array(['79.43500492483774', "['RJMrLA']", 'Hoes Come Easy'], dtype='<U661'),
#  array(['79.43443382725046', "['Green Day']", 'Minority'], dtype='<U661'),
#  array(['79.43118488821628',
#         "['MOD SUN', 'Machine Gun Kelly', 'Goody Grace']",
#         'Stay Away (feat. Machine Gun Kelly & Goody Grace)'], dtype='<U661'),
#  array(['79.42852953853728', "['Rex Orange County']",
#         'Belly (The Grass Stains)'], dtype='<U661'),
#  array(['79.42833955445774', "['Icona Pop', 'Charli XCX']",
#         'I Love It (feat. Charli XCX)'], dtype='<U661'),
#  array(['79.42689450663768', "['blink-182']", 'Story Of A Lonely Guy'],
#        dtype='<U661'),
#  array(['79.4256873866183', "['G-Eazy', 'Devon Baldwin']",
#         'Mad (feat. Devon Baldwin)'], dtype='<U661'),
#  array(['79.42241378154672', "['Trippie Redd']", 'Lil Wayne'],
#        dtype='<U661'),
#  array(['79.4209106644177', "['Motörhead']", '(We Are) The Roadcrew'],
#        dtype='<U661'),
#  array(['79.41914226356643', "['Don Toliver']", 'After Party'],
#        dtype='<U661'),
#  array(['79.41684964655232', "['Trippie Redd']", 'Love Scars 3'],
#        dtype='<U661'),
#  array(['79.41257410081047', "['Mike Sherm']", 'Hot Nigga'], dtype='<U661'),
#  array(['79.41152284640842', "['McCafferty']", 'Alligator Skin Boots'],
#        dtype='<U661'),
#  array(['79.41046453741251', "['Machine Gun Kelly']", 'Habits'],
#        dtype='<U661'),
#  array(['79.40855865966594', "['Chimaira']", 'Power Trip'], dtype='<U661'),
#  array(['79.40700436169959', "['Senses Fail']", 'One Eight Seven'],
#        dtype='<U661'),
#  array(['79.40580227159556', "['Sublime']", 'The Ballad Of Johnny Butt'],
#        dtype='<U661'),
#  array(['79.40503682050577', "['HELLYEAH']", 'Moth'], dtype='<U661'),
#  array(['79.40499417777423', '["Jane\'s Addiction"]', 'Idiots Rule'],
#        dtype='<U661'),
#  array(['79.40383544470617', "['Cockney Rejects']", 'Oi! Oi! Oi!'],
#        dtype='<U661'),
#  array(['79.40238812620295', "['Slipknot']", 'No Life'], dtype='<U661'),
#  array(['79.4021563492604', "['Future']", 'Married To The Game'],
#        dtype='<U661'),
#  array(['79.40134329218039', "['Icona Pop', 'Charli XCX']",
#         'I Love It (feat. Charli XCX) - Original Version'], dtype='<U661'),
#  array(['79.40093001391442', "['Koe Wetzel']", 'Ragweed'], dtype='<U661'),
#  array(['79.40087182579572', "['The Script']", 'Six Degrees of Separation'],
#        dtype='<U661'),
#  array(['79.40078653277942', "['Miley Cyrus', 'French Montana']",
#         'FU (feat. French Montana)'], dtype='<U661'),
#  array(['79.39960431033832', "['Lil Peep', 'Lil Tracy']", 'white tee'],
#        dtype='<U661'),
#  array(['79.39790112458302', "['Doja Cat']", 'Bottom Bitch'], dtype='<U661'),
#  array(['79.39768421356497', "['Tame Impala']", "Yes I'm Changing"],
#        dtype='<U661'),
#  array(['79.39735321899694', "['Shawty Lo']", 'Dunn, Dunn'], dtype='<U661'),
#  array(['79.39320915561514', "['RL Grime', '24hrs']", 'UCLA'],
#        dtype='<U661'),
#  array(['79.39157216364593', "['Buckcherry']", 'Sorry'], dtype='<U661'),
#  array(['79.39151790396085', "['$uicideBoy$']", 'Sunshine'], dtype='<U661'),
#  array(['79.38982469771825', "['Kehlani']", 'Bad News'], dtype='<U661'),
#  array(['79.38950279838942', "['The 1975']", 'Sex'], dtype='<U661'),
#  array(['79.38729732283112', "['The Script']", 'For the First Time'],
#        dtype='<U661'),
#  array(['79.38586452025505', "['Seether']", 'Like Suicide'], dtype='<U661'),
#  array(['79.38572020390235', "['OutKast']", '?'], dtype='<U661'),
#  array(['79.38435198508942', "['Sublime']", 'The Ballad Of Johnny Butt'],
#        dtype='<U661'),
#  array(['79.38137989484318', "['Machine Gun Kelly']", 'Bloody Valentine'],
#        dtype='<U661'),
#  array(['79.38126718799552', "['Butthole Surfers']",
#         "Jingle Of A Dog's Collar"], dtype='<U661'),
#  array(['79.38077871004013', "['Kevin Gates']", 'Smiling Faces'],
#        dtype='<U661'),
#  array(['79.37895981752058', "['5 Seconds of Summer']", 'Want You Back'],
#        dtype='<U661'),
#  array(['79.3767762022386',
#         "['John Gallagher, Jr.', 'Brian Johnson', 'Jonathan B. Wright', 'Gideon Glick', 'Skylar Astin', 'Jonathan Groff']",
#         'The Bitch Of Living - Original Broadway Cast Recording/2006'],
#        dtype='<U661'),
#  array(['79.37458447244784', "['iann dior']", '18'], dtype='<U661'),
#  array(['79.37421864241585', "['Wiz Khalifa', 'Quavo']",
#         'Out in Space (feat. Quavo)'], dtype='<U661'),
#  array(['79.37382347300515', "['The Chainsmokers', '5 Seconds of Summer']",
#         'Who Do You Love'], dtype='<U661'),
#  array(['79.37300130817616', "['SiR', 'Zacari']", 'Mood (feat. Zacari)'],
#        dtype='<U661'),
#  array(['79.37256155642723', "['Bad Religion']", 'Fuck You'], dtype='<U661'),
#  array(['79.37180385180379', "['Tenacious D']", 'Lee'], dtype='<U661'),
#  array(['79.36955912600551', "['Rebel Son']", "Quit Your Bitchin'"],
#        dtype='<U661'),
#  array(['79.36940431082712', "['Static-X']", 'Wisconsin Death Trip'],
#        dtype='<U661'),
#  array(['79.36584637541755', "['Green Day']", 'Stuart and the Ave.'],
#        dtype='<U661'),
#  array(['79.36400801113841', "['Still Woozy']", 'Foolsong'], dtype='<U661'),
#  array(['79.36399860691614', "['Local H']", 'Eddie Vedder'], dtype='<U661'),
#  array(['79.36320563866231', "['Lil Peep']", 'ghost girl'], dtype='<U661'),
#  array(['79.36306704044132', "['Wiz Khalifa', 'Tyga']",
#         'Contact (feat. Tyga)'], dtype='<U661'),
#  array(['79.36043752014618', "['Green Day']", 'Let Yourself Go'],
#        dtype='<U661'),
#  array(['79.35845700939187', "['Kamiyada+', 'The Virus and Antidote']",
#         'ProductOfDrugs (Prod. The Virus and Antidote)'], dtype='<U661'),
#  array(['79.35838895715675', "['Theory of a Deadman']", 'Blow'],
#        dtype='<U661'),
#  array(['79.35753562381038', "['Gob']", 'I Hear You Calling'],
#        dtype='<U661'),
#  array(['79.3556120654504', "['Don Toliver']", 'Wasted'], dtype='<U661'),
#  array(['79.35532523638209', "['Wiz Khalifa', 'Tyga']",
#         'Contact (feat. Tyga)'], dtype='<U661'),
#  array(['79.35511414803118', "['Future']", 'I Serve the Base'],
#        dtype='<U661'),
#  array(['79.35511244033383', "['Bazzi']", 'Why'], dtype='<U661'),
#  array(['79.354786156871', "['The Fugs']", 'Slum Goddess'], dtype='<U661'),
#  array(['79.35430945195698', "['I Prevail']", 'Come And Get It'],
#        dtype='<U661'),
#  array(['79.35409489947489', "['Lil Peep', 'Lil Tracy']", 'White Wine'],
#        dtype='<U661'),
#  array(['79.35379998657268', "['Anti-Flag']",
#         '1 Trillion Dollar$ - Dirty Version'], dtype='<U661'),
#  array(['79.3516971961541', "['Lil Peep', 'Lil Tracy']",
#         'walk away as the door slams - acoustic'], dtype='<U661'),
#  array(['79.35037205909741', "['Black Joe Lewis & The Honeybears']",
#         'Bitch, I Love You'], dtype='<U661'),
#  array(['79.3490057708926', "['Los Inquietos Del Norte']",
#         'Que Se Cree Ese Perro (En Vivo)'], dtype='<U661'),
#  array(['79.34542290517847', "['Eazy-E']", 'Exxtra Special Thankz'],
#        dtype='<U661'),
#  array(['79.34533491182425', "['Start Trouble']",
#         "Let's Get Fucked Up - Explicit Album Version"], dtype='<U661'),
#  array(['79.34421105139059', "['Twista']", 'Kill Us All'], dtype='<U661'),
#  array(['79.3372935001746', "['Sheck Wes']", 'Mo Bamba'], dtype='<U661'),
#  array(['79.33722706130794', "['311']", 'Purpose'], dtype='<U661'),
#  array(['79.33695999218287', "['Modern Baseball']", 'Fine, Great'],
#        dtype='<U661'),
#  array(['79.33674609995202', "['Tyler, The Creator']",
#         'RUNNING OUT OF TIME'], dtype='<U661'),
#  array(['79.33404912190785', "['$uicideBoy$', 'Pouya']", 'BREAKDALAW2K16'],
#        dtype='<U661'),
#  array(['79.33312398613111', "['Alkaline Trio']", 'Private Eye'],
#        dtype='<U661'),
#  array(['79.33043912814529', "['JFA']", 'Beach Blanket Bongout'],
#        dtype='<U661'),
#  array(['79.32701567910422', "['System Of A Down']", 'Mr. Jack'],
#        dtype='<U661'),
#  array(['79.32692928133578', "['Lil Peep']", 'Save That Shit'],
#        dtype='<U661'),
#  array(['79.32397586120823', "['Logic', 'Dria']", 'Stainless'],
#        dtype='<U661'),
#  array(['79.32207467516979', "['Sick Puppies']", "You're Going Down"],
#        dtype='<U661'),
#  array(['79.32143062987703',
#         "['Tech N9ne', 'Krizz Kaliko', 'Serj Tankian']",
#         'Straight Out the Gate'], dtype='<U661'),
#  array(['79.3186660341442', "['Sublime With Rome', 'Dirty Heads']",
#         'Sirens (feat. Dirty Heads)'], dtype='<U661'),
#  array(['79.3183898294177', "['La Sonora Dinamita']",
#         'Se Me Perdio La Cadenita'], dtype='<U661'),
#  array(['79.31709226408513', "['Post Malone', 'Swae Lee']",
#         'Spoil My Night (feat. Swae Lee)'], dtype='<U661'),
#  array(['79.31450636869984', "['Stone Sour']", 'Get Inside'], dtype='<U661'),
#  array(['79.31447812486633', "['Ariana Grande']", 'God is a woman'],
#        dtype='<U661'),
#  array(['79.31444203046235', "['Five Finger Death Punch', 'Maria Brink']",
#         'Anywhere But Here (feat. Maria Brink)'], dtype='<U661'),
#  array(['79.31129996994687', "['Linkin Park', 'Kiiara']",
#         'Heavy (feat. Kiiara)'], dtype='<U661'),
#  array(['79.31127234244606', "['$uicideBoy$']",
#         'I Will Celebrate For Stepping On Broken Glass And Slipping On Stomach Soaked Floors'],
#        dtype='<U661'),
#  array(['79.31010876661814', "['Huncho Jack', 'Travis Scott', 'Quavo']",
#         'Saint'], dtype='<U661'),
#  array(['79.30364657607736', "['Crass']", 'Punk Is Dead'], dtype='<U661'),
#  array(['79.30301996554307', "['The Pogues']",
#         'The Sick Bed of Cuchulainn'], dtype='<U661'),
#  array(['79.30174991023382', "['Machine Gun Kelly']", 'Bloody Valentine'],
#        dtype='<U661'),
#  array(['79.29828569373677', "['Danzig']", 'Evil Thing'], dtype='<U661'),
#  array(['79.29397641837974', "['Juice WRLD']", 'Make Believe'],
#        dtype='<U661'),
#  array(['79.29350654531821', "['Three Days Grace']", 'Riot'], dtype='<U661'),
#  array(['79.29303169900096', "['W.A.S.P.']", 'Blind In Texas'],
#        dtype='<U661'),
#  array(['79.2929025869478', "['Say Anything']", 'Woe'], dtype='<U661'),
#  array(['79.29281826760626', "['Dwarves']", 'I Will Deny'], dtype='<U661'),
#  array(['79.29179957383535', "['Janelle Monáe']", 'I Like That'],
#        dtype='<U661'),
#  array(['79.29117478179867', "['Portugal. The Man']", 'Creep in a T-Shirt'],
#        dtype='<U661'),
#  array(['79.2908721109155', "['YUNGBLUD', 'Halsey', 'Travis Barker']",
#         '11 Minutes (with Halsey feat. Travis Barker)'], dtype='<U661'),
#  array(['79.28715261464548', "['Jessie J']", 'Do It Like A Dude'],
#        dtype='<U661'),
#  array(['79.2859132575384', "['Lil Peep']", 'Life is Beautiful'],
#        dtype='<U661'),
#  array(['79.28460046193074', "['My Bloody Valentine']", 'Sueisfine'],
#        dtype='<U661'),
#  array(['79.28457670702372', "['Five Finger Death Punch']",
#         'Blue on Black'], dtype='<U661'),
#  array(['79.2836422214569', "['Buddy', 'Khalid']",
#         "Trippin' (feat. Khalid)"], dtype='<U661'),
#  array(['79.28254319832823', "['Travis Scott']", 'YOSEMITE'], dtype='<U661'),
#  array(['79.28050753759706', "['Never Shout Never']", "Can't Stand It"],
#        dtype='<U661'),
#  array(['79.27903407879144', "['The Weeknd']", 'Save Your Tears'],
#        dtype='<U661'),
#  array(['79.27752189357527', "['W.A.S.P.']", 'The Flame'], dtype='<U661'),
#  array(['79.27507394178144', "['Matt Maeson']", 'Hallucinogenics'],
#        dtype='<U661'),
#  array(['79.2721388349967', "['Trefuego']", '90mh'], dtype='<U661'),
#  array(['79.2714872583312', "['Chief Keef', 'Soulja Boy']",
#         'Save That Shit'], dtype='<U661'),
#  array(['79.27037442748994', "['Waka Flocka Flame', 'Trey Songz']",
#         "I Don't Really Care (feat. Trey Songz)"], dtype='<U661'),
#  array(['79.27013593553309', "['Nickelback']", 'Edge Of A Revolution'],
#        dtype='<U661'),
#  array(['79.26992625641297', "['Three Days Grace']", 'Right Left Wrong'],
#        dtype='<U661'),
#  array(['79.2679634673295', "['Noah Kahan']", 'False Confidence'],
#        dtype='<U661'),
#  array(['79.26592877270302', "['Saving Abel']", 'Addicted'], dtype='<U661'),
#  array(['79.26345996197234', "['Joji']", 'XNXX'], dtype='<U661'),
#  array(['79.26288504867617', "['Calvin Harris', 'Big Sean']",
#         'Open Wide (feat. Big Sean)'], dtype='<U661'),
#  array(['79.26181576466597',
#         "['T3R Elemento', 'David Bernal', 'Ruben Figueroa']",
#         'Jalo y Exhalo'], dtype='<U661'),
#  array(['79.26088659451128', "['Kanye West']", 'Waves'], dtype='<U661'),
#  array(['79.25870716608672', "['A Day To Remember']", 'City Of Ocala'],
#        dtype='<U661'),
#  array(['79.25612846525405', "['Bazzi']", '3:15'], dtype='<U661'),
#  array(['79.25484100824865', "['Doobie']", 'Kids on Drugs'], dtype='<U661'),
#  array(['79.25466125424263', "['Lil Wayne', 'Shanell']", 'Prom Queen'],
#        dtype='<U661'),
#  array(['79.25351827107731', "['Dr. Know']", 'Watch It Burn'],
#        dtype='<U661'),
#  array(['79.25302329539377', "['blink-182']", 'Roller Coaster'],
#        dtype='<U661'),
#  array(['79.2497685771933', "['blink-182']", 'Dammit'], dtype='<U661'),
#  array(['79.24831864389121', "['Upchurch', 'Justin Adams']",
#         'The Old Days (feat. Justin Adams)'], dtype='<U661'),
#  array(['79.24796214940329', "['Omar Ruiz']", 'Mi Amiga Maria Juana'],
#        dtype='<U661'),
#  array(['79.2474457294825', "['Juice WRLD']", 'Won’t Let Go'],
#        dtype='<U661'),
#  array(['79.24701524926266', "['Beyoncé']", 'Sandcastles'], dtype='<U661'),
#  array(['79.2443413942786', "['KSI', 'Aiyana-Lee']",
#         'Killa Killa (feat. Aiyana-Lee)'], dtype='<U661'),
#  array(['79.24326997265128', "['Russ']", 'Me You'], dtype='<U661'),
#  array(['79.24322704245867', "['Brent Faiyaz']", 'Rehab (Winter In Paris)'],
#        dtype='<U661'),
#  array(['79.24106517402896', "['Seether']", 'Same Damn Life'],
#        dtype='<U661'),
#  array(['79.24066113158865', "['The Front Bottoms']",
#         'The Plan (Fuck Jobs)'], dtype='<U661'),
#  array(['79.24009643733653', "['G-Eazy', 'Big Sean']",
#         'One Of Them (feat. Big Sean)'], dtype='<U661'),
#  array(['79.2392260311158', "['Chris Kleiber']", 'One Nightstand'],
#        dtype='<U661'),
#  array(['79.23883347592772', "['Kamaiyah', 'YG']", 'Fuck It up (feat. Yg)'],
#        dtype='<U661'),
#  array(['79.23771532897042', "['Mindless Self Indulgence']", 'Clarissa'],
#        dtype='<U661'),
#  array(['79.23620383701655', "['PARTYNEXTDOOR']", 'Her Way'], dtype='<U661'),
#  array(['79.23397525164032', "['Kittie']", 'Spit'], dtype='<U661'),
#  array(['79.23327856937895', "['Elliott Smith']", 'Bled White'],
#        dtype='<U661'),
#  array(['79.23225685959657', "['Incubus']", 'Make Yourself'], dtype='<U661'),
#  array(['79.23207664630453', "['Halsey']", 'Walls Could Talk'],
#        dtype='<U661'),
#  array(['79.23101417226887', "['Metallica']",
#         'Last Caress/Green Hell (Remastered)'], dtype='<U661'),
#  array(['79.22634135266412', "['Kittie']", 'Brackish'], dtype='<U661'),
#  array(['79.2261991126294', "['Deftones']", 'Root'], dtype='<U661'),
#  array(['79.22589134420807', "['Lil Durk']", 'Bora Bora'], dtype='<U661'),
#  array(['79.22540297947293', "['Wheeler Walker Jr.']", 'Fuck You Bitch'],
#        dtype='<U661'),
#  array(['79.22504561092771', "['Logic', 'Marshmello']", 'Everyday'],
#        dtype='<U661'),
#  array(['79.2241990766876', "['Korn', 'Skrillex']",
#         'Get Up! (feat. Skrillex)'], dtype='<U661'),
#  array(['79.22277551652316', "['Bloodbath']", 'Eaten'], dtype='<U661'),
#  array(['79.22255689078104', "['Juice WRLD']", "I'm Still"], dtype='<U661'),
#  array(['79.2220955559806',
#         "['Green Day', 'John Gallagher Jr.', 'Rebecca Naomi Jones', 'Stark Sands', 'The American Idiot Broadway Company']",
#         'Boulevard of Broken Dreams (feat. John Gallagher Jr., Rebecca Naomi Jones, Stark Sands, The American Idiot Broadway Company)'],
#        dtype='<U661'),
#  array(['79.22014085854514', "['W.A.S.P.']", 'The Last Command'],
#        dtype='<U661'),
#  array(['79.21908858472321', "['Hey Violet']", 'O.D.D.'], dtype='<U661'),
#  array(['79.21837618118131', "['Nicki Minaj']", 'Va Va Voom'],
#        dtype='<U661'),
#  array(['79.21828727278947', "['Slipknot']", 'No Life'], dtype='<U661'),
#  array(['79.21742607724886', "['Halestorm']", 'Freak Like Me'],
#        dtype='<U661'),
#  array(['79.21719899346373', "['Rex Orange County']", 'Know Love'],
#        dtype='<U661'),
#  array(['79.21718265714487', "['Papa Roach']", 'No Matter What'],
#        dtype='<U661'),
#  array(['79.21201521329294', "['Sunny Ledfurd', 'Colt Ford']",
#         'Nickel Sized Hail (feat. Colt Ford)'], dtype='<U661'),
#  array(['79.21186571532746', "['Future', 'Travis Scott']",
#         'Solitaires (feat. Travis Scott)'], dtype='<U661'),
#  array(['79.21177784049675', "['Five Finger Death Punch']",
#         'Stranger Than Fiction'], dtype='<U661'),
#  array(['79.21146599543873', "['Youth Of Today']", 'Take a Stand'],
#        dtype='<U661'),
#  array(['79.21113270737219', "['Asking Alexandria']", 'Killing You'],
#        dtype='<U661'),
#  array(['79.21096320713815', "['YUNGBLUD']", 'parents'], dtype='<U661'),
#  array(['79.21025030224506', "['Bryce Vine']", 'Guilty Pleasure'],
#        dtype='<U661'),
#  array(['79.20862316184068', "['T.S.O.L.']", 'Silent Scream'],
#        dtype='<U661'),
#  array(['79.20796169291462', "['sadeyes']", 'jaded'], dtype='<U661'),
#  array(['79.20301579922959', "['The 1975']", 'Sex'], dtype='<U661'),
# ...
#        dtype='<U661'),
#  array(['78.92730339031749', "['Days N Daze']", 'Fuck It!'], dtype='<U661'),
#  array(['78.92585777287762', "['Twang and Round']", 'Here Kitty Kitty'],
#        dtype='<U661'),
#  array(['78.92548972598674', "['Five Finger Death Punch']", 'Walk Away'],
#        dtype='<U661'),
#  array(['78.92519599796299', "['Tinashe']", 'Throw A Fit'], dtype='<U661'),
#  array(['78.92272826091151', "['Yeek']", 'Cleaner Air'], dtype='<U661'),
#  array(['78.92143254295513', "['Juice WRLD']", 'Who Shot Cupid?'],
#        dtype='<U661'),
#  array(['78.92102798582243', "['The Lonely Island', 'Justin Timberlake']",
#         'Motherlover'], dtype='<U661'),
#  array(['78.92054919583386', "['Paris Shadows', 'Trippie Redd']",
#         'GONE (feat. Trippie Redd)'], dtype='<U661'),
#  array(['78.92023008063164', "['6 Dogs']", 'Faygo Dreams'], dtype='<U661'),
#  array(['78.92015461922097', "['Bad Bunny']", 'Soliá'], dtype='<U661'),
#  array(['78.91983516261054', "['Conan Gray']", 'Wish You Were Sober'],
#        dtype='<U661'),
#  array(['78.91957777821678', "['Murder By Death']", 'Spring Break 1899'],
#        dtype='<U661'),
#  array(['78.9194317137603', "['Эрнест Хемингуэй']",
#         'Часть 14.3 & Часть 15.1 - Старик и море'], dtype='<U661'),
#  array(['78.91891649253539', "['Five Finger Death Punch']",
#         'Jekyll and Hyde'], dtype='<U661'),
#  array(['78.91877758574162', "['De La Ghetto']", 'Sensacion Del Bloque'],
#        dtype='<U661'),
#  array(['78.91868300217556', "['Xuitcasecity']",
#         'Need Somebody (Acoustic)'], dtype='<U661'),
#  array(['78.91868259146382', "['ScHoolboy Q']", 'Man Of The Year'],
#        dtype='<U661'),
#  array(['78.91685464469406', "['Lil Peep']", 'Kiss'], dtype='<U661'),
#  array(['78.9167667465666', "['The Weeknd']", 'Hardest To Love'],
#        dtype='<U661'),
#  array(['78.9154453321467', "['Senses Fail']",
#         "You're Cute When You Scream"], dtype='<U661'),
#  array(['78.91530664352078', "['Clawfinger']", 'Biggest & the Best'],
#        dtype='<U661'),
#  array(['78.91413500703221', "['Third Eye Blind']", 'Crystal Baller'],
#        dtype='<U661'),
#  array(['78.91352240210365', "['Jeezy']", 'Get Allot'], dtype='<U661'),
#  array(['78.91158788068806', "['Five Finger Death Punch']",
#         'A Day in My Life'], dtype='<U661'),
#  array(['78.91127810928803', "['Steel Panther']", 'Community Property'],
#        dtype='<U661'),
#  array(['78.91110320672725', "['Luh Kel']", 'Pull Up'], dtype='<U661'),
#  array(['78.90984457462085', "['Pouya', 'Ghostemane']", '1000 Rounds'],
#        dtype='<U661'),
#  array(['78.90927720936496', "['Five Finger Death Punch']",
#         'Darkness Settles In'], dtype='<U661'),
#  array(['78.90914512548947', "['Alaina Castillo']", 'just a boy'],
#        dtype='<U661'),
#  array(['78.90878135312737', "['Demi Lovato']", 'I Love Me'], dtype='<U661'),
#  array(['78.90785344827628', "['Melanie Martinez']", 'Play Date'],
#        dtype='<U661'),
#  array(['78.90747177827772', "['The Boys']", 'Tonight'], dtype='<U661'),
#  array(['78.90522405171313', "['Yelawolf', 'Fefe Dobson']", 'Animal'],
#        dtype='<U661'),
#  array(['78.90381662673964', "['Daddy Yankee']", 'Rompe'], dtype='<U661'),
#  array(['78.90367183070529', "['Cold']", 'Suffocate'], dtype='<U661'),
#  array(['78.90355487745659', "['Rob Bailey & The Hustle Standard']",
#         'Hungry'], dtype='<U661'),
#  array(['78.9034415460928', "['Brendan Maclean']", 'Stupid'], dtype='<U661'),
#  array(['78.90296764182101', "['Bullet For My Valentine']", 'Fever'],
#        dtype='<U661'),
#  array(['78.89973349527762', "['Three 6 Mafia']", "Poppin' My Collar"],
#        dtype='<U661'),
#  array(['78.89957112820001', "['Wiz Khalifa', 'K CAMP']",
#         'Clouds in the Air (feat. K CAMP)'], dtype='<U661'),
#  array(['78.89890526511593', "['Imanbek', 'Martin Jensen']",
#         "I'm Just Feelin' (Du Du Du)"], dtype='<U661'),
#  array(['78.89798218295718', "['$uicideBoy$']", 'Shattered Amethyst'],
#        dtype='<U661'),
#  array(['78.89789036816906', "['DaBaby', 'Offset']",
#         'Baby Sitter (feat. Offset)'], dtype='<U661'),
#  array(['78.89688911634316', "['Melanie Martinez']", 'Class Fight'],
#        dtype='<U661'),
#  array(['78.89688590195377', "['Young Money']", 'Roger That'],
#        dtype='<U661'),
#  array(['78.8967701698504', "['Lil Uzi Vert', 'Syd']",
#         'Urgency (feat. Syd)'], dtype='<U661'),
#  array(['78.89624995268987', "['$uicideBoy$']",
#         'New Chains, Same Shackles'], dtype='<U661'),
#  array(['78.89456812725588', "['Tame Impala']", "'Cause I'm A Man"],
#        dtype='<U661'),
#  array(['78.8941037933829', "['Gym Class Heroes', 'The-Dream']",
#         'Cookie Jar (feat. The-Dream)'], dtype='<U661'),
#  array(['78.89386190702302', "['The Distillers']", 'Hall of Mirrors'],
#        dtype='<U661'),
#  array(['78.89118019053936', "['Run The Jewels']", 'All My Life'],
#        dtype='<U661'),
#  array(['78.88902061757153', "['Post Malone']", 'No Option'], dtype='<U661'),
#  array(['78.88879674238689', "['Lil Peep']", 'Liar'], dtype='<U661'),
#  array(['78.88866663700571', "['BROCKHAMPTON']", 'SUGAR'], dtype='<U661'),
#  array(['78.88849398068788', "['Divide The Day']", 'Fuck Away the Pain'],
#        dtype='<U661'),
#  array(['78.88843042291805', "['Rainbow Kitten Surprise']",
#         "It's Called: Freefall"], dtype='<U661'),
#  array(['78.88656899809332', "['King Princess']", 'Upper West Side'],
#        dtype='<U661'),
#  array(['78.88616287947957', "['The Adicts']", 'Chinese Takeaway'],
#        dtype='<U661'),
#  array(['78.8859549288232', "['Rex Orange County']",
#         'Television / So Far So Good'], dtype='<U661'),
#  array(['78.88471755156193', "['Sepultura']", 'Cut-Throat'], dtype='<U661'),
#  array(['78.882367987673', "['Liz Phair']", "Why Can't I?"], dtype='<U661'),
#  array(['78.88220597891632', "['blink-182']", 'Reckless Abandon'],
#        dtype='<U661'),
#  array(['78.88182306770288', "['T3R Elemento', 'Gerardo Ortiz']",
#         'Aerolínea Carrillo'], dtype='<U661'),
#  array(['78.88129621301216', "['Marilyn Manson']", '1996'], dtype='<U661'),
#  array(['78.88103418155657', "['Angels & Airwaves']", 'It Hurts'],
#        dtype='<U661'),
#  array(['78.8810257225539', "['Luh Kel', 'Lil Tjay']",
#         'Wrong (feat. Lil Tjay) - Remix'], dtype='<U661'),
#  array(['78.88081907002096', "['Joyner Lucas']", 'ADHD'], dtype='<U661'),
#  array(['78.87983593902506', "['Choker']", 'Juno'], dtype='<U661'),
#  array(['78.87923368630335', "['Faith No More']",
#         'The Gentle Art of Making Enemies'], dtype='<U661'),
#  array(['78.87790852512306', "['Twista', 'Trey Songz']",
#         'Girl Tonite (feat. Trey Songz)'], dtype='<U661'),
#  array(['78.87703167985575', "['Mac Miller']", 'Smile Back'], dtype='<U661'),
#  array(['78.87697358044569', "['tobi lou']", 'Buff Baby'], dtype='<U661'),
#  array(['78.87686307994154', "['Kid Cudi']", 'CONFUSED!'], dtype='<U661'),
#  array(['78.8764862094029', "['JFA']", 'JFA'], dtype='<U661'),
#  array(['78.87553035973532', "['Bad Bunny']", 'Dime Si Te Acuerdas'],
#        dtype='<U661'),
#  array(['78.87532394680346', "['Bryce Vine']", 'Sour Patch Kids'],
#        dtype='<U661'),
#  array(['78.87379478055703', "['Joey Trap']", 'Alexis'], dtype='<U661'),
#  array(['78.8723826510467', "['Beastie Boys']", 'I Want Some'],
#        dtype='<U661'),
#  array(['78.87216947648929', "['The Offspring']", 'Americana'],
#        dtype='<U661'),
#  array(['78.87175730308732', "['blackbear']", 'Different Hos'],
#        dtype='<U661'),
#  array(['78.87131264535921', "['Godsmack']", '1000hp'], dtype='<U661'),
#  array(['78.87120042558705', "['Melanie Martinez']", 'The Principal'],
#        dtype='<U661'),
#  array(['78.87054597427806', "['Lil Peep']", 'crybaby'], dtype='<U661'),
#  array(['78.86953200145584', "['Nelly']", 'Hey Porsche'], dtype='<U661'),
#  array(['78.86909825690432', "['Static-X']", "I'm With Stupid"],
#        dtype='<U661'),
#  array(['78.86898497824352', "['Marilyn Manson']", 'mOBSCENE'],
#        dtype='<U661'),
#  array(['78.86884556418792', "['Mindless Self Indulgence']", 'Faggot'],
#        dtype='<U661'),
#  array(['78.86791611431384', "['Marilyn Manson']", 'Cake And Sodomy'],
#        dtype='<U661'),
#  array(['78.86651872827838', "['K.Flay']", 'Blood In The Cut'],
#        dtype='<U661'),
#  array(['78.86405650639604', "['Post Malone', 'Justin Bieber']", 'Deja Vu'],
#        dtype='<U661'),
#  array(['78.86299228009068', "['Rage Against The Machine']", 'In My Eyes'],
#        dtype='<U661'),
#  array(['78.8605761065078', "['Nipsey Hussle']", 'U See Us'], dtype='<U661'),
#  array(['78.86030615193319', '["Guns N\' Roses"]', 'Mr. Brownstone'],
#        dtype='<U661'),
#  array(['78.86015902940184', "['Kevin Abstract']", 'American Boyfriend'],
#        dtype='<U661'),
#  array(['78.85968002787862', "['SAINt JHN']",
#         'I Heard You Got Too Litt Last Night'], dtype='<U661'),
#  array(['78.85899389076997', "['iann dior', 'PnB Rock']", 'romance361'],
#        dtype='<U661'),
#  array(['78.85870645682989', "['The Vandals']", 'Flowers Are Pretty'],
#        dtype='<U661'),
#  array(['78.85757953418889', "['Prince']", 'Damn U'], dtype='<U661'),
#  array(['78.85681739678981', "['Apollo Fresh']", 'JoJo Pose'],
#        dtype='<U661'),
#  array(['78.85558052027493', "['Slipknot']", 'Unsainted'], dtype='<U661'),
#  array(['78.85548399893787', "['Jack Harlow']", 'HEY BIG HEAD'],
#        dtype='<U661'),
#  array(['78.85470928218166', "['Trippie Redd']", 'Topanga'], dtype='<U661'),
#  array(['78.85425871411218', "['French Montana', 'City Girls']",
#         'Wiggle It (feat. City Girls)'], dtype='<U661'),
#  array(['78.85411298275885', "['Liz Phair']", 'Flower (Remastered)'],
#        dtype='<U661'),
#  array(['78.85257374789103', "['Gregory Alan Isakov']", 'Saint Valentine'],
#        dtype='<U661'),
#  array(['78.85093419539557', "['My Chemical Romance']", 'House of Wolves'],
#        dtype='<U661'),
#  array(['78.85043172755702', "['Avatar']", 'Hail The Apocalypse'],
#        dtype='<U661'),
#  array(['78.85037102555138', "['Lil Loaded']", 'Gang Unit'], dtype='<U661'),
#  array(['78.84962202298298', "['Disturbed']", "Droppin' Plates"],
#        dtype='<U661'),
#  array(['78.84872438380447', "['Body Count']", "Body Count's in the House"],
#        dtype='<U661'),
#  array(['78.8480661378052', "['Passenger']", 'Holes'], dtype='<U661'),
#  array(['78.8473956340555', "['blink-182']", 'Aliens Exist - Live/1999'],
#        dtype='<U661'),
#  array(['78.84729065556577', "['The Fall']", 'Lost in Music'],
#        dtype='<U661'),
#  array(['78.84529746367367', "['Melanie Martinez']", 'Milk and Cookies'],
#        dtype='<U661'),
#  array(['78.84512696585001', "['Sticky Fingers']", 'Gold Snafu'],
#        dtype='<U661'),
#  array(['78.8448225438147', '["Guns N\' Roses"]', 'Mr. Brownstone'],
#        dtype='<U661'),
#  array(['78.84392300581085', "['MKTO']", 'Wasted'], dtype='<U661'),
#  array(['78.84328989055545', "['Trippie Redd', 'Chance the Rapper']",
#         'I Love You'], dtype='<U661'),
#  array(['78.84165390756822', "['Diplo', 'Trippie Redd']", 'Wish'],
#        dtype='<U661'),
#  array(['78.83934924832214', "['Upchurch']", 'Hillbilly'], dtype='<U661'),
#  array(['78.83901658997424', "['Bea Miller']", 'feel something'],
#        dtype='<U661'),
#  array(['78.8385449915623', "['iann dior']", 'Pretty Girls'], dtype='<U661'),
#  array(['78.83814445585435', "['Rob Bailey & The Hustle Standard']",
#         "Try 'n Hold Me Back"], dtype='<U661'),
#  array(['78.8353888733452', "['Mumford & Sons']", 'Monster'], dtype='<U661'),
#  array(['78.83471854723099', "['Linkin Park']", 'Hands Held High'],
#        dtype='<U661'),
#  array(['78.83348209540459', "['Travis Scott', 'Kanye West']",
#         'Piss On Your Grave (feat. Kanye West)'], dtype='<U661'),
#  array(['78.83210805569934', "['No Rome', 'The 1975']",
#         'Narcissist (feat. The 1975)'], dtype='<U661'),
#  array(['78.8318411989848', "['Cake']", 'Mexico'], dtype='<U661'),
#  array(['78.83062220088878', "['Post Malone']", 'Broken Whiskey Glass'],
#        dtype='<U661'),
#  array(['78.82902519516371', "['Miranda!', 'Julieta Venegas']",
#         'Perfecta - Versión con Julieta Venegas'], dtype='<U661'),
#  array(['78.82901605550181', "['Mumford & Sons']", 'Little Lion Man'],
#        dtype='<U661'),
#  array(['78.82834067543479', "['Marianas Trench']", 'Desperate Measures'],
#        dtype='<U661'),
#  array(['78.82833694548272', "['Tyler, The Creator']", 'EARFQUAKE'],
#        dtype='<U661'),
#  array(['78.82794709479985', "['P!nk']", 'Walk of Shame'], dtype='<U661'),
#  array(['78.82784788585354', "['Sammy Adams', 'Wyred']",
#         'Where You Are (feat. Wyred)'], dtype='<U661'),
#  array(['78.82748219066364', "['Kesha']", 'Thinking of You'], dtype='<U661'),
#  array(['78.82721348574313', "['Kanye West']", 'Famous'], dtype='<U661'),
#  array(['78.82612983227608', "['The Weeknd']", 'Hardest To Love'],
#        dtype='<U661'),
#  array(['78.82441394593167', "['Ariana Grande']", 'goodnight n go'],
#        dtype='<U661'),
#  array(['78.82353232717495', "['DJ Screw', 'Big Moe']", 'Sippin Codine'],
#        dtype='<U661'),
#  array(['78.82301073817288', "['Black Flag']", 'Nervous Breakdown'],
#        dtype='<U661'),
#  array(['78.82266095266776', "['Lana Del Rey']", 'Radio'], dtype='<U661'),
#  array(['78.82205587882339', "['Fame on Fire']", 'Lucid Dreams'],
#        dtype='<U661'),
#  array(['78.82196846015131', "['Bondo']", "Fuck You I'm Drunk"],
#        dtype='<U661'),
#  array(['78.82148811900117', "['(Hed) P.E.']", 'Renegade'], dtype='<U661'),
#  array(['78.81977064008436', "['W.A.S.P.']", 'Paint It Black'],
#        dtype='<U661'),
#  array(['78.81932683775138', "['blink-182']", 'Give Me One Good Reason'],
#        dtype='<U661'),
#  array(['78.81887083157407', "['Lucero']", 'Sweet Little Thing'],
#        dtype='<U661'),
#  array(['78.81840456863175', "['Joji']", 'SLOW DANCING IN THE DARK'],
#        dtype='<U661'),
#  array(['78.81745136776895', "['Red Hot Chili Peppers']", 'Suck My Kiss'],
#        dtype='<U661'),
#  array(['78.81743823555844', "['Avril Lavigne']", 'I Can Do Better'],
#        dtype='<U661'),
#  array(['78.8173753510772', "['Gorilla Zoe', 'Yung Joc']",
#         'Juice Box (feat. Yung Joc)'], dtype='<U661'),
#  array(['78.81537246061006', "['Childish Gambino', 'Jhené Aiko']",
#         'I. Pink Toes'], dtype='<U661'),
#  array(['78.81501482697448',
#         "['Young Money', 'Tyga', 'Nicki Minaj', 'Lil Wayne']", 'Senile'],
#        dtype='<U661'),
#  array(['78.81403963356657', "['Struggle Jennings', 'Aaron Lewis']",
#         'The Struggle Is Real'], dtype='<U661'),
#  array(['78.81224636837624', "['Wiz Khalifa']", 'We Dem Boyz'],
#        dtype='<U661'),
#  array(['78.81200349621012', "['Sam Kinison']", 'Wild Thing'],
#        dtype='<U661'),
#  array(['78.8113223140911', "['Joji']", 'WANTED U'], dtype='<U661'),
#  array(['78.81048245647594', "['Baby Keem']", 'HONEST'], dtype='<U661'),
#  array(['78.81011170824387', "['Three 6 Mafia', 'Paula Campbell']",
#         'Hard Out Here for a Pimp'], dtype='<U661'),
#  array(['78.80980151962216', "['Puddle Of Mudd']", 'Away From Me'],
#        dtype='<U661'),
#  array(['78.80859412024891', "['Lana Del Rey']", 'Radio'], dtype='<U661'),
#  array(['78.80847763741347', "['PLVTINUM', 'Tarro', 'Ellusive']",
#         'Champagne & Sunshine (Ellusive Remix)'], dtype='<U661'),
#  array(['78.80820999096034', "['Childish Gambino']",
#         'V. 3005 - Beach Picnic Version'], dtype='<U661'),
#  array(['78.80801819206098', "['W.A.S.P.']", 'Forever Free'], dtype='<U661'),
#  array(['78.80736544923387', "['Speaker Knockerz']", 'Dap You Up'],
#        dtype='<U661'),
#  array(['78.80730803232889', "['Diamond Head']", "It's Electric"],
#        dtype='<U661'),
#  array(['78.8071544179898', "['G-Eazy', 'Dominique Le Jeune']",
#         'Marilyn (feat. Dominique Le Jeune)'], dtype='<U661'),
#  array(['78.80672604341885', "['XXXTENTACION']", 'Orlando'], dtype='<U661'),
#  array(['78.80670835448275', "['XXXTENTACION']", 'Triumph'], dtype='<U661'),
#  array(['78.80641154963504', "['HI-FI CAMP']", 'Cabin Sound'],
#        dtype='<U661'),
#  array(['78.80617448922821', "['Post Malone']", 'Rich & Sad'],
#        dtype='<U661'),
#  array(['78.80527620422352', "['Lana Del Rey']", 'Radio'], dtype='<U661'),
#  array(['78.80452521292337', "['The Who']", 'Dreaming From The Waist'],
#        dtype='<U661'),
#  ...]

# %%
playlist_added = ids[sort_indices][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MixjNzY3MzJjMzEwNmJmNmYyN2U0Yzk1OTY5NjdhODE0YWYwOGI3MmQ3'}
