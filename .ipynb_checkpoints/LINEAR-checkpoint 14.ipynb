# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Toby Keith']", 'Made in America'],
#         ["['K/DA', 'Madison Beer', '(G)I-DLE', 'Jaira Burns', 'League of Legends']",
#          'POP/STARS'],
#         ["['Taylor Swift']", 'Getaway Car'],
#         ...,
#         ["['Mariah Carey']", 'When I Saw You'],
#         ["['Vampire Weekend']", 'Everlasting Arms'],
#         ["['Clay Walker']", 'If I Could Make a Living']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.001

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.c_[predictions, song_info]

# %%
predictions = np.array(predictions)
type(predictions)
# Out:
# numpy.ndarray

# %%
predicted = predicted[np.argsort(predictions)]

# %%
list(predicted)
# Out:
# [array(['95.11425724732506', "['Lakeside']", 'Fantastic Voyage'],
#        dtype='<U661'),
#  array(['94.91441667376891', "['Stone Poneys', 'Linda Ronstadt']",
#         'Different Drum'], dtype='<U661'),
#  array(['95.11616428022919', "['Steps']", 'Tragedy'], dtype='<U661'),
#  array(['95.04892163373115', '["The O\'Jays"]', 'Sing A Happy Song'],
#        dtype='<U661'),
#  array(['94.85167593443798', "['George Strait']", 'Ace In The Hole'],
#        dtype='<U661'),
#  array(['94.76585878877947', "['Champaign']", 'Try Again'], dtype='<U661'),
#  array(['95.14424129566851', "['Fastball']", 'The Way'], dtype='<U661'),
#  array(['94.7735211730366', "['Jim Morrison', 'The Doors']",
#         'Angels and Sailors'], dtype='<U661'),
#  array(['94.86355797314685', "['Logic']", 'Gang Related'], dtype='<U661'),
#  array(['94.79420771769833', "['Captain Beefheart & His Magic Band']",
#         "Where There's Woman"], dtype='<U661'),
#  array(['94.7983986741136', "['Paulinho Da Viola', 'Elton Medeiros']",
#         'Maioria Sem Nenhum'], dtype='<U661'),
#  array(['94.98608509203576', "['The Surfaris']", 'Waikiki Run'],
#        dtype='<U661'),
#  array(['95.15312408762402', "['Bruce Springsteen']",
#         "It's Hard To Be A Saint In The City - Live at the Roxy Theatre, W. Hollywood, CA - July 1978"],
#        dtype='<U661'),
#  array(['94.43963438208016',
#         "['Max Reger', 'Concertgebouworkest', 'Eduard van Beinum']",
#         'Variations And Fugue On A Theme By Wolfgang Amadeus Mozart, Op.132: Variation III'],
#        dtype='<U661'),
#  array(['95.05288739702276', "['Billy Currington']",
#         "That's How Country Boys Roll"], dtype='<U661'),
#  array(['94.53559051793796', "['Dick Haymes']", 'And Mimi'], dtype='<U661'),
#  array(['94.80583158892631', "['Ramon Ayala Y Sus Bravos Del Norte']",
#         'Qué Casualidad'], dtype='<U661'),
#  array(['94.87453972044165', "['Paul Revere & The Raiders']",
#         'There She Goes'], dtype='<U661'),
#  array(['94.59418055424851', "['Roy Orbison']", 'Borne on the Wind'],
#        dtype='<U661'),
#  array(['94.92697844035463', "['The Rolling Stones']", 'Miss Amanda Jones'],
#        dtype='<U661'),
#  array(['94.48242506655271', "['The Staple Singers']",
#         "I Know I've Got Religion"], dtype='<U661'),
#  array(['94.7235271270727', "['Paddy Reilly']", 'The Fields of Athenry'],
#        dtype='<U661'),
#  array(['94.87533106153943', "['GAS']", 'Pop 1'], dtype='<U661'),
#  array(['94.57864698838164', "['Sleepy Hallow', 'Jay Critch']", 'Nauseous'],
#        dtype='<U661'),
#  array(['94.92257867718423', "['The Stanley Brothers']",
#         'Clinch Mountain Backstep'], dtype='<U661'),
#  array(['94.56793306461432', "['G. Gangone']", 'Italy: Dormi e Riposa'],
#        dtype='<U661'),
#  array(['94.98128839505888',
#         "['Gustav Mahler', 'Judith Raskin', 'George Szell', 'Cleveland Orchestra']",
#         'Symphony No. 4 in G Major: IV. Sehr behaglich - "Wir geniessen die himmlischen Freuden"'],
#        dtype='<U661'),
#  array(['94.52509653454196', "['Lata Mangeshkar']",
#         'Meri Ankhon Ki Neend Le Gaya'], dtype='<U661'),
#  array(['94.77287250935001', "['Эрих Мария Ремарк']",
#         'Часть 111.2 - На Западном фронте без перемен'], dtype='<U661'),
#  array(['94.34943665416552', "['Harimati']", 'Tora Nahin Kanhaiya'],
#        dtype='<U661'),
#  array(['94.7557687863915', "['Grupo Laberinto']",
#         'El Transformer Y La Cobra'], dtype='<U661'),
#  array(['95.05029781865609', "['Linval Thompson']",
#         'I Love Marijuana - Edit'], dtype='<U661'),
#  array(['94.96556450014899', "['Soda Stereo']",
#         'Si No Fuera Por... - Remasterizado 2007'], dtype='<U661'),
#  array(['94.80525771826657', "['Deitrick Haddon']", "Sinner's Prayer"],
#        dtype='<U661'),
#  array(['94.98321206948874', "['Louis Prima']", 'Che La Luna'],
#        dtype='<U661'),
#  array(['94.49917057759404', "['Larry Carr', 'Bethe Douglas']",
#         "Isn't This a Lovely Day"], dtype='<U661'),
#  array(['94.76164733925125', "['Nino Bravo']", 'Un Beso Y Una Flor'],
#        dtype='<U661'),
#  array(['94.71446630405842', "['Dusty Springfield']",
#         'Every Day I Have To Cry'], dtype='<U661'),
#  array(['95.01995250324978', "['潘越雲']", '我是不是你最疼愛的人'], dtype='<U661'),
#  array(['94.41006228778139',
#         "['Wolfgang Amadeus Mozart', 'Cesare Siepi', 'Walter Berry', 'Erna Berger', 'Wiener Philharmoniker', 'Wilhelm Furtwängler']",
#         "Don Giovanni, K. 527, Act I: Guarda un po' come seppe (Live)"],
#        dtype='<U661'),
#  array(['94.96211981512722', "['Yann Tiersen']", 'Evening Party'],
#        dtype='<U661'),
#  array(['95.10153913430771', "['Gorillaz', 'Daley']",
#         'Doncamatic (feat. Daley)'], dtype='<U661'),
#  array(['94.9040929827974', "['Banda Cuisillos']", 'No Se Lo Digas A Ella'],
#        dtype='<U661'),
#  array(['94.69336101549203', "['C418']", 'Excuse'], dtype='<U661'),
#  array(['94.70432411879659',
#         "['Camille Saint-Saëns', 'Charles Münch', 'New York Philharmonic']",
#         'Symphony No. 3 in C Minor, Op. 78 "Organ": IV. Maestoso - Allegro'],
#        dtype='<U661'),
#  array(['94.93599302706926', "['Sum 41']", 'Open Your Eyes'], dtype='<U661'),
#  array(['94.3706499490924', "['Francisco Canaro']",
#         'Que le importa - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.60740586857892', "['Blossom Dearie']", 'Boum'], dtype='<U661'),
#  array(['94.55210842961674', "['Dean Martin']", 'Always in My Heart'],
#        dtype='<U661'),
#  array(['95.00487857313091', "['Dan + Shay']", 'All To Myself'],
#        dtype='<U661'),
#  array(['94.99088951845482', "['Jeremy Camp']", 'Lay Down My Pride'],
#        dtype='<U661'),
#  array(['94.56670331058865', "['Lefty Frizzell']",
#         'Look What Thoughts Will Do'], dtype='<U661'),
#  array(['94.45430267918208', "['Luis Rovira y su Orquesta']",
#         "Riffin' And Jivin"], dtype='<U661'),
#  array(['94.80468896460309', "['The Charlie Daniels Band']",
#         "Old Rock 'N Roller"], dtype='<U661'),
#  array(['94.35966502219202', "['Johannes Brahms', 'Eugene Istomin']",
#         'Variations and Fugue on a Theme by Handel, Op. 24: Variation XV'],
#        dtype='<U661'),
#  array(['94.61364164718913', "['Little Jimmy Dickens']",
#         'May The Bird Of Paradise Fly Up Your Nose'], dtype='<U661'),
#  array(['95.0520275070095', "['Megadeth']",
#         'Holy Wars...The Punishment Due - Demo/Remastered 2004'],
#        dtype='<U661'),
#  array(['95.07068980799279', "['Rocío Dúrcal']", 'Como Tu Mujer'],
#        dtype='<U661'),
#  array(['95.14107714202856', "['Flux Pavilion']", "I Can't Stop"],
#        dtype='<U661'),
#  array(['94.955580548613', "['Sara Evans']", 'A Real Fine Place to Start'],
#        dtype='<U661'),
#  array(['94.71900825948661', "['George Winston']", 'Living Without You'],
#        dtype='<U661'),
#  array(['94.9350685530604', "['Ricardo Montaner']", 'Ojos negros'],
#        dtype='<U661'),
#  array(['94.94957384621542', "['Liberación']", 'Con El Corazón En La Mano'],
#        dtype='<U661'),
#  array(['94.73643022623071', "['Duke Ellington', 'Count Basie']", 'To You'],
#        dtype='<U661'),
#  array(['95.08432748386244', "['Wu-Tang Clan']",
#         'After the Laughter Comes Tears - Tearz Vocal'], dtype='<U661'),
#  array(['94.50763526047963', "['The Soft Winds']", 'What Is There To Say'],
#        dtype='<U661'),
#  array(['95.48426435384319', "['Helloween']", 'Keeper of the Seven Keys'],
#        dtype='<U661'),
#  array(['94.56271282944674', "['Henry Mancini']", 'Dreamsville'],
#        dtype='<U661'),
#  array(['95.05954601098139', "['David Guetta']", "Love Don't Let Me Go"],
#        dtype='<U661'),
#  array(['94.69659953228967', "['Bert Kaempfert']", 'Take Me'],
#        dtype='<U661'),
#  array(['94.56389022810521', "['Geeta Dutt']", 'Jiya Mora Hale Dole Ho'],
#        dtype='<U661'),
#  array(['94.99511779438026', "['Insane Clown Posse']", 'Toy Box'],
#        dtype='<U661'),
#  array(['94.95653518239826', "['PARTYNEXTDOOR', 'Drake']",
#         'Come and See Me (feat. Drake)'], dtype='<U661'),
#  array(['94.61813802245437', "['Alcoholics Anonymous']", 'On His Way'],
#        dtype='<U661'),
#  array(['94.5377454928067', "['Sylvia Rexach', 'Tuti Umpierre']",
#         'Di Corazón'], dtype='<U661'),
#  array(['94.77887490591829', "['Oscar Peterson Trio']", "Bag's Groove"],
#        dtype='<U661'),
#  array(['94.92205643323528', "['Arctic Monkeys']", 'Riot Van'],
#        dtype='<U661'),
#  array(['94.38117305311974', "['Markos Vamvakaris']", 'Arap Zeimpekiko'],
#        dtype='<U661'),
#  array(['94.62944990129029', "['The Everly Brothers']",
#         "Please Help Me, I'm Falling"], dtype='<U661'),
#  array(['95.12810304702072', "['Majid Jordan']", 'Her'], dtype='<U661'),
#  array(['94.98341565820999', "['Taylor Swift']",
#         'Cornelia Street - Live From Paris'], dtype='<U661'),
#  array(['94.9221014819801', "['Althea And Donna']",
#         'No More Fighting - 2001 Digital Remaster'], dtype='<U661'),
#  array(['94.82250336157982', "['The Beatles']",
#         'Matchbox - Remastered 2009'], dtype='<U661'),
#  array(['94.93608295048706', "['Aleks Syntek']", 'Corazones Invencibles'],
#        dtype='<U661'),
#  array(['95.03658235936369', "['Def Leppard']", 'Excitable'], dtype='<U661'),
#  array(['94.78018171197776', "['INDIA']", 'Ese Hombre'], dtype='<U661'),
#  array(['94.39719704321166', "['Erroll Garner']", "She's Funny That Way"],
#        dtype='<U661'),
#  array(['94.44372536419681',
#         "['Pyotr Ilyich Tchaikovsky', 'Arturo Toscanini', 'NBC Symphony Orchestra', 'Vladimir Horowitz']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: III. Allegro con fuoco'],
#        dtype='<U661'),
#  array(['94.40950471327608', "['Tommy Dorsey', 'Jimmy Dorsey']",
#         'Dippermouth Blues (feat. Jimmy Dorsey)'], dtype='<U661'),
#  array(['94.38380929312511', "['Igor Stravinsky']",
#         'Four Russian Peasant Songs "Saucers" - For Equal Voices with Four Horns: II. Ovsen - Revised 1954 version'],
#        dtype='<U661'),
#  array(['94.65113064147587', "['Paul Williams']",
#         "Phantom's Theme (Beauty And The Beast)"], dtype='<U661'),
#  array(['95.09264257601095', "['Ghostface Killah', 'Superb']",
#         'Ghost Deini (feat. Superb)'], dtype='<U661'),
#  array(['95.1998917417938', "['Rage Against The Machine']", 'Freedom'],
#        dtype='<U661'),
#  array(['95.02472933451988', "['NCT 127']", 'Kick It'], dtype='<U661'),
#  array(['95.28191552341897', "['Danilo Montero']", 'Revelacion'],
#        dtype='<U661'),
#  array(['94.89948919369036', "['Green Day']", "Bab's Uvula Who?"],
#        dtype='<U661'),
#  array(['94.59976102345973', "['Pablo de Sarasate', 'Ossy Renardy']",
#         'Romanza Andaluza (Danse espagnole No. 3), Op. 22, No. 1'],
#        dtype='<U661'),
#  array(['94.87945849216608', "['Queen']", 'Seaside Rendezvous'],
#        dtype='<U661'),
#  array(['94.90159895020182', "['Duelo']", 'Sentimientos De Cartón'],
#        dtype='<U661'),
#  array(['94.9937015535823', "['Black Eyed Peas']", 'Missing You'],
#        dtype='<U661'),
#  array(['94.99505603878377', "['Ludwig van Beethoven', 'Friedrich Gulda']",
#         'Piano Sonata No.14 in C sharp minor, Op.27 No.2 -"Moonlight": 1. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['94.74534408696763', "['Fito Paez']", 'Cable A Tierra'],
#        dtype='<U661'),
#  array(['94.81309120476632', "['Ricky Van Shelton']",
#         'I Meant Every Word He Said'], dtype='<U661'),
#  array(['95.02873214931401', "['Daryl Hall & John Oates']",
#         'Your Imagination'], dtype='<U661'),
#  array(['94.98120628174931', "['Tesla']", 'Be A Man'], dtype='<U661'),
#  array(['94.41105480980264', "['Markos Vamvakaris']",
#         'Otan Pino Toumpekaki'], dtype='<U661'),
#  array(['95.15453429399527', "['The Clash']",
#         'Living In Fame - Remastered'], dtype='<U661'),
#  array(['94.63395739217154', "['Tom Lehrer']",
#         'We Will All Go Together When We Go'], dtype='<U661'),
#  array(['94.8667397158736', "['Samuel Hernández']",
#         'Dios sabe lo que hace'], dtype='<U661'),
#  array(['94.73604688013342', "['Dionne Warwick']", "We've Only Just Begun"],
#        dtype='<U661'),
#  array(['95.04705594203145', "['Mari Trini']", 'Yo no soy esa'],
#        dtype='<U661'),
#  array(['94.52332034219987', "['Giuseppe Verdi', 'Arturo Toscanini']",
#         'La Traviata: Act I, Prelude'], dtype='<U661'),
#  array(['95.08548111500322', "['Maná']", 'Si No Te Hubieras Ido'],
#        dtype='<U661'),
#  array(['94.53948758116648',
#         '[\'Giuseppe Verdi\', \'Mario del Monaco\', \'Hilde Gueden\', \'Giulietta Simionato\', \'Aldo Protti\', "Orchestra dell\'Accademia Nazionale di Santa Cecilia", \'Alberto Erede\']',
#         'Rigoletto / Act 3: Quartetto. "Un dì, se ben rammentomi"'],
#        dtype='<U661'),
#  array(['94.4065374814364', "['Lead Belly']", "Bring Me Li'l Water Silvy"],
#        dtype='<U661'),
#  array(['94.89330565042442', "['Frank Sinatra']",
#         "Swingin' Down The Lane - Remastered 1998"], dtype='<U661'),
#  array(['94.7147111761066', "['Joan Baez']", 'Jesse'], dtype='<U661'),
#  array(['94.92004365207413', "['Modern Talking']", "Angie's Heart"],
#        dtype='<U661'),
#  array(['94.75062770020543', "['Ismael Rivera', 'Cortijo Y Su Combo']",
#         'Borinquén'], dtype='<U661'),
#  array(['94.89721016268022', "['George Howard']",
#         'Everything I Miss At Home'], dtype='<U661'),
#  array(['95.09066149095291', "['Los Nietos']", 'Coqueta'], dtype='<U661'),
#  array(['94.62369083031179', "['Zofia Dromlewiczowa']",
#         'Chapter 3.18 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['94.9015920863456', "['Selena']", 'Missing My Baby'], dtype='<U661'),
#  array(['95.00542386079154', "['Frankie Ruiz']", 'Quiero Llenarte'],
#        dtype='<U661'),
#  array(['94.94268771536954', "['Pink Floyd']", 'Pigs on the Wing 1'],
#        dtype='<U661'),
#  array(['94.92849147631107', "['MC YOGI']", 'Shanti (Peace Out)'],
#        dtype='<U661'),
#  array(['94.65925625978798', "['Mary Wells']", 'Bye Bye Baby'],
#        dtype='<U661'),
#  array(['94.50300781187276', "['Richard Wagner', 'Arturo Toscanini']",
#         'Götterdämmerung, WWV 86D: Vorspiel: Zu neuen Taten, teurer Helde'],
#        dtype='<U661'),
#  array(['94.78355029471123', "['The Rivieras']", 'California Sun'],
#        dtype='<U661'),
#  array(['94.7869041278945', "['Virlan Garcia']", 'Y Cambió Mi Suerte'],
#        dtype='<U661'),
#  array(['94.93804525657421', "['U2']",
#         'Indian Summer Sky - Remastered 2009'], dtype='<U661'),
#  array(['94.44892542911711',
#         "['Claude Debussy', 'Robert Casadesus', 'Gaby Casadesus']",
#         'En blanc et noir, L. 134: III. Scherzando'], dtype='<U661'),
#  array(['94.79487483812011', "['Fairuz']", 'Saalouny El Nas'],
#        dtype='<U661'),
#  array(['95.1510594080986', "['Coldplay']", 'Orphans'], dtype='<U661'),
#  array(['94.87449952271308', "['Bad Religion']", 'World War III'],
#        dtype='<U661'),
#  array(['94.4947879214331', "['Titi Botez']", 'O mia bella Napoli'],
#        dtype='<U661'),
#  array(['95.13731874735915', "['Julieta Venegas']", 'Algo Está Cambiando'],
#        dtype='<U661'),
#  array(['94.6805682453848', "['Connie Francis']", 'Roman Guitar'],
#        dtype='<U661'),
#  array(['94.69800408754809', "['Townes Van Zandt']",
#         'She Came and She Touched Me - Live'], dtype='<U661'),
#  array(['94.87957591435854', "['Elvis Crespo']", 'Tu Sonrisa'],
#        dtype='<U661'),
#  array(['94.95491937604925', "['Grupo Bryndis']", 'Una Aventura Más'],
#        dtype='<U661'),
#  array(['95.41503309448836', "['Van Morrison']", 'T. B. Sheets'],
#        dtype='<U661'),
#  array(['94.72897768523508',
#         "['Chalino Sanchez', 'Los Amables Del Norte']", 'Mariano Félix'],
#        dtype='<U661'),
#  array(['94.36271863068804', "['Francisco Canaro']",
#         'Canillita - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.79249911857254', "['Rick Springfield']", 'I Get Excited'],
#        dtype='<U661'),
#  array(['94.43391994056886', "['Titi Botez']", 'Ai să iubești odată și tu'],
#        dtype='<U661'),
#  array(['94.64970400689985', "['Carpenters']", 'I Need To Be In Love'],
#        dtype='<U661'),
#  array(['94.46685135815645', "['Shamim Akhtar']",
#         'Tir Unka Kaleje Ke Us Paar'], dtype='<U661'),
#  array(['94.97627340915477', "['Queen']",
#         'Somebody To Love - 1991 Bonus Remix'], dtype='<U661'),
#  array(['94.78741355798638', "['Howard Blake']",
#         'Viens Mallika Sous Le Dome Edais From Lakme'], dtype='<U661'),
#  array(['94.37177036338082', "['Chittoor V. Nagaiah']",
#         'Paavana Guna Rama'], dtype='<U661'),
#  array(['94.70616325630935', "['Эрих Мария Ремарк']",
#         'Часть 121.2 - Триумфальная арка'], dtype='<U661'),
#  array(['94.42835476912323', "['Francisco Canaro', 'Agustín Irusta']",
#         'Amurado - Remasterizado'], dtype='<U661'),
#  array(['94.8665010327388', "['The Monkees']",
#         "(I'm Not Your) Steppin' Stone - 2006 Remaster"], dtype='<U661'),
#  array(['95.08978641296267', "['No Doubt']", "Don't Speak"], dtype='<U661'),
#  array(['94.48640573762992',
#         "['Modest Mussorgsky', 'Belgrade National Opera Chorus', 'Nikola Janchich', 'Belgrade National Opera Orchestra', 'Kreshimir Baranovich']",
#         'Boris Godounov, Act 4 (Arr. Rimsky-Korsakov): "Trrr, trrr, trrr, trrr...Zhelyezny kolpak"'],
#        dtype='<U661'),
#  array(['95.04506976853287', "['Sparks']", 'Tryouts For The Human Race'],
#        dtype='<U661'),
#  array(['95.07538208055398', "['Cultura Profética']", 'Un Deseo'],
#        dtype='<U661'),
#  array(['94.56406237868973',
#         "['Olivier Messiaen', 'Esa-Pekka Salonen', 'Philharmonia Orchestra']",
#         'VII. Turangalîla II - Un peu vif, bien modéré from Turangalîla-Symphonie'],
#        dtype='<U661'),
#  array(['94.73915009002188', "['Otis Redding']", "It's Too Late"],
#        dtype='<U661'),
#  array(['94.47698914358612', "['Stan Kenton & His Orchestra']", 'Taboo'],
#        dtype='<U661'),
#  array(['94.66800723341893', "['Regulo Caro']", 'Sería Un Error'],
#        dtype='<U661'),
#  array(['94.97248059642227',
#         '[\'Ottorino Respighi\', "Orchestra dell\' Accademia Nazionale di Santa Cecilia, Roma", \'Antonio Pappano\', "Orchestra dell\'Accademia Nazionale di Santa Cecilia"]',
#         'Pini di Roma (The Pines of Rome): IV. I pini di Via Appia'],
#        dtype='<U661'),
#  array(['94.86819627929682', "['Marvin Gaye']", 'All The Way Around'],
#        dtype='<U661'),
#  array(['94.92384755001214', "['Soft Cell']",
#         'Say Hello, Wave Goodbye - 7" Single Version'], dtype='<U661'),
#  array(['94.84191255154398',
#         "['The Notorious B.I.G.', 'Busta Rhymes', 'Fabolous', 'Nate Dogg', 'Snoop Dogg']",
#         'Running Your Mouth (feat. Snoop Dogg, Nate Dogg, Fabolous & Busta Rhymes) - 2007 Remaster'],
#        dtype='<U661'),
#  array(['95.00467022295587', "['Sisters of Mercy']", 'No Time to Cry'],
#        dtype='<U661'),
#  array(['94.47198355673342',
#         "['Markos Vamvakaris', 'Apostolos Xatzixristos']",
#         'Koula Fragkosiriani'], dtype='<U661'),
#  array(['94.50294084557194', "['Castro Barbosa']", 'Lig Lig Lé'],
#        dtype='<U661'),
#  array(['94.96061438731141', "['HOTEI']",
#         'Battle Without Honor Or Humanity'], dtype='<U661'),
#  array(['95.02693472536258', "['Erykah Badu']", 'In Love With You'],
#        dtype='<U661'),
#  array(['94.64183404631912', "['Agathoklis Mouskas']",
#         'Eleni ta sgoura mallia'], dtype='<U661'),
#  array(['95.03212676939967', "['U2']", 'Wire - Remastered 2009'],
#        dtype='<U661'),
#  array(['95.06452415942063', "['Shakira']", 'Que Vuelvas'], dtype='<U661'),
#  array(['94.58687053192115', "['Dinah Washington']",
#         "I'll Never Kiss You Goodbye"], dtype='<U661'),
#  array(['94.70681455097176',
#         "['Wolfgang Amadeus Mozart', 'Paul Schöffler', 'Anton Dermota', 'Erich Kunz', 'Emmy Loose', 'Lisa della Casa', 'Christa Ludwig', 'Wiener Philharmoniker', 'Karl Böhm']",
#         'Così fan tutte, K.588 / Act 2: "Richiamati da regio contordine"'],
#        dtype='<U661'),
#  array(['94.68840522589697', "['Maxwell']", 'Whenever Wherever Whatever'],
#        dtype='<U661'),
#  array(['94.89633275282084', "['SiR']", 'John Redcorn'], dtype='<U661'),
#  array(['94.73404541889701', "['Эрнест Хемингуэй']",
#         'Часть 39.2 - Зеленые холмы Африки'], dtype='<U661'),
#  array(['94.98578849918836', "['Marianas Trench']", 'Good To You'],
#        dtype='<U661'),
#  array(['94.7797346978944', "['Chet Baker', 'Art Pepper']",
#         'Resonant Emotions'], dtype='<U661'),
#  array(['94.88759182466583', "['LANY']", 'ILYSB - STRIPPED'], dtype='<U661'),
#  array(['94.60882436318884',
#         "['La Numero 1 Banda Jerez De Marco A. Flores']", 'La Cabrona'],
#        dtype='<U661'),
#  array(['94.76435739023958', "['Bill Withers']", "Ain't No Sunshine"],
#        dtype='<U661'),
#  array(['95.03678716739448', "['Sugarcult']", 'Do It Alone'], dtype='<U661'),
#  array(['94.5382368405045',
#         '[\'The Chenille Sisters\', "James Dapogny\'s Chicago Jazz Band"]',
#         'Nagasaki'], dtype='<U661'),
#  array(['95.07769225672388', "['Pink Floyd']", 'What Do You Want from Me'],
#        dtype='<U661'),
#  array(['94.41970870094505', "['Jikki']", 'Srimantulu Dheemantulu'],
#        dtype='<U661'),
#  array(['94.75829876429339', "['Tarika Blue']", 'Dreamflower'],
#        dtype='<U661'),
#  array(['95.06565482128129', "['Tyler Rich']", 'Leave Her Wild'],
#        dtype='<U661'),
#  array(['95.13784021531319', "['Disturbed']", 'Inside the Fire'],
#        dtype='<U661'),
#  array(['94.66769679418167', "['Cream']", 'As You Said'], dtype='<U661'),
#  array(['94.50064503634512', "['C. Ramchandra']", 'Ab Yaad Teri Leke'],
#        dtype='<U661'),
#  array(['95.05176319540739', "['Seafret']", 'Oceans'], dtype='<U661'),
#  array(['94.79445142130636', "['Matt Monro']", 'My Kind of Girl'],
#        dtype='<U661'),
#  array(['94.96128033965124', "['The Offspring']", 'So Alone'],
#        dtype='<U661'),
#  array(['95.2638177857709', "['TOOL']", 'Right In Two'], dtype='<U661'),
#  array(['94.58111133178821', "['Vic Damone']",
#         'The Shadow of Your Smile (Love Theme from "The Sandpiper")'],
#        dtype='<U661'),
#  array(['94.97410179987763', "['El Tri']", 'Pobre soñador'], dtype='<U661'),
#  array(['95.01950537347392', "['John Denver']", 'Ponies'], dtype='<U661'),
#  array(['94.95612397695804', "['Grupo Bryndis']", 'Pagando Mi Pasado'],
#        dtype='<U661'),
#  array(['94.78858189442258', "['JR JR']", 'God Only Knows - EP Version'],
#        dtype='<U661'),
#  array(['95.11797964946659', "['Tove Styrke', 'Vanic']",
#         'Borderline - Vanic Remix'], dtype='<U661'),
#  array(['94.89156024167103',
#         "['Mike Jones', 'Ying Yang Twins', 'Mr. Collipark']", 'Badd'],
#        dtype='<U661'),
#  array(['94.62286921405996', "['Miles Davis']",
#         'I Wants to Stay Here (aka I Loves You Porgy)'], dtype='<U661'),
#  array(['95.04022022168802', "['Rush']", 'Countdown'], dtype='<U661'),
#  array(['94.47266309556677',
#         "['Giacomo Puccini', 'Kiri Te Kanawa', 'Sir John Pritchard', 'London Philharmonic Orchestra']",
#         "La Bohème: Quando m'en vò'"], dtype='<U661'),
#  array(['94.98874309880368', "['Michael Jackson']", 'Earth Song'],
#        dtype='<U661'),
#  array(['94.97481333741013', "['Heaven 17']",
#         "Let's All Make A Bomb - 2006 Digital Remaster"], dtype='<U661'),
#  array(['94.98504705778414', "['Céline Dion']", 'If You Asked Me To'],
#        dtype='<U661'),
#  array(['94.51343701672943', "['Charles Mingus']", 'Old Portrait'],
#        dtype='<U661'),
#  array(['94.80864677059589', "['Bullet For My Valentine']",
#         'Scream Aim Fire'], dtype='<U661'),
#  array(['94.95801692294552', "['The Fratellis']", 'Flathead'],
#        dtype='<U661'),
#  array(['94.52433214231978', "['Dilip Kumar']", 'Gun Gavo'], dtype='<U661'),
#  array(['94.94258871996794', "['JAY-Z', 'Rick Ross']",
#         'F*ckwithmeyouknowigotit'], dtype='<U661'),
#  array(['94.74982958226809',
#         "['Chris Brown', 'Drake', 'T.I.', 'Kanye West', 'Fabolous', 'Rick Ross', 'André 3000']",
#         'Deuces Remix (feat. Drake, T.I., Kanye West, Fabolous, Rick Ross & André 3000)'],
#        dtype='<U661'),
#  array(['94.85278331684432', "['Mountain']", 'Mississippi Queen'],
#        dtype='<U661'),
#  array(['95.06945815732757', "['The Charlie Daniels Band']",
#         'The Devil Went Down to Georgia'], dtype='<U661'),
#  array(['94.53061766904908', "['Doris Day & With Orchestra']",
#         "A Woman's Touch"], dtype='<U661'),
#  array(['94.91050493003424', "['Cymande']", 'Rastafarian Folk Song'],
#        dtype='<U661'),
#  array(['95.05763609836565', "['Van Halen']", 'Humans Being'],
#        dtype='<U661'),
#  array(['94.56699447862381', "['Robin Williams']", 'Wines'], dtype='<U661'),
#  array(['94.81150780986887', "['Rage Against The Machine']",
#         'Take The Power Back'], dtype='<U661'),
#  array(['95.02142872913338', "['Lobo']",
#         'Intro / Me and You and a Dog Named Boo'], dtype='<U661'),
#  array(['95.04581462659958',
#         "['Jessie Mueller', 'Drew Gehling', 'Waitress Original Broadway Cast Ensemble']",
#         'Bad Idea'], dtype='<U661'),
#  array(['95.0450185635196', "['Tears For Fears']", 'Break It Down Again'],
#        dtype='<U661'),
#  array(['95.10531784280613', "['Alan Walker', 'K-391', 'Emelie Hollow']",
#         'Lily'], dtype='<U661'),
#  array(['94.78120377127152', "['Clarence Carter']", 'Do What You Gotta Do'],
#        dtype='<U661'),
#  array(['95.09874134657395', "['Bruce Springsteen']",
#         'Born To Run - Live at Giants Stadium, E. Rutherford, NJ - August 1985'],
#        dtype='<U661'),
#  array(['94.61462588058852', "['Frankie Yankovic & His Yanks']",
#         'Milwaukee Polka'], dtype='<U661'),
#  array(['94.56658048126334', "['THE GUY']", 'When We Die'], dtype='<U661'),
#  array(['94.80796549151593', "['Louis Armstrong']",
#         "Struttin' With Some Barbecue"], dtype='<U661'),
#  array(['95.0389696994362', "['Gordon Lightfoot']", "I'd Do It Again"],
#        dtype='<U661'),
#  array(['94.87025501968218', "['Alec Benjamin']", 'Outrunning Karma'],
#        dtype='<U661'),
#  array(['95.03542363464476', "['Rammstein']", 'Mutter'], dtype='<U661'),
#  array(['94.58541424664608', "['George Harrison']",
#         'Red Lady Too - 2014 Mix'], dtype='<U661'),
#  array(['94.3545476218014',
#         "['Hattle McDaniel', 'Rita Christina', 'Willie Best', 'Jesse Lee Brooks']",
#         'Ice Cold Katie'], dtype='<U661'),
#  array(['94.71980050498757',
#         '[\'Bobby "Boris" Pickett\', \'The Crypt-Kickers\']',
#         "Monster's Holiday"], dtype='<U661'),
#  array(['94.64996501736096', "['Irwin Kostal']", 'Processional Waltz'],
#        dtype='<U661'),
#  array(['94.83236696798862', "['Sonny Rollins']", 'Solitude'],
#        dtype='<U661'),
#  array(['94.47630176618165', "['Louis Armstrong & His Hot Seven']",
#         'S.O.L. Blues'], dtype='<U661'),
#  array(['94.70044422444768', "['Nas']", 'Stillmatic (The Intro)'],
#        dtype='<U661'),
#  array(['94.84986543744104', "['Céline Dion']", 'I Surrender'],
#        dtype='<U661'),
#  array(['94.89725234911212', "['Caifanes']", 'Antes de Que Nos Olviden'],
#        dtype='<U661'),
#  array(['94.964547420153', "['Walter Egan']", 'Magnet & Steel'],
#        dtype='<U661'),
#  array(['94.382616575687', "['Marika Frantzeskopoulou']",
#         'Kakourga pethera'], dtype='<U661'),
#  array(['95.03284512810274', "['Miles Davis']",
#         'Chance It (aka Max Is Making Wax) - Live at Pasadena Civic Auditorium, Pasadena, CA - February 1956'],
#        dtype='<U661'),
#  array(['94.53462971019775', "['Ignacio Corsini']",
#         'Melancólica Casita - Remasterizado'], dtype='<U661'),
#  array(['94.96447125867392', "['Roxette']", 'Soul Deep'], dtype='<U661'),
#  array(['94.62619083509199', "['Jerry Reed']",
#         "Don't Think Twice It's All Right"], dtype='<U661'),
#  array(['94.834735918006', "['Kenny Burrell']", "Kenny's Sound (Take 10)"],
#        dtype='<U661'),
#  array(['94.85386570274218', "['Master P', 'Silkk The Shocker']",
#         "Let's Get 'Em"], dtype='<U661'),
#  array(['95.0039195840565', "['Brand New']", 'Failure By Design'],
#        dtype='<U661'),
#  array(['94.87081543862907', "['Alice Cooper']",
#         'Hell Is Living Without You'], dtype='<U661'),
#  array(['94.42185902188851', "['Francisco Canaro', 'Charlo']",
#         "Y Pa' Que Ser Bueno - Remasterizado"], dtype='<U661'),
#  array(['95.097064298647', "['Morgan Wallen']", 'Cover Me Up'],
#        dtype='<U661'),
#  array(['94.62845354272116', "['The Beach Boys']",
#         'A Thing Or Two - Remastered 2001'], dtype='<U661'),
#  array(['95.14240181355996', "['The Stone Roses']",
#         'Fools Gold - Remastered'], dtype='<U661'),
#  array(['95.06100598293098', "['Anna Clendening']", 'Boys Like You'],
#        dtype='<U661'),
#  array(['94.77216204113346', "['Liquid Mind']", 'Letting Go, Pt. 1'],
#        dtype='<U661'),
#  array(['94.85272259678551', "['Jez Dior', 'Jon Waltz', 'Danny Score']",
#         'Heroin'], dtype='<U661'),
#  array(['95.00926521821007', "['Bobby Moore & The Rhythm Aces']",
#         'Searching For My Love'], dtype='<U661'),
#  array(['94.9976787508464', "['Ohio Players']", 'O-H-I-O'], dtype='<U661'),
#  array(['95.01616373078147', "['Fleetwood Mac']", 'Rhiannon - Live 1977'],
#        dtype='<U661'),
#  array(['94.38576027128389', '["Juan D\'Arienzo"]', 'El triunfo'],
#        dtype='<U661'),
#  array(['95.04746644969134', "['Childish Gambino']", 'Stand Tall'],
#        dtype='<U661'),
#  array(['95.05842436230976',
#         "['Harold Melvin', 'Harold Melvin & The Blue Notes']",
#         'The Love I Lost'], dtype='<U661'),
#  array(['95.04384401032594', "['Santo & Johnny']", 'Hey Jude'],
#        dtype='<U661'),
#  array(['94.7216138697226', "['The xx']", 'Crystalised'], dtype='<U661'),
#  array(['94.45456909788884', "['The Prisonaires']", 'Baby Please'],
#        dtype='<U661'),
#  array(['94.85197737582362', "['Juvenile']", 'Gone Ride With Me'],
#        dtype='<U661'),
#  array(['94.75809754180376', "['Simón Díaz']", 'El Becerrito'],
#        dtype='<U661'),
#  array(['94.83738656128959', "['Little Joe And The Latinaires']",
#         'Ojitos Verdes'], dtype='<U661'),
#  array(['94.88427675582464', "['Danny Berrios']", 'Él Es Jehová'],
#        dtype='<U661'),
#  array(['94.55633773089204', "['The Shells']", 'Deep in My Heart'],
#        dtype='<U661'),
#  array(['94.60079616776717', "['The Brothers Four']",
#         'Where Is Your Heart'], dtype='<U661'),
#  array(['94.80291376203412', "['Gilbert Bécaud']", 'Nathalie'],
#        dtype='<U661'),
#  array(['94.95335445137123', "['Gloria Trevi']", 'Un Día Más de Vida'],
#        dtype='<U661'),
#  array(['94.86878016667774', "['Frédéric Chopin', 'Mikhail Pletnev']",
#         'Chopin: Nocturne No. 20 in C-Sharp Minor, Op. Posth.'],
#        dtype='<U661'),
#  array(['94.99544819503792', "['Alejandra Guzman']", 'Rosas Rojas'],
#        dtype='<U661'),
#  array(['94.55774292757772', "['Cat Power']", 'He War'], dtype='<U661'),
#  array(['94.92703980431718', "['One Direction']", 'Half a Heart'],
#        dtype='<U661'),
#  array(['94.91625119456123', "['The Brothers Johnson']",
#         "Thunder Thumbs And Lightnin' Licks"], dtype='<U661'),
#  array(['94.90049213516323', "['Morgan Wallen']", "Talkin' Tennessee"],
#        dtype='<U661'),
#  array(['94.50781977128176', "['Odetta', 'Larry']", 'Water Boy'],
#        dtype='<U661'),
#  array(['94.6942965784882', "['Gordon Lightfoot']", 'Beautiful'],
#        dtype='<U661'),
#  array(['94.80089557687063', "['Robin Trower']", 'Sweet Wine of Love'],
#        dtype='<U661'),
#  array(['94.95368191088336', "['Sublime']", 'New Song'], dtype='<U661'),
#  array(['94.6277087597764', "['Vicente Fernández']",
#         'Tiempo Y Destiempo - Tema Remasterizado'], dtype='<U661'),
#  array(['94.55893689224122', "['Alexander Scriabin', 'Vladimir Horowitz']",
#         'Sonata No. 3, Op. 23 in F-Sharp Minor: III. Andante'],
#        dtype='<U661'),
#  array(['95.1662677218214', '["King\'s X"]', 'Black the Sky'],
#        dtype='<U661'),
#  array(['94.69782016326401',
#         "['Jesse L. Martin', 'Tracie Thoms', 'Cast Of The Motion Picture Rent']",
#         "I'll Cover You - Reprise"], dtype='<U661'),
#  array(['94.88740922057247', "['Theodore Bikel']", 'Dve Gitari'],
#        dtype='<U661'),
#  array(['94.75883769438002', "['Gram Parsons']",
#         "I Can't Dance - Remastered Version"], dtype='<U661'),
#  array(['94.95197496995257', "['The Intruders']", 'I Wanna Know Your Name'],
#        dtype='<U661'),
#  array(['94.88761902170934', "['UGK']", 'Something Good'], dtype='<U661'),
#  array(['94.44091644165877', "['Johnny Cash']", "I Can't Help It"],
#        dtype='<U661'),
#  array(['94.62975077977683',
#         "['Wolfgang Amadeus Mozart', 'Arturo Toscanini']",
#         'Symphony No. 35 in D Major, K. 385 "Haffner": II. Andante'],
#        dtype='<U661'),
#  array(['94.73870121245994', "['John Denver']", 'The Eagle and the Hawk'],
#        dtype='<U661'),
#  array(['94.45154676223622',
#         "['Giorgos Papasideris', 'Klarino KOstas Giaouzos']", 'Ta Niata'],
#        dtype='<U661'),
#  array(['94.7329587988696', "['Johnny Cash']",
#         'Bridge Over Troubled Water'], dtype='<U661'),
#  array(['94.54979833578179', "['Ninu Mazumder']", 'Aaj Hans Hanske, Pt. 1'],
#        dtype='<U661'),
#  array(['94.62064291458162', "['Zofia Dromlewiczowa']",
#         'Chapter 2.20 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['95.0026525511248', "['Skillet']", "Don't Wake Me"], dtype='<U661'),
#  array(['94.86817298048653', "['Lowell George']", 'Find a River'],
#        dtype='<U661'),
#  array(['94.44014870195892', "['Ludwig van Beethoven', 'Rudolf Serkin']",
#         'Sonata No. 30 in E Major for Piano, Op. 109: II. Prestissimo'],
#        dtype='<U661'),
#  array(['94.69662352417014', "['Elmore James']", 'Early One Morning'],
#        dtype='<U661'),
#  array(['94.54157127891851', "['Gloria Lynne', 'Marty Paich']",
#         'I Wish You Love'], dtype='<U661'),
#  array(['95.1188947200749', "['MARINA']", 'Hollywood - Single Version'],
#        dtype='<U661'),
#  array(['94.53595845169706', "['Art Blakey Percussion Ensemble']",
#         'The Sacrifice'], dtype='<U661'),
#  array(['95.1508487411894', "['Chilliwack']", 'Whatcha Gonna Do'],
#        dtype='<U661'),
#  array(['95.09016229746831', "['Lijadu Sisters']", 'Not Any Longer'],
#        dtype='<U661'),
#  array(['95.06503183157386', "['Supertramp']", "Another Man's Woman"],
#        dtype='<U661'),
#  array(['94.51885092032319', "['M. K. Thyagaraja Bhagavathar']",
#         'Manam Ninainthenginene'], dtype='<U661'),
#  array(['94.40326568415733', "['Stan Kenton']", 'Pennies From Heaven'],
#        dtype='<U661'),
#  array(['94.71681852709197', "['Bette Midler']", 'Otto Titsling'],
#        dtype='<U661'),
#  array(['94.97938118040167', "['Crown The Empire']", 'Millennia'],
#        dtype='<U661'),
#  array(['95.10628357567094', "['Black Sabbath']",
#         "War Pigs / Luke's Wall - 2014 Remaster"], dtype='<U661'),
#  array(['94.91723185295524', "['The Jacksons']", 'Time Waits For No One'],
#        dtype='<U661'),
#  array(['94.70932864198286', "['Luis Miguel']",
#         'No Me Puedo Escapar De Ti'], dtype='<U661'),
#  array(['94.48258339720986', "['Igor Stravinsky', 'Pierre Monteux']",
#         'The Rite of Spring: Part I: Dances of the Young Girls'],
#        dtype='<U661'),
#  array(['94.87939058492992', "['Ty Dolla $ign', 'Tory Lanez']",
#         'Droptop in the Rain (feat. Tory Lanez)'], dtype='<U661'),
#  array(['94.7967373303043', "['Playa Limbo']", 'El Tiempo de Ti'],
#        dtype='<U661'),
#  array(['94.7957161469311', "['Эрнест Хемингуэй']",
#         'Часть 46.4 & Часть 47.1 - По ком звонит колокол'], dtype='<U661'),
#  array(['94.92212145294367', "['Nina Simone']", 'Just Like a Woman'],
#        dtype='<U661'),
#  array(['95.05873387897351', "['Moby']", 'Flower'], dtype='<U661'),
#  array(['94.71720232095602', "['Marah']", 'Home for the Holidays'],
#        dtype='<U661'),
#  array(['94.7626535639105', "['Donna Summer']", 'Whispering Waves'],
#        dtype='<U661'),
#  array(['94.80934447570768', "['El Poder Del Norte']", 'Acepto Mi Derrota'],
#        dtype='<U661'),
#  array(['94.72601548684582', "['The Lumineers']", 'Ho Hey'], dtype='<U661'),
#  array(['94.62795684140728',
#         "['Wolfgang Amadeus Mozart', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Cosi fan tutte, K. 588, Act II: "Per pietà, ben mio, perdona"'],
#        dtype='<U661'),
#  array(['94.92836073491792', "['Céline Dion']",
#         'The Power of Love - Radio Edit'], dtype='<U661'),
#  array(['95.32778018506117', "['Shekinah Glory Ministry']",
#         'Praise Is What I Do'], dtype='<U661'),
#  array(['94.52616138978668', "['Geeta Dutt']", 'Nache Ghoda Nache'],
#        dtype='<U661'),
#  array(['95.13496246281093', "['Peter Tosh']", 'Soon Come - 2002 Remaster'],
#        dtype='<U661'),
#  array(['94.51628150521542', "['Culture Club']",
#         "That's The Way - I'm Only Trying To Help You; 2002 Digital Remaster"],
#        dtype='<U661'),
#  array(['95.11257525964555', "['Tarkan']", 'Şımarık'], dtype='<U661'),
#  array(['95.13874589595852', "['David Archuleta']", 'Crush'], dtype='<U661'),
#  array(['94.7732938535507', "['Jason Isbell']", 'Speed Trap Town'],
#        dtype='<U661'),
#  array(['94.97934901579279', "['Tracy Byrd']",
#         "Don't Take Her She's All I Got"], dtype='<U661'),
#  array(['95.13010624581806', "['Metallica']",
#         'Fade To Black (Live at The Hollywood Palladium, Los Angeles, CA – March 10th, 1985)'],
#        dtype='<U661'),
#  array(['94.410759687842',
#         "['Edward Elgar', 'Philharmonia Orchestra', 'Andrew Davis']",
#         'Enigma Variations, Op. 36: Variation 4: W.M.B.'], dtype='<U661'),
#  array(['95.00193463146934', "['Alabama']", 'Song of the South'],
#        dtype='<U661'),
#  array(['94.43945153635904', "['Manuel Pomian']", 'Ayer y Hoy'],
#        dtype='<U661'),
#  array(['94.96938221300483', "['Cypress Hill']",
#         'Tequila Sunrise - Spanish Version'], dtype='<U661'),
#  array(['94.77262477321189', "['Astrud Gilberto']",
#         'Crickets Sing For Anamaria (Os Grillos)'], dtype='<U661'),
#  array(['94.59186211316134', "['Bob Brookmeyer', 'Bill Evans']",
#         'As Time Goes By'], dtype='<U661'),
#  array(['94.73041847310755', "['Эрих Мария Ремарк']",
#         'Часть 160.4 & Часть 161.1 - Триумфальная арка'], dtype='<U661'),
#  array(['94.96960498363059', "['He Is We', 'Owl City']", 'All About Us'],
#        dtype='<U661'),
#  array(['94.78460637649309', "['Willie Nelson']",
#         'Can I Sleep in Your Arms'], dtype='<U661'),
#  array(['94.44683883426924', "['Aaron Copland', 'Martha Lipton']",
#         'Twelve Poems of Emily Dickinson: XI. Going to Heaven!'],
#        dtype='<U661'),
#  array(['95.24986119606817', "['Triumph']",
#         'Blinding Light Show / Moonchild'], dtype='<U661'),
#  array(['94.99661936463028', "['Depeche Mode']",
#         "It Doesn't Matter - 2006 Remaster"], dtype='<U661'),
#  array(['94.55711487043018', "['Jack Payne', 'His BBC Dance Orchestra']",
#         'When You Were My Sweetheart and I Was the Kid Next Door'],
#        dtype='<U661'),
#  array(['94.3979282379839', "['Malti']", 'Aaj More Dwar Anand Apaar'],
#        dtype='<U661'),
#  array(['94.81965128561073', "['Chalino Sanchez', 'Banda Brava']",
#         'Arcadio Barraza'], dtype='<U661'),
#  array(['95.20204772142537',
#         "['Aniceto Molina Y La Luz Roja De San Marcos']",
#         'Cumbia Sampuesana'], dtype='<U661'),
#  array(['95.11537365892147', "['At The Drive In']", 'Quarantined'],
#        dtype='<U661'),
#  array(['94.81380175157138', "['Jerry Garcia']",
#         "Knockin' On Heaven's Door"], dtype='<U661'),
#  array(['94.61987477645356', "['Carmen Miranda']",
#         'Mulato Anti-Metropolitano'], dtype='<U661'),
#  array(['95.25718624317442',
#         '[\'Eric Benét\', \'Faith Evans\', \'Kevin "K.D." Davis\']',
#         'Georgy Porgy (feat. Faith Evans)'], dtype='<U661'),
#  array(['94.55478021965506', "['Jascha Heifetz']",
#         'Tambourin Chinois - 1944'], dtype='<U661'),
#  array(['94.47492386765198', "['Johann Sebastian Bach', 'Glenn Gould']",
#         'Partita No. 5 in G Major, BWV 829: III. Courente'], dtype='<U661'),
#  array(['95.16575958712902', "['Miley Cyrus']", 'Party In The U.S.A.'],
#        dtype='<U661'),
#  array(['94.96075567796152', "['Wings']", 'Time To Hide - Remastered 2014'],
#        dtype='<U661'),
#  array(['95.22777346702856', "['Avenged Sevenfold']",
#         'Strength of the World'], dtype='<U661'),
#  array(['94.92840207883377', "['Dzeko & Torres', 'Delaney Jane']",
#         "L'amour toujours (feat. Delaney Jane) - Tiësto Edit"],
#        dtype='<U661'),
#  array(['94.80674496172742', "['Rose Royce']", 'I Wanna Get Next To You'],
#        dtype='<U661'),
#  array(['95.21848630963682', "['Def Leppard']",
#         "Bringin' On The Heartbreak"], dtype='<U661'),
#  array(['94.92235539876529', "['Barbra Streisand']",
#         'Till I Loved You (Duet with Don Johnson)'], dtype='<U661'),
#  array(['94.47263112424606', "['Shamshad Begum', 'Mukesh']",
#         'Kya Jadu Hai Tere Paas Piya'], dtype='<U661'),
#  array(['94.89090821661493', "['Vince Gill']", 'Look At Us'], dtype='<U661'),
#  array(['94.60607338465019', "['Johann Sebastian Bach', 'Claudio Arrau']",
#         'Goldberg Variations, BWV 988: Variation XXI - Canon at the Seventh'],
#        dtype='<U661'),
#  array(['94.96664616013094', "['Dinah Washington', 'Clifford Brown']",
#         'Lover Come Back To Me - Live In Los Angeles, 1954'], dtype='<U661'),
#  array(['94.39704591653009', "['C. Ramchandra']",
#         'Subhaschandra Ke Naam Se, Pt. 1'], dtype='<U661'),
#  array(['95.158094764271', "['Don Henley']", 'Sunset Grill'], dtype='<U661'),
#  array(['94.84334924879423', "['Jeezy', 'T.I.']", 'F.A.M.E.'],
#        dtype='<U661'),
#  array(['95.07536779891338', "['Týr']", 'Blood of Heroes'], dtype='<U661'),
#  array(['94.85264381959315', "['David Bowie']", 'Sorrow - 2015 Remaster'],
#        dtype='<U661'),
#  array(['95.10219719360437', "['Chase Rice']", 'Gonna Wanna Tonight'],
#        dtype='<U661'),
#  array(['94.86016800614749', "['Rod Stewart']",
#         'Have I Told You Lately - 2008 Remaster'], dtype='<U661'),
#  array(['94.40728662258098', "['Buddy Holly']", 'Look At Me'],
#        dtype='<U661'),
#  array(['94.62040631316314', "['Tommy James & The Shondells']",
#         'Run, Run, Baby, Run'], dtype='<U661'),
#  array(['94.29649130698381', "['Francis Poulenc', 'Pierre Bernac']",
#         'Main dominée par le coeur, FP 135'], dtype='<U661'),
#  array(['94.57719232981299', "['Raffi']", 'Cluck, Cluck, Red Hen'],
#        dtype='<U661'),
#  array(['94.53351445782386',
#         "['Jule Styne', 'Jacqueline Mayro', 'Karen Moore', 'The Gypsy Ensemble', 'Milton Rosenstock']",
#         'Gypsy: Baby June and Her Newsboys'], dtype='<U661'),
#  array(['94.74754879886682', "['Mac Miller']", 'Avian'], dtype='<U661'),
#  array(['94.84460158998432', "['Slipknot']", 'Vermilion, Pt. 2'],
#        dtype='<U661'),
#  array(['94.49425074840089', "['Woody Guthrie']",
#         'Riding in my car (Car song)'], dtype='<U661'),
#  array(['94.46218916576593', "['Markos Vamvakaris']",
#         'Ki an methaw ta vradakia'], dtype='<U661'),
#  array(['94.49262720005599', "['Noor Jehan']", 'Yeh Kaun Hansa'],
#        dtype='<U661'),
#  array(['95.09418558980482', "['Mudvayne']", 'Nothing To Gein'],
#        dtype='<U661'),
#  array(['94.55272529577606', "['Tom Lehrer']",
#         'It Makes A Fellow Proud To Be A Soldier'], dtype='<U661'),
#  array(['94.99854932838528', "['Hole']", 'I Think That I Would Die'],
#        dtype='<U661'),
#  array(['95.14436182770652', "['Scorpions']", "Don't Stop At The Top"],
#        dtype='<U661'),
#  array(['95.13403850004728', "['Hillsong Young & Free']", 'Wake - Live'],
#        dtype='<U661'),
#  array(['95.12153706360189', "['The Kooks']", 'Sweet Emotion'],
#        dtype='<U661'),
#  array(['94.97502636486128', "['Marvin Gaye']", 'Help The People'],
#        dtype='<U661'),
#  array(['95.01095499974716', "['El As De La Sierra']",
#         'Patron De Patrones'], dtype='<U661'),
#  array(['95.18273277807948',
#         "['Enrique Iglesias', 'Descemer Bueno', 'Gente De Zona']",
#         'Bailando - Spanish Version'], dtype='<U661'),
#  array(['95.05813522840683', "['The Cure', 'Paul Oakenfold']",
#         'Close to Me - Closest Mix'], dtype='<U661'),
#  array(['94.84872985773771', "['Drake']", 'The Ride'], dtype='<U661'),
#  array(['94.83934757625089', "['Kate Bush']",
#         'Hounds Of Love - 2018 Remaster'], dtype='<U661'),
#  array(['94.84955101533403', "['Luke Faulkner']", 'Clocks'], dtype='<U661'),
#  array(['94.95610642019399', "['Trevor Jones']", "Thirteen O'Clock"],
#        dtype='<U661'),
#  array(['94.79039119110521', "['Shiny Gnomes']", 'Spirit of the Band'],
#        dtype='<U661'),
#  array(['95.11784568660678', "['Dream Theater']", 'Space-Dye Vest'],
#        dtype='<U661'),
#  array(['94.77101735851892', "['No Jumper', 'Tay-K', 'BlocBoy JB']",
#         'Hard (feat. Tay-K and BlocBoy JB)'], dtype='<U661'),
#  array(['94.59595483557023', "['Jaganmoy Mitra']", 'Satti Bachhar Age'],
#        dtype='<U661'),
#  array(['94.98028163225376',
#         "['The Presidents Of The United States Of America']",
#         'Kick Out the Jams'], dtype='<U661'),
#  array(['94.71290453432604', "['Ian & Sylvia']", 'Nancy Whiskey'],
#        dtype='<U661'),
#  array(['95.02285293336058', "['Jem']", 'They'], dtype='<U661'),
#  array(['94.45990195806432', "['Cristian Vasile']", 'Seniorita mea'],
#        dtype='<U661'),
#  array(['94.59542076846415', "['Igor Stravinsky', 'Leopold Stokowski']",
#         'Le sacre du printemps (The Rite of Spring): Part II: The Sacrifice: Mystic Circles of the Young Girls'],
#        dtype='<U661'),
#  array(['95.00549263805016', "['Kinto Sol']", 'Hecho En Mexico'],
#        dtype='<U661'),
#  array(['94.89348878485028', "['Gucci Mane', 'Drake', 'Lil Wayne']",
#         'Both (feat. Drake & Lil Wayne) - Remix'], dtype='<U661'),
#  array(['94.49190114192184', "['Frank Sinatra', 'Tommy Dorsey Orchestra']",
#         'Imagination'], dtype='<U661'),
#  array(['94.93289548367808', "['Oingo Boingo']", 'Nasty Habits'],
#        dtype='<U661'),
#  array(['95.32964017873336', "['Neil Young', 'Crazy Horse']",
#         'Love to Burn'], dtype='<U661'),
#  array(['94.940047024509', "['Ozzy Osbourne']", 'Tonight'], dtype='<U661'),
#  array(['94.74083289524644', "['Frank Sinatra']",
#         'Try A Little Tenderness - Remastered'], dtype='<U661'),
#  array(['94.49035591591385', "['Robert Johnson']",
#         'Hell Hound On My Trail'], dtype='<U661'),
#  array(['94.99312136731538', "['Alfred Hitchcock']",
#         'The Haunted and the Hunters'], dtype='<U661'),
#  array(['94.61771222023594', "['Dean Martin']", "Sparklin' Eyes"],
#        dtype='<U661'),
#  array(['94.52328268334318', "['Meena Kapoor']", 'Bansuri Bajai Aaj'],
#        dtype='<U661'),
#  array(['94.63799771167632', "['Apocolothoth']", 'Heaven'], dtype='<U661'),
#  array(['94.47019216534133', "['Kamala Jharia']", 'O Bidesi Bandhu'],
#        dtype='<U661'),
#  array(['95.5405223075138', "['Crosby, Stills, Nash & Young']",
#         'Southern Man - Live'], dtype='<U661'),
#  array(['95.00227961236408', "['AWOLNATION']", 'Woman Woman'],
#        dtype='<U661'),
#  array(['94.80647539014781', "['Los Llayras']", 'He Creído'], dtype='<U661'),
#  array(['94.69543324114566', "['Эрнест Хемингуэй']",
#         'Часть 15.2 - Старик и море'], dtype='<U661'),
#  array(['94.84836309408092', "['Trevor Morris']",
#         'Dragon Age Inquisition Theme'], dtype='<U661'),
#  array(['95.14902578482571', "['Seether']", 'Words As Weapons'],
#        dtype='<U661'),
#  array(['94.94404716535308', "['Deep Purple']", 'Soldier of Fortune'],
#        dtype='<U661'),
#  array(['95.05512012626313', "['Weezer']", 'Memories'], dtype='<U661'),
#  array(['94.50368530975317', "['Orchestra Studio 7']",
#         'Passione - Instrument and base Version'], dtype='<U661'),
#  array(['94.5898175123311', "['The Moody Blues']",
#         'The Best Way To Travel - BBC Radio One "Top Gear" Session / 1968'],
#        dtype='<U661'),
#  array(['94.88895292860495', "['Wolfgang Amadeus Mozart', 'Jenő Jandó']",
#         'Piano Sonata No. 18 in D Major, K. 576: II. Adagio'],
#        dtype='<U661'),
#  array(['94.62740417208491', "['Percy Faith & His Orchestra']",
#         'Blue on Blue'], dtype='<U661'),
#  array(['95.02705710531103', "['Chase Bryant']", 'Change Your Name'],
#        dtype='<U661'),
#  array(['94.85131184034866', "['Stevie Wonder']", 'Blame It On The Sun'],
#        dtype='<U661'),
#  array(['94.75587235303068', "['The Dave Brubeck Quartet']",
#         'Like Someone In Love - Live'], dtype='<U661'),
#  array(['94.89502241505879',
#         "['Ludwig van Beethoven', 'London Symphony Orchestra', 'Josef Krips']",
#         'Symphony No. 7 in a Major, Op. 92: I. Poco sostenuto - Vivace'],
#        dtype='<U661'),
#  array(['94.80310791743811', "['Sam Cooke']", 'Chain Gang - Live'],
#        dtype='<U661'),
# ...
#         'Journey to Fort Sedgewick / Shooting Star / The John Dunbar Theme / Arrival at Fort Sedgewick (expanded)'],
#        dtype='<U661'),
#  array(['94.63210730395437', "['Freddie Hubbard']", 'Body And Soul'],
#        dtype='<U661'),
#  array(['95.02097111151521', "['The Beach Boys']",
#         'Sloop John B - Live At Universal Studios, Universal City, CA/1989'],
#        dtype='<U661'),
#  array(['94.59799720674512', "['Joji']", "I Don't Wanna Waste My Time"],
#        dtype='<U661'),
#  array(['94.78073210786229', "['Keith Whitley']",
#         'When You Say Nothing at All'], dtype='<U661'),
#  array(['94.36887730043085', "['Shamshad Begum', 'Rajkumari']",
#         'Ishq Mein Hum Mar Jayenge'], dtype='<U661'),
#  array(['94.46082409283528', "['Isaura Garcia']", 'Linda Flor Yaya'],
#        dtype='<U661'),
#  array(['94.72875748979715',
#         "['Christoph Willibald Gluck', 'Arturo Toscanini']",
#         'Act II: Dance of the Blessed Spirits'], dtype='<U661'),
#  array(['94.73240304986561', "['The Velvet Underground']",
#         "I'm Sticking With You"], dtype='<U661'),
#  array(['95.05926701179648', "['Sparta']", 'Cut Your Ribbon'],
#        dtype='<U661'),
#  array(['94.65657828240782', "['Duke Ellington']", 'Sonnet to Hank Cinq'],
#        dtype='<U661'),
#  array(['94.86867189359003', "['Luther Ingram']",
#         "Ain't That Loving You For More Reasons Than One"], dtype='<U661'),
#  array(['94.63777608191413', "['Vic Damone']",
#         'Just Say I Love Her (Dicitencello Vuie)'], dtype='<U661'),
#  array(['94.7805470636967',
#         "['George Gershwin', 'Oscar Levant', 'Andre Kostelanetz', 'New York Philharmonic']",
#         'Piano Concerto in F Major: I. Allegro'], dtype='<U661'),
#  array(['94.70851839317403', "['The Rolling Stones']",
#         'Lady Jane - Mono Version'], dtype='<U661'),
#  array(['94.84407753059106', "['Britney Spears']",
#         "I'm Not a Girl, Not Yet a Woman"], dtype='<U661'),
#  array(['94.60740124232004', "['Frank Sinatra', 'Larry Walsh']",
#         "What's New? - 2018 Stereo Mix"], dtype='<U661'),
#  array(['95.04420715067282', '["Guns N\' Roses"]', "Sweet Child O' Mine"],
#        dtype='<U661'),
#  array(['95.08002265486239', "['J Balvin', 'Farruko']", '6 AM'],
#        dtype='<U661'),
#  array(['94.89979945333214',
#         "['DJ Khaled', 'Drake', 'Rick Ross', 'Lil Wayne']",
#         'No New Friends - SFTB Remix'], dtype='<U661'),
#  array(['94.87806074273634', "['Gary Bartz']", 'Music Is My Sanctuary'],
#        dtype='<U661'),
#  array(['94.93604705749074', "['A Tribe Called Quest']",
#         'We The People....'], dtype='<U661'),
#  array(['94.36749452378292', "['Kreider']", 'Allegro 1'], dtype='<U661'),
#  array(['94.73547111102933', "['Merle Haggard']",
#         'Okie From Muskogee - Live In Muskogee, Oklahoma/1969'],
#        dtype='<U661'),
#  array(['95.00380540358991', "['Black Oak Arkansas']", 'Hot And Nasty'],
#        dtype='<U661'),
#  array(['94.74104197225759', "['Cornelio Reyna']", 'Que Tal Sí Te Compró'],
#        dtype='<U661'),
#  array(['94.43526378587852', "['Doris Day']", 'The Christmas Song'],
#        dtype='<U661'),
#  array(['94.6192559286856', "['Sam Cooke']", 'A Whole Lotta Woman'],
#        dtype='<U661'),
#  array(['94.73759935829194', "['The Notorious B.I.G.']",
#         'Things Done Changed - 2005 Remaster'], dtype='<U661'),
#  array(['94.58713372880223', "['Bob Wills & His Texas Playboys']",
#         'Cotton Eyed Joe - Single Version'], dtype='<U661'),
#  array(['95.10274040592638', "['Mark Wills']", "Jacob's Ladder"],
#        dtype='<U661'),
#  array(['94.9590355710218', "['Morbid Angel']", 'Maze of Torment'],
#        dtype='<U661'),
#  array(['94.78385711849721', "['James Taylor']", 'Music - 2019 Remaster'],
#        dtype='<U661'),
#  array(['95.21007852095579', "['Don Moen']", 'God Is Good All The Time'],
#        dtype='<U661'),
#  array(['95.08152111152481', "['Mötley Crüe']", 'City Boy Blues'],
#        dtype='<U661'),
#  array(['94.60087039721559', "['Johnny Cash']",
#         'Five Feet High and Rising'], dtype='<U661'),
#  array(['95.04663312619346',
#         "['Dana Fuchs', 'Jim Sturgess', 'Evan Rachel Wood', 'T.V. Carpio']",
#         'Dear Prudence'], dtype='<U661'),
#  array(['94.9873691982581', "['Crossfade']", 'The Unknown'], dtype='<U661'),
#  array(['94.95989116615658', "['Joni Mitchell']",
#         "Harry's House / Centerpiece"], dtype='<U661'),
#  array(['95.14887673125045', "['George Strait']", 'Ocean Front Property'],
#        dtype='<U661'),
#  array(['94.6809976262513', "['Tony Bennett']",
#         'My Favorite Things - Single Version'], dtype='<U661'),
#  array(['95.15708907095572', "['Public Enemy']", 'Fight The Power'],
#        dtype='<U661'),
#  array(['95.09165611097458', "['Thelonious Monk Septet']",
#         "Well, You Needn't"], dtype='<U661'),
#  array(['94.75522758660698', "['Townes Van Zandt']", "Standin'"],
#        dtype='<U661'),
#  array(['94.984062120217', "['Subhumans']", "'Til the Pigs Come Round"],
#        dtype='<U661'),
#  array(['94.56896439205407', "['The Warren Barker Orchestra']",
#         'Caper at the Coffee House'], dtype='<U661'),
#  array(['94.64824415372574', "['Marni Nixon']",
#         "Wouldn't It Be Loverly - Voice"], dtype='<U661'),
#  array(['94.41693045278792', "['Roberto Murolo']", 'Marechiare'],
#        dtype='<U661'),
#  array(['94.9684031506597', "['Del The Funky Homosapien']",
#         'The Wacky World of Rapid Transit'], dtype='<U661'),
#  array(['94.80754134569544', "['Barbra Streisand']",
#         'My Heart Belongs to Me'], dtype='<U661'),
#  array(['94.40462659244076', "['Titi Botez']", 'Seara'], dtype='<U661'),
#  array(['94.99772966928036', "['Buddy Guy']", 'Feels Like Rain'],
#        dtype='<U661'),
#  array(['94.97454721767997', "['Carlos Vives']", 'La Tierra del Olvido'],
#        dtype='<U661'),
#  array(['95.05066606430314', "['Red Rockers']", 'China'], dtype='<U661'),
#  array(['94.44402940448946', "['Χρυσούλα Στίνη', 'Μ.Χάλαρης', 'Ι.Δέδες']",
#         'Θα σε κλέψω'], dtype='<U661'),
#  array(['94.33493224451799', "['Fats Waller']", 'My Fate Is In Your Hands'],
#        dtype='<U661'),
#  array(['94.76560743296623', "['Эрих Мария Ремарк']",
#         'Часть 182.3 & Часть 183.1 - Триумфальная арка'], dtype='<U661'),
#  array(['95.11067730566467',
#         "['Commander Cody and His Lost Planet Airmen']",
#         'Down To Seeds And Stems Again Blues - Live (1973/Austin, TX)'],
#        dtype='<U661'),
#  array(['95.06891970628425', "['Nickelback']", 'Because of You'],
#        dtype='<U661'),
#  array(['94.49200862248502', "['Les Paul']", 'Sleep'], dtype='<U661'),
#  array(['94.54850038101976', "['Claude King']", 'Big River, Big Man'],
#        dtype='<U661'),
#  array(['94.99110236841851',
#         "['Ludwig van Beethoven', 'Rudolf Serkin', 'Bruno Walter']",
#         'Concerto No. 5 in E-Flat Major for Piano and Orchestra, Op. 73 "Emperor": I. Allegro'],
#        dtype='<U661'),
#  array(['94.84960219697408', "['Daryl Hall & John Oates']",
#         'Had I Known You Better Then'], dtype='<U661'),
#  array(['94.9394275676464', "['Aerosmith']",
#         'Back in the Saddle - Live at Market Square Arena, Indianapolis, IN - July 1977'],
#        dtype='<U661'),
#  array(['94.71773894458735', "['Waylon Jennings']",
#         'Dreaming My Dreams with You'], dtype='<U661'),
#  array(['94.48721856576597', "['Geeta Dutt', 'Mohammed Rafi']",
#         'Jane Kahan Mera Jigar Gaya Ji'], dtype='<U661'),
#  array(['94.42613239088803', "['Cornelia Otis Skinner']",
#         'Song: "Tourne Mon Moulin"'], dtype='<U661'),
#  array(['95.02165612198151', "['The Royal Concept']", 'On Our Way'],
#        dtype='<U661'),
#  array(['94.78374736258054', "['Philip Aaberg']", 'No Wonder They Sing'],
#        dtype='<U661'),
#  array(['95.09784082615961', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 29'], dtype='<U661'),
#  array(['95.16190553122516', "['Ebo Taylor']", 'Love and Death'],
#        dtype='<U661'),
#  array(['94.90423028074535', "['Billy Bragg']",
#         'Must I Paint You a Picture'], dtype='<U661'),
#  array(['94.83392519345112', "['El Trono de Mexico']", 'Prometiste Volver'],
#        dtype='<U661'),
#  array(['94.98359771628837', "['Jake Owen']", 'Barefoot Blue Jean Night'],
#        dtype='<U661'),
#  array(['94.8841975523629', "['G-Eazy', 'E-40', 'Jay Anthony']",
#         'Far Alone (feat. E-40 & Jay Ant)'], dtype='<U661'),
#  array(['94.72295980018107', "['Los Caminantes']", 'Pobre Millonario'],
#        dtype='<U661'),
#  array(['94.50865720525786', "['Flatt & Scruggs']", "What's Good About It"],
#        dtype='<U661'),
#  array(['94.55098653970792', "['Johannes Brahms', 'Glenn Gould']",
#         'Intermezzo No. 7 in A Minor, Op. 76 - Moderato semplice - Remastered'],
#        dtype='<U661'),
#  array(['94.67111747787591', "['The Jud Conlon Chorus']",
#         'Main Title (The Second Star to the Right) / All This Has Happened Before'],
#        dtype='<U661'),
#  array(['94.75369171292638',
#         "['Ludwig van Beethoven', 'Vladimir Horowitz']",
#         'Piano Sonata No. 8 in C Minor, Op. 13 "Pathétique": II. Adagio cantabile'],
#        dtype='<U661'),
#  array(['94.741368939793', "['Fred von Hoerschelmann']",
#         'Kapitel 12 - Amtmann Enders'], dtype='<U661'),
#  array(['95.03021225099548', "['Megadeth']", 'No More Mr. Nice Guy'],
#        dtype='<U661'),
#  array(['95.0633324895365', "['Boyz II Men']", 'Never'], dtype='<U661'),
#  array(['94.84024687842307', "['The Who']", 'I Can See For Miles'],
#        dtype='<U661'),
#  array(['94.90920550275052', "['Antonio Aguilar']", 'La Recién Casada'],
#        dtype='<U661'),
#  array(['94.53226288923106', "['Kanak Das Biswas']",
#         'Arupbeena Ruper Arale'], dtype='<U661'),
#  array(['95.00377407168233', "['Idina Menzel', 'Tracie Thoms']",
#         'Take Me or Leave Me'], dtype='<U661'),
#  array(['94.65586316190154', "['Harry Belafonte']",
#         'Hush, Hush (Thula, Thula)'], dtype='<U661'),
#  array(['94.89464777837455', "['SDIB']", 'Sugar'], dtype='<U661'),
#  array(['95.29645062334956', "['Childish Gambino', 'Ariana Grande']",
#         'Time (feat. Ariana Grande)'], dtype='<U661'),
#  array(['94.63318549345891', "['The Turtles']", 'Like The Seasons'],
#        dtype='<U661'),
#  array(['94.6604902458108', "['Enrique Guzman']", "Oye Niña (Let's Dance)"],
#        dtype='<U661'),
#  array(['94.46082494889416', "['Rashîd al-Qundarjî']", 'Maqâm Bayyâtî'],
#        dtype='<U661'),
#  array(['95.15111896697327', "['Lone Justice']", 'Ways To Be Wicked'],
#        dtype='<U661'),
#  array(['94.78906437276959', "['Astrud Gilberto']", 'O Ganso'],
#        dtype='<U661'),
#  array(['94.59958344577477', "['Art Blakey']", 'Futurity'], dtype='<U661'),
#  array(['94.47263788534714', "['Alexander Scriabin', 'Vladimir Horowitz']",
#         'Étude in D-sharp minor, Op. 8, No. 12'], dtype='<U661'),
#  array(['94.66478603194719', "['Ludwig van Beethoven', 'Rudolf Serkin']",
#         'Sonata No. 23 in F Minor, Op. 57 "Appassionata": III. Allegro ma non troppo'],
#        dtype='<U661'),
#  array(['94.42503489273088', "['Arun Kumar']", 'Tere Dukh Ke Din Phirenge'],
#        dtype='<U661'),
#  array(['94.63857928778027', "['Dean Martin']",
#         'Return To Me (Ritorna-Me)'], dtype='<U661'),
#  array(['94.74579604629886', "['Minnie Riperton']", 'Take A Little Trip'],
#        dtype='<U661'),
#  array(['95.14099450175051', "['Soul II Soul']", 'Get A Life'],
#        dtype='<U661'),
#  array(['94.79560690623575', "['Tee Grizzley', 'Lil Yachty']",
#         '2 Vaults (feat. Lil Yachty)'], dtype='<U661'),
#  array(['94.9112924244406', '["Mother\'s Finest"]', 'Fire'], dtype='<U661'),
#  array(['94.5930590859521', "['Tony Bennett']", 'Dancing in the Dark'],
#        dtype='<U661'),
#  array(['94.80410399087492', "['Ray Conniff']", 'Lisbon Antigua'],
#        dtype='<U661'),
#  array(['95.08203561980415', "['Dierks Bentley']",
#         'Free And Easy (Down The Road I Go)'], dtype='<U661'),
#  array(['94.44426455291703', "['Elsie Houston']", 'Cadê Minha Pomba Rola'],
#        dtype='<U661'),
#  array(['94.77908969752379', "['Three Dog Night']", 'Heavy Church'],
#        dtype='<U661'),
#  array(['94.97814627471374', "['Daya']", 'Hide Away'], dtype='<U661'),
#  array(['94.57714252906224', "['Эрнест Хемингуэй']",
#         'Часть 61.2 - Прощай оружие'], dtype='<U661'),
#  array(['95.2211462752744', "['Richie Spice']", 'Youth Dem Cold'],
#        dtype='<U661'),
#  array(['94.87814295893256', "['The Who']", 'Heat Wave'], dtype='<U661'),
#  array(['94.84769959925192',
#         "['Ralph Vaughan Williams', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Fantasia on Greensleeves'], dtype='<U661'),
#  array(['95.04362394746481', "['Robin Trower']", 'Lost in Love'],
#        dtype='<U661'),
#  array(['95.14056546435872', "['Röyksopp']", 'Remind Me'], dtype='<U661'),
#  array(['94.53347402076166',
#         "['John Williams', 'London Symphony Orchestra']",
#         "Marion's Theme / The Crate"], dtype='<U661'),
#  array(['95.02121548833948', "['Erasure']", 'Chorus'], dtype='<U661'),
#  array(['95.06849851215378', "['The Bellamy Brothers']",
#         'Do You Love As Good As You Look'], dtype='<U661'),
#  array(['95.06859775315665', "['Voxtrot']", 'The Start Of Something'],
#        dtype='<U661'),
#  array(['94.77150519839127', "['Woody Herman']", 'Greasy Sack Blues'],
#        dtype='<U661'),
#  array(['95.01629566477494', "['Michel Teló']",
#         'Ai Se Eu Te Pego - Ao Vivo'], dtype='<U661'),
#  array(['94.8782464357585', "['The Guess Who']",
#         'Albert Flasher - Single Version'], dtype='<U661'),
#  array(['94.56263961539818', "['Coro Infantil Sinfonico']",
#         'Stetit Puella'], dtype='<U661'),
#  array(['94.85223707240173',
#         "['Gottfried von Einem', 'Max Lorenz', 'László Szemere', 'Luise Leitner', 'Vienna State Opera Chorus', 'Wiener Philharmoniker', 'Karl Böhm']",
#         'Der Prozeß, Op. 14, Pt. 2: Wohnt hier der maler titorelli'],
#        dtype='<U661'),
#  array(['94.80482332896617', "['The Cars']", 'Coming Up on You'],
#        dtype='<U661'),
#  array(['95.12295564653928', "['Womack & Womack']", 'Teardrops'],
#        dtype='<U661'),
#  array(['94.55277774728641', "['Vic Damone']", "You're Breaking My Heart"],
#        dtype='<U661'),
#  array(['94.63773017491549', "['Jerry Vale']",
#         "I Have But One Heart ('O Marenariello)"], dtype='<U661'),
#  array(['94.66476977791038', "['Эрих Мария Ремарк']",
#         'Часть 109.2 - Триумфальная арка'], dtype='<U661'),
#  array(['94.68210109583018', "['B.B. King']", 'Please Set A Date'],
#        dtype='<U661'),
#  array(['95.05743420343019', "['Pet Shop Boys']",
#         "King's Cross - 2001 Remaster"], dtype='<U661'),
#  array(['94.5369794267989', "['Rosemary Clooney', 'The Mellomen']",
#         'Count Your Blessings (Instead of Sheep) (with The Mellomen)'],
#        dtype='<U661'),
#  array(['95.05932643826928',
#         "['Tyler, The Creator', 'Lil Wayne', 'Kanye West']",
#         'SMUCKERS (feat. Lil Wayne & Kanye West)'], dtype='<U661'),
#  array(['94.42952741692244',
#         "['Wolfgang Amadeus Mozart', 'George Szell', 'Cleveland Orchestra']",
#         'Symphony No. 39 in E-Flat Major, K. 543: IV. Finale. Allegro'],
#        dtype='<U661'),
#  array(['95.06001515876767', "['Megadeth']", 'Symphony Of Destruction'],
#        dtype='<U661'),
#  array(['94.61474108947323', "['Coven']", 'White Witch of Rosehall'],
#        dtype='<U661'),
#  array(['95.05291510156685', "['XTC']",
#         'Living Through Another Cuba - 2001 Remaster'], dtype='<U661'),
#  array(['95.1554288076026', "['The Moody Blues']", 'Lost In A Lost World'],
#        dtype='<U661'),
#  array(['94.96368535463792', "['Dondria']", "You're the One"],
#        dtype='<U661'),
#  array(['95.02519834807038', "['Gerardo Ortiz']",
#         'Mañana Voy A Conquistarla'], dtype='<U661'),
#  array(['95.06962213097415', "['The Black Crowes']", 'Thorn In My Pride'],
#        dtype='<U661'),
#  array(['94.97900413825091', "['Metallica']",
#         '(Anesthesia)--Pulling Teeth (Remastered)'], dtype='<U661'),
#  array(['95.07056530782988', "['Violent Femmes']", 'Please Do Not Go'],
#        dtype='<U661'),
#  array(['94.8330397582864', "['Romeo Santos']", 'Héroe Favorito'],
#        dtype='<U661'),
#  array(['95.18117842956622', "['Trivium']",
#         'A Gunshot to the Head of Trepidation'], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
