# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# [array([["['Yellowcard']", 'Everywhere'],
#         ["['Damageplan']", 'Save Me'],
#         ["['Pillar']", 'Fireproof'],
#         ...,
#         ["['The Black Crowes']", 'Hard To Handle'],
#         ["['Vicetone', 'Kat Nestel']",
#          'Nothing Stopping Me (feat. Kat Nestel)'],
#         ["['Chaka Khan', 'Lew Hahn']", 'I Was Made to Love Him']],
#        dtype='<U661')]

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= .1

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.c_[predictions, song_info]

# %%
predicted = predicted[predicted[:,0].argsort()][::-1]

# %%
list(predicted)
# Out:
# [array(['99.33003968000412', "['Federico García Lorca']",
#         'Capítulo 4.6 & Capítulo 5.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.31967610120773', "['Federico García Lorca']",
#         'Capítulo 5.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.3056130707264', "['Federico García Lorca']",
#         'Capítulo 5.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.29480141401291', "['Black Flag']", 'Family Man'], dtype='<U661'),
#  array(['99.27960243821144', "['Federico García Lorca']",
#         'Capítulo 13.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.27954816818237', "['Federico García Lorca']",
#         'Capítulo 13.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.2669970691204', "['Federico García Lorca']",
#         'Capítulo 11.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.26679673790932', "['Federico García Lorca']",
#         'Capítulo 10.4 & Capítulo 11.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.26514902710915', "['Federico García Lorca']",
#         'Capítulo 8.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.25999203324318', "['Federico García Lorca']",
#         'Capítulo 6.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.25818917155266', "['Federico García Lorca']",
#         'Capítulo 4.5 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.25380319356918', "['James Baldwin']", 'The Struggle - Part II'],
#        dtype='<U661'),
#  array(['99.24046477675438', "['Federico García Lorca']",
#         'Capítulo 12.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.23504078388214', "['Federico García Lorca']",
#         'Capítulo 8.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.23075824975967', "['Federico García Lorca']",
#         'Capítulo 6.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.22529801726341', "['Federico García Lorca']",
#         'Capítulo 12.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.21988886594772', "['Federico García Lorca']",
#         'Capítulo 2.3 & Capítulo 3.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.21904626488686', "['Federico García Lorca']",
#         'Capítulo 13.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.21888783574104', "['Federico García Lorca']",
#         'Capítulo 4.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.21779298782349', "['Federico García Lorca']",
#         'Capítulo 11.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.21669572591782', "['Federico García Lorca']",
#         'Capítulo 4.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.21412432193756', "['Federico García Lorca']",
#         'Capítulo 10.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.20754659175873',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 6'],
#        dtype='<U661'),
#  array(['99.20104283094406', "['Federico García Lorca']",
#         'Capítulo 7.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.19996052980423', "['Federico García Lorca']",
#         'Capítulo 11.5 & Capítulo 12.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.189681828022', "['Edgar Allan Poe']",
#         'Das Herz des Mr. Barclay, Kapitel 5'], dtype='<U661'),
#  array(['99.17825210094452', "['Federico García Lorca']",
#         'Capítulo 9.5 & Capítulo 10.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.17761927843094', "['Federico García Lorca']",
#         'Capítulo 6.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.17217203974724', "['Federico García Lorca']",
#         'Capítulo 3.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.16195818781853',
#         "['Michael Jackson', 'Rod Temperton', 'Vincent Price']",
#         'Voice-Over Intro / Voice-Over Session from Thriller'],
#        dtype='<U661'),
#  array(['99.155756264925', "['Federico García Lorca']",
#         'Capítulo 9.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.15297147631645', "['Federico García Lorca']",
#         'Capítulo 14.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.15160897374153', "['Fred von Hoerschelmann']",
#         'Kapitel 15 - Amtmann Enders'], dtype='<U661'),
#  array(['99.14586240053177', "['Federico García Lorca']",
#         'Capítulo 8.5 & Capítulo 9.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.14385414123535', "['Kurt Heynicke']",
#         'Kapitel 18 - Oktoberfrühling'], dtype='<U661'),
#  array(['99.14232966303825', "['Federico García Lorca']",
#         'Capítulo 14.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.13934844732285', "['Federico García Lorca']",
#         'Capítulo 5.5 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.13840460777283', "['Federico García Lorca']",
#         'Capítulo 4.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.13715717196465', "['Federico García Lorca']",
#         'Capítulo 9.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.1342316865921',
#         "['Deutsche Grammophon Literatur', 'Johann Wolfgang von Goethe', 'Gustaf Grundgens']",
#         'Marthens Garten - Teil 04'], dtype='<U661'),
#  array(['99.12831029295921', "['Kurt Heynicke']",
#         'Kapitel 6 - Oktoberfrühling'], dtype='<U661'),
#  array(['99.12472686171532', "['Federico García Lorca']",
#         'Capítulo 10.3 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.12319141626358', "['Fred von Hoerschelmann']",
#         'Kapitel 17 - Amtmann Enders'], dtype='<U661'),
#  array(['99.11895287036896', "['Wilhelm Hauff']", 'Kapitel 6 - Zwerg Nase'],
#        dtype='<U661'),
#  array(['99.11595326662064', "['Raffi']", 'Spider on the Floor'],
#        dtype='<U661'),
#  array(['99.11511898040771', "['Gisela Prugel']",
#         'Kapitel 2 - Apoll an der Seine'], dtype='<U661'),
#  array(['99.11507019400597', "['Federico García Lorca']",
#         'Capítulo 6.5 & Capítulo 7.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.11373907327652', "['Federico García Lorca']",
#         'Capítulo 3.5 & Capítulo 4.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.11365410685539', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 55'],
#        dtype='<U661'),
#  array(['99.10117456316948', "['T. Rex']",
#         'The T. Rex Electric Warrior Interview'], dtype='<U661'),
#  array(['99.10066610574722', "['Bud Powell Trio']",
#         'Interview with Bud Powell'], dtype='<U661'),
#  array(['99.09883522987366', "['Harper Lee', 'Eva Mattes']",
#         'Wer die Nachtigall stört ..., Kapitel 9'], dtype='<U661'),
#  array(['99.09305241703987', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 2'], dtype='<U661'),
#  array(['99.09126102924347', "['Federico García Lorca']",
#         'Capítulo 3.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.08903536200523', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 51'],
#        dtype='<U661'),
#  array(['99.08862966299057', "['Too $hort']", 'Dope Fiend Beat'],
#        dtype='<U661'),
#  array(['99.08842134475708', "['Patricia St. John']",
#         'Kapitel 21 - Spuren im Schnee'], dtype='<U661'),
#  array(['99.08829593658447', "['Raffi']", 'Five Little Pumpkins'],
#        dtype='<U661'),
#  array(['99.08743795752525', "['Manfried Rössner']",
#         'Kapitel 16 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['99.08188113570213', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger in den Feldern, Kapitel 36'], dtype='<U661'),
#  array(['99.08099085092545', "['Patricia St. John']",
#         'Kapitel 53 - Hamid und Kinza'], dtype='<U661'),
#  array(['99.08072879910469', "['Patra']", 'Queen of the Pack'],
#        dtype='<U661'),
#  array(['99.07909786701202', "['Fred von Hoerschelmann']",
#         'Kapitel 12 - Amtmann Enders'], dtype='<U661'),
#  array(['99.07853490114212', "['Fred von Hoerschelmann']",
#         'Kapitel 24 - Amtmann Enders'], dtype='<U661'),
#  array(['99.0772340297699',
#         "['TisaKorean', 'Kblast', 'Huncho Da Rockstar']", 'The Mop'],
#        dtype='<U661'),
#  array(['99.0767422914505', "['Honoré de Balzac']",
#         'Kapitel 24 - Tante Lisbeth'], dtype='<U661'),
#  array(['99.07435283064842', "['Gisela Prugel']",
#         'Kapitel 25 - Apoll an der Seine'], dtype='<U661'),
#  array(['99.07089966535568', "['Zofia Dromlewiczowa']",
#         'Chapter 1.26 & Chapter 2.1 - Dziewczynka z Luna Parku: Część 2'],
#        dtype='<U661'),
#  array(['99.07068514823914', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 38'], dtype='<U661'),
#  array(['99.07002654671669', "['Patricia St. John']",
#         'Kapitel 167 - Hamid und Kinza'], dtype='<U661'),
#  array(['99.06719809770584', "['Patricia St. John']",
#         'Kapitel 87 - Spuren im Schnee'], dtype='<U661'),
#  array(['99.06697607040405', "['Zofia Dromlewiczowa']",
#         'Chapter 2.11 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['99.06647258996964', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 30'], dtype='<U661'),
#  array(['99.06539660692215', "['Georg Kaiser']", 'Kapitel 4 - Klawitter'],
#        dtype='<U661'),
#  array(['99.06470263004303', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 7'], dtype='<U661'),
#  array(['99.06432315707207', "['Harold Courlander']",
#         'Two Feasts for Anansi'], dtype='<U661'),
#  array(['99.06411108374596', "['Rudyard Kipling']",
#         'Kapitel 7 - Dschungelbuch'], dtype='<U661'),
#  array(['99.06130388379097', "['Gisela Prugel']",
#         'Kapitel 8 - Apoll an der Seine'], dtype='<U661'),
#  array(['99.06053665280342', "['Gebrüder Grimm']",
#         'Kapitel 12 - König Drosselbart'], dtype='<U661'),
#  array(['99.05945256352425', "['YG', 'Will Claye']",
#         'Idgaf (feat. Will Claye)'], dtype='<U661'),
#  array(['99.05862826108932', "['Federico García Lorca']",
#         'Capítulo 12.5 & Capítulo 13.1 - la Casa de Bernarda Alba'],
#        dtype='<U661'),
#  array(['99.05845457315445', "['Coquelin']",
#         'Cyrano De Bergerac Acte 4 Scene 9'], dtype='<U661'),
#  array(['99.0580795109272', "['Bill Engvall']", 'Dorkfish'], dtype='<U661'),
#  array(['99.05597099661827', "['Edgar Allan Poe']",
#         'Das Herz des Mr. Barclay, Kapitel 4'], dtype='<U661'),
#  array(['99.05563935637474', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 43'],
#        dtype='<U661'),
#  array(['99.04817602038383', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 50'],
#        dtype='<U661'),
#  array(['99.04775461554527', "['Kurt Heynicke']",
#         'Kapitel 21 - Oktoberfrühling'], dtype='<U661'),
#  array(['99.04752525687218', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 4'], dtype='<U661'),
#  array(['99.045036226511',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 5'],
#        dtype='<U661'),
#  array(['99.0439881682396', "['Federico García Lorca']",
#         'Capítulo 2.2 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['99.04015058279037', "['Patricia St. John']",
#         'Kapitel 29 - Hamid und Kinza'], dtype='<U661'),
#  array(['99.03984758257866', "['Jerry Clower']", 'Southern Humor'],
#        dtype='<U661'),
#  array(['99.03984132409096', "['Hugo von Hofmannsthal']",
#         'Kapitel 4 - Lucidor'], dtype='<U661'),
#  array(['99.03903138637543', "['Rod Temperton']",
#         'Voice-Over Intro Rod Temperton Interview #1 / Rod Temperton Interview #1'],
#        dtype='<U661'),
#  array(['99.03417092561722', "['Harold Courlander']",
#         'Anansi, the Oldest of Animals'], dtype='<U661'),
#  array(['99.0339902639389', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 21'], dtype='<U661'),
#  array(['99.03353133797646',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 30'],
#        dtype='<U661'),
#  array(['99.03334948420525', "['Fred von Hoerschelmann']",
#         'Kapitel 19 - Amtmann Enders'], dtype='<U661'),
#  array(['99.03325831890106', "['Manfried Rössner']",
#         'Kapitel 33 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['99.03306299448013', "['Harold Courlander']", 'Anansi Plays Dead'],
#        dtype='<U661'),
#  array(['99.03261268138885', "['Kurt Heynicke']",
#         'Kapitel 19 - Oktoberfrühling'], dtype='<U661'),
#  array(['99.03152471780777', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 17'], dtype='<U661'),
#  array(['99.03008913993835', "['Kurt Heynicke']",
#         'Kapitel 16 - Oktoberfrühling'], dtype='<U661'),
#  array(['99.02772891521454', "['Fred von Hoerschelmann']",
#         'Kapitel 20 - Amtmann Enders'], dtype='<U661'),
#  array(['99.02664551138878', "['Lil Jon & The East Side Boyz']",
#         "Couldn't Be A Better Playa - Lil Jon & the Eastside Boyz Feat. T"],
#        dtype='<U661'),
#  array(['99.02616569399834', "['Zofia Dromlewiczowa']",
#         'Chapter 2.6 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['99.02463945746422', "['Nikolai Gogol']",
#         'Kapitel 8 - Der große Krach der großen Herren'], dtype='<U661'),
#  array(['99.02443492412567', "['Alfred Hitchcock']", 'The Magician'],
#        dtype='<U661'),
#  array(['99.02358964085579',
#         "['Deutsche Grammophon Literatur', 'Johann Wolfgang von Goethe', 'Gustaf Grundgens']",
#         'Studierzimmer - Teil 07'], dtype='<U661'),
#  array(['99.0218839943409', "['Gebrüder Grimm']",
#         'Kapitel 13 - König Drosselbart'], dtype='<U661'),
#  array(['99.02101910114288', "['Rudyard Kipling']",
#         'Kapitel 6 - Dschungelbuch'], dtype='<U661'),
#  array(['99.02073094248772', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 59'],
#        dtype='<U661'),
#  array(['99.0207172036171', "['Eazy-E']", 'Boyz-N-The-Hood - Remix;Edited'],
#        dtype='<U661'),
#  array(['99.02056646347046',
#         "['Deutsche Grammophon Literatur', 'Johann Wolfgang von Goethe', 'Gustaf Grundgens']",
#         'Studierzimmer - Teil 22'], dtype='<U661'),
#  array(['99.02037492394447',
#         "['Louis Prima', 'Sam Butera & The Witnesses']",
#         'Greenback Dollar Bill - Live; 1999 - Remaster'], dtype='<U661'),
#  array(['99.02013975381851', "['Patricia St. John']",
#         'Kapitel 54 - Hamid und Kinza'], dtype='<U661'),
#  array(['99.01925215125084', "['Manfried Rössner']",
#         'Kapitel 20 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['99.01814129948616', "['Manfried Rössner']",
#         'Kapitel 17 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['99.01653304696083', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 42'],
#        dtype='<U661'),
#  array(['99.01592817902565', "['Frank Sinatra']",
#         'The Tea Break (Sinatra Monologue) - Live At The Sands Hotel And Casino/1966'],
#        dtype='<U661'),
#  array(['99.0140151977539', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 142'], dtype='<U661'),
#  array(['99.01342737674713', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 33'],
#        dtype='<U661'),
#  array(['99.01275873184204', "['Fred von Hoerschelmann']",
#         'Kapitel 16 - Amtmann Enders'], dtype='<U661'),
#  array(['99.01204910874367',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 44'],
#        dtype='<U661'),
#  array(['99.00868436694145', "['Wolfgang Weyrauch']",
#         'Kapitel 1 - Das Wirtshaus im Taunus und andere Erzählungen'],
#        dtype='<U661'),
#  array(['99.00695085525513',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 50'],
#        dtype='<U661'),
#  array(['99.006770581007', "['Manfried Rössner']",
#         'Kapitel 14 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['99.00577348470688', "['Franz Lehár', 'Elisabeth Schwarzkopf']",
#         'Lehár: Das Land des Lächelns, Act 1: Dialog, "Guten Abend, Hoheit!" (Lisa, Sou-Chong)'],
#        dtype='<U661'),
#  array(['99.00556793808937',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 39'],
#        dtype='<U661'),
#  array(['99.00525197386742', "['Honoré de Balzac']",
#         'Kapitel 19 - Tante Lisbeth'], dtype='<U661'),
#  array(['99.00382214784622',
#         "['Franz Lehár', 'Elisabeth Schwarzkopf', 'Otto Ackermann', 'Philharmonia Orchestra']",
#         'Die Lustige Witwe (2001 - Remaster), Act I: Dialog: Njegus, Geliebter, wo ist Vaterland? (Danilo/Njegus/Hanna/Valencienne/Zeta)'],
#        dtype='<U661'),
#  array(['99.00329041481018',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 60'],
#        dtype='<U661'),
#  array(['99.00276094675064',
#         "['Mitchell Hope', 'Spencer Lee', 'Kala Balch', 'Marco Marinangeli']",
#         'Be Our Guest'], dtype='<U661'),
#  array(['98.99919757246971', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 39'], dtype='<U661'),
#  array(['98.99812313914299', "['Zofia Dromlewiczowa']",
#         'Chapter 2.12 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.99791765213013', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 57'],
#        dtype='<U661'),
#  array(['98.99505490064621', "['The Soft Winds']",
#         'Herb Ellis & Lou Carter'], dtype='<U661'),
#  array(['98.99420836567879', "['Billy De Wolfe']",
#         "Don't Dress Your Cat In An Apron"], dtype='<U661'),
#  array(['98.99364906549454', "['The Smothers Brothers']", 'Chocolate'],
#        dtype='<U661'),
#  array(['98.99251082539558',
#         "['Franz Lehár', 'Elisabeth Schwarzkopf/Nicolai Gedda/Felix Kent/André von Mattoni/Philharmonia Orchestra/Otto Ackermann']",
#         'Lehár: Das Land des Lächelns, Act 1: Dialog, "Hoheit, der Sekretär der chinesischen Gesandschaft" (Der Diener, Lisa, Sou-Chong, Fu-Li)'],
#        dtype='<U661'),
#  array(['98.9919042289257',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 13'],
#        dtype='<U661'),
#  array(['98.9915780723095', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 47'],
#        dtype='<U661'),
#  array(['98.9907515347004', "['Frank Wedekind']",
#         'Kapitel 20 - Der Kammersänger'], dtype='<U661'),
#  array(['98.99039122462273', "['Hugo von Hofmannsthal']",
#         'Kapitel 7 - Lucidor'], dtype='<U661'),
#  array(['98.99033150076866',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 20'],
#        dtype='<U661'),
#  array(['98.98843017220497', "['Zofia Dromlewiczowa']",
#         'Chapter 2.18 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.98784017562866', "['Zofia Dromlewiczowa']",
#         'Chapter 2.4 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.98715850710869', "['Patricia St. John']",
#         'Kapitel 46 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.98700150847435', "['Louise Bogan']", 'The Alchemist'],
#        dtype='<U661'),
#  array(['98.98653671145439', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 130'], dtype='<U661'),
#  array(['98.98592835664749', "['Ryan Montbleau']", '75 and Sunny'],
#        dtype='<U661'),
#  array(['98.98553282022476', "['Zofia Dromlewiczowa']",
#         'Chapter 2.16 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.98470172286034',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 14'],
#        dtype='<U661'),
#  array(['98.98460891842842', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 47'], dtype='<U661'),
#  array(['98.98441407084465',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 48'],
#        dtype='<U661'),
#  array(['98.984304189682', "['François Mauriac', 'Jean Amrouche']",
#         'Le mystère Frontenac'], dtype='<U661'),
#  array(['98.98356622457504', "['Art Blakey Quintet']",
#         'Announcement By Pee Wee Marquette - Live At Birdland, New York/1954'],
#        dtype='<U661'),
#  array(['98.98339203000069', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 23'], dtype='<U661'),
#  array(['98.98218441009521', "['Raffi']", 'Brush Your Teeth'],
#        dtype='<U661'),
#  array(['98.98203471302986', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 95'], dtype='<U661'),
#  array(['98.98169279098511', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 155'], dtype='<U661'),
#  array(['98.98106440901756', "['Patricia St. John']",
#         'Kapitel 30 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.98095282912254',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 53'],
#        dtype='<U661'),
#  array(['98.98060521483421', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 127'], dtype='<U661'),
#  array(['98.98050484061241',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 8'],
#        dtype='<U661'),
#  array(['98.97984513640404', "['Harry Belafonte']", 'Man Piaba - Live'],
#        dtype='<U661'),
#  array(['98.97968077659607', "['Harold Courlander']",
#         "The Porcupine's Hoe"], dtype='<U661'),
#  array(['98.97962260246277', "['Brian Regan']", 'Lousy In Little League'],
#        dtype='<U661'),
#  array(['98.97959938645363', "['Patricia St. John']",
#         'Kapitel 52 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.97936424612999',
#         "['Ana Belén', 'Víctor Manuel', 'Juan Echanove', 'Antonio Flores', 'Pablo Milanés', 'Manolo Tena', 'Joaquín Sabina', 'Miguel Rios', 'Joan Manuel Serrat']",
#         'La Puerta De Alcalá - En Directo'], dtype='<U661'),
#  array(['98.97928503155708', "['Mathias Wieman']", 'Eingang'],
#        dtype='<U661'),
#  array(['98.97900724411011', "['Fabricantes De Lluvia']",
#         'Cozy Rain Sound'], dtype='<U661'),
#  array(['98.97830390930176', "['Zofia Dromlewiczowa']",
#         'Chapter 2.17 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.97826769948006', "['Honoré de Balzac']",
#         'Kapitel 15 - Die läßliche Sünde'], dtype='<U661'),
#  array(['98.977971971035', "['Insane Clown Posse']", 'The Show Must Go On'],
#        dtype='<U661'),
#  array(['98.97602218389511',
#         '[\'Old Crow Medicine Show\', \'Joel Rafael\', \'Jimmy LaFave\', \'Donovan\', \'Rosanne Cash\', \'John Leventhal\', \'Sweet Honey In The Rock\', \'Lucinda Williams\', \'Judy Collins\', \'Tom Morello\', \'Ani DiFranco\', \'Ry Cooder\', \'Dan Gellert\', \'Jackson Browne\', \'The Del McCoury Band\', \'Tony Trischka\', "Tim O\'Brien", \'John Mellencamp\', "Ramblin\' Jack Elliott"]',
#         'This Train is Bound for Glory'], dtype='<U661'),
#  array(['98.97519078850746',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 21'],
#        dtype='<U661'),
#  array(['98.97475844621658', "['Manfried Rössner']",
#         'Kapitel 29 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['98.97366884350777', "['Zofia Dromlewiczowa']",
#         'Chapter 2.13 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.97313320636749', "['Harold Courlander']", "Nyame's Well"],
#        dtype='<U661'),
#  array(['98.97286066412926',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 31'],
#        dtype='<U661'),
#  array(['98.97171086072922', "['Pedro & Man']", '1st Gear, 2nd Gear'],
#        dtype='<U661'),
#  array(['98.97164288163185', "['Zofia Dromlewiczowa']",
#         'Chapter 1.1 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.97134494781494',
#         "['Deutsche Grammophon Literatur', 'Johann Wolfgang von Goethe', 'Gustaf Grundgens']",
#         'Straße 1 - Teil 01'], dtype='<U661'),
#  array(['98.9709777534008',
#         '[\'Igor Stravinsky\', \'Paul Pasquier\', "L\'Orchestre de la Suisse Romande", \'Ernest Ansermet\']',
#         'Oedipus Rex - Actus secundus: La dispute des princes attire Jocasta'],
#        dtype='<U661'),
#  array(['98.96987462043762',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 58'],
#        dtype='<U661'),
#  array(['98.96827417612076',
#         "['Franz Lehár', 'Elisabeth Schwarzkopf', 'Otto Ackermann', 'Philharmonia Orchestra']",
#         'Die Lustige Witwe (2001 - Remaster), Act I: Dialog:Njegus, waren Sie beim Grafen Danilo? (Zeta/Hanna/Njegus)'],
#        dtype='<U661'),
#  array(['98.96807739138603', "['Patricia St. John']",
#         'Kapitel 97 - Hamid und Kinza'], dtype='<U661'),
#  array(['98.96743729710579', "['Harry Belafonte']",
#         'Man Smart (Woman Smarter) - Live'], dtype='<U661'),
#  array(['98.96653273701668',
#         "['Christopher Jackson', 'Daveed Diggs', 'Lin-Manuel Miranda', 'Okieriete Onaodowan']",
#         'Cabinet Battle #2'], dtype='<U661'),
#  array(['98.96616199612617', "['Robert Frost']", 'The Pasture Mowing'],
#        dtype='<U661'),
#  array(['98.96584317088127', "['Fred von Hoerschelmann']",
#         'Kapitel 6 - Amtmann Enders'], dtype='<U661'),
#  array(['98.9657889008522', "['Patricia St. John']",
#         'Kapitel 90 - Hamid und Kinza'], dtype='<U661'),
#  array(['98.96513620018959',
#         "['Lin-Manuel Miranda', 'Leslie Odom Jr.', 'Anthony Ramos', 'Daveed Diggs', 'Okieriete Onaodowan']",
#         'Aaron Burr, Sir'], dtype='<U661'),
#  array(['98.96463778614998', "['Edgar Allan Poe']",
#         'Das Herz des Mr. Barclay, Kapitel 8'], dtype='<U661'),
#  array(['98.96460425853729', "['Patricia St. John']",
#         'Kapitel 40 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.96439805626869', "['James Brown']", 'Get Up Offa That Thing'],
#        dtype='<U661'),
#  array(['98.9643962085247', "['Common']", 'Retrospect for Life'],
#        dtype='<U661'),
#  array(['98.96415251493454', "['Tiagz']", 'My Heart Went Oops'],
#        dtype='<U661'),
#  array(['98.96382090449333', "['Zofia Dromlewiczowa']",
#         'Chapter 2.22 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.96370467543602', "['Hugo von Hofmannsthal']",
#         'Kapitel 9 - Lucidor'], dtype='<U661'),
#  array(['98.96336975693703', "['Zofia Dromlewiczowa']",
#         'Chapter 3.17 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.96159160137177', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 26'], dtype='<U661'),
#  array(['98.96126511693001', "['Eric Prydz']", 'Call on Me - Radio Mix'],
#        dtype='<U661'),
#  array(['98.96123588085175', "['Insane Clown Posse']", "The Joker's Wild"],
#        dtype='<U661'),
#  array(['98.96058863401413', "['Manfried Rössner']",
#         'Kapitel 22 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['98.9602780342102',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 57'],
#        dtype='<U661'),
#  array(['98.95958590507507', "['Friedrich Wilhelm Nietzsche']",
#         'Kapitel 8 - Gedichte von Friedrich Nietzsche'], dtype='<U661'),
#  array(['98.95930829644203', "['The Beach Boys']",
#         "Wouldn't It Be Nice - Live At Michigan State University/1966"],
#        dtype='<U661'),
#  array(['98.95818036794662', "['François Mauriac', 'Jean Amrouche']",
#         'La période du Bœuf sur le toit'], dtype='<U661'),
#  array(['98.95794034004211', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 8'], dtype='<U661'),
#  array(['98.9576281607151', "['Jim Croce']", 'Trucker - Monologue; Live'],
#        dtype='<U661'),
#  array(['98.95549187064171', "['Zofia Dromlewiczowa']",
#         'Chapter 1.8 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.95525160431862', "['Public Enemy']",
#         'Meet The G That Killed Me'], dtype='<U661'),
#  array(['98.95449024438858',
#         "['Ruff Ryders', 'Snoop Dogg', 'Scarface', 'Jadakiss', 'Yung Wun']",
#         'WW III'], dtype='<U661'),
#  array(['98.95398035645485', "['Cheech & Chong']", 'Dave'], dtype='<U661'),
#  array(['98.95397135615349', "['Suzanne Vega']", "Tom's Diner"],
#        dtype='<U661'),
#  array(['98.9539424777031', "['Patricia St. John']",
#         'Kapitel 12 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.95393851399422', "['Zofia Dromlewiczowa']",
#         'Chapter 2.10 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.95384854078293', "['Manfried Rössner']",
#         'Kapitel 2 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['98.95350152254105', "['Run–D.M.C.']", 'Proud to Be Black'],
#        dtype='<U661'),
#  array(['98.95315119624138', "['Public Enemy']", 'Rebel Without A Pause'],
#        dtype='<U661'),
#  array(['98.95309269428253', "['TobyMac', 'Hollyn']",
#         'Lights Shine Bright'], dtype='<U661'),
#  array(['98.95298513770103', "['Patricia St. John']",
#         'Kapitel 79 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.95290696620941',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 47'],
#        dtype='<U661'),
#  array(['98.95202428102493', "['Bob Marley & The Wailers']",
#         "Don't Rock My Boat"], dtype='<U661'),
#  array(['98.95140239596367', "['Ray Charles']",
#         'In a Little Spanish Town - Live at Newport Jazz Festival, Rhode Island, 7/5/1958'],
#        dtype='<U661'),
#  array(['98.95122388005257', "['Miles Davis']",
#         'Introduction by Gene Norman - Live at Pasadena Civic Auditorium, Pasadena, CA - February 1956'],
#        dtype='<U661'),
#  array(['98.950886875391', "['Brian Regan']", 'Horns & Windshields'],
#        dtype='<U661'),
#  array(['98.95020920038223', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 139'], dtype='<U661'),
#  array(['98.95004630088806',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 17'],
#        dtype='<U661'),
#  array(['98.94960916042328', "['Harold Courlander']",
#         "All Stories are Anansi's"], dtype='<U661'),
#  array(['98.94951182603836', "['Psychostick']", 'Beer!'], dtype='<U661'),
#  array(['98.94929477572441',
#         "['Burt Reynolds', 'Jackie Gleason', 'Jerry Reed']",
#         'Incidental CB Dialogue - Bandit, Smokey & Snowman'], dtype='<U661'),
#  array(['98.94833818078041', "['Zofia Dromlewiczowa']",
#         'Chapter 1.15 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.9473548233509', "['Patricia St. John']",
#         'Kapitel 50 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.9469273686409', "['Zofia Dromlewiczowa']",
#         'Chapter 3.10 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.94689160585403', "['Rudyard Kipling']",
#         'Kapitel 8 - Dschungelbuch'], dtype='<U661'),
#  array(['98.94685670733452', "['Erwin Wickert']",
#         'Kapitel 9 - Der Tag von Hiroshima'], dtype='<U661'),
#  array(['98.94677665829659', "['Solo on pan-pipes of thirteen tubes']",
#         'Fiesta Dance Music'], dtype='<U661'),
#  array(['98.94656038284302', "['Jerry Clower']",
#         'Newgene And The Lion - Live 1977'], dtype='<U661'),
#  array(['98.9461010992527', "['Patricia St. John']",
#         'Kapitel 76 - Hamid und Kinza'], dtype='<U661'),
#  array(['98.94596800208092', "['Eric B. & Rakim']", 'Mahogany'],
#        dtype='<U661'),
#  array(['98.94588086009026',
#         "['Franz Lehár', 'Anton Niessner/Emmy Loose/Philharmonia Orchestra/Otto Ackermann', 'Otto Ackermann', 'Philharmonia Orchestra']",
#         'Die Lustige Witwe (2001 - Remaster), Act II: Dialog: Exzellenz, man hat im Pavillon diesen Fächer gefunden (Njegus/Zeta/Valencinne)'],
#        dtype='<U661'),
#  array(['98.94521889090538', "['Lil Jon & The East Side Boyz']",
#         'Real N***A Roll Call (feat. Ice Cube)'], dtype='<U661'),
#  array(['98.94520834088326', "['Bruce Springsteen']",
#         'Fire - Live at the Winterland, San Francisco, CA - December 1978'],
#        dtype='<U661'),
#  array(['98.94506496191025',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 41'],
#        dtype='<U661'),
#  array(['98.94473084807396',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 44'],
#        dtype='<U661'),
#  array(['98.94455146789551', "['Frank Zappa']", 'Dong Work For Yuda'],
#        dtype='<U661'),
#  array(['98.94433093070984', "['Lightning, Thunder and Rain Storm']",
#         'Midnight Thunderstorm Part 2'], dtype='<U661'),
#  array(['98.94340974092484',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 42'],
#        dtype='<U661'),
#  array(['98.94302326440811', "['Shabba Ranks']", 'Ting-A-Ling'],
#        dtype='<U661'),
#  array(['98.9413366317749', "['Rudyard Kipling']",
#         'Kapitel 12 - Dschungelbuch'], dtype='<U661'),
#  array(['98.94132229685783', "['Patricia St. John']",
#         'Kapitel 131 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.94128370285034', "['Sam Cooke']",
#         'Soul Twist / Introduction - Live'], dtype='<U661'),
#  array(['98.94102463126183', "['Anton Tschechow']",
#         'Kapitel 11 - In der Osternacht'], dtype='<U661'),
#  array(['98.94056004285812', "['Banda Zarape']", 'Caliente Caliente'],
#        dtype='<U661'),
#  array(['98.94031620025635', "['Miles Davis']", 'Miles Davis Comments'],
#        dtype='<U661'),
#  array(['98.94016683101654', "['Zofia Dromlewiczowa']",
#         'Chapter 1.8 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.93931493163109', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 184'], dtype='<U661'),
#  array(['98.93929040431976', "['Eric Prydz']", 'Call On Me - Radio Edit'],
#        dtype='<U661'),
#  array(['98.93922656774521',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 55'],
#        dtype='<U661'),
#  array(['98.93830010294914', "['Johnny Cash']",
#         "June's Poem - Live at Folsom State Prison, Folsom, CA (1st Show) - January 1968"],
#        dtype='<U661'),
#  array(['98.93813070654869', "['Patricia St. John']",
#         'Kapitel 50 - Hamid und Kinza'], dtype='<U661'),
#  array(['98.93794214725494', "['Unspecified']",
#         'Natural Sounds - Wood Thrush, Slowed Down to 1/2 Speed'],
#        dtype='<U661'),
#  array(['98.9376589357853', "['The Smothers Brothers']", "I Don't Care"],
#        dtype='<U661'),
#  array(['98.93764600157738', "['Patricia St. John']",
#         'Kapitel 120 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.93703705072403', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 33'], dtype='<U661'),
#  array(['98.93648302555084', "['Hank Williams, Jr.']",
#         "Family Tradition / Hey, Good Lookin' - Live"], dtype='<U661'),
#  array(['98.9362382888794', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 70'], dtype='<U661'),
#  array(['98.9359490275383', "['Zofia Dromlewiczowa']",
#         'Chapter 3.18 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.93568331003189', "['Jerry Clower']",
#         'How To Back Into Show Business'], dtype='<U661'),
#  array(['98.93523275852203', "['Honoré de Balzac']",
#         'Kapitel 13 - Die läßliche Sünde'], dtype='<U661'),
#  array(['98.93468400835991',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 52'],
#        dtype='<U661'),
#  array(['98.93458369374275', "['Zofia Dromlewiczowa']",
#         'Chapter 1.12 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.9344009757042',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 48'],
#        dtype='<U661'),
#  array(['98.93392851948738', "['Brian Regan']", 'Evel Knievel'],
#        dtype='<U661'),
#  array(['98.93392637372017',
#         "['Gustav Mahler', 'Bruno Walter', 'Arnold Michaelis']",
#         'A Talking Portrait: Bruno Walter in Conversation with Arnold Michaelis'],
#        dtype='<U661'),
#  array(['98.93383061885834', "['Friedrich Wilhelm Nietzsche']",
#         'Kapitel 7 - Gedichte von Friedrich Nietzsche'], dtype='<U661'),
#  array(['98.933070987463', "['Zofia Dromlewiczowa']",
#         'Chapter 1.2 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.93187090754509', "['Seamus Kennedy']", 'The Scotsman'],
#        dtype='<U661'),
#  array(['98.93171718716621', "['Handsome Boy Modeling School']",
#         "Rock N' Roll (Could Never Hip Hop Like This)"], dtype='<U661'),
#  array(['98.93149080872536', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 16'], dtype='<U661'),
#  array(['98.93146389722824',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 33'],
#        dtype='<U661'),
#  array(['98.93129941821098',
#         "['Major Lazer', 'Bruno Mars', 'Tyga', 'Mystic']", 'Bubble Butt'],
#        dtype='<U661'),
#  array(['98.93122813105583', "['Yuen Ren Chao']",
#         'Ex. 1, Questions to Answer'], dtype='<U661'),
#  array(['98.93120673298836', "['Dylan Thomas']",
#         'In My Craft or Sullen Art'], dtype='<U661'),
#  array(['98.93081167340279', "['Zofia Dromlewiczowa']",
#         'Chapter 3.5 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.93077549338341', "['Bill Cosby']", 'Rigor Mortis'],
#        dtype='<U661'),
#  array(['98.93066009879112', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 160'], dtype='<U661'),
#  array(['98.93055191636086', "['Kirk Franklin', 'The Family']",
#         'Melodies From Heaven'], dtype='<U661'),
#  array(['98.92931693792343', "['Georg Kaiser']", 'Kapitel 16 - Klawitter'],
#        dtype='<U661'),
#  array(['98.92916092276573', "['Erykah Badu']",
#         'Next Lifetime - Live Version'], dtype='<U661'),
#  array(['98.92912575602531', "['Miles Davis']",
#         'Flamenco Sketches - Studio Sequence 1'], dtype='<U661'),
#  array(['98.92892533540726', "['Manfried Rössner']",
#         'Kapitel 21 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['98.92873001098633', "['Victor Borge']",
#         'Phonetic Punctuation - Voice'], dtype='<U661'),
#  array(['98.92861011624336', "['Patricia St. John']",
#         'Kapitel 108 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.92832514643669',
#         "['Deutsche Grammophon Literatur', 'Johann Wolfgang von Goethe', 'Gustaf Grundgens']",
#         'Am Brunnen - Teil 02'], dtype='<U661'),
#  array(['98.92825016379356', "['Brian Regan']", 'Crank Calls'],
#        dtype='<U661'),
#  array(['98.9273818731308', "['Tamás Cseh']", 'Marilyn dala'],
#        dtype='<U661'),
#  array(['98.92731896042824', "['Patricia St. John']",
#         'Kapitel 103 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.92655393481255', "['Sacha Guitry']",
#         'Différence entre cinéma et théâtre'], dtype='<U661'),
#  array(['98.92637231945992', "['Frank Wedekind']",
#         'Kapitel 8 - Der Kammersänger'], dtype='<U661'),
#  array(['98.92622715234756', "['Victor Borge']", 'Phonetic Punctuation'],
#        dtype='<U661'),
#  array(['98.92579519748688',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 38'],
#        dtype='<U661'),
#  array(['98.92456066608429',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 43'],
#        dtype='<U661'),
#  array(['98.92448803782463',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 19'],
#        dtype='<U661'),
#  array(['98.9242473244667', "['Unspecified']",
#         'Khatak Dance: Dance music from the Katak people in the Frontier Province'],
#        dtype='<U661'),
#  array(['98.9242296218872',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 58'],
#        dtype='<U661'),
#  array(['98.92412489652634', "['Zofia Dromlewiczowa']",
#         'Chapter 2.20 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.92362195253372',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 54'],
#        dtype='<U661'),
#  array(['98.9236172735691',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 11'],
#        dtype='<U661'),
#  array(['98.92358756065369', "['Patricia St. John']",
#         'Kapitel 34 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.92321941256523', "['Jean Malaurie', 'Olivier Germain-Thomas']",
#         'Progrès dévastateur: une catastrophe annoncée'], dtype='<U661'),
#  array(['98.92314574122429', "['A Tribe Called Quest']", 'Find a Way'],
#        dtype='<U661'),
#  array(['98.92259165644646', "['The Beach Boys']",
#         '"Cassius" Love Vs. "Sonny" Wilson (Mono)'], dtype='<U661'),
#  array(['98.92230066657066', "['Barbra Streisand']", 'Queen Bee'],
#        dtype='<U661'),
#  array(['98.92213645577431', "['Nas', 'Olu Dara']",
#         'Bridging the Gap (feat. Olu Dara)'], dtype='<U661'),
#  array(['98.92198634147644', "['Patricia St. John']",
#         'Kapitel 167 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.92154839634895', "['Zofia Dromlewiczowa']",
#         'Chapter 1.2 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.92145228385925', "['Jeff Beatman']", 'The Three Little Pigs'],
#        dtype='<U661'),
#  array(['98.92141404747963', "['Jackie Gleason']",
#         'Casey At The Bat - Live'], dtype='<U661'),
#  array(['98.9213290810585', "['Christian Finnegan']",
#         'Office People (And A Perfectly Good Font Joke)'], dtype='<U661'),
#  array(['98.92122820019722', "['Alfred Hitchcock']",
#         'The Haunted and the Hunters'], dtype='<U661'),
#  array(['98.92107284069061', "['Frank Wedekind']",
#         'Kapitel 3 - Der Kammersänger'], dtype='<U661'),
#  array(['98.92045184969902', "['Bob Marley & The Wailers']",
#         'So Much Things To Say'], dtype='<U661'),
#  array(['98.91997683048248', "['Yves Montand']",
#         'Le Peintre, La Pomme Et Picasso'], dtype='<U661'),
#  array(['98.9198445379734', "['James Brown']", 'Get Up Offa That Thing'],
#        dtype='<U661'),
#  array(['98.91925132274628', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 19'], dtype='<U661'),
#  array(['98.91882398724556', "['Anna Russell']",
#         'A Practical Banana Promotion'], dtype='<U661'),
#  array(['98.91849449276924', "['Kirk Franklin', 'The Family']",
#         'Melodies From Heaven'], dtype='<U661'),
#  array(['98.91838377714157', "['Gisela Prugel']",
#         'Kapitel 21 - Apoll an der Seine'], dtype='<U661'),
#  array(['98.91830044984818', "['Gebrüder Grimm']",
#         'Kapitel 4 - Ausgewählte Märchen'], dtype='<U661'),
#  array(['98.91811490058899', "['Jeff Foxworthy']",
#         'You Might Be a Redneck If...'], dtype='<U661'),
#  array(['98.91788604855537', "['Rudyard Kipling']",
#         'Kapitel 9 - Dschungelbuch'], dtype='<U661'),
#  array(['98.91782754659653', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 24'], dtype='<U661'),
#  array(['98.91780254244804', "['Healy']", '$150 / roll widdit'],
#        dtype='<U661'),
#  array(['98.9169527888298', "['Bob Seger']",
#         'Get Out Of Denver - Live In Detroit/1975'], dtype='<U661'),
#  array(['98.91654327511787', "['Gorillaz', 'Gruff Rhys']",
#         'Superfast Jellyfish (feat. Gruff Rhys and De La Soul)'],
#        dtype='<U661'),
#  array(['98.91624262928963', "['Mitch Hedberg']", 'Candy Bars'],
#        dtype='<U661'),
#  array(['98.91623070836067', "['Zofia Dromlewiczowa']",
#         'Chapter 1.9 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.91464552283287', "['Eric B. & Rakim']", 'As The Rhyme Goes On'],
#        dtype='<U661'),
#  array(['98.9143817126751', "['Victor Borge']", 'Family Background'],
#        dtype='<U661'),
#  array(['98.91412511467934', "['Patricia St. John']",
#         'Kapitel 59 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.91387185454369', "['John Denver']",
#         'Farewell Andromeda (Welcome to My Morning) - Live at the Universal Amphitheatre, Los Angeles, CA - August/September 1974'],
#        dtype='<U661'),
#  array(['98.91381841897964', "['Fugees']", 'Fu-Gee-La - Sly & Robbie Mix'],
#        dtype='<U661'),
#  array(['98.91346889734268', "['Zofia Dromlewiczowa']",
#         'Chapter 3.12 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.9130625128746', "['Zofia Dromlewiczowa']",
#         'Chapter 1.19 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.91288360953331',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 53'],
#        dtype='<U661'),
#  array(['98.91253599524498', "['Jim Morrison', 'The Doors']",
#         'To Come of Age'], dtype='<U661'),
#  array(['98.91211760044098', "['Nature Sounds']", 'Rain: Evening Sleep'],
#        dtype='<U661'),
#  array(['98.91208711266518', "['Brian Regan']", 'Big Family Stuff'],
#        dtype='<U661'),
#  array(['98.91197571158409', "['Patricia St. John']",
#         'Kapitel 97 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.91191586852074', "['Daniel Tosh']", 'America The Augmented'],
#        dtype='<U661'),
#  array(['98.91178315877914', "['Sinclair Lewis', 'Frank Arnold']",
# ...
#         'Das ist bei uns nicht möglich, Kapitel 117'], dtype='<U661'),
#  array(['98.82401099801064', "['Tom Petty and the Heartbreakers']",
#         'American Girl - Live At The Wiltern/1985'], dtype='<U661'),
#  array(['98.82368743419647', "['Talking Heads']",
#         'Once in a Lifetime - Live'], dtype='<U661'),
#  array(['98.82365664839745', "['Alcoholics Anonymous']", 'A Close Shave'],
#        dtype='<U661'),
#  array(['98.82359674572945', "['M.I.A.']", 'Paper Planes'], dtype='<U661'),
#  array(['98.82359507679939', "['Johnny Cash', 'Carl Perkins']",
#         'Blue Suede Shoes - Live at Folsom State Prison, Folsom, CA (1st Show) - January 1968'],
#        dtype='<U661'),
#  array(['98.82348242402077', "['Bill Cosby']", 'Half Man'], dtype='<U661'),
#  array(['98.82308489084244', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 123'], dtype='<U661'),
#  array(['98.82279306650162', "['The Blasters']", "I'm Shakin'"],
#        dtype='<U661'),
#  array(['98.82273316383362', "['Flyleaf']", 'Cassie'], dtype='<U661'),
#  array(['98.822699457407', "['Billie Holiday']",
#         'What A Little Moonlight Can Do - Live At Carnegie Hall,1956'],
#        dtype='<U661'),
#  array(['98.82269787788391', "['James Taylor']", 'Steamroller Blues'],
#        dtype='<U661'),
#  array(['98.82262894511223', "['Patricia St. John']",
#         'Kapitel 72 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.822524279356', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 150'], dtype='<U661'),
#  array(['98.82233408093452', "['NF']", 'Statement'], dtype='<U661'),
#  array(['98.8222761452198', "['Steve Martin']", 'Googlephonics'],
#        dtype='<U661'),
#  array(['98.82226067781448', "['Bass Mekanik']", '65 Hz Test Tone'],
#        dtype='<U661'),
#  array(['98.82222172617912', "['Run–D.M.C.']", 'Peter Piper'],
#        dtype='<U661'),
#  array(['98.82219809293747', "['Robert Frost']", 'The White-Tailed Deer'],
#        dtype='<U661'),
#  array(['98.82193461060524', "['BTS', 'Lauv']",
#         'Make It Right (feat. Lauv)'], dtype='<U661'),
#  array(['98.82182791829109', "['Claude McKay']",
#         'If We Must Die (Introduction)'], dtype='<U661'),
#  array(['98.82179912924767', "['Little Feat']",
#         "Don't Bogart That Joint - Live at Lisner Auditorium, Washington, DC, 8/8/1977"],
#        dtype='<U661'),
#  array(['98.82165244221687', "['Robin Williams']", 'Alcohol - Live'],
#        dtype='<U661'),
#  array(['98.82161304354668', "['Patricia St. John']",
#         'Kapitel 67 - Spuren im Schnee'], dtype='<U661'),
#  array(['98.82154494524002', "['Cheryl Lynn']",
#         'Encore - Extended Version'], dtype='<U661'),
#  array(['98.82140019536018', "['Seweryn Goszczyński']",
#         'Chapter 3.11 - Zamek kaniowski'], dtype='<U661'),
#  array(['98.82125115394592', "['Alfred Hitchcock']",
#         'Jimmy Takes Vanishing Lessons'], dtype='<U661'),
#  array(['98.82123598456383', "['Rod & Kevin', 'B-Legit']", 'Cool Beans'],
#        dtype='<U661'),
#  array(['98.82115411758423', "['Little Feat']",
#         'Rocket In My Pocket - Live at the Rainbow Theatre, London, UK, 8/2/1977'],
#        dtype='<U661'),
#  array(['98.82112115621567', "['John Mulaney']", 'Math and King Solomon'],
#        dtype='<U661'),
#  array(['98.82094642519951', "['The Wailers']",
#         'Duppy Conqueror - Live At Leeds Polytechnic, 1973'], dtype='<U661'),
#  array(['98.82093885540962', "['The Beach Boys']",
#         'Our Favorite Recording Sessions (Mono)'], dtype='<U661'),
#  array(['98.82088220119476', "['iLoveMemphis']",
#         'Hit the Quan - Original Version'], dtype='<U661'),
#  array(['98.82072919607162', "['Mitch Hedberg']", 'Teeth'], dtype='<U661'),
#  array(['98.82058900594711', "['Alice In Chains']",
#         'Angry Chair - Live at the Majestic Theatre, Brooklyn, NY - April 1996'],
#        dtype='<U661'),
#  array(['98.8205306828022', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 174'], dtype='<U661'),
#  array(['98.82044145464897', "['Youngbloodz']", 'Presidential'],
#        dtype='<U661'),
#  array(['98.82038280367851', "['Robert Frost']", 'Desert Places'],
#        dtype='<U661'),
#  array(['98.82005456089973', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #23 - On the Home Front (October 12, 1942)'],
#        dtype='<U661'),
#  array(['98.82004374265671', "['Sacha Guitry']",
#         "Présentation de l'ensemble des métiers du film"], dtype='<U661'),
#  array(['98.81978610157967', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 1'],
#        dtype='<U661'),
#  array(['98.81963375210762', "['Alcoholics Anonymous']",
#         'The Seven Month Slip'], dtype='<U661'),
#  array(['98.8195370733738', "['Seweryn Goszczyński']",
#         'Chapter 3.15 - Zamek kaniowski'], dtype='<U661'),
#  array(['98.81948661804199', "['Tom Lehrer']", 'I Wanna Go Back To Dixie'],
#        dtype='<U661'),
#  array(['98.81935724616051', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 33'], dtype='<U661'),
#  array(['98.81929689645767', "['Manfried Rössner']",
#         'Kapitel 7 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['98.81908270716667', "['Judas Priest']", 'The Ripper - Live'],
#        dtype='<U661'),
#  array(['98.81894958019257', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 135'], dtype='<U661'),
#  array(['98.81892344355583',
#         "['The Who', 'Andy Macpherson', 'Jon Astley']",
#         "I Can't Explain - 40th Anniversary Version - Live At Leeds"],
#        dtype='<U661'),
#  array(['98.81866556406021', "['Viktor Vaughn']", 'Vaudeville Villain'],
#        dtype='<U661'),
#  array(['98.81860592961311', "['Bruce Springsteen']",
#         'Two Hearts - Live at Meadowlands Arena, E. Rutherford, NJ - July 1981'],
#        dtype='<U661'),
#  array(['98.81858217716217', "['Indigo Girls']",
#         'Tangled Up In Blue - Live at the Great American Music Hall, San Francisco, CA -Aug 1992'],
#        dtype='<U661'),
#  array(['98.81846326589584', "['Honoré de Balzac']",
#         'Kapitel 3 - Tante Lisbeth'], dtype='<U661'),
#  array(['98.8184542953968', "['Victor Borge']",
#         'A Mozart Opera by Borge - Voice'], dtype='<U661'),
#  array(['98.81842774152756', "['Manfried Rössner']",
#         'Kapitel 12 - Karl III. Und Anna von Österreich'], dtype='<U661'),
#  array(['98.81833404302597', "['Metallica']",
#         'Ride The Lightning (Live at The Hollywood Palladium, Los Angeles, CA – March 10th, 1985)'],
#        dtype='<U661'),
#  array(['98.81811571121216', "['Chris LeDoux']",
#         'Hooked On An 8 Second Ride'], dtype='<U661'),
#  array(['98.81810909509659', "['Louis Armstrong']", 'All of Me'],
#        dtype='<U661'),
#  array(['98.81801667809486', "['Fleetwood Mac']",
#         'The Chain - Live at Warner Brothers Studios in Burbank, CA 5/23/97'],
#        dtype='<U661'),
#  array(['98.81797829270363', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 53'], dtype='<U661'),
#  array(['98.81787142157555', "['Bob Marley & The Wailers']",
#         'Rat Race - Live At The Pavillon De Paris, 1977'], dtype='<U661'),
#  array(['98.81781303882599', "['Gorillaz']", 'Andromeda (feat. DRAM)'],
#        dtype='<U661'),
#  array(['98.81780725717545', "['MF DOOM']", 'Kon Karne'], dtype='<U661'),
#  array(['98.81760329008102', "['Eric Clapton']",
#         'Let It Grow - Live At Hammersmith'], dtype='<U661'),
#  array(['98.81757256388664', "['Edgar Allan Poe']",
#         'Das Herz des Mr. Barclay, Kapitel 1'], dtype='<U661'),
#  array(['98.81745758652687', "['Mitch Hedberg']", 'Sandwiches'],
#        dtype='<U661'),
#  array(['98.81738874316216', "['Odette Joyeux']",
#         "Je fais un geste d'impatience lasse..."], dtype='<U661'),
#  array(['98.8173660337925', "['Warner Bros Studio Orchestra']",
#         'Of All the Gin Joints In All the Towns In All the World...'],
#        dtype='<U661'),
#  array(['98.81731727719307', "['Big Daddy Kane']", 'Warm It Up, Kane'],
#        dtype='<U661'),
#  array(['98.81727406382561', "['Harry McClintock']",
#         'There is Nothing New in Automobiles'], dtype='<U661'),
#  array(['98.81712520122528', "['DJ Jazzy Jeff & The Fresh Prince']",
#         'Summertime'], dtype='<U661'),
#  array(['98.81708669662476', "['Jimmy Cliff']", 'Journey'], dtype='<U661'),
#  array(['98.8169110417366', "['Bob Seger']",
#         "Betty Lou's Gettin' Out Tonight - Live/Remastered"], dtype='<U661'),
#  array(['98.81684538722038', "['Bruce Springsteen']",
#         'Rosalita (Come Out Tonight) - Live at the Roxy Theatre, W. Hollywood, CA - July 1978'],
#        dtype='<U661'),
#  array(['98.8168358206749', "['Bill Cosby']", 'Oops!'], dtype='<U661'),
#  array(['98.81678369641304', "['Queen']", 'Spread Your Wings - Live'],
#        dtype='<U661'),
#  array(['98.81674516201019', "['Slick Rick']", "The Ruler's Back"],
#        dtype='<U661'),
#  array(['98.81666421890259', "['Bruce Springsteen']",
#         "Candy's Room - Live at Meadowlands Arena, E. Rutherford, NJ - July 1981"],
#        dtype='<U661'),
#  array(['98.81657314300537', "['Beyoncé']", 'Yes'], dtype='<U661'),
#  array(['98.816515147686', "['Friedrich Schiller']",
#         'Kapitel 3 - Was heißt und zu welchem Ende studiert man Universalgeschichte?'],
#        dtype='<U661'),
#  array(['98.81647551059723', "['Jeff Beatman']",
#         "Here we go 'round the Mulberry Bush"], dtype='<U661'),
#  array(['98.81645748019218', "['Stoney LaRue']", 'Oklahoma Breakdown'],
#        dtype='<U661'),
#  array(['98.81638869643211', "['Bad Brains']", 'Intro'], dtype='<U661'),
#  array(['98.81638512015343', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 93'], dtype='<U661'),
#  array(['98.81635388731956', "['Seweryn Goszczyński']",
#         'Chapter 4.5 - Zamek kaniowski'], dtype='<U661'),
#  array(['98.8161569237709', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 107'], dtype='<U661'),
#  array(['98.81615683436394', "['Pink Floyd']", 'Time - Live'],
#        dtype='<U661'),
#  array(['98.81611359119415', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 50'], dtype='<U661'),
#  array(['98.8159308731556', "['Led Zeppelin']",
#         'Whole Lotta Love - 2007 Remaster'], dtype='<U661'),
#  array(['98.81576281785965', "['Digable Planets']",
#         'Time & Space (A New Refutation Of)'], dtype='<U661'),
#  array(['98.81576085090637', "['Judas Priest']", "Devil's Child - Live"],
#        dtype='<U661'),
#  array(['98.81567686796188', '["Fred Wesley & The J.B.\'s"]',
#         'Damn Right I Am Somebody'], dtype='<U661'),
#  array(['98.81563913822174', "['Zofia Dromlewiczowa']",
#         'Chapter 3.8 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['98.81557968258858', "['Tom Lehrer']", 'Oedipus Rex'],
#        dtype='<U661'),
#  array(['98.81536415219307', "['Pink Floyd']", 'Us and Them - Live'],
#        dtype='<U661'),
#  array(['98.81513085961342', "['Linton Kwesi Johnson']",
#         'Di Black Petty Booshwah'], dtype='<U661'),
#  array(['98.81509950757027', "['Los Angeles Azules', 'Jay de la Cueva']",
#         '17 Años - Concierto Sinfónico Cumbia Fuzion'], dtype='<U661'),
#  array(['98.81502622365952', "['The Roots']", 'Silent Treatment'],
#        dtype='<U661'),
#  array(['98.81499940156937', "['Marshmello', 'Lil Peep']", 'Spotlight'],
#        dtype='<U661'),
#  array(['98.81492698192596', "['deadmau5']", 'Sofi Needs a Ladder'],
#        dtype='<U661'),
#  array(['98.81489732861519', "['Firefall']", 'Just Remember I Love You'],
#        dtype='<U661'),
#  array(['98.81481629610062', "['Zofia Dromlewiczowa']",
#         'Chapter 1.18 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['98.8147292137146', "['John Mulaney']",
#         'The Salt and Pepper Diner'], dtype='<U661'),
#  array(['98.81472697854042', "['Liberace']",
#         '"The Wonderful Art of Playing Latin Percussion Instruments" - Live'],
#        dtype='<U661'),
#  array(['98.81472092866898', "['Alex Campos']", 'Te Puedo Sentir'],
#        dtype='<U661'),
#  array(['98.81471958756447', "['Bob Marley & The Wailers']",
#         'Natural Mystic'], dtype='<U661'),
#  array(['98.81462648510933', "['Louise Bogan']", 'Kept'], dtype='<U661'),
#  array(['98.81450092792511', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 36'], dtype='<U661'),
#  array(['98.8144979774952', "['Amy Winehouse']", 'Cherry'], dtype='<U661'),
#  array(['98.81433656811714', "['Chuck Mangione', 'Esther Satterfield']",
#         'Land Of Make Believe'], dtype='<U661'),
#  array(['98.81430667638779', "['Tom Lehrer']",
#         'We Will All Go Together When We Go'], dtype='<U661'),
#  array(['98.81420290470123', '["Lil\' Flip"]', 'Game Over'], dtype='<U661'),
#  array(['98.81418931484222', "['Vampire Weekend']", 'California English'],
#        dtype='<U661'),
#  array(['98.81402921676636',
#         "['Jean Cocteau', 'André Parinaud', 'Yvette Guilbert']",
#         'La politique / Colette'], dtype='<U661'),
#  array(['98.81400588154793', "['Harold Arlen', 'E.Y. Harburg']",
#         'Munchkinland Musical Sequence - Rehearsal Demo'], dtype='<U661'),
#  array(['98.81397640705109', "['Sheri Jones-Moffett']",
#         'Encourage Yourself'], dtype='<U661'),
#  array(['98.81364172697067', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 25'], dtype='<U661'),
#  array(['98.81363308429718', "['Alanis Morissette']",
#         'Head over Feet - Live / Unplugged'], dtype='<U661'),
#  array(['98.81335026025772', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 7'], dtype='<U661'),
#  array(['98.81331619620323', "['Tom Lehrer']", 'MLF Lullaby'],
#        dtype='<U661'),
#  array(['98.81290546059608', "['U2']",
#         'Bullet The Blue Sky - Live - Rattle & Hum Version'], dtype='<U661'),
#  array(['98.81252667307854', "['Flight of the Conchords']",
#         'Hurt Feelings'], dtype='<U661'),
#  array(['98.81245413422585', "['Prince']", 'Lady Cab Driver'],
#        dtype='<U661'),
#  array(['98.81231448054314', "['The Kinks']",
#         'You Really Got Me - Live at Lowell Memorial Auditorium, Lowell, MA - March 1979'],
#        dtype='<U661'),
#  array(['98.81230890750885', "['Zapp']", "It Doesn't Really Matter"],
#        dtype='<U661'),
#  array(['98.81227180361748', "['Robin Williams']", 'Ballet - Live'],
#        dtype='<U661'),
#  array(['98.81225326657295', "['Alcoholics Anonymous']",
#         'Women Suffer Too'], dtype='<U661'),
#  array(['98.81214639544487', "['Bill Cosby']", 'The Playground'],
#        dtype='<U661'),
#  array(['98.81209647655487', "['Juan Gabriel']",
#         'Amor Eterno (En Vivo) - En el Palacio de Bellas Artes'],
#        dtype='<U661'),
#  array(['98.81191089749336', "['6ix9ine', 'Nicki Minaj']",
#         'TROLLZ (with Nicki Minaj)'], dtype='<U661'),
#  array(['98.81137499213219', "['Ray Wylie Hubbard']", 'Redneck Mother'],
#        dtype='<U661'),
#  array(['98.81120684742928', "['Harry McClintock']",
#         'Pete Wells and the Negro Fireman'], dtype='<U661'),
#  array(['98.81116518378258', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 49'], dtype='<U661'),
#  array(['98.81115633249283', "['Linkin Park']",
#         'Lying from You - Live LP Underground Tour 2003'], dtype='<U661'),
#  array(['98.81104618310928', "['Seweryn Goszczyński']",
#         'Chapter 4.9 - Zamek kaniowski'], dtype='<U661'),
#  array(['98.81091740727425', "['John Mayer']",
#         'Good Love Is On the Way - Live at the Nokia Theatre, Los Angeles, CA - December 2007'],
#        dtype='<U661'),
#  array(['98.81055691838264', "['Goodie Mob']", 'Cell Therapy'],
#        dtype='<U661'),
#  array(['98.8104556798935', "['DERYL DODD']", 'New Tony Lamas'],
#        dtype='<U661'),
#  array(['98.81034070253372', "['Seweryn Goszczyński']",
#         'Chapter 4.12 - Zamek kaniowski'], dtype='<U661'),
#  array(['98.81022500991821', "['Andy Mineo', 'Lecrae']", 'Coming In Hot'],
#        dtype='<U661'),
#  array(['98.81004762649536', "['Michael Stanley Band']",
#         'Rosewood Bitters - Live'], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
