# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'STARGAZING':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['Travis Scott']", 'STARGAZING'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=5001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Kanye West']", 'All Of The Lights'],
#         ["['YUNGBLUD', 'Halsey', 'Travis Barker']",
#          '11 Minutes (with Halsey feat. Travis Barker)'],
#         ["['Juice WRLD']", "I'll Be Fine"],
#         ...,
#         ["['Ambjaay']", 'Uno'],
#         ["['Staind']", 'So Far Away'],
#         ["['Rob Zombie', 'Howard Stern']",
#          'The Great American Nightmare']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.0006

# %%
relevance
# Out:
# 96.99999999997146

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.column_stack((predictions, song_info[:,0], song_info[:,1]))

# %%
sort_indices = np.argsort(predictions)[::-1]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[sort_indices]

# %%
list(predicted)
# Out:
# [array(['99.2795833884498', "['Rain Sounds For Sleep']",
#         'Fall Asleep Rain'], dtype='<U661'),
#  array(['99.27052441454666', "['Rain Sounds For Sleep']",
#         'Sleep Well Rain Sound'], dtype='<U661'),
#  array(['99.2698456244186', "['Rain Sound Studio']", 'Under Shelter Rain'],
#        dtype='<U661'),
#  array(['99.2619928703771', "['Sound Carrie']",
#         'Loopable Sound - Flight 2021'], dtype='<U661'),
#  array(['99.2511945772905', "['Sampling XL']", 'Spirit Body Rain Fall'],
#        dtype='<U661'),
#  array(['99.24177784846799',
#         "['Igor Stravinsky', 'Michael Tilson Thomas']",
#         "Le sacre du printemps (The Rite of Spring): Première partie: L'adoration de la terre (Part I: Adoration of the Earth): Le sage (The Sage)"],
#        dtype='<U661'),
#  array(['99.23490889894498', "['The Rain Library']",
#         'White Noise Rain Sound'], dtype='<U661'),
#  array(['99.23106731092972', "['Dreams of Dreams']", 'River Rain'],
#        dtype='<U661'),
#  array(['99.22783352009672', "['Nature Sounds']",
#         'Thoughtful Approaching Thunderstorm'], dtype='<U661'),
#  array(['99.22615931968656', "['Rain Hard']", 'Lush Rain'], dtype='<U661'),
#  array(['99.22528864990065',
#         "['Rain Sounds', 'Mindfulness Meditation Music Spa Maestro', 'Mindfulness Mediation World']",
#         'Awakening Rain'], dtype='<U661'),
#  array(['99.2249650965674', "['Rain Man Sounds']",
#         'Light Intense Sleep Rain'], dtype='<U661'),
#  array(['99.22256784199216', "['Ambiworld']",
#         'Pouring Rain - Striking Thunder'], dtype='<U661'),
#  array(['99.22129936808156', "['Pro Sounds of Nature']", 'Afternoon Rain'],
#        dtype='<U661'),
#  array(['99.2124133568449', "['Rain Storm Sample Library']",
#         'Serenity Rain'], dtype='<U661'),
#  array(['99.210454909515', "['Empty Fields']", 'Aero Noise'], dtype='<U661'),
#  array(['99.20800087990838', "['Hayden Ball']", 'Rain And Wind'],
#        dtype='<U661'),
#  array(['99.20769238372527', "['Lush Rain Creators']", 'Summer Rain 2'],
#        dtype='<U661'),
#  array(['99.20598296851215', "['Weather Factory']", 'Forest Thunderstorm'],
#        dtype='<U661'),
#  array(['99.20450648243003', "['Rain Sounds Factory STHLM']",
#         'Rain Sound : Night Time'], dtype='<U661'),
#  array(['99.20287810219489', "['Chill Bees']", 'Light Rain'], dtype='<U661'),
#  array(['99.2024254900089', "['Benjamin Martins']", 'Clear Conscience'],
#        dtype='<U661'),
#  array(['99.20155283225003', "['Rain Recorders']", 'Dock Rain'],
#        dtype='<U661'),
#  array(['99.20118642699663', "['Sleep Sounds of Nature']",
#         'Under a Waterfall (Relaxing Sounds)'], dtype='<U661'),
#  array(['99.19949895896636', "['Rain Sounds ACE']", 'Rain in the Park'],
#        dtype='<U661'),
#  array(['99.19878008851435', "['Forest FX']", 'Campfire Rain'],
#        dtype='<U661'),
#  array(['99.19528816342908', "['Natural Sound Selections']",
#         'Lluvia Eterna'], dtype='<U661'),
#  array(['99.19464168723492', "['The Rain Library']", 'Dripping Rain'],
#        dtype='<U661'),
#  array(['99.19437677433308', "['Granular']", 'Brown Noise 355 LPF'],
#        dtype='<U661'),
#  array(['99.19432181178757', "['520Hz']", '8-Bit CockPit'], dtype='<U661'),
#  array(['99.19362164089497',
#         "['Rain Sounds', 'Rainfall', 'Rain for Deep Sleep', 'Rain Sounds Nature Collection', 'Fresh Water Spa', 'Sounds Of Nature : Thunderstorm, Rain']",
#         'Gentle Rain Fall'], dtype='<U661'),
#  array(['99.19216695158549', "['Nature Sounds']",
#         'Tranquil Rumbling Thunderstorm'], dtype='<U661'),
#  array(['99.1918018035058', "['Noise Makers']", 'Brain X 1000'],
#        dtype='<U661'),
#  array(['99.1893651534794', "['Thunderstorm']", 'Rain Downpour'],
#        dtype='<U661'),
#  array(['99.18930511122844', "['Wonderful Escape']",
#         'Lightning Strikes at the Farm'], dtype='<U661'),
#  array(['99.18852294970804', "['Jimi Hendrix']",
#         'The Star Spangled Banner - Woodstock Festival Excerpt'],
#        dtype='<U661'),
#  array(['99.18685908565972', "['Big Sounds']", 'In the Forest Rain'],
#        dtype='<U661'),
#  array(['99.18637830603849', "['Sky Fall SF']", 'Rain Sounds: Rainfall'],
#        dtype='<U661'),
#  array(['99.18483545969514', "['Beach Top Sounders']", 'Sleep Refreshed'],
#        dtype='<U661'),
#  array(['99.18434294546593', "['Decidic FX']", 'Breeze Rain'],
#        dtype='<U661'),
#  array(['99.18411100778212',
#         "['White Noise Baby Sleep', 'White Noise for Babies', 'White Noise For Baby Sleep', 'Natural Sounds', 'Nature & Sounds Backgrounds']",
#         'The Early Morning Rain'], dtype='<U661'),
#  array(['99.18301892108921', "['Sleepy Times']",
#         'Thunderstorm for Relaxing Sleep, Pt. 4'], dtype='<U661'),
#  array(['99.18269932819084', "['Nature Sounds']",
#         'Healthful Rolling Thunder with Distant Rumbles'], dtype='<U661'),
#  array(['99.18029614421263', "['Sleepy Times']",
#         'Thunderstorm for Relaxing Sleep, Pt. 47'], dtype='<U661'),
#  array(['99.17969849005163', "['Granular']", 'White Noise - 145 hz'],
#        dtype='<U661'),
#  array(['99.17811099927273', "['Rain Recorders']", 'Rainy Alley'],
#        dtype='<U661'),
#  array(['99.1751777903897', "['Silent Knights']",
#         'Womb Heartbeat (No Fade for Looping)'], dtype='<U661'),
#  array(['99.17425413029298', "['Lluvia PQ']", 'Rain All Night'],
#        dtype='<U661'),
#  array(['99.17116358411909',
#         "['Soothing White Noise for Infant Sleeping and Massage, Crying & Colic Relief']",
#         'Quiet Rain Showers & Rolling Thunder Storms Imix for Mom’s Napping Toddler'],
#        dtype='<U661'),
#  array(['99.17103745618324', "['Sound Library XL']", 'Calming Water'],
#        dtype='<U661'),
#  array(['99.1707127071073', "['The Rain Library']", 'Deep Rain'],
#        dtype='<U661'),
#  array(['99.16959126032181', "['Tranquility Spree']", 'Perfect Rain'],
#        dtype='<U661'),
#  array(['99.16879057007783', "['Dreams of Dreams']", 'Oceanic Calmness'],
#        dtype='<U661'),
#  array(['99.16796476291617', "['Winds and Oceans']", 'Wet Dreams of Rain'],
#        dtype='<U661'),
#  array(['99.16789895943538', "['The Sleep Helpers']", 'Stormy Rain Sound'],
#        dtype='<U661'),
#  array(['99.1658983571721', "['Brain Timbre']",
#         'Open Window Thunder Sounds'], dtype='<U661'),
#  array(['99.16589238821027', "['Rain Sound Studio']",
#         'Calmness Rain Sound'], dtype='<U661'),
#  array(['99.16397249942109', "['Mother Nature FX']", 'Relaxation Rain'],
#        dtype='<U661'),
#  array(['99.16378007288304', "['High Altitude Samples']",
#         'Cabin Back Noise'], dtype='<U661'),
#  array(['99.16294416028724', "['Rain Sounds ACE']", 'Moderate Rain'],
#        dtype='<U661'),
#  array(['99.1626291100707', "['The Outdoor Library']",
#         'Sounds of Nature: Thunder'], dtype='<U661'),
#  array(['99.16245764311327', "['Mother Nature Sound FX']",
#         'Thunderstorm In The Cabin'], dtype='<U661'),
#  array(['99.16208079681601', "['Nature Sounds Nature Music']",
#         'Rain Forest and Tropical Beach Sound'], dtype='<U661'),
#  array(['99.16189150033344', "['Mother Nature FX']", 'Relaxing Rain Sound'],
#        dtype='<U661'),
#  array(['99.16061071974126', "['Rain Sounds Factory STHLM']",
#         'Rain Sound : Dark Sky'], dtype='<U661'),
#  array(['99.16051956706048', "['The Relaxing Sounds of Swedish Nature']",
#         'Rain for Sleep'], dtype='<U661'),
#  array(['99.16037692142883', "['Nature Sounds']",
#         'Babbling Brook - Flowing Stream'], dtype='<U661'),
#  array(['99.15915881288916', "['Yoga Rain']", 'Rain against Ground'],
#        dtype='<U661'),
#  array(['99.15803202816392', "['Sound Library XL']", 'Water Pour'],
#        dtype='<U661'),
#  array(['99.15742454060495', "['Rain Sounds']",
#         'Gentle Rain, Rain Sound Meditation'], dtype='<U661'),
#  array(['99.15540525540966', "['Weather Factory']", 'Deep Thunderstorm'],
#        dtype='<U661'),
#  array(['99.15538562521209', "['Chill Bees']", 'Rain at Dawn'],
#        dtype='<U661'),
#  array(['99.15479169873133', "['Hi Freq Samples']", 'Heavy Rain'],
#        dtype='<U661'),
#  array(['99.15343894409435', "['Sleep Tight']", 'River Rain Fall'],
#        dtype='<U661'),
#  array(['99.15310918088656', "['Deep Rain Sampling']", 'Water Sounds Rain'],
#        dtype='<U661'),
#  array(['99.15167057102403', "['Outside Broadcast Recordings']",
#         'Soggy Afternoon'], dtype='<U661'),
#  array(['99.14998778040584', "['Sleep Rain']", 'Rain: Sleep'],
#        dtype='<U661'),
#  array(['99.14955426126221', "['TOOL']", 'Mantra'], dtype='<U661'),
#  array(['99.14761958461932', "['Sample Rain Library']", 'Cozy Rain'],
#        dtype='<U661'),
#  array(['99.1473568998853', "['Nature Sounds']", 'Forest Rain'],
#        dtype='<U661'),
#  array(['99.14721748936023', "['Epic Soundscapes']", 'Heavy Rain'],
#        dtype='<U661'),
#  array(['99.14668030840215', "['Thunderstorm']", 'Rain - Sound of Nature'],
#        dtype='<U661'),
#  array(['99.14607772074494', "['Wonderful Escape']",
#         'Thunder From Under the Tree'], dtype='<U661'),
#  array(['99.14606143273396', "['Beach Top Sounders']", 'Wake Up Calm'],
#        dtype='<U661'),
#  array(['99.14504515541316', "['Natural Samples']", 'Soft Rain Samples'],
#        dtype='<U661'),
#  array(['99.14499316718911', "['Waves Hard']", 'Ocean For Sleep'],
#        dtype='<U661'),
#  array(['99.14419127003762', "['Rain Recordings']", 'Poolside Rain'],
#        dtype='<U661'),
#  array(['99.14283988298506',
#         "['Rain Sounds', 'Sleep Sounds of Nature', 'Zen Music Garden']",
#         'Quiet Rain(Loopable,No fade)'], dtype='<U661'),
#  array(['99.14195343996651', "['Rain Recorders']", 'City Rain'],
#        dtype='<U661'),
#  array(['99.14110133924711', "['HI-FI CAMP']", 'Cabin Sound'],
#        dtype='<U661'),
#  array(['99.1408416386762', "['Decidic FX']", 'Softer Rain'], dtype='<U661'),
#  array(['99.14084025852769',
#         "['Igor Stravinsky', 'Columbia Symphony Orchestra']",
#         "L'Oiseau de feu: Mort de Kachtchei - Profonds ténèbres - 1910 version"],
#        dtype='<U661'),
#  array(['99.14084025852769',
#         "['Igor Stravinsky', 'Columbia Symphony Orchestra']",
#         "L'Oiseau de feu: Mort de Kachtchei - Profonds ténèbres - 1910 version"],
#        dtype='<U661'),
#  array(['99.1407277676059', "['Heavy Rain Sounds']",
#         'Heavy Rain With Brown Noise'], dtype='<U661'),
#  array(['99.1405607269616', "['Sample Rain Library']", 'Ambiente Lluvia'],
#        dtype='<U661'),
#  array(['99.14049745163184', "['Microdynamic Recordings']", 'Calm Pour'],
#        dtype='<U661'),
#  array(['99.14020642698208',
#         "['The White Noise Zen & Meditation Sound Lab']",
#         'Calm Rain Storm & Gentle White Noise'], dtype='<U661'),
#  array(['99.13992140115757', "['Nataural']", 'Under Shelter Rain'],
#        dtype='<U661'),
#  array(['99.1399079439706', "['Forest FX']", 'Camping Rain'], dtype='<U661'),
#  array(['99.13943701831619', "['The Sleep Helpers']", 'Street Rain'],
#        dtype='<U661'),
#  array(['99.13943380560916', "['Sample Rain Library']", 'Dark Rain Sound'],
#        dtype='<U661'),
#  array(['99.13858350965599', "['Nature Sounds']",
#         'Soothing Approaching Storm with Warning Thunder Rolls'],
#        dtype='<U661'),
#  array(['99.13734873529192', "['Max Richter']", 'The Departure'],
#        dtype='<U661'),
#  array(['99.13670175807452', "['Rain Sound Studio']", 'Downpoar'],
#        dtype='<U661'),
#  array(['99.13596340349582',
#         "['Soothing White Noise for Infant Sleeping and Massage, Crying & Colic Relief']",
#         'Falling Rain Drops & Water Soundtrack to De Stress Screaming Baby, Tantrums'],
#        dtype='<U661'),
#  array(['99.13539280439477', "['Leah Day']", 'Snowdonia'], dtype='<U661'),
#  array(['99.13503059773774',
#         "['Sleep Baby Sleep', 'Ocean Sounds', 'Ocean Waves For Sleep', 'Fresh Water Sounds', 'Relajación']",
#         'Beach Waves and Soothing Brown Noise'], dtype='<U661'),
#  array(['99.1346456979154', "['Sounds Of Rain & Thunder Storms']",
#         'Storm Rain Sounds'], dtype='<U661'),
#  array(['99.1331736287134', "['Serenity of Sound']", 'Exotic Rain'],
#        dtype='<U661'),
#  array(['99.1320237540589', "['Oliver Évilo']", 'Jupiter Sunrise'],
#        dtype='<U661'),
#  array(['99.13164597572595', "['Thunderstorm Sound Bank']",
#         'Thunderstorm By The Waterfall'], dtype='<U661'),
#  array(['99.13047470175866', "['Nataural']", 'Forest Thunderstorm'],
#        dtype='<U661'),
#  array(['99.13034948809832', "['High Altitude Samples']",
#         'Soft Brown Noise'], dtype='<U661'),
#  array(['99.13026755127238', "['Mother Nature Sound FX']",
#         'Florida Rain Storm'], dtype='<U661'),
#  array(['99.1299374648016',
#         "['Ocean Waves For Sleep', 'Ocean Sounds Collection', 'Ocean Sounds', 'Fresh Water Sounds', 'Water Sound Natural White Noise']",
#         'Rolling Ocean Waves'], dtype='<U661'),
#  array(['99.12993000182999', "['Mother Nature Sound FX']",
#         'Caribbean Thunderstorm'], dtype='<U661'),
#  array(['99.12973971707959', "['Christoph Willibald Gluck', 'Yuja Wang']",
#         "Orfeo ed Euridice, Wq. 30 - Arranged Sgambati / Act 2: Melodie dell'Orfeo"],
#        dtype='<U661'),
#  array(['99.12948540928322', "['Rain Sounds XLE Library']",
#         'Rain Sound: Pouring'], dtype='<U661'),
#  array(['99.1293766206748', "['WNX']", 'Lo-Air'], dtype='<U661'),
#  array(['99.12912647691711', "['Granular']", 'Brown Noise 140 hz Sharp Q'],
#        dtype='<U661'),
#  array(['99.1284675961568', "['Morton Feldman']", 'Rothko Chapel 5'],
#        dtype='<U661'),
#  array(['99.12633842563852', "['Dream Shard']", 'Baby Dreams PT 2'],
#        dtype='<U661'),
#  array(['99.12621581507364', "['Spirits Of Our Dreams']", 'Moving Silence'],
#        dtype='<U661'),
#  array(['99.12607736015411', "['Erik Satie', 'Cristina Ariagno']",
#         'Enfantillages pittoresques: II. Berceuse'], dtype='<U661'),
#  array(['99.12547980522386', "['Ocean Sounds ACE']", 'Sleep: Soft Ocean'],
#        dtype='<U661'),
#  array(['99.12539482124872', "['Deep Rain Sampling']", 'Warm Forest Rain'],
#        dtype='<U661'),
#  array(['99.12535579759133',
#         "['Howard Blake', 'Steven Isserlis', 'Stephen Hough']",
#         "Archangel's Lullaby"], dtype='<U661'),
#  array(['99.1231928033413', "['Lila Om']", 'Dulled White Noise'],
#        dtype='<U661'),
#  array(['99.12282312575714', "['Rain Man Sounds']", 'Heavy Straight Rain'],
#        dtype='<U661'),
#  array(['99.12168075970716',
#         "['Sleep Baby Sleep', 'Vacuum Cleaner White Noise', 'White Noise Research', 'Baby Naptime', 'Outside Broadcast Recordings']",
#         'Vacuum Cleaner and Soothing Brown Noise'], dtype='<U661'),
#  array(['99.12011199925344', "['KISS']", 'Rock And Roll Party'],
#        dtype='<U661'),
#  array(['99.12004951310216', "['Nature Sounds Artists']",
#         'Thunderstorm Approaching'], dtype='<U661'),
#  array(['99.11997440454479', "['Alexandre Desplat']", 'Harry and Ginny'],
#        dtype='<U661'),
#  array(['99.11978520412406', "['Granular']", 'White Noise - 700 hz'],
#        dtype='<U661'),
#  array(['99.1197572489937', "['Nine Inch Nails']", 'Pinion'], dtype='<U661'),
#  array(['99.11962612390319', "['Nature Sounds']", 'Rain And Thunder'],
#        dtype='<U661'),
#  array(['99.11933229122965', "['The Sleep Helpers']", 'Rain In The Bay'],
#        dtype='<U661'),
#  array(['99.1185734802203', "['Igor Stravinsky', 'Leopold Stokowski']",
#         'Le sacre du printemps (The Rite of Spring): Part I: The Adoration of the Earth: Adoration of the Earth (Wise Elder)'],
#        dtype='<U661'),
#  array(['99.1177541365136', "['Desolate Horizons']", 'More Than Anything'],
#        dtype='<U661'),
#  array(['99.1164372682642', "['Naturally Recurring']", 'Sunrise Glory'],
#        dtype='<U661'),
#  array(['99.11496938312031', "['Gentle Rain Makers']", 'Drip Drop Sleep'],
#        dtype='<U661'),
#  array(['99.11450483838117', "['Yue Yan Jen']",
#         '梦蝶 - Dream to be a butterfly'], dtype='<U661'),
#  array(['99.11376902036159', "['Wp Sounds']", 'Rain Sounds Chill'],
#        dtype='<U661'),
#  array(['99.11315080876372', "['Epic Soundscapes']",
#         'Heavy Rain & Gentle Thunder'], dtype='<U661'),
#  array(['99.11241088046566', "['Rain Sounds']", 'White Noise'],
#        dtype='<U661'),
#  array(['99.11233810903089', "['Rain Storm Sample Library']",
#         'Sleep and Chill Rain'], dtype='<U661'),
#  array(['99.11202314981034', "['Various Artists']",
#         'Death Of The First Born - The Prince Of Egypt/Soundtrack Version'],
#        dtype='<U661'),
#  array(['99.1116955312375', "['Binaural Beats Sleep']",
#         'Binaural Beats (Restful Sleep)'], dtype='<U661'),
#  array(['99.11163275674984', "['Zen Sounds']",
#         'White Noise: Mindfulness Meditations (Loopable)'], dtype='<U661'),
#  array(['99.11161020152733', "['Natural Woodland Sounds']",
#         'Meditation Rain'], dtype='<U661'),
#  array(['99.11119906692113', "['Deep Sleep Music Collective']",
#         'Sleeping Music (Calm Sleep)'], dtype='<U661'),
#  array(['99.11058776933379', "['Winds and Oceans']", 'White Noise Rain'],
#        dtype='<U661'),
#  array(['99.11007030463321', "['Nature Sounds']",
#         'Surrounded by Thunder Rumbles'], dtype='<U661'),
#  array(['99.10979010394398',
#         "['Rain Sounds', 'Rain Sounds & White Noise', 'Relaxing Rain Sounds', 'Meditation Rain Sounds', 'Sleep Sound Library', 'Sleep Sounds of Nature']",
#         'Pouring Rain'], dtype='<U661'),
#  array(['99.10830953990525', "['Nataural']", 'Gusty Waves'], dtype='<U661'),
#  array(['99.10804805563943', "['Fabricantes De Lluvia']", 'Smooth Rain'],
#        dtype='<U661'),
#  array(['99.1076765953797', "['Waves Hard']", 'Waves for Dreaming'],
#        dtype='<U661'),
#  array(['99.10752660753306',
#         "['Sleep Baby Sleep', 'Meditation Spa', 'White Noise Therapy', 'Rain Spa', 'Rain Shower']",
#         'Pouring Rain - Loopable with No Fade'], dtype='<U661'),
#  array(['99.10688180538959', "['Natural Sound Selections']",
#         'Good Night Sleep'], dtype='<U661'),
#  array(['99.10677564949675', "['Baby Lullaby Academy']",
#         'Baby Lullaby Music'], dtype='<U661'),
#  array(['99.10670698166719', "['Erik Satie', 'Roland Pöntinen']",
#         '3 Gnossiennes: Gnossienne No.3'], dtype='<U661'),
#  array(['99.10669396491245', "['Deep Sleep Music Collective']",
#         'Starlight'], dtype='<U661'),
#  array(['99.10655770629299',
#         "['Sleep Baby Sleep', 'Meditation Spa', 'White Noise Therapy', 'Rain Spa', 'Rain Shower']",
#         'Pouring Rain - Loopable with No Fade'], dtype='<U661'),
#  array(['99.1061781947962',
#         "['Rain Sounds', 'Rain Sounds & White Noise', 'Relaxing Rain Sounds', 'Meditation Rain Sounds', 'Sleep Sound Library', 'Rain Sounds Sleep']",
#         'A Gentle Thunderstorm'], dtype='<U661'),
#  array(['99.10581687548104', "['Harold Budd', 'Brian Eno']",
#         'The Pearl - 2005 Digital Remaster'], dtype='<U661'),
#  array(['99.10577935217955', "['Max Richter']",
#         'Dream 1 (before the wind blows it all away) - Pt. 1'],
#        dtype='<U661'),
#  array(['99.1056860501249',
#         "['Igor Stravinsky', 'Columbia Symphony Orchestra']",
#         'Le sacre du printemps: Part 1 "Adoration of the Earth", The Wise Elder'],
#        dtype='<U661'),
#  array(['99.10568543798301', "['FX & Effects']", 'Smooth Rain'],
#        dtype='<U661'),
#  array(['99.10513986673902', "['The Outdoor Library']",
#         'Sounds of Nature: Dripping Rain'], dtype='<U661'),
#  array(['99.1050203340071',
#         "['Calming Rainforest Sounds', 'Rainfall', 'Rain Sounds', 'Rain for Deep Sleep', 'Thunderstorm Sleep']",
#         'Soothing Brown Waves with the Pouring Rain - Loopable with no fade'],
#        dtype='<U661'),
#  array(['99.10459994817433', "['Rain Sound Studio']", 'Miami Rain'],
#        dtype='<U661'),
#  array(['99.1045408399308', "['Mother Nature Sound FX']",
#         'Pouring Rain & Thunder'], dtype='<U661'),
#  array(['99.10418520104402',
#         "['Meditation Music Club', 'Meditation Music Masters', 'Thunderstorm Sleep', 'Thunder Storm', 'Lightning, Thunder and Rain Storm', 'Thunderstorms', 'Sounds of Nature: Thunderstom, Rain']",
#         'A Gentle Thunderstorm'], dtype='<U661'),
#  array(['99.10393623244036', "['Outside HD Samples']", 'Calm Rain pt. 1'],
#        dtype='<U661'),
#  array(['99.1039314753644', "['Thunderstorm Sound Bank']",
#         'Rain & Thunder'], dtype='<U661'),
#  array(['99.10387195713271', "['Carl Borg']", 'Connection'], dtype='<U661'),
#  array(['99.10374317312446', "['Deep Sleep Music Collective']", 'Moonbeam'],
#        dtype='<U661'),
#  array(['99.10302890284679', "['Ocean Makers']", 'Soothing Waves Sounds'],
#        dtype='<U661'),
#  array(['99.1026744580862', "['The Tides']", 'Your Peace'], dtype='<U661'),
#  array(['99.10239006110808',
#         "['Rain Sounds', 'Sleep Sounds of Nature', 'Zen Music Garden']",
#         'Soothing Rain(Loopable,No fade)'], dtype='<U661'),
#  array(['99.1020268395578', "['Deep Sleep Music Collective']",
#         'Ocean Beauty'], dtype='<U661'),
#  array(['99.10158472087666', "['Frédéric Chopin', 'Khatia Buniatishvili']",
#         'Waltz in C-Sharp Minor, Op. 64 No. 2'], dtype='<U661'),
#  array(['99.1013940118258',
#         "['James Horner', 'London Symphony Orchestra']", "Murron's Burial"],
#        dtype='<U661'),
#  array(['99.1006459939315', "['Deep Sleep Music Collective']", 'REM Sleep'],
#        dtype='<U661'),
#  array(['99.10031979298648', "['Deep Sleep Music Collective']",
#         'Sleeping Music (Sounds for Sleep)'], dtype='<U661'),
#  array(['99.10020479640306', "['Deep Sleep Music Collective']",
#         'Sleeping Music (Piano Sleep Music)'], dtype='<U661'),
#  array(['99.10020084695033', "['Deep Sleep Music Collective']",
#         'Purple Star'], dtype='<U661'),
#  array(['99.10010158158272', "['Deep Sleep Music Collective']",
#         'Reflections'], dtype='<U661'),
#  array(['99.09989045499', "['Aaron Lansing']", 'Faded Dreams'],
#        dtype='<U661'),
#  array(['99.09976089107187', "['Sebastiano Effe']",
#         'Nobody Is Holding My Hand'], dtype='<U661'),
#  array(['99.09967073298363', "['Sky Fall SF']", 'Rain Sounds: Raining'],
#        dtype='<U661'),
#  array(['99.09959642368737',
#         "['Camille Saint-Saëns', 'Philippe Entremont', 'Gaby Casadesus', 'Yo-Yo Ma']",
#         'Carnival of the Animals, R. 125: Tortoises'], dtype='<U661'),
#  array(['99.09947324492258', "['Deep Sleep Music Collective']",
#         'New Age Piano for Sleep'], dtype='<U661'),
#  array(['99.09922691978',
#         "['Igor Stravinsky', 'Columbia Symphony Orchestra']",
#         'Le sacre du printemps: Part 1 "Adoration of the Earth", The Wise Elder'],
#        dtype='<U661'),
#  array(['99.09922691978',
#         "['Igor Stravinsky', 'Columbia Symphony Orchestra']",
#         'Le sacre du printemps: Part 1 "Adoration of the Earth", The Wise Elder'],
#        dtype='<U661'),
#  array(['99.09825849293395', "['Nature Sounds']",
#         'Serene Thunderstorm in the Distance'], dtype='<U661'),
#  array(['99.09816170454205', "['Deep Sleep Music Collective']",
#         'Sleep Music (Distant Lands)'], dtype='<U661'),
#  array(['99.09800749859096', "['Koby Laver']", 'Close your eyes'],
#        dtype='<U661'),
#  array(['99.09799399078261', "['Natural White Noise Relaxation']",
#         'White and Pink Noise: Light Forest Rain, Ambient Water to Help Aid Sound Sleep'],
#        dtype='<U661'),
#  array(['99.09797324323824', "['Factorial FX']", 'Rain Droplets'],
#        dtype='<U661'),
#  array(['99.09776929154721', "['Deep Sleep Music Collective']",
#         'Quiet Music for Sleep'], dtype='<U661'),
#  array(['99.09775185214396', "['Deep Sleep Music Collective']",
#         'Above the Clouds'], dtype='<U661'),
#  array(['99.09731511168641',
#         "['Erik Eriksson', 'White Noise Baby Sleep', 'White Noise for Babies']",
#         'Clean White Noise - Loopable with no fade'], dtype='<U661'),
#  array(['99.09647822470565', "['Erik Satie', 'Jean-Yves Thibaudet']",
#         'Gnossiennes: No. 4'], dtype='<U661'),
#  array(['99.09635672270612', "['Deep Sleep Music Collective']",
#         'Sleep Songs'], dtype='<U661'),
#  array(['99.09625860885606', "['Deep Sleep Music Collective']",
#         'Sleep Music (Gentleness)'], dtype='<U661'),
#  array(['99.09597882827697', "['John Williams']", 'Opening Titles'],
#        dtype='<U661'),
#  array(['99.09594953249096', "['Deep Sleep Music Collective']",
#         'Soothing Sleep'], dtype='<U661'),
#  array(['99.09445254623499', "['Latium']", 'Space'], dtype='<U661'),
#  array(['99.09415865812839', "['Jeremy Soule']", "Kyne's Peace"],
#        dtype='<U661'),
#  array(['99.09362575385134', "['C418']", 'Thirteen'], dtype='<U661'),
#  array(['99.09330198308074', "['Benny Goodman']",
#         'Applause; Setting-up for BG Small Groups - Live'], dtype='<U661'),
#  array(['99.09327665976075',
#         "['Erik Eriksson', 'Lullabies for Deep Meditation', 'Baby Sweet Dream', 'White Noise Research']",
#         'White Noise - Loopable With No Fade'], dtype='<U661'),
#  array(['99.09306908751921', "['Deep Sleep Music Collective']",
#         'Calm Sounds for Sleep'], dtype='<U661'),
#  array(['99.09276243133242', "['Boards of Canada']", 'Olson'],
#        dtype='<U661'),
#  array(['99.09271527923396', "['Deep Sleep Music Collective']",
#         'The Shore'], dtype='<U661'),
#  array(['99.09250801016934', "['C418']", 'Oxygène'], dtype='<U661'),
#  array(['99.0923705778476', "['Nature Sounds']",
#         'Crickets and Frogs in the Swamp at Night'], dtype='<U661'),
#  array(['99.0923578183403', "['Keira Conlon']", 'Lyrebird'], dtype='<U661'),
#  array(['99.09230857465234', "['Atlas Fret']", '(silent track)'],
#        dtype='<U661'),
#  array(['99.09229027378768', "['Nature Sounds']", 'Zen Rain'],
#        dtype='<U661'),
#  array(['99.09212732617014', "['Nataural']", 'Street Rain'], dtype='<U661'),
#  array(['99.09177943554565', "['Deep Sleep Music Collective']",
#         'Calm Ocean Waves'], dtype='<U661'),
#  array(['99.09174123107454', "['Deep Sleep Music Collective']",
#         'Music to Help You Sleep'], dtype='<U661'),
#  array(['99.09092929502805', "['Robert Schumann', 'Martha Argerich']",
#         'Kinderszenen, Op.15: 12. Kind im Einschlummern'], dtype='<U661'),
#  array(['99.09057015113326', "['Robert Earl Keen']", 'Silent Track'],
#        dtype='<U661'),
#  array(['99.08963257043264', "['Phillipp Vogler']", 'Schwebend'],
#        dtype='<U661'),
#  array(['99.08928524320937', "['Binary One']", 'Returning'], dtype='<U661'),
#  array(['99.0890403932347', "['Deep Sleep Music Collective']",
#         'Awakenings'], dtype='<U661'),
#  array(['99.08887207032693', "['Deep Sleep Music Collective']",
#         'Sleeping Music (Deep Sleep)'], dtype='<U661'),
#  array(['99.08850899661768', "['Zoe Handfield']", 'Andromeda'],
#        dtype='<U661'),
#  array(['99.08845005616473', "['Joel Lyssarides']", 'Silent Agreement'],
#        dtype='<U661'),
#  array(['99.08804902367649', "['Nicholas Hooper']", 'In Noctem'],
#        dtype='<U661'),
#  array(['99.08803834588586', "['Sleep Sounds of Nature']",
#         'Discover Relax with a Thunderstorm'], dtype='<U661'),
#  array(['99.08795374488632', "['Frédéric Chopin', 'Peter Jablonski']",
#         'Waltz No.19 in A minor, Op.posth.'], dtype='<U661'),
#  array(['99.08793685000971', "['Rain Sounds Factory STHLM']",
#         'Rain Sound : Monsun'], dtype='<U661'),
#  array(['99.08749021490642', "['Factorial FX']", 'Soft Rain Pouring'],
#        dtype='<U661'),
#  array(['99.08735449058057', "['Pink Floyd']", 'Round and Around - Live'],
#        dtype='<U661'),
#  array(['99.08728475603247', "['Nature Sounds Nature Music']",
#         'Tropical Storm'], dtype='<U661'),
#  array(['99.08670186867256', "['Thunderstorm Sound Bank']",
#         'Monsun Thunderstorm'], dtype='<U661'),
#  array(['99.08670115596482',
#         "['Camille Saint-Saëns', 'Mischa Maisky', 'Orpheus Chamber Orchestra']",
#         'Le Carnaval des Animaux, R 125: Le cygne'], dtype='<U661'),
#  array(['99.08667101099448',
#         "['Erik Eriksson', 'White Noise for Babies', 'White Noise Baby Sleep']",
#         'Pure Brown Noise - Loopable with no fade'], dtype='<U661'),
#  array(['99.08618461485845', "['Queens of the Stone Age']",
#         'The Real Song For The Deaf'], dtype='<U661'),
#  array(['99.08545572586473', "['Nature Sounds']",
#         'Relaxed Circling Thunderstorm'], dtype='<U661'),
#  array(['99.08493721847', "['James Horner', 'London Symphony Orchestra']",
#         'A Gift Of A Thistle'], dtype='<U661'),
#  array(['99.08490822361475', "['Nature Sounds']",
#         'Refreshing Claps In Thunderstorm'], dtype='<U661'),
#  array(['99.08440622261259', "['Dream Shard']",
#         'Street Noise - Brown Noise'], dtype='<U661'),
#  array(['99.0842071862119', "['Hans Zimmer']",
#         'What Shall We Die For - From "Pirates of the Caribbean: At World\'s End"/Score'],
#        dtype='<U661'),
#  array(['99.08414448642134', "['Jeremy Soule']", 'Dawn'], dtype='<U661'),
#  array(['99.0840818509337', "['Jóhann Jóhannsson']",
#         'A Model of the Universe'], dtype='<U661'),
#  array(['99.08364577232493', "['Sounds of Nature Noise']", 'Rain Storm'],
#        dtype='<U661'),
#  array(['99.08276169248452', "['George Gershwin', 'Frank Braley']",
#         'Song Book: The Man I Love. Slow and in singing style'],
#        dtype='<U661'),
#  array(['99.08168689398542', "['Gabriel Fauré', 'Yo-Yo Ma']",
#         'Après un rêve, Op. 7, No. 1'], dtype='<U661'),
#  array(['99.08139877034553',
#         "['Camille Saint-Saëns', 'Ensemble Musique Oblique']",
#         'Le Carnaval des animaux: Le Carnaval des animaux: Aquarium'],
#        dtype='<U661'),
#  array(['99.08136600669812', "['Jeremy Soule']", 'Secunda'], dtype='<U661'),
#  array(['99.08122299784229', "['Meditation Music Zone']",
#         'Deep Meditation'], dtype='<U661'),
#  array(['99.08117617357317', "['Brian Eno']", 'Signals - Remastered 2005'],
#        dtype='<U661'),
#  array(['99.08097572525492', "['Deep Sleep Music Collective']",
#         'Sand Castles'], dtype='<U661'),
#  array(['99.08096095180595', "['John Williams']", 'Hatching Baby Raptor'],
#        dtype='<U661'),
#  array(['99.08086386980561', "['Biosphere']", 'Poa Alpina'], dtype='<U661'),
#  array(['99.08069011114716', "['Crickets']", 'Cricket Sounds'],
#        dtype='<U661'),
#  array(['99.0806390511787', "['Naturally Recurring']", 'Finding Calmness'],
#        dtype='<U661'),
#  array(['99.08036750377882', "['Rain Recordings']", 'Forest Rain'],
#        dtype='<U661'),
#  array(['99.08026447043876', "['Ludwig van Beethoven', 'Louis Lortie']",
#         'Piano Sonata No. 14 in C-Sharp Minor, Op. 27 No. 2 "Moonlight": I. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['99.08025786224414', "['Black Flag']", 'Depression'], dtype='<U661'),
#  array(['99.08007648038752', "['Lori Dulac']", 'cognizant'], dtype='<U661'),
#  array(['99.07936109288678', "['Thomas Newman']", 'American Beauty'],
#        dtype='<U661'),
#  array(['99.0792005591258', "['Ludwig van Beethoven', 'Paul Lewis']",
#         'Sonata No. 14 "Moonlight" in C-Sharp Minor", Op. 27 No. 2: I. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['99.07917983424555', "['Stereo Outdoor Sampling']",
#         'Quiet Rain in River'], dtype='<U661'),
#  array(['99.07877389825332', "['Deep Sleep Music Collective']",
#         'Soft Piano'], dtype='<U661'),
#  array(['99.07845338585086', "['James Horner']", 'Rooftop Kiss'],
#        dtype='<U661'),
#  array(['99.07834894030113', "['Najma Wallin']", 'Med slutna ögon'],
#        dtype='<U661'),
#  array(['99.07792749044293', "['Elsa Greeve']",
#         'Catastrophically in love with you'], dtype='<U661'),
#  array(['99.07792203565921', "['Granular']", 'White Noise - BP 228 hz'],
#        dtype='<U661'),
#  array(['99.07783641304269', "['Hans Zimmer']", 'Day One'], dtype='<U661'),
#  array(['99.07708096186458', "['Ambiworld']",
#         'Earthy Rain With Rolling Thunder'], dtype='<U661'),
#  array(['99.07644621206776', "['Václav Slezák']",
#         'Trpělivost růže přináší'], dtype='<U661'),
#  array(['99.07630602236512',
#         "['Hans Zimmer', 'Gavin Greenaway', 'The Lyndhurst Orchestra', 'Lisa Gerrard']",
#         'Progeny'], dtype='<U661'),
#  array(['99.07628317123334', "['Deep Sleep Music Collective']",
#         'Music to Sleep By'], dtype='<U661'),
#  array(['99.07626299308619', "['Thomas Newman']", 'Danger of Hell'],
#        dtype='<U661'),
#  array(['99.07485441009813', "['Enigma']", 'Second Chapter'], dtype='<U661'),
#  array(['99.0743295323019', "['Thomas Newman']", 'Any Other Name'],
#        dtype='<U661'),
#  array(['99.07431538613255',
#         "['Hans Zimmer', 'Gavin Greenaway', 'The Lyndhurst Orchestra']",
#         'Earth'], dtype='<U661'),
#  array(['99.07417419464247', "['John Williams']", 'The Patronus Light'],
#        dtype='<U661'),
#  array(['99.07408867313666', "['Gigi Masin']",
#         'The City Lights - Original Mix'], dtype='<U661'),
#  array(['99.07394935889357',
#         "['Camille Saint-Saëns', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Symphony No. 3 in C Minor, Op. 78 "Organ": I. Adagio'],
#        dtype='<U661'),
#  array(['99.07389590173916', "['chillchild']", 'Our Beginning'],
#        dtype='<U661'),
#  array(['99.0735017896201', "['Franz Liszt', 'Joseph Banowetz']",
#         "6 Chants polonais, S. 480: No. 2, Frühling (Wiosna, Spring) [After Chopin's Op. 74]"],
#        dtype='<U661'),
#  array(['99.07321726304895', "['Deep Sleep Music Collective']",
#         'Sleep Meditation'], dtype='<U661'),
#  array(['99.072888656539', "['Max Richter']",
#         'Lamentation For A Lost Life'], dtype='<U661'),
#  array(['99.07247204215749', "['Ofra Haza']",
#         'Cry - The Prince Of Egypt/Soundtrack Version'], dtype='<U661'),
#  array(['99.07231906904087', "['Ferdinando Zetticci']", 'Sonnambulismo'],
#        dtype='<U661'),
#  array(['99.07227428495658', "['Ludwig van Beethoven', 'Louis Lortie']",
#         'Piano Sonata No. 14 in C-Sharp Minor, Op. 27 No. 2 "Moonlight": I. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['99.07226222839257', "['Deep Sleep Music Collective']",
#         'Glowing Sunset'], dtype='<U661'),
#  array(['99.07220772392876', "['Nature Sounds']",
#         'Relaxing Constant Rain Storm with Distant Thunder Sfx'],
#        dtype='<U661'),
#  array(['99.07212700808614', "['Hans Zimmer']", 'No Time for Caution'],
#        dtype='<U661'),
#  array(['99.07205896992122', "['Jeremy Soule']", 'Awake'], dtype='<U661'),
#  array(['99.07205161032486',
#         "['John Williams', 'Itzhak Perlman', 'Boston Symphony Orchestra']",
#         "Theme From Schindler's List (Reprise)"], dtype='<U661'),
#  array(['99.0716747324251', "['Lady Gaga']", 'Chromatica I'], dtype='<U661'),
#  array(['99.07140550584178', "['Claes Nilsson']", 'Beyond Barricades'],
#        dtype='<U661'),
#  array(['99.07140496100259', "['Deep Sleep Music Collective']",
#         'Dark Skies'], dtype='<U661'),
#  array(['99.07130477335144', "['Benny Goodman']",
#         'Applause, Transition to Twenty Years of Jazz - Live'],
#        dtype='<U661'),
#  array(['99.07102727572543', "['Deep Inside']", 'A Glowing Heart'],
#        dtype='<U661'),
#  array(['99.07068436112264', "['Nataural']", 'Dripping Rain'],
#        dtype='<U661'),
#  array(['99.0706384090398', "['Pink Noise Babies']",
#         'Infant Airplane Training Pink Noise - Loopable with No Fade'],
#        dtype='<U661'),
#  array(['99.07049115612439',
#         "['Camille Saint-Saëns', 'Yo-Yo Ma', 'Kathryn Stott']",
#         'The Carnival of the Animals, R. 125: XIII. The Swan (Arr. for Cello and Piano)'],
#        dtype='<U661'),
#  array(['99.07002772078256', "['James Horner']", 'Main Title'],
#        dtype='<U661'),
#  array(['99.06925688030147',
#         "['Wolfgang Amadeus Mozart', 'Sir Neville Marriner', 'Academy of St. Martin in the Fields']",
#         'Requiem, K. 626 - Introitus (Eternal Rest Give To Them, O Lord)'],
#        dtype='<U661'),
#  array(['99.06912403824262', "['Elise Ryen']", 'Kritagya'], dtype='<U661'),
#  array(['99.06912192255699', "['xerLK']", 'Sandy Foam'], dtype='<U661'),
#  array(['99.06820608079384',
#         "['Sergei Prokofiev', 'Slovak Radio Symphony Orchestra', 'Ondrej Lenard']",
#         'Peter and the Wolf, Op. 67: Peter in the meadow'], dtype='<U661'),
#  array(['99.06817766356146', "['Weather Factory']", 'Calm Rain & Thunder'],
#        dtype='<U661'),
#  array(['99.06803640499773', "['Boards of Canada']", 'Wildlife Analysis'],
#        dtype='<U661'),
#  array(['99.06788311371382',
#         "['Sergei Prokofiev', 'Slovak Radio Symphony Orchestra', 'Ondrej Lenard']",
#         'Peter and the Wolf, Op. 67: Peter in the meadow'], dtype='<U661'),
#  array(['99.06782090229386', "['Goldmund']", 'Finding It There'],
#        dtype='<U661'),
#  array(['99.06780721404905', "['R. Carlos Nakai']",
#         'Homage to the Ancient Ones'], dtype='<U661'),
#  array(['99.06769454027453', "['Selective Sounds PTA']", 'Spring Rain'],
#        dtype='<U661'),
#  array(['99.0674269408468', "['Binaural Landscapes']", 'Polar Drone'],
#        dtype='<U661'),
#  array(['99.06741050272888', "['Native American Meditations']",
#         'Thunder Storm'], dtype='<U661'),
#  array(['99.06739546147952', "['Rob Zombie']", 'Perversion 99'],
#        dtype='<U661'),
#  array(['99.06678048869522', "['Shaman']", 'Open Skies'], dtype='<U661'),
#  array(['99.06635131156841', "['Brian Eno']", 'Matta - Remastered 2005'],
#        dtype='<U661'),
#  array(['99.0661927835882', "['Judas Priest']", 'Battle Hymn'],
#        dtype='<U661'),
#  array(['99.06617795302367', "['Béla Bartók', 'Zoltán Kocsis']",
#         '6 Roumanian Folk Dances, BB 68, Sz. 56: 3. In One Spot'],
#        dtype='<U661'),
#  array(['99.06595231470274', "['Deep Sleep Music Collective']", 'Pink Sky'],
#        dtype='<U661'),
#  array(['99.06587397311044',
#         "['Giacomo Puccini', 'Vienna State Opera Chorus', 'Wiener Philharmoniker', 'Herbert von Karajan']",
#         'Madama Butterfly / Act 2: Coro a bocca chiusa (Humming Chorus)'],
#        dtype='<U661'),
#  array(['99.06532451219528', "['Bruce Faulconer']",
#         'Vegeta - Super Saiyan'], dtype='<U661'),
#  array(['99.06516340085282',
#         "['Camille Saint-Saëns', 'Pascal Rogé', 'Cristina Ortiz', 'London Sinfonietta', 'Charles Dutoit']",
#         'Le Carnaval des Animaux, R. 125: 7. Aquarium'], dtype='<U661'),
#  array(['99.0651201938946', "['Black Flag']", 'Thirsty And Miserable'],
#        dtype='<U661'),
#  array(['99.06482757893168', "['Václav Slezák']",
#         'Snesl bych ti modré z nebe'], dtype='<U661'),
#  array(['99.06433054267784', "['Natural White Noise Relaxation']",
#         'Soothing White and Brown Noise: Sounds for Getting a Good Night’s Sleep'],
#        dtype='<U661'),
#  array(['99.06430843385162', "['Ludovico Einaudi']", 'Una mattina'],
#        dtype='<U661'),
#  array(['99.06417950591083', "['Intentional Vibes']", '...There You Are!'],
#        dtype='<U661'),
#  array(['99.06400827360828', "['Nataural']", 'Rain in the Bay'],
#        dtype='<U661'),
#  array(['99.06368442042682', "['Harold Budd', 'Brian Eno']",
#         'Late October - 2005 Digital Remaster'], dtype='<U661'),
#  array(['99.06346311342536', "['Franz Liszt', 'Paul Lewis']",
#         'En rêve, nocturne, S. 207'], dtype='<U661'),
#  array(['99.063006574491',
#         "['Sleep Baby Sleep', 'White Noise Babies', 'White Noise For Baby Sleep', 'Spa Relaxation', 'Spa Relaxation & Spa']",
#         'Soothing Brown Noise Waves'], dtype='<U661'),
#  array(['99.06298100087827', "['Ennio Morricone']", 'Marcia Without Hope'],
#        dtype='<U661'),
#  array(['99.0628016405963', "['Philip Glass']", 'The Poet Acts'],
#        dtype='<U661'),
#  array(['99.06279171206201', "['Donato Manna']", 'For Emmabelle'],
#        dtype='<U661'),
#  array(['99.0622132488894', "['Nataural']",
#         'Thunderstorm by the Waterfall'], dtype='<U661'),
#  array(['99.06182671216116', "['Frédéric Chopin', 'Benjamin Grosvenor']",
#         'Nocturne No. 19 in E Minor, Op. 72, No. 1'], dtype='<U661'),
#  array(['99.06182275557262', "['Deep Sleep Music Collective']", 'Teal Sky'],
#        dtype='<U661'),
#  array(['99.06176974506054', "['The Rain Library']", 'Monsun Rain Fall'],
#        dtype='<U661'),
#  array(['99.06143213600161', "['Benny Goodman']",
#         'Applause for Second Encore - Live'], dtype='<U661'),
#  array(['99.06070294821782', "['Claude Debussy', 'Jean-Yves Thibaudet']",
#         'Rêverie, L. 68: Rêverie'], dtype='<U661'),
#  array(['99.06062207688689', "['Granular']", 'White Noise - BP 153 hz'],
#        dtype='<U661'),
#  array(['99.06060331256307', "['John Field', 'Benjamin Frith']",
#         'Nocturne No. 2 in C Minor'], dtype='<U661'),
#  array(['99.06059685675982', "['Racer X']", 'Scarified'], dtype='<U661'),
#  array(['99.06041481349273', "['Edward Newton']",
#         "I'm in the Mood for Love: I'm in the Mood for Love"],
#        dtype='<U661'),
#  array(['99.06036614713398', "['Rain Storm Sample Library']",
#         'Sleep Easy Rain'], dtype='<U661'),
#  array(['99.0595479037574',
#         "['Hubert Clifford', 'BBC Philharmonic', 'Martyn Brabbins']",
#         '5 English Nursery Tunes: IV. Curly Locks: Andantino'],
#        dtype='<U661'),
#  array(['99.05893381956308', "['Dardan Leistra']", 'Maak me niet wakker'],
#        dtype='<U661'),
#  array(['99.05878427713212', "['Erik Satie', 'Alena Cherny']",
#         'Gnossienne No. 1'], dtype='<U661'),
#  array(['99.05849990084515', "['Agatha Reilly']", 'Fantasazing'],
#        dtype='<U661'),
#  array(['99.05840809309844', "['C418']", 'Excuse'], dtype='<U661'),
#  array(['99.05783643020055', "['Amy Beach', 'Joanne Polk']",
#         'Young Birches, Op. 128, No. 2'], dtype='<U661'),
#  array(['99.0573612430505',
#         "['James Horner', 'London Symphony Orchestra']",
#         'The Secret Wedding'], dtype='<U661'),
#  array(['99.05718494961546', "['David Darling']", 'Darkwood 1'],
#        dtype='<U661'),
#  array(['99.05708213306359', "['Giuseppe Verdi', 'Arturo Toscanini']",
#         "Aida: O tu che sei d'Osiride"], dtype='<U661'),
#  array(['99.0570819601039', "['Vas Bela']", 'Éjszakai'], dtype='<U661'),
#  array(['99.05706143307536', "['Randy Edelman']", 'Parlay'], dtype='<U661'),
#  array(['99.05661378286946', "['Momento']", 'The Destination'],
#        dtype='<U661'),
#  array(['99.05655467520407', "['Moon Laika']", 'Sleep Hibernation'],
#        dtype='<U661'),
#  array(['99.05650309500949', "['Thunderstorm']", 'Rain Sleep'],
#        dtype='<U661'),
#  array(['99.05641740381976', "['Pat Metheny Group']", 'Aprilwind'],
#        dtype='<U661'),
#  array(['99.05637967485099', "['John Williams']", "Fluffy's Harp"],
#        dtype='<U661'),
#  array(['99.05612156801814', "['Natural Sample Makers']", 'Rain Gutter'],
#        dtype='<U661'),
#  array(['99.05606206816925', "['Fizzonaut']", 'Heedful Pink Noise'],
#        dtype='<U661'),
#  array(['99.05587678415891', "['TOOL']", 'Eon Blue Apocalypse'],
#        dtype='<U661'),
#  array(['99.05583770821869', "['Matilda Charpie']", 'Fermez vos yeux'],
#        dtype='<U661'),
#  array(['99.05526496480373',
#         "['Dmitri Shostakovich', 'I Musici de Montréal', 'Maxim Shostakovich']",
#         'Piano Concerto No. 2 in F Major, Op. 102: II. Andante'],
#        dtype='<U661'),
#  array(['99.05498233971501', "['Jon E. Amber']", 'All Is Good'],
#        dtype='<U661'),
#  array(['99.05496484769189', "['Daft Punk']", 'The Son of Flynn'],
#        dtype='<U661'),
#  array(['99.05478616828275', "['Alexandre Desplat']",
#         'Extremely Loud and Incredibly Close'], dtype='<U661'),
#  array(['99.05475699978564', "['Harold Budd', 'Brian Eno']",
#         'Lost In The Humming Air - 2005 Digital Remaster'], dtype='<U661'),
#  array(['99.05460121246023',
#         "['Igor Stravinsky', 'Concertgebouworkest', 'Eduard van Beinum']",
#         'The Firebird - Suite (1919): 1. Introduction'], dtype='<U661'),
#  array(['99.05441057259479', "['Thomas Newman']",
#         'Shawshank Prison - Stoic Theme'], dtype='<U661'),
#  array(['99.05435443871234',
#         "['John Williams', 'London Symphony Orchestra']",
#         "Washington Men / Indy's Home"], dtype='<U661'),
#  array(['99.05407421371343', "['John Williams']", 'The British Grenadiers'],
#        dtype='<U661'),
#  array(['99.05391908133535',
#         "['Maurice Ravel', 'Louis Lortie', 'Hélène Mercier']",
#         "Ma mère l'oye, M. 60 (Version for Piano Duo): III. Laideronnette, imperatrice des pagodes"],
#        dtype='<U661'),
#  array(['99.05374758436207', "['Rosa Løvstrøm']", 'Noctis'], dtype='<U661'),
#  array(['99.05355176199588', "['Nicholas Hooper']",
#         "Dumbledore's Farewell"], dtype='<U661'),
#  array(['99.05300508320983', "['Yue Yan Jen']",
#         '守得云开见月明 - Every cloud has a silver lining'], dtype='<U661'),
#  array(['99.05296926036124', "['Night Poets']", 'Parts Unknown'],
#        dtype='<U661'),
#  array(['99.05261758221548',
#         "['Pyotr Ilyich Tchaikovsky', 'Mariinsky Orchestra', 'Valery Gergiev']",
#         'The Nutcracker, Op.71, TH.14 / Act 2: No. 12b Coffee (Arabian Dance)'],
#        dtype='<U661'),
#  array(['99.05248193026665', "['Nataural']", 'Florida Rain Storm'],
#        dtype='<U661'),
#  array(['99.05248001059378',
#         "['Ludwig van Beethoven', 'Vladimir Ashkenazy']",
#         'Piano Sonata No.14 In C Sharp Minor, Op.27 No.2 -"Moonlight": 1. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['99.0524240017436', "['James Newton Howard', 'Hans Zimmer']",
#         'Eptesicus'], dtype='<U661'),
#  array(['99.05213302975436', "['Sound Library XL']", 'Sleep Rain'],
#        dtype='<U661'),
#  array(['99.05205601706685', "['Shaman']", 'Northern Thunder'],
#        dtype='<U661'),
#  array(['99.05195064988358', "['Donald Beaudoin']", 'Boötes'],
#        dtype='<U661'),
#  array(['99.05163663656215', "['Pola Ris']", 'Imgur'], dtype='<U661'),
#  array(['99.05159318500752', "['Aphex Twin']", 'aisatsana [102]'],
#        dtype='<U661'),
#  array(['99.05118242233965',
#         '[\'Wolfgang Amadeus Mozart\', \'Academy of Ancient Music\', \'Stephen Cleobury\', "Choir of King\'s College, Cambridge"]',
#         'Requiem, K. 626: Lacrimosa'], dtype='<U661'),
#  array(['99.05112728199336',
#         "['James Horner', 'London Symphony Orchestra']",
#         "The Princess Pleads For Wallace's Life"], dtype='<U661'),
#  array(['99.0509919276183', "['Syntropy']", 'Samadhi (Alpha 10 hz)'],
#        dtype='<U661'),
#  array(['99.05035333388304',
#         "['James Horner', 'London Symphony Orchestra']",
#         'For The Love Of A Princess'], dtype='<U661'),
#  array(['99.04986368501984', "['Jeremy Soule']", 'Glory of Cyrodiil'],
#        dtype='<U661'),
#  array(['99.04974628221895', "['Leah Maur']", 'For now'], dtype='<U661'),
#  array(['99.04964526118009', "['LUCHS']", 'Reverie'], dtype='<U661'),
#  array(['99.04954562113052',
#         "['George Frideric Handel', 'Anne Queffélec']",
#         'Menuet en Sol Mineur, Transcription de Wilhem Kempff d’après Le Menuet de la Suite en Si Bémol Majeur No. 1, HWV 434, 1er Cahier'],
#        dtype='<U661'),
#  array(['99.04947347517394', "['Stephan Moccio']", 'Whitby'], dtype='<U661'),
#  array(['99.04918352726288', "['Gustavo Santaolalla', 'Alan Umstead']",
#         'The Choice'], dtype='<U661'),
#  array(['99.04891751714604', "['Pink Floyd']", 'On the Run - Live'],
#        dtype='<U661'),
#  array(['99.04883815500219', "['Charlie Chaplin']", 'Hope Springs Eternal'],
#        dtype='<U661'),
#  array(['99.04882632844009', "['Deep Inside']", 'Painting The Horizon'],
#        dtype='<U661'),
#  array(['99.04864565240021', "['Antologie']", 'Time Travel'], dtype='<U661'),
#  array(['99.04846580281719', "['Matilda Charpie']", 'Crépuscule'],
#        dtype='<U661'),
#  array(['99.0483520234789',
#         "['Claude Debussy', 'Roger Desormière/Choeurs Yvonne Gouverné/Orchestre Symphonique de Paris', 'Roger Desormiere', 'Orchestre Symphonique De Paris']",
#         'Pelléas et Mélisande (2006 Digital Remaster), Act I, Scene One: Introduction'],
#        dtype='<U661'),
#  array(['99.04814661329243', "['O.A.S.']", 'Jupiter Song'], dtype='<U661'),
#  array(['99.04798261485125', "['Nature Sound Collection']",
#         'Rain in the City with Thunder Cracks and Rumbles'], dtype='<U661'),
#  array(['99.04797672538399', "['Zachary Patel']", "Bartram's Garden"],
#        dtype='<U661'),
#  array(['99.04797505813964', "['Harold Budd', 'Brian Eno']",
#         'An Echo Of Night - 2005 Digital Remaster'], dtype='<U661'),
#  array(['99.04789685406213', "['John Foxx', 'Harold Budd']", 'Subtext'],
#        dtype='<U661'),
#  array(['99.04781400720042', "['Clyde Boudreaux']", 'Nepenthe'],
#        dtype='<U661'),
#  array(['99.04763317241508', "['Binaural Beats Sleep']",
#         'Binaural Beats (REM Sleep)'], dtype='<U661'),
#  array(['99.0474780425196', "['Stephan Moccio']", 'Sea Change'],
#        dtype='<U661'),
#  array(['99.04723825477181', "['Jeremy Soule']", 'Dusk at the Market'],
#        dtype='<U661'),
#  array(['99.04712127777013', "['Oneke']", 'Rays of Hope'], dtype='<U661'),
#  array(['99.04699428076164', "['Fabricantes De Lluvia']", 'Lluvia'],
# ...
#  array(['99.00460691434188', "['Aaron Lansing']", 'Naive Spin'],
#        dtype='<U661'),
#  array(['99.00459942376266', "['Coldplay']", 'Life in Technicolor'],
#        dtype='<U661'),
#  array(['99.0045962199532', "['Igor Stravinsky', 'Leopold Stokowski']",
#         'Le sacre du printemps (The Rite of Spring): Part II: The Sacrifice: Introduction (Pagan Night)'],
#        dtype='<U661'),
#  array(['99.00445113206709', "['Jeremy Soule']", 'The Streets of Whiterun'],
#        dtype='<U661'),
#  array(['99.00444997621851', "['Andrew Vasquez']", 'Far From Home'],
#        dtype='<U661'),
#  array(['99.0043874831673', "['Johannes Brahms', 'Idil Biret']",
#         '16 Waltzes, Op. 39: No. 15 In A Flat Major'], dtype='<U661'),
#  array(['99.00437979564613', "['Benny Goodman']",
#         'Applause; Setting Up & Tuning Up for BG Small Groups - Live'],
#        dtype='<U661'),
#  array(['99.0043427709279', "['Roedelius']", 'Brise'], dtype='<U661'),
#  array(['99.00426096911531', "['Mayhem']", 'Funeral Fog'], dtype='<U661'),
#  array(['99.00414801720675', "['Thomas Bergersen', 'Two Steps from Hell']",
#         'Protectors of the Earth'], dtype='<U661'),
#  array(['99.00408485285467', "['Michael Giacchino']",
#         'Ratatouille Main Theme'], dtype='<U661'),
#  array(['99.00407266776243', "['Howard Shore', 'Renée Fleming']",
#         'The Grace of Undómiel (feat. Renée Fleming)'], dtype='<U661'),
#  array(['99.0039552608597',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 1 in D Major "Titan": Ia. Langsam, schleppend'],
#        dtype='<U661'),
#  array(['99.00355646021167', "['Gemma Casimaty']",
#         'Will you be there when I wake up'], dtype='<U661'),
#  array(['99.00354058813829', "['Joe Hisaishi']",
#         'In the Sea of Corruption'], dtype='<U661'),
#  array(['99.00347585240216', "['Brian Eno']",
#         'Under Stars II - Remastered 2005'], dtype='<U661'),
#  array(['99.00345390178133',
#         "['London Symphony Orchestra', 'John Williams']",
#         'Main Theme (From "Jaws")'], dtype='<U661'),
#  array(['99.00335957585804', "['Dean Stance']", "We Don't Talk Anymore"],
#        dtype='<U661'),
#  array(['99.00312637473985', "['Thomasine Robinson']",
#         'It is a Beauteous Evening'], dtype='<U661'),
#  array(['99.00310133309598', "['Ludwig van Beethoven', 'Friedrich Gulda']",
#         'Piano Sonata No.14 in C sharp minor, Op.27 No.2 -"Moonlight": 1. Adagio sostenuto'],
#        dtype='<U661'),
#  array(['99.00304101387775', "['Jeremy Soule']", "Auriel's Ascension"],
#        dtype='<U661'),
#  array(['99.00297238859326', "['Jeremy Soule']", 'Harvest Dawn'],
#        dtype='<U661'),
#  array(['99.00294964903794', "['Jeremy Soule']", 'The City Gates'],
#        dtype='<U661'),
#  array(['99.00294950934273', "['Stephan Moccio']", 'Fracture'],
#        dtype='<U661'),
#  array(['99.00289641490103',
#         "['Erik Satie', 'Claude Debussy', 'Slovak Radio Symphony Orchestra', 'Ondrej Lenard']",
#         '3 Gymnopedies (orch. Debussy): Gymnopedie No. 2'], dtype='<U661'),
#  array(['99.00283828692702', "['Robert Schumann', 'Martha Argerich']",
#         'Kinderszenen, Op. 15: 7. Träumerei'], dtype='<U661'),
#  array(['99.00282436195164', "['Bela Nemeth']", 'This Moment'],
#        dtype='<U661'),
#  array(['99.00278999016156', "['Franz Liszt', 'Jenő Jandó']",
#         'Années de pèlerinage, 1ère année "Suisse", S. 160: No. 2. Au lac de Wallenstadt (At the Lake of Wallenstadt)'],
#        dtype='<U661'),
#  array(['99.00278450720047', "['Dan Fogelberg']", 'Tullamore Dew'],
#        dtype='<U661'),
#  array(['99.00270127348662', "['James Horner']", 'Rose'], dtype='<U661'),
#  array(['99.00268504676363',
#         "['Christoph Willibald Gluck', 'Johannes Brahms', 'Matti Raekallio']",
#         'Iphigenie en Aulide, Act II: Gavotte (arr. J. Brahms)'],
#        dtype='<U661'),
#  array(['99.00268292358543', "['Bathory']", 'In Consperacy with Satan'],
#        dtype='<U661'),
#  array(['99.00268165076038', "['The Surfaris']", 'Wipe Out'], dtype='<U661'),
#  array(['99.0025854181042',
#         "['Pyotr Ilyich Tchaikovsky', 'André Previn', 'London Symphony Orchestra']",
#         'Swan Lake, Op.20, Act I: 7. Subject'], dtype='<U661'),
#  array(['99.00254827338394', "['Devin Townsend']", 'Hyperdrive'],
#        dtype='<U661'),
#  array(['99.00253876945872', "['TOOL']", 'Message To Harry Manback'],
#        dtype='<U661'),
#  array(['99.00246063069109',
#         "['Claude Debussy', 'Roger Desormière/Choeurs Yvonne Gouverné/Orchestre Symphonique de Paris', 'Roger Desormiere', 'Orchestre Symphonique De Paris']",
#         'Pelléas et Mélisande (2006 Digital Remaster), Act III, Scene Three: Interlude'],
#        dtype='<U661'),
#  array(['99.00237005871624', "['Marconi Union']", 'Weightless Part 4'],
#        dtype='<U661'),
#  array(['99.00233038952499', "['Terrorizer']", 'After World Obliteration'],
#        dtype='<U661'),
#  array(['99.00220673117423',
#         "['Leonard Bernstein', 'New York Philharmonic', 'West Side Story Original Broadway Cast']",
#         'Symphonic Dances from "West Side Story" *: Symphonic Dances from West Side Story: Mambo (Meno presto)'],
#        dtype='<U661'),
#  array(['99.00216073117525', "['kwajbasket']", 'The Only Thing Left'],
#        dtype='<U661'),
#  array(['99.00201671648301', "['Harold Budd', 'Brian Eno']",
#         'Their Memories - 2005 Digital Remaster'], dtype='<U661'),
#  array(['99.00201590527293', "['C418']", 'Droopy Likes Your Face'],
#        dtype='<U661'),
#  array(['99.00201424243025', "['Harold Budd', 'Brian Eno']",
#         'Still Return - 2005 Digital Remaster'], dtype='<U661'),
#  array(['99.00196248575597',
#         "['Sergei Rachmaninoff', 'Valery Gergiev', 'Mariinsky Orchestra', 'Denis Matsuev']",
#         'Rhapsody On a Theme of Paganini, Op. 43: V. Variation XVIII'],
#        dtype='<U661'),
#  array(['99.00192254139434', "['Randy Edelman']", 'The Courier'],
#        dtype='<U661'),
#  array(['99.00185021578153', "['Maurice Ravel', 'Bertrand Chamayou']",
#         'Ravel: Pavane pour une infante défunte, M. 19'], dtype='<U661'),
#  array(['99.00173658309245', "['Edvard Grieg', 'Mikhail Pletnev']",
#         'Lyric Pieces Book II, Op.38: 1. Berceuse'], dtype='<U661'),
#  array(['99.00172645815813', "['Berlioz']", 'Isla De Flores'],
#        dtype='<U661'),
#  array(['99.00171515043057', "['John Williams']", 'Granny Wendy'],
#        dtype='<U661'),
#  array(['99.00168779943944',
#         "['The Cinematic Orchestra', 'London Metropolitan Orchestra']",
#         'Arrival of the Birds'], dtype='<U661'),
#  array(['99.00165387010826', "['John Barry']",
#         'Two Socks / The Wolf Theme'], dtype='<U661'),
#  array(['99.001607302917', "['John Williams']",
#         'The Invisibility Cloak and the Library Scene'], dtype='<U661'),
#  array(['99.00159942243563',
#         "['Leonard Bernstein', 'New York Philharmonic']",
#         'Symphonic Dances (From "West Side Story"): X. Finale (Adagio)'],
#        dtype='<U661'),
#  array(['99.00155653788461', "['Robert Schumann', 'Martha Argerich']",
#         'Fantasiestücke, Op. 12: III. Warum?'], dtype='<U661'),
#  array(['99.00154226209048', "['Ahmad Jamal Trio']",
#         'Autumn In New York - Live At The Spotlite Club, Washington, D.C./1958'],
#        dtype='<U661'),
#  array(['99.00153440600074', "['Ted Nugent']",
#         "Stormtroopin' - Live at Seattle Center Coliseum, Seattle, WA - August 1977"],
#        dtype='<U661'),
#  array(['99.00141724563487', "['Keira Barton']", 'Buoyant'], dtype='<U661'),
#  array(['99.00138109927344',
#         "['Edward Elgar', 'Paul Goodwin', 'Osian Ellis', 'English Chamber Orchestra']",
#         'Sospiri, Opus 70'], dtype='<U661'),
#  array(['99.00126072837102', "['Erik Satie', 'Philippe Entremont']",
#         'Gnossienne No. 2'], dtype='<U661'),
#  array(['99.00123754485078', "['Amity Fall']", 'Duende'], dtype='<U661'),
#  array(['99.00121368047', "['Aaron Copland', 'London Symphony Orchestra']",
#         'Appalachian Spring: VIII. Coda. Moderato'], dtype='<U661'),
#  array(['99.00120597333918',
#         "['Gabriel Fauré', 'Slovak Radio Symphony Orchestra', 'Ondrej Lenard']",
#         'Sicilienne, Op. 78 (arr. for orchestra)'], dtype='<U661'),
#  array(['99.0011509798785', "['Hans Zimmer']", 'Mountains'], dtype='<U661'),
#  array(['99.00114450103973', "['Howard Shore']", 'The Shadow of the Past'],
#        dtype='<U661'),
#  array(['99.00113667275879', "['Lavinia Meijer']", 'Due tramonti'],
#        dtype='<U661'),
#  array(['99.00108017011523', "['Connie Francis']", 'My Yiddishe Momme'],
#        dtype='<U661'),
#  array(['99.00100502740743',
#         "['Pyotr Ilyich Tchaikovsky', 'Leonard Bernstein', 'New York Philharmonic']",
#         'The Nutcracker Suite, Op. 71a, TH 35: IIb. Danses caractéristiques. Danse de la fée-dragée'],
#        dtype='<U661'),
#  array(['99.0008404888806', "['Group of Hanunóo children']",
#         'Buzzers, Zithers and Whistles'], dtype='<U661'),
#  array(['99.00069445540474', "['Brian Eno']",
#         'Becalmed - 2004 Digital Remaster'], dtype='<U661'),
#  array(['99.00052556116967', "['NOFX']", 'The Quass'], dtype='<U661'),
#  array(['99.00046360952761', "['Thomas Newman', 'Tom Newton']",
#         'So Was Red'], dtype='<U661'),
#  array(['99.0003785535707',
#         "['Igor Stravinsky', 'Leonard Bernstein', 'London Symphony Orchestra']",
#         'The Rite of Spring (Scenes of Pagan Russia in Two Parts): Mystical Circles of the Young Girls'],
#        dtype='<U661'),
#  array(['99.00034206548905', "['Frédéric Chopin', 'Leif Ove Andsnes']",
#         'Chopin: Impromptu No. 1 in A-Flat Major, Op. 29'], dtype='<U661'),
#  array(['99.00026056323611', "['James Horner']",
#         'The Wedding - Instrumental'], dtype='<U661'),
#  array(['99.00024798916633', "['Enigma']", 'The Voice & The Snake'],
#        dtype='<U661'),
#  array(['99.00017228362488', "['Frédéric Chopin', 'Maurizio Pollini']",
#         'Nocturne No.2 In E Flat, Op.9 No.2'], dtype='<U661'),
#  array(['99.00015002788163', "['Frédéric Chopin', 'Mitsuko Uchida']",
#         'Piano Sonata No.3 in B minor, Op.58: 2. Scherzo (Molto vivace)'],
#        dtype='<U661'),
#  array(['99.00011589409993', "['Vangelis']", 'Tears in Rain'],
#        dtype='<U661'),
#  array(['99.0000794188732', "['James Horner']",
#         'The Gift Of Mortality - Instrumental'], dtype='<U661'),
#  array(['99.00007838030898', "['The 2 Inversions']",
#         'From Shores To Mountains'], dtype='<U661'),
#  array(['98.99989039747871',
#         "['Ludwig van Beethoven', 'Arthur Rubinstein']",
#         'Sonata No. 14 in C-Sharp Minor, Op. 27 No. 2 "Moonlight": I. Adagio sostenuto - Redbook Stereo'],
#        dtype='<U661'),
#  array(['98.99985751076451', "['Santana']", 'Waves Within'], dtype='<U661'),
#  array(['98.99982769800374', "['Alan Menken']",
#         'River\'s Edge - From "Pocahontas"/Score'], dtype='<U661'),
#  array(['98.99968429972328',
#         "['Ralph Vaughan Williams', 'Academy of St. Martin in the Fields', 'Sir Neville Marriner']",
#         'Fantasia on Greensleeves'], dtype='<U661'),
#  array(['98.99948469483942',
#         "['Igor Stravinsky', 'Leonard Bernstein', 'London Symphony Orchestra']",
#         'The Rite of Spring (Scenes of Pagan Russia in two parts): Part Two - The Sacrifice: Mystical Circles of the Young Girls'],
#        dtype='<U661'),
#  array(['98.99948158123958', "['Mr Pillow']", 'Comfortable Night'],
#        dtype='<U661'),
#  array(['98.99946833857513', "['R. Carlos Nakai']", 'Into the Maze'],
#        dtype='<U661'),
#  array(['98.9993995063306', "['John Williams']", 'Mr. Longbottom Flies'],
#        dtype='<U661'),
#  array(['98.99932361037382',
#         "['John Williams', 'Itzhak Perlman', 'Boston Symphony Orchestra']",
#         "Theme From Schindler's List"], dtype='<U661'),
#  array(['98.99930488587081',
#         "['The City of Prague Philharmonic Orchestra']",
#         'The Fellowship (From "The Lord of the Rings: The Fellowship of the Ring ")'],
#        dtype='<U661'),
#  array(['98.99900117710891',
#         "['Aaron Copland', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Billy the Kid Suite: IV. Prairie Night. Card Game at Night'],
#        dtype='<U661'),
#  array(['98.99895582990818', "['Benjamin Gustafsson']", 'Dormiveglia'],
#        dtype='<U661'),
#  array(['98.99894154565546', "['James Newton Howard']",
#         '12 Years Later - From "Treasure Planet"/Score'], dtype='<U661'),
#  array(['98.99885839758313', "['Howard Shore']",
#         'At the Sign of the Prancing Pony'], dtype='<U661'),
#  array(['98.99881508016796',
#         "['Klaus Badelt', 'Lisa Gerrard', 'Gavin Greenaway', 'The Lyndhurst Orchestra']",
#         'Elysium'], dtype='<U661'),
#  array(['98.99877166706986',
#         "['Franz Schubert', 'Mischa Maisky', 'Daria Hovora']",
#         'Schwanengesang, D.957: Ständchen "Leise flehen meine Lieder"'],
#        dtype='<U661'),
#  array(['98.99873164704617', "['Cyrano Brussee']", 'Wacht op mij'],
#        dtype='<U661'),
#  array(['98.99865995779994', "['Drop Nineteens']", 'Delaware'],
#        dtype='<U661'),
#  array(['98.99864371797203', "['Empty Space']", 'Whisperer'], dtype='<U661'),
#  array(['98.99863991195974',
#         "['Igor Stravinsky', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         "Stravinsky: L'oiseau de feu (The Firebird) - Suite (1919): Berceuse (Lullaby)"],
#        dtype='<U661'),
#  array(['98.9986296325579',
#         "['John Williams', 'London Symphony Orchestra']",
#         'Grievous Speaks to Lord Sidious'], dtype='<U661'),
#  array(['98.99857291776927',
#         "['John Williams', 'London Symphony Orchestra']",
#         "Anakin's Betrayal"], dtype='<U661'),
#  array(['98.9985712149294', "['Team Sleep']", 'Blvd. Nights'],
#        dtype='<U661'),
#  array(['98.99839659114805', "['James Horner']", 'The Portrait'],
#        dtype='<U661'),
#  array(['98.99836297987397', "['John Barry']",
#         "If I Know A Song Of Africa (Karen's Theme III) - Out Of Africa/Soundtrack Version"],
#        dtype='<U661'),
#  array(['98.99828564578644', "['Ataraxia']", 'Deja Vu'], dtype='<U661'),
#  array(['98.99827370966558', "['Bernard Herrmann']", 'The Elevator'],
#        dtype='<U661'),
#  array(['98.9981677778958', "['Alan Menken']",
#         'I\'ll Never See Him Again - From "Pocahontas"/Score'],
#        dtype='<U661'),
#  array(['98.99811121192074', "['Misfits', 'Glenn Danzig']", 'She'],
#        dtype='<U661'),
#  array(['98.9980452518184',
#         "['Philip Glass', 'Kronos Quartet', 'Michael Riesman']",
#         'MISHIMA/Closing'], dtype='<U661'),
#  array(['98.99804447043473', "['Robert Tree Cody']", 'Whispering Journeys'],
#        dtype='<U661'),
#  array(['98.998036668901', "['Robert Schumann', 'Murray Perahia']",
#         'Kreisleriana, Op. 16: IV. Sehr langsam'], dtype='<U661'),
#  array(['98.99793876968424',
#         "['Claude Debussy', 'London Symphony Orchestra', 'Michael Tilson Thomas']",
#         'La boîte à joujoux, L. 128: III. La bergerie à vendre'],
#        dtype='<U661'),
#  array(['98.99789674067593',
#         "['Frederick Delius', 'Vernon Handley', 'London Philharmonic Orchestra']",
#         'Delius: 2 Pieces for Small Orchestra: No. 1, On Hearing the First Cuckoo in Spring'],
#        dtype='<U661'),
#  array(['98.99783570035792',
#         "['Max Richter', 'Louisa Fuller', 'Natalia Bonner', 'John Metcalfe', 'Philip Sheppard', 'Chris Worsey']",
#         'On The Nature Of Daylight'], dtype='<U661'),
#  array(['98.99778569733792', "['Mélanie Laurent']", 'Début'], dtype='<U661'),
#  array(['98.99776013389517', "['John Barry']", 'Falling In Love'],
#        dtype='<U661'),
#  array(['98.99775395315373', "['Howard Shore', 'James Galway']",
#         'The Grey Havens (feat. Sir James Galway)'], dtype='<U661'),
#  array(['98.99771990732756',
#         "['George Frideric Handel', 'Leopold Stokowski', 'Bournemouth Symphony Orchestra', 'José Serebrier']",
#         'Messiah, HWV 56, Part I: Pastoral Symphony, "Pifa" (arr. L. Stokowski)'],
#        dtype='<U661'),
#  array(['98.99770147768581', "['Kyuss']", 'Molten Universe'], dtype='<U661'),
#  array(['98.99768879745574', "['Louis and Bebe Barron']",
#         'Once Around Altair'], dtype='<U661'),
#  array(['98.99767804164458', "['Mélanie Laurent']", 'Début'], dtype='<U661'),
#  array(['98.99767714582055', "['Klaus Badelt']", 'The Medallion Calls'],
#        dtype='<U661'),
#  ...]

# %%
playlist_added = ids[sort_indices][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MixlOTc4YjJkNDRiYTNkY2MzYTlmYmM0ZWU4Mjg1NDc0NGVmZWEzMDc4'}
