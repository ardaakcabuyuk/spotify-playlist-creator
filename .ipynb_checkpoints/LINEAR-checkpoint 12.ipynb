# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Toby Keith']", 'Made in America'],
#         ["['K/DA', 'Madison Beer', '(G)I-DLE', 'Jaira Burns', 'League of Legends']",
#          'POP/STARS'],
#         ["['Taylor Swift']", 'Getaway Car'],
#         ...,
#         ["['Mariah Carey']", 'When I Saw You'],
#         ["['Vampire Weekend']", 'Everlasting Arms'],
#         ["['Clay Walker']", 'If I Could Make a Living']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.001

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.c_[predictions, song_info]

# %%
# Out:
# array([94.80331967, 94.74637929, 94.76033456, ..., 94.78830816,
#        94.54114659, 94.8485535 ])

# %%
predicted = predicted[predictions.argsort()][::-1]

# %%
list(predicted)
# Out:
# [array(['94.60532048899577', "['Эрнест Хемингуэй']",
#         'Часть 8.5 & Часть 9.1 - Старик и море'], dtype='<U661'),
#  array(['94.97975336952544', "['Nina Simone']",
#         '22nd Century - Remastered'], dtype='<U661'),
#  array(['95.04793508123169', "['Ellie Goulding']", 'Starry Eyed'],
#        dtype='<U661'),
#  array(['94.62169955895003', "['Erroll Garner']", 'Love In Bloom'],
#        dtype='<U661'),
#  array(['94.7366874537916', "['Orchestra Studio 7']",
#         "'A sunnambula - Instrument and base Version"], dtype='<U661'),
#  array(['94.5218816396344', "['The Four Lads']", 'Somebody Loves Me'],
#        dtype='<U661'),
#  array(['94.39054092945828', "['Ahmet Celal Bey']", 'Ninni'], dtype='<U661'),
#  array(['94.60105508120182', "['Nirvana']", 'Polly'], dtype='<U661'),
#  array(['94.5071877366465', "['Ignacio Corsini']",
#         'Tuyita - Remasterizado'], dtype='<U661'),
#  array(['94.6015390279986', "['Mort Garson']",
#         'Music to Soothe the Savage Snake Plant'], dtype='<U661'),
#  array(['94.65390335565974', "['Xavier Cugat & His Orchestra']",
#         'Rum & Coca Cola (Mambo)'], dtype='<U661'),
#  array(['95.07104847382632', "['Black Uhuru']", 'Great Train Robbery'],
#        dtype='<U661'),
#  array(['95.07738040141012', "['Iration']", 'Time Bomb'], dtype='<U661'),
#  array(['94.75501186159767', "['Sofia Romualdez']", 'Pikit Mata'],
#        dtype='<U661'),
#  array(['94.71175267716278', "['Yuri']", 'Es Ella Mas Que Yo'],
#        dtype='<U661'),
#  array(['94.8182517207269', "['Alejandro Sanz']",
#         'Te lo agradezco, pero no'], dtype='<U661'),
#  array(['94.44349295250625', "['Эрнест Хемингуэй']",
#         'Часть 148.2 - По ком звонит колокол'], dtype='<U661'),
#  array(['94.4060937984181',
#         "['Anita Darian', 'Louise Parker', 'The Merrill Staton Choir']",
#         "Can't Help Lovin' Dat Man"], dtype='<U661'),
#  array(['94.50444285678905', "['Frédéric Chopin', 'Robert Lortat']",
#         '12 Études, Op. 25: No. 9 in G-Flat Major "Butterfly\'s Wings"'],
#        dtype='<U661'),
#  array(['94.84850861668163',
#         "['The Presidents Of The United States Of America']", 'Back Porch'],
#        dtype='<U661'),
#  array(['94.79931717665237', "['The Impressions']", "It's All Right"],
#        dtype='<U661'),
#  array(['94.60936269423763', "['The Kingston Trio']",
#         'The Long Black Rifle'], dtype='<U661'),
#  array(['94.57544827956099', "['Ram Marathe']", 'Haase Bala'],
#        dtype='<U661'),
#  array(['95.10911489562498', "['Bow Wow', 'Ciara']",
#         'Like You (feat. Ciara)'], dtype='<U661'),
#  array(['94.9593278604985',
#         "['Kanye West', 'JAY-Z', 'Rick Ross', 'Nicki Minaj', 'Bon Iver']",
#         'Monster'], dtype='<U661'),
#  array(['95.11406138172732', "['TKA']", 'Louder Than Love'], dtype='<U661'),
#  array(['95.08931786679241', "['Hop Along']", 'Tibetan Pop Stars'],
#        dtype='<U661'),
#  array(['94.70441969513523',
#         "['Red Garland', 'Paul Chambers', 'Art Taylor']",
#         "Stompin' At The Savoy"], dtype='<U661'),
#  array(['94.41323777599342', "['Woody Guthrie']", 'Howdido'], dtype='<U661'),
#  array(['94.90927191543776', "['John Lennon']", 'Watching The Wheels'],
#        dtype='<U661'),
#  array(['94.46395909972027', "['Bob Dylan']",
#         "Bob Dylan's Blues - Witmark Demo - 1963"], dtype='<U661'),
#  array(['95.04826736085263', '["Sinéad O\'Connor"]',
#         'I Want Your (Hands on Me)'], dtype='<U661'),
#  array(['94.75881072161968', "['Arijit Singh']",
#         'Khairiyat (From "Chhichhore")'], dtype='<U661'),
#  array(['94.47788940351813', "['Billie Holiday']", 'This Is Heaven To Me'],
#        dtype='<U661'),
#  array(['94.81187757874491',
#         "['Johannes Brahms', 'Vladimir Horowitz', 'Arturo Toscanini', 'NBC Symphony Orchestra']",
#         'Piano Concerto No. 2 in B-Flat Major, Op. 83: III. Andante'],
#        dtype='<U661'),
#  array(['95.14270180125246', "['Type O Negative']", 'Everything Dies'],
#        dtype='<U661'),
#  array(['94.90607624848012', "['Dan Fogelberg']",
#         "Someone's Been Telling You Stories"], dtype='<U661'),
#  array(['95.12196424188173', "['Elton John']",
#         'All The Girls Love Alice - Remastered 2014'], dtype='<U661'),
#  array(['95.00945138920505',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 4 in G Major: I. Bedächtig, nicht eilen'],
#        dtype='<U661'),
#  array(['94.76740485074917',
#         "['Miles Davis', 'Sonny Rollins', 'Horace Silver', 'Percy Heath', 'Kenny Clarke']",
#         'But Not For Me (Take 2) - RVG Remaster'], dtype='<U661'),
#  array(['94.9266526770623', "['Whitechapel']", 'This Is Exile'],
#        dtype='<U661'),
#  array(['94.68055975380751', "['John Coltrane']", 'Time Was'],
#        dtype='<U661'),
#  array(['94.59687236792692',
#         '[\'Igor Stravinsky\', "L\'Orchestre de la Suisse Romande", \'Ernest Ansermet\']',
#         'Divertimento from "Baiser de la fée": 1. Sinfonia'], dtype='<U661'),
#  array(['94.49972613066193', "['Johnny Cash']", 'Hey Good Lookin'],
#        dtype='<U661'),
#  array(['94.91476896630374', "['T.I.', 'Nelly']",
#         'Get Loose (feat. Nelly)'], dtype='<U661'),
#  array(['95.06651262370796', "['Vicente Fernández']",
#         'Hoy Platique Con Mi Gallo'], dtype='<U661'),
#  array(['94.90416834530272', "['Serge Gainsbourg']", 'Ah Melody'],
#        dtype='<U661'),
#  array(['95.0303318413538', "['Billy Joel']", 'Close to the Borderline'],
#        dtype='<U661'),
#  array(['94.7835212114479', "['Peter Gabriel']", 'Washing Of The Water'],
#        dtype='<U661'),
#  array(['95.05782445532306', "['Oingo Boingo']", 'Islands'], dtype='<U661'),
#  array(['95.00761431503408', "['David Bowie']", 'Blackout - 2017 Remaster'],
#        dtype='<U661'),
#  array(['94.40446534051226', "['Francisco Canaro']",
#         'He Visto Llorar a un Hombre - Instrumental (Remasterizado)'],
#        dtype='<U661'),
#  array(['94.90701409468706', "['Miley Cyrus']", '#GETITRIGHT'],
#        dtype='<U661'),
#  array(['95.19982929421562', "['Cultura Profética']", 'Ideas Nuevas'],
#        dtype='<U661'),
#  array(['94.96200266936025', "['Armor For Sleep']",
#         'Dream to Make Believe'], dtype='<U661'),
#  array(['94.56732289780126', "['Jean Ritchie']",
#         'The Cuckoo - Another Version'], dtype='<U661'),
#  array(['94.78306831355758', "['The Amity Affliction']",
#         "Don't Lean on Me"], dtype='<U661'),
#  array(['94.73762036425896', "['John Barry']",
#         'A Day Together - Somewhere In Time/Soundtrack Version'],
#        dtype='<U661'),
#  array(['94.74100655471021', "['Andrea Bocelli']", 'Con Te Partirò'],
#        dtype='<U661'),
#  array(['94.8516408206416', "['Carpenters']", "You're Enough"],
#        dtype='<U661'),
#  array(['94.98690325904548', "['Kanye West']",
#         'All Of The Lights - Album Version (Edited)'], dtype='<U661'),
#  array(['95.04918313118448', "['Florida Georgia Line']",
#         'Take It Out On Me'], dtype='<U661'),
#  array(['94.56356187462205', "['Billie Holiday']",
#         'One Never Knows, Does One?'], dtype='<U661'),
#  array(['95.13519342515755', "['Little Mix']", 'Touch'], dtype='<U661'),
#  array(['94.67744134231836', "['Cat Power']", 'Cross Bones Style'],
#        dtype='<U661'),
#  array(['94.68915758570057', "['Эрих Мария Ремарк']",
#         'Часть 105.3 - Триумфальная арка'], dtype='<U661'),
#  array(['94.45621032218364', "['Matías Giovannone']", 'Gotas de lluvia'],
#        dtype='<U661'),
#  array(['94.52332093033154', "['Asha Bhosle']", 'Chanda Mama Door Ke'],
#        dtype='<U661'),
#  array(['95.02563229727866', "['Stevie Ray Vaughan']",
#         "Couldn't Stand the Weather"], dtype='<U661'),
#  array(['94.9840403038902', "['Hootie & The Blowfish']",
#         'Let Me Be Your Man'], dtype='<U661'),
#  array(['94.59010063094917', "['Blossom Dearie']", 'Teach Me Tonight'],
#        dtype='<U661'),
#  array(['95.07672387168152', "['The Smiths']",
#         'Death of a Disco Dancer - 2011 Remaster'], dtype='<U661'),
#  array(['94.78619800016463', "['Vicente Fernández']", 'No Me Hagas Menos'],
#        dtype='<U661'),
#  array(['95.0726941736581', "['Los Rieleros Del Norte']",
#         'Golondrina Viajera'], dtype='<U661'),
#  array(['94.82197564598651', "['D Savage']", 'I Know'], dtype='<U661'),
#  array(['94.95032282868429', "['Air']", 'Cherry Blossom Girl'],
#        dtype='<U661'),
#  array(['94.92180518392634', "['Kansas']",
#         'Play the Game Tonight - Remastered'], dtype='<U661'),
#  array(['95.07153433804775', "['Vance Joy']", 'Mess Is Mine'],
#        dtype='<U661'),
#  array(['94.40279629343138', "['Lead Belly']",
#         "In The Evenin' When The Sun Goes Down"], dtype='<U661'),
#  array(['94.4229175998232', "['Billie Holiday']", 'Solitude - Take 1'],
#        dtype='<U661'),
#  array(['94.79711055512081', "['Miles Davis Quintet']",
#         'If I Were A Bell - Rudy Van Gelder Remaster'], dtype='<U661'),
#  array(['95.02142616589782', "['Jackyl']", 'Down On Me'], dtype='<U661'),
#  array(['94.6616509682126', "['Эрнест Хемингуэй']",
#         'Часть 36.3 & Часть 37.1 - По ком звонит колокол'], dtype='<U661'),
#  array(['94.41901200902144', "['N. Maldacea Jr']", 'Carmè carmeè'],
#        dtype='<U661'),
#  array(['94.44140280419084', "['Robert Johnson']", "Ramblin' On My Mind"],
#        dtype='<U661'),
#  array(['94.91929042533181', "['Little Feat']", 'Cold, Cold, Cold'],
#        dtype='<U661'),
#  array(['94.51536412572455', "['George Winston']", 'Road'], dtype='<U661'),
#  array(['94.44141723977152', "['Thelonious Monk']",
#         'Willow Weep For Me - Remastered 1998'], dtype='<U661'),
#  array(['94.56123270811048',
#         "['V. Alexander', 'E. Fitzgerald', 'Ella Fitzgerald']",
#         'A-Tisket A-Tasket - (Live) (Edit)'], dtype='<U661'),
#  array(['95.10862314973873', "['3 Doors Down']", 'Not Enough'],
#        dtype='<U661'),
#  array(['95.22924690564024', "['Massive Attack']", 'Teardrop'],
#        dtype='<U661'),
#  array(['94.82220598701484', "['A Boogie Wit da Hoodie']",
#         'Cinderella Story'], dtype='<U661'),
#  array(['94.58206209142887', "['Jim Reeves']", 'When You Are Gone'],
#        dtype='<U661'),
#  array(['95.01444063433321', "['A Tribe Called Quest']",
#         'Electric Relaxation'], dtype='<U661'),
#  array(['94.71691191209995', "['Johnny Cash']", 'Long Black Veil'],
#        dtype='<U661'),
#  array(['94.66248854885694',
#         "['Richard Himber and his Orchestra', 'Joey Nash']",
#         'If I Had A Million Dollars'], dtype='<U661'),
#  array(['95.16944371057274', "['BJ The Chicago Kid']", "Turnin' Me Up"],
#        dtype='<U661'),
#  array(['94.86848925641492', "['Rockabye Baby!']", 'Bohemian Rhapsody'],
#        dtype='<U661'),
#  array(['94.59118734477211', "['The Hollywood Four Blazes']",
#         "Oh Boy, That's Where My Money Goes"], dtype='<U661'),
#  array(['95.07745202610471', "['SUPER JUNIOR']", 'Mr. Simple'],
#        dtype='<U661'),
#  array(['94.72858105586543', "['Ray Charles']", 'The Right Time'],
#        dtype='<U661'),
#  array(['94.84508264122707', "['CeCe Winans']", 'I Surrender All'],
#        dtype='<U661'),
#  array(['95.04597155127209', "['Blondie']",
#         "(I'm Always Touched By Your) Presence, Dear"], dtype='<U661'),
#  array(['94.68381969879027', "['Johannes Brahms', 'Arturo Toscanini']",
#         'Symphony No. 1 in C Minor, Op. 68: II. Andante sostenuto'],
#        dtype='<U661'),
#  array(['94.91216389339712', "['Nelly']", 'Flap Your Wings'], dtype='<U661'),
#  array(['95.11668574167226', "['Miles Davis Sextet']", "Walkin'"],
#        dtype='<U661'),
#  array(['95.11684390238906', "['Lupe Fiasco']", 'Sunshine'], dtype='<U661'),
#  array(['94.86522244437714',
#         "['Johann Sebastian Bach', 'The English Concert', 'Trevor Pinnock']",
#         'Brandenburg Concerto No.3 In G Major, BWV 1048: 1. (Allegro)'],
#        dtype='<U661'),
#  array(['95.16910688912526', "['The Marshall Tucker Band']",
#         'In My Own Way'], dtype='<U661'),
#  array(['95.32949348821127', "['Miles Davis']", 'Footprints'],
#        dtype='<U661'),
#  array(['94.96460346288427', "['Soda Stereo']",
#         'Sueles Dejarme Solo - Remasterizado 2007'], dtype='<U661'),
#  array(['94.88756870957029',
#         '["\'Legally Blonde\' Ensemble", \'Michael Rupert\']',
#         'Blood in the Water'], dtype='<U661'),
#  array(['95.01830079429656', "['Industria del Amor']", 'Para Qué'],
#        dtype='<U661'),
#  array(['94.42007184083504', "['Francisco Canaro', 'Charlo']",
#         'De a Traicion - Remasterizado'], dtype='<U661'),
#  array(['94.79472077581937', "['Jack Johnson']", 'Gone'], dtype='<U661'),
#  array(['94.49123981044349', "['Alexander Scriabin', 'Vladimir Horowitz']",
#         'Prelude in E Major, Op. 11, No. 9: Andantino - Remastered'],
#        dtype='<U661'),
#  array(['95.06911128786071', "['Dio']", 'Evil Eyes'], dtype='<U661'),
#  array(['95.00046050661908', "['Los Tucanes De Tijuana']",
#         'Porque Me Enamoré De Tí'], dtype='<U661'),
#  array(['94.36621025298072', "['Francisco Canaro', 'Charlo']",
#         'Flor de Belleza - Remasterizado'], dtype='<U661'),
#  array(['94.74691956848366', "['Vince Guaraldi Trio']",
#         'Christmas Time Is Here - Vocal - Album Version'], dtype='<U661'),
#  array(['95.02633166153952', "['Michael Jackson']",
#         'Black or White - Single Version'], dtype='<U661'),
#  array(['94.82677005865986', "['Mozzy', 'King Von', 'G Herbo']",
#         'Body Count (feat. King Von & G Herbo)'], dtype='<U661'),
#  array(['95.07559326968523', "['Wynton Kelly']", 'Temperance'],
#        dtype='<U661'),
#  array(['95.01832643136089', "['Steppenwolf', 'John Kay']",
#         'Who Needs Ya - Single Version'], dtype='<U661'),
#  array(['94.7636246616528', "['The Kinks']", "He's Evil"], dtype='<U661'),
#  array(['94.8645878745327', "['Slim Thug']", 'AJs'], dtype='<U661'),
#  array(['94.7880124601281', "['Bill Evans Trio']",
#         "Gloria's Step - Live - (take 2)"], dtype='<U661'),
#  array(['94.737209017673', "['Roy Eldridge All-Stars']",
#         "Somebody Loves Me - from George White's Scandals Of 1924"],
#        dtype='<U661'),
#  array(['94.83862788600544', "['Metallica']", 'Hardwired'], dtype='<U661'),
#  array(['94.6550445133996', "['The Beatles']",
#         'A Day In The Life - Take 1'], dtype='<U661'),
#  array(['94.63606177515847', "['The Electric Prunes']",
#         'Try Me on for Size'], dtype='<U661'),
#  array(['94.86420937863129', "['José Alfredo Jimenez']",
#         'Cuando Sale la Luna'], dtype='<U661'),
#  array(['95.00714607724248', "['Gipsy Kings']", 'La Dona'], dtype='<U661'),
#  array(['94.96649007509947', "['The Offspring']", 'The Meaning Of Life'],
#        dtype='<U661'),
#  array(['95.03362534587498', "['The Cult']", 'Aphrodisiac Jacket'],
#        dtype='<U661'),
#  array(['94.63514247712894', "['Seweryn Goszczyński']",
#         'Chapter 2.7 - Zamek kaniowski'], dtype='<U661'),
#  array(['94.86452642187223', "['Nirvana']", 'On A Plain'], dtype='<U661'),
#  array(['94.59501228503962', "['Childish Gambino']", 'Death By Numbers'],
#        dtype='<U661'),
#  array(['94.65813690500778', "['Sonia Lopez']", 'Laberinto'], dtype='<U661'),
#  array(['94.6377432021288', "['Milt Jackson']", 'Tahiti'], dtype='<U661'),
#  array(['94.63512870701787',
#         "['Richard Adler', 'Jerry Ross', 'Carol Haney', 'Peter Gennaro', 'Jim Hutchison', 'The Original Broadway Cast Of The Pajama Game', 'Hal Hastings']",
#         'The Pajama Game: Steam Heat'], dtype='<U661'),
#  array(['94.83521501542869', "['Down A.K.A Kilo']", 'Lean Like A Cholo'],
#        dtype='<U661'),
#  array(['94.75372022257743', "['Lester Young']", 'Gigantic Blues'],
#        dtype='<U661'),
#  array(['94.4318750216996', "['Claude Debussy', 'William Kapell']",
#         "Children's Corner: Dr. Gradus ad Parnassum"], dtype='<U661'),
#  array(['94.52518511529571',
#         "['Peter De Rose', 'Paul Robeson Jr.', 'Lawrence Brown', 'Columbia Concert Orchestra']",
#         'Wagon Wheels'], dtype='<U661'),
#  array(['94.83520061287041', "['Young Dolph', 'Key Glock']",
#         'Water on Water on Water'], dtype='<U661'),
#  array(['94.49285157741117', "['Billie Holiday', 'Teddy Wilson']",
#         'My First Impression of You (with Teddy Wilson & His Orchestra) - Take 4'],
#        dtype='<U661'),
#  array(['94.4633777458033', "['Ignacio Corsini']",
#         'Tu Promesa - Remasterizado'], dtype='<U661'),
#  array(['94.55210842961674', "['Dean Martin']", 'Always in My Heart'],
#        dtype='<U661'),
#  array(['94.56315957460721', "['Asha Bhosle']",
#         'Meri Zindagi Pe Na Muskura'], dtype='<U661'),
#  array(['94.9690704458615', "['Jerry Rivera']",
#         'Vuela Muy Alto - Salsa Version'], dtype='<U661'),
#  array(['95.0955231952054', "['Selena Gomez']", 'Birthday'], dtype='<U661'),
#  array(['94.824706622638', "['Eminem']", 'Business'], dtype='<U661'),
#  array(['95.00504352426168', "['ZZ Top']", 'Backdoor Love Affair'],
#        dtype='<U661'),
#  array(['95.07529395817521', "['Glen Campbell']",
#         'Reason To Believe - Remastered 2001'], dtype='<U661'),
#  array(['94.73046960273281', "['Jack Johnson']", 'F-Stop Blues'],
#        dtype='<U661'),
#  array(['94.91682909514994', "['ZZ Top']", 'Groovy Little Hippie Pad'],
#        dtype='<U661'),
#  array(['94.9311055613865', "['Mellow Fellow']", 'Dancing'], dtype='<U661'),
#  array(['94.60673278069488', "['Little Junior Parker']", 'Mystery Train'],
#        dtype='<U661'),
#  array(['95.11134959728837', "['Charly Black', 'Daddy Yankee']",
#         'Gyal You A Party Animal - Remix'], dtype='<U661'),
#  array(['95.2519241668328', "['Ricardo Arjona']", 'Historia de Taxi'],
#        dtype='<U661'),
#  array(['95.05127185716297', "['Sun Ra']", 'Space is the Place'],
#        dtype='<U661'),
#  array(['94.99502316649756', "['Levert']", "Smilin'"], dtype='<U661'),
#  array(['94.72646387532251', "['Эрнест Хемингуэй']",
#         'Часть 65.2 - По ком звонит колокол'], dtype='<U661'),
#  array(['94.79740409403372', "['10,000 Maniacs']", 'Verdi Cries'],
#        dtype='<U661'),
#  array(['94.84726881004578', "['John Coltrane']", 'Tunji'], dtype='<U661'),
#  array(['95.17533227756877', "['James TW']", 'Say Love'], dtype='<U661'),
#  array(['95.00739068191477', "['Pete Fountain']",
#         'Walking Through New Orleans'], dtype='<U661'),
#  array(['94.99373290469637', "['Audien', 'Lady A']", 'Something Better'],
#        dtype='<U661'),
#  array(['95.32133018332354', '[\'Evelyn "Champagne" King\']',
#         'Love Come Down'], dtype='<U661'),
#  array(['95.1034045727509', "['Inspector']", 'Me Estoy Enamorando'],
#        dtype='<U661'),
#  array(['94.70663337727756', "['Maurice Chevalier']", 'The Aristocats'],
#        dtype='<U661'),
#  array(['94.50426479322664',
#         "['Christoph Willibald Gluck', 'Arturo Toscanini']",
#         'Orfeo ed Euridice, Wq. 30: Act II: Scene 2 - Dance of the Blessed Spirits: Dance of the Heroes and Heroines - 1992 Remastered'],
#        dtype='<U661'),
#  array(['95.08540965656785', "['Ismael Rivera']", 'El Nazareno'],
#        dtype='<U661'),
#  array(['95.18636846829608', "['Johnny Gill']", 'My, My, My'],
#        dtype='<U661'),
#  array(['95.05939766725483', '["Alexander O\'Neal"]',
#         '(What Can I Say) To Make You Love Me'], dtype='<U661'),
#  array(['94.92503606105753', "['AFI']", 'Porphyria'], dtype='<U661'),
#  array(['95.06707712799573', "['Bachman-Turner Overdrive']",
#         'Find Out About Love'], dtype='<U661'),
#  array(['94.9810378425956', "['Three Dog Night']", 'Good Feeling'],
#        dtype='<U661'),
#  array(['94.88222466771555', "['Westside Connection']", 'Call 9-1-1'],
#        dtype='<U661'),
#  array(['95.00461611981635', "['Avril Lavigne']", "Nobody's Home"],
#        dtype='<U661'),
#  array(['94.55559509909064', "['Frédéric Chopin', 'William Kapell']",
#         'Mazurka, Op.33, No 4 in B Minor'], dtype='<U661'),
#  array(['94.62628437134302', "['Irma Thomas']", 'While The City Sleeps'],
#        dtype='<U661'),
#  array(['94.73427221082834',
#         "['Gregorian Chant', 'Benedictine Monks of the Abbey of St. Maurice & St. Maur, Clevaux']",
#         'Te Deum - Hymnus (tonus monasticus)'], dtype='<U661'),
#  array(['94.56299048095666', "['Robin Majumdar']", 'Ki Jeno Kahite Chay'],
#        dtype='<U661'),
#  array(['94.49915894400333', "['Mamie Smith']",
#         'The Lure of the South - Live'], dtype='<U661'),
#  array(['94.75148748488576', "['Emile Ford & The Checkmates']", 'Still'],
#        dtype='<U661'),
#  array(['94.86677900976733', "['Jerry Lewis']",
#         'Back In Your Own Back Yard'], dtype='<U661'),
#  array(['94.52593718324427', "['Bill Monroe & His Blue Grass Boys']",
#         'Little Community Church'], dtype='<U661'),
#  array(['94.95530935666457', "['The Smiths']",
#         'Sheila Take a Bow - 2011 Remaster'], dtype='<U661'),
#  array(['94.77810682809323',
#         "['Diddy - Dirty Money', 'Nicki Minaj', 'Rick Ross']",
#         'Hello Good Morning - Remix'], dtype='<U661'),
#  array(['94.45741863869627', "['Liva Weel']", 'Gå med i lunden'],
#        dtype='<U661'),
#  array(['94.5999081000444', "['The Louvin Brothers']", 'Today'],
#        dtype='<U661'),
#  array(['94.85354560472344', "['Eminem']", 'Stepdad'], dtype='<U661'),
#  array(['94.6870933301361', "['Beastie Boys']",
#         'Flute Loop - Remastered 2009'], dtype='<U661'),
#  array(['94.94642222402285', "['Los Terricolas']", 'Te Juro Que Te Amo'],
#        dtype='<U661'),
#  array(['95.03922374510316', "['Hank Williams, Jr.']", "Country Relaxin'"],
#        dtype='<U661'),
#  array(['94.94683708369509', "['John Mellencamp']", 'Golden Gates'],
#        dtype='<U661'),
#  array(['94.54010682527354', "['Ken Elkinson']",
#         'Have Yourself A Merry Little Christmas'], dtype='<U661'),
#  array(['94.41886109182798', "['Henry Mancini']", 'Shades Of Sennett'],
#        dtype='<U661'),
#  array(['94.4478231117832', "['Billie Holiday', 'Teddy Wilson']",
#         "Foolin' Myself (with Teddy Wilson & His Orchestra)"],
#        dtype='<U661'),
#  array(['94.81728499326775', "['Beanie Sigel']", 'Beanie (Mack B****)'],
#        dtype='<U661'),
#  array(['94.84215007745752', "['Mason Williams', 'Mannheim Steamroller']",
#         'Classical Gas'], dtype='<U661'),
#  array(['94.92093795090418', "['Boosie Badazz']", 'Bank Roll'],
#        dtype='<U661'),
#  array(['94.52894095031007', "['Sam Cooke']", 'Mona Lisa'], dtype='<U661'),
#  array(['95.03760847472539', "['Eric Clapton']", 'After Midnight'],
#        dtype='<U661'),
#  array(['94.61247621478921', "['Lata Mangeshkar']",
#         'Sunte The Naam Ham Jinka Bahar Se'], dtype='<U661'),
#  array(['94.77007149742501', "['Miles Davis']",
#         'Summertime - Mono Version'], dtype='<U661'),
#  array(['94.78151408232961', "['Ella Fitzgerald']", "Let's Do It"],
#        dtype='<U661'),
#  array(['94.49537463074259', "['Hot Lips Page']",
#         "Walkin' In A Daze - 78rpm Version"], dtype='<U661'),
#  array(['94.74892441973341', "['Morton Gould', 'Benny Goodman']",
#         'Derivations for Clarinet and Band: II. Contrapuntal Blues'],
#        dtype='<U661'),
#  array(['95.033952539102', "['Vicente Fernández']", 'Las Botas De Charro'],
#        dtype='<U661'),
#  array(['95.07939254105682', "['R.E.M.']", 'Strange'], dtype='<U661'),
#  array(['94.95683917085205', "['Los Palominos']",
#         'La Carta Que Nunca Envie'], dtype='<U661'),
#  array(['94.34070667868836', "['Francisco Canaro']",
#         'El Amor Es Como el Ave - Instrumental (Remasterizado)'],
#        dtype='<U661'),
#  array(['94.80989575079882', "['Demi Lovato']", 'Fix a Heart'],
#        dtype='<U661'),
#  array(['94.65103999903044', "['Ashra']", 'Oasis'], dtype='<U661'),
#  array(['94.47452542789063', "['Surendra']", 'Ab Kaun Hai Mera'],
#        dtype='<U661'),
#  array(['94.95996682841565', "['The Who']",
#         'I Can See For Miles - Incl. Charles Atlas Commercial'],
#        dtype='<U661'),
#  array(['94.59728883142475',
#         "['Frédéric Chopin', 'Guiomar Novaes', 'New York Philharmonic', 'George Szell']",
#         'Concerto pour piano No. 2 in F Minor, Op. 21: II. Larghetto'],
#        dtype='<U661'),
#  array(['94.66814850081406', "['Ellise']", '911'], dtype='<U661'),
#  array(['95.17118093749195', "['Floyd Seivright']", 'Jah Jah Why?'],
#        dtype='<U661'),
#  array(['94.5816399032425', "['Rosemary Clooney', 'Benny Goodman Sextet']",
#         "It's Bad for Me (with The Benny Goodman Sextet)"], dtype='<U661'),
#  array(['94.84882582289572',
#         "['John Williams', 'London Symphony Orchestra']",
#         'The Trip to the Naboo Temple and the Audience with Boss Nass'],
#        dtype='<U661'),
#  array(['94.67920113821053', "['Earl Sweatshirt', 'Vince Staples']",
#         'Burgundy (feat. Vince Staples)'], dtype='<U661'),
#  array(['94.96308481432497', "['Heart']", 'What About Love?'],
#        dtype='<U661'),
#  array(['94.51787125454057', "['Lefty Frizzell']", 'These Hands'],
#        dtype='<U661'),
#  array(['94.75294899811252',
#         "['Gioachino Rossini', 'Roberto Servile', 'Sonia Ganassi', 'Ramón Vargas', 'Angelo Romero', 'Franco de Grandis', 'Ingrid Kertesi', 'Kazmer Sarkany', 'Laszlo Orban', 'Ferenc Korpas', 'Hungarian Radio Chorus', 'Budapest Failoni Chamber Orchestra', 'Will Humburg']",
#         'Il barbiere di Siviglia (The Barber of Seville): Act I No. 2: Cavatina: Largo al factotum della citta'],
#        dtype='<U661'),
#  array(['94.93357997782618',
#         "['A.B. Quintanilla III Y Los Kumbia Kings', 'Fito Olivares']",
#         'Azúcar'], dtype='<U661'),
#  array(['95.06642339712519', "['Lionel Richie']", 'Se La - 12" Version'],
#        dtype='<U661'),
#  array(['94.9924342512701', "['Guaynaa']", 'Rebota'], dtype='<U661'),
#  array(['95.15051373238451', "['Big Country']", 'In A Big Country'],
#        dtype='<U661'),
#  array(['94.30027413314629', "['Red Willie Smith']", 'Salty Dog Blues'],
#        dtype='<U661'),
#  array(['94.94569195981929', "['Romeo Santos', 'Usher']",
#         'Promise (feat. Usher)'], dtype='<U661'),
#  array(['94.93434079341587', '["Oscar D\'León", \'Beny Moré\']',
#         'El Baile del Suavecito'], dtype='<U661'),
#  array(['94.64502151569626', "['Louis Armstrong']",
#         'One Moment Worth Years'], dtype='<U661'),
#  array(['94.68033456849683', "['Matthias Kadar']", 'Oiseaux de passage'],
#        dtype='<U661'),
#  array(['95.24400354013885',
#         "['Susan Sarandon', 'Little Nell', 'Barry Bostwick', 'Peter Hinwood']",
#         'Rose Tint My World'], dtype='<U661'),
#  array(['94.63166128889281', "['Bob Dylan']", "Fixin' to Die"],
#        dtype='<U661'),
#  array(['94.52568525919781', "['Andrés Segovia', 'Alonso Mudarra']",
#         'Romanesca, "Guardame las vacas" (arr. for guitar)'], dtype='<U661'),
#  array(['94.70683758383447', "['Oliver Wallace', 'Peggy Lee']",
#         'What a Dog/He\'s a Tramp - From "Lady and the Tramp"/Soundtrack Version'],
#        dtype='<U661'),
#  array(['94.8865196358292', "['King Geedorah']", 'Krazy World'],
#        dtype='<U661'),
#  array(['94.85118443999559', "['Black Sheep']", 'Similak Child'],
#        dtype='<U661'),
#  array(['94.4691410133395', "['Isaac Albéniz', 'Claudio Arrau']",
#         'Iberia Book I: II. El puerto'], dtype='<U661'),
#  array(['95.09214830213081', "['Corinne Bailey Rae']",
#         'Put Your Records On'], dtype='<U661'),
#  array(['94.50718733776412', "['Al Hirt']",
#         'Green Hornet Theme - From the Greenway-20th Century-Fox TV Series "The Green Hornet"'],
#        dtype='<U661'),
#  array(['94.83671081181043', "['Richard Marx']", 'Now And Forever'],
#        dtype='<U661'),
#  array(['94.5393209512278', "['Dhirendrachandra Mitra']",
#         'Or Nishitha Samadhi'], dtype='<U661'),
#  array(['94.75893682130734', "['Gangsta Pat', 'The Villian']",
#         'Deadly Verses'], dtype='<U661'),
#  array(['95.01348039632258', "['Troop']", 'Spread My Wings'], dtype='<U661'),
#  array(['94.30740854702671', "['Rita Ampatzi']", 'Kokkinoforemeni'],
#        dtype='<U661'),
#  array(['94.99800710308976', "['Killer Dwarfs']", 'Dirty Weapons'],
#        dtype='<U661'),
#  array(['94.80363849610578', "['Dae Dae']", 'Wat U Mean (Aye, Aye, Aye)'],
#        dtype='<U661'),
#  array(['94.81333733003662', "['Led Zeppelin']",
#         'Everybody Makes It Through - In the Light; Early Version / In Transit'],
#        dtype='<U661'),
#  array(['94.75732227585485', "['Otis Redding']",
#         "I'm Coming Home to See About You"], dtype='<U661'),
#  array(['95.12937860211336', "['Egypt Central']", 'Kick Ass'],
#        dtype='<U661'),
#  array(['94.99558774120919', "['The Allman Brothers Band']", 'Revival'],
#        dtype='<U661'),
#  array(['95.00600374606802', "['Billy Idol']", 'All Summer Single'],
#        dtype='<U661'),
#  array(['94.88106606435146', "['Bad Brains']", 'Destroy Babylon'],
#        dtype='<U661'),
#  array(['94.63874736718591', "['Alfred Newman']",
#         'The Day Begins - From “The Song Of Bernadette”'], dtype='<U661'),
#  array(['94.58704618920915', "['Aretha Franklin']", 'Just for You'],
#        dtype='<U661'),
#  array(['94.57906962420628', "['Dean Martin']",
#         'If You Were the Only Girl (In the World)'], dtype='<U661'),
#  array(['94.78093257754956', "['Nelson Riddle']", 'El Dorado (Vocal)'],
#        dtype='<U661'),
#  array(['95.04353699364007', "['Disturbed']", 'Voices'], dtype='<U661'),
#  array(['94.8746541070069', "['Louis Armstrong']",
#         'Hello Brother - Single Version'], dtype='<U661'),
#  array(['94.5547402290378', "['Xrisoula Staurou']", 'Alatsatiani'],
#        dtype='<U661'),
#  array(['95.10733177030536', "['Kenny Loggins']", 'What a Fool Believes'],
#        dtype='<U661'),
#  array(['94.47916717030985', "['Natalino Otto']", "Ore d'oblio"],
#        dtype='<U661'),
#  array(['94.56689151560535',
#         "['Miklós Rózsa', 'Jascha Heifetz', 'Gregor Piatigorsky']",
#         'Sinfonia concertante, Op. 29: Tema con variazioni: Variation I'],
#        dtype='<U661'),
#  array(['94.98204500738379', "['Waylon Jennings']",
#         'Are You Ready for the Country'], dtype='<U661'),
#  array(['94.65636891958381', "['Dean Martin']",
#         'Amor - Digitally Remastered 1998'], dtype='<U661'),
#  array(['94.69051480907055',
#         "['John Coltrane', 'Red Garland', 'Paul Chambers', 'Art Taylor']",
#         'I See Your Face Before Me - RVG Remaster'], dtype='<U661'),
#  array(['94.52785453584809', "['B Jayamma']", 'Mallikaarjuna Palsu'],
#        dtype='<U661'),
#  array(['95.1145572843299', "['Stevie Ray Vaughan']", 'Testify'],
#        dtype='<U661'),
#  array(['95.08202255375888', "['Autechre']", 'Bike'], dtype='<U661'),
#  array(['94.53264741148962',
#         "['Carmen Delia Dipini', 'La Sonora Matancera']", 'Experiencia'],
#        dtype='<U661'),
#  array(['94.83036389695611', "['Anthony Gonzalez', 'Gael Garcia Bernal']",
#         'Un Poco Loco'], dtype='<U661'),
#  array(['94.90060641103422', '["Guns N\' Roses"]', 'Anything Goes'],
#        dtype='<U661'),
#  array(['94.7127077872438', "['Raul Seixas']", 'O Trem Das 7'],
#        dtype='<U661'),
#  array(['94.88739558701317', '["Kimie\'", \'Imua Garza\']',
#         'Make Me Say (feat. Imua Garza)'], dtype='<U661'),
#  array(['94.77024726292707', "['David Bowie']", 'When I Live My Dream'],
#        dtype='<U661'),
#  array(['94.52383792153104', "['Billie Holiday']",
#         "You're Too Lovely to Last - Take 2"], dtype='<U661'),
#  array(['95.0545433379544', "['Ludwig van Beethoven', 'Arturo Toscanini']",
#         'Symphony No. 3 in E-Flat Major, Op. 55 "Eroica": II. Marcia funebre. Adagio assai'],
#        dtype='<U661'),
#  array(['94.81515612548246', "['Captain Beyond']", 'Armworth'],
#        dtype='<U661'),
#  array(['94.76433301330802', "['Elvis Costello & The Attractions']",
#         'Shipbuilding'], dtype='<U661'),
#  array(['94.4905380095859', "['Abbasuddin Ahmed']",
#         'O Bandhu Kajal Bhomara'], dtype='<U661'),
#  array(['94.84905284925175', "['Redman']", "Tonight's Da Night"],
#        dtype='<U661'),
#  array(['94.91771820598807', "['Weather Report']", 'Birdland'],
#        dtype='<U661'),
#  array(['94.9123510358711', "['Misfits', 'Glenn Danzig']", 'Static Age'],
#        dtype='<U661'),
#  array(['94.65799680195524', "['Max Steiner']",
#         'Casablanca (1942) Main Title'], dtype='<U661'),
#  array(['94.91751245030048', "['Misfits']", 'We Bite'], dtype='<U661'),
#  array(['94.86709138052095', "['Sonny Stitt']",
#         'Between The Devil And The Deep Blue Sea'], dtype='<U661'),
#  array(['95.23279200424996', "['Jean-Michel Jarre']", 'Oxygene, Pt. 5'],
#        dtype='<U661'),
#  array(['94.95111457647099', "['Johnny Jenkins', 'Duane Allman']",
#         'Down Along The Cove'], dtype='<U661'),
#  array(['94.99081141007386', "['Alcoholics Anonymous']",
#         'Home Brewmeister'], dtype='<U661'),
#  array(['94.51725544573677', "['Francisco Canaro', 'Carlos Roldán']",
#         'Tres Amigos - Remasterizado'], dtype='<U661'),
#  array(['94.85769322879952', "['P. Mobil']", "Rock 'n' Roll"],
#        dtype='<U661'),
#  array(['94.62609829998308', "['Sibylle Baier']", 'Forget About'],
#        dtype='<U661'),
#  array(['95.02696677041823', "['Lynyrd Skynyrd']",
#         'The Needle And The Spoon - Live / Fox Theater 2001'],
#        dtype='<U661'),
#  array(['94.6900459034576', "['Orchestra Studio 7']",
#         'Scalinatella - Musical base Version'], dtype='<U661'),
#  array(['94.891360795093', "['Aretha Franklin']", 'Spirit in the Dark'],
#        dtype='<U661'),
#  array(['94.8091489754027', "['Red Sovine']", 'Teddy Bear'], dtype='<U661'),
#  array(['94.50754766123802', "['Amirbai Karnataki', 'Nanji']",
#         'Tumne Pyar Sikhaya Mujhko'], dtype='<U661'),
#  array(['94.63564774649235', "['Oscar Brand']", 'I Wanted Wings'],
#        dtype='<U661'),
#  array(['94.79418691450729', "['Bo Diddley']", 'Nursery Rhyme'],
#        dtype='<U661'),
#  array(['94.41897060677184', "['Samuel Barber', 'Vladimir Horowitz']",
#         'Piano Sonata in E-Flat Minor, Op. 26: II. Allegro vivace e leggero'],
#        dtype='<U661'),
#  array(['94.56432095591869', "['Chet Atkins', 'Les Paul']",
#         "It's Been A Long, Long Time"], dtype='<U661'),
#  array(['94.87809697771448', "['Lizzo']", 'Coconut Oil'], dtype='<U661'),
#  array(['94.77742088758363', "['Blessid Union Of Souls']",
#         'Light In Your Eyes'], dtype='<U661'),
#  array(['94.5356169548779', "['Charles Mingus']",
#         'Orange Was The Color Of Her Dress, Then Silk Blues'],
#        dtype='<U661'),
#  array(['94.51489254328357', "['Eddie Heywood']", 'Soft Summer Breeze'],
#        dtype='<U661'),
#  array(['94.51941658149582', "['Peggy Lee']", "'Deed I Do"], dtype='<U661'),
#  array(['95.14188123904172', "['The Doobie Brothers']", 'Here to Love You'],
#        dtype='<U661'),
#  array(['94.5882776418289', "['George Jones']", 'She Once Lived Here'],
#        dtype='<U661'),
#  array(['94.99866734225144', "['Johnny Clegg', 'Savuka']", 'Dela'],
#        dtype='<U661'),
#  array(['96.36375691953167', "['Abdel Halim Hafez']", 'Qareat El Fengan'],
#        dtype='<U661'),
#  array(['94.60874766272654', "['Paul Petersen']", 'My Dad'], dtype='<U661'),
#  array(['94.63675666416586', "['Julie Andrews']", 'My Favorite Things'],
#        dtype='<U661'),
#  array(['95.11363904107469', "['Big Bad Voodoo Daddy']",
#         'Mr. Pinstripe Suit'], dtype='<U661'),
#  array(['94.7584554433675', "['Eagles']",
#         'Certain Kind of Fool - 2013 Remaster'], dtype='<U661'),
#  array(['94.98618932952404', "['Toby Keith']", 'Stays In Mexico'],
#        dtype='<U661'),
#  array(['95.14490521545348', "['Metallica']",
#         'Sad But True (Live in Mexico City)'], dtype='<U661'),
#  array(['95.03988439826809', "['Crowded House']", 'I Walk Away'],
#        dtype='<U661'),
#  array(['94.63443403395624', "['Эрнест Хемингуэй']", 'Часть 55.2 - Фиеста'],
#        dtype='<U661'),
#  array(['94.70514816840254', "['Augustin Lehfuss']", 'Love'], dtype='<U661'),
#  array(['94.97089311999747', "['The Buoys']", 'Timothy'], dtype='<U661'),
#  array(['95.1489645198915', "['Yanni']",
#         'Acroyali / Standing In Motion - Live'], dtype='<U661'),
#  array(['94.58295968654988', "['The Troggs']", 'The Kitty Cat Song'],
#        dtype='<U661'),
#  array(['94.9578544124088', "['Madonna']", 'Express Yourself'],
#        dtype='<U661'),
#  array(['94.73438574024419', "['The Beach Boys']",
#         "I'm Waiting For The Day - Remastered"], dtype='<U661'),
#  array(['94.7365681534958', "['Lil Peep']", 'Gym Class'], dtype='<U661'),
#  array(['94.96376739030246', "['George Strait']",
#         "Love's Gonna Make It Alright"], dtype='<U661'),
#  array(['95.0700623162535', "['blink-182']", 'Bored To Death'],
#        dtype='<U661'),
#  array(['95.1187378751774', "['Big Gigantic', 'GRiZ']", 'Good Times Roll'],
#        dtype='<U661'),
#  array(['94.62585339493631', "['Julie Andrews']",
#         'Prelude / The Sound of Music'], dtype='<U661'),
#  array(['94.81890460010227', "['The Stooges']",
#         'Not Right - 2019 Remaster'], dtype='<U661'),
#  array(['94.79049612846077',
#         "['Sergei Prokofiev', 'Jascha Heifetz', 'Charles Münch', 'Boston Symphony Orchestra']",
#         'Violin Concerto No. 2 in G Minor, Op. 63: I. Allegro moderato'],
#        dtype='<U661'),
#  array(['94.77191041513358', "['Jacky Cheung']", '她來聽我的演唱會'], dtype='<U661'),
#  array(['95.04646382319714', "['Del Shannon']", 'Runaway'], dtype='<U661'),
#  array(['94.58540192522555', "['The Percy Faith Strings']",
#         'Beyond the Sea'], dtype='<U661'),
#  array(['95.04826648787545', "['Metallica']",
#         'Ride The Lightning (Live at The Hollywood Palladium, Los Angeles, CA – March 10th, 1985)'],
#        dtype='<U661'),
#  array(['94.68136118483257', "['Travis Scott']", 'YOSEMITE'], dtype='<U661'),
#  array(['94.97219774708933', "['Dierks Bentley']", 'Every Mile A Memory'],
#        dtype='<U661'),
#  array(['94.4375544892283', "['Suraiya']", 'Door Papiha Bole'],
#        dtype='<U661'),
#  array(['94.7541302107906', "['Ray Conniff']", 'The White Cliffs of Dover'],
#        dtype='<U661'),
#  array(['94.7799274781911', "['Otis Redding']", "I Can't Turn You Loose"],
#        dtype='<U661'),
#  array(['94.69873085146217', "['Chet Baker']", 'These Foolish Things'],
#        dtype='<U661'),
#  array(['94.49190934467394', "['Amália Rodrigues']", 'Ai ai ai, meu irmão'],
#        dtype='<U661'),
#  array(['95.1377186714788', "['Green Day']",
#         '¿Viva La Gloria? (Little Girl)'], dtype='<U661'),
#  array(['94.82290505136648', "['India.Arie']", 'Ready For Love'],
#        dtype='<U661'),
#  array(['94.83552035581168', "['Fatman Scoop', 'The Crooklyn Clan']",
#         'Be Faithful'], dtype='<U661'),
#  array(['94.82670263425504', "['The Merlons']", 'Romanior'], dtype='<U661'),
#  array(['94.80259162525859', "['Black Sabbath']",
#         "She's Gone - 2013 Remaster"], dtype='<U661'),
#  array(['94.95210799891633', "['Cody Johnson']", 'Diamond In My Pocket'],
#        dtype='<U661'),
#  array(['94.68524921595484',
#         "['The Stanley Brothers', 'The Clinch Mountain Boys']",
#         'Daniel Prayed'], dtype='<U661'),
#  array(['94.91865752310805', "['Van Halen']",
#         'Light up the Sky - 2015 Remaster'], dtype='<U661'),
#  array(['95.10771367472184', "['J Balvin']", 'Tranquila'], dtype='<U661'),
#  array(['94.86354081807474', "['Frank Zappa']", "I'm So Cute"],
#        dtype='<U661'),
#  array(['94.73027522782537', "['Rubén Blades']", 'Decisiones'],
#        dtype='<U661'),
#  array(['94.7042247944336',
#         "['Duke Ellington', 'Clark Terry', 'Willie Cook', 'Cat Anderson', 'Ray Nance', 'Quentin Jackson', 'Britt Woodman', 'George Jean', 'Jimmy Hamilton', 'Rick Henderson', 'Russell Procope', 'Paul Gonsalves', 'Harry Carney', 'Wendell Marshall', 'Dave Black']",
#         'Warm Valley'], dtype='<U661'),
#  array(['94.66351087458392', "['Jerry Garcia Band', 'Jerry Garcia']",
#         'Palm Sunday'], dtype='<U661'),
#  array(['94.9439954008578', "['Marvin Gaye']", 'You'], dtype='<U661'),
#  array(['94.95923560065006', "['John Holt', 'The Paragons']",
#         "I've Got to Get Away (aka Man Next Door)"], dtype='<U661'),
#  array(['94.80329785553806', "['James Taylor']", 'Everyday'], dtype='<U661'),
#  array(['94.48437122725386', "['Sister Rosetta Tharpe', 'The Rosettes']",
#         'In The Garden'], dtype='<U661'),
#  array(['94.92170082551416', "['Stevie Nicks']",
#         'Gate and Garden - 2016 Remaster'], dtype='<U661'),
#  array(['94.79921517943546', "['Lil Happy Lil Sad']", 'Let Me Die'],
#        dtype='<U661'),
#  array(['94.45651078135505', "['Dean Martin']", 'Moments Like This'],
#        dtype='<U661'),
#  array(['94.86537045300433', "['JAY-Z']", "The Ruler's Back"],
#        dtype='<U661'),
#  array(['94.61102105888043', "['Sweethearts of the Rodeo']",
#         'Jingle Bell Rock'], dtype='<U661'),
#  array(['94.902253801707', "['Stevie Wonder']", "Send Me Some Lovin'"],
#        dtype='<U661'),
#  array(['94.52170359493539', "['James Gang']", 'Yadig?'], dtype='<U661'),
#  array(['94.78919094252555', "['Ozzy Osbourne']",
#         'You Looking at Me, Looking at You'], dtype='<U661'),
#  array(['94.8307324327737', "['Albert Hammond']", "I'm a Train"],
#        dtype='<U661'),
#  array(['94.40958467590913', "['Francesco Durante', 'Richard Tucker']",
#         'Danza, danza, fanciulla gentile - Voice'], dtype='<U661'),
#  array(['94.85559733081077', "['Bill Evans Trio']",
#         "Gloria's Step - Live - (take 3)"], dtype='<U661'),
#  array(['94.83264227072327', "['Dj Shungi']",
#         'Setlogolo Saga Lekwadu - Jevido Del Cee. Vudoo Mix'],
#        dtype='<U661'),
#  array(['94.71531980815341', "['Ann-Margret']", 'Bye Bye Birdie (Reprise)'],
#        dtype='<U661'),
#  array(['94.5092967014893', "['Tito Schipa']", 'Era De Maggio'],
#        dtype='<U661'),
#  array(['94.91388403186497', "['Culture Club']", "I'll Tumble 4 Ya"],
#        dtype='<U661'),
#  array(['94.96382760080448', "['Michael Bublé']", 'To Love Somebody'],
#        dtype='<U661'),
#  array(['94.86671835576462', "['Trippie Redd', 'DaBaby']", 'Death'],
#        dtype='<U661'),
#  array(['94.99005216442059', "['Conjunto Atardecer']", 'Olvídala'],
#        dtype='<U661'),
#  array(['95.00206546523071', "['Fiona Apple']", 'To Your Love'],
#        dtype='<U661'),
#  array(['94.73917177880625', "['Juvenile', 'Baby']", 'Bounce Back'],
#        dtype='<U661'),
#  array(['94.50492935956623', "['Dinah Washington']", 'Long John Blues'],
#        dtype='<U661'),
#  array(['95.20940434455122', "['Michael Wycoff']", 'Looking Up to You'],
#        dtype='<U661'),
#  array(['94.99931223286463', "['Tally Hall']", 'Cannibal'], dtype='<U661'),
#  array(['94.31539032846632', "['Crowder Brother']", 'Depot Blues'],
#        dtype='<U661'),
#  array(['94.97481502789684', "['The Goo Goo Dolls']", 'Naked'],
#        dtype='<U661'),
#  array(['94.76130893091764', '[\'Bobby "Blue" Bland\']',
#         'Twenty-Four Hour Blues - Single Version'], dtype='<U661'),
#  array(['94.58179003199886', "['Usha Khanna', 'Asha Bhosle']",
#         'Anadi Hai Shikari Dekho Dillagi'], dtype='<U661'),
#  array(['95.13121437302904', "['Spice Girls']", 'Do It'], dtype='<U661'),
#  array(['94.59944769080273', "['張淑美']", '懷鄉的一封信'], dtype='<U661'),
#  array(['94.81071093440305', "['Serge Gainsbourg']", 'Mambo miam miam'],
#        dtype='<U661'),
#  array(['94.98766180736128', "['Kenny Rogers', 'Dottie West']",
#         "Anyone Who Isn't Me Tonight"], dtype='<U661'),
#  array(['95.04311700342416', "['Paula Abdul']", 'Cold Hearted'],
#        dtype='<U661'),
#  array(['94.46721257532316', "['Rafique Gaznavi']",
#         'Aaya Toofan Jaag Bharat Ki Nari'], dtype='<U661'),
#  array(['94.96176409417397', "['Grupo Toppaz De Reynaldo Flores']",
#         'Amándote'], dtype='<U661'),
#  array(['95.12033776585655', "['Nahko And Medicine For The People']",
#         '7 Feathers'], dtype='<U661'),
#  array(['95.11026357141917', "['Lemon Demon']", 'Two Trucks'],
#        dtype='<U661'),
#  array(['94.5720759998371', "['Sam Cooke', 'The Soul Stirrers']",
#         "He's So Wonderful"], dtype='<U661'),
#  array(['95.12893208184437', "['Bachman-Turner Overdrive']", 'Second Hand'],
#        dtype='<U661'),
#  array(['94.94746534122247', "['Jadakiss', 'Styles of The Lox']",
#         'We Gonna Make It - Edit'], dtype='<U661'),
#  array(['95.17279452485515', "['Bobby Brown']", 'Every Little Step'],
#        dtype='<U661'),
#  array(['95.09280904069216', "['Rush']", 'Marathon'], dtype='<U661'),
#  array(['94.70619592156906', "['Daniel Caesar']", 'Little Rowboat'],
#        dtype='<U661'),
#  array(['94.43031047247496', "['Carmen Miranda']",
#         'O Dengo Que A Nega Tem'], dtype='<U661'),
#  array(['94.49674888466642', "['Shamim Akhtar']", 'Raat Suhani Aao Guiyan'],
#        dtype='<U661'),
#  array(['94.8579105540998', "['Little River Band']",
#         'Time For Us - Remastered 2010'], dtype='<U661'),
#  array(['94.99054055518899', "['The Head and the Heart']",
#         'Lost in My Mind'], dtype='<U661'),
#  array(['94.8028204007943', "['6LACK']", 'Nonchalant'], dtype='<U661'),
#  array(['94.77346529572159', "['Diamond Rio']", 'Beautiful Mess'],
#        dtype='<U661'),
#  array(['94.86048624248512', "['Jeff Beck']", "I Ain't Superstitious"],
#        dtype='<U661'),
#  array(['94.84087258461737', "['Greensky Bluegrass']", 'Past My Prime'],
#        dtype='<U661'),
#  array(['94.80353771330441', "['Hacken Lee']", '一生不變'], dtype='<U661'),
#  array(['94.73963190466843', "['LL Cool J']", 'Go Cut Creator Go'],
#        dtype='<U661'),
#  array(['94.83567949765583',
#         "['2Pac', '50 Cent', 'Lloyd Banks', 'Young Buck']",
#         'Loyal To The Game'], dtype='<U661'),
#  array(['94.36500853013064', "['Francesc Macia']",
#         'Els Segadors - Instrumental'], dtype='<U661'),
#  array(['94.95529512418288', "['Oingo Boingo']", "Dead Man's Party"],
#        dtype='<U661'),
#  array(['95.28533194028748', "['Donna Summer']",
#         'She Works Hard For The Money'], dtype='<U661'),
#  array(['95.04383600341667', "['Teriyaki Boyz']",
#         'Tokyo Drift (Fast & Furious) - From "The Fast And The Furious: Tokyo Drift" Soundtrack'],
#        dtype='<U661'),
#  array(['95.04160584768978', "['George Harrison']",
#         "Hari's On Tour (Express) - 2014 Mix"], dtype='<U661'),
#  array(['94.84437849861298', "['Bob Dylan']",
#         "It's All Over Now, Baby Blue - Live at Royal Albert Hall, London, UK - May 26, 1966"],
#        dtype='<U661'),
#  array(['95.04582181249901', "['Gang Starr']", 'You Know My Steez'],
#        dtype='<U661'),
#  array(['94.49141026345913', "['Alan Lomax']", 'Rambling Gambler'],
#        dtype='<U661'),
#  array(['94.38805310123875',
#         "['University of North Texas Symphony Orchestra']", 'แสงเทียน'],
#        dtype='<U661'),
#  array(['94.9322980539725', "['A$AP Rocky']", 'r - Cali'], dtype='<U661'),
#  array(['94.92630268321228', "['Grupo Exterminador']", 'El Padre De Todos'],
#        dtype='<U661'),
#  array(['95.01329930055871', "['Curtis Mayfield']",
#         'I Plan to Stay a Believer - Live @ Bitter End, NYC'],
#        dtype='<U661'),
#  array(['94.41224122211841', "['Sofia Vebo']", 'Παπούτσι από τον τόπο σου'],
#        dtype='<U661'),
#  array(['94.42605058538156', "['Geeta Dutt']",
#         'Phoolon Se Kar Loon Naina Char'], dtype='<U661'),
#  array(['94.32460942822085', "['Louis Armstrong & His Hot Five']",
#         'Cornet Chop Suey'], dtype='<U661'),
#  array(['94.52966444561453', "['Doris Monteiro']", 'Desejo'], dtype='<U661'),
#  array(['95.18499590569606', "['TOOL']", 'Forty Six & 2'], dtype='<U661'),
#  array(['95.15354671395642', "['Santana']",
#         'Black Magic Woman / Gypsy Queen'], dtype='<U661'),
#  array(['94.34229078024109', "['Ed Lang & His Orchestra']",
#         'Bugle Call Rag - 78 rpm Version'], dtype='<U661'),
#  array(['94.469830662052', "['Snehprabha']", 'Mere Bhaiya Ko Meri Umar'],
#        dtype='<U661'),
#  array(['94.91760078903695',
#         "['Tony Jay', 'Tom Hulce', 'Chorus - The Hunchback Of Notre Dame']",
#         "Heaven's Light/Hellfire"], dtype='<U661'),
#  array(['94.87610063880736', "['Twisted Sister']", 'Stay Hungry'],
#        dtype='<U661'),
#  array(['94.49176788138976', "['Roza Eskenazi']", 'H gletzou h Smirnia'],
#        dtype='<U661'),
#  array(['94.48181918733611', "['Gustav Mahler', 'Desi Halban']",
#         'Lieder und Gesänge aus der Jugendzeit: II. Scheiden und meiden'],
#        dtype='<U661'),
#  array(['95.15912994299674', "['The Jackson 5']", 'Hum Along And Dance'],
#        dtype='<U661'),
#  array(['95.11488996759329', "['Lizzo']", 'Water Me'], dtype='<U661'),
#  array(['95.02803053738538', "['Billie Myers']", 'Kiss The Rain'],
#        dtype='<U661'),
#  array(['94.8271335402011', "['Dalida']", 'Love In Portofino'],
#        dtype='<U661'),
#  array(['94.43613665377734', "['Woody Herman & His Orchestra']",
#         'Apple Honey - Alternate Take 2'], dtype='<U661'),
#  array(['95.08743713247785', "['City and Colour']", 'Lover Come Back'],
#        dtype='<U661'),
#  array(['94.84712199976217', "['Beastie Boys']", 'The Move - Remastered'],
#        dtype='<U661'),
#  array(['95.08184395256362', "['Audioslave']", 'Be Yourself'],
#        dtype='<U661'),
#  array(['95.10564905179895', "['Sponge']", 'Molly (Sixteen Candles)'],
#        dtype='<U661'),
#  array(['94.5712763539351', "['George Bernard Shaw']",
#         'Civilization, Russia and North America, The Class War'],
# ...
#        dtype='<U661'),
#  array(['94.48622316725027', "['Franco Ricci']", "Desiderio 'E Sole"],
#        dtype='<U661'),
#  array(['94.70983586599085', "['TNT Band']", 'Sabre Olvidar'],
#        dtype='<U661'),
#  array(['94.93005624734634', "['Crosby, Stills, Nash & Young']",
#         'Slowpoke'], dtype='<U661'),
#  array(['94.92551312176286', "['Christian Death']", 'Dream for Mother'],
#        dtype='<U661'),
#  array(['95.09061388800212', "['Freak Power']",
#         'Turn On, Tune In, Cop Out - Radio Edit'], dtype='<U661'),
#  array(['94.62351141324245', "['Willie Nelson']",
#         'The Last Thing I Needed First Thing This Morning'], dtype='<U661'),
#  array(['94.79361616417532', "['Rick Ross', 'Lil Wayne']", '9 Piece'],
#        dtype='<U661'),
#  array(['94.65857936217286', "['Depeche Mode']",
#         "What's Your Name? - 2006 Remaster"], dtype='<U661'),
#  array(['94.53085908021704', "['Bill Monroe & His Blue Grass Boys']",
#         'I Hear a Sweet Voice Calling'], dtype='<U661'),
#  array(['94.58038756964042', "['Donovan']", 'The Lullaby Of Spring'],
#        dtype='<U661'),
#  array(['95.24586201798132', "['L.T.D.', 'Jeffrey Osborne']",
#         'Back In Love Again'], dtype='<U661'),
#  array(['95.17163560593839', "['Vargas de Tecalitlan']",
#         'Remembranza De Pedro Infante'], dtype='<U661'),
#  array(['94.50738845395115', "['Julie London']",
#         'Remember - 2002 Remaster'], dtype='<U661'),
#  array(['94.8044237863301', "['blink-182']", 'Reckless Abandon'],
#        dtype='<U661'),
#  array(['94.76419651827462', "['The Notorious B.I.G.']",
#         'Miss U - 2014 Remaster'], dtype='<U661'),
#  array(['94.68112364913726', "['VeggieTales']", 'The Water Buffalo Song'],
#        dtype='<U661'),
#  array(['94.60464318390855',
#         "['Ludwig van Beethoven', 'NBC Symphony Orchestra', 'Arturo Toscanini']",
#         'Symphony No. 1 in C Major, Op. 21: IV. Finale (Adagio - Allegro molto e vivace)'],
#        dtype='<U661'),
#  array(['95.04076773949882', "['Justice', 'Simian']",
#         'We Are Your Friends - Justice Vs Simian'], dtype='<U661'),
#  array(['95.30986462096882', "['Violent Femmes']", 'Never Tell'],
#        dtype='<U661'),
#  array(['94.57579269218213', "['Little Brother']",
#         "Lovin' It (feat. Joe Scudda)"], dtype='<U661'),
#  array(['95.11501588710763', "['Townes Van Zandt']", 'Loretta'],
#        dtype='<U661'),
#  array(['94.89136097380528', "['Belle & Sebastian']", 'Expectations'],
#        dtype='<U661'),
#  array(['95.1004412397883', "['Missing Persons']", 'Words'], dtype='<U661'),
#  array(['94.62616155603065', "['Ravi Shankar']",
#         'An Introduction to Indian Music'], dtype='<U661'),
#  array(['94.68664965881793', "['Johnny Mathis']", 'Misty'], dtype='<U661'),
#  array(['95.03186814436405', "['Elvis Costello']", "God's Comic"],
#        dtype='<U661'),
#  array(['95.15393552079661', "['The Pretty Things']", 'I See You'],
#        dtype='<U661'),
#  array(['94.6071674904216', "['Sonny Boy Williamson I']",
#         'I Been Dealing With The Devil'], dtype='<U661'),
#  array(['94.85899423841893',
#         "['Charles-Valentin Alkan', 'Laurent Martin']",
#         '25 Preludes dans tous les tons majeurs et mineurs, Op. 31: No. 8 La chanson de la folle au bord de la mer: Lentement'],
#        dtype='<U661'),
#  array(['94.63394206353986', "['Carmen McRae']", 'Summer Is Gone'],
#        dtype='<U661'),
#  array(['94.96407592713034',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 12'],
#        dtype='<U661'),
#  array(['95.08655827519267', "['Amanaz']", 'Easy Street'], dtype='<U661'),
#  array(['95.0689358310508', "['Pegboard Nerds']", 'Disconnected'],
#        dtype='<U661'),
#  array(['94.69967957239086', "['Fred Mollin']",
#         'Just Around The Riverbend'], dtype='<U661'),
#  array(['94.74673505991784', "['Ludwig van Beethoven', 'Pablo Casals']",
#         'Cello Sonata No. 2 in G Minor, Op. 5 No. 2: III. Rondo. Allegro'],
#        dtype='<U661'),
#  array(['94.94006465422534', "['Johnny Burnette']", 'Little Boy Sad'],
#        dtype='<U661'),
#  array(['94.57076370304499', "['K. Rani', 'Raavu Balasaraswathi']",
#         'Anbe Paavama'], dtype='<U661'),
#  array(['94.88756773531533', "['Bad Meets Evil']", 'The Reunion'],
#        dtype='<U661'),
#  array(['94.93906691175657', "['Hollywood Undead']", 'Everywhere I Go'],
#        dtype='<U661'),
#  array(['95.01088220120621', "['Escape the Fate']", 'Reverse the Curse'],
#        dtype='<U661'),
#  array(['94.88040280644785', "['Baby Huey & The Baby Sitters']",
#         'Mama Get Yourself Together'], dtype='<U661'),
#  array(['94.85008776023196', "['T.I.', 'Chris Brown']",
#         'Private Show (feat. Chris Brown)'], dtype='<U661'),
#  array(['94.75799608548519', "['Frankie Ruiz']", 'Amor De Un Momento'],
#        dtype='<U661'),
#  array(['95.26077554346618', "['Stevie Ray Vaughan']",
#         'Texas Flood - Live at The Spectrum, Montreal; Augusy 17 1984 (Late Show)'],
#        dtype='<U661'),
#  array(['94.9420308307893', "['John Coltrane']", 'Come Rain Or Come Shine'],
#        dtype='<U661'),
#  array(['95.17722236710198', "['The Cure']", "Friday I'm in Love"],
#        dtype='<U661'),
#  array(['94.59803580851973', "['Avelino Muñoz']", 'Patria'], dtype='<U661'),
#  array(['94.69034552147757', "['Teddy Wilson']", 'Honeysuckle Rose'],
#        dtype='<U661'),
#  array(['95.0077349480291', "['Sabrina Claudio']", 'Confidently Lost'],
#        dtype='<U661'),
#  array(['94.71879603488999', "['Louis Armstrong']",
#         "Struttin' With Some Barbecue - Live"], dtype='<U661'),
#  array(['95.06753185152633', "['Twenty One Pilots']", 'Cancer'],
#        dtype='<U661'),
#  array(['94.51256091323756', "['Billy Joel']", 'Got to Begin Again'],
#        dtype='<U661'),
#  array(['95.10393347828258', "['Seal']", 'Fly Like an Eagle'],
#        dtype='<U661'),
#  array(['94.89610201891779', "['Voz De Mando']",
#         'Comandos Del M.P (500 Balazos)'], dtype='<U661'),
#  array(['94.53025492403272', "['Billy Joel']", 'Why Judy Why'],
#        dtype='<U661'),
#  array(['94.7082838059125', "['Gheorghe Zamfir']", 'Theme From Limelight'],
#        dtype='<U661'),
#  array(['94.91934946959461', "['Leonard Bernstein']",
#         'On The Town: Opening: New York, New York - Excerpt'],
#        dtype='<U661'),
#  array(['94.85058357914792', "['Daft Punk']", 'Disc Wars'], dtype='<U661'),
#  array(['94.86530279466352', "['The Sweet Remains']",
#         'Moving in Slow Motion'], dtype='<U661'),
#  array(['95.10360715357649', "['Pierce The Veil', 'Lindsey Stamey']",
#         'Hold On Till May'], dtype='<U661'),
#  array(['94.51759235958579', "['Gaetano Donizetti', 'Fausto Cleva']",
#         'Lucia di Lamermoor: Act II: Scene 2: Appressati, Lucia... Il pallor, funesto, orrendo'],
#        dtype='<U661'),
#  array(['94.66072638221084',
#         "['Jean Sibelius', 'Jascha Heifetz', 'Walter Hendl']",
#         'Violin Concerto in D Minor, Op. 47: III. Allegro, ma non tanto'],
#        dtype='<U661'),
#  array(['94.7758769669589', "['Wings']",
#         'Richard Cory - Live / Remastered'], dtype='<U661'),
#  array(['94.60540299320452',
#         "['Enrique Granados', 'Vicente Gomez', 'Guillermo Gomez']",
#         'Danza Espanola No. 5: Playera'], dtype='<U661'),
#  array(['94.66153028928103', "['Andy Williams']", 'Misty'], dtype='<U661'),
#  array(['94.54573768883145', "['David Foster']", 'Georgetown'],
#        dtype='<U661'),
#  array(['94.92755048796216', "['Ricky Nelson']", 'Stood Up - Remastered'],
#        dtype='<U661'),
#  array(['94.74925063926528', "['Эрнест Хемингуэй']",
#         'Часть 10.5 - Прощай оружие'], dtype='<U661'),
#  array(['94.54941812007317', "['Talat Mahmood']",
#         'Ae Mere Dil Kahin Aur Chal'], dtype='<U661'),
#  array(['94.61474911399611', "['D. Brubeck', 'Dave Brubeck']",
#         'The Golden Horn'], dtype='<U661'),
#  array(['94.74812511955167',
#         '[\'Maury Yeston\', "Brian D\'Arcy James", \'Kevin Stites\']',
#         "Barrett's Song"], dtype='<U661'),
#  array(['94.92526721954616', "['Buck Owens']", "Love's Gonna Live Here"],
#        dtype='<U661'),
#  array(['94.57455209430806', "['XXXTENTACION']", 'Revenge'], dtype='<U661'),
#  array(['95.28490019467506', "['Pink Floyd']", 'Money - Live'],
#        dtype='<U661'),
#  array(['95.05770786629313', "['Neil Diamond']",
#         'Summerlove - From "The Jazz Singer" Soundtrack'], dtype='<U661'),
#  array(['94.6201677959613', "['The Supremes']", 'Long Gone Lover'],
#        dtype='<U661'),
#  array(['95.09216503076995', "['Smile Empty Soul']", 'Bottom of a Bottle'],
#        dtype='<U661'),
#  array(['94.36645432047611',
#         "['Giovanni Gabrieli', 'The Philadelphia Brass Ensemble', 'The Chicago Brass Ensemble', 'Richard Burgin']",
#         'Canzon Septimi Toni No. 2'], dtype='<U661'),
#  array(['94.58534795961653', "['The Ventures']", 'Moon Child'],
#        dtype='<U661'),
#  array(['94.97569873935102', "['Grupo Galé']", 'Ven a Medellín'],
#        dtype='<U661'),
#  array(['94.74152701222191', "['Sonny Rollins']", 'Rain Check'],
#        dtype='<U661'),
#  array(['94.95191407547348', "['Alpha Blondy']", 'Sweet Fanta Diallo'],
#        dtype='<U661'),
#  array(['94.58628782392418', "['Jimmy Scott']", 'An Evening In Paradise'],
#        dtype='<U661'),
#  array(['94.99245241089363', "['Los Inquietos Del Norte']", 'Tu Direccion'],
#        dtype='<U661'),
#  array(['95.12792245001104',
#         "['Justin Timberlake', 'Anna Kendrick', 'Earth, Wind & Fire']",
#         'September - from DreamWorks Animation\'s "TROLLS"'], dtype='<U661'),
#  array(['94.63917693275462', "['Jackie Gleason']", 'Boy'], dtype='<U661'),
#  array(['94.7463296468396', "['Eminem']", 'Ass Like That'], dtype='<U661'),
#  array(['94.6635531475513', "['Jorge Lavat']", 'Desiderata'], dtype='<U661'),
#  array(['94.62147204522304', "['Domenico Scarlatti', 'Julian Bream']",
#         'Sonata in E Minor, K. 11'], dtype='<U661'),
#  array(['94.9803561612649', "['Tina Turner']", 'Better Be Good to Me'],
#        dtype='<U661'),
#  array(['94.5881337450035',
#         "['Jerome Kern', 'Barbara Cook', 'Stephen Douglass', 'Franz Allers']",
#         'You Are Love (from "Show Boat")'], dtype='<U661'),
#  array(['94.45293662949726', "['Stellakis Perpiniadis']",
#         'H Lilh h skantaliara'], dtype='<U661'),
#  array(['94.48105688821332', "['Ignacio Corsini']",
#         'Canta Claro - Remasterizado'], dtype='<U661'),
#  array(['94.44120895769609', "['Ignacio Corsini']",
#         'Artículo de Lujo - Remasterizado'], dtype='<U661'),
#  array(['94.95023643383256',
#         "['Ty Dolla $ign', 'Nathaniel Alford', 'Twice As Nice', 'Lil Wayne', 'The-Dream']",
#         'Love U Better (feat. Lil Wayne & The-Dream)'], dtype='<U661'),
#  array(['94.55909553388713', "['The Cadillacs']", "That's All I Need"],
#        dtype='<U661'),
#  array(['95.21818675502725', "['The Future Sound Of London']",
#         'Papua New Guinea'], dtype='<U661'),
#  array(['95.18143591306725', "['Azucar Moreno']", 'Ven Devórame Otra Vez'],
#        dtype='<U661'),
#  array(['94.48661445239097', "['The Ventures']", 'Lolita Ya Ya'],
#        dtype='<U661'),
#  array(['95.01001128896506', "['John Denver']",
#         'Matthew - Live at the Universal Amphitheatre, Los Angeles, CA - August/September 1974'],
#        dtype='<U661'),
#  array(['94.93017889989382', "['Counting Crows']",
#         'St. Robinson In His Cadillac Dream'], dtype='<U661'),
#  array(['94.7029355733118',
#         "['Anthony Ramos', 'Okieriete Onaodowan', 'Daveed Diggs', 'Lin-Manuel Miranda', 'Leslie Odom Jr.']",
#         'The Story of Tonight - Reprise'], dtype='<U661'),
#  array(['94.81071760557944', "['Les & Larry Elgart']", 'Meditation'],
#        dtype='<U661'),
#  array(['94.58211993094616', "['Max Steiner']",
#         'Main Title - Gone With the Wind'], dtype='<U661'),
#  array(['94.86348779914222', "['Gloria Estefan']", 'Hoy - Spanish Version'],
#        dtype='<U661'),
#  array(['95.1012448446074', "['Robert Earl Keen']",
#         'The Road Goes On Forever'], dtype='<U661'),
#  array(['95.18530227650706', "['Arctic Monkeys']", 'My Propeller'],
#        dtype='<U661'),
#  array(['94.65617703811046',
#         "['Leslie Caron', 'Betty Wand', 'Hermione Gingold', 'Louis Jourdan']",
#         'The Night They Invented Champagne'], dtype='<U661'),
#  array(['95.11582352027858', "['Ministry']", 'All Day Remix'],
#        dtype='<U661'),
#  array(['94.5487419915883', "['Frankie Valli & The Four Seasons']",
#         "Ain't That a Shame"], dtype='<U661'),
#  array(['94.92891925640006', "['Ready For The World']", 'Love You Down'],
#        dtype='<U661'),
#  array(['94.65321239763436', "['Bob Dylan']",
#         'Poor Boy Blues - Witmark Demo - 1962'], dtype='<U661'),
#  array(['94.93040234452438', "['Selena y los Dinos']",
#         'La Llamada - Remastered'], dtype='<U661'),
#  array(['94.81740459586322', "['Niall Horan']", 'Put A Little Love On Me'],
#        dtype='<U661'),
#  array(['94.9927317573041', "['The Rolling Stones']",
#         '2000 Man - Remastered 2017 / Stereo'], dtype='<U661'),
#  array(['94.61809016595264', "['Fiorello! - Original Broadway Cast']",
#         'When Did I Fall In Love'], dtype='<U661'),
#  array(['94.97966301826116', "['The Grass Roots']", 'Sooner Or Later'],
#        dtype='<U661'),
#  array(['94.59404650882152', "['Ennio Morricone']", 'Love Theme'],
#        dtype='<U661'),
#  array(['94.81680092845495', "['Barbara Mandrell']",
#         'No Walls No Ceilings No Floors'], dtype='<U661'),
#  array(['94.87687533813158', "['Valentín Elizalde']", 'Y Se Parece A Ti'],
#        dtype='<U661'),
#  array(['94.96267903056074', "['Cassidy', 'Mashonda']",
#         'Get No Better (feat. Mashonda)'], dtype='<U661'),
#  array(['94.44540698850243', "['Oscar Peterson']", 'Pick Yourself Up'],
#        dtype='<U661'),
#  array(['94.62705043181053',
#         "['Wolfgang Amadeus Mozart', 'Maria Cebotari', 'London Philharmonic Orchestra', 'Josef Krips']",
#         'Le nozze di Figaro, K. 492 (Excerpts): E Susanna non vien! - Dove sono i bei momenti'],
#        dtype='<U661'),
#  array(['95.20846295715864', "['Alcoholics Anonymous']",
#         'He Thought He Could Drink Like A Gentleman'], dtype='<U661'),
#  array(['94.8741532258655', "['Peter Murphy']",
#         "Marlene Dietrich's Favourite Poem"], dtype='<U661'),
#  array(['95.0470940190169', "['Lord Tariq', 'Peter Gunz']",
#         'Déjà Vu (Uptown Baby)'], dtype='<U661'),
#  array(['95.0642258112089', "['Burning Spear']", 'The Sun'], dtype='<U661'),
#  array(['94.48500823798504',
#         "['Giorgos Papasideris', 'Xar. Margelis-klarino']", 'Dafnes'],
#        dtype='<U661'),
#  array(['94.73447455010478', "['Amnesty']", 'Liberty'], dtype='<U661'),
#  array(['95.20823380659661', "['Stevie Wonder']", "Isn't She Lovely"],
#        dtype='<U661'),
#  array(['94.3411263318623', "['Unspecified']", 'Sea Animals - Manatee'],
#        dtype='<U661'),
#  array(['94.87192545524782',
#         "['Ludwig van Beethoven', 'Tilla Briem', 'Elisabeth Höngen', 'Peter Anders', 'Rudolf Watzke', 'Choeur Bruno Kittel', 'Berliner Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": I. Allegro ma non troppo, un poco maestoso'],
#        dtype='<U661'),
#  array(['94.66981025834633', "['ZZ Top']", 'Chevrolet'], dtype='<U661'),
#  array(['94.5741632366614', "['Little Richard']", 'Ready Teddy'],
#        dtype='<U661'),
#  array(['94.88005302185368', "['Mary Wells']", "She Don't Love You"],
#        dtype='<U661'),
#  array(['94.76230951964303', "['The Beach Boys']",
#         'Then I Kissed Her - Remastered'], dtype='<U661'),
#  array(['94.58455713086774',
#         "['Dizzy Gillespie', 'Charlie Parker', 'Thelonious Monk', 'Curly Russell', 'Buddy Rich']",
#         'Leap Frog - Take 1 / Incomplete'], dtype='<U661'),
#  array(['95.17002315033547', "['Nazia Hassan']", 'Disco Deewane'],
#        dtype='<U661'),
#  array(['94.95631856367037', "['The Yardbirds']",
#         'Tinker Tailor - 2002 Stereo Mix; 2003 Remaster'], dtype='<U661'),
#  array(['95.17004787880145', "['Celly Cel']", 'Heat 4 Yo Azz'],
#        dtype='<U661'),
#  array(['94.6938510925405', "['Zofia Dromlewiczowa']",
#         'Chapter 3.11 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['95.12478984090806', "['Newsboys']",
#         "God's Not Dead (Like A Lion)"], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
