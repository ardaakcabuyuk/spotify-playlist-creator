# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=5001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Imagine Dragons']", 'Thunder'],
#         ["['Rachel Platten']", 'Fight Song'],
#         ["['Sia']", 'Together'],
#         ...,
#         ["['Taylor Swift']", 'Long Live'],
#         ["['Sam Smith']", 'Money On My Mind'],
#         ["['Foo Fighters']", 'Generator']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.01

# %%
relevance
# Out:
# 49.999999999984375

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.column_stack((predictions, song_info[:,0], song_info[:,1]))

# %%
sort_indices = np.argsort(predictions)[::-1]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[sort_indices][::-1]

# %%
list(predicted)
# Out:
# [array(['23.548417224081582', "['Sound Dreamer']",
#         'Brown Noise - 90 Minutes'], dtype='<U661'),
#  array(['30.999281280710655', "['Sounds for Life']",
#         'Brown Noise for Sleep'], dtype='<U661'),
#  array(['32.02900984258704', "['Chuck Riley']", 'Aladdin - Storyteller'],
#        dtype='<U661'),
#  array(['36.63775820341914', "['Ocean Waves For Sleep']",
#         'Ocean Waves for Sleep'], dtype='<U661'),
#  array(['36.64992389551224', "['Ocean Sounds']", 'Ocean Waves Sounds'],
#        dtype='<U661'),
#  array(['37.04561848071103', "['Lightning, Thunder and Rain Storm']",
#         'Midnight Thunderstorm Part 2'], dtype='<U661'),
#  array(['37.22664395790959', "['Franklin Delano Roosevelt']",
#         'Address to Congress on Yalta - 03 01 1945'], dtype='<U661'),
#  array(['38.13707050816146', "['Sleep']", 'Dopesmoker'], dtype='<U661'),
#  array(['38.60261291059352', "['Environments']",
#         'The Psychologically Ultimate Seashore (16 rpm)'], dtype='<U661'),
#  array(['38.770379268801015', "['Umm Kulthum']", 'Enta Oumry'],
#        dtype='<U661'),
#  array(['38.863900548735174', "['Umm Kulthum']", 'Naheg El Berda'],
#        dtype='<U661'),
#  array(['39.46474844432346', "['President Franklin Delano Roosevelt']",
#         'State of the Union Address (January 7, 1943)'], dtype='<U661'),
#  array(['39.7049120448539', "['Brian Eno']",
#         'Thursday Afternoon - 2005 Digital Remaster'], dtype='<U661'),
#  array(['40.75868693912992', "['Gaston Bachelard']",
#         'Les dormeurs éveillés. La rêverie lucide'], dtype='<U661'),
#  array(['41.05997784489318', "['Christopher Plummer']",
#         'The Many Adventures of Winnie the Pooh'], dtype='<U661'),
#  array(['41.766682040111334', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #12 - On the Recession (April 14, 1938)'],
#        dtype='<U661'),
#  array(['42.650565862780965', "['Merian C. Cooper']", 'King Kong'],
#        dtype='<U661'),
#  array(['43.377062858626616', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #20 - On the Progress of the War (February 23, 1942)'],
#        dtype='<U661'),
#  array(['43.38580441178168', "['Franklin Delano Roosevelt']",
#         'On the Progress of the War - 02 23 1942'], dtype='<U661'),
#  array(['43.8844109097339', "['Umm Kulthum']", 'Ahl El Hawa'],
#        dtype='<U661'),
#  array(['43.90043290613275', "['Umm Kulthum']", 'Yalle Kan Yshgek Anene'],
#        dtype='<U661'),
#  array(['44.36673897902179', "['Portugallien']", 'Anslag'], dtype='<U661'),
#  array(['45.02486581184816', "['Umm Kulthum']", 'Halet Layale El Qamar'],
#        dtype='<U661'),
#  array(['45.346040760946224', "['Franklin Delano Roosevelt']",
#         "Response to Hitler's invasions - 05 26 1940"], dtype='<U661'),
#  array(['45.73949943702351', "['Franklin Delano Roosevelt']",
#         'Speech at Madison Square Garden - 10 31 1936'], dtype='<U661'),
#  array(['45.84928813936789', "['Alcoholics Anonymous']",
#         'He Had To Be Shown'], dtype='<U661'),
#  array(['46.132520345402924', "['Franklin Delano Roosevelt']",
#         'On the Fall of Mussolini - 07 28 1943'], dtype='<U661'),
#  array(['46.48831053377176', "['Franklin Delano Roosevelt']",
#         'Purge of the Democratic Party - 06 24 1938'], dtype='<U661'),
#  array(['46.56687628751547', "['Danny Kaye']",
#         'Opening Night of Playhouse'], dtype='<U661'),
#  array(['46.71458122878542', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #13 - On Purging the Democratic Party (June 24, 1938)'],
#        dtype='<U661'),
#  array(['46.831414043883775', "['Umm Kulthum']", 'Ghana El Rabea'],
#        dtype='<U661'),
#  array(['47.101386537577085',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 3 - Dialogues'], dtype='<U661'),
#  array(['47.11172324780489', "['Danny Kaye']",
#         'Danny Returns from New York'], dtype='<U661'),
#  array(['47.18738704827156', "['Alcoholics Anonymous']",
#         'Our Southern Friend'], dtype='<U661'),
#  array(['47.2424688179033', "['Danny Kaye']", 'Benny Rubin'], dtype='<U661'),
#  array(['47.31239192200091', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #27 - On the Tehran and Cairo Conferences (December 24, 1943)'],
#        dtype='<U661'),
#  array(['47.361836204229576', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #28 - On the State of the Union (January 11, 1944)'],
#        dtype='<U661'),
#  array(['47.436969454855216', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #6 - On Government and Capitalism (September 30, 1934)'],
#        dtype='<U661'),
#  array(['48.13128912816933', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #23 - On the Home Front (October 12, 1942)'],
#        dtype='<U661'),
#  array(['48.34990899974599', "['Danny Kaye']", 'His Own Guest Star'],
#        dtype='<U661'),
#  array(['48.754831971846656', "['Moses Hadas']",
#         'Introduction / Books I-III / Book IV'], dtype='<U661'),
#  array(['48.85881916808576', "['Danny Kaye']",
#         'The Great Donivitch Kayeoff'], dtype='<U661'),
#  array(['48.9548627025765',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 1 - Dialogues'], dtype='<U661'),
#  array(['48.96530622674078', "['Alcoholics Anonymous']", "Joe's Woes"],
#        dtype='<U661'),
#  array(['49.0297534235674', "['Isaac Asimov']",
#         'Pebble In The Sky (Radio Drama)'], dtype='<U661'),
#  array(['49.080864511361504', "['Franklin Delano Roosevelt']",
#         'On the war with Japan - 12 09 1941'], dtype='<U661'),
#  array(['49.08186574768562', "['Jeremy Soule']", 'Skyrim Atmospheres'],
#        dtype='<U661'),
#  array(['49.08836930631536', "['Franklin Delano Roosevelt']",
#         'Defending the New Deal - 04 28 1935'], dtype='<U661'),
#  array(['49.208832766138755', "['Franklin Delano Roosevelt']",
#         'On meetings in Cairo and Teheran with Churchill, Stalin, and Chiang Kai-shek - 12 24 1943'],
#        dtype='<U661'),
#  array(['49.21754365737664', "['Terry Riley']", 'In C - 2009 Remastered'],
#        dtype='<U661'),
#  array(['49.234513379080624', "['Abdel Halim Hafez']", 'Qareat El Fengan'],
#        dtype='<U661'),
#  array(['49.31764386588945', "['Tony Hancock']", 'The Jewel Robbery'],
#        dtype='<U661'),
#  array(['49.34392574430434', "['Angela Davis']",
#         'Panel Discussion with Burnham, Mitchell and Noble'], dtype='<U661'),
#  array(['49.357143101094024', "['Dwight D. Eisenhower']",
#         'On the atomic capabilities - 12 08 1953'], dtype='<U661'),
#  array(['49.40734506939987', "['Dwight D. Eisenhower']",
#         'Cross of Iron Speech (after the death of Stalin) - 04 16 1953'],
#        dtype='<U661'),
#  array(['49.44583126588284', "['Environments']", 'Ultimate Thunderstorm'],
#        dtype='<U661'),
#  array(['49.5032839985149',
#         "['Richard Wagner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Bruno Walter Rehearses the Siegfried-Idyll'], dtype='<U661'),
#  array(['49.510236680471024', "['Umm Kulthum']", 'Gholobt Asaleh Fe Rohy'],
#        dtype='<U661'),
#  array(['49.81533031199977', "['Anna Russell']",
#         'Survey of Singing from Madrigals to Modern Opera'], dtype='<U661'),
#  array(['50.052065050517754', "['Franklin Delano Roosevelt']",
#         'German submarine fired an American destroyer - 09 11 1941'],
#        dtype='<U661'),
#  array(['50.149024940686566', "['Alcoholics Anonymous']",
#         'New Vision For A Sculptor'], dtype='<U661'),
#  array(['50.158242383905886', "['Franklin Delano Roosevelt']",
#         'On Sacrifice and Losses - 04 28 1948'], dtype='<U661'),
#  array(['50.17547081136787', "['Umm Kulthum']", 'Woleda El Hoda'],
#        dtype='<U661'),
#  array(['50.42492546073954', "['William Kapell']",
#         'Interview with William Kapell'], dtype='<U661'),
#  array(['50.42492546073954', "['William Kapell']",
#         'Interview with William Kapell'], dtype='<U661'),
#  array(['50.66836373666108', "['Umm Kulthum']", 'El Ahat'], dtype='<U661'),
#  array(['50.71864134441723',
#         "['Billy Strayhorn', 'Bob Roberts', 'J.C. Johnson', 'Jimmy Larkin', 'Jimmy McHugh', 'Spoken Word', 'Traditional', 'Bob Prince', 'Leonard Bernstein', 'Pete Johnson', 'Phil Woods']",
#         'What is Jazz - Part One (Types of Jazz)'], dtype='<U661'),
#  array(['50.89873754653354', "['Angela Davis']", '13 Question Interview'],
#        dtype='<U661'),
#  array(['50.938301185628', "['Alcoholics Anonymous']", 'Riding the Rods'],
#        dtype='<U661'),
#  array(['51.00084092050163', "['André Breton', 'André Parinaud']",
#         "De la fin de Dada au premier manifeste surréaliste: activités expérimentales. Robert Desnos / L'aventure surréaliste"],
#        dtype='<U661'),
#  array(['51.10676613052911', "['Alcoholics Anonymous']",
#         'He Who Loses His Life'], dtype='<U661'),
#  array(['51.393950450599334', "['Irving Berlin', 'Victor Borge']",
#         'Comedy in Music, Part I - Voice'], dtype='<U661'),
#  array(['51.457704754244325',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 2 - Dialogues'], dtype='<U661'),
#  array(['52.064491804814274', "['Dwight D. Eisenhower']",
#         'Call for peace and on the rising of the MIC military-industrial complex - 01-17-1961'],
#        dtype='<U661'),
#  array(['52.10426129220089', "['President Franklin Delano Roosevelt']",
#         'Fireside Chat #22 - On Inflation and Food Prices (September 7, 1942)'],
#        dtype='<U661'),
#  array(['52.259389155727206', "['Alcoholics Anonymous']",
#         "There's Nothing the Matter With Me!"], dtype='<U661'),
#  array(['52.276767677754975',
#         "['André Gide', 'Jean Amrouche', 'Arthur Rubinstein']",
#         'Les "Cahiers d\'André Walter"'], dtype='<U661'),
#  array(['52.299684221668585', "['Alcoholics Anonymous']",
#         "The Doctor's Nightmare"], dtype='<U661'),
#  array(['52.3263873920538', "['Umm Kulthum']", 'Raq El Habeb'],
#        dtype='<U661'),
#  array(['52.37250452871305', "['Umm Kulthum']", 'Seret El Hob'],
#        dtype='<U661'),
#  array(['52.46889882946057', "['Umm Kulthum']", 'Salo Qalbe'],
#        dtype='<U661'),
#  array(['52.67030449508617', "['Fishmans']", 'LONG SEASON'], dtype='<U661'),
#  array(['52.699807352780056', "['Alcoholics Anonymous']",
#         'He Thought He Could Drink Like A Gentleman'], dtype='<U661'),
#  array(['52.706418423352815', "['Anna Russell']",
#         'A Practical Banana Promotion'], dtype='<U661'),
#  array(['52.81566177906901', "['Alcoholics Anonymous']", 'The Unbeliever'],
#        dtype='<U661'),
#  array(['52.95715167995822', "['Umm Kulthum']", 'Sahran Lewahde'],
#        dtype='<U661'),
#  array(['53.03951477177741', "['Umm Kulthum']", 'Amal Hayate'],
#        dtype='<U661'),
#  array(['53.044778397213754', "['Alcoholics Anonymous']",
#         'Alcoholics Anonymous Number Three'], dtype='<U661'),
#  array(['53.101329751474566', "['Danny Kaye']", "Uncle Dan's Cabin"],
#        dtype='<U661'),
#  array(['53.38311743885188', "['Alcoholics Anonymous']",
#         'Annie the Cop Fighter'], dtype='<U661'),
#  array(['53.42364490523956', "['Alcoholics Anonymous']", 'His Conscience'],
#        dtype='<U661'),
#  array(['53.46652595359376', "['Franklin Delano Roosevelt']",
#         'First Inaugural Address - 03 04 1933'], dtype='<U661'),
#  array(['53.572784194632945', "['Wolfgang Weyrauch']",
#         'Kapitel 1 - Das Wirtshaus im Taunus und andere Erzählungen'],
#        dtype='<U661'),
#  array(['53.608680475592394', "['Alcoholics Anonymous']",
#         'Traveler, Editor, Scholar'], dtype='<U661'),
#  array(['53.64633432739277', "['T. Rex']",
#         'The T. Rex Electric Warrior Interview'], dtype='<U661'),
#  array(['53.67882698471296',
#         "['M. V. Subbaiah Naidu', 'Lakshmi Bai', 'R. Nagendra Rao', 'Ganapathibhat', 'Kamala Bai', 'B.S. Raja Iyengar', 'G. V. Krishnamurthy']",
#         'Satya Harishchandra, Pt. 4 - Dialogues'], dtype='<U661'),
#  array(['53.72281368237945', "['Umm Kulthum']", 'Hadeth El Rouh'],
#        dtype='<U661'),
#  array(['53.754016892068265', "['Prince']",
#         'Eye No, Alphabet St., Glam Slam, Anna Stesia, Dance On, Lovesexy, When 2R in Love, I Wish U Heaven, Positivity'],
#        dtype='<U661'),
#  array(['53.78173609239336', "['André Breton', 'André Parinaud']",
#         'La rupture avec Dada / Rencontres et ruptures'], dtype='<U661'),
#  array(['53.830889772665415', "['Tamás Cseh']", 'Halaknak álma'],
#        dtype='<U661'),
#  array(['53.85981022979024', "['Alcoholics Anonymous']",
#         'The European Drinker'], dtype='<U661'),
#  array(['53.88053570714108', "['Alcoholics Anonymous']", 'My Wife And I'],
#        dtype='<U661'),
#  array(['53.88124894316992', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 17'],
#        dtype='<U661'),
#  array(['54.043048997407595', "['Various Artists', 'Igor Stravinsky']",
#         'A propos of Le Sacre - Commentary by Igor Stravinsky About the History of a Musical Landmark'],
#        dtype='<U661'),
#  array(['54.12872443612036', "['President Franklin Delano Roosevelt']",
#         'The "Stab in the Back" Speech (June 10, 1940)'], dtype='<U661'),
#  array(['54.19351479429673',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         "Emergence d'une vocation"], dtype='<U661'),
#  array(['54.20612871674314', "['Umm Kulthum']", 'Robaaeyat El Khayam'],
#        dtype='<U661'),
#  array(['54.26250565904206', "['Harry S. Truman']",
#         'Honoring the memory of President Roosevelt - 04 16 1945'],
#        dtype='<U661'),
#  array(['54.26574751685382', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['54.35342152472094', "['Glenn Gould', 'SYMPHONIA QUARTET']",
#         'String Quartet, Op. 1'], dtype='<U661'),
#  array(['54.39585217828474',
#         "['Spoken Word', 'Victor Young', 'Will Harris', 'Leonard Bernstein']",
#         'What is Jazz - Part Two (Popular Song - Improvisation)'],
#        dtype='<U661'),
#  array(['54.39999503403741', "['Umm Kulthum']", 'Ezkrony'], dtype='<U661'),
#  array(['54.464356376636324', "['Tamás Cseh']", 'Tevedal'], dtype='<U661'),
#  array(['54.61186424717725', "['Charles Mingus', 'Eric Dolphy']",
#         'Fables Of Faubus'], dtype='<U661'),
#  array(['54.67818839055748', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['54.701332360218444', "['Blaise Cendrars', 'Michel Manoll']",
#         'Voyage en Transsibérien...'], dtype='<U661'),
#  array(['54.768194494278305', "['Anna Russell', 'Jimmy Carroll']",
#         'A Square Talk on Popular Music or the Decline and Fall of the Popular Song Performer'],
#        dtype='<U661'),
#  array(['54.80639048469781',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 3 in D Minor, Part I: I. Kräftig, Entschieden - Remastered'],
#        dtype='<U661'),
#  array(['54.846224207317235', "['Umm Kulthum']", 'Ana Fe Entzark'],
#        dtype='<U661'),
#  array(['54.88699896062859', "['The Allman Brothers Band']",
#         'Mountain Jam (Theme From “First There Is A Mountain”) - Live At The Fillmore East, March 12 & 13, 1971'],
#        dtype='<U661'),
#  array(['55.06212259514569',
#         "['Gustav Mahler', 'Leonard Bernstein', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['55.09846560081385', "['Alcoholics Anonymous']",
#         "A Business Man's Recovery"], dtype='<U661'),
#  array(['55.12514430423836', "['Alcoholics Anonymous']",
#         'Ace Full Seven Eleven'], dtype='<U661'),
#  array(['55.23376708773077', "['Gaston Bachelard']", "Les poèmes de l'air"],
#        dtype='<U661'),
#  array(['55.26162571573725',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 51'],
#        dtype='<U661'),
#  array(['55.2794369264963',
#         "['Igor Stravinsky', 'Philadelphia Orchestra', 'Leopold Stokowski']",
#         'Petrushka'], dtype='<U661'),
#  array(['55.29046049467348', "['François Mauriac', 'Jean Amrouche']",
#         'Thérèse Desqueyroux'], dtype='<U661'),
#  array(['55.32862814584075', "['Alcoholics Anonymous']",
#         'Home Brewmeister'], dtype='<U661'),
#  array(['55.35563747107943', "['André Breton', 'André Parinaud']",
#         "Devant la guerre 14-18 / Les germes de l'aventure surréaliste"],
#        dtype='<U661'),
#  array(['55.36150129444195', "['Alcoholics Anonymous']", 'The Back Slider'],
#        dtype='<U661'),
#  array(['55.37815209078347',
#         "['André Gide', 'Jean Amrouche', 'Arthur Rubinstein']", '"Saül"'],
#        dtype='<U661'),
#  array(['55.44339752786591',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C Minor "Resurrection": V. Finale. Im Tempo des Scherzos'],
#        dtype='<U661'),
#  array(['55.45060010978311', "['James Baldwin']", 'The Struggle - Part I'],
#        dtype='<U661'),
#  array(['55.45882389029005', "['Emerson, Lake & Palmer']",
#         'Karn Evil 9 - i. 1st Impression, ii. 2nd Impression, iii. 3rd Impression; Live 1974; 2016 - Remaster'],
#        dtype='<U661'),
#  array(['55.466505656511195',
#         "['Gustav Mahler', 'Bruno Walter', 'New York Philharmonic']",
#         'Symphony No. 2 in C minor "Resurrection": V. Im Tempo des Scherzos. Wild herausfahrend'],
#        dtype='<U661'),
#  array(['55.516252153112326',
#         "['Gustav Mahler', 'Bruno Walter', 'Arnold Michaelis']",
#         'A Talking Portrait: Bruno Walter in Conversation with Arnold Michaelis'],
#        dtype='<U661'),
#  array(['55.54441201722649', "['Miles Davis']", 'He Loved Him Madly'],
#        dtype='<U661'),
#  array(['55.552013320094375',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 9'],
#        dtype='<U661'),
#  array(['55.56487581495472', "['Deftones']", 'MX'], dtype='<U661'),
#  array(['55.62522160379727', "['Jethro Tull']", 'Ian Anderson Interview'],
#        dtype='<U661'),
#  array(['55.66998838692361', "['Franz Liszt', 'Vladimir Horowitz']",
#         'Piano Sonata in B Minor, S. 178'], dtype='<U661'),
#  array(['55.6834140005401',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 1'],
#        dtype='<U661'),
#  array(['55.73424910227577', "['Environments']",
#         'The Psychologically Ultimate Seashore'], dtype='<U661'),
#  array(['55.860521895484425', "['Dr. Seuss']", "Dr. Seuss's Sleep Book"],
#        dtype='<U661'),
#  array(['55.86224324876194', "['Alcoholics Anonymous']", 'The Salesman'],
#        dtype='<U661'),
#  array(['55.91856654659405', "['Alcoholics Anonymous']",
#         'Women Suffer Too'], dtype='<U661'),
#  array(['55.9605132784905', "['Umm Kulthum']", 'Habeby Yasaed Awqato'],
#        dtype='<U661'),
#  array(['56.023445336166255', "['Franklin Delano Roosevelt']",
#         'On the Fall of Rome - 06 05 1944'], dtype='<U661'),
#  array(['56.114820114581434', "['Alcoholics Anonymous']",
#         'A Feminine Victory'], dtype='<U661'),
#  array(['56.16684426196567',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 46'],
#        dtype='<U661'),
#  array(['56.20487697344506', "['Alcoholics Anonymous']",
#         'The Professor and the Paradox'], dtype='<U661'),
#  array(['56.22945307235557', "['Alcoholics Anonymous']",
#         'Smile With Me At Me'], dtype='<U661'),
#  array(['56.23397268545743',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 49'],
#        dtype='<U661'),
#  array(['56.23649225781982', "['Franklin Delano Roosevelt']",
#         'On the Armistice in Italy - 09 08 1943'], dtype='<U661'),
#  array(['56.239438013255985', "['Gaston Bachelard']", 'Les images du feu'],
#        dtype='<U661'),
#  array(['56.25322471305161',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 59'],
#        dtype='<U661'),
#  array(['56.256239233631746', "['President Franklin Delano Roosevelt']",
#         'Democratic National Convention (July 20, 1944)'], dtype='<U661'),
#  array(['56.345660707996444',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 31'],
#        dtype='<U661'),
#  array(['56.38681209161636',
#         "['André Gide', 'Jean Amrouche', 'Arthur Rubinstein']",
#         '"Les nourritures terrestres"'], dtype='<U661'),
#  array(['56.41276467169712',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'La retraite sentimentale'], dtype='<U661'),
#  array(['56.45697786074555',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 56'],
#        dtype='<U661'),
#  array(['56.46919057975268', "['James Baldwin']", 'The Struggle - Part II'],
#        dtype='<U661'),
#  array(['56.478415560713216',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 56'],
#        dtype='<U661'),
#  array(['56.53490188973288',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 62'],
#        dtype='<U661'),
#  array(['56.5528059286951', "['Fela Kuti']", 'Beasts of No Nation'],
#        dtype='<U661'),
#  array(['56.557862505235846',
#         "['André Gide', 'Jean Amrouche', 'Arthur Rubinstein']",
#         "Découverte de l'URSS..."], dtype='<U661'),
#  array(['56.582994371938774',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 33'],
#        dtype='<U661'),
#  array(['56.59649079592364',
#         "['Ludwig van Beethoven', 'Leonard Bernstein', 'New York Philharmonic']",
#         "How a Great Symphony Was Written (Leonard Bernstein Discusses the First Movement of Beethoven's Eroica with Musical Illustrations)"],
#        dtype='<U661'),
#  array(['56.62365288869395',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 18'],
#        dtype='<U661'),
#  array(['56.63800698454992', "['Nature Sounds']",
#         'Relaxing Rain and Thunderstorm'], dtype='<U661'),
#  array(['56.64998667595693', "['Bill Cosby']", 'Tonsils'], dtype='<U661'),
#  array(['56.65021694969849', "['Brian Eno']",
#         'Discreet Music - Remastered 2004'], dtype='<U661'),
#  array(['56.727681027563264',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 46'],
#        dtype='<U661'),
#  array(['56.73103612790528',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 21'],
#        dtype='<U661'),
#  array(['56.7534395058026',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 51'],
#        dtype='<U661'),
#  array(['56.78581254546488',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 15'],
#        dtype='<U661'),
#  array(['56.80161800144454', "['Alcoholics Anonymous']",
#         'The Independent Blonde'], dtype='<U661'),
#  array(['56.9115036009114',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 25'],
#        dtype='<U661'),
#  array(['56.94748058390083', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 36'],
#        dtype='<U661'),
#  array(['56.97209931676282',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 64'],
#        dtype='<U661'),
#  array(['56.9837932763419', "['Steve Roach']", 'Structures from Silence'],
#        dtype='<U661'),
#  array(['56.99066864692565',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 17'],
#        dtype='<U661'),
#  array(['57.00862649608345', "['Dmitri Shostakovich', 'Arturo Toscanini']",
#         'Symphony No. 7 in C Major, Op. 60 "Leningrad": I. Allegretto'],
#        dtype='<U661'),
#  array(['57.01870360821533',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'Une tutelle consentie'], dtype='<U661'),
#  array(['57.0371795825677',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 32'],
#        dtype='<U661'),
#  array(['57.05334512072193', "['Alcoholics Anonymous']", 'Lone Endeavor'],
#        dtype='<U661'),
#  array(['57.069327112876266', "['Franklin Delano Roosevelt']",
#         'On the Bank Crisis - 03 12 1933'], dtype='<U661'),
#  array(['57.075515456838254',
#         "['Orkestr Borisa Shermana', 'Boris Sherman', 'Rostislav Pljatt', 'Vasiliy Kachalov', 'Mikhail Janshin', 'Mikhail Nazvanov']",
#         'Vstrecha s Gertsogom i Gertsoginey'], dtype='<U661'),
#  array(['57.1041863812329',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 34'],
#        dtype='<U661'),
#  array(['57.11317967424749', "['Nature Sounds']",
#         'Rain With Light Thunderstorm'], dtype='<U661'),
#  array(['57.11317967424749', "['Nature Sounds']",
#         'Rain With Distant Thunderstorm'], dtype='<U661'),
#  array(['57.129042640080435',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 55'],
#        dtype='<U661'),
#  array(['57.12915197216667',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 26'],
#        dtype='<U661'),
#  array(['57.13985133406363',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 35'],
#        dtype='<U661'),
#  array(['57.16488511824217', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone: Raise Positive Vibrations - Healing Frequency (Positive Energy Boost)'],
#        dtype='<U661'),
#  array(['57.17459685263326', "['Alcoholics Anonymous']",
#         'Another Prodigal Story'], dtype='<U661'),
#  array(['57.18903326275417', "['Pharoah Sanders']",
#         'The Creator Has A Master Plan'], dtype='<U661'),
#  array(['57.19934483648456',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'Les rencontres de Colette'], dtype='<U661'),
#  array(['57.23758574556081',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 25'],
#        dtype='<U661'),
#  array(['57.26002749742584', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone With 528Hz Solfeggio Frequency'], dtype='<U661'),
#  array(['57.26935221041999', "['André Gide', 'Jean Amrouche']",
#         'Péguy, Rolland, Jarry, Apollinaire'], dtype='<U661'),
#  array(['57.29382146619602', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 27'], dtype='<U661'),
#  array(['57.329294815757436', "['Pierre Dac', 'Francis Blanche']",
#         'Le Sar Rabindranath Duval'], dtype='<U661'),
#  array(['57.35141767829544', "['Alcoholics Anonymous']",
#         "An Artist's Concept"], dtype='<U661'),
#  array(['57.39521950078162', "['Boris Karloff']",
#         'How The Grinch Stole Christmas'], dtype='<U661'),
#  array(['57.41474928692058', "['Gaston Bachelard']", "L'élément terrestre"],
#        dtype='<U661'),
#  array(['57.421203695894185',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 42'],
#        dtype='<U661'),
#  array(['57.44447854741092', "['Sacha Guitry', 'Jean Françaix']",
#         'Mise en chantier du film'], dtype='<U661'),
#  array(['57.44976651659194',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'Le départ de M. Willy'], dtype='<U661'),
#  array(['57.45488285269337', "['Alcoholics Anonymous']", 'The Car Smasher'],
#        dtype='<U661'),
#  array(['57.470746490821185',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'I. Andante comodo'], dtype='<U661'),
#  array(['57.47732781329661',
#         "['Gustav Mahler', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Major: I. Andante comodo'], dtype='<U661'),
#  array(['57.48814171903318',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 23'],
#        dtype='<U661'),
#  array(['57.50373073950455',
#         "['André Gide', 'Jean Amrouche', 'Arthur Rubinstein']",
#         'Voyage au Congo'], dtype='<U661'),
#  array(['57.50405541039084', "['Jacqueline Harpet', 'Marguerite Duras']",
#         'Marguerite Duras parle avec des enfants'], dtype='<U661'),
#  array(['57.52414329568667',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'Dualité de Colette et Claudine'], dtype='<U661'),
#  array(['57.637626222026476',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 36'],
#        dtype='<U661'),
#  array(['57.65749437244929', "['環球群星']", '活寶愛十三a'], dtype='<U661'),
#  array(['57.690052456932946', "['PowerThoughts Meditation Club']",
#         '432Hz Miracle Tone: Rainy Days'], dtype='<U661'),
#  array(['57.70451457125881',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 4'],
#        dtype='<U661'),
#  array(['57.73650254603976', "['Philippe Gerard']",
#         'Les Nourritures Terrestres'], dtype='<U661'),
#  array(['57.74273989895612',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 40'],
#        dtype='<U661'),
#  array(['57.758383993058395', "['Fela Kuti']", 'Original Sufferhead'],
#        dtype='<U661'),
#  array(['57.777006512579796',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 29'],
#        dtype='<U661'),
#  array(['57.79049109749032',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 30'],
#        dtype='<U661'),
#  array(['57.79661073656989',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 3'],
#        dtype='<U661'),
#  array(['57.798092034181145',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         "Mine ou l'ingénue libertine"], dtype='<U661'),
#  array(['57.804380009233526', "['André Gide', 'Jean Amrouche']",
#         '1920: Gide célébre et attaqué'], dtype='<U661'),
#  array(['57.823800271492054', "['Alcoholics Anonymous']", 'Fired Again'],
#        dtype='<U661'),
#  array(['57.853876548075675',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 40'],
#        dtype='<U661'),
#  array(['57.85427843263741',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 65'],
#        dtype='<U661'),
#  array(['57.85445859765717',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 10'],
#        dtype='<U661'),
#  array(['57.85786885606324', "['環球群星']", '活寶姑娘a'], dtype='<U661'),
#  array(['57.901046456992475', "['Duke Ellington']",
#         'The Grand Finale - Rehearsal / Lines / Interview / Music / Strings / Murder'],
#        dtype='<U661'),
#  array(['57.91613929696974',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 18'],
#        dtype='<U661'),
#  array(['57.941973023929094', "['Sacha Guitry']",
#         "Présentation de l'ensemble des métiers du film"], dtype='<U661'),
#  array(['57.95768159461994',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 44'],
#        dtype='<U661'),
#  array(['57.961489286914', "['Jean Malaurie', 'Jean-Luc Hees']",
#         'La tragique et emblématique histoire de Minik'], dtype='<U661'),
#  array(['57.97464953811159', "['Tamás Cseh']", 'Marilyn dala'],
#        dtype='<U661'),
#  array(['57.98840120104392',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 24'],
#        dtype='<U661'),
#  array(['57.98965017356697', "['環球群星']", '活寶姑娘b'], dtype='<U661'),
#  array(['58.00874848468858',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 41'],
#        dtype='<U661'),
#  array(['58.02093674338187',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 63'],
#        dtype='<U661'),
#  array(['58.02455602324605',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'Découverte de la capitale'], dtype='<U661'),
#  array(['58.03882778629386',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 8'],
#        dtype='<U661'),
#  array(['58.06586633285771', "['Miles Davis']", 'Go Ahead John'],
#        dtype='<U661'),
#  array(['58.08208093137217',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 26'],
#        dtype='<U661'),
#  array(['58.08482133061077',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 28'],
#        dtype='<U661'),
#  array(['58.092882411185855',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 20'],
#        dtype='<U661'),
#  array(['58.10389579673814', "['André Gide', 'Jean Amrouche']",
#         '"Les Faux-monnayeurs": Composition...'], dtype='<U661'),
#  array(['58.136321026681436', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 45'],
#        dtype='<U661'),
#  array(['58.140223456573025',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 15'],
#        dtype='<U661'),
#  array(['58.15140455643252', "['Andy Griffith']",
#         'What It Was, Was Football'], dtype='<U661'),
#  array(['58.157920847351264', "['Alcoholics Anonymous']",
#         'A Ward of the Probate Court'], dtype='<U661'),
#  array(['58.17446936674989', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 19'],
#        dtype='<U661'),
#  array(['58.19427575290881',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 32'],
#        dtype='<U661'),
#  array(['58.20220146832022', "['Rodney Dangerfield']", 'No Respect'],
#        dtype='<U661'),
#  array(['58.21052713532682',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 43'],
#        dtype='<U661'),
#  array(['58.22565299049804', "['Marcel Pagnol']",
#         "Le contrat de Raimu est résilié : insultes, Pagnol veut retirer ''Fanny''"],
#        dtype='<U661'),
#  array(['58.22623267433364', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 3'], dtype='<U661'),
#  array(['58.230203177587796', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 16'],
#        dtype='<U661'),
#  array(['58.23600837626515',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 47'],
#        dtype='<U661'),
#  array(['58.240590096938895',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 34'],
#        dtype='<U661'),
#  array(['58.24168452419856', "['N. S. Krishnan', 'T A Madhuram']",
#         'Therukkootthu'], dtype='<U661'),
#  array(['58.266320894966064',
#         "['Noel Coward', 'Andre Kostelanetz & His Orchestra', 'Frank Miller', 'Julius Baker', 'Leonid Hambro', 'Jascha Zayde']",
#         'The Carnival of the Animals'], dtype='<U661'),
#  array(['58.26663043311347', "['Dr. Jeffrey Thompson']", 'Delta Sleep One'],
#        dtype='<U661'),
#  array(['58.28314335935471',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 47'],
#        dtype='<U661'),
#  array(['58.29021457459157',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 58'],
#        dtype='<U661'),
#  array(['58.29929900038043',
#         "['André Gide', 'Jean Amrouche', 'Arthur Rubinstein']", '"Thésée"'],
#        dtype='<U661'),
#  array(['58.3085842209982',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 8'],
#        dtype='<U661'),
#  array(['58.37422817022068', "['André Gide', 'Jean Amrouche']",
#         'La Roque. Les salons littéraires. "Le traité du Narcisse"'],
#        dtype='<U661'),
#  array(['58.384758091285384', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 18'], dtype='<U661'),
#  array(['58.39604895606004', "['Miles Davis']", 'Bitches Brew'],
#        dtype='<U661'),
#  array(['58.39734991366658',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 36'],
#        dtype='<U661'),
#  array(['58.40199031709561', "['Miles Davis']", 'Bitches Brew'],
#        dtype='<U661'),
#  array(['58.40427774427172',
#         "['Henryk Górecki', 'Dawn Upshaw', 'London Sinfonietta', 'David Zinman']",
#         'Symphony No. 3, Op. 36: I. Lento - Sostenuto Tranquillo Ma Cantabile'],
#        dtype='<U661'),
#  array(['58.42276754361377', "['Bill Cosby']", 'Chicken Heart'],
#        dtype='<U661'),
#  array(['58.48502353333599',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 45'],
#        dtype='<U661'),
#  array(['58.505371123643535',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 37'],
#        dtype='<U661'),
#  array(['58.520840444403966', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 44'],
#        dtype='<U661'),
#  array(['58.561550983182904', "['Abdel Halim Hafez']",
#         'حاول تفتكرنى تسجيل حفلة'], dtype='<U661'),
#  array(['58.56860516597119', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 1'], dtype='<U661'),
#  array(['58.58041521035014',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 41'],
#        dtype='<U661'),
#  array(['58.58092265922918',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 28'],
#        dtype='<U661'),
#  array(['58.59542192930003',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 19'],
#        dtype='<U661'),
#  array(['58.60683436986733',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 42'],
#        dtype='<U661'),
#  array(['58.61124189727603', "['André Gide', 'Jean Amrouche']",
#         '... Thèmes et personnages'], dtype='<U661'),
#  array(['58.632843420156625',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 9 in D Minor, WAB 109 (Original 1894 Version): I. Feierlich, misterioso - Edition: Leopold Nowak'],
#        dtype='<U661'),
#  array(['58.651159179755474', "['Led Zeppelin']",
#         'Dazed and Confused - Live at MSG 1973; 2018 Remaster'],
#        dtype='<U661'),
#  array(['58.65183672457066',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 5'],
#        dtype='<U661'),
#  array(['58.66662673194251',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 50'],
#        dtype='<U661'),
#  array(['58.66903668143271', "['Sounds Of Nature : Thunderstorm, Rain']",
#         'Music For Sleep Thunderstorm, Rain'], dtype='<U661'),
#  array(['58.67867860986718', "['Francesc Macia']",
#         "El President Macià Anuncia al Poble de Catalunya L'Aprovació de L'Estatut el 9 de Setembre de 1932"],
#        dtype='<U661'),
#  array(['58.696538538673295',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 43'],
#        dtype='<U661'),
#  array(['58.7085168262615',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         "De l'inspiration à l'écriture"], dtype='<U661'),
#  array(['58.714071917563466',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 13'],
#        dtype='<U661'),
#  array(['58.719355024309365', "['Harold Courlander']",
#         'The Cow-Tail Switch'], dtype='<U661'),
#  array(['58.720867736165076', "['Mike Oldfield']", 'Tubular Bells - Pt. I'],
#        dtype='<U661'),
#  array(['58.73111244721981', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 39'], dtype='<U661'),
#  array(['58.74442526139481',
#         "['Colette', 'André Parinaud', 'Robert Casadessus']",
#         'Travailler aux ateliers'], dtype='<U661'),
#  array(['58.76610831599099',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 19'],
#        dtype='<U661'),
#  array(['58.78546618826394', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 1'],
#        dtype='<U661'),
#  array(['58.788979670905874', "['André Gide', 'Jean Amrouche']",
#         'De "L\'Immoraliste" à "La porte étroite"'], dtype='<U661'),
#  array(['58.79217160468306',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 2'],
#        dtype='<U661'),
#  array(['58.7971476947497', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 46'],
#        dtype='<U661'),
#  array(['58.8014598966665', "['André Gide', 'Jean Amrouche']", '"Paludes"'],
#        dtype='<U661'),
#  array(['58.818730257907944', "['Jeff Foxworthy']",
#         'T.V. And Its Side Effects'], dtype='<U661'),
#  array(['58.82191536842318',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Sorge dich nicht - lebe! - Die Kunst, zu einem von Ängsten und Aufregungen befreiten Leben zu finden, Kapitel 10'],
#        dtype='<U661'),
#  array(['58.84672823438444', "['The Soft Winds']", 'Jazzspeak'],
#        dtype='<U661'),
#  array(['58.846782595005436', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 14'],
#        dtype='<U661'),
#  array(['58.84780095538316', "['Charpin', 'Oriane Demazis', 'Mouries']",
#         'Acte 2, scène 6'], dtype='<U661'),
#  array(['58.85200844617579', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 20'], dtype='<U661'),
#  array(['58.85738545455131', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 35'], dtype='<U661'),
#  array(['58.8668635834746', "['Francisco Canaro', 'Azucena Maizani']",
#         'Canta Corazón - Remasterizado'], dtype='<U661'),
#  array(['58.870984910462106',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 59'],
#        dtype='<U661'),
#  array(['58.898242969480705', "['Bill Hayes']", 'Electioneering'],
#        dtype='<U661'),
#  array(['58.902357589408936',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 27'],
#        dtype='<U661'),
# ...
#         'Chapter 1.11 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['61.67067058046297', "['Abdel Halim Hafez']",
#         'قارئة الفنجان تسجيل حفلة'], dtype='<U661'),
#  array(['61.67261672468371', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 86'], dtype='<U661'),
#  array(['61.67505985114471', "['Ogden Nash']", 'The Outcome'],
#        dtype='<U661'),
#  array(['61.67526423336898', "['Zofia Dromlewiczowa']",
#         'Chapter 1.12 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['61.67568118700542', "['Seweryn Goszczyński']",
#         'Chapter 4.2 - Zamek kaniowski'], dtype='<U661'),
#  array(['61.67923204391788', "['Zofia Dromlewiczowa']",
#         'Chapter 1.22 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['61.682327701799665',
#         "['Pyotr Ilyich Tchaikovsky', 'Arturo Toscanini', 'NBC Symphony Orchestra', 'Vladimir Horowitz']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: I. Allegro non troppo e molto maestoso'],
#        dtype='<U661'),
#  array(['61.68984165102398', "['Zofia Dromlewiczowa']",
#         'Chapter 2.11 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['61.69471040083834', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 38'], dtype='<U661'),
#  array(['61.695357475652116', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 202'], dtype='<U661'),
#  array(['61.69656607921546', "['Carol Channing']", 'Housework'],
#        dtype='<U661'),
#  array(['61.698940759954176', "['Seweryn Goszczyński']",
#         'Chapter 1.12 - Zamek kaniowski'], dtype='<U661'),
#  array(['61.70047573476005',
#         "['Jean Cocteau', 'André Parinaud', 'Yvette Guilbert']",
#         'La politique / Colette'], dtype='<U661'),
#  array(['61.703177954513684', "['Cornelia Otis Skinner']",
#         'Yvette Guilbert / Songs: "St. Lazare" & "Mme. Arthur"'],
#        dtype='<U661'),
#  array(['61.70363105584641', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 197'], dtype='<U661'),
#  array(['61.70780392398562', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 72'], dtype='<U661'),
#  array(['61.71021490579823', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 100'], dtype='<U661'),
#  array(['61.71152004769237', "['Colette', 'René-Maurice Picard']",
#         "L'Académie Goncourt"], dtype='<U661'),
#  array(['61.71306352772303', "['Alfred Hitchcock']",
#         'The Haunted and the Hunters'], dtype='<U661'),
#  array(['61.71663003328845',
#         "['Joe E. Brown', 'Cornelius Peeples', 'Porter W. Heaps']",
#         'How To Play Baseball - Hitting - Part 4'], dtype='<U661'),
#  array(['61.72348885798187', "['Langston Hughes']",
#         'The Weary Blues; Wide River; Homesick Blues; Night and Morn'],
#        dtype='<U661'),
#  array(['61.72842584148141',
#         "['Joe E. Brown', 'Cornelius Peeples', 'Porter W. Heaps']",
#         'How To Play Baseball - Pitching - Part 1'], dtype='<U661'),
#  array(['61.72885530123724', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 174'], dtype='<U661'),
#  array(['61.72938796285933', "['Quincy Jones']",
#         'Quincy Jones Interview #3'], dtype='<U661'),
#  array(['61.73026798699108', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 52'], dtype='<U661'),
#  array(['61.73392705609953', "['Truman Capote']",
#         'Ottilie and the Bee (Bonus Track)'], dtype='<U661'),
#  array(['61.73750338804812', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 1'], dtype='<U661'),
#  array(['61.73755911179266', "['Bill Cosby']",
#         'Chocolate Cake For Breakfast'], dtype='<U661'),
#  array(['61.73824632214202', "['Dilip Kumar', 'Waheeda Rehman']",
#         'Aadmi - Dialogues'], dtype='<U661'),
#  array(['61.74135859434698', "['Patricia St. John']",
#         'Kapitel 124 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.74218484811722', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 133'], dtype='<U661'),
#  array(['61.74332946362339', "['Zofia Dromlewiczowa']",
#         'Chapter 1.23 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['61.74333346965571', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 104'], dtype='<U661'),
#  array(['61.744260330956656',
#         "['Marcel Pagnol', 'Raimu', 'Pierre Fresnay']",
#         'Acte 3, le retour'], dtype='<U661'),
#  array(['61.749100094050185', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Von der Renaissance bis heute, Kapitel 30'], dtype='<U661'),
#  array(['61.751266726099104', "['Patricia St. John']",
#         'Kapitel 148 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.75141744735416', "['Patricia St. John']",
#         'Kapitel 9 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.75399408593074', "['Patricia St. John']",
#         'Kapitel 170 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.75511591894556', "['Harold Courlander']", 'Throw Mountains'],
#        dtype='<U661'),
#  array(['61.76394276146782', "['Zofia Dromlewiczowa']",
#         'Chapter 1.10 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['61.76394537648155', "['Patricia St. John']",
#         'Kapitel 13 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.76556183833867', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 183'], dtype='<U661'),
#  array(['61.765745464139826', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 139'], dtype='<U661'),
#  array(['61.767719720740764', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 17'], dtype='<U661'),
#  array(['61.769521218806865',
#         "['Pyotr Ilyich Tchaikovsky', 'Arturo Toscanini', 'NBC Symphony Orchestra', 'Vladimir Horowitz']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: I. Allegro non troppo e molto maestoso'],
#        dtype='<U661'),
#  array(['61.77120510523855', "['Fela Kuti']",
#         'Shuffering And Shmiling (Part 1 & 2)'], dtype='<U661'),
#  array(['61.77790165591373', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 169'], dtype='<U661'),
#  array(['61.778793595312024', "['Patricia St. John']",
#         'Kapitel 142 - Hamid und Kinza'], dtype='<U661'),
#  array(['61.78469918120183', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 130'], dtype='<U661'),
#  array(['61.78700859998203', "['Yes']",
#         'The Gates of Delirium - 2003 Remaster'], dtype='<U661'),
#  array(['61.789361568434614', "['Zofia Dromlewiczowa']",
#         'Chapter 2.4 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['61.7904248447532', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 18'], dtype='<U661'),
#  array(['61.79407117060534', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 153'], dtype='<U661'),
#  array(['61.7967844054708', "['Ritchie Valens']",
#         'Bob Keane Intro - Live, Side 1'], dtype='<U661'),
#  array(['61.80388928129652', "['Francesc Macia']",
#         "Introducció: Francesc Macià Proclamant la República Catalana el 14 D'Abril de 1931"],
#        dtype='<U661'),
#  array(['61.80458980139479', "['Terry Riley']",
#         'Poppy Nogood and the Phantom Band - Instrumental'], dtype='<U661'),
#  array(['61.804765796357124', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 80'], dtype='<U661'),
#  array(['61.80591132984934', "['Patricia St. John']",
#         'Kapitel 98 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.806040481678096', "['Georg Kaiser']", 'Kapitel 27 - Klawitter'],
#        dtype='<U661'),
#  array(['61.80796967127273', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 62'], dtype='<U661'),
#  array(['61.81368624788515', "['Charles Mingus']",
#         'C Jam Blues - Live Version'], dtype='<U661'),
#  array(['61.81734106754184',
#         "['Richard Strauss', 'Claudio Arrau', 'Désiré Defauw', 'Chicago Symphony Orchestra']",
#         'Burleske for Piano and Orchestra in D Minor, TrV 145 - Live'],
#        dtype='<U661'),
#  array(['61.82204654690818', "['Jim Hall']", 'Concierto De Aranjuez'],
#        dtype='<U661'),
#  array(['61.82237424610615', "['Zofia Dromlewiczowa']",
#         'Chapter 3.11 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['61.8237222233147', "['Harold Courlander']",
#         "The Tiger's War Against Borneo"], dtype='<U661'),
#  array(['61.82464448059239', "['Dick Gregory']",
#         'Commentary on Affairs Political'], dtype='<U661'),
#  array(['61.830915776423396', "['Jean Giono', 'Taos Amrouche']",
#         'Le grand voyage immobile'], dtype='<U661'),
#  array(['61.83347930824628', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 50'], dtype='<U661'),
#  array(['61.83443537594283', "['Joe E. Brown', 'Cornelius Peeples']",
#         'How To Play Baseball - Running - Part 3'], dtype='<U661'),
#  array(['61.83583190192262', "['Zofia Dromlewiczowa']",
#         'Chapter 1.17 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['61.84483742708092', "['David Raskin']",
#         "Part III: Amber's Theme / Ride / Death / Sickness / Attack / Ordeal"],
#        dtype='<U661'),
#  array(['61.84730912576506',
#         "['Frederick Delius', 'Sir Thomas Beecham', 'Philadelphia Orchestra']",
#         'Paris - A Nocturne: Adagio - Allegretto grazioso - Molto lento - Lunga'],
#        dtype='<U661'),
#  array(['61.84845673476275', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 9'], dtype='<U661'),
#  array(['61.85150775020547', "['Zofia Dromlewiczowa']",
#         'Chapter 1.25 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['61.856245096031344', "['King Crimson']",
#         'Lizard (Prince Rupert Awakes/Bolero/The Battle of Glass Tears/Big Top)'],
#        dtype='<U661'),
#  array(['61.858793766140295', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 97'], dtype='<U661'),
#  array(['61.85944206171597',
#         "['Leonard Bernstein', 'New York Philharmonic']",
#         'Symphonic Dances from "West Side Story"'], dtype='<U661'),
#  array(['61.86241512856667', "['Zofia Dromlewiczowa']",
#         'Chapter 2.5 - Dziewczynka z Luna Parku: Część 2'], dtype='<U661'),
#  array(['61.86306601695263', "['Bill Cosby']", 'A Nut in Every Car'],
#        dtype='<U661'),
#  array(['61.86712159322418', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 4'], dtype='<U661'),
#  array(['61.869188875647765', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 2'], dtype='<U661'),
#  array(['61.87225089086269', "['Marcel Pagnol']",
#         'La dispute entre Raimu et Léon Volterra'], dtype='<U661'),
#  array(['61.872990519105066', "['Charpin', 'Mouries', 'Vattier', 'Raimu']",
#         'Acte 1, scène 9'], dtype='<U661'),
#  array(['61.881665968492655',
#         "['Anton Bruckner', 'Wiener Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 5 in B-Flat Major, WAB 105: IV. Finale. Adagio - Allegro moderato (Live)'],
#        dtype='<U661'),
#  array(['61.88431393438972', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 103'], dtype='<U661'),
#  array(['61.890133713483884', "['Dick Gregory']", 'Congo Daily Tribune'],
#        dtype='<U661'),
#  array(['61.89030211647917',
#         "['Anton Bruckner', 'Berliner Philharmoniker', 'Carl Schuricht']",
#         'Symphony No.7 In E Major, WAB 107 - Ed. Haas: 1. Allegro moderato'],
#        dtype='<U661'),
#  array(['61.894862858317566', "['Safiye Ayla']", 'Ayrı Düştüm Sevdiğimden'],
#        dtype='<U661'),
#  array(['61.89842210209627', "['Kurt Heynicke']",
#         'Kapitel 1 - Oktoberfrühling'], dtype='<U661'),
#  array(['61.89888921529827', "['Patricia St. John']",
#         'Kapitel 125 - Spuren im Schnee'], dtype='<U661'),
#  array(['61.89909966326307', "['Federico García Lorca']",
#         'Capítulo 9.4 - la Casa de Bernarda Alba'], dtype='<U661'),
#  array(['61.9009759884652', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 173'], dtype='<U661'),
#  array(['61.91175588121992', "['Marianne Moore']", 'In Distrust of Merits'],
#        dtype='<U661'),
#  array(['61.917013279512915', "['Robin Williams']", 'Cocaine - Live'],
#        dtype='<U661'),
#  array(['61.923521764434405', "['Jacques Prévert']", 'Barbara'],
#        dtype='<U661'),
#  array(['61.9236438150929', "['Mary Norton', 'Katharina Thalbach']",
#         'Die Borger, Kapitel 16'], dtype='<U661'),
#  array(['61.923812369099124', "['Quincy Jones']",
#         'Voice-Over Intro Quincy Jones Interview #2/Quincy Jones Interview #2 / Voice-Over Intro Billie Jean (Demo)'],
#        dtype='<U661'),
#  array(['61.92484917728498',
#         "['Bedřich Smetana', 'Prague National Theatre Chorus', 'Prague National Theatre Orchestra', 'Jan Maria Ouředník', 'Václav Talich', 'Josef Křikava', 'Marie Podvalová', 'Stanislav Muž', 'Vilém Zítek', 'Josef Vojta', 'Ota Horáková', 'Marta Krásová', 'Jaroslav Veverka']",
#         'Libuše: "Bohové mocní!" (Libuše, Přemysl ze Stadic, Chrudoš od Otavy, Šťáhlav na Radbuze, Krasava, Radmila, Lutobor, Radovan) - Live'],
#        dtype='<U661'),
#  array(['61.93011749723625',
#         "['Johannes Brahms', 'Rudolf Serkin', 'Fritz Reiner', 'Pittsburgh Symphony Orchestra']",
#         'Concerto No. 1 in D Minor for Piano and Orchestra, Op. 15: I. Maestoso'],
#        dtype='<U661'),
#  array(['61.93378882690642', "['Zofia Dromlewiczowa']",
#         'Chapter 2.5 - Dziewczynka z Luna Parku: Część 1'], dtype='<U661'),
#  array(['61.93590097230857', "['Umm Kulthum']", 'Zalamone El Nas'],
#        dtype='<U661'),
#  array(['61.937739629520024',
#         "['Pyotr Ilyich Tchaikovsky', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Piano Concerto No. 1 in B-Flat Minor, Op. 23: I. Allegro non troppo e molto maestoso'],
#        dtype='<U661'),
#  array(['61.941399778874185', "['Seweryn Goszczyński']",
#         'Chapter 4.6 - Zamek kaniowski'], dtype='<U661'),
#  array(['61.94506034576595', "['Jackie Gleason']",
#         'Casey At The Bat - Live'], dtype='<U661'),
#  array(['61.94779644278967', "['Howard Shelly', 'Kurt Graunke']",
#         'III. Phantaisie Pathetique'], dtype='<U661'),
#  array(['61.95008263781169', "['Arthur Askey and cast']",
#         'Band Waggon (Pt 4) - 1939 Recording'], dtype='<U661'),
#  array(['61.95442880768894', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 150'], dtype='<U661'),
#  array(['61.95490570016488',
#         "['Anton Bruckner', 'Karl Böhm', 'Staatskapelle Dresden']",
#         'Bruckner: Symphony No. 4 in E-Flat Major, "Romantic": IV. Finale - Bewegt, doch nicht zu schnell'],
#        dtype='<U661'),
#  array(['61.95612309196509', "['Nikolai Gogol']",
#         'Kapitel 7 - Der große Krach der großen Herren'], dtype='<U661'),
#  array(['61.957686722782384',
#         "['Ludwig van Beethoven', 'Tilla Briem', 'Elisabeth Höngen', 'Peter Anders', 'Rudolf Watzke', 'Choeur Bruno Kittel', 'Berliner Philharmoniker', 'Wilhelm Furtwängler']",
#         'Symphony No. 9 in D Minor, Op. 125 "Ode to Joy": III. Adagio molto e cantabile - Andante moderato'],
#        dtype='<U661'),
#  array(['61.961218667802754', "['Benny Goodman']",
#         'Honeysuckle Rose - Live'], dtype='<U661'),
#  array(['61.96259105647368', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 177'], dtype='<U661'),
#  array(['61.966500830132', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 158'], dtype='<U661'),
#  array(['61.966580621114666', "['Genesis']",
#         "Supper's Ready - New Stereo Mix"], dtype='<U661'),
#  array(['61.96993137673459', "['Seweryn Goszczyński']",
#         'Chapter 1.9 - Zamek kaniowski'], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[sort_indices][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MixjNzY3MzJjMzEwNmJmNmYyN2U0Yzk1OTY5NjdhODE0YWYwOGI3MmQ3'}
