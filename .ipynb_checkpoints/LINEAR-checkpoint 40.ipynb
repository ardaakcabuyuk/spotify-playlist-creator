# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['Travis Scott']", 'STARGAZING'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=5001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Kanye West']", 'All Of The Lights'],
#         ["['YUNGBLUD', 'Halsey', 'Travis Barker']",
#          '11 Minutes (with Halsey feat. Travis Barker)'],
#         ["['Juice WRLD']", "I'll Be Fine"],
#         ...,
#         ["['Ambjaay']", 'Uno'],
#         ["['Staind']", 'So Far Away'],
#         ["['Rob Zombie', 'Howard Stern']",
#          'The Great American Nightmare']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.0006

# %%
relevance
# Out:
# 96.99999999997146

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.column_stack((predictions, song_info[:,0], song_info[:,1]))

# %%
sort_indices = np.argsort(predictions)[::-1]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[sort_indices]

# %%
list(predicted)
# Out:
# [array(['98.6193693622084', "['Night Lovell', '$uicideBoy$']",
#         'Joan of Arc'], dtype='<U661'),
#  array(['98.61378683089907', "['Tierra Whack']", 'Hungry Hippo'],
#        dtype='<U661'),
#  array(['98.61302356596084', "['ОТВАЛ БАWKN', 'Cartier99']", 'No Cap'],
#        dtype='<U661'),
#  array(['98.6073860330237', "['Huncho Jack', 'Travis Scott', 'Quavo']",
#         'Saint'], dtype='<U661'),
#  array(['98.60691337507369', "['Lil Boodang']", 'Officer Boodang'],
#        dtype='<U661'),
#  array(['98.60413137755236', "['Comethazine', 'Ugly God']",
#         'Let It Eat (feat. Ugly God)'], dtype='<U661'),
#  array(['98.60360717550243', "['$uicideBoy$']", '2nd Hand'], dtype='<U661'),
#  array(['98.60342524934185', "['Night Lovell']", 'Live Television'],
#        dtype='<U661'),
#  array(['98.60243934780759', "['Tory Lanez']", 'Freaky'], dtype='<U661'),
#  array(['98.6022489162953', "['Tory Lanez']", 'Freaky'], dtype='<U661'),
#  array(['98.6018664173636', "['Ambjaay']", 'Uno'], dtype='<U661'),
#  array(['98.60071415198347', "['Rich Brian']", 'Dat $tick'], dtype='<U661'),
#  array(['98.60059651879351', "['DUOBAIANO', 'TICIANE']",
#         'XOTE DAS MENINAS'], dtype='<U661'),
#  array(['98.6001322907052', "['$uicideBoy$']", 'Magazine'], dtype='<U661'),
#  array(['98.59917734281879', "['Lil Pump']", 'Gucci Gang'], dtype='<U661'),
#  array(['98.59904038440509', "['$uicideBoy$']", 'Paris'], dtype='<U661'),
#  array(['98.59841691699071', "['Ouija Macc']", 'Fucc Me Over'],
#        dtype='<U661'),
#  array(['98.59834972211273', "['Reel Big Fish']", 'S.R.'], dtype='<U661'),
#  array(['98.5976736373824', "['YBN Nahmir']", 'Bounce Out With That'],
#        dtype='<U661'),
#  array(['98.597369647149', "['Ugly God']", 'One Two'], dtype='<U661'),
#  array(['98.59734179081484', "['Lil Boodang']", 'Bone Daddy'],
#        dtype='<U661'),
#  array(['98.59684257544741', "['Saweetie']", 'ICY GRL'], dtype='<U661'),
#  array(['98.59650182492763', "['Future']", 'Married To The Game'],
#        dtype='<U661'),
#  array(['98.59636675239739', "['Migos']", 'Taco Tuesday'], dtype='<U661'),
#  array(['98.5962489182374', "['$uicideBoy$']", 'Champion Of Death'],
#        dtype='<U661'),
#  array(['98.59606751941713', "['Jack Harlow']", '2STYLISH'], dtype='<U661'),
#  array(['98.59569845639442', "['XXXTENTACION']", 'going down!'],
#        dtype='<U661'),
#  array(['98.59539647541443',
#         "['Quality Control', 'Offset', 'Playboi Carti']",
#         '100 Racks (Offset feat. Playboi Carti)'], dtype='<U661'),
#  array(['98.59496672216045', "['Ouija Macc', 'Crybaby Ouija']",
#         'Piece of Shit'], dtype='<U661'),
#  array(['98.59459995569355', "['Bhad Bhabie']", 'Hi Bich'], dtype='<U661'),
#  array(['98.5945929867572', "['KYLE']", 'What It Is'], dtype='<U661'),
#  array(['98.59443703564294', "['$uicideBoy$']", 'Do You Believe In God?'],
#        dtype='<U661'),
#  array(['98.59433585854481', "['Jack Harlow', 'Bryson Tiller']",
#         'THRU THE NIGHT (feat. Bryson Tiller)'], dtype='<U661'),
#  array(['98.59397669335962', '[\'Dr. Dre\', "Knoc-Turn\'al"]',
#         'Bad Intentions'], dtype='<U661'),
#  array(['98.59394576677023', "['$uicideBoy$']", 'Memoirs Of A Gorilla'],
#        dtype='<U661'),
#  array(['98.59375559261737', "['Gunna']", 'GIMMICK'], dtype='<U661'),
#  array(['98.5936167088373', "['gianni & kyle']", '5 shots'], dtype='<U661'),
#  array(['98.59341525738537', "['Bloodhound Gang']",
#         'The Ballad Of Chasey Lain'], dtype='<U661'),
#  array(['98.59317103229517', "['Luh Kel']", 'Pull Up'], dtype='<U661'),
#  array(['98.59262240455584', "['2 Chainz']", 'Riot'], dtype='<U661'),
#  array(['98.59261192041059', "['Joey Purp']", 'Elastic'], dtype='<U661'),
#  array(['98.59253133200278', "['Rihanna', 'SZA']", 'Consideration'],
#        dtype='<U661'),
#  array(['98.59235005113352', "['Wiz Khalifa', 'Tyga']",
#         'Contact (feat. Tyga)'], dtype='<U661'),
#  array(['98.59214988739365', "['Wiz Khalifa', 'Tyga']",
#         'Contact (feat. Tyga)'], dtype='<U661'),
#  array(['98.59135048192304', "['Wiz Khalifa', 'K CAMP']",
#         'Clouds in the Air (feat. K CAMP)'], dtype='<U661'),
#  array(['98.59100158443832', "['Lil Loaded']", 'Gang Unit'], dtype='<U661'),
#  array(['98.59096140786541', "['DripReport']", 'Skechers'], dtype='<U661'),
#  array(['98.59015382294177', "['Molotov']", 'Puto'], dtype='<U661'),
#  array(['98.58970674479573', "['BlackMayo']", "Jus' Know"], dtype='<U661'),
#  array(['98.58955666695852', "['Jack Harlow']", 'HEY BIG HEAD'],
#        dtype='<U661'),
#  array(['98.58935725332437', "['Iggy Azalea', 'Jennifer Hudson']",
#         'Trouble'], dtype='<U661'),
#  array(['98.58891664710232', "['Lil Pump']", 'Boss'], dtype='<U661'),
#  array(['98.58879159156749', "['$uicideBoy$']", 'Sunshine'], dtype='<U661'),
#  array(['98.58849253034168', "['Jack Harlow', 'jetsonmade']",
#         'I WANNA SEE SOME ASS (feat. jetsonmade)'], dtype='<U661'),
#  array(['98.58846124757144', "['Hünkar']", 'Uzay (Intro)'], dtype='<U661'),
#  array(['98.58833838763175', "['Drake', 'Giggs']", 'KMT'], dtype='<U661'),
#  array(['98.58803497104313', "['Skizzy Mars']", 'Calabasas'], dtype='<U661'),
#  array(['98.58785712258135', "['$uicideBoy$']",
#         'What The Fuck Is Happening'], dtype='<U661'),
#  array(['98.58750987491686', "['ОТВАЛ БАWKN', 'Lil Uzi Kop', 'Cartier99']",
#         'Phonk 2'], dtype='<U661'),
#  array(['98.58720656458291', "['Chloe x Halle']", 'Tipsy'], dtype='<U661'),
#  array(['98.58703569133114', "['Freddie Dredd']", 'GTG'], dtype='<U661'),
#  array(['98.58678697706785', "['Russ']", 'Me You'], dtype='<U661'),
#  array(['98.58671473495167', "['Tiësto', 'Sevenn', 'Gucci Mane']", 'BOOM'],
#        dtype='<U661'),
#  array(['98.58669368795535', "['Nelly', 'Jeremih']",
#         'The Fix (feat. Jeremih)'], dtype='<U661'),
#  array(['98.58666758656838', "['$uicideBoy$']", 'Dead Batteries'],
#        dtype='<U661'),
#  array(['98.58611866273858', "['Chief Keef']", "That's It"], dtype='<U661'),
#  array(['98.5860916092217', "['Mike Sherm']", 'Hot Nigga'], dtype='<U661'),
#  array(['98.58599095925736', "['Xavier Wulf']", 'Psycho Pass'],
#        dtype='<U661'),
#  array(['98.58593680928684', "['NAV', 'Young Thug']",
#         'Spend It (feat. Young Thug)'], dtype='<U661'),
#  array(['98.58572547750329', "['Ca$h Out']", 'She Twerkin'], dtype='<U661'),
#  array(['98.5854984846781',
#         "['Dreamville', 'JID', 'EARTHGANG', 'Buddy', 'Guapdad 4000']",
#         'Wells Fargo (with JID & EARTHGANG feat. Buddy & Guapdad 4000) - Interlude'],
#        dtype='<U661'),
#  array(['98.58532084807844', "['88rising', 'Joji', 'BlocBoy JB']",
#         'Peach Jam'], dtype='<U661'),
#  array(['98.58506079502018', "['$uicideBoy$']", 'Putrid Pride'],
#        dtype='<U661'),
#  array(['98.58505002588498', "['Nicki Minaj', 'Ciara']", "I'm Legit"],
#        dtype='<U661'),
#  array(['98.58502196793823',
#         "['Quality Control', 'Lil Yachty', 'Ty Dolla $ign']", 'Movin’ Up'],
#        dtype='<U661'),
#  array(['98.58493398313152', "['Upchurch']", 'Dirty Boys'], dtype='<U661'),
#  array(['98.58471417158066', "['Halsey']", 'Walls Could Talk'],
#        dtype='<U661'),
#  array(['98.58446822209912', "['Young Money', 'Nicki Minaj']",
#         'Lookin Ass'], dtype='<U661'),
#  array(['98.58433168525502', '[\'Westside Connection\', "Knoc-Turn\'al"]',
#         'Lights Out'], dtype='<U661'),
#  array(['98.58419078322851', "['DaBaby', 'Offset']",
#         'Baby Sitter (feat. Offset)'], dtype='<U661'),
#  array(['98.58386514050719', "['$uicideBoy$']", 'O Pana!'], dtype='<U661'),
#  array(['98.58380718633626', "['Ouija Macc']", 'Turn out All the Lights'],
#        dtype='<U661'),
#  array(['98.58368505427183', "['Marshmello', 'Tyga', 'Chris Brown']",
#         'Light It Up (with Tyga & Chris Brown)'], dtype='<U661'),
#  array(['98.58363649790205', "['Little Mix']", 'Wasabi'], dtype='<U661'),
#  array(['98.58325161038675', "['Too $hort']", 'Burn Rubber'], dtype='<U661'),
#  array(['98.58312355502397', "['City Girls']", 'Act Up'], dtype='<U661'),
#  array(['98.58285972779855', "['Dr. Dre', 'Eminem']", 'Forgot About Dre'],
#        dtype='<U661'),
#  array(['98.58249878223678', "['YG']", 'Still Brazy'], dtype='<U661'),
#  array(['98.5821904719735', "['Chris Brown', 'Nicki Minaj']",
#         'Love More (feat. Nicki Minaj)'], dtype='<U661'),
#  array(['98.58214017736695', "['Joey Trap']", 'Tables'], dtype='<U661'),
#  array(['98.58209176597764', "['French Montana', 'City Girls']",
#         'Wiggle It (feat. City Girls)'], dtype='<U661'),
#  array(['98.58201242389237', "['Sublime']", 'The Ballad Of Johnny Butt'],
#        dtype='<U661'),
#  array(['98.58174840197833', "['blackbear']", 'Different Hos'],
#        dtype='<U661'),
#  array(['98.58158429920933', "['King Staccz']", 'Pretty Face'],
#        dtype='<U661'),
#  array(['98.58153696894139', "['2Pac', 'Trick Daddy']",
#         "Still Ballin' - Nitty Remix"], dtype='<U661'),
#  array(['98.58152670931861', "['Kevin Gates']", 'Smiling Faces'],
#        dtype='<U661'),
#  array(['98.58151053722834', "['SAINt JHN', 'Future']",
#         'Roses Remix (feat. Future)'], dtype='<U661'),
#  array(['98.58144126422255', "['DDG']", 'OD'], dtype='<U661'),
#  array(['98.58121200482667', "['Tinashe']", 'Throw A Fit'], dtype='<U661'),
#  array(['98.58116996953899', "['$IMEON']", 'My Gal'], dtype='<U661'),
#  array(['98.58105193695634', "['Icona Pop', 'Charli XCX']",
#         'I Love It (feat. Charli XCX) - Original Version'], dtype='<U661'),
#  array(['98.58101123212506', "['XXXTENTACION']", 'Looking for a Star'],
#        dtype='<U661'),
#  array(['98.58093428355447', "['RMR', 'Future', 'Lil Baby']",
#         'DEALER (feat. Future & Lil Baby)'], dtype='<U661'),
#  array(['98.58089032530837', "['YG']", "One Time Comin'"], dtype='<U661'),
#  array(['98.58083999929973', "['Sublime']", 'Wrong Way'], dtype='<U661'),
#  array(['98.58058217652012', "['Bhad Bhabie', 'Kodak Black']",
#         'Bestie (feat. Kodak Black)'], dtype='<U661'),
#  array(['98.58058032006986', "['Blac Youngsta']", 'Booty'], dtype='<U661'),
#  array(['98.58046622988253', "['2 Chainz']", "I'm Different"],
#        dtype='<U661'),
#  array(['98.5800099624975', "['2 Chainz']", 'El Chapo Jr'], dtype='<U661'),
#  array(['98.5800039063754', "['PARTYNEXTDOOR']", 'Break from Toronto'],
#        dtype='<U661'),
#  array(['98.57978815492706', "['Peach Tree Rascals']", 'Mango'],
#        dtype='<U661'),
#  array(['98.57977872366212', "['Icona Pop', 'Charli XCX']",
#         'I Love It (feat. Charli XCX)'], dtype='<U661'),
#  array(['98.57967053623284', "['Gorilla Zoe']", 'Hood Nigga'],
#        dtype='<U661'),
#  array(['98.5796271615889', "['Kanye West']",
#         'Father Stretch My Hands Pt. 1'], dtype='<U661'),
#  array(['98.57944908928106', "['$uicideBoy$', 'Pouya']", 'BREAKDALAW2K16'],
#        dtype='<U661'),
#  array(['98.57938927415461', "['blink-182']", 'Blow Job - Live/1999'],
#        dtype='<U661'),
#  array(['98.57928159132452', "['Lil Peep']",
#         'skyscrapers (love now, cry later)'], dtype='<U661'),
#  array(['98.57926377864558', "['Alexander 23']", 'Mars'], dtype='<U661'),
#  array(['98.57912906756995', "['IDK', 'A$AP Ferg']", 'Mazel Tov'],
#        dtype='<U661'),
#  array(['98.57871440714105',
#         "['Eric Bellinger', 'Chris Brown', 'OG Parker']",
#         'Type a Way (feat. Chris Brown & OG Parker)'], dtype='<U661'),
#  array(['98.57857069553157', "['Ghostface Killah', 'U-God']",
#         'Cherchez LaGhost'], dtype='<U661'),
#  array(['98.5784176661966', "['Trippie Redd']", 'The Grinch'],
#        dtype='<U661'),
#  array(['98.57811497762847', "['Kanye West']", 'No Mistakes'],
#        dtype='<U661'),
#  array(['98.57809927452583', "['Juicy J', 'Travis Scott']",
#         'Neighbor (feat. Travis Scott)'], dtype='<U661'),
#  array(['98.57787586308953', "['Lil Yachty', 'Offset', 'Lil Baby']",
#         'MICKEY'], dtype='<U661'),
#  array(['98.57754978165016', "['Three 6 Mafia']", '44 Killers'],
#        dtype='<U661'),
#  array(['98.5774843704409', "['Zion & Lennox']", 'Mujer Satisfecha'],
#        dtype='<U661'),
#  array(['98.57739929685965',
#         "['Nate Dogg', 'Eminem', 'Obie Trice', 'Bobby Creekwater']",
#         'Shake That (Remix)'], dtype='<U661'),
#  array(['98.57739079059442', "['Sublime']", 'The Ballad Of Johnny Butt'],
#        dtype='<U661'),
#  array(['98.57713104818745',
#         "['2Pac', '50 Cent', 'Lloyd Banks', 'Young Buck']",
#         'Loyal To The Game'], dtype='<U661'),
#  array(['98.5770632636243', "['YG', 'DaBaby']",
#         'Stop Snitchin (feat. DaBaby) - Remix'], dtype='<U661'),
#  array(['98.57699434679486', "['Wiz Khalifa', 'Quavo']",
#         'Out in Space (feat. Quavo)'], dtype='<U661'),
#  array(['98.57699262419824', "['Lil Skies']", 'Big Money'], dtype='<U661'),
#  array(['98.57683329146654', "['Bad Bunny', 'Diplo', 'Nitti Gritti']",
#         '200 Mph'], dtype='<U661'),
#  array(['98.57683160982636', "['YoungBoy Never Broke Again']",
#         'Outside Today'], dtype='<U661'),
#  array(['98.57671151491444', "['Drake']", 'Madonna'], dtype='<U661'),
#  array(['98.57666575186177', "['Austin Awake']", 'ALL IN'], dtype='<U661'),
#  array(['98.57654274009282', "['Three 6 Mafia', 'Project Pat']",
#         'Roll With It (feat. Project Pat) - Explicit Album Version'],
#        dtype='<U661'),
#  array(['98.57652852031812', "['SAINt JHN', 'Lil Baby']", 'Trap'],
#        dtype='<U661'),
#  array(['98.57644354490952', "['Three 6 Mafia', 'Project Pat']",
#         'Roll With It - Explicit Album Version'], dtype='<U661'),
#  array(['98.57641322792828', "['Drake']", 'Gyalchester'], dtype='<U661'),
#  array(['98.57628900063241', "['Los Inquietos Del Norte']",
#         'Que Se Cree Ese Perro (En Vivo)'], dtype='<U661'),
#  array(['98.57628027615259', "['NAV']", 'She Hurtin'], dtype='<U661'),
#  array(['98.57620184013179', "['Bryson Tiller']", 'Self-Made'],
#        dtype='<U661'),
#  array(['98.57615641529789', "['Ashnikko']", 'Working Bitch'],
#        dtype='<U661'),
#  array(['98.57615503009956', "['Bazzi']", 'I.F.L.Y.'], dtype='<U661'),
#  array(['98.57608607372956', "['$uicideBoy$']",
#         '...And To Those I Love, Thanks For Sticking Around'],
#        dtype='<U661'),
#  array(['98.57597038853362', "['Maroon 5']", 'Makes Me Wonder'],
#        dtype='<U661'),
#  array(['98.5759682477456', "['Lil Peep']", 'yesterday'], dtype='<U661'),
#  array(['98.5759431046577', "['A Boogie Wit da Hoodie']", 'My Shit'],
#        dtype='<U661'),
#  array(['98.57589367489688', "['Lauv']", 'Tattoos Together'], dtype='<U661'),
#  array(['98.57578459358784', "['Lil Yachty', 'Draft Day']",
#         'Demon Time (Lil Yachty feat. Draft Day)'], dtype='<U661'),
#  array(['98.57569563931261', "['$uicideBoy$']", 'Hard To Tell'],
#        dtype='<U661'),
#  array(['98.57568808676656', "['Rihanna']", 'Birthday Cake'], dtype='<U661'),
#  array(['98.57565093869317',
#         "['DJ Scheme', 'Lil Yachty', 'Danny Towers', 'Ski Mask The Slump God']",
#         'How You Feel? (Freestyle) (feat. Lil Yachty, Danny Towers & Ski Mask The Slump God)'],
#        dtype='<U661'),
#  array(['98.5755851378295', "['Gerardo Coronel']", 'Te Deseo Lo Mejor'],
#        dtype='<U661'),
#  array(['98.5755441649984', "['NAV']", 'Did You Wrong'], dtype='<U661'),
#  array(['98.57537610444948', "['KINGMOSTWANTED']", 'High Power'],
#        dtype='<U661'),
#  array(['98.57533274971622', "['03 Greedo']", 'Run For Yo Life'],
#        dtype='<U661'),
#  array(['98.57532608633436', "['Rihanna']", 'Birthday Cake'], dtype='<U661'),
#  array(['98.5752535112766', "['LMFAO', 'Lil Jon']", 'Shots'], dtype='<U661'),
#  array(['98.575232395927', "['Speaker Knockerz']", 'Count up (Bonus)'],
#        dtype='<U661'),
#  array(['98.575219608367', "['iann dior', 'Trippie Redd']", 'gone girl'],
#        dtype='<U661'),
#  array(['98.5752174157208', "['Young Thug']", 'Best Friend'], dtype='<U661'),
#  array(['98.57508047696443', "['Mahogany Lox']", 'Take Your Man'],
#        dtype='<U661'),
#  array(['98.57500884127596', "['K CAMP']", 'Ice Cold'], dtype='<U661'),
#  array(['98.5749854131559', "['Migos']", 'Racks 2 Skinny'], dtype='<U661'),
#  array(['98.57496225498714', "['iann dior', 'Trippie Redd']", 'gone girl'],
#        dtype='<U661'),
#  array(['98.57458012116675', "['Mulatto']", 'He Say She Say'],
#        dtype='<U661'),
#  array(['98.57437072479235', "['Jay Rock']", 'WIN'], dtype='<U661'),
#  array(['98.57416301105023', "['Lil Uzi Vert']", 'Moon Relate'],
#        dtype='<U661'),
#  array(['98.57407636757947', "['Bazzi', '21 Savage']",
#         'Focus (feat. 21 Savage)'], dtype='<U661'),
#  array(['98.5739977513401', "['Travis Porter']", 'Bring It Back'],
#        dtype='<U661'),
#  array(['98.57392136178044', "['Kamil']", 'Bakugo!'], dtype='<U661'),
#  array(['98.57390718440838', "['Yella Beezy', 'Young Thug']", 'Headlocc'],
#        dtype='<U661'),
#  array(['98.57390196194208', "['Travis Scott']", 'NC-17'], dtype='<U661'),
#  array(['98.57383862816087', "['Screwston', 'Skrilla', 'Coast']",
#         'Murderholics'], dtype='<U661'),
#  array(['98.57381597100773', "['Young Dolph', 'Key Glock']",
#         '1 Hell of a Life'], dtype='<U661'),
#  array(['98.57380699907243', "['Migos']", 'Handsome And Wealthy'],
#        dtype='<U661'),
#  array(['98.5736848283009',
#         "['Timbaland', 'Justin Timberlake', 'Nelly Furtado']",
#         'Give It To Me'], dtype='<U661'),
#  array(['98.57347239660614', "['2Pac']", 'Thug 4 Life'], dtype='<U661'),
#  array(['98.57346343686667', "['Lil Jon', 'LMFAO']", 'Shots'],
#        dtype='<U661'),
#  array(['98.57327930338944', "['Tay-K']", 'Megaman'], dtype='<U661'),
#  array(['98.57324899856695', "['YG']", 'In The Dark'], dtype='<U661'),
#  array(['98.57322049091316', "['Travis Scott']", 'YOSEMITE'], dtype='<U661'),
#  array(['98.57321932382234', "['Tenacious D']", 'History'], dtype='<U661'),
#  array(['98.57312652469018', "['$uicideBoy$']",
#         'New Chains, Same Shackles'], dtype='<U661'),
#  array(['98.57295074040066', "['Princess Nokia']", 'I Like Him'],
#        dtype='<U661'),
#  array(['98.57269399225599',
#         "['Trippie Redd', 'YoungBoy Never Broke Again']", 'Hate Me'],
#        dtype='<U661'),
#  array(['98.5725821661036', "['Rihanna']", 'Pour It Up'], dtype='<U661'),
#  array(['98.57254505176108', "['Eminem']", 'Just Lose It'], dtype='<U661'),
#  array(['98.57248284966093', "['Kstylis']", 'Booty Me Down'], dtype='<U661'),
#  array(['98.57228059506062', "['Kodak Black']", 'Calling My Spirit'],
#        dtype='<U661'),
#  array(['98.57223050874126', "['Eminem']", 'Just Lose It'], dtype='<U661'),
#  array(['98.57221484474343', "['YNW Melly']", 'Wine For Me'], dtype='<U661'),
#  array(['98.57203886452392', "['Rihanna']", 'Pour It Up'], dtype='<U661'),
#  array(['98.57200756433673', "['Q-Tip']", 'Vivrant Thing - Club Mix'],
#        dtype='<U661'),
#  array(['98.57200407407827', "['iann dior']", 'Pretty Girls'],
#        dtype='<U661'),
#  array(['98.5719000175793', "['Bazzi']", 'Mine'], dtype='<U661'),
#  array(['98.57168228133763', "['DaniLeigh', 'Lil Baby']",
#         'Lil Bebe (feat. Lil Baby) - Remix'], dtype='<U661'),
#  array(['98.57165089877446', "['Bazzi']", 'No Way!'], dtype='<U661'),
#  array(['98.57164004954315', "['Tory Lanez']", 'Broke In A Minute'],
#        dtype='<U661'),
#  array(['98.57163640503232',
#         "['XXXTENTACION', 'PnB Rock', 'Trippie Redd']",
#         'bad vibes forever'], dtype='<U661'),
#  array(['98.57160287523482', "['Yung Gravy', 'Chief Keef', 'Y2K']",
#         'Tampa Bay Bustdown'], dtype='<U661'),
#  array(['98.57154579016611', "['blackbear', 'Tiny Meat Gang']",
#         'Short Kings Anthem'], dtype='<U661'),
#  array(['98.57152511615173', "['Megan Thee Stallion', 'VickeeLo']",
#         'Ride Or Die - From "Queen & Slim: The Soundtrack"'], dtype='<U661'),
#  array(['98.5714934309324', "['XXXTENTACION', 'PnB Rock', 'Trippie Redd']",
#         'bad vibes forever'], dtype='<U661'),
#  array(['98.57140276609258', "['Vince Staples']", 'Norf Norf'],
#        dtype='<U661'),
#  array(['98.57135910121113', "['Eminem']", 'Just Lose It'], dtype='<U661'),
#  array(['98.57124490674207', "['FIDLAR']", 'Sober'], dtype='<U661'),
#  array(['98.57112097258799', "['NAV']", 'Brown Boy'], dtype='<U661'),
#  array(['98.5710399889169', "['City Girls']", 'Take Yo Man'], dtype='<U661'),
#  array(['98.57096391819303', "['JAY-Z']", 'Change Clothes'], dtype='<U661'),
#  array(['98.57082880335597', "['Moe']", 'Outta There'], dtype='<U661'),
#  array(['98.57081895528759', "['Chris Brown', 'Kevin McCall']",
#         'Strip (feat. Kevin McCall)'], dtype='<U661'),
#  array(['98.57081039252857', "['OutKast']", '?'], dtype='<U661'),
#  array(['98.5707829344956', "['Machine Gun Kelly']", 'Dopeman'],
#        dtype='<U661'),
#  array(['98.57067010544753', "['Aminé']", 'BLACKJACK'], dtype='<U661'),
#  array(['98.57065570521513', "['Eric Bellinger', 'Fetty Wap', '2 Chainz']",
#         'Valet (feat. Fetty Wap and 2 Chainz)'], dtype='<U661'),
#  array(['98.57055830645041', "['South Park Mexican']", 'High So High'],
#        dtype='<U661'),
#  array(['98.57044047538963', "['Too $hort']", 'Blow the Whistle'],
#        dtype='<U661'),
#  array(['98.57034448073274', "['Y2K', 'bbno$']", 'Lalala'], dtype='<U661'),
#  array(['98.57024113886725',
#         "['Summer Walker', 'London On Da Track', 'Chris Brown']",
#         'Something Real (with London On Da Track & Chris Brown)'],
#        dtype='<U661'),
#  array(['98.57023508206362', "['Aminé', 'Nelly']", 'Yellow'], dtype='<U661'),
#  array(['98.5701978167866',
#         "['Beast Coast', 'Joey Bada$$', 'Flatbush Zombies', 'Issa Gold', 'Erick the Architect', 'Powers Pleasant']",
#         'Distance (feat. Issa Gold & Erick The Architect)'], dtype='<U661'),
#  array(['98.57019696877612', "['Playboi Carti', 'A$AP Rocky']",
#         'New Choppa'], dtype='<U661'),
#  array(['98.570178653234', "['Skye', 'XXXTENTACION']",
#         'VOICES (feat. XXXTENTACION)'], dtype='<U661'),
#  array(['98.57015888280716', "['Dom Kennedy']", 'I Love Dom'],
#        dtype='<U661'),
#  array(['98.57015797116308', "['Red Hot Chili Peppers']",
#         'Out In L.A. - 2002 Digital Remaster'], dtype='<U661'),
#  array(['98.5701374167752', "['Twista', 'Chris Brown']", 'Make A Movie'],
#        dtype='<U661'),
#  array(['98.57008836265058', "['Future']", '(Bonus) Itchin'], dtype='<U661'),
#  array(['98.5700025903103', "['Nate Dogg', 'Dr. Dre']",
#         'Your Wife (feat. Dr. Dre)'], dtype='<U661'),
#  array(['98.56999372325392', "['Jeezy', 'Bankroll Fresh']", 'All There'],
#        dtype='<U661'),
#  array(['98.56978458952294', "['Kid Ink', 'Usher', 'Tinashe']",
#         'Body Language (feat. Usher & Tinashe)'], dtype='<U661'),
#  array(['98.56967832308464', "['KGodd']", 'Daygo'], dtype='<U661'),
#  array(['98.56958355067952', "['Doja Cat']", 'Cyber Sex'], dtype='<U661'),
#  array(['98.56939161871686', "['Snoop Dogg']", 'G Funk (Intro)'],
#        dtype='<U661'),
#  array(['98.56931112724223', "['Lil Tecca']", 'Shots'], dtype='<U661'),
#  array(['98.56928921411003', "['Eric Bellinger', 'Fetty Wap', '2 Chainz']",
#         'Valet (feat. Fetty Wap and 2 Chainz)'], dtype='<U661'),
#  array(['98.56927713294691', "['NAV', 'Don Toliver']",
#         'Recap (feat. Don Toliver)'], dtype='<U661'),
#  array(['98.56924774025785', "['Upchurch']", 'Hillbilly'], dtype='<U661'),
#  array(['98.56921522860715', "['$uicideBoy$', 'Denzel Curry']",
#         'Ultimate $uicide'], dtype='<U661'),
#  array(['98.56917305743453', "['Chris Brown', 'Tyga']", 'Ayo'],
#        dtype='<U661'),
#  array(['98.5691614100489', "['Sublime']", 'Wrong Way'], dtype='<U661'),
#  array(['98.5690333682958', "['Kid Ink', 'Usher', 'Tinashe']",
#         'Body Language (feat. Usher & Tinashe)'], dtype='<U661'),
#  array(['98.56896847911702', "['Kehlani']", 'F&MU'], dtype='<U661'),
#  array(['98.5689353453363', "['Meghan Trainor']", 'All About That Bass'],
#        dtype='<U661'),
#  array(['98.56891414513726', "['Roddy Ricch']",
#         'Feed Tha Streets 2 (Intro)'], dtype='<U661'),
#  array(['98.56886216232255', "['Anti-Flag']",
#         '1 Trillion Dollar$ - Dirty Version'], dtype='<U661'),
#  array(['98.56882065285728',
#         "['Machine Gun Kelly', 'Young Thug', 'RJMrLA', 'Lil Duke']",
#         'Bullets With Names (feat. Young Thug, RJMrLA & Lil Duke)'],
#        dtype='<U661'),
#  array(['98.56879824607306', "['Kevin Gates']", 'By My Lonely'],
#        dtype='<U661'),
#  array(['98.56879603565157', "['Jack Harlow', '2forwOyNE']",
#         'WARSAW (feat. 2forwOyNE)'], dtype='<U661'),
#  array(['98.56878760826346', "['Kid Ink', 'Chris Brown']",
#         'Main Chick (feat. Chris Brown)'], dtype='<U661'),
#  array(['98.56866098420204', "['Ty Dolla $ign', 'YG']", 'Ex (feat. YG)'],
#        dtype='<U661'),
#  array(['98.56863801401211', "['Doja Cat', 'Tyga']", 'Juicy'],
#        dtype='<U661'),
#  array(['98.56859962713233', "['$uicideBoy$']",
#         'CLYDE (I Hope At Least One Of My Ex-Girlfriends Hears This)'],
#        dtype='<U661'),
#  array(['98.56849582852857', "['Muse']", 'Panic Station'], dtype='<U661'),
#  array(['98.56839576179229', "['$uicideBoy$']", 'Exodus'], dtype='<U661'),
#  array(['98.56838230911937', "['Oliver Tree']", 'Alien Boy'], dtype='<U661'),
#  array(['98.56835766611069', "['The Suicide Machines']", 'No Face'],
#        dtype='<U661'),
#  array(['98.5683101855689', "['$uicideBoy$']", 'Eclipse'], dtype='<U661'),
#  array(['98.56825972419313', "['Russ']", 'Some Time'], dtype='<U661'),
#  array(['98.56824709931294', "['T-Pain']", 'Get Up'], dtype='<U661'),
#  array(['98.5681965885807', "['Russ', 'BIA']",
#         'BEST ON EARTH (feat. BIA) - Bonus'], dtype='<U661'),
#  array(['98.56816645085546', "['Lil Baby']", 'Freestyle'], dtype='<U661'),
#  array(['98.56809755639614', "['Molotov']", 'Frijolero'], dtype='<U661'),
#  array(['98.56798740705828', "['Iggy Azalea', 'Charli XCX']", 'Fancy'],
#        dtype='<U661'),
#  array(['98.5679864176205', "['Meghan Trainor']", 'All About That Bass'],
#        dtype='<U661'),
#  array(['98.56796922220374', "['Sammy Adams']", 'All Night Longer'],
#        dtype='<U661'),
#  array(['98.56792648810264', "['Hollywood Undead']", 'Whatever It Takes'],
#        dtype='<U661'),
#  array(['98.5679264841527', "['Insane Clown Posse']", 'My Axe'],
#        dtype='<U661'),
#  array(['98.56780749723112', "['MadeinTYO', 'A$AP Ferg']",
#         'Ned Flanders (feat. A$AP Ferg)'], dtype='<U661'),
#  array(['98.56780579034974', "['Drake', 'Playboi Carti']",
#         'Pain 1993 (with Playboi Carti)'], dtype='<U661'),
#  array(['98.56777692644607', "['Playboi Carti', 'Young Nudy']",
#         'R.I.P. Fredo (feat. Young Nudy) - Notice Me'], dtype='<U661'),
#  array(['98.56777368458734', "['Saweetie', 'Jhené Aiko', 'City Girls']",
#         'My Type (feat. City Girls & Jhené Aiko) - Remix'], dtype='<U661'),
#  array(['98.56776421668782', "['DaBaby', 'Stunna 4 Vegas']",
#         'REALLY (feat. Stunna 4 Vegas)'], dtype='<U661'),
#  array(['98.56775061941063', "['Conan Gray']", 'Wish You Were Sober'],
#        dtype='<U661'),
#  array(['98.5677504852041', "['Trevor Daniel', 'Summer Walker']",
#         'Falling (Summer Walker Remix)'], dtype='<U661'),
#  array(['98.56774844875599', "['Jack Harlow']", 'SUNDOWN'], dtype='<U661'),
#  array(['98.56772855704949', "['Solange']", 'Almeda'], dtype='<U661'),
#  array(['98.56767561749585', "['Lil Peep', 'Lil Tracy']", 'white tee'],
#        dtype='<U661'),
#  array(['98.56766485340086', "['Doja Cat', 'Tyga']", 'Juicy'],
#        dtype='<U661'),
#  array(['98.5675960216099', "['Doja Cat']", 'Juicy'], dtype='<U661'),
#  array(['98.567548181303', "['Lil Mosey']", 'Live This Wild'],
#        dtype='<U661'),
#  array(['98.56754617538954', "['Josh A', 'Iamjakehill']",
#         'Endless Nightmare'], dtype='<U661'),
#  array(['98.56751336264963', "['Young Thug']", 'Millions'], dtype='<U661'),
#  array(['98.56743963414868', "['DripReport', 'Tyga']",
#         'Skechers (feat. Tyga) - Remix'], dtype='<U661'),
#  array(['98.56742374917759', "['Arizona Zervas']", 'Swerve'], dtype='<U661'),
#  array(['98.56740993464419', "['Drake', 'Rick Ross']",
#         'Money In The Grave (Drake ft. Rick Ross)'], dtype='<U661'),
#  array(['98.567363059981', "['Esteban Gabriel']", 'Tirando la H'],
#        dtype='<U661'),
#  array(['98.567356722319', "['Wiz Khalifa']", 'Cabin Fever'], dtype='<U661'),
#  array(['98.56734323148162', "['Pretty Ricky']", 'Boo Thang'],
#        dtype='<U661'),
#  array(['98.5673072907336', "['Money Man']", '24'], dtype='<U661'),
#  array(['98.56729384989232', "['Don Toliver']", 'Wasted'], dtype='<U661'),
#  array(['98.56723252958454', "['Ester Dean', 'Chris Brown']",
#         'Drop It Low'], dtype='<U661'),
#  array(['98.56719142277535', "['Jasiah', '6ix9ine']",
#         'Case 19 (feat. 6ix9ine)'], dtype='<U661'),
#  array(['98.56718339667923', "['KSI', 'Aiyana-Lee']",
#         'Killa Killa (feat. Aiyana-Lee)'], dtype='<U661'),
#  array(['98.56716224245689', "['Rae Sremmurd']", 'No Flex Zone'],
#        dtype='<U661'),
#  array(['98.56716062607993', "['Tenacious D']", 'Friendship'],
#        dtype='<U661'),
#  array(['98.56713593482576', "['SAINt JHN', 'Imanbek']",
#         'Roses - Imanbek Remix'], dtype='<U661'),
#  array(['98.5670961093294', "['Huncho Jack', 'Travis Scott', 'Quavo']",
#         'Motorcycle Patches'], dtype='<U661'),
#  array(['98.56708969202819', "['Prince']", 'Sister'], dtype='<U661'),
#  array(['98.567022050004', "['Machine Gun Kelly', 'Trippie Redd']",
#         'Candy (feat. Trippie Redd)'], dtype='<U661'),
#  array(['98.56701063841221', "['24kGoldn', 'Imanbek']",
#         'VALENTINO - Imanbek Remix'], dtype='<U661'),
#  array(['98.56693259008344', "['Miranda!']", 'Don'], dtype='<U661'),
#  array(['98.56690917658418', "['Eminem']", 'Rock Bottom'], dtype='<U661'),
#  array(['98.56680638984545',
#         "['Shoreline Mafia', 'OHGEESY', 'Fenix Flexin']", 'Wings'],
#        dtype='<U661'),
#  array(['98.56679347580938', "['Project Pat']", 'Niggas Got Me Fucked Up'],
#        dtype='<U661'),
#  array(['98.56679102575094', "['Lil Mosey']", 'Blueberry Faygo'],
#        dtype='<U661'),
#  array(['98.56672213857146', "['South Park Mexican']", 'Screens Falling'],
#        dtype='<U661'),
#  array(['98.56667664647102', "['Lil Mosey']", 'Blueberry Faygo'],
#        dtype='<U661'),
#  array(['98.56667260510439',
#         "['Wiz Khalifa', 'Snoop Dogg', 'Ty Dolla $ign']",
#         'You and Your Friends (feat. Snoop Dogg & Ty Dolla $ign)'],
#        dtype='<U661'),
#  array(['98.5666486204088', "['Lil Baby']", 'Social Distancing'],
#        dtype='<U661'),
#  array(['98.56663626982278', "['Three 6 Mafia', 'Paula Campbell']",
#         'Hard Out Here for a Pimp'], dtype='<U661'),
#  array(['98.56657865214595', "['Trippie Redd']", 'Lil Wayne'],
#        dtype='<U661'),
#  array(['98.56653271751273', "['The Beatnuts', 'Big Pun', 'Cuban Linx']",
#         'Off the Books (feat. Big Pun & Cuban Linx)'], dtype='<U661'),
#  array(['98.56642583387517', "['YBN Cordae']", 'Kung Fu'], dtype='<U661'),
#  array(['98.56638629283968', "['Playboi Carti', 'Skepta']",
#         'Lean 4 Real (feat. Skepta)'], dtype='<U661'),
#  array(['98.56637915912889', "['Kodak Black']", "Transportin'"],
#        dtype='<U661'),
#  array(['98.56626080495748', "['Saweetie', 'Quavo']",
#         'Tip Toes (feat. Quavo)'], dtype='<U661'),
#  array(['98.56625900284803', "['Never Shout Never']", "Can't Stand It"],
#        dtype='<U661'),
#  array(['98.56623432203142', "['Logic']", 'Everybody'], dtype='<U661'),
#  array(['98.56620765697465', "['XXXTENTACION']",
#         'A GHETTO CHRISTMAS CAROL'], dtype='<U661'),
#  array(['98.56617867374798', "['Quinn XCII']", "Bootleggin'"],
#        dtype='<U661'),
#  array(['98.5661545539703', "['Problem']", "Don't Be Mad At Me"],
#        dtype='<U661'),
#  array(['98.56608978242002', "['Xavier Wulf']", 'Mobile Suit Woe'],
#        dtype='<U661'),
#  array(['98.5660261256052', "['Nicki Minaj']", 'Good Form'], dtype='<U661'),
#  array(['98.56578592631543', "['Amy Winehouse']", 'Fuck Me Pumps'],
#        dtype='<U661'),
#  array(['98.56577523324603', "['Iggy Azalea']", 'Team'], dtype='<U661'),
#  array(['98.56576273142463', "['Black Joe Lewis & The Honeybears']",
#         'Get Yo Shit'], dtype='<U661'),
#  array(['98.56575786547573', "['Gucci Mane', 'Megan Thee Stallion']",
#         'Big Booty (feat. Megan Thee Stallion)'], dtype='<U661'),
#  array(['98.56574837674758', "['iann dior']", 'Never Is Enough'],
#        dtype='<U661'),
#  array(['98.56571922352309',
#         "['Smokepurpp', 'Murda Beatz', 'Lil Yachty', 'Offset']",
#         'Do Not Disturb (feat. Lil Yachty & Offset)'], dtype='<U661'),
#  array(['98.56571487622882', "['Steve Lacy']", 'Some'], dtype='<U661'),
#  array(['98.56571328799028', "['Trippie Redd']", "Can't Love"],
#        dtype='<U661'),
#  array(['98.56571084426342', "['Tyga', 'Megan Thee Stallion']", 'FREAK'],
#        dtype='<U661'),
#  array(['98.5656866833828', "['Bad Bunny']", 'La Zona'], dtype='<U661'),
#  array(['98.56561043175212', "['Pouya', 'Ghostemane']", '1000 Rounds'],
#        dtype='<U661'),
#  array(['98.56559811963928', "['N.E.R.D', 'Rihanna', 'Pharrell Williams']",
#         'Lemon'], dtype='<U661'),
#  array(['98.56551495499096', "['Scarface']", "Mind Playin' Tricks 94"],
#        dtype='<U661'),
#  array(['98.56548272749444', "['Bazzi']", 'Young & Alive'], dtype='<U661'),
#  array(['98.56544656925901', "['Lil Peep']", 'ghost boy'], dtype='<U661'),
#  array(['98.56539715021775',
#         "['Quality Control', 'Offset', 'DaBaby', 'Gunna']",
#         'Pink Toes (Offset, DaBaby feat. Gunna)'], dtype='<U661'),
#  array(['98.56537659318937', "['Waka Flocka Flame']", 'Rooster in My Rari'],
#        dtype='<U661'),
#  array(['98.56533650037933', "['XXXTENTACION', 'Matt Ox']",
#         '$$$ - with Matt Ox'], dtype='<U661'),
#  array(['98.56526910100033', "['The Lonely Island', 'Justin Timberlake']",
#         'Motherlover'], dtype='<U661'),
#  array(['98.56523304862962',
#         "['Young Money', 'Tyga', 'Nicki Minaj', 'Lil Wayne']", 'Senile'],
#        dtype='<U661'),
#  array(['98.56522330113124', "['Croosh']", 'Zeus'], dtype='<U661'),
#  array(['98.56521695616279', "['Ariana Grande']", 'goodnight n go'],
#        dtype='<U661'),
#  array(['98.56518680609379', "['Akon']", 'Locked Up'], dtype='<U661'),
#  array(['98.56515827291493', "['Juicy J', 'Project Pat']",
#         'Twerk (feat. Project Pat)'], dtype='<U661'),
#  array(['98.5651412551587', "['Ariana Grande']", 'pete davidson'],
#        dtype='<U661'),
#  array(['98.56513116259383', "['Lil Peep', 'Lil Tracy']", 'white tee'],
#        dtype='<U661'),
#  array(['98.56512056104037',
#         "['Justin Quiles', 'Daddy Yankee', 'El Alfa']", 'PAM'],
#        dtype='<U661'),
#  array(['98.56510834518218', "['Ben Folds', 'Regina Spektor']",
#         "You Don't Know Me (feat. Regina Spektor)"], dtype='<U661'),
#  array(['98.56509402201141', "['Comethazine']", 'Permanent'], dtype='<U661'),
#  array(['98.5650282649597', "['Lil Wayne', 'Sosamann']",
#         'What About Me (feat. Sosamann)'], dtype='<U661'),
#  array(['98.56496901379137', "['Eminem']", 'Rock Bottom'], dtype='<U661'),
#  array(['98.56493853721747', "['Kanye West']", "Frank's Track"],
#        dtype='<U661'),
#  array(['98.56493504849817', "['Bad Bunny', 'Sech']", 'Ignorantes'],
#        dtype='<U661'),
#  array(['98.56488905640714', "['Trippie Redd']", 'Loyalty Before Royalty'],
#        dtype='<U661'),
#  array(['98.56484464129784', "['Lil Reese', 'Chief Keef']", 'Traffic'],
#        dtype='<U661'),
#  array(['98.56476852032242', "['Oliver Tree']", 'Miracle Man'],
#        dtype='<U661'),
#  array(['98.56476280345495', "['A Boogie Wit da Hoodie']", 'Mood Swings'],
#        dtype='<U661'),
#  array(['98.5647004067921', "['Project Pat']", 'North North'],
#        dtype='<U661'),
#  array(['98.56466195744045', "['Rich The Kid']", 'Plug Walk'],
#        dtype='<U661'),
#  array(['98.56454867067', "['Nelly']",
#         'N Dey Say - Album Version / Explicit'], dtype='<U661'),
#  array(['98.56441706073889',
#         "['Aesop Rock', 'Del The Funky Homosapien', 'Wu-Tang Clan']",
#         'Preservation'], dtype='<U661'),
#  array(['98.56441074891876', "['The Click']", 'Out My Body'], dtype='<U661'),
#  array(['98.56439226177795',
#         "['ОТВАЛ БАWKN', 'Cartier99', 'Hackequation']", 'Trap'],
#        dtype='<U661'),
#  array(['98.56437167812282', "['50 Cent']", 'What Up Gangsta'],
#        dtype='<U661'),
#  array(['98.56434465834592', "['XXXTENTACION']", 'Ex Bitch'], dtype='<U661'),
#  array(['98.56428300996832', "['Lil Skies']", 'Going Off'], dtype='<U661'),
#  array(['98.56421117213485', "['Ty Dolla $ign', 'Gucci Mane', 'Quavo']",
#         'Pineapple (feat. Gucci Mane & Quavo)'], dtype='<U661'),
#  array(['98.5642075784839', "['50 Cent']", 'What Up Gangsta'],
#        dtype='<U661'),
#  array(['98.56419185646928', "['iann dior']", 'crash my whip'],
#        dtype='<U661'),
#  array(['98.5641679831553', "['Young Dolph']", 'Sunshine'], dtype='<U661'),
#  array(['98.56415216448406', "['BIA']", 'COVER GIRL'], dtype='<U661'),
#  array(['98.56410553878109', "['NAV']", 'Saint Laurenttt'], dtype='<U661'),
#  array(['98.56405114395565', "['iann dior', 'Gunna']", 'Strings'],
#        dtype='<U661'),
#  array(['98.56402217032795', "['JAY-Z']", 'Interlude'], dtype='<U661'),
#  array(['98.56400567113045', "['Tenacious D']", 'Lee'], dtype='<U661'),
#  array(['98.56398715314383', '["Fun Lovin\' Criminals"]', 'Scooby Snacks'],
#        dtype='<U661'),
#  array(['98.56398590846229', "['Trippie Redd']", 'Love Me More'],
#        dtype='<U661'),
#  array(['98.56396109816211', "['Nicki Minaj', 'Drake', 'Lil Wayne']",
#         'Truffle Butter'], dtype='<U661'),
#  array(['98.56381725785553', "['Bruno Mars']", 'Treasure'], dtype='<U661'),
#  array(['98.56380589218175', "['Fetty Wap', 'Monty']",
#         'My Way (feat. Monty)'], dtype='<U661'),
#  array(['98.56379249592347', "['XXXTENTACION']", 'ATTENTION!'],
#        dtype='<U661'),
#  array(['98.56375714990241', "['Trippie Redd']", 'Love Me More'],
#        dtype='<U661'),
#  array(['98.56375268329636', "['Bad Bunny', 'Don Omar']", "PA' ROMPERLA"],
#        dtype='<U661'),
#  array(['98.56369535262534', "['Wire']",
#         'Mr Suit - 2006 Remastered Version'], dtype='<U661'),
#  array(['98.56365125938491', "['The Offspring']",
#         "Why Don't You Get A Job"], dtype='<U661'),
#  array(['98.56363664282718', "['JAY-Z', 'Linkin Park']",
#         "Big Pimpin' / Papercut"], dtype='<U661'),
#  array(['98.56361558366842', "['Pastor Troy']", 'Vica Versa'],
#        dtype='<U661'),
#  array(['98.56361152398037', "['Logic', 'Big Sean']", 'Alright'],
#        dtype='<U661'),
#  array(['98.56354767386586', "['Shwayze', 'Cisco Adler']", "Buzzin'"],
#        dtype='<U661'),
#  array(['98.56350169910084', "['Adam Calhoun', 'Upchurch']", 'Die Tonight'],
#        dtype='<U661'),
#  array(['98.56347012500181', "['Young M.A', 'Relle Bey', 'Max YB']",
#         'NNAN'], dtype='<U661'),
#  array(['98.56344619977331', "['T.I.', 'Iggy Azalea']",
#         'No Mediocre (feat. Iggy Azalea)'], dtype='<U661'),
#  array(['98.56344218361163', "['Young Thug', 'Lil Baby']",
#         'Bad Bad Bad (feat. Lil Baby)'], dtype='<U661'),
#  array(['98.5634242259778', "['Rich Brian', 'Joji']",
#         'Introvert (feat. Joji)'], dtype='<U661'),
#  array(['98.56340398431139', "['Shiny Toy Guns']", 'Le Disko'],
#        dtype='<U661'),
#  array(['98.56328702777101', "['Jelly Roll']", 'Only'], dtype='<U661'),
#  array(['98.56322173642808', "['Kiya Juliet']", 'How Could You Play Me'],
#        dtype='<U661'),
#  array(['98.56318776511867', "['Run The Jewels']", 'Get It'], dtype='<U661'),
#  array(['98.563185132586', "['XXXTENTACION']", 'Floor 555'], dtype='<U661'),
#  array(['98.56314359172832',
#         "['YoungBoy Never Broke Again', 'Kevin Gates']",
#         'Head On (feat. Kevin Gates)'], dtype='<U661'),
#  array(['98.56308217087069', "['blackbear']", 'me & ur ghost'],
#        dtype='<U661'),
#  array(['98.56300763154134', "['Loote']", 'Your Side Of The Bed'],
#        dtype='<U661'),
#  array(['98.56295696845757', "['Ski Mask The Slump God']", 'Foot Fungus'],
#        dtype='<U661'),
#  array(['98.56293474659863', '[\'The Notorious B.I.G.\', "Lil\' Kim"]',
#         "Another (feat. Lil' Kim) - 2014 Remaster"], dtype='<U661'),
#  array(['98.56293368972771', "['$uicideBoy$']", 'Fold'], dtype='<U661'),
#  array(['98.56292726661012', "['Kevin Gates']", 'Plug Daughter'],
#        dtype='<U661'),
#  array(['98.56290818740938', "['Bad Bunny']", 'Vete'], dtype='<U661'),
#  array(['98.5628466131201', "['SZA']", 'Prom'], dtype='<U661'),
#  array(['98.56283757485492', "['Gunna', 'Young Thug']",
#         'DOLLAZ ON MY HEAD (feat. Young Thug)'], dtype='<U661'),
#  array(['98.56278539313386', "['Sik World']", '7 Years (Remix)'],
#        dtype='<U661'),
#  array(['98.56277494553704', "['Bad Bunny']", 'Vete'], dtype='<U661'),
#  array(['98.56258158531016', "['Rich Brian']", '100 Degrees'],
#        dtype='<U661'),
#  array(['98.56257410849688', "['Tenacious D']", 'POD'], dtype='<U661'),
#  array(['98.562502389966', "['Gucci Mane']", 'Freaky Girl'], dtype='<U661'),
#  array(['98.56247055524291', "['Sublime']", '40oz. To Freedom'],
#        dtype='<U661'),
#  array(['98.5624648093397', "['Bazzi']", 'Paradise'], dtype='<U661'),
#  array(['98.5623939118112', "['Young Thug', 'Future']",
#         'Relationship (feat. Future)'], dtype='<U661'),
#  array(['98.56239145535129', "['Paris Shadows', 'Trippie Redd']",
#         'GONE (feat. Trippie Redd)'], dtype='<U661'),
#  array(['98.56237245951377', "['Young Thug']", 'Digits'], dtype='<U661'),
#  array(['98.56233902246152', "['Lil Mosey', 'Chris Brown']",
#         'G Walk (with Chris Brown)'], dtype='<U661'),
#  array(['98.56229454346436', "['Diplo', 'Morgan Wallen']",
#         'Heartless (feat. Morgan Wallen)'], dtype='<U661'),
#  array(['98.56229435626763', "['Saweetie']", 'My Type'], dtype='<U661'),
#  array(['98.56229374640878', "['Machine Gun Kelly']", 'el Diablo'],
#        dtype='<U661'),
#  array(['98.56224314576404', "['Akon']", 'Locked Up'], dtype='<U661'),
#  array(['98.56219288549856', "['K.Flay']", 'Blood In The Cut'],
#        dtype='<U661'),
#  array(['98.56218896591399', "['Young Roc']", 'We Are Not the Same'],
#        dtype='<U661'),
#  array(['98.56217242875529', "['Doja Cat']", 'Bottom Bitch'], dtype='<U661'),
#  array(['98.56216818069028', "['N.W.A.']", 'Automobile'], dtype='<U661'),
#  array(['98.56216750127729', "['Rozei']", 'Ooo La La'], dtype='<U661'),
#  array(['98.56215700498771', "['Tiny Meat Gang']", 'Walk Man'],
#        dtype='<U661'),
#  array(['98.56210126610148', "['NAV', 'Gunna', 'Travis Scott']",
#         'Turks (feat. Travis Scott)'], dtype='<U661'),
#  array(['98.56207003928134', "['Trippie Redd', '6ix9ine']", 'Poles 1469'],
#        dtype='<U661'),
#  array(['98.5620696799304', "['Mike Jones', 'Big Moe']",
#         "Flossin' (feat. Big Moe)"], dtype='<U661'),
#  array(['98.56202868218118', "['Ghostemane']", 'Venom'], dtype='<U661'),
#  array(['98.56201841848396', "['Amy Winehouse']", 'Just Friends'],
#        dtype='<U661'),
#  array(['98.56199433933173', "['A$AP Ferg']", 'Value'], dtype='<U661'),
#  array(['98.56197003031279', "['RJMrLA']", 'Hoes Come Easy'], dtype='<U661'),
#  array(['98.56192960542214', "['Eazy-E']", 'Creep n Crawl'], dtype='<U661'),
#  array(['98.56176651044035', '[\'Dr. Dre\', \'Eminem\', "Knoc-Turn\'al"]',
#         'The Watcher'], dtype='<U661'),
#  array(['98.56176425880169', "['Flipp Dinero']", 'Leave Me Alone'],
#        dtype='<U661'),
#  array(['98.56165961174935', "['Flipp Dinero']", 'Leave Me Alone'],
#        dtype='<U661'),
#  array(['98.56161072149273', "['Sage The Gemini']", "Don't You"],
#        dtype='<U661'),
#  array(['98.56151531643104', "['Baby Bash', 'Akon']", "Baby, I'm Back"],
#        dtype='<U661'),
#  array(['98.56146619132623',
#         "['A$AP Mob', 'A$AP Twelvyy', 'A$AP ANT', 'A$AP NAST', 'A$AP Ferg', 'Playboi Carti']",
#         'Walk On Water (feat. A$AP Twelvyy, A$AP Ant, A$AP Nast, A$AP Ferg & Playboi Carti)'],
#        dtype='<U661'),
#  array(['98.56144720860412', "['Mustard', 'Travis Scott', 'YG']",
#         'Dangerous World (feat. Travis Scott & YG)'], dtype='<U661'),
#  array(['98.56144551606646', "['21 Savage']", 'ball w/o you'],
#        dtype='<U661'),
#  array(['98.56143891782035', "['Dua Lipa']", 'IDGAF'], dtype='<U661'),
#  array(['98.56142683271912', "['Puri', 'Jhorrmountain', 'Adje']", 'Coño'],
#        dtype='<U661'),
#  array(['98.56142495468926', "['lil ricefield', 'seiji oda']", 'Trapanese'],
#        dtype='<U661'),
#  array(['98.5613958266132', "['Anderson .Paak']", 'Put Me Thru'],
#        dtype='<U661'),
#  array(['98.56133392100611', "['Drake']", '6 God'], dtype='<U661'),
#  array(['98.5612901416187', "['Lil Pump']", 'Esskeetit'], dtype='<U661'),
#  array(['98.56123500743308', "['PARTYNEXTDOOR']", 'Welcome to the Party'],
#        dtype='<U661'),
#  array(['98.5612160654658', "['Machine Gun Kelly']",
#         'Half Naked & Almost Famous'], dtype='<U661'),
#  array(['98.56118863815888', "['Wiz Khalifa']", 'Ass Drop'], dtype='<U661'),
#  array(['98.56112228506076', "['Famous Dex', 'A$AP Rocky']",
#         'PICK IT UP (feat. A$AP Rocky)'], dtype='<U661'),
#  array(['98.5610639949343',
#         "['MOD SUN', 'Machine Gun Kelly', 'Goody Grace']",
#         'Stay Away (feat. Machine Gun Kelly & Goody Grace)'], dtype='<U661'),
#  array(['98.56104508093334', "['Calvin Harris', 'Big Sean']",
#         'Open Wide (feat. Big Sean)'], dtype='<U661'),
#  array(['98.56104033960611', "['Ludacris', 'Sleepy Brown']",
#         'Blueberry Yum Yum'], dtype='<U661'),
#  array(['98.56099795629191', "['Mindless Self Indulgence']", "Boomin'"],
#        dtype='<U661'),
#  array(['98.56098904318843', "['Famous Dex', 'A$AP Rocky']",
#         'PICK IT UP (feat. A$AP Rocky)'], dtype='<U661'),
#  array(['98.56093388015405', "['Lil Yachty', 'DaBaby', 'Drake']",
#         'Oprah’s Bank Account (Lil Yachty & DaBaby feat. Drake)'],
#        dtype='<U661'),
#  array(['98.56093199603124', "['French Montana', 'Tory Lanez']", 'Cold'],
#        dtype='<U661'),
#  array(['98.56092183259469',
#         "['Huncho Jack', 'Travis Scott', 'Quavo', 'Takeoff']", 'Eye 2 Eye'],
#        dtype='<U661'),
#  array(['98.56090502746908', "['blackbear']", 'Dirty Laundry'],
#        dtype='<U661'),
#  array(['98.56089954660446', "['Roddy Ricch', 'Ty Dolla $ign']",
#         'Bacc Seat (feat. Ty Dolla $ign)'], dtype='<U661'),
#  array(['98.56089558695435', "['Metro Boomin', '21 Savage']",
#         "Don't Come Out The House (with 21 Savage)"], dtype='<U661'),
#  array(['98.5608448985729', "['Big Sean']", 'Moves'], dtype='<U661'),
#  array(['98.56082636784973', "['Sublime']", 'What I Got'], dtype='<U661'),
#  array(['98.5607414063809', "['Travis Scott']", 'goosebumps'],
#        dtype='<U661'),
#  array(['98.56073930830317', "['Baby Bash', 'Akon']", "Baby, I'm Back"],
#        dtype='<U661'),
#  array(['98.56069661792564', "['Shwayze']", 'Love Is Overrated'],
#        dtype='<U661'),
#  array(['98.56064898757184', "['Wiz Khalifa']", 'The Kid Frankie'],
#        dtype='<U661'),
#  array(['98.56040810261854', "['Eazy-E']", 'Gimmie That Nutt'],
#        dtype='<U661'),
#  array(['98.5603949610996', "['Too $hort']", 'Gangsters & Strippers'],
#        dtype='<U661'),
#  array(['98.56037411815586', "['O.T. Genasis']", 'Everybody Mad'],
#        dtype='<U661'),
#  array(['98.56034073431552', "['Noah Cyrus']", 'Stay Together'],
#        dtype='<U661'),
#  array(['98.56030845199612', "['Wallows']", 'OK'], dtype='<U661'),
#  array(['98.56030654245822', "['Joji']", 'Bitter Fuck'], dtype='<U661'),
#  array(['98.56029380762267', "['Katy Perry']", 'Peacock'], dtype='<U661'),
#  array(['98.56028564046089', "['Mary Lambert']", 'Secrets'], dtype='<U661'),
#  array(['98.56026449949523',
#         "['Calvin Harris', 'Pharrell Williams', 'Katy Perry', 'Big Sean']",
#         'Feels (feat. Pharrell Williams, Katy Perry & Big Sean)'],
#        dtype='<U661'),
#  array(['98.56025739125701', "['Ludacris']", 'How Low'], dtype='<U661'),
#  array(['98.56023447716088', "['Juice WRLD']", 'Who Shot Cupid?'],
#        dtype='<U661'),
#  array(['98.56018456287242', "['Future']", 'Touch The Sky'], dtype='<U661'),
#  array(['98.56016622505581', "['YoungBoy Never Broke Again']",
#         'Through the Storm'], dtype='<U661'),
#  array(['98.56014844700842', "['Lil Baby', 'Future']", 'Out The Mud'],
#        dtype='<U661'),
#  array(['98.5601435484793', "['DaBaby', 'Stunna 4 Vegas']",
#         '4x (feat. Stunna 4 Vegas)'], dtype='<U661'),
#  array(['98.56012551089678', "['Gucci Mane', 'Lil Baby']",
#         'Both Sides (feat. Lil Baby)'], dtype='<U661'),
#  array(['98.56011289471917', "['A Tribe Called Quest']",
#         'We The People....'], dtype='<U661'),
#  array(['98.56010903541585', "['YoungBoy Never Broke Again']",
#         'Through the Storm'], dtype='<U661'),
#  array(['98.56008088305812', "['Bad Religion']",
#         'The Positive Aspect of Negative Thinking'], dtype='<U661'),
#  array(['98.56005852609847', "['Iggy Azalea', 'Tyga']",
#         'Kream (feat. Tyga)'], dtype='<U661'),
#  array(['98.56004989750136', "['bülow']", 'Get Stüpid'], dtype='<U661'),
#  array(['98.5599499564754',
#         "['Calvin Harris', 'Pharrell Williams', 'Katy Perry', 'Big Sean']",
# ...
#  array(['98.55247628521235', "['Raekwon', 'Ghostface Killah']",
#         'Wisdom Body (feat. Ghostface Killah)'], dtype='<U661'),
#  array(['98.55247233501886', "['Ty Dolla $ign', 'B.o.B']",
#         'Paranoid (feat. B.o.B)'], dtype='<U661'),
#  array(['98.55246119112296', "['Jon Bellion']", 'Ungrateful Eyes'],
#        dtype='<U661'),
#  array(['98.55245945774078', "['Khia']", 'My Neck, My Back'], dtype='<U661'),
#  array(['98.55243522408699', "['Lil Peep']", 'Honestly'], dtype='<U661'),
#  array(['98.55242942899766', "['A Boogie Wit da Hoodie']", 'Ransom'],
#        dtype='<U661'),
#  array(['98.55241677475213', "['Crass']", 'Punk Is Dead'], dtype='<U661'),
#  array(['98.55241601476874', "['5 Seconds of Summer']", 'Want You Back'],
#        dtype='<U661'),
#  array(['98.55240355449884', "['Tay-K', 'Maxo Kream']",
#         'I <3 My Choppa (feat. Maxo Kream) - Remix'], dtype='<U661'),
#  array(['98.55239345254711', "['Logic', 'Marshmello']", 'Everyday'],
#        dtype='<U661'),
#  array(['98.55238226110782', "['Doobie', 'Caskey']", 'Icy Titties'],
#        dtype='<U661'),
#  array(['98.55232480852736', "['Uncle Kracker']", 'Follow Me'],
#        dtype='<U661'),
#  array(['98.55230851285496', "['Hoodie Allen', 'Chiddy']",
#         'Fame Is for Assholes (feat. Chiddy)'], dtype='<U661'),
#  array(['98.55227677959145', "['Say Anything']",
#         'Wow, I Can Get Sexual Too'], dtype='<U661'),
#  array(['98.55223746431241', "['M City JR']", 'Addicted to My Ex'],
#        dtype='<U661'),
#  array(['98.55222128200934', "['Kevin Gates', 'Boobie Black']",
#         'Thugged Out (feat. Boobie Black)'], dtype='<U661'),
#  array(['98.55220782633566', "['Cardi B']", 'Thru Your Phone'],
#        dtype='<U661'),
#  array(['98.55219344049357', "['Megan Thee Stallion']", 'Freak Nasty'],
#        dtype='<U661'),
#  array(['98.55219043921583', "['Imanbek', 'Martin Jensen']",
#         "I'm Just Feelin' (Du Du Du)"], dtype='<U661'),
#  array(['98.55217109822124', "['Waka Flocka Flame', 'T.I.']",
#         '50K Remix (feat. T.I.)'], dtype='<U661'),
#  array(['98.55215133662698', "['DJ ESCO', 'Future', 'Lil Uzi Vert']",
#         'Too Much Sauce (feat. Future & Lil Uzi Vert)'], dtype='<U661'),
#  array(['98.55212296236125', "['Guttermouth']", 'Lipstick'], dtype='<U661'),
#  array(['98.55210961762327', "['XXXTENTACION']", 'SAD!'], dtype='<U661'),
#  array(['98.5520953398103', "['Ice Cube', 'Krayzie Bone']",
#         'Until We Rich'], dtype='<U661'),
#  array(['98.55206162951774', "['OMB Peezy']", 'Big Homie'], dtype='<U661'),
#  array(['98.55205562459197', "['Illa J']", 'All Good'], dtype='<U661'),
#  array(['98.55203140847769', "['311']", 'Hive'], dtype='<U661'),
#  array(['98.55201899066009', "['JAY-Z', 'Beanie Sigel', 'Memphis Bleek']",
#         'Change The Game'], dtype='<U661'),
#  array(['98.55199655928202', "['Black Joe Lewis & The Honeybears']",
#         'Bitch, I Love You'], dtype='<U661'),
#  array(['98.55197847698969', "['Brendan Maclean']", 'Stupid'],
#        dtype='<U661'),
#  array(['98.55197334777392', "['Tiny Meat Gang']", 'Broke Bitch'],
#        dtype='<U661'),
#  array(['98.55196799254821', "['Rod Wave']", 'Weight On My Shoulders'],
#        dtype='<U661'),
#  array(['98.55187924584338', "['Ouija Macc']", 'Trashfire'], dtype='<U661'),
#  array(['98.55187456441247', "['Special Duties']", 'Violent Society'],
#        dtype='<U661'),
#  array(['98.5518382743742',
#         "['Quando Rondo', '2 Chainz', 'A Boogie Wit da Hoodie']",
#         'Bad Vibe (feat. A Boogie Wit da Hoodie & 2 Chainz)'],
#        dtype='<U661'),
#  array(['98.5518352066599', "['Charlie Heat', 'Ant Beale']", 'Sunshine'],
#        dtype='<U661'),
#  array(['98.5518282584161', "['ScHoolboy Q']", 'Man Of The Year'],
#        dtype='<U661'),
#  array(['98.55181898024519', '[\'Yung Joc\', \'Brandy "Ms. B" Hambrick\']',
#         'I Know You See It (feat. Brandy "Ms. B" Hambrick)'], dtype='<U661'),
#  array(['98.55176061559223', "['Lily Allen']", 'Smile'], dtype='<U661'),
#  array(['98.55174423939671', "['Korn']", "Y'all Want a Single"],
#        dtype='<U661'),
#  array(['98.55173611698044', "['Arizona Zervas']", 'FML'], dtype='<U661'),
#  array(['98.55169672117846', "['Moneybagg Yo', 'Lil Baby']",
#         'U Played (feat. Lil Baby)'], dtype='<U661'),
#  array(['98.55166334021858', "['Drake']", 'Started From the Bottom'],
#        dtype='<U661'),
#  array(['98.55164880316184', "['G-Eazy', 'Tory Lanez', 'Tyga']",
#         'Still Be Friends (feat. Tory Lanez & Tyga)'], dtype='<U661'),
#  array(['98.55164664099411',
#         "['Sofi Tukker', 'NERVO', 'The Knocks', 'ALISA UENO']",
#         'Best Friend'], dtype='<U661'),
#  array(['98.55164058851283', "['Jessie Reyez', '6LACK']",
#         'Imported (with 6LACK)'], dtype='<U661'),
#  array(['98.55160872694096', "['Lil Wil']", 'My Dougie'], dtype='<U661'),
#  array(['98.55159613937487', "['$uicideBoy$']", 'Shattered Amethyst'],
#        dtype='<U661'),
#  array(['98.55159346321241', "['Justin Timberlake', 'Timbaland']",
#         'SexyBack (feat. Timbaland)'], dtype='<U661'),
#  array(['98.55159049788047', "['Lady Gaga']", 'Sexxx Dreams'],
#        dtype='<U661'),
#  array(['98.55157581963853', "['Tyler, The Creator', 'Rex Orange County']",
#         'Foreword (feat. Rex Orange County)'], dtype='<U661'),
#  array(['98.5515750685822', "['convolk']", 'i fucked up'], dtype='<U661'),
#  array(['98.55153140777308', "['$uicideBoy$']", "I'm Done."], dtype='<U661'),
#  array(['98.55144976120314', "['Gorilla Biscuits']", 'Start Today'],
#        dtype='<U661'),
#  array(['98.55142839513391', "['Tego Calderon']",
#         'Al Natural (feat. Yandel)'], dtype='<U661'),
#  array(['98.55139334574781', "['Quavo']", 'WORKIN ME'], dtype='<U661'),
#  array(['98.55138013549467', "['Trippie Redd', 'Chance the Rapper']",
#         'I Love You'], dtype='<U661'),
#  array(['98.55130754762628', "['Lil Tecca', 'Internet Money']",
#         'Out Of Love (feat. Internet Money)'], dtype='<U661'),
#  array(['98.5512524931333', "['Lorde']", 'Tennis Court'], dtype='<U661'),
#  array(['98.551241213063', "['Kevin Gates']", "Don't Know What to Call It"],
#        dtype='<U661'),
#  array(['98.55123441791882', "['Drake']", 'Started From the Bottom'],
#        dtype='<U661'),
#  array(['98.5511754395375', "['South Park Mexican']", 'Dope Game'],
#        dtype='<U661'),
#  array(['98.55116597242662', "['blink-182']", 'Roller Coaster'],
#        dtype='<U661'),
#  array(['98.55109637482778', "['blackbear', 'FRND']",
#         'anxiety (with FRND)'], dtype='<U661'),
#  array(['98.55109167252608', "['Curtis Waters', 'Harm Franklin']",
#         "Stunnin'"], dtype='<U661'),
#  array(['98.55108133986347', "['Drake']", 'Right Hand'], dtype='<U661'),
#  array(['98.55108063275598', "['Electric Guest']", 'Waves'], dtype='<U661'),
#  array(['98.55107845955057', "['Promoting Sounds', 'Powfu', 'Ouse']",
#         'Dead Eyes'], dtype='<U661'),
#  array(['98.5510688619657', "['De La Ghetto']", 'Sensacion Del Bloque'],
#        dtype='<U661'),
#  array(['98.55106319233745', "['BROCKHAMPTON']", 'ZIPPER'], dtype='<U661'),
#  array(['98.5510243409251', "['Lorde']", 'Tennis Court'], dtype='<U661'),
#  array(['98.55100589850522', "['Eminem', 'Don Toliver']",
#         'No Regrets (feat. Don Toliver)'], dtype='<U661'),
#  array(['98.55097196225553', "['Gwen Stefani']", 'Hollaback Girl'],
#        dtype='<U661'),
#  array(['98.55087308515999', "['Miley Cyrus']", 'Do My Thang'],
#        dtype='<U661'),
#  array(['98.55085914503954', "['Tyga']", 'SWISH'], dtype='<U661'),
#  array(['98.55085522721005', "['P!nk']", 'Walk of Shame'], dtype='<U661'),
#  array(['98.55084405968353', "['Ski Mask The Slump God']",
#         'Carbonated Water'], dtype='<U661'),
#  array(['98.55084271996931', "['K CAMP']", 'Slum Anthem'], dtype='<U661'),
#  array(['98.55083843493499', "['The Kid LAROI']", 'Addison Rae'],
#        dtype='<U661'),
#  array(['98.55081685642175', "['Jaden', 'Christian Rich']", 'GHOST'],
#        dtype='<U661'),
#  array(['98.55081201452224', "['WILLOW']", 'Time Machine'], dtype='<U661'),
#  array(['98.550798219676', "['Dr. Dre', 'Snoop Dogg']", 'The Next Episode'],
#        dtype='<U661'),
#  array(['98.55077557059789', "['Travis Scott']", 'lose'], dtype='<U661'),
#  array(['98.55077191549155', "['Gucci Mane']", 'Photoshoot'], dtype='<U661'),
#  array(['98.55076212158107', "['T-Wayne']", 'Nasty Freestyle'],
#        dtype='<U661'),
#  array(['98.5507615514984', "['Roddy Ricch']", 'Nascar'], dtype='<U661'),
#  array(['98.55075743271766', "['Offset', 'Cardi B']",
#         'Clout (feat. Cardi B)'], dtype='<U661'),
#  array(['98.55075497480335', "['Insane Clown Posse']", 'My Axe'],
#        dtype='<U661'),
#  array(['98.55059854497212', "['Sage The Gemini', 'Kool John']",
#         'College Drop'], dtype='<U661'),
#  array(['98.55058625533648', "['Rich Brian', 'Guapdad 4000']", 'BALI'],
#        dtype='<U661'),
#  array(['98.55057284952184', "['P!nk']", 'Raise Your Glass'], dtype='<U661'),
#  array(['98.55054475873493', "['No Jumper', 'Tay-K', 'BlocBoy JB']",
#         'Hard (feat. Tay-K and BlocBoy JB)'], dtype='<U661'),
#  array(['98.55053478269859', "['Ariana Grande']", 'successful'],
#        dtype='<U661'),
#  array(['98.55047134763736',
#         "['John Gallagher, Jr.', 'Brian Johnson', 'Jonathan B. Wright', 'Gideon Glick', 'Skylar Astin', 'Jonathan Groff']",
#         'The Bitch Of Living - Original Broadway Cast Recording/2006'],
#        dtype='<U661'),
#  array(['98.55046853587885', "['311']", 'Loco'], dtype='<U661'),
#  array(['98.55039104208848', "['$uicideBoy$']", 'Either Hated Or Ignored'],
#        dtype='<U661'),
#  array(['98.55038217718801', "['Mindless Self Indulgence']",
#         'Cocaine and Toupees'], dtype='<U661'),
#  array(['98.5503679899749', "['NAV']", 'Coast To Coast'], dtype='<U661'),
#  array(['98.5503598445691', "['Kid Ink', 'Fetty Wap']",
#         'Promise (feat. Fetty Wap)'], dtype='<U661'),
#  array(['98.55033591995137', "['Don Toliver', 'Quavo', 'Offset']",
#         'HAD ENOUGH (feat. Quavo & Offset)'], dtype='<U661'),
#  array(['98.5503067691036', "['Wiz Khalifa', 'Lil Uzi Vert']",
#         'Pull Up (feat. Lil Uzi Vert)'], dtype='<U661'),
#  array(['98.55028521788567', "['Trippie Redd']", 'Topanga'], dtype='<U661'),
#  array(['98.55028276451611', "['ScHoolboy Q', 'E-40']", 'Dope Dealer'],
#        dtype='<U661'),
#  array(['98.55022221728196', "['Tyga', 'Offset']", 'Taste (feat. Offset)'],
#        dtype='<U661'),
#  array(['98.5502084472628', "['Green Day']", 'All the Time'], dtype='<U661'),
#  array(['98.55020689781335', "['Young Thug']", 'Memo'], dtype='<U661'),
#  array(['98.55018737728992', "['Don Toliver', 'Offset', 'Quavo']",
#         'Had Enough (feat. Quavo & Offset)'], dtype='<U661'),
#  array(['98.55018240170594', "['Doja Cat']", 'Go To Town'], dtype='<U661'),
#  array(['98.55016491167959', "['2Pac']", 'So Many Tears'], dtype='<U661'),
#  array(['98.55016463800817', "['50 Cent']", 'Places To Go'], dtype='<U661'),
#  array(['98.5501386935565', "['Aminé']", 'RATCHET SATURN GIRL'],
#        dtype='<U661'),
#  array(['98.55011557439977', "['NAV', 'Young Thug']",
#         'No Debate (feat. Young Thug)'], dtype='<U661'),
#  array(['98.55010484225433', "['Pierce The Veil']", 'Floral & Fading'],
#        dtype='<U661'),
#  array(['98.55009457443667', "['Rod Wave']", 'Brace Face'], dtype='<U661'),
#  array(['98.55003366773877', "['Roy Woods']", 'Down Girl'], dtype='<U661'),
#  array(['98.55002790052299', "['Three 6 Mafia']", 'Where Da Cheese At'],
#        dtype='<U661'),
#  array(['98.55000491153089', "['Aries']", 'SAYONARA'], dtype='<U661'),
#  array(['98.54997826628474', "['Trey Songz', 'Nicki Minaj']",
#         'Touchin, Lovin (feat. Nicki Minaj)'], dtype='<U661'),
#  array(['98.54996975827328', "['Nicky Jam', 'Daddy Yankee']",
#         'En La Cama (feat. Daddy Yankee)'], dtype='<U661'),
#  array(['98.54996713610163', "['Start Trouble']",
#         "Let's Get Fucked Up - Explicit Album Version"], dtype='<U661'),
#  array(['98.54996655736197', "['Offset', 'Metro Boomin']",
#         'Ric Flair Drip (& Metro Boomin)'], dtype='<U661'),
#  array(['98.54995294127521', "['Jidenna', 'Roman GianArthur']",
#         'Classic Man (feat. Roman GianArthur)'], dtype='<U661'),
#  array(['98.54985151088762', "['Xavier Wulf']", 'Thunder Man'],
#        dtype='<U661'),
#  array(['98.54984856457052', "['Doja Cat', 'Smino']", "Won't Bite"],
#        dtype='<U661'),
#  array(['98.54980790517322', "['Juice WRLD']", 'Long Gone'], dtype='<U661'),
#  array(['98.54979606111512', "['Sublime']", 'What I Got - Reprise'],
#        dtype='<U661'),
#  array(['98.54979462317297', "['Mac Miller']", 'Loud'], dtype='<U661'),
#  array(['98.54974577376397', "['P!nk']", 'U + Ur Hand'], dtype='<U661'),
#  array(['98.5497087368138', "['Tyla Yaweh']", 'High Right Now'],
#        dtype='<U661'),
#  array(['98.54970167120882', "['Three 6 Mafia', 'UGK', 'Project Pat']",
#         'Sippin On Some Syrup (feat. UGK (Underground Kingz) & Project Pat)'],
#        dtype='<U661'),
#  array(['98.54969874889024', "['Travis Scott']", 'A-Team'], dtype='<U661'),
#  array(['98.5496583599053', "['Childish Gambino']", 'Retro (Rough)'],
#        dtype='<U661'),
#  array(['98.54965021020502', "['Night Lovell']", 'Concept Nothing'],
#        dtype='<U661'),
#  array(['98.54962139799214', "['Chief Keef', 'King Louie']", 'Winnin'],
#        dtype='<U661'),
#  array(['98.54961994642353', "['Nicki Minaj']", 'MEGATRON'], dtype='<U661'),
#  array(['98.54961087543565', "['Bad Bunny']", 'Tenemos Que Hablar'],
#        dtype='<U661'),
#  array(['98.54960847942769', "['Quality Control', 'Quavo', 'Lil Yachty']",
#         'Ice Tray'], dtype='<U661'),
#  array(['98.54959718620981', "['Cam Meekins', 'Skizzy Mars']",
#         'High (feat. Skizzy Mars)'], dtype='<U661'),
#  array(['98.54959558367008', "['Kid Cudi', 'Kanye West', 'Common']",
#         'Make Her Say'], dtype='<U661'),
#  array(['98.54959250371527', "['Trick Daddy']", "I'm a Thug"],
#        dtype='<U661'),
#  array(['98.54957492580719', "['will.i.am', 'Nicki Minaj']",
#         'Check It Out - Main, Explicit Version'], dtype='<U661'),
#  array(['98.54953953049069', "['Fuerza Regida']", 'Adicto'], dtype='<U661'),
#  array(['98.54952485336383', "['Black Eyed Peas', 'Ozuna', 'J. Rey Soul']",
#         'MAMACITA'], dtype='<U661'),
#  array(['98.54950979921014', "['Kid Cudi', 'Kanye West', 'Common']",
#         'Make Her Say'], dtype='<U661'),
#  array(['98.54948494142945', "['Vinny West']", 'Too Player'], dtype='<U661'),
#  array(['98.54947013257782', "['Yella Beezy', 'Chris Brown']",
#         'Restroom Occupied'], dtype='<U661'),
#  array(['98.54943132834374', "['Lil Skies']", 'Riot'], dtype='<U661'),
#  array(['98.54941756332961', "['iann dior']", 'pouring'], dtype='<U661'),
#  array(['98.54937070747016', "['$uicideBoy$']",
#         "You're Now Tuning Into 66.6 FM With DJ Rapture (The Hottest Hour Of The Evening)"],
#        dtype='<U661'),
#  array(['98.54935468891566', "['Moneybagg Yo', 'DaBaby']",
#         'Protect Da Brand (feat. DaBaby)'], dtype='<U661'),
#  array(['98.5493523995424', "['Kamiyada+', 'The Virus and Antidote']",
#         'ProductOfDrugs (Prod. The Virus and Antidote)'], dtype='<U661'),
#  array(['98.54933036977584', "['Gucci Mane', 'Bruno Mars', 'Kodak Black']",
#         'Wake Up in the Sky'], dtype='<U661'),
#  array(['98.54932903608113', "['Sublime']", 'What I Got - Reprise'],
#        dtype='<U661'),
#  array(['98.54932415476387', "['MadeinTYO', 'Travis Scott']",
#         'Uber Everywhere (feat. Travis Scott)'], dtype='<U661'),
#  array(['98.54929430106999', "['Green Day']", 'Minority'], dtype='<U661'),
#  array(['98.5492936581245', "['Trippie Redd']", 'Love Scars'],
#        dtype='<U661'),
#  array(['98.5492916957151', "['Skizzy Mars']", 'Girl on a Train'],
#        dtype='<U661'),
#  array(['98.54923055902981', "['DJ Khaled', 'Rihanna', 'Bryson Tiller']",
#         'Wild Thoughts (feat. Rihanna & Bryson Tiller)'], dtype='<U661'),
#  array(['98.54921562445284', "['DMX']", "Fuckin' Wit' D"], dtype='<U661'),
#  array(['98.5492096658819', "['NAV']", 'Good Intentions (Intro)'],
#        dtype='<U661'),
#  array(['98.54919081421824', "['blackbear']", '4u'], dtype='<U661'),
#  array(['98.54918089278435', "['N.W.A.']", 'Kamurshol'], dtype='<U661'),
#  array(['98.54916686276717', "['Trick Daddy', 'Big Boi', 'CeeLo Green']",
#         'In da Wind'], dtype='<U661'),
#  ...]

# %%
playlist_added = ids[sort_indices][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
