# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import oauth2
import csv
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import NearestNeighbors

# %%
cid = '8c4cb3ef1c0c412181ea69d07b3df0ca'
secret = 'a07e05c762a24e12933c4c118c6c18ca'
redirect_uri = 'http://localhost:8910/callback'

# %%
username = input('Enter username: ')
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# Out:
# Enter username: ardabyk07

# %%
#results = sp.current_user_top_tracks(limit=50, offset=0, time_range='medium_term')
results = sp.user_playlists(username)
user_all_songs = []
for playlist in results['items']:
    tracks = sp.user_playlist_tracks(username, playlist['id'])['items']
    for track in tracks:
        user_all_songs.append(track['track']['id'])

#fav_tracks = []
#for i, items in enumerate(results['items']):
#    fav_tracks.append(items['id'])

# %%
dataset_path = "./data/data.csv"
with open(dataset_path, 'r') as token_file:
    lines = csv.reader(token_file)
    dataset = list(lines)
    data = np.array(dataset)

# %%
indices = []
id_index = -1
info = []
choose = -1
name_index = -1
for i in range(data.shape[1]):
    if data[0][i] in ['key', 'artists', 'release_date', 'name']:
        indices.append(i)
        if data[0][i] == 'name':
            name_index = i
    elif data[0][i] == 'id':
        id_index = i
        
    if data[0][i] in ['artists', 'name']:
        info.append(i)

# %%
data = data[1:,:]
np.random.shuffle(data)
ids = np.array(data[:,id_index:id_index+1])
for j in range(data.shape[0]):
    if data[j][name_index] == 'Blinding Lights':
        choose = j
    
ids = np.ndarray.flatten(ids)

song_info = np.array(data[:,info])
indices.append(id_index)
data = np.delete(data, indices, axis=1)

# %%
song_info[choose]
# Out:
# array(["['The Weeknd']", 'Blinding Lights'], dtype='<U661')

# %%
data = data.astype('float64')

# %%
#first obtain 5000 songs with NN
model = NearestNeighbors(n_neighbors=10001, algorithm='ball_tree')
scalar = StandardScaler()
scalar.fit(data)
data_nn = scalar.transform(data)
model.fit(data_nn)
distances, indices = model.kneighbors([data_nn[choose]])

# %%
selected = song_info[choose]
playlist = song_info[indices]
playlist = playlist[:,1:,:]
indices = np.ndarray.flatten(indices[:,1:])

# %%
playlist
# Out:
# array([[["['Toby Keith']", 'Made in America'],
#         ["['K/DA', 'Madison Beer', '(G)I-DLE', 'Jaira Burns', 'League of Legends']",
#          'POP/STARS'],
#         ["['Taylor Swift']", 'Getaway Car'],
#         ...,
#         ["['Mariah Carey']", 'When I Saw You'],
#         ["['Vampire Weekend']", 'Everlasting Arms'],
#         ["['Clay Walker']", 'If I Could Make a Living']]], dtype='<U661')

# %%
data = scalar.transform(data)

# %%
tracks = ids[indices]
tracks = np.ndarray.flatten(tracks)
tracks = list(tracks)

# %%
song_train = []
found_id = []

tracks_numpy = np.array(tracks)
ids_numpy = np.array(ids)

found_indices = np.where(np.in1d(ids_numpy, tracks_numpy))[0]
found_id = ids[found_indices]
song_train = data[found_indices]
#for track_id in tracks:
    #for i, dataset_id in enumerate(ids):
        #if track_id == dataset_id:
            #song_train.append(data[i])
            #found_id.append(track_id)

# %%
relevances = []
relevance = 100
for i, track_id in enumerate(found_id):
    relevances.append(relevance)
    relevance -= 0.001

# %%
reg = LinearRegression().fit(song_train, relevances)
#for i, track in enumerate(data):
    #if not ids[i] in found_id:
        #predictions.append((reg.predict([track]), ids[i], song_info[i]))
predictions = reg.predict(data)
predicted = np.c_[predictions, song_info]

# %%
predictions = np.array(predictions)
predictions = predictions.astype('float64')

# %%
predicted = predicted[np.argsort(predictions)[::-1]]

# %%
list(predicted)
# Out:
# [array(['94.83447258119263', "['KISS']", 'Calling Dr. Love'], dtype='<U661'),
#  array(['94.90897271445496', "['2Pac', 'Treach', 'Apache', 'Live Squad']",
#         '5 Deadly Venomz'], dtype='<U661'),
#  array(['94.76570055359448', "['Alexander Scriabin', 'Vladimir Horowitz']",
#         'Sonata No. 5, Op. 53'], dtype='<U661'),
#  array(['95.08104443138318',
#         "['Sonny Rollins', 'Tommy Flanagan', 'Doug Watkins', 'Max Roach']",
#         'Moritat'], dtype='<U661'),
#  array(['94.95366293089769', "['Simply Red']",
#         'Come to My Aid - 2008 Remaster'], dtype='<U661'),
#  array(['95.12804427001392', "['Bobby Brown']", 'On Our Own'],
#        dtype='<U661'),
#  array(['94.5024480615791', "['Robert Schumann', 'Vladimir Horowitz']",
#         'Fantasiestücke, Op. 111: Con forza, assai marcato'], dtype='<U661'),
#  array(['94.7606285312006', "['Jona Lewie']",
#         "You'll Always Find Me In The Kitchen At Parties"], dtype='<U661'),
#  array(['95.01484069196877', "['Selena']", 'La Carcacha'], dtype='<U661'),
#  array(['94.4446188966555', "['Shamim Akhtar']",
#         'Dil Ki Duniya Jo Loota Di'], dtype='<U661'),
#  array(['94.93471607355116', "['Franco Battiato']",
#         'Centro Di Gravità Permanente - Remastered'], dtype='<U661'),
#  array(['95.08484267518472', "['Caifanes']", 'El Comunicador'],
#        dtype='<U661'),
#  array(['94.68651901884648', "['Richard Strauss', 'Arturo Toscanini']",
#         'Tod und Verklärung, Op. 24: Largo'], dtype='<U661'),
#  array(['94.99254570809998', "['Hüsker Dü']", 'Turn on the News'],
#        dtype='<U661'),
#  array(['94.75600105501067', "['Nina Simone']",
#         'Mississippi Goddam - Unedited version from original live concert'],
#        dtype='<U661'),
#  array(['95.15720715156733', "['Chaka Khan']", 'I Know You, I Live You'],
#        dtype='<U661'),
#  array(['94.66979896267868', "['Bobby Darin']", 'Where Is the One'],
#        dtype='<U661'),
#  array(['95.04866818244965', "['Fleetwood Mac']",
#         'Go Your Own Way - Live 1977'], dtype='<U661'),
#  array(['94.76394612805532', "['Lee Ritenour']",
#         'I Can’t Let Go - Remastered'], dtype='<U661'),
#  array(['94.69313484294193', "['Joan Sebastian']", 'Carrera A Muerte'],
#        dtype='<U661'),
#  array(['94.86423048898372',
#         "['Johannes Brahms', 'Vladimir Horowitz', 'Arturo Toscanini', 'NBC Symphony Orchestra']",
#         'Piano Concerto No. 2 in B-Flat Major, Op. 83: I. Allegro non troppo'],
#        dtype='<U661'),
#  array(['94.51860788563859',
#         "['Pietro Mascagni', 'Jussi Björling', 'Nils Grevillius']",
#         'Cavalleria rusticana: "Mamma, mamma!, quel vino è generoso"'],
#        dtype='<U661'),
#  array(['94.6169384921191', "['Elvis Presley']", 'In the Garden'],
#        dtype='<U661'),
#  array(['94.94973993339698', "['Cake']", 'Race Car Ya-Yas'], dtype='<U661'),
#  array(['94.9602586824901', "['Bill Conti']", 'Conquest'], dtype='<U661'),
#  array(['94.50641507089705', "['Billie Holiday', 'Teddy Wilson']",
#         'With Thee I Swing (with Teddy Wilson & His Orchestra)'],
#        dtype='<U661'),
#  array(['94.84037919779115', "['Onyx', 'DMX']", "Shut 'Em Down"],
#        dtype='<U661'),
#  array(['94.96359698281668', "['The Southern Death Cult']", 'Moya'],
#        dtype='<U661'),
#  array(['95.02656367672432', "['Ebo Taylor']", 'Heaven'], dtype='<U661'),
#  array(['95.054688280835', "['The Aggrovators']", "Rocker's Almighty Dub"],
#        dtype='<U661'),
#  array(['94.76203200588726',
#         "['Dave Brubeck', 'Paul Desmond', 'Dave Van Kriedt']",
#         "Leo's Place"], dtype='<U661'),
#  array(['94.96909122138106', "['Primus']", 'Too Many Puppies'],
#        dtype='<U661'),
#  array(['94.78556165871633', "['Bill Withers']",
#         'For My Friend - Live at Carnegie Hall, New York, NY - October 1972'],
#        dtype='<U661'),
#  array(['95.03533550472451', "['Harold Melvin & The Blue Notes']",
#         "Don't Leave Me This Way"], dtype='<U661'),
#  array(['94.88921028632532', "['Dido']", 'White Flag'], dtype='<U661'),
#  array(['94.78084397090575', "['Felix Mendelssohn', 'Pablo Casals']",
#         'Piano Trio No. 1 in D Minor, Op. 49, MWV Q 29: IV. Finale. Allegro assai appassionato'],
#        dtype='<U661'),
#  array(['95.09155926885374', "['Steely Dan']", 'Peg'], dtype='<U661'),
#  array(['94.44118259159858', "['Sandhya Mukherjee']",
#         'Amare Loye Je (From "Samapika")'], dtype='<U661'),
#  array(['94.47270661765968', "['Marty Robbins']", 'Hurt'], dtype='<U661'),
#  array(['94.35921508277836', "['Noor Jehan']", 'Aaja Ri Nindiya'],
#        dtype='<U661'),
#  array(['95.00716971935168', "['KC & The Sunshine Band']",
#         "I'm so Crazy ('Bout You) - 2004 Remaster"], dtype='<U661'),
#  array(['94.85197162217', "['Little Feat']", 'Fat Man In A Bathtub - Live'],
#        dtype='<U661'),
#  array(['95.08412172672696', "['Peter Gabriel']", 'Mercy Street - Live'],
#        dtype='<U661'),
#  array(['94.94062646181989', "['Bauhaus']", 'Double Dare'], dtype='<U661'),
#  array(['94.66692522341604', "['Stan Kenton & His Orchestra']",
#         "Stompin' At The Savoy"], dtype='<U661'),
#  array(['95.08533595393561', "['Godsmack']", 'Speak'], dtype='<U661'),
#  array(['94.62853419357272', "['Rex Harrison']",
#         "I've Grown Accustomed to Her Face"], dtype='<U661'),
#  array(['95.18944978885929', "['Iron Maiden']",
#         'Phantom of the Opera - 2015 Remaster'], dtype='<U661'),
#  array(['94.7282611483216', "['Camila Cabello']", 'First Man'],
#        dtype='<U661'),
#  array(['94.85049435552659', "['Old Dominion']", "I'm On It"],
#        dtype='<U661'),
#  array(['94.82262454898394', "['The Dubliners']", 'Black Velvet Band'],
#        dtype='<U661'),
#  array(['94.95496156157309', "['Canned Heat']", "Let's Work Together"],
#        dtype='<U661'),
#  array(['95.1771416707665', "['Ini Kamoze']", 'World A Music'],
#        dtype='<U661'),
#  array(['94.52216889656862', "['Robert Schumann', 'Pablo Casals']",
#         'Piano Trio No. 1 in D Minor, Op. 63: II. Lebhaft, doch nicht zu rasch'],
#        dtype='<U661'),
#  array(['94.94522876518425', "['Duke Ellington', 'John Coltrane']",
#         'The Feeling Of Jazz'], dtype='<U661'),
#  array(['94.6925198536785', "['Billy Joel']", 'Somewhere Along the Line'],
#        dtype='<U661'),
#  array(['94.54987050707317', "['Young Dolph', 'Wiz Khalifa']",
#         'On the River'], dtype='<U661'),
#  array(['94.97558168423072', "['Elton John']",
#         'Bennie And The Jets - Remastered 2014'], dtype='<U661'),
#  array(['94.56696303681606', "['Ray Price']", 'Are You Sure'],
#        dtype='<U661'),
#  array(['95.03980291607355', "['Haddaway']", 'Life - Radio Edit'],
#        dtype='<U661'),
#  array(['94.33600015088534', "['Francisco Canaro']",
#         'Oh París - Remasterizado'], dtype='<U661'),
#  array(['94.76539687531677', "['Eminem']", 'Phenomenal'], dtype='<U661'),
#  array(['95.16463764340973', "['El Dipy']", 'Soy Soltero'], dtype='<U661'),
#  array(['95.18380403751769', "['New Kids On The Block']", 'Step by Step'],
#        dtype='<U661'),
#  array(['94.7021086507729', "['John Prine']", 'Grandpa Was a Carpenter'],
#        dtype='<U661'),
#  array(['94.48945922582068',
#         "['Johannes Brahms', 'William Kapell', 'William Primrose']",
#         'Sonata in F Minor, Op. 120 No. 1: IV. Vivace'], dtype='<U661'),
#  array(['94.91400299501768', "['Otis Redding']", "Send Me Some Lovin'"],
#        dtype='<U661'),
#  array(['94.61992851363331', "['Mohammed Rafi', 'Lata Mangeshkar']",
#         'Yunhi Tum Mujhse - From Sachaa Jhutha'], dtype='<U661'),
#  array(['94.81798308202903', "['Antônio Carlos Jobim']", 'Tereza My Love'],
#        dtype='<U661'),
#  array(['94.65482086339462', "['Frankie Valli & The Four Seasons']",
#         'Marlena'], dtype='<U661'),
#  array(['94.64431621708489', "['Gene Chandler']", 'Stand By Me'],
#        dtype='<U661'),
#  array(['94.87782090679099', "['Morphine']", 'All Your Way'], dtype='<U661'),
#  array(['94.50587132421002', "['Thelonious Monk']",
#         "I Got It Bad (And That Ain't Good)"], dtype='<U661'),
#  array(['95.1318989552778', "['Boz Scaggs']", 'JoJo'], dtype='<U661'),
#  array(['95.08735929578813', "['Hunter Hayes']", "Somebody's Heartbreak"],
#        dtype='<U661'),
#  array(['94.9227028346913', "['Otis Clay']", 'When The Gates Swing Open'],
#        dtype='<U661'),
#  array(['94.96951043067484', "['Damn Yankees']", 'Bad Reputation'],
#        dtype='<U661'),
#  array(['94.67677426783858', "['La Lupe']", 'La Tirana'], dtype='<U661'),
#  array(['94.8048886547554', "['Champion Jack Dupree']", 'Stack-O-Lee'],
#        dtype='<U661'),
#  array(['94.73198231251658', "['Talking Heads']",
#         'The Overload - 2005 Remaster'], dtype='<U661'),
#  array(['94.68923695405898', "['Mazzy Star']", 'Give You My Lovin'],
#        dtype='<U661'),
#  array(['95.22360089765733', "['Eagles']",
#         'King of Hollywood - 2013 Remaster'], dtype='<U661'),
#  array(['94.39802802011519', "['Francisco Canaro', 'Ernesto Fama']",
#         'A Mi No Me Hablen de Penas - Remasterizado'], dtype='<U661'),
#  array(['94.791001708156', "['Chicago']",
#         'Does Anybody Really Know What Time It Is?'], dtype='<U661'),
#  array(['94.70027384012764', "['Frank Sinatra']", 'Prisoner Of Love'],
#        dtype='<U661'),
#  array(['94.61622084720786', "['Paco de Lucía', 'Ricardo Modrego']",
#         'La Nina De Puerta Oscura'], dtype='<U661'),
#  array(['94.92166744350396', "['Strawberry Alarm Clock']",
#         'Pretty Song From Psych-Out'], dtype='<U661'),
#  array(['94.81511303816846', "['Cesária Evora']", 'Besame Mucho'],
#        dtype='<U661'),
#  array(['94.90272628265484', "['Ja Rule', 'Bobby Brown']", "Thug Lovin'"],
#        dtype='<U661'),
#  array(['94.84492599617046', "['Modern Baseball']", 'Fine, Great'],
#        dtype='<U661'),
#  array(['94.66297208307925', "['Judy Garland']",
#         'Gotta Have Me Go With You Judy Garland, Male Chorus - Live'],
#        dtype='<U661'),
#  array(['94.78933358196443', "['Built To Spill']", 'Car'], dtype='<U661'),
#  array(['94.91287600708921', "['Koe Wetzel']", 'Never Leave'],
#        dtype='<U661'),
#  array(['94.82045370153229', "['Jim Croce']", 'Speedball Tucker'],
#        dtype='<U661'),
#  array(['94.88866012793649', "['Pierce The Veil', 'Kellin Quinn']",
#         'King For A Day'], dtype='<U661'),
#  array(['94.90096426475917', "['The Allman Brothers Band']",
#         'Leave My Blues At Home'], dtype='<U661'),
#  array(['95.01745162512164', "['Elvis Costello']",
#         'Waiting For The End Of The World'], dtype='<U661'),
#  array(['95.01967561414203', "['Los Acosta']", 'Pobrecito de mí'],
#        dtype='<U661'),
#  array(['94.65861876872287', "['Keith Urban']", 'Tonight I Wanna Cry'],
#        dtype='<U661'),
#  array(['94.70695686219041',
#         "['Gewandhausorchester Leipzig', 'Václav Neumann']",
#         'Symphony No. 5 in C-Sharp Minor: IV. Adagietto - Tod in Venedig'],
#        dtype='<U661'),
#  array(['94.54299784984804', "['The Moody Blues']",
#         'Visions Of Paradise - Instrumental Mix'], dtype='<U661'),
#  array(['94.83453933408418', "['Aretha Franklin']", 'How I Got Over'],
#        dtype='<U661'),
#  array(['94.53162805627782', "['Oscar Peterson']", 'Yesterdays'],
#        dtype='<U661'),
#  array(['95.10858551701176', "['Britney Spears']", 'Toxic'], dtype='<U661'),
#  array(['94.81478091395965', "['Dead Kennedys']", "Straight A's"],
#        dtype='<U661'),
#  array(['94.65209534184098', "['Lata Mangeshkar', 'Mukesh']",
#         'Sun Baal Bramhachari'], dtype='<U661'),
#  array(['94.79231065661368', "['Lil Tecca', 'Lil Tjay']",
#         'All Star (with Lil Tjay)'], dtype='<U661'),
#  array(['94.80041215408414', "['Tom Jones']", 'Without Love'],
#        dtype='<U661'),
#  array(['95.05228122600052', "['Kenny Wayne Shepherd']", 'Aberdeen'],
#        dtype='<U661'),
#  array(['95.02414621817496', "['Vance Joy']", 'Like Gold'], dtype='<U661'),
#  array(['95.171031671622', "['Grupo Firme', 'Banda Coloso']",
#         'Juro por Dios - En Vivo'], dtype='<U661'),
#  array(['94.4740674917279', "['Carmen Miranda', 'Dorival Caymmi']",
#         'A Preta Do Acarajé'], dtype='<U661'),
#  array(['94.58048286495534', "['Art Pepper']", 'Brown Gold'], dtype='<U661'),
#  array(['94.79635127130442', "['Frank Sinatra']",
#         'Strangers In The Night - Live'], dtype='<U661'),
#  array(['94.83830748712535', "['Van Morrison']",
#         'Brand New Day - 2013 Remaster'], dtype='<U661'),
#  array(['94.81913722210348', "['Gunna', 'Young Thug']",
#         'DOLLAZ ON MY HEAD (feat. Young Thug)'], dtype='<U661'),
#  array(['94.46253185155152', "['Sexteto Habanero']", 'Mama Ines'],
#        dtype='<U661'),
#  array(['94.66418852792799',
#         '[\'Harry "Sweets" Edison\', \'Buck Clayton\']',
#         "Walkin' With Sweets"], dtype='<U661'),
#  array(['95.02977591566611', "['Taj Mahal']", 'Statesboro Blues'],
#        dtype='<U661'),
#  array(['94.53102991654077', "['Radiohead']", 'Untitled'], dtype='<U661'),
#  array(['94.99818127697387', "['Poison']", 'Back To The Rocking Horse'],
#        dtype='<U661'),
#  array(['94.62795684140728',
#         "['Wolfgang Amadeus Mozart', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Cosi fan tutte, K. 588, Act II: "Per pietà, ben mio, perdona"'],
#        dtype='<U661'),
#  array(['94.60851169662227', "['Charles Mingus', 'Eric Dolphy']",
#         'ATFW You'], dtype='<U661'),
#  array(['94.45405608429223', "['Miss Moti']", 'Piya Na Bole'],
#        dtype='<U661'),
#  array(['95.0504839079746', "['Michelle Branch']", 'Are You Happy Now?'],
#        dtype='<U661'),
#  array(['94.44406399856', "['Marian McPartland']", 'Love Is Here To Stay'],
#        dtype='<U661'),
#  array(['94.58847075013293', "['Mahalia Jackson']",
#         'Jesus Met the Woman at the Well - Live'], dtype='<U661'),
#  array(['94.82493555579586', "['Herb Ellis']",
#         'Thank You, Charlie Christian'], dtype='<U661'),
#  array(['94.68236921388414',
#         "['Johannes Brahms', 'London Philharmonic Orchestra']",
#         'Symphony No. 3 in F Op. 90: III Poco allegretto'], dtype='<U661'),
#  array(['94.80938013455186', "['B.o.B', '2 Chainz']",
#         'HeadBand (feat. 2 Chainz)'], dtype='<U661'),
#  array(['94.43929499980275',
#         "['Leonard Bernstein', 'New York Philharmonic']",
#         'Symphonic Dances (From "West Side Story"): IV. Mambo (Meno presto)'],
#        dtype='<U661'),
#  array(['94.74759723656531', "['Rod Wave']", 'Dark Conversations'],
#        dtype='<U661'),
#  array(['94.92410487233195',
#         "['T.I.', 'B.o.B', 'Kendrick Lamar', 'Kris Stephens']",
#         'Memories Back Then (feat. B.o.B, Kendrick Lamar & Kris Stephens)'],
#        dtype='<U661'),
#  array(['95.04531549527466', "['X']", 'The Hungry Wolf'], dtype='<U661'),
#  array(['94.57933950210082',
#         "['Bing Crosby', 'Fred Waring & The Pennsylvanians']",
#         'This Is A Great Country'], dtype='<U661'),
#  array(['94.61206026323975', "['Jimmy Knepper Quintet']",
#         "The Jumpin' Blues"], dtype='<U661'),
#  array(['94.67988918937176', "['Harry Nilsson']", "Makin' Whoopee!"],
#        dtype='<U661'),
#  array(['94.43385852843672', "['Ioánnis Tzivánis', 'Rena Stamou']",
#         'Ennoia sou ennoia sou'], dtype='<U661'),
#  array(['94.50994412791817', "['Lata Mangeshkar', 'Mukesh']",
#         'O Mere Sanam'], dtype='<U661'),
#  array(['94.40597176110256', "['Marlene']", 'Toca Pedroca (Cuidado Amigo)'],
#        dtype='<U661'),
#  array(['94.50571248424026', "['Roy Fox']", "Look What You've Done"],
#        dtype='<U661'),
#  array(['94.9747859783109', "['Royal Blood']", 'Figure It Out'],
#        dtype='<U661'),
#  array(['94.59888458306294', "['Brian Hyland']", 'Rosemary'], dtype='<U661'),
#  array(['94.99398478599853', "['Los Temerarios']", 'Una Lágrima Más'],
#        dtype='<U661'),
#  array(['94.53524517874965', "['Talat Mahmood']",
#         'Hoyto Se Katha Tomar Smarane Nei'], dtype='<U661'),
#  array(['94.65609888888689', '["Original Broadway Cast of \'Pal Joey\'"]',
#         'In Our Little Den'], dtype='<U661'),
#  array(['94.87563274169761', "['Rodney-O & Joe Cooley']",
#         'This Is For The Homies'], dtype='<U661'),
#  array(['95.10841659517597', "['Paco Barrón y sus Norteños Clan']",
#         'Popurri - Bronco'], dtype='<U661'),
#  array(['94.6561155939827', "['José José']", 'La Barca'], dtype='<U661'),
#  array(['94.94318724909309', "['zebrahead']", 'Falling Apart'],
#        dtype='<U661'),
#  array(['95.10710972864754', "['Lynch Mob']", 'Wicked Sensation'],
#        dtype='<U661'),
#  array(['94.45646048787583',
#         "['Isham Jones & His Orchestra', 'Frank Sylvano']",
#         "It's Winter Again (feat. Frank Sylvano)"], dtype='<U661'),
#  array(['95.20389612707254', "['BoomBox']", 'Mr Boogie Man'], dtype='<U661'),
#  array(['95.03634101889334', "['Ernst H. Gombrich', 'Christoph Waltz']",
#         'Eine kurze Weltgeschichte für junge Leser: Von den Anfängen bis zum Mittelalter, Kapitel 22'],
#        dtype='<U661'),
#  array(['94.9992001362289', "['Aqua']", 'Cartoon Heroes - Radio Edit'],
#        dtype='<U661'),
#  array(['94.69149570498382', "['Martin Denny']", "Bali Ha'i"],
#        dtype='<U661'),
#  array(['94.50396633636683', "['Frédéric Chopin', 'Arthur Rubinstein']",
#         '24 Preludes, Op. 28: Prelude No. 22 in G minor'], dtype='<U661'),
#  array(['94.71250166340236', "['Muddy Waters']", 'Mannish Boy'],
#        dtype='<U661'),
#  array(['94.89789896293122', "['Elvis Presley']",
#         "I Just Can't Help Believin' - Live"], dtype='<U661'),
#  array(['94.75711794426294', "['Chet Baker']",
#         "I've Never Been In Love Before - Vocal Version"], dtype='<U661'),
#  array(['95.02628831823667', "['Make Them Suffer']", 'Widower'],
#        dtype='<U661'),
#  array(['94.38292611385243',
#         "['Joseph Achron', 'Felix Mendelssohn', 'Jascha Heifetz', 'Unknown Artist']",
#         '6 Songs, Op. 34: No. 2, On Wings of Song, MWV K 86 (Take 4) [Arr. for Violin & Piano]'],
#        dtype='<U661'),
#  array(['94.87833112255286',
#         "['Richard Rodgers', 'Julie Andrews', 'John Mauceri', 'Hollywood Bowl Orchestra']",
#         'Getting To Know You'], dtype='<U661'),
#  array(['94.73561332632829', "['Bad Brains']", 'Pay to Cum'], dtype='<U661'),
#  array(['94.40726275330985', "['Felix and his Krazy Kats']", 'Bob White'],
#        dtype='<U661'),
#  array(['94.85552696847704', "['El Gran Combo De Puerto Rico']",
#         'Trampolín'], dtype='<U661'),
#  array(['94.79137028604472', "['Willis Alan Ramsey']",
#         'Muskrat Love (Muskrat Candlelight)'], dtype='<U661'),
#  array(['94.37054762477749', "['Marian McPartland']", 'Yesterdays'],
#        dtype='<U661'),
#  array(['94.70836779298389', "['The Blues Brothers']",
#         'Everybody Needs Somebody to Love'], dtype='<U661'),
#  array(['95.01520873271672', "['Killswitch Engage']",
#         'When Darkness Falls'], dtype='<U661'),
#  array(['94.9971841724499', "['A Perfect Circle']", 'Magdalena'],
#        dtype='<U661'),
#  array(['94.33300840189573', "['M. S. Rama Rao']",
#         'Ee Reyi Nannolla Nerava'], dtype='<U661'),
#  array(['94.73444646634717', "['Sarah Vaughan']",
#         'Spring Will Be a Little Late This Year - From the Film "Christmas Holiday"'],
#        dtype='<U661'),
#  array(['95.0526589321118', "['All Time Low']", 'Stella'], dtype='<U661'),
#  array(['94.96666297060061', "['Kehlani', 'Jhené Aiko']",
#         'Change Your Life (feat. Jhené Aiko)'], dtype='<U661'),
#  array(['94.7459556951906', "['Stanley Turrentine']", 'Sheri'],
#        dtype='<U661'),
#  array(['94.60519318603501', "['Johann Sebastian Bach', 'Glenn Gould']",
#         'Italian Concerto in F Major, BWV 971: III. Presto - Version of 1981'],
#        dtype='<U661'),
#  array(['94.44482179667047', "['Frédéric Chopin', 'Vladimir Horowitz']",
#         'Scherzo No. 3 in C-Sharp Minor, Op. 39'], dtype='<U661'),
#  array(['94.92415515129495', "['Los Terricolas']", 'Yo Lo Comprendo'],
#        dtype='<U661'),
#  array(['95.05323885490554', "['João Gilberto']", 'Besame Mucho'],
#        dtype='<U661'),
#  array(['95.06947895053133', "['Youngblood Hawke']", 'We Come Running'],
#        dtype='<U661'),
#  array(['94.92633980660632', '["Mother\'s Finest"]', "Micky's Monkey"],
#        dtype='<U661'),
#  array(['94.90103702908918', "['Eric Clapton']",
#         'Holy Mother - 1999 Remaster'], dtype='<U661'),
#  array(['94.74337180532842', "['50 Cent']", 'I Get Money'], dtype='<U661'),
#  array(['94.75554734907492', "['Helen Merrill']", 'Yesterdays'],
#        dtype='<U661'),
#  array(['95.0186674657513', "['Tommy James & The Shondells']", "I'm Alive"],
#        dtype='<U661'),
#  array(['94.53263654536711', "['Meena Kapoor', 'Patanjali']",
#         'Aate Hai Woh Ahista Ahista'], dtype='<U661'),
#  array(['94.84240204431826', "['Yung Bans', 'Lil Skies']", 'Lonely'],
#        dtype='<U661'),
#  array(['95.02710192837823', "['Steel Pulse']", 'Leggo Beast'],
#        dtype='<U661'),
#  array(['95.06466674778501', "['Pearl Jam']", 'Nothing As It Seems'],
#        dtype='<U661'),
#  array(['94.70039366700766', "['Red Hot Chili Peppers']",
#         'Fire - Remastered'], dtype='<U661'),
#  array(['95.19352967680811', "['La Secta AllStar']",
#         'La Locura Automática'], dtype='<U661'),
#  array(['94.51536412572455', "['George Winston']", 'Road'], dtype='<U661'),
#  array(['94.69047445182741', "['Eydie Gormé', 'Los Panchos']",
#         'No Te Vayas Sin Mí'], dtype='<U661'),
#  array(['94.74495777480084', "['Johnny Adams']", 'Reconsider Me'],
#        dtype='<U661'),
#  array(['94.74876443025386', "['Stiff Little Fingers']", 'Wasted Life'],
#        dtype='<U661'),
#  array(['94.68730658413843', "['Engelbert Humperdinck']",
#         'By The Time I Get To Phoenix'], dtype='<U661'),
#  array(['94.62140701060869', "['Ray Charles']",
#         'Tell All the World About You'], dtype='<U661'),
#  array(['94.79486684791772', "['Kool G Rap', 'DJ Polo']",
#         'Ill Street Blues'], dtype='<U661'),
#  array(['94.39445266988312', "['Roza Eskenazi', 'Klarino Soukris']",
#         'Tis Dimitrenas (Tis Mitrenas)'], dtype='<U661'),
#  array(['94.54862185333951',
#         "['Victor Silvester and his Ballroom Orchestra']",
#         'Every Day and in Every Way'], dtype='<U661'),
#  array(['95.02186734505311', "['Lamar Campbell & Spirit Of Praise']",
#         'More Than Anything'], dtype='<U661'),
#  array(['95.04831800255187', "['Rush']", 'Afterimage'], dtype='<U661'),
#  array(['94.65306220269245',
#         "['Johannes Brahms', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#         'Concerto No. 2 for Piano and Orchestra in B-Flat Major, Op. 83: II. Allegro appassionato'],
#        dtype='<U661'),
#  array(['94.913015784444', "['Elvis Presley']", 'Kentucky Rain'],
#        dtype='<U661'),
#  array(['94.59937981236618',
#         "['Giacomo Puccini', 'Tito Gobbi', 'Dario Caselli', 'Orchestra Del Teatro Alla Scala, Milano', 'Victor de Sabata']",
#         'Puccini: Tosca, Act 2: "Tosca è un buon falco" (Scarpia, Sciarrone)'],
#        dtype='<U661'),
#  array(['94.99428880117358', "['Beautiful Chorus']", "Faith's Hymn"],
#        dtype='<U661'),
#  array(['95.07337027877509', "['Bow Wow', 'J-Kwon', 'Jermaine Dupri']",
#         "Fresh Az I'm Iz (feat. J-Kwon & Jermaine Dupri)"], dtype='<U661'),
#  array(['95.01035432517703', "['Mastodon']", 'Seabeast'], dtype='<U661'),
#  array(['94.94454235245118', "['The Chemical Brothers']",
#         'Hey Boy Hey Girl'], dtype='<U661'),
#  array(['94.48732794725075', "['Dimitris Arapakis']",
#         'Poios eide tetoio thaymasma'], dtype='<U661'),
#  array(['95.01959684328949', "['Hikaru Utada']", 'First Love'],
#        dtype='<U661'),
#  array(['95.14997491689078', "['Rival Sons']", 'Pressure and Time'],
#        dtype='<U661'),
#  array(['94.9781390948401', "['Beastie Boys']", 'Slow Ride'], dtype='<U661'),
#  array(['95.08390974177404', "['Sister Sledge']", 'Lost in Music'],
#        dtype='<U661'),
#  array(['95.16405984872983', "['Sisters of Mercy']",
#         'Flood I - New Version for Digital'], dtype='<U661'),
#  array(['95.0281903487163', "['Gojira']", 'Silvera'], dtype='<U661'),
#  array(['94.33956810810419', "['Francisco Canaro']",
#         "That's Why I Love You - Instrumental (Remasterizado)"],
#        dtype='<U661'),
#  array(['94.63807246605174', "['David Tolk']", 'Grace'], dtype='<U661'),
#  array(['94.63364494046616', "['Silu Wang']",
#         'Sonata Alla Toccata: Mvt. II. Andante con moto e semplice'],
#        dtype='<U661'),
#  array(['94.54092608884471',
#         "['ZAVEL ZILBERTS', 'Richard Tucker', 'Sholom Secunda']",
#         'Havdalah (Traditional Prayer For The End Of The Sabbath) - Voice'],
#        dtype='<U661'),
#  array(['95.15073881686504', "['Ram Herrera']", 'Ahora Dile'],
#        dtype='<U661'),
#  array(['95.09897699188129', "['Blake Shelton', 'Trace Adkins']",
#         'Hell Right (feat. Trace Adkins)'], dtype='<U661'),
#  array(['94.70232636246273', "['Illinois Jacquet']", 'Port Of Rico'],
#        dtype='<U661'),
#  array(['94.6764166764333', "['Johann Sebastian Bach', 'Glenn Gould']",
#         'Partita No. 3 in A Minor, BWV 827: II. Allemande'], dtype='<U661'),
#  array(['94.86430348080303', "['Dermot Kennedy']", 'A closeness'],
#        dtype='<U661'),
#  array(['95.0547886094392', "['Cuco']", 'Lover Is a Day'], dtype='<U661'),
#  array(['94.45651078135505', "['Dean Martin']", 'Moments Like This'],
#        dtype='<U661'),
#  array(['94.63356082670954', "['Andy Williams']", 'The First Noël'],
#        dtype='<U661'),
#  array(['94.92249066638375', "['Don Williams']",
#         "If Hollywood Don't Need You - Single Version"], dtype='<U661'),
#  array(['94.52155495090014', "['Richard Rodgers', 'Various Artists']",
#         'South Pacific: A Wonderful Guy'], dtype='<U661'),
#  array(['95.0402083899893', "['Dada']", 'Dim'], dtype='<U661'),
#  array(['95.01970417207635', "['Digable Planets']", 'Dog It'],
#        dtype='<U661'),
#  array(['95.14287366586912', "['Yusef Lateef']",
#         "Oscarlypso - Live At Pep's Lounge, Philadelphia / 1964"],
#        dtype='<U661'),
#  array(['94.66629370398144', "['Barbra Streisand']", "I Don't Care Much"],
#        dtype='<U661'),
#  array(['94.9204086476369', "['Banda El Recodo']", 'La Gitanilla'],
#        dtype='<U661'),
#  array(['94.81117958540021', "['George Jones']", "Bartender's Blues"],
#        dtype='<U661'),
#  array(['95.10693036005497', "['Rihanna']", 'Same Ol’ Mistakes'],
#        dtype='<U661'),
#  array(['94.57487453372107', "['Seweryn Goszczyński']",
#         'Chapter 1.22 - Zamek kaniowski'], dtype='<U661'),
#  array(['94.87036825634529', "['Ludacris', 'Mary J. Blige']",
#         'Runaway Love'], dtype='<U661'),
#  array(['94.84344024308726', "['Orquesta La Terrifica']",
#         'Como da Vueltas la Vida'], dtype='<U661'),
#  array(['94.67494584210597', "['Louis Armstrong']",
#         "Heigh-Ho (The Dwarf's Marching Song)"], dtype='<U661'),
#  array(['95.10653702198626', "['The Beatles']",
#         'Come Together - Remastered 2009'], dtype='<U661'),
#  array(['94.87186785054256', "['La Adictiva Banda San José de Mesillas']",
#         'En la Sierra y la Ciudad (La China)'], dtype='<U661'),
#  array(['94.77876335522032', "['Stephen Bishop']",
#         'Save It For A Rainy Day'], dtype='<U661'),
#  array(['94.92542921920257', "['blink-182']", 'Enthused'], dtype='<U661'),
#  array(['94.71243522377969', "['Nina Simone']",
#         "You'd Be so Nice to Come Home To - Live at the Newport Jazz Festival, Newport, RI, June 30, 1960"],
#        dtype='<U661'),
#  array(['95.18374888119888', "['Dan + Shay']", 'Tequila'], dtype='<U661'),
#  array(['94.58552120108554', "['Johnny Hodges']",
#         'Ballade For Very Tired And Very Sad Lotus Eaters'], dtype='<U661'),
#  array(['94.68074912635466', "['Tim Hardin']",
#         'How Can We Hang On To A Dream'], dtype='<U661'),
#  array(['94.45638396117491', "['Saraswati Rane']",
#         'Tu Kisliye Khamosh Hain'], dtype='<U661'),
#  array(['94.35467675907628', "['Lowell Fulson']", "You're Gonna Miss Me"],
#        dtype='<U661'),
#  array(['94.49335041105269', "['Dhananjay Bhattacharya']",
#         'Rangila Rangila'], dtype='<U661'),
#  array(['94.91263767442794', "['Rae Sremmurd', 'Migos']",
#         'Look Alive - Remix'], dtype='<U661'),
#  array(['95.07550713786043', "['Charles Mingus']",
#         'Better Get Hit In Your Soul - Instrumental'], dtype='<U661'),
#  array(['95.06101875222724', "['Bob Seger']", 'Hollywood Nights'],
#        dtype='<U661'),
#  array(['94.86748339610607', "['John Coltrane']", 'Cousin Mary - Mono'],
#        dtype='<U661'),
#  array(['94.74209382612644',
#         '[\'Max Roach\', \'Carlos "Potato" Valdez\', \'Carlos "Totico" Eugenio\']',
#         'Man From South Africa'], dtype='<U661'),
#  array(['94.32009979464522', "['George Olsen']",
#         'Nobody Knows What a Red-Head Mama Can Do'], dtype='<U661'),
#  array(['95.12576443652081', "['Michael Franks']", 'One Bad Habit'],
#        dtype='<U661'),
#  array(['94.67495594027908', "['Johann Sebastian Bach', 'Glenn Gould']",
#         'English Suite No. 5 in E Minor, BWV 810: I. Prelude'],
#        dtype='<U661'),
#  array(['94.77241213368791', "['Comethazine', 'Ugly God']",
#         'Let It Eat (feat. Ugly God)'], dtype='<U661'),
#  array(['95.0121055350448', "['The D.O.C.']", 'Let the Bass Go'],
#        dtype='<U661'),
#  array(['94.39556119227625', "['Vatsala Kumthekar']",
#         'Meri Ankhen Sharabi'], dtype='<U661'),
#  array(['94.57904602066371', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 158'], dtype='<U661'),
#  array(['95.51418714526223', "['Charles Mingus']",
#         'Medley: Mode D-Trio and Group Dancers/Mode E- Single solos and Group Dance/ModeF-Group and Solo Dance'],
#        dtype='<U661'),
#  array(['94.3929057136967', "['Dmitri Shostakovich', 'William Kapell']",
#         'Preludes, Op. 34: No. 24 in D Minor'], dtype='<U661'),
#  array(['95.21317895428561', "['Tito Rojas Y Su Orquesta']", 'Este Amor'],
#        dtype='<U661'),
#  array(['95.13896650223869', "['Gregory Isaacs']",
#         'Soon Forward - 1990 Digital Remaster'], dtype='<U661'),
#  array(['94.94118611765116', "['Cro-Mags']", 'We Gotta Know'],
#        dtype='<U661'),
#  array(['95.07980813815867', "['Ciara', '50 Cent']",
#         "Can't Leave 'Em Alone (feat. 50 Cent)"], dtype='<U661'),
#  array(['94.57855102192546', "['Sinclair Lewis', 'Frank Arnold']",
#         'Das ist bei uns nicht möglich, Kapitel 133'], dtype='<U661'),
#  array(['94.84858794797151', "['Mac Dre']", 'Thizzle Dance'], dtype='<U661'),
#  array(['94.96413845870129', "['Miki Howard']", 'Baby, Be Mine'],
#        dtype='<U661'),
#  array(['94.5305142866526',
#         '[\'Ninon Vallin\', \'Georges Thill\', \'Germaine Féraldy\', "Chœur et Orchestre de l\'Opéra de Paris", \'Elie Cohen\']',
#         "Werther, Acte III: oui, c'est moi!"], dtype='<U661'),
#  array(['94.45829288174941', "['Hemant Kumar']", 'Amar Raat Pohalo'],
#        dtype='<U661'),
#  array(['94.9943982939401', "['J Moss']", 'Praise on the Inside'],
#        dtype='<U661'),
#  array(['94.58532797915223', '[\'Richard "Groove" Holmes\']', 'Misty'],
#        dtype='<U661'),
#  array(['94.97257238016199', "['Fishbone', 'Little Richard']",
#         "Two Timin' Woman"], dtype='<U661'),
#  array(['95.06754488123951', "['The Brothers Johnson']",
#         'Stomp! - Single Version'], dtype='<U661'),
#  array(['94.79248808414253', "['Roy Orbison']", 'Bye Bye Love'],
#        dtype='<U661'),
#  array(['95.1658993082381', "['Alcoholics Anonymous']",
#         "The Doctor's Nightmare"], dtype='<U661'),
#  array(['94.87329089190673', "['Mel Tillis']", 'Coca Cola Cowboy'],
#        dtype='<U661'),
#  array(['94.80638060938999', "['Jack Johnson']", 'Dreams Be Dreams'],
#        dtype='<U661'),
#  array(['94.58590726351964', "['Lupita P\\x82rez']",
#         '¨ Has o¡do eso?/ Me pregunto'], dtype='<U661'),
#  array(['94.44575629198881', "['Billie Holiday', 'Teddy Wilson']",
#         "The Mood That I'm In (with Teddy Wilson & His Orchestra)"],
#        dtype='<U661'),
#  array(['95.06909278130799', "['The Rolling Stones']",
#         'Too Much Blood - Remastered'], dtype='<U661'),
#  array(['94.51091538337815', "['Aretha Franklin']",
#         'Love Is the Only Thing'], dtype='<U661'),
#  array(['95.05955911472223', "['Miranda Lambert']",
#         'Baggage Claim - Radio Edit'], dtype='<U661'),
#  array(['94.98009542149143', "['Wishbone Ash']", 'Jail Bait'],
#        dtype='<U661'),
#  array(['94.7088184691214',
#         "['Johann Sebastian Bach', 'Glenn Gould', 'Columbia Symphony Orchestra', 'Leonard Bernstein']",
#         'Keyboard Concerto No. 1 in D Minor, BWV 1052: I. Allegro'],
#        dtype='<U661'),
#  array(['94.76163641402295', "['Eminem', 'Dr. Dre']", 'Guilty Conscience'],
#        dtype='<U661'),
#  array(['95.03398468482806', "['Tyrone Davis']", "I Can't Wait"],
#        dtype='<U661'),
#  array(['94.99249493798818', "['Bon Jovi']", 'Wild In The Streets'],
#        dtype='<U661'),
#  array(['95.09416011398805', "['Incubus']", 'Deep Inside'], dtype='<U661'),
#  array(['95.05788169073978', "['Merle Haggard']",
#         "Let's Chase Each Other Around the Room"], dtype='<U661'),
#  array(['94.82258157567945', "['Barbara Lewis']",
#         'Does Anyone Want a Lover'], dtype='<U661'),
#  array(['94.98183152365159', "['The Black Keys']", 'The Go Getter'],
#        dtype='<U661'),
#  array(['94.89645887459739', "['Minutemen']", 'June 16th'], dtype='<U661'),
#  array(['95.04405222796417', "['DEAN', 'Crush', 'Jeff Bernat']",
#         'What 2 Do'], dtype='<U661'),
#  array(['94.49966258923236', "['Frédéric Chopin', 'Eugene Istomin']",
#         'Nocturnes, Op. 32: No. 1 in B Major'], dtype='<U661'),
#  array(['94.78844707506565', "['Anuhea']", 'Simple Love Song'],
#        dtype='<U661'),
#  array(['94.60174645361795', "['P. Leela']", 'Andame Aanandam, Pt. 1'],
#        dtype='<U661'),
#  array(['94.50928424284045', "['Merle Haggard']",
#         'If I Had Left It Up To You - Remastered'], dtype='<U661'),
#  array(['94.80961341259277', "['Mase']", 'Feel so Good'], dtype='<U661'),
#  array(['94.70551264793383', "['Julius Aston']", 'Trieste'], dtype='<U661'),
#  array(['94.75700257609563', "['Colter Wall']", 'Thirteen Silver Dollars'],
#        dtype='<U661'),
#  array(['94.62240012390347', "['Hubert Fol']", 'I Want to Be Happy'],
#        dtype='<U661'),
#  array(['94.57585832710895', "['The Pied Pipers']", 'Should I'],
#        dtype='<U661'),
#  array(['94.82619511746053', "['Sabah']", 'يانا يانا'], dtype='<U661'),
#  array(['95.005868120313', "['Voces Del Rancho']", 'Corrido De Los Perez'],
#        dtype='<U661'),
#  array(['94.92723456251241', "['Cody Johnson']", 'On My Way to You'],
#        dtype='<U661'),
#  array(['94.85042328649637', "['The Monkees']",
#         'You Just May Be The One - 2006 Remastered Version T.V. Version'],
#        dtype='<U661'),
#  array(['95.01617593263812', "['Neil Young']",
#         'Field of Opportunity - 2016 Remaster'], dtype='<U661'),
#  array(['94.70386287441522', "['Alex de Grassi']", 'Western'],
#        dtype='<U661'),
#  array(['95.00730801126376', "['Skillet']", "It's Not Me, It's You"],
#        dtype='<U661'),
#  array(['94.79580037408991', "['Indigo Girls']", 'Center Stage'],
#        dtype='<U661'),
#  array(['94.51062764891385', "['Jr. Walker & The All Stars']", 'Hot Cha'],
#        dtype='<U661'),
#  array(['95.12113400830461', "['Bridgit Mendler']", 'Ready or Not'],
#        dtype='<U661'),
#  array(['94.57953637614868', "['Patricia St. John']",
#         'Kapitel 106 - Spuren im Schnee'], dtype='<U661'),
#  array(['94.79479922678274', "['Prince']", 'Little Red Corvette'],
#        dtype='<U661'),
#  array(['95.10004698364256', "['Tokyo Police Club']", 'Bambi'],
#        dtype='<U661'),
#  array(['94.85001556902215',
#         "['Dale Carnegie', 'Till Hagen', 'Stefan Kaminski']",
#         'Wie man Freunde gewinnt - Die Kunst, beliebt und einflussreich zu werden, Kapitel 39'],
#        dtype='<U661'),
#  array(['94.74454935837139', "['紫薇']", '戀之火'], dtype='<U661'),
#  array(['95.1327797711529', "['Klymaxx', 'Louil Silas Jr.']",
#         'The Men All Pause'], dtype='<U661'),
#  array(['95.0919698609596', "['Banda Pachuco']", 'Tengo Que Olvidar'],
#        dtype='<U661'),
#  array(['95.1430408638843', "['Led Zeppelin']",
#         'The Ocean - 2012 Remaster'], dtype='<U661'),
#  array(['94.84535432511201', "['Jay Chou']", '世界末日'], dtype='<U661'),
#  array(['94.77946730226246', "['Vern Gosdin']",
#         "This Ain't My First Rodeo"], dtype='<U661'),
#  array(['95.13509712873488', "['Rush']", 'Red Tide - 2004 Remaster'],
#        dtype='<U661'),
#  array(['94.92578125921261', "['Mel Waiters']", 'Hole In the Wall'],
#        dtype='<U661'),
#  array(['94.73481862034413',
#         "['Carl Ditters von Dittersdorf', 'Failoni Kamarazenekar', 'Hanspeter Gmür']",
#         'Symphony No. 1 in C Major, "Die 4 Weltalter" (the 4 Ages of the World): I. Larghetto'],
#        dtype='<U661'),
#  array(['95.40849050408083', "['Freeez']", 'I.O.U. (12" Version)'],
#        dtype='<U661'),
#  array(['95.16584863697426', "['Waterfront Home']", 'Take A Chance'],
#        dtype='<U661'),
#  array(['95.09681876225467', "['The Weeknd']", 'In Your Eyes'],
#        dtype='<U661'),
#  array(['95.05681581709362', "['Rise Against']", 'Injection'],
#        dtype='<U661'),
#  array(['94.9946774044482', "['RBL Posse']", 'Remind Me'], dtype='<U661'),
#  array(['95.22908765270809', "['Arrested Development']", 'People Everyday'],
#        dtype='<U661'),
#  array(['94.49483404310652', "['Claudio Villa']",
#         'Nannì (Una gita a li castelli)'], dtype='<U661'),
#  array(['94.98968102405564', "['Simon Curtis']", 'Pit Of Vipers'],
#        dtype='<U661'),
#  array(['94.92898314356039', "['Freestyle']", 'This Time'], dtype='<U661'),
#  array(['94.74382122662168', "['Stevie Wonder']",
#         'The Secret Life Of Plants'], dtype='<U661'),
#  array(['94.94122113908196', "['Elton John']",
#         'Dirty Little Girl - Remastered 2014'], dtype='<U661'),
#  array(['94.82152294793603', "['Johnny Ip']", '忘盡心中情 - 無線電視劇[蘇乞兒]主題曲'],
#        dtype='<U661'),
#  array(['94.98334790034333', "['KISS']", "Comin' Home"], dtype='<U661'),
#  array(['95.07493917947329', "['Bembeya Jazz National']", 'Petit Sékou'],
#        dtype='<U661'),
#  array(['94.37508462594198', "['Lalita Phadke']", 'Langada Ga Bai Langada'],
#        dtype='<U661'),
#  array(['94.98358535068455', "['Audioslave']", 'Yesterday To Tomorrow'],
#        dtype='<U661'),
#  array(['94.43273976412763', "['Eddie Heywood']", 'Without A Song'],
#        dtype='<U661'),
#  array(['94.43268766669512', "['Francisco Canaro']",
#         'La Quimera - Instrumental (Remasterizado)'], dtype='<U661'),
#  array(['94.41245851288143', "['Demetri Martin']", 'Yep'], dtype='<U661'),
#  array(['94.84550498159678', "['Yung Lean']", 'Yoshi City'], dtype='<U661'),
#  array(['94.74008480517239', "['Motograter']", 'Suffocate'], dtype='<U661'),
#  array(['94.4674196836521', "['Franz Liszt', 'Vladimir Horowitz']",
#         'Rakóczy March, No. 15 from Hungarian Rhapsodies for Piano'],
#        dtype='<U661'),
#  array(['94.89290657605433', "['Jarabe De Palo']", 'La flaca'],
#        dtype='<U661'),
#  array(['95.02472598798526', "['Breaking Benjamin']", 'You Fight Me'],
#        dtype='<U661'),
#  array(['94.52720847154636', "['The Lettermen']",
#         'The Way You Look Tonight'], dtype='<U661'),
#  array(['94.58315113665255', "['Doris Day']",
#         'I\'ve Never Been In Love Before - (from the musical "Guys and Dolls")'],
#        dtype='<U661'),
#  array(['94.65878294921247', "['Frank Sinatra']",
#         "It's A Lonesome Old Town - 1958 Mono Mix"], dtype='<U661'),
#  array(['94.61102105888043', "['Sweethearts of the Rodeo']",
#         'Jingle Bell Rock'], dtype='<U661'),
#  array(['94.36252626047292', "['Francisco Canaro', 'Roberto Maida']",
#         'Filomena - Remasterizado'], dtype='<U661'),
#  array(['94.51491272179008', "['Thelonious Monk']",
#         'Introspection - Rudy Van Gelder 24-Bit Mastering / 1998 Digital Remaster'],
#        dtype='<U661'),
#  array(['95.1987504633845', "['The Beatles']",
#         'While My Guitar Gently Weeps - Remastered 2009'], dtype='<U661'),
#  array(['94.95360327893684', "['Honeymoon Suite']", 'Stay in the Light'],
#        dtype='<U661'),
#  array(['95.0214900742896', "['Heatwave']", 'Boogie Nights'], dtype='<U661'),
#  array(['94.65698083948766', "['Oscar Levant', 'MGM Studio Orchestra']",
#         'Concerto In F - 3rd Movement'], dtype='<U661'),
#  array(['94.52890730578466',
#         "['Paul Clayton', 'Jean Ritchie', 'Richard Chase']",
#         'The Bashful Courtship'], dtype='<U661'),
#  array(['95.08521924420481', "['Earth, Wind & Fire']",
#         'Africano / Power - Live'], dtype='<U661'),
#  array(['95.30379233196685',
#         "['Anton Bruckner', 'Bruno Walter', 'Columbia Symphony Orchestra']",
#         'Symphony No. 4 in E-Flat Major, WAB 104 "Romantic": IV. Finale. Bewegt, doch nicht zu schnell'],
#        dtype='<U661'),
#  array(['95.00494821808282', "['The Beach Boys']",
#         'Your Summer Dream (Stereo)'], dtype='<U661'),
#  array(['94.65934100382461', "['Alan Jackson']",
#         'Standing On The Promises'], dtype='<U661'),
#  array(['95.08262554417662', "['Amy Winehouse']", 'Brother'], dtype='<U661'),
#  array(['94.69596071727663', "['The Louvin Brothers']",
#         "I'm Ready To Go Home"], dtype='<U661'),
#  array(['94.97395290062207', "['Metallica']",
#         'Fight Fire With Fire (Remastered)'], dtype='<U661'),
#  array(['94.70357937259578', '["Original Broadway Cast of \'Pal Joey\'"]',
#         'The Flower Garden Of My Heart'], dtype='<U661'),
#  array(['94.86702791121252', "['Dan Fogelberg']", 'Run for the Roses'],
#        dtype='<U661'),
#  array(['94.75870957240838', "['Best Coast']", "When I'm With You"],
#        dtype='<U661'),
#  array(['94.49941435754845', "['Pankaj Mullick']",
#         'Timir Abogunthane Badan Tabo Dhaki'], dtype='<U661'),
#  array(['94.55982428553797', "['Kid Cudi', 'Chip Tha Ripper']", 'T.G.I.F.'],
#        dtype='<U661'),
#  array(['94.68440782281304', "['Yusuf / Cat Stevens']", 'The Wind'],
#        dtype='<U661'),
#  array(['94.71025812765764', "['Miles Davis']", "'Round Midnight"],
#        dtype='<U661'),
#  array(['94.82688184140089', "['Johnathan Adams']", 'Eddie'], dtype='<U661'),
#  array(['94.8190792290909', "['Korn']", 'Evolution'], dtype='<U661'),
#  array(['94.56862992918929', "['Marty Robbins']", "The Master's Call"],
#        dtype='<U661'),
#  array(['95.1543985598404', "['AFI']", 'The Leaving Song Pt. II'],
#        dtype='<U661'),
#  array(['94.87772554675823', "['Queen']",
#         'Funny How Love Is - Remastered 2011'], dtype='<U661'),
#  array(['95.19862654395855', "['Ray LaMontagne']", 'Hold You in My Arms'],
#        dtype='<U661'),
#  array(['94.49620119121998',
#         "['Ludwig van Beethoven', 'Budapest String Quartet']",
#         'String Quartet No. 1 in F Major, Op. 18: III. Scherzo. Allegro molto'],
#        dtype='<U661'),
#  array(['95.16638002913108', "['Mocedades']", 'Eres Tú'], dtype='<U661'),
#  array(['95.04326991731045', "['Santana', 'Everlast']",
#         'Put Your Lights On (feat. Everlast)'], dtype='<U661'),
#  array(['94.84533891700322', "['Tom Waits']", 'Clap Hands'], dtype='<U661'),
#  array(['95.06395397035585', "['El As De La Sierra']", 'La Loba Del Mal'],
#        dtype='<U661'),
#  array(['94.58624735870451', "['Paul Simon']", 'A Most Peculiar Man'],
#        dtype='<U661'),
#  array(['94.79377278426152', "['Jacques Dutronc']",
#         "Il est cinq heures, Paris s'éveille"], dtype='<U661'),
#  array(['95.07450444238158', "['Bauhaus']", 'Of Lilies and Remains'],
#        dtype='<U661'),
#  array(['94.65618966394416', "['John Williams']",
#         "Slave Children's Crusade"], dtype='<U661'),
#  array(['94.82181302245185', "['Andre Nickatina']", 'Situation Critical'],
#        dtype='<U661'),
#  array(['94.8842780341806', "['The J. Geils Band']", 'Must of Got Lost'],
#        dtype='<U661'),
#  array(['94.44881731314184',
#         "['Francesco Paolo Tosti', 'Mario Lanza', 'Constantine Callinicos']",
#         'Marechiare'], dtype='<U661'),
#  array(['95.05064259205705', "['Nine Inch Nails']", 'Happiness In Slavery'],
#        dtype='<U661'),
#  array(['94.95674211034586', "['Hank Williams, Jr.']", 'Kaw-Liga'],
#        dtype='<U661'),
#  array(['94.46268154711258', "['My Chemical Romance']",
#         'Blood - Hidden Track'], dtype='<U661'),
#  array(['94.75385135052632', "['Mandy Patinkin', 'Bernadette Peters']",
#         'Color and Light'], dtype='<U661'),
#  array(['94.68288898860015', "['Barbra Streisand']", 'Sadie, Sadie'],
#        dtype='<U661'),
#  array(['94.83034682572371', "['The Impressions']", 'Gypsy Woman'],
#        dtype='<U661'),
#  array(['94.68544465943039', "['Antonio Morel']", 'Quisqueya Libre'],
#        dtype='<U661'),
#  array(['95.25148715614212', "['Audioslave']", 'Like a Stone'],
#        dtype='<U661'),
#  array(['94.76289247929114', "['Mista Madd', 'Yungstar', 'Slim Thug']",
#         'Down South'], dtype='<U661'),
#  array(['94.8859525259151', "['dodie']", 'Monster'], dtype='<U661'),
#  array(['94.91251667494379', "['Gloria Trevi']", 'Agárrate'], dtype='<U661'),
#  array(['94.75828220420017', "['Nitty Gritty Dirt Band', 'Roy Acuff']",
#         'I Saw The Light'], dtype='<U661'),
#  array(['94.43534267685341', "['Robin Majumdar']",
#         'E Ranga Godhuli Hole Abasan'], dtype='<U661'),
#  array(['94.49923829866313', "['Jack Costanzo']",
#         'The Peanut Vendor - 2003 Remaster'], dtype='<U661'),
#  array(['94.91310035971235', "['ABBA']", 'Man In The Middle'],
#        dtype='<U661'),
#  array(['95.06765149134336', "['Paul Simon']",
#         'The Story of "Graceland" as Told by Paul Simon'], dtype='<U661'),
#  array(['95.08835750555406', "['Kesha']", 'We R Who We R'], dtype='<U661'),
#  array(['94.93211584301922', "['The Maytals']", "54-46 That's My Number"],
#        dtype='<U661'),
#  array(['94.67114999586767', "['The Pogues']",
#         'The Sick Bed of Cuchulainn'], dtype='<U661'),
#  array(['94.65744370150894',
#         "['Giuseppe Verdi', 'Richard Tucker', 'Max Rudolf']",
#         'Otello: Già nella notte'], dtype='<U661'),
#  array(['95.17944170099538', "['Elevation Worship']", 'See A Victory'],
#        dtype='<U661'),
#  array(['94.53598921827125', "['Roza Eskenazi']", 'To Marikaki'],
#        dtype='<U661'),
#  array(['95.2437392007599', "['Grupo Cañaveral De Humberto Pabón']",
#         'Tiene Espinas El Rosal'], dtype='<U661'),
#  array(['94.8558468952487',
#         "['YoungBoy Never Broke Again', 'Kevin Gates']",
#         'TTG (feat. Kevin Gates)'], dtype='<U661'),
#  array(['95.01239354517797', "['Billy Dean']", 'Billy The Kid'],
#        dtype='<U661'),
#  array(['95.23733572839048', "['Juan Gabriel']", 'El Noa Noa'],
#        dtype='<U661'),
#  array(['94.9914569206559', "['Pretenders']", 'Back on the Chain Gang'],
#        dtype='<U661'),
#  array(['94.9216650828534', "['City and Colour']", 'Northern Wind'],
#        dtype='<U661'),
#  array(['94.87318499705088', "['Maroon 5', 'Wiz Khalifa']", 'Payphone'],
#        dtype='<U661'),
#  array(['94.85303566038381', "['Madonna']", 'Frozen'], dtype='<U661'),
#  array(['94.42357660423178',
#         "['Wolfgang Amadeus Mozart', 'Sir Thomas Beecham', 'Royal Philharmonic Orchestra']",
#         'Symphony No. 38 in D Major, K. 505, “Prague”: 3. Finale - Presto'],
#        dtype='<U661'),
#  array(['94.82804031545626', "['Fuerza Regida']", 'Aquí Sigo Yo'],
#        dtype='<U661'),
#  array(['94.82479897356498', "['Billie Holiday']",
#         "Baby Won't You Please Come Home"], dtype='<U661'),
#  array(['94.94080577067372', "['Squeeze']", 'Goodbye Girl'], dtype='<U661'),
#  array(['95.03695257355079', "['Chase Rice']", "What's Your Name"],
#        dtype='<U661'),
#  array(['94.80189847999952', "['Ferlin Husky']", 'Wings Of A Dove'],
#        dtype='<U661'),
#  array(['94.9637803626847', "['Earth, Wind & Fire']", "Burnin' Bush"],
#        dtype='<U661'),
#  array(['94.46938634942862', "['Ethel Waters']", 'Shake That Thing'],
#        dtype='<U661'),
#  array(['94.59204006401748', "['The Piano Guys']", 'Story of My Life'],
#        dtype='<U661'),
#  array(['95.18104172242371', "['Herbie Hancock']",
#         'Just Around the Corner'], dtype='<U661'),
#  array(['94.60705589003332', "['Claude Debussy', 'William Kapell']",
#         'Suite bergamasque: Passepied'], dtype='<U661'),
#  array(['94.86630465785069', "['Earl Thomas Conley']",
#         'Nobody Falls Like a Fool'], dtype='<U661'),
#  array(['95.31490446238492', "['Donna Summer']", 'I Feel Love'],
#        dtype='<U661'),
#  array(['94.55189768411476', "['Lester Young']", 'Blue Lester'],
#        dtype='<U661'),
#  array(['94.84531905850527', "['Aventura']", 'Amor Bonito (Novela 2)'],
#        dtype='<U661'),
#  array(['95.0525405247049', "['Dream']", 'This Is Me'], dtype='<U661'),
#  array(['94.62035904283348', "['Etta Jones']",
#         'On The Street Where You Live'], dtype='<U661'),
#  array(['94.9706348112623', "['Jon Pardi']", "When I've Been Drinkin'"],
#        dtype='<U661'),
#  array(['94.7719663310877', "['Rascal Flatts']", 'Bless The Broken Road'],
#        dtype='<U661'),
#  array(['95.21892332850486', "['Justin Bieber', 'Kehlani']",
#         'Get Me (feat. Kehlani)'], dtype='<U661'),
# ...
#         'Sajni Chalo Chale Us Paar'], dtype='<U661'),
#  array(['94.82557527686248',
#         "['Béla Bartók', 'Herbert von Karajan', 'Philharmonia Orchestra']",
#         'Bartók: Music for Strings, Percussion and Celesta, Sz. 106: I. Andante tranquillo'],
#        dtype='<U661'),
#  array(['94.73939293942774', "['Trippie Redd', 'Coi Leray']",
#         'Everything BoZ'], dtype='<U661'),
#  array(['95.09873459113057', "['Deodato']", "Skatin'"], dtype='<U661'),
#  array(['94.61876954803836', "['Claudio Villa']", 'Marina'], dtype='<U661'),
#  array(['95.19742031699697', "['Rush']",
#         'La Villa Strangiato - Live In Canada / 1980'], dtype='<U661'),
#  array(['95.07455638661762', "['Culture Club']",
#         'Karma Chameleon - Remastered'], dtype='<U661'),
#  array(['95.13325700321272', "['LOUDNESS']", 'Lost Without Your Love'],
#        dtype='<U661'),
#  array(['94.65398708114004', "['Miles Davis Quintet']",
#         'I Could Write A Book'], dtype='<U661'),
#  array(['94.67085280767714', "['John Coltrane Quartet']",
#         "You Don't Know What Love Is"], dtype='<U661'),
#  array(['95.05077927594859', "['Toots & The Maytals']", 'Louie Louie'],
#        dtype='<U661'),
#  array(['95.10731001467931', "['Bruce Springsteen']",
#         'Hungry Heart - Live at Nassau Coliseum, Uniondale, NY - December 1980'],
#        dtype='<U661'),
#  array(['94.88725074026777',
#         "['Flosstradamus', 'FKi 1st', 'graves', 'Post Malone', 'KEY!']",
#         'Came Up'], dtype='<U661'),
#  array(['95.05108523808131', "['The Human League']", "Don't You Want Me"],
#        dtype='<U661'),
#  array(['94.99529978665701', "['ICEHOUSE']", 'Hey, Little Girl'],
#        dtype='<U661'),
#  array(['95.1430604204476', "['Tina Turner']", 'Proud Mary'], dtype='<U661'),
#  array(['94.83557906278277', "['Julio Iglesias']",
#         'Quiereme Mucho - Yours'], dtype='<U661'),
#  array(['94.56898803724313',
#         "['George Frideric Handel', 'Wolfgang Meyer', 'Berliner Philharmoniker', 'Rafael Kubelik']",
#         'Water Music Suite, HWV 348-350: Alla Hornpipe'], dtype='<U661'),
#  array(['94.77183358816163', "['Andre Nickatina']", 'Killa Whale'],
#        dtype='<U661'),
#  array(['95.06019873729852', "['Rise Against']", 'This Is Letting Go'],
#        dtype='<U661'),
#  array(['95.11265903822506', "['Slipknot']", 'Before I Forget'],
#        dtype='<U661'),
#  array(['95.1875044195246', "['ZZ Top']", 'La Grange'], dtype='<U661'),
#  array(['94.73016778729284', "['Fairuz']", 'Ya Ana Ya Ana - Live'],
#        dtype='<U661'),
#  array(['95.06036084005474', "['The Deele']", 'Two Occasions'],
#        dtype='<U661'),
#  array(['95.28979789807597', "['Donna Summer', 'Barbra Streisand']",
#         'No More Tears (Enough Is Enough) - 12" Version'], dtype='<U661'),
#  array(['94.90525563636237', "['The Dave Brubeck Quartet']",
#         'Since Love Had Its Way - previously unreleased'], dtype='<U661'),
#  array(['94.93725579999023', "['Billy Joel']",
#         "C'etait toi (You Were the One)"], dtype='<U661'),
#  array(['94.76044956377383', "['Tennessee Ernie Ford']", 'Goober Peas'],
#        dtype='<U661'),
#  array(['94.55131216586727', "['Aaron Copland', 'William Kapell']",
#         'Piano Sonata: Molto moderato'], dtype='<U661'),
#  array(['94.89313836033159', "['The Stills-Young Band']",
#         'Long May You Run - 2017 Remaster'], dtype='<U661'),
#  array(['94.54797911444409', "['Robert Frost']", 'The Road Not Taken'],
#        dtype='<U661'),
#  array(['94.48559882841488', "['Satish', 'Jyoti']", 'Aai Rajni Kali Kali'],
#        dtype='<U661'),
#  array(['94.70883813696645', "['Эрих Мария Ремарк']",
#         'Часть 203.4 & Часть 204.1 - Триумфальная арка'], dtype='<U661'),
#  array(['94.71717092512647', '["The O\'Jays"]', 'Brandy'], dtype='<U661'),
#  array(['94.98555562851115', "['Dave Matthews Band']", 'Mercy'],
#        dtype='<U661'),
#  array(['94.77583528673512', "['Juan Gabriel']", 'La Muerte del Palomo'],
#        dtype='<U661'),
#  array(['95.09077386153591', "['Shakira']", 'Try Everything'],
#        dtype='<U661'),
#  array(['95.18915316511041', "['FUNKIST']", 'Ft.'], dtype='<U661'),
#  array(['95.11598878007047', "['Dream Theater']", 'The Mirror'],
#        dtype='<U661'),
#  array(['94.40366667705136', "['Francisco Canaro', 'Charlo']",
#         'Piñataro - Remasterizado'], dtype='<U661'),
#  array(['95.02195495485691', "['New Order']", 'Fine Time - 2015 Remaster'],
#        dtype='<U661'),
#  array(['94.82376811049879', "['Pesteg Dred', 'SS-Say', 'Martin Hall']",
#         'Care'], dtype='<U661'),
#  array(['95.04481041746524', "['Ratatat']", 'Seventeen Years'],
#        dtype='<U661'),
#  array(['94.63642376261187', "['Frédéric Chopin', 'Arthur Rubinstein']",
#         'Nocturnes, Op. 32: No. 2 in A-Flat'], dtype='<U661'),
#  array(['94.7598720232665', "['Brenton Wood']", 'Whoop It On Me'],
#        dtype='<U661'),
#  array(['94.66312047792526', "['Felix Ortega']", 'Entriega de Novios'],
#        dtype='<U661'),
#  array(['94.34796618132052', "['Henry Mancini']",
#         'Happy Barefoot Boy (From "Two for the Road")'], dtype='<U661'),
#  array(['94.5161961306237', "['Sonny Boy Williamson I']",
#         'Sugar Mama Blues No. 2'], dtype='<U661'),
#  array(['94.80697428433695', "['Matt Monro']", 'This Is The Life'],
#        dtype='<U661'),
#  array(['94.80907861140629', "['Banda Cuisillos']", 'Un Muchacho Pobre'],
#        dtype='<U661'),
#  array(['94.75022157051933', "['Andrew Hill']",
#         'New Monastery - Rudy Van Gelder Edition/1999 Remaster'],
#        dtype='<U661'),
#  array(['94.76172786588408', '[\'Francisco "Charro" Avitia\']',
#         'Mi Caballo Bayo'], dtype='<U661'),
#  array(['95.09832424176619', "['George Benson']", 'Love X Love'],
#        dtype='<U661'),
#  array(['95.03756811316157', "['REO Speedwagon']", "I Do' Wanna Know"],
#        dtype='<U661'),
#  array(['95.25316597661143', "['Grace Jones']",
#         'Slave To The Rhythm - Hot Blooded Version'], dtype='<U661'),
#  array(['94.87031657334727', "['DEVO']", 'Beautiful World'], dtype='<U661'),
#  array(['94.54499996147734', "['Mose Allison']", 'One Room Country Shack'],
#        dtype='<U661'),
#  array(['95.12877083652097', "['Pavement']", 'Cut Your Hair'],
#        dtype='<U661'),
#  array(['94.64878865161705', "['Charlie Parker']", 'Passport'],
#        dtype='<U661'),
#  array(['94.76849236992967', "['Pepe Aguilar']", 'Por Una Mujer Bonita'],
#        dtype='<U661'),
#  array(['95.10967012069221', "['Charles Mingus']", 'Folk Forms, No. 1'],
#        dtype='<U661'),
#  array(['94.5248692594274', "['Louise Bennett']", 'Day Dah Light'],
#        dtype='<U661'),
#  array(['94.52316786445223',
#         "['Ludwig van Beethoven', 'Paul Baumgartner']",
#         '33 Piano Variations In C, Op.120 On A Waltz By Anton Diabelli: Variation 33 (Tempo di minuetto moderato, ma non tirarsi dietro)'],
#        dtype='<U661'),
#  array(['94.99777938987154', "['Herencia de Patrones']",
#         'Cosas De La Clica'], dtype='<U661'),
#  array(['94.64968271861422',
#         "['Pyotr Ilyich Tchaikovsky', 'Fritz Reiner']",
#         'Symphony No. 6 in B Minor, Op. 74 "Pathétique": III. Allegro molto vivace'],
#        dtype='<U661'),
#  array(['94.90594490284172', "['N.W.A.']", "I Ain't Tha 1"], dtype='<U661'),
#  array(['94.63161385963633', "['Javier Solís']", 'Payaso'], dtype='<U661'),
#  array(['94.72704583423675', "['Basia']", 'Waters of March'], dtype='<U661'),
#  array(['94.6446664833861', "['Balmorhea']", 'Truth (Helios Remix)'],
#        dtype='<U661'),
#  array(['94.61413248499859', "['Эрнест Хемингуэй']",
#         'Часть 44.4 & Часть 45.1 - Фиеста'], dtype='<U661'),
#  array(['94.46397666548967',
#         "['Richard Strauss', 'London Philharmonic Orchestra']",
#         'Le Bourgeois Gentilhomme – Suite Op.60: II Minuet'], dtype='<U661'),
#  array(['95.08794851356046', "['702']", 'Where My Girls At'], dtype='<U661'),
#  array(['94.98338250081468', "['Deuter']", 'Temple of Silence'],
#        dtype='<U661'),
#  array(['94.68594975313441', "['This Mortal Coil']",
#         'Song To The Siren (Remastered)'], dtype='<U661'),
#  array(['94.8075073916854', "['Khalid']", 'Saturday Nights'], dtype='<U661'),
#  array(['95.09248486194464', "['Queensrÿche']",
#         'Suite Sister Mary - Remastered 2003'], dtype='<U661'),
#  array(['94.54836871280006',
#         "['Giorgos Nakos', 'Klarino- Nikos Karakostas']", 'I Haido'],
#        dtype='<U661'),
#  array(['94.61112773345413', "['Sonny Rollins']", 'Mambo Bounce'],
#        dtype='<U661'),
#  array(['94.6044781094794', "['Béla Bartók', 'Isaac Stern']",
#         'Violin Sonata No. 1, Sz. 75: III. Allegro'], dtype='<U661'),
#  array(['94.73486722056577', "['Jason Hayes']", 'Elwynn Forest'],
#        dtype='<U661'),
#  array(['94.77581416088107', "['Amanda Perez']", 'Angel'], dtype='<U661'),
#  array(['95.05469625967994', "['Bryan Adams']", 'Here I Am - End Title'],
#        dtype='<U661'),
#  array(['94.7033149261166', "['Shelley Fabares']",
#         'Johnny Angel - Single Version'], dtype='<U661'),
#  array(['94.33120799324857', "['Francisco Canaro']",
#         'Asi me Dejas - Remasterizado'], dtype='<U661'),
#  array(['94.89647424128204', "['Buddy Miles']", "Heart's Delight"],
#        dtype='<U661'),
#  array(['94.37397618930554', "['Ghulam Haider']",
#         'Meri Duaon Ka Ya Rab Asar Dikha'], dtype='<U661'),
#  array(['94.44109463533853', "['Margarita Cueto', 'Carlos Mejía']",
#         'Soy Virgencita'], dtype='<U661'),
#  array(['94.6156174925536', "['Olle Adolphson']", 'Snurra min jord'],
#        dtype='<U661'),
#  array(['94.82739013180395', "['B.B. King']", "You're Losin' Me"],
#        dtype='<U661'),
#  array(['94.44922208601172',
#         "['Emmanuel Chabrier', 'Robert Casadesus', 'Gaby Casadesus']",
#         'Trois Valses romantiques: I. Très vite et impétueusement'],
#        dtype='<U661'),
#  array(['95.04025462359623', "['Kodaline']", 'Wherever You Are'],
#        dtype='<U661'),
#  array(['94.91323787063061', "['Van Morrison']",
#         "I've Been Working - Early Version; Take 2"], dtype='<U661'),
#  array(['94.89293193812041', "['The Rolling Stones']",
#         'Sympathy For The Devil - 50th Anniversary Edition'], dtype='<U661'),
#  array(['94.92752765406696', "['Ha*Ash']", 'Te Dejo en Libertad'],
#        dtype='<U661'),
#  array(['94.76882530841506', "['Enya']", 'Drifting'], dtype='<U661'),
#  array(['94.58320672949382', "['Jean Marion', 'Bourvil']",
#         'Les Culottes rouges (1960) La fuite'], dtype='<U661'),
#  array(['95.00476104566064', "['Red Hot Chili Peppers']",
#         "Walkin' On Down The Road"], dtype='<U661'),
#  array(['94.95212180764693', "['Tina Turner']",
#         'I Might Have Been Queen - 2015 Remaster'], dtype='<U661'),
#  array(['95.07295857951358', "['Akwid']", 'Sin Ti'], dtype='<U661'),
#  array(['94.96301080451066', "['Young Thug']", 'Die Today'], dtype='<U661'),
#  array(['94.6956505199491', "['Elaine Paige', 'Barbara Dickson']",
#         'I Know Him So Well'], dtype='<U661'),
#  array(['95.10494398037082', "['The Tragically Hip']", 'Three Pistols'],
#        dtype='<U661'),
#  array(['94.7242067533183', "['Ella Fitzgerald']", 'The Man That Got Away'],
#        dtype='<U661'),
#  array(['94.55774789069908', "['Harry Belafonte']", 'Unchained Melody'],
#        dtype='<U661'),
#  array(['95.01562108503742', "['Crosby, Stills & Nash']",
#         '49 Bye-Byes - 2005 Remaster'], dtype='<U661'),
#  array(['94.62007252015505', "['Seweryn Goszczyński']",
#         'Chapter 3.9 - Zamek kaniowski'], dtype='<U661'),
#  array(['94.84293046429688', "['Bo Burnham']",
#         'WORDS, WORDS, WORDS (studio)'], dtype='<U661'),
#  array(['94.66533840347742', "['Lefty Frizzell']",
#         "I Don't Trust You Anymore"], dtype='<U661'),
#  array(['95.10677337356819', "['Tom Petty and the Heartbreakers']",
#         "A Woman In Love (It's Not Me)"], dtype='<U661'),
#  array(['95.04124051472995', "['Lady Gaga']", 'Marry The Night'],
#        dtype='<U661'),
#  array(['94.64483467944724', "['Эрих Мария Ремарк']",
#         'Часть 106.2 - Триумфальная арка'], dtype='<U661'),
#  array(['94.75055303335547',
#         "['Doris Day', 'Frank DeVol & His Orchestra']",
#         'Hooray for Hollywood (with Frank DeVol & His Orchestra)'],
#        dtype='<U661'),
#  array(['94.5105080331663', "['Woody Guthrie']",
#         'Race you down the mountain'], dtype='<U661'),
#  array(['94.90493004454616', "['Bob Dylan']",
#         'Something There Is About You'], dtype='<U661'),
#  array(['94.8029341470417', "['Eric Clapton']", 'Get Ready'], dtype='<U661'),
#  array(['94.76440765349017', "['J.J. Johnson']", 'Hello, Young Lovers'],
#        dtype='<U661'),
#  array(['95.12760009259388', "['Wild Cherry']",
#         'What In The Funk Do You See'], dtype='<U661'),
#  array(['95.07104814604723', "['Twisted Sister']", 'Come out and Play'],
#        dtype='<U661'),
#  array(['94.96940907026483', "['Wage War']", 'The River'], dtype='<U661'),
#  array(['95.135679652765', "['Mary Jane Girls']", 'Candy Man'],
#        dtype='<U661'),
#  array(['94.85821173784193', "['Run The Jewels']", 'Run the Jewels'],
#        dtype='<U661'),
#  array(['94.87484476045327', "['Big Star']", 'Thirteen'], dtype='<U661'),
#  array(['94.8591303016144', "['Hootie & The Blowfish']",
#         'Hey, Hey What Can I Do - 2019 Remaster'], dtype='<U661'),
#  array(['94.4467515224065', "['Shamshad Begum', 'Mubarak Begum']",
#         'Aaj Ghar Wale Nahin Bhaiya'], dtype='<U661'),
#  array(['94.99388783983767', "['Frank Zappa', 'The Mothers Of Invention']",
#         'Wowie Zowie'], dtype='<U661'),
#  array(['94.62871121293226', "['Эрнест Хемингуэй']",
#         'Часть 27.2 - Прощай оружие'], dtype='<U661'),
#  array(['94.6163762919599', "['Igor Stravinsky']",
#         "The Soldier's Tale Suite: III. Pastorale"], dtype='<U661'),
#  array(['95.05866075349343', "['The Starting Line']", 'The Best Of Me'],
#        dtype='<U661'),
#  array(['94.52984096056137', "['Peggy Lee']", 'My Heart Stood Still'],
#        dtype='<U661'),
#  array(['94.53802971615761', "['Dooley Wilson']",
#         'Medley (It Had to Be You / Shine)'], dtype='<U661'),
#  array(['95.04991474472114', "['Alan Jackson']", "Livin' On Love"],
#        dtype='<U661'),
#  array(['94.59511199034236', "['Gene Autry']",
#         'Rudolph the Red-Nosed Reindeer'], dtype='<U661'),
#  array(['94.56687520171164', "['Willie Dixon']", 'Big 3 Stomp'],
#        dtype='<U661'),
#  array(['94.72547532102342', "['El Chapo De Sinaloa']",
#         'Recostada En La Cama'], dtype='<U661'),
#  array(['94.98672675487326', "['Queen']",
#         'Flick Of The Wrist - Remastered 2011'], dtype='<U661'),
#  array(['94.62883198319327', "['Danny Wright']", 'Forrest Gump Suite'],
#        dtype='<U661'),
#  array(['94.50219002843674', "['Honoré de Balzac']",
#         'Kapitel 10 - Die läßliche Sünde'], dtype='<U661'),
#  array(['94.82536856500063', "['Bushy']", "There's a Light"], dtype='<U661'),
#  array(['95.10433677588696', "['Chucho Ponce Los Daddys de Chinantla']",
#         'Lucerito'], dtype='<U661'),
#  array(['94.70728663270211', "['Etta James']", 'Seven Day Fool'],
#        dtype='<U661'),
#  array(['95.01681480005475', "['Fourplay', 'Chaka Khan', 'Nathan East']",
#         'Between the Sheets'], dtype='<U661'),
#  array(['94.69859567938822', "['The Dave Clark Five']",
#         'I Need You I Love You - 2019 - Remaster'], dtype='<U661'),
#  array(['94.824171745101', "['Boz Scaggs']", 'Slow Dancer'], dtype='<U661'),
#  array(['94.30936724590276', "['Francisco Canaro', 'Azucena Maizani']",
#         'Fabriquera, Fabriquera - Remasterizado'], dtype='<U661'),
#  array(['95.13711572574552', "['Najee']", 'For The Love Of You'],
#        dtype='<U661'),
#  array(['95.02948556122249', "['Calvin Harris', 'Florence Welch']",
#         'Sweet Nothing (feat. Florence Welch)'], dtype='<U661'),
#  array(['95.00208462387201', "['The Beatles']", 'Fixing A Hole - Take 1'],
#        dtype='<U661'),
#  array(['94.5392979984042', "['Osvald Helmuth']",
#         'Hende konen, kællinge, madammen'], dtype='<U661'),
#  array(['94.99281669125789', "['Los Rieleros Del Norte']",
#         'Corrido de Durango'], dtype='<U661'),
#  array(['94.37158839090951', "['Münir Nurettin Selçuk']",
#         'Vesvese (Sevdiğin Dünyalar Kadar)'], dtype='<U661'),
#  array(['95.15044354352189', "['Ben Lee']", 'Catch My Disease'],
#        dtype='<U661'),
#  array(['94.98726615267924', "['Olga Tañón']", 'Una Noche Mas'],
#        dtype='<U661'),
#  ...]

# %%
playlist_added = ids[predictions.argsort()][::-1][:100]

# %%
playlist_name = "CS464 - Term Project (LINEAR REGRESSION)"
scope = "playlist-modify-public"
username = input('Enter username:')
token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri=redirect_uri) 
sp = spotipy.Spotify(auth=token)
sp.user_playlist_create(username, name=playlist_name)
playlists = sp.user_playlists(username)
sp.user_playlist_add_tracks(username, playlists['items'][0]['id'], list(playlist_added))
# Out:
# Enter username:ardabyk07
# {'snapshot_id': 'MiwwNzY4OTJmN2ExM2I3ZGFhNTAxMDI0ZmMwNTVkYjc3NmYwODgzYzAw'}
